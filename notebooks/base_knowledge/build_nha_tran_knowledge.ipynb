# %%
# !pip install -q google-genai underthesea transformers torch numpy qdrant-client uuid6
# !pip install qdrant-client sentence-transformers -q
# !pip install -q groq  pydantic
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 25.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 398.1/398.1 kB 14.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 17.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.3/142.3 kB 3.6 MB/s eta 0:00:00

# %% [markdown]
# # Mục mới

# %%
# str(uuid6.uuid7())

# %% [markdown]
# ### import and config
# import, danh sách can chi, check can chi trong văn bản (đầu trang hoặc đầu dòng (\n))
#
# Số lượng trang cho từng lần gọi api
#
# Các kí hiệu chọn để ngắt dòng (RecursiveCharacterTextSplitter )
#
# Số lượng word, min and max overlap, max context lenght của model embedding

# %%
from __future__ import annotations

import abc
import json
import os
import pathlib
import re
import time
import urllib.request
import uuid6
from dataclasses import dataclass
from typing import Optional

from __future__ import annotations

import abc
import json
import os
import pathlib
import re
import time
import urllib.request
import uuid6
from dataclasses import dataclass
from typing import Optional

import numpy as np
import torch
from pydantic import BaseModel
from transformers import AutoModel, AutoTokenizer
from underthesea import word_tokenize
from google.colab import userdata
from qdrant_client import QdrantClient, models
from qdrant_client.http.models import Distance, VectorParams, PointStruct

# 60-cycle sexagenary calendar names (Giáp Tý → Quý Hợi)
CAN_CHI_60: list[str] = [
    "Giáp Tý",  "Ất Sửu",  "Bính Dần", "Đinh Mão", "Mậu Thìn", "Kỷ Tỵ",
    "Canh Ngọ", "Tân Mùi", "Nhâm Thân","Quý Dậu",  "Giáp Tuất","Ất Hợi",
    "Bính Tý",  "Đinh Sửu","Mậu Dần",  "Kỷ Mão",   "Canh Thìn","Tân Tỵ",
    "Nhâm Ngọ", "Quý Mùi", "Giáp Thân","Ất Dậu",   "Bính Tuất","Đinh Hợi",
    "Mậu Tý",   "Kỷ Sửu",  "Canh Dần", "Tân Mão",  "Nhâm Thìn","Quý Tỵ",
    "Giáp Ngọ", "Ất Mùi",  "Bính Thân","Đinh Dậu", "Mậu Tuất", "Kỷ Hợi",
    "Canh Tý",  "Tân Sửu", "Nhâm Dần", "Quý Mão",  "Giáp Thìn","Ất Tỵ",
    "Bính Ngọ", "Đinh Mùi","Mậu Thân", "Kỷ Dậu",   "Canh Tuất","Tân Hợi",
    "Nhâm Tý",  "Quý Sửu", "Giáp Dần", "Ất Mão",   "Bính Thìn","Đinh Tỵ",
    "Mậu Ngọ",  "Kỷ Mùi",  "Canh Thân","Tân Dậu",  "Nhâm Tuất","Quý Hợi",
]


# Sort longest-first to prevent sub-string matches (e.g. "Giáp" before "Giáp Tý")
_CAN_CHI_PATTERN: str = "|".join(
    re.escape(cc) for cc in sorted(CAN_CHI_60, key=len, reverse=True)
)
print(f"in can chi nè : {_CAN_CHI_PATTERN}\n")


# Danh sách tên các tháng trong năm (Tháng 1 → Tháng 12)
MONTHS_LIST: list[str] = [
    "Tháng 1", "Tháng 2", "Tháng 3", "Tháng 4", "Tháng 5", "Tháng 6",
    "Tháng 7", "Tháng 8", "Tháng 9", "Tháng 10", "Tháng 11", "Tháng 12"
]

# Tạo Pattern mẫu dạng: (Tháng 1|Tháng 2|...|Tháng 12)
_MONTHS_PATTERN: str = "|".join(MONTHS_LIST)

# Regex nhận diện Tháng ở đầu dòng (hỗ trợ cả trường hợp có mã [54a] hoặc không)
# MONTHS_LINE_START_RE: re.Pattern = re.compile(
#     r"^(?:\[\d{2}[ab]\]\s+)?(" + _MONTHS_PATTERN + r")(?=\s*|\,|[\[\(\.]|$)",
#     re.MULTILINE
# )


# Regex hỗ trợ cả: [Mã]? + [Năm]? + [Can Chi hoặc Tháng] + [Nhìn trước]
CAN_CHI_MONTH_RE: re.Pattern = re.compile(
    r"^(?:\[\d{1,2}[ab]\]\s+)?(?:Năm\s+)?(?:" + _CAN_CHI_PATTERN + r"|" + _MONTHS_PATTERN + r")(?=\s*|\,|[\[\(\.]|$)",
    re.MULTILINE
)



# Tìm thẻ và trang trong văn bản [1], [2], …  , [PAGE:12]
FOOTNOTE_REF_RE: re.Pattern = re.compile(r"\[(\d{1,2})\]")
PAGE_MARKER_RE: re.Pattern = re.compile(r"\n\s*\[\[\[PAGE:(\d+)\]\]\]\s*\n")


# Separator priority list for word-aware text splitting
SEPARATORS: list[str] = ["\n\n", "\n", ".", "?", "!", ";", ":", ",", " ", ""]


# Sliding-window page counts per book
BOOK_WINDOW_SIZES: dict[str, int] = {
    "Đại Việt Sử Ký Toàn Thư":                3,
    "Khâm Định Việt Sử Thông Giám Cương Mục":   3,
    "Việt Sử Toàn Thư":                        3,
    "Vương Triều Trần":                         5
}
DEFAULT_WINDOW_SIZE: int = 5


# Model IDs
# GEMINI_MODEL_ID: str = "gemini-2.5-flash"
GEMINI_MODEL_ID: str = "gemini-3.1-flash-lite"
# GEMINI_MODEL_ID: str = "Gemini 3.5 Flash"

GROQ_MODEL_LLAMA_70B = "llama-3.3-70b-versatile"
GROQ_MODEL_LLAMA_8B  = "llama-3.1-8b-instant"
GROQ_MODEL_QWEN      = "qwen/qwen3-32b"


EMBEDDING_MODELS = {
    "bkai": {
        "model_id": "bkai-foundation-models/vietnamese-bi-encoder",
    },
    "dangvantuan": {
        "model_id": "dangvantuan/vietnamese-embedding",
    },
    "bge_m3": {
        "model_id": "BAAI/bge-m3",
    },
    "gte": {
        "model_id": "Alibaba-NLP/gte-multilingual-base",
    },
    "halong": {
        "model_id": "hiieu/halong_embedding",
    },
    "aiteamvn": {
        "model_id": "AITeamVN/Vietnamese_Embedding",
    },
}


# MODEL_KEY = "bkai"
# MODEL_KEY = "halong"
# MODEL_KEY = "gte"
MODEL_KEY = "aiteamvn"
# MODEL_KEY = "bge_m3"
# MODEL_KEY = "dangvantuan"

CHUNK_CONTEXT_LENGTH = 512


EMBED_MODEL_ID = EMBEDDING_MODELS[MODEL_KEY]["model_id"]


# GEMINI_MODEL_ID: str = "gemini-2.5-flash"
GEMINI_MODEL_ID: str = "gemini-3.1-flash-lite"

GROQ_MODEL_LLAMA_70B = "llama-3.3-70b-versatile"
GROQ_MODEL_LLAMA_8B  = "llama-3.1-8b-instant"
GROQ_MODEL_QWEN      = "qwen/qwen3-32b"



CHUNKING_CONFIGS = {
    256: {
        # semantic target
        "ideal_min_chunks": 2,
        "ideal_max_chunks": 3,

        # hard cap by mini-chunk count
        "max_group_size": 5,

        # token constraints
        "target_token_min": 90,
        "target_token_max": 210,

        # hard safety limits
        "min_chunk_tokens": 70,
        "max_chunk_tokens": 240,

        # overlap
        "overlap_tokens": 20,

        "output_file": "chunks_256.json",
    },

    512: {
        "ideal_min_chunks": 3,
        "ideal_max_chunks": 6,

        "max_group_size":9,

        "target_token_min": 180,
        "target_token_max": 400,

        # tránh sát trần 512
        "min_chunk_tokens": 120,
        "max_chunk_tokens": 460,

        "overlap_tokens": 30,

        "output_file": "chunks_512.json",
    },

    1024: {
        "ideal_min_chunks": 6,
        "ideal_max_chunks": 12,

        "max_group_size": 17,

        "target_token_min": 350,
        "target_token_max": 800,

        "min_chunk_tokens": 220,
        "max_chunk_tokens": 950,

        "overlap_tokens": 40,

        "output_file": "chunks_1024.json",
    },

    2048: {
        "ideal_min_chunks": 12,
        "ideal_max_chunks": 24,

        "max_group_size": 32,

        "target_token_min": 700,
        "target_token_max": 1500,

        "min_chunk_tokens": 400,
        "max_chunk_tokens": 1800,

        "overlap_tokens": 60,

        "output_file": "chunks_2048.json",
    },
}

CHUNK_CONFIG = CHUNKING_CONFIGS[CHUNK_CONTEXT_LENGTH]


# Mini-chunk & merge sizing
MINI_CHUNK_WORDS: int  = 35     # ≈ 55-70 BPE tokens for classical Vietnamese
OVERLAP_TOK_MIN:  int  = 20
OVERLAP_TOK_MAX:  int  = CHUNK_CONFIG["overlap_tokens"]

OVERLAP_TOKENS = CHUNK_CONFIG["overlap_tokens"]

MIN_CHUNK_TOKENS = CHUNK_CONFIG["min_chunk_tokens"]
MAX_EMBED_TOKENS = CHUNK_CONFIG["max_chunk_tokens"]

def build_collection_name(model_key: str, chunk_size: int) -> str:
    return f"history_{model_key}_chunk_{chunk_size}"


# Lấy cấu hình bảo mật từ Secrets của Colab
QDRANT_URL = userdata.get('QDRANT_URL')
API_KEY = userdata.get('QDRANT_API_KEY')

client = QdrantClient(url=QDRANT_URL, api_key=API_KEY)


device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"[DEVICE] {device}")



COLLECTION_NAME = build_collection_name(
    MODEL_KEY,
    CHUNK_CONTEXT_LENGTH
)

tokenizer = AutoTokenizer.from_pretrained(
    EMBED_MODEL_ID,
    trust_remote_code=True
)

embed_model = AutoModel.from_pretrained(
    EMBED_MODEL_ID,
    trust_remote_code=True
).to(device).eval()

VECTOR_SIZE = embed_model.config.hidden_size
print("MODEL:", MODEL_KEY)
print("MODEL ID:", EMBED_MODEL_ID)
print("COLLECTION:", COLLECTION_NAME)
print("VECTOR SIZE:", VECTOR_SIZE)

# Check if collection exists and its configuration matches
if client.collection_exists(collection_name=COLLECTION_NAME):
    collection_info = client.get_collection(collection_name=COLLECTION_NAME).config
    current_vector_size = collection_info.params.vectors.size

    if current_vector_size != VECTOR_SIZE:
        raise ValueError(
            f"Collection '{COLLECTION_NAME}' có vector size {current_vector_size}, "
            f"nhưng model hiện tại cần {VECTOR_SIZE}."
        )

    print(f"Collection '{COLLECTION_NAME}' đã tồn tại và khớp vector size {VECTOR_SIZE}.")
else:
    client.create_collection(
        collection_name=COLLECTION_NAME,
        vectors_config=VectorParams(
            size=VECTOR_SIZE,
            distance=Distance.COSINE
        )
    )
    print(f"Đã tạo collection mới: {COLLECTION_NAME}, vector size={VECTOR_SIZE}.")
# Out:
# in can chi nè : Nhâm\ Thân|Giáp\ Tuất|Canh\ Thìn|Giáp\ Thân|Bính\ Tuất|Nhâm\ Thìn|Bính\ Thân|Giáp\ Thìn|Canh\ Tuất|Bính\ Thìn|Canh\ Thân|Nhâm\ Tuất|Bính\ Dần|Đinh\ Mão|Mậu\ Thìn|Canh\ Ngọ|Đinh\ Sửu|Nhâm\ Ngọ|Đinh\ Hợi|Canh\ Dần|Giáp\ Ngọ|Đinh\ Dậu|Mậu\ Tuất|Nhâm\ Dần|Bính\ Ngọ|Đinh\ Mùi|Mậu\ Thân|Giáp\ Dần|Giáp\ Tý|Tân\ Mùi|Quý\ Dậu|Bính\ Tý|Mậu\ Dần|Quý\ Mùi|Tân\ Mão|Canh\ Tý|Tân\ Sửu|Quý\ Mão|Tân\ Hợi|Nhâm\ Tý|Quý\ Sửu|Đinh\ Tỵ|Mậu\ Ngọ|Tân\ Dậu|Quý\ Hợi|Ất\ Sửu|Ất\ Hợi|Kỷ\ Mão|Tân\ Tỵ|Ất\ Dậu|Mậu\ Tý|Kỷ\ Sửu|Quý\ Tỵ|Ất\ Mùi|Kỷ\ Hợi|Kỷ\ Dậu|Ất\ Mão|Kỷ\ Mùi|Kỷ\ Tỵ|Ất\ Tỵ
#
# [DEVICE] cpu
# config.json:   0%|          | 0.00/708 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/964 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.27G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/391 [00:00<?, ?it/s]
# MODEL: aiteamvn
# MODEL ID: AITeamVN/Vietnamese_Embedding
# COLLECTION: history_aiteamvn_chunk_512
# VECTOR SIZE: 1024
# Collection 'history_aiteamvn_chunk_512' đã tồn tại và khớp vector size 1024.

# %% [markdown]
# ### Data Structures
# $$\text{Văn bản thô (chứa [PAGE:N])} \longrightarrow \text{PageSpan} \longrightarrow \text{MiniChunk} \longrightarrow \text{FinalChunk (Lưu Database)}$$

# %%
@dataclass
class PageSpan:
    """One [PAGE:N] block from source text, with the marker stripped."""
    page_no:      int   # -1 if text precedes the first marker
    start_offset: int   # char offset in the reconstructed marker-free text
    end_offset:   int
    text:         str


@dataclass
class MiniChunk:
    """Small ~35-word fragment before LLM semantic merging."""
    idx:           int
    text:          str


    start_offset:  int   # absolute offset in clean-text coordinate space
    end_offset:    int
    pages:         list[int]
    footnote_refs: list[str]   # ordered, deduplicated


@dataclass
class FinalChunk:
    """Production-ready chunk post-embedding."""
    chunk_id:       str
    book_name:      str
    pages:          list[int]
    raw_text:       str          # exact source text, never mutated
    segmented_text: str          # underthesea-segmented version (for embedding)
    footnote_refs:  list[str]
    footnotes:      dict[str, str]
    token_count:    int
    # vector:         list[float]

# %% [markdown]
# ###  PAGE PARSER
# Tách trang: Lưu vị trí đầu trang, cuối trang, nội dung trang
# Trả về văn bản sạch không có số trang
# Trả về số trang khi người dùng đưa cho một PageSpan

# %%
def parse_page_spans(full_text: str) -> list[PageSpan]:
    # tìm thẻ page
    markers = list(PAGE_MARKER_RE.finditer(full_text))
    # print(f"tìm thẻ page: {markers}\n")

    spans:   list[PageSpan] = []
    cursor = 0   # con trỏ vị trí (vị trí tiếp theo của trang)

 # Nếu không thấy thì là trang -1 và toàn bộ văn bản đều ở 1 trang
    if not markers:
        spans.append(PageSpan(-1, 0, len(full_text), full_text))
        # print(f"[PARSER] No [PAGE:N] markers found — "
        #       f"entire text treated as page -1 ({len(full_text):,} chars)")
        return spans

    # xử lí văn bản trước thẻ PAGE
    pre = full_text[: markers[0].start()]
    if pre:
        spans.append(PageSpan(-1, 0, len(pre), pre))
        cursor = len(pre)   # chiều dài của văn bản trước PAGE
        # print(f"[PARSER] Pre-marker text: {len(pre):,} chars → page_no=-1")

# Vòng lặp xử lý từng trang (i số page tìm được còn m là đối tượng )
    for i, m in enumerate(markers):
        page_no   = int(m.group(1))    # lấy phần sau (chứa số trang )
        raw_start = m.end()
        raw_end   = markers[i + 1].start() if i + 1 < len(markers) else len(full_text)
        page_text = full_text[raw_start:raw_end]   # văn bản trong 1 trang

        span_start = cursor
        span_end   = cursor + len(page_text)
        spans.append(PageSpan(page_no, span_start, span_end, page_text))    # lưu các thông tin của trang
        cursor = span_end
        # print(f"Nội dung của một trang {page_text} \n\n\n\n\n\n")
    # print(f"[PARSER] {len(spans)} PageSpans | "
    #       f"pages {spans[0].page_no} → {spans[-1].page_no} | "
    #       f"clean-text total {cursor:,} chars")
    return spans



# trả về toàn bộ văn bản sạch không có page
def build_clean_text(spans: list[PageSpan]) -> str:
    return "".join(s.text for s in spans)




# Tìm xem đoạn từ ký tự [start] đến [end] đang nằm ở (những) trang sách số mấy? trả về [4, 5]
def map_pages_to_slice(
    spans: list[PageSpan], start: int, end: int
) -> list[int]:
    result: list[int] = []
    for s in spans:
        if s.end_offset   <= start:
            continue
        if s.start_offset >= end:
            break
        if s.page_no != -1:
            result.append(s.page_no)
    return sorted(set(result))

# %% [markdown]
# ### Cắt theo can chi (window text)
# Cắt theo trang mặc định sau đó mới duyệt ngược lại cắt theo can chi

# %%
@dataclass
class WindowResult:
    text: str
    pages: list[int]
    global_start: int
    global_end: int


def _get_window_size(book_name: str) -> int:
    for key, size in BOOK_WINDOW_SIZES.items():
        if key.lower() in book_name.lower() or book_name.lower() in key.lower():
            return size
    return DEFAULT_WINDOW_SIZE


def create_dynamic_can_chi_windows(
    spans: list[PageSpan], book_name: str
) -> list[WindowResult]:

    N = _get_window_size(book_name)
    print(f"\n[WINDOWS] book='{book_name}' | window_size={N} pages")

    windows: list[WindowResult] = []
    remainder_text: str = ""
    remainder_origin: int = 0

    real_spans = [s for s in spans if s.page_no != -1]
    if not real_spans:
        return []

    idx = 0
    total = len(spans)

    while idx < total or remainder_text.strip():

        batch = spans[idx: idx + N]
        is_last = idx + len(batch) >= total

        if not batch and not remainder_text.strip():
            break

        batch_text = "".join(s.text for s in batch) if batch else ""

        if remainder_text:
            pool_text = remainder_text + batch_text
            pool_start = remainder_origin
        else:
            pool_text = batch_text
            pool_start = batch[0].start_offset if batch else remainder_origin

        if not pool_text.strip():
            idx += len(batch)
            continue

        if is_last:
            cut_local = len(pool_text)

        else:
            last_page_text = batch[-1].text if batch else ""
            last_page_start_in_pool = len(pool_text) - len(last_page_text)

            cut_local = -1

            matches = list(CAN_CHI_MONTH_RE.finditer(last_page_text))
            if matches:
                cut_local = last_page_start_in_pool + matches[-1].start()

            if cut_local <= 0:
                para = last_page_text.rfind("\n\n")
                if para != -1:
                    cut_local = last_page_start_in_pool + para + 2

            if cut_local <= 0:
                nl = last_page_text.rfind("\n")
                if nl != -1:
                    cut_local = last_page_start_in_pool + nl + 1

            if cut_local <= 0:
                dot = last_page_text.rfind(".")
                if dot != -1:
                    cut_local = last_page_start_in_pool + dot + 1

            if cut_local <= 0:
                cut_local = len(pool_text)

        window_text = pool_text[:cut_local]
        window_len = len(window_text)

        if (
            not is_last
            and window_len < 6000
            and (idx + len(batch)) < total
        ):
            extra_batch = spans[idx + len(batch): idx + len(batch) + 1]

            if extra_batch:
                extra_text = "".join(s.text for s in extra_batch)

                pool_text += extra_text

                # Tính lại điểm cắt dựa trên trang cuối mới
                last_page_text = extra_batch[-1].text
                last_page_start_in_pool = len(pool_text) - len(last_page_text)

                cut_local = -1

                matches = list(CAN_CHI_MONTH_RE.finditer(last_page_text))

                if matches:
                    cut_local = last_page_start_in_pool + matches[-1].start()

                if cut_local <= 0:
                    para = last_page_text.rfind("\n\n")
                    if para != -1:
                        cut_local = last_page_start_in_pool + para + 2

                if cut_local <= 0:
                    nl = last_page_text.rfind("\n")
                    if nl != -1:
                        cut_local = last_page_start_in_pool + nl + 1

                if cut_local <= 0:
                    dot = last_page_text.rfind(".")
                    if dot != -1:
                        cut_local = last_page_start_in_pool + dot + 1

                if cut_local <= 0:
                    cut_local = len(pool_text)

                window_text = pool_text[:cut_local]
                window_len = len(window_text)

                batch.extend(extra_batch)



        window_start = pool_start
        window_end = pool_start + cut_local

        remainder_text = pool_text[cut_local:]
        remainder_origin = pool_start + cut_local

        idx += len(batch)

        if not window_text.strip():
            if is_last:
                break
            continue

        pages = map_pages_to_slice(spans, window_start, window_end)

        windows.append(WindowResult(
            text=window_text,
            pages=pages,
            global_start=window_start,
            global_end=window_end,
        ))

        if is_last:
            break

    return windows

# %%
# def run_pipeline(
#     input_json:         dict,
#     backends:           list[LLMBackend],
#     batch_orchestrator: Optional[GeminiBatchOrchestrator] = None,
# ) -> list[dict]:

#     book_name          = input_json["book_name"]
#     full_text          = input_json["full_text"]
#     page_footnotes_map = input_json["page_footnotes_map"]

# # bóc tách trang
#     spans = parse_page_spans(full_text)

# # chia sách thành các trang cho các lần gọi api
#     windows = create_dynamic_can_chi_windows(spans, book_name)

#     total_windows: int        = len(windows)

#     for wi, window in enumerate(windows):
#         print(f"\n{'─' * 72}")
#         pg_str = str(window.pages[:6]) + ("…" if len(window.pages) > 6 else "")
#         print(f"  WINDOW {wi + 1:>4}/{total_windows} | pages={pg_str} | chars={len(window.text):,} \n\n\n")

# %% [markdown]
# ### Cấu trúc cắt
# Cấu hình các thành phần có thể cắt tùy vào từng loại sách
#
# Cắt một chuỗi văn bản dài thành các đoạn nhỏ hơn

# %%
def detect_structural_boundaries(text: str, book_name: str) -> list[int]:
    bk = book_name
    offsets: set[int] = {0, len(text)}

    if "Đại Việt Sử Ký Toàn Thư" in bk:
        # Can-Chi names at the start of a line
        for m in CAN_CHI_MONTH_RE.finditer(text):
            offsets.add(m.start())

    elif "Khâm Định Việt Sử Thông Giám Cương Mục" in bk:
        # Lines that begin with "Năm <Can-Chi>"
        pat = re.compile(
            r"^Năm\s+(?:" + _CAN_CHI_PATTERN + r")(?=\s|$)", re.MULTILINE
        )
        for m in pat.finditer(text):
            offsets.add(m.start())

    elif "Việt Sử Toàn Thư" in bk:
        # Numbered section markers: "12 - " at line start
        for m in re.finditer(r"^\d+\s*-\s*", text, re.MULTILINE):
            offsets.add(m.start())
        # Paragraph breaks (soft boundaries)
        for m in re.finditer(r"\n{1,}", text):
            offsets.add(m.end())

    elif "Vương Triều Trần" in bk:
        # Soft paragraph breaks only
        for m in re.finditer(r"\n{1,}", text):
            offsets.add(m.end())

    else:
        for m in re.finditer(r"\n{1,}", text):
            offsets.add(m.end())

    result = sorted(offsets)
    print(f"      [STRUCT] {len(result)} structural boundaries | book='{book_name[:35]}'")
    return result



def split_text_by_words(
    text: str, max_words: int, separators: list[str]
) -> list[tuple[int, int, str]]:
    if not text.strip():
        return []
    text = re.sub(r'(?<=[a-zà-ỹ])[\n\;](?=[a-zà-ỹ])', ' ', text)
    if len(text.split()) <= max_words:
        return [(0, len(text), text)]

    results: list[tuple[int, int, str]] = []
    cursor = 0

    while cursor < len(text):
        remaining = text[cursor:]
        if not remaining.strip():
            break

        if len(remaining.split()) <= max_words:
            results.append((cursor, len(text), remaining))
            break

        word_count = 0
        in_word    = False
        approx_end = len(remaining)
# đếm số lượng từ
        for ci, ch in enumerate(remaining):
            is_ws = ch in (" ", "\n", "\t", "\r")
            if is_ws:
                in_word = False
            elif not in_word:
                in_word = True
                word_count += 1
                if word_count > max_words:
                    approx_end = ci
                    break
        # print(f"Số lượng từ: {in_word} \n\n\n")
        # ── Walk backward to find the best separator at or before approx_end ─
        cut_local: int = -1
        for sep in separators:
            if sep == "":
                # Empty string = hard-cut at approx_end (last resort)
                cut_local = approx_end
                break
            search_bound = min(approx_end + len(sep), len(remaining))
            idx = remaining.rfind(sep, 0, search_bound)
            if idx != -1 and (idx + len(sep)) > 0:
                cut_local = idx + len(sep)
                break

        if cut_local <= 0:
            cut_local = approx_end
        if cut_local <= 0 or cut_local > len(remaining):
            cut_local = len(remaining)

        frag = remaining[:cut_local]   # exact source slice — no mutation
        if frag.strip():
            results.append((cursor, cursor + cut_local, frag))

        cursor += cut_local

    return results

# %% [markdown]
# ### Mini Chunk Creation (rule-based pre-segmentation)
# Từ các trang sách tách tiếp thành các thành phần bỏ hơn
# Từ các thành phần trên tách tiếp thành các chunk có kích thước khoản 35 word

# %%
def create_mini_chunks(
    window: WindowResult, spans: list[PageSpan], book_name: str
) -> list[MiniChunk]:

    text       = window.text
    # print(f"window text\n {text} \n\n\n")
    boundaries = detect_structural_boundaries(text, book_name)
    # print(f"boundaries\n {boundaries} \n\n\n")

    mini_chunks: list[MiniChunk] = []
    idx = 0

    for bi in range(len(boundaries) - 1):
        seg_start = boundaries[bi]
        seg_end   = boundaries[bi + 1]
        seg_text  = text[seg_start:seg_end]   # exact source slice
        # print(f"các phần đoạn văn trong trang \n {seg_text} \n\n\n")
        if not seg_text.strip():
            continue

        frags = split_text_by_words(seg_text, MINI_CHUNK_WORDS, SEPARATORS)

        for (local_s, local_e, frag_text) in frags:
            if not frag_text.strip():
                continue

            # Absolute offsets in the global clean-text coordinate space
            abs_start = window.global_start + seg_start + local_s
            abs_end   = window.global_start + seg_start + local_e

            # Page mapping
            pages = map_pages_to_slice(spans, abs_start, abs_end)
            # print(f"map_pages_to_slice: \n {pages}  index {idx} ")
            # print(f"{frag_text} \n")
            # tok_count = inspect_tokens(frag_text, frag_text, tokenizer, "019e40d8-c484-791c-b758-df87ba39ecba")
            # print(f"tok_count {tok_count} \n\n\n")
            if not pages:
                pages = list(window.pages)   # fallback: window-level pages
                # print("méo hiểu kiểu gì \n\n\n")

            # Footnote refs: dict.fromkeys preserves insertion order & deduplicates
            refs = list(dict.fromkeys(FOOTNOTE_REF_RE.findall(frag_text)))
            # print(f"danh sách footer\n {refs} \n\n\n")
            mini_chunks.append(MiniChunk(
                idx=idx,
                text=frag_text,
                start_offset=abs_start,
                end_offset=abs_end,
                pages=pages,
                footnote_refs=refs,
            ))
            idx += 1

    print(f"    [MINI-CHUNK] window chars={len(text):,} → {len(mini_chunks)} mini-chunks")
    return mini_chunks

# %%
# def run_pipeline(
#     input_json:         dict,
#     backends:           list[LLMBackend],
# ) -> list[dict]:

#     book_name          = input_json["book_name"]
#     full_text          = input_json["full_text"]
#     page_footnotes_map = input_json["page_footnotes_map"]

# # bóc tách trang
#     spans = parse_page_spans(full_text)

# # chia sách thành các trang cho các lần gọi api
#     windows = create_dynamic_can_chi_windows(spans, book_name)

#     total_windows: int        = len(windows)

#     for wi, window in enumerate(windows):
#         print(f"\n{'─' * 72}")
#         pg_str = str(window.pages[:6]) + ("…" if len(window.pages) > 6 else "")
#         print(f"  WINDOW {wi + 1:>4}/{total_windows} | pages={pg_str} | chars={len(window.text):,} \n\n\n")

#         mini_chunks = create_mini_chunks(window, spans, book_name)
#         if not mini_chunks:
#             print("    [SKIP] No content mini-chunks produced for this window.")
#             continue

# %% [markdown]
# ### call llm

# %% [markdown]
# #### promt và gán nhãn cho input,  output
#
# Luồng chạy: tạo form cho các minichunk sau đó sử dụng llm. llm sử dungj

# %%
class SplitResponse(BaseModel):
    """
    Structured-output schema enforced on every LLM call (batch and sync).
    Guarantees the model can ONLY return a valid JSON object of this shape:
        {"split_after_indices": [3, 7, 12]}
    """
    split_after_indices: list[int]

def build_system_prompt(context_length: int, config: dict) -> str:
    return f"""\
You are an expert semantic chunk-boundary detector specializing in Vietnamese historical chronicles, royal annals, classical Vietnamese historical texts, and academic history documents.

YOUR TASK:
Analyze a sequence of pre-split Vietnamese historical text fragments called "mini-chunks".
Each mini-chunk is formatted as: <start_chunk_i tokens=X>text<end_chunk_i>
Your job is to determine ONLY the indices AFTER which a split must occur, so that the final macro-chunks are perfectly sized for a {context_length}-token embedding model.
STRICT OUTPUT RULES:
1. NEVER rewrite, summarize, translate, paraphrase, normalize, or correct the source text.
2. NEVER output any words, phrases, sentences, names, or quotes from the source text.
3. NEVER explain your reasoning.
4. NEVER use markdown fences.
5. OUTPUT ONLY one valid JSON object on a single line.
6. The JSON object must have exactly this shape:
{{"split_after_indices":[3,7,12]}}

INDEXING RULES:
- Indices are 0-based local mini-chunk indices.
- A split index i means: split AFTER mini-chunk i.
- Never return the final mini-chunk index.
- If no split is needed, return:
{{"split_after_indices":[]}}

VIETNAMESE HISTORICAL SEMANTIC SPLIT CRITERIA:
Insert a split when there is a clear shift in historical context, especially:
- A change in dynasty, reign era, historical year, or Can-Chi cycle.
- A transition to a new king, lord, general, envoy, scholar, official, or political actor.
- A shift to a different geographic location, battlefield, province, diplomatic mission, or administrative area.
- A transition between different event types, such as war, diplomacy, succession, taxation, law, ritual, disaster, rebellion, punishment, appointment, or royal order.
- A structural transition between narrative text, royal edict, decree, memorial, historian commentary, critique, citation, or explanatory note.
- A clear ending of one historical event before the text moves to another event.

ANTI-OVERFRAGMENTATION RULE:
Do NOT split merely because of sentence boundaries.
Do NOT split if the mini-chunks are part of the same continuous event, battle, royal discussion, decree, dialogue, campaign, or explanation.
Keep related historical context together when it remains coherent and within the token limits.
HARD RULE: NEVER split if the current macro-chunk accumulated so far contains fewer than {config["ideal_min_chunks"]} mini-chunks (or is under {config["target_token_min"]} token), unless absolutely forced by a shift in Dynasty. Prioritize grouping smaller events together into a single macro-chunk.
TOKEN SIZE TARGETS:
The embedding model context length is {context_length} tokens.
- Every mini-chunk now has a 'tokens' attribute (e.g., tokens=55).
- HARD LIMIT: Never allow the accumulated tokens of any macro-chunk to exceed {config["max_chunk_tokens"]} tokens.
- If a continuous historical topic is too long and the next chunk would push the total sum over {config["max_chunk_tokens"]} tokens, you MUST force a split immediately at the current index, even if the semantic event is not finished!
The preferred final macro-chunk range is approximately {config["target_token_min"]} to {config["target_token_max"]} tokens.
Avoid creating chunks below {config["min_chunk_tokens"]} tokens unless the text is a complete standalone historical unit.
Avoid creating chunks above {config["max_chunk_tokens"]} tokens.

MINI-CHUNK GROUPING TARGETS:
Prefer {config["ideal_min_chunks"]} to {config["ideal_max_chunks"]} mini-chunks per macro-chunk when the historical context is coherent.
No macro-chunk may contain more than {config["max_group_size"]} mini-chunks.

FORCED SPLIT RULE:
If no clear semantic boundary appears, force a split before the macro-chunk would exceed:
- {config["max_group_size"]} mini-chunks, or
- approximately {config["max_chunk_tokens"]} tokens.

PRIORITY ORDER:
1. Preserve historical semantic coherence.
2. Avoid exceeding token and mini-chunk limits.
3. Avoid very small chunks.
4. Prefer natural historical boundaries over fixed-size boundaries.

OUTPUT FORMAT:
Return EXACTLY one JSON object:
{{"split_after_indices":[...]}}
"""

_USER_TEMPLATE: str = """\
The following {n} tagged mini-chunks are a sequential sub-batch from a Vietnamese historical text.
Review the text content and indices carefully. Output the split indices according to the system instructions.

[START OF MINI-CHUNKS]
{tagged}
[END OF MINI-CHUNKS]

Your JSON response:"""


# form cho các minichunk trước khi gửi cho llm
def _format_tagged_chunks(chunks: list[MiniChunk]) -> str:
    return "\n".join(
        f"<start_chunk_{mc.idx}>{mc.text}<end_chunk_{mc.idx}>"
        for mc in chunks
    )


# Nhận câu trả lời của llm trả về mảng int chứa các vị trí cần cắt
def _parse_split_response(raw: str, n_chunks: int, max_group_size: int,) -> list[int]:
    clean = re.sub(r"^```[a-z]*\n?", "", raw.strip())
    clean = re.sub(r"\n?```$", "", clean.strip())
    clean = re.sub(r"<think>.*?</think>", "", clean, flags=re.DOTALL).strip()

    parsed = json.loads(clean)
    indices = parsed.get("split_after_indices", [])

    max_valid = n_chunks - 2

    #  Lọc split từ LLM
    splits = sorted(
        set(
            int(i) for i in indices
            if isinstance(i, (int, float)) and 0 <= int(i) <= max_valid
        )
    )

    #  Ép cứng: không group nào được dài hơn max_group_size
    forced_splits = []
    group_start = 0

    for split_idx in splits:
        while split_idx - group_start + 1 > max_group_size:
            forced_idx = group_start + int(max_group_size / 2)
            if forced_idx <= max_valid:
                forced_splits.append(forced_idx)
            group_start = forced_idx + int(max_group_size / 2)

        forced_splits.append(split_idx)
        group_start = split_idx + 1

    #  Xử lý đoạn cuối sau split cuối cùng
    last_idx = n_chunks - 1
    while last_idx - group_start + 1 > max_group_size:
        forced_idx = group_start + max_group_size - 1
        if forced_idx <= max_valid:
            forced_splits.append(forced_idx)
        group_start = forced_idx + 1

    return sorted(set(forced_splits))

# %% [markdown]
# #### chọn llm

# %%
# Lớp abstract cho gọi các llm
class LLMBackend(abc.ABC):
    @property
    @abc.abstractmethod
    def label(self) -> str:
        # in ra tên model hay nội dung nào đó để log
        pass

    @abc.abstractmethod # nhận system promt và user promt rồi trả về chuỗi nếu lỗi trả về lỗi
    def call(self, system: str, user: str) -> str:
        pass



class GroqBackend(LLMBackend):

    def __init__(self, api_key: str, model_id: str = GROQ_MODEL_LLAMA_70B):
        from groq import Groq
        self._client = Groq(api_key=api_key)
        self._model  = model_id

    @property
    def label(self) -> str:
        return f"groq/{self._model}"

    def call(self, system: str, user: str) -> str:
        completion = self._client.chat.completions.create(
            model=self._model,
            messages=[
                {"role": "system", "content": system},
                {"role": "user",   "content": user},
            ],
            temperature=0.0,
            max_tokens=2048,
        )
        return completion.choices[0].message.content


class GeminiBackend(LLMBackend):

    def __init__(self, api_key: Optional[str] = None,
                 model_id: str = GEMINI_MODEL_ID):
        from google import genai
        from google.genai import types as _gtypes
        self._types  = _gtypes
        self._client = genai.Client(api_key=api_key) if api_key else genai.Client()
        self._model  = model_id

    @property
    def label(self) -> str:
        return f"gemini-sync/{self._model}"

    def call(self, system: str, user: str) -> str:
        resp = self._client.models.generate_content(
            model=self._model,
            contents=user,
            config=self._types.GenerateContentConfig(
                system_instruction=system,
                temperature=0.0,
                max_output_tokens=4096,
            ),
        )
        return resp.text

# %% [markdown]
# ####  Gọi LLM để gộp các minichunk theo ngữ nghĩa

# %%
def llm_semantic_split(
    mini_chunks: list[MiniChunk],
    backends: list[LLMBackend],
    context_length: int,
    chunk_config: dict,
    max_retries: int = 3,
) -> list[int]:

    if len(mini_chunks) < 3:
        print(f"    [LLM-SYNC] Skipping — only {len(mini_chunks)} chunk(s).")
        return []

    tagged = _format_tagged_chunks(mini_chunks)
    # print(f"tagged {tagged} \n\n\n")
    user_msg = _USER_TEMPLATE.format(n=len(mini_chunks), tagged=tagged)
    system_prompt = build_system_prompt(context_length, chunk_config)
    # print(f"system prommpt {system_prompt} \n\n\n")

    n = len(mini_chunks)
    max_group_size = chunk_config["max_group_size"]

    for backend in backends:
        print(f"    [LLM-SYNC] Trying: {backend.label}")

        for attempt in range(1, max_retries + 1):
            raw = ""

            try:
                raw = backend.call(system_prompt, user_msg)

                print(f"llm trả lời \n{raw}\n")

                valid = _parse_split_response(
                    raw=raw,
                    n_chunks=n,
                    max_group_size=max_group_size,
                )

                print(
                    f"    [LLM-SYNC/{backend.label}] "
                    f"attempt={attempt} | chunks={n} → splits={valid}"
                )

                return valid

            except json.JSONDecodeError as exc:
                print(
                    f"    [LLM-SYNC/{backend.label}] JSON error "
                    f"(attempt {attempt}/{max_retries}): {exc} | "
                    f"raw={repr(raw[:120])}"
                )

            except Exception as exc:
                print(
                    f"    [LLM-SYNC/{backend.label}] Error "
                    f"(attempt {attempt}/{max_retries}): "
                    f"{type(exc).__name__}: {exc}"
                )

            if attempt < max_retries:
                wait = 2 ** attempt
                print(f"    [LLM-SYNC/{backend.label}] Waiting {wait}s…")
                time.sleep(wait)

        print(f"    [LLM-SYNC/{backend.label}] Exhausted — next backend.")

    print("    [LLM-SYNC] ALL backends failed → zero splits for this window.")
    return []

# %% [markdown]
# ### Semantic Merging
# Merge theo kết quả của gemini trả về
# Và overlap các chunk

# %%
def _tok_count_full(text: str, tokenizer) -> int:
    return len(tokenizer.encode(text, add_special_tokens=True, truncation=False))

 # group theo danh sách mà llm gợi ý
def _group_by_splits(
    chunks: list[MiniChunk], split_indices: list[int]
) -> list[list[MiniChunk]]:

    if not chunks:
        return []
    split_set = set(split_indices)
    groups:  list[list[MiniChunk]] = []
    current: list[MiniChunk]       = []
    # thêm các chunks vào current. Nếu gặp điểm cắt thì đẩy vào groups rồi làm sạch
    for mc in chunks:
        current.append(mc)
        if mc.idx in split_set:
            groups.append(current)
            current = []
    if current:
        groups.append(current)
    return groups


  #  raw_text   — văn bản gốc
  # embed_input— raw_text + a semantic overlap slice
  # groups chứa list chunks. trong chunks có các minichunks
def build_chunk_texts(
    groups: list[list[MiniChunk]], tokenizer
) -> list[tuple[str, str]]:

    results: list[tuple[str, str]] = []

    for i, group in enumerate(groups):
        raw   = "".join(mc.text for mc in group)
        embed = raw   # default: no overlap

        if i + 1 < len(groups): # lấy văn bản của chunk tiếp theo
            next_raw  = "".join(mc.text for mc in groups[i + 1])
            next_toks = tokenizer.encode(next_raw, add_special_tokens=False,
                                         truncation=False)
            n_next = len(next_toks)
            MAX = OVERLAP_TOK_MAX;
            MIN = OVERLAP_TOK_MIN;
            if(n_next <=  CHUNK_CONFIG["min_chunk_tokens"]):
                MAX = MAX * 3
                MIN = MIN * 3
            elif(n_next <=  (CHUNK_CONFIG["min_chunk_tokens"] + MAX)):
                MAX = MAX * 2
                MIN = MIN * 2

            if n_next > 0:
                for ovl in range(MAX, MIN - 1, -1):
                    # Estimate character count corresponding to `ovl` tokens
                    # using the token/char ratio of next_raw.
                    ratio    = min(ovl / n_next, 1.0)
                    char_end = max(1, int(len(next_raw) * ratio))

                    # Snap forward to the next whitespace to avoid mid-word cut
                    while (char_end < len(next_raw) and
                           next_raw[char_end] not in (" ", "\n", "\t", "\r")):
                        char_end += 1

                    ovl_slice = next_raw[:char_end]   # pure source slice
                    candidate = raw + " " + ovl_slice

                    if _tok_count_full(candidate, tokenizer) <= CHUNK_CONTEXT_LENGTH:
                        embed = candidate
                        break
                    # If MIN overlap still overflows, leave embed = raw
        embed = re.sub((r"\[(\d{1,2})\]"), ' ', embed)
        results.append((raw, embed))

    return results


 # gắn footer
def collect_group_metadata(
    groups: list[list[MiniChunk]], page_footnotes_map: dict
) -> list[dict]:
    metas: list[dict] = []

    for group in groups:
        all_pages: list[int] = []
        all_refs:  list[str] = []
        for mc in group:
            all_pages.extend(mc.pages)
            all_refs.extend(mc.footnote_refs)

        pages = sorted(set(all_pages))
        refs  = list(dict.fromkeys(all_refs))   # ordered dedup

        footnotes: dict[str, str] = {}
        for ref in refs:
            for pg in pages:
                pg_str = str(pg)
                if (pg_str in page_footnotes_map and
                        ref in page_footnotes_map[pg_str]):
                    footnotes[ref] = page_footnotes_map[pg_str][ref]
                    break   # first page defining this ref wins

        metas.append({
            "pages":          pages,
            "footnote_refs":  refs,
            "footnotes":      footnotes,
        })

    return metas

# %% [markdown]
# ### Word Segmentation (underthesea) and tokenizer

# %%
def segment_underthesea(text: str) -> str:
    return word_tokenize(text, format="text")


def inspect_tokens(
    raw: str, seg: str, tokenizer, chunk_id: str
) -> int:
    ids   = tokenizer.encode(
        seg,
        add_special_tokens=True,
        truncation=True,
        max_length=CHUNK_CONTEXT_LENGTH,
    )
    count = len(ids)
    # print(count)

    print(f"      [TOKEN] id={chunk_id[:8]}… | "
          f"raw[0:60]={raw[:60].strip()!r}")
    print(f"              seg[0:60]={seg[:60].strip()!r}")
    print(f"              ids[:8]={ids[:8]} | total_tokens={count}")
    return count

# %% [markdown]
# ### Embedding Model

# %%
def _mean_pool(model_output, attention_mask: torch.Tensor) -> torch.Tensor:
    """Compute attention-mask-weighted mean pool over token embeddings."""
    tok_emb  = model_output.last_hidden_state            # (B, T, D)
    mask_exp = attention_mask.unsqueeze(-1).expand(tok_emb.size()).float()
    return torch.sum(tok_emb * mask_exp, dim=1) / mask_exp.sum(dim=1).clamp(min=1e-9)


def embed_text(
    seg_text: str,
    tokenizer,
    model:  AutoModel,
    device: str,
) -> list[float]:
    enc = tokenizer(
        seg_text,
        padding=True,
        truncation=True,
        max_length=CHUNK_CONTEXT_LENGTH,
        return_tensors="pt",
    ).to(device)

    with torch.no_grad():
        out = model(**enc)

    emb = _mean_pool(out, enc["attention_mask"])
    emb = torch.nn.functional.normalize(emb, p=2, dim=1)
    return emb[0].cpu().numpy().tolist()

# %% [markdown]
# ###  QDRANT PAYLOAD
#
# $$\text{Chuỗi text thô} \xrightarrow{\text{Underthesea}} \text{word segmented} \xrightarrow{\text{Encoder + Pooling}} \text{Vector [768 chiều]} \xrightarrow{\text{Đóng gói}} \text{Qdrant Database}$$

# %%
def to_qdrant_point(chunk: FinalChunk) -> dict:
    return {
        "id":      chunk.chunk_id,
        # "vector":  chunk.vector,
        "payload": {
            "book_name":      chunk.book_name,
            "pages":          chunk.pages,
            "raw_text":       chunk.raw_text,
            "segmented_text": chunk.segmented_text,
            # "footnote_refs":  chunk.footnote_refs,
            "footnotes":      chunk.footnotes,
            "token_count":    chunk.token_count,
        },
    }

# %% [markdown]
# ### MAIN
# run_pipeline(input_json, backends)
#
# 1. Lấy tên sách, text, footnote
# 2. In thông tin pipeline
# 3. Load tokenizer + embedding model
# 4. Tách full_text thành page spans
# 5. Gom page spans thành windows
# 6. Tạo mini-chunks cho từng window
# 7. Nếu dùng batch:
#       gửi tất cả mini-chunk cho Gemini Batch để lấy split indices
#    Nếu không:
#       lát nữa gọi LLM từng window
# 8. Với từng window:
#       8.1 lấy mini-chunk
#       8.2 lấy split indices từ batch hoặc gọi LLM sync
#       8.3 gộp mini-chunk thành semantic groups
#       8.4 tạo raw_text + embed_input
#       8.5 lấy metadata trang và footnote
#       8.6 segment tiếng Việt bằng underthesea
#       8.7 đếm token
#       8.8 embedding thành vector
#       8.9 tạo PointStruct
#       8.10 upload lên Qdrant
# 9. Trả về danh sách point

# %%
def run_pipeline(
    input_json:         dict,
    backends:           list[LLMBackend],
) -> list[dict]:

    book_name          = input_json["book_name"]
    full_text          = input_json["full_text"]
    page_footnotes_map = input_json["page_footnotes_map"]

    print("\n" + "═" * 72)
    print(f"  [PHASE 1] RUN CHUNKING PIPELINE — '{book_name}'")
    print(f"  Using Context Length Target: {CHUNK_CONTEXT_LENGTH}")
    print("═" * 72)
# bóc tách trang
    spans = parse_page_spans(full_text)

# chia sách thành các trang cho các lần gọi api
    windows = create_dynamic_can_chi_windows(spans, book_name)

    all_chunks:    list[dict] = []
    total_windows: int        = len(windows)


# chia từng minichunk cho danh sách trang trên
    for wi, window in enumerate(windows):

        print(f"\n{'─' * 72}")
        pg_str = str(window.pages[:6]) + ("…" if len(window.pages) > 6 else "")
        print(f"  WINDOW {wi + 1:>4}/{total_windows} | pages={pg_str} | chars={len(window.text):,}")


        mini_chunks = create_mini_chunks(window, spans, book_name)
        if not mini_chunks:
            print("    [SKIP] No content mini-chunks produced for this window.")
            continue

        print(f"    [STEP5-SYNC] Calling LLM chain…")
        split_indices = llm_semantic_split( mini_chunks, backends, context_length=CHUNK_CONTEXT_LENGTH, chunk_config=CHUNK_CONFIG,)
        print(f"llm trả về \n {split_indices} \n\n\n")

# Merge groups + overlap + footnote metadata
        groups       = _group_by_splits(mini_chunks, split_indices)
        chunk_texts  = build_chunk_texts(groups, tokenizer)    # (raw, embed_input)
        metas        = collect_group_metadata(groups, page_footnotes_map)

        print(f"    [MERGE] {len(mini_chunks)} mini-chunks + {len(split_indices)} splits "
              f"→ {len(groups)} semantic groups")

        points_to_upload = []
# Segment, inspect, embed, format
        for gi, ((raw_text, embed_input), meta) in enumerate(zip(chunk_texts, metas)):
            if not raw_text.strip():
                continue

            chunk_id = str(uuid6.uuid7())

      # Word segmentation (applied to embed_input which includes overlap)
            seg_text = segment_underthesea(embed_input)

      #  Token inspection + count
            tok_count = inspect_tokens(raw_text, seg_text, tokenizer, chunk_id)

            chunk_dict = {
                "chunk_id": chunk_id,
                "book_name": book_name,
                "pages": meta["pages"],
                "raw_text": raw_text,
                "embed_input": embed_input,
                "segmented_text": seg_text,
                # "footnote_refs": meta["footnote_refs"],
                "footnotes": meta["footnotes"],
                "token_count": tok_count
            }
            all_chunks.append(chunk_dict)

        time.sleep(2.0)
    return all_chunks

# %%
def run_embedding_pipeline(chunked_data: list[dict]) -> int:

    print("\n" + "═" * 72)
    print(f"  RUN EMBEDDING PIPELINE — Processing {len(chunked_data):,} chunks")
    print(f"  Target Collection : {COLLECTION_NAME}")
    print(f"  Device Deployment : {device.upper()}")
    print("═" * 72)

    points_to_upload = []

    for index, chunk in enumerate(chunked_data, start=1):
        embed_input = chunk["embed_input"]

        # Sinh vector mật độ cao (Dense embedding) dựa trên model, tokenizer và device toàn cục
        vector = embed_text(embed_input, tokenizer, embed_model, device)

        # Chuẩn hóa định dạng vector (tensor/ndarray -> float list)
        if hasattr(vector, "tolist"):
            vector = vector.tolist()
        elif isinstance(vector, np.ndarray):
            vector = vector.astype(float).tolist()

        # Tạo cấu trúc PointStruct chuẩn để đẩy lên Qdrant
        point = PointStruct(
            id=chunk["chunk_id"],
            vector=vector,
            payload={
                "book_name": chunk["book_name"],
                "pages": chunk["pages"],
                "raw_text": chunk["raw_text"],
                "overlap_text": chunk["embed_input"],
                # "footnote_refs": chunk["footnote_refs"],
                "footnotes": chunk["footnotes"],
                "token_count": chunk["token_count"]
            }
        )
        points_to_upload.append(point)

        if index % 50 == 0:
            print(f"    -> Embedded {index}/{len(chunked_data)} chunks...")

    # Tiến hành upload dữ liệu lên Qdrant Cloud theo từng Batch nhỏ
    if points_to_upload:
        print(f"\n[QDRANT] Đang đẩy {len(points_to_upload)} points lên Qdrant Cloud...")
        client.upload_points(
            collection_name=COLLECTION_NAME,
            points=points_to_upload,
            batch_size=64,  # Tránh tràn băng thông hoặc nghẽn mạng trên Colab
            wait=True
        )
        print("  ✓ Đã lưu toàn bộ dữ liệu thành công lên Qdrant Cloud!")
    else:
        print("  ⚠ Không tìm thấy dữ liệu hợp lệ để xử lý embedding.")

    print("\n" + "═" * 72)
    print(f"  [COMPLETED] Embedding & Upsert finish for {len(points_to_upload)} points.")
    print("═" * 72)
    return len(points_to_upload)

# %% [markdown]
# #  RUN Đại Việt Sử Ký

# %%
# @title

import os
from google.colab import userdata


JSON_PATH = "full_DVSK_data.json"           # Đại Việt Sử Ký Toàn Thư
# JSON_PATH = "full_KhamDinh_data.json"        # Khâm Định Việt Sử Thông Giám Cương Mục
# JSON_PATH = "full_VietSu_data.json"                 # Việt Sử Toàn Thư
# JSON_PATH = "full_VTT_data.json"                  # Vương Triều Trần
# JSON_PATH = "full_test.json"
# JSON_PATH = "full_test_VTT.json"


OUTPUT_PATH = JSON_PATH.replace(".json", f"_{MODEL_KEY}_{CHUNK_CONTEXT_LENGTH}.json")


def _load_key(colab_secret: str, env_var: str) -> str:
    try:
        from google.colab import userdata as _ud
        val = _ud.get(colab_secret)
        if val:
            print(f"[KEY] '{colab_secret}' loaded from Colab Secrets.")
            return val
    except Exception:
        pass
    val = os.environ.get(env_var, "")
    if val:
        print(f"[KEY] '{env_var}' loaded from environment variable.")
    return val

GROQ_API_KEY   = _load_key("grok_key",  "grok_key")
GEMINI_API_KEY = _load_key("GEMINI_API_KEY", "GEMINI_API_KEY")

if not GROQ_API_KEY and not GEMINI_API_KEY:
    print("[KEY] ⚠  No API keys found. "
          "Add GROQ_API_KEY and/or GOOGLE_API_KEY to Colab Secrets.")


LLM_BACKENDS:       list[LLMBackend]                  = []

# if GROQ_API_KEY:
#     LLM_BACKENDS.append(GroqBackend(GROQ_API_KEY, GROQ_MODEL_LLAMA_70B))
#     LLM_BACKENDS.append(GroqBackend(GROQ_API_KEY, GROQ_MODEL_LLAMA_8B))
#     LLM_BACKENDS.append(GroqBackend(GROQ_API_KEY, GROQ_MODEL_QWEN))

if GEMINI_API_KEY:
    try:
        LLM_BACKENDS.append(GeminiBackend(GEMINI_API_KEY, GEMINI_MODEL_ID))
        print(f"[INIT] GeminiBackend added: {GEMINI_MODEL_ID}")
    except Exception as exc:
        print(f"[INIT] GeminiBackend skipped ({type(exc).__name__}: {exc})")


if not LLM_BACKENDS:
    raise RuntimeError(
        "LLM_BACKENDS is empty. Provide GROQ_API_KEY and/or GEMINI_API_KEY."
    )


print(f"[INIT] Sync LLM chain ready ({len(LLM_BACKENDS)} backend(s)):")
for i, backend in enumerate(LLM_BACKENDS, start=1):
    print(f"   [{i}] {backend.label}")

print()

# Load input JSON
print(f"[LOAD] Reading '{JSON_PATH}'…")

with open(JSON_PATH, "r", encoding="utf-8") as fh:
    input_data: dict = json.load(fh)


assert "book_name" in input_data, "Missing key: book_name"
assert "full_text" in input_data, "Missing key: full_text"
assert "page_footnotes_map" in input_data, "Missing key: page_footnotes_map"

assert isinstance(input_data["book_name"], str), "book_name must be str"
assert isinstance(input_data["full_text"], str), "full_text must be str"
assert isinstance(input_data["page_footnotes_map"], dict), "page_footnotes_map must be dict"

print("[LOAD] Input validation passed ✓")


# Run pipeline
qdrant_points: list[dict] = run_pipeline(
    input_data,
    backends=LLM_BACKENDS,
)


# Save local output
print(f"\n[SAVE] Writing {len(qdrant_points):,} points → '{OUTPUT_PATH}'…")

with open(OUTPUT_PATH, "w", encoding="utf-8") as fh:
    json.dump(qdrant_points, fh, ensure_ascii=False, indent=2)

kb = os.path.getsize(OUTPUT_PATH) / 1024
print(f"[SAVE] Done. {kb:.1f} KB written.")
# Out:
# [KEY] 'grok_key' loaded from Colab Secrets.
# [KEY] 'GEMINI_API_KEY' loaded from Colab Secrets.
# [INIT] GeminiBackend added: gemini-3.1-flash-lite
# [INIT] Sync LLM chain ready (1 backend(s)):
#    [1] gemini-sync/gemini-3.1-flash-lite
#
# [LOAD] Reading 'full_DVSK_data.json'…
# [LOAD] Input validation passed ✓
#
# ════════════════════════════════════════════════════════════════════════
#   [PHASE 1] RUN CHUNKING PIPELINE — 'Đại Việt Sử Ký Toàn Thư'
#   Using Context Length Target: 512
# ════════════════════════════════════════════════════════════════════════
#
# [WINDOWS] book='Đại Việt Sử Ký Toàn Thư' | window_size=3 pages
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW    1/50 | pages=[154, 155, 156] | chars=7,436
#       [STRUCT] 14 structural boundaries | book='Đại Việt Sử Ký Toàn Thư'
#     [MINI-CHUNK] window chars=7,436 → 69 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
# {"split_after_indices":[4,8,13,16,21,23,28,35,39,45,49,52,57,62]}
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=69 → splits=[4, 8, 13, 16, 21, 23, 28, 35, 39, 45, 49, 52, 57, 62]
# llm trả về
#  [4, 8, 13, 16, 21, 23, 28, 35, 39, 45, 49, 52, 57, 62]
#
#
#
#     [MERGE] 69 mini-chunks + 14 splits → 15 semantic groups
#       [TOKEN] id=019e5677… | raw[0:60]='việc lớn của nước, quốc sử không thể không chép được. Có lẽ'
#               seg[0:60]='việc lớn của nước , quốc_sử không_thể không chép được . Có_l'
#               ids[:8]=[0, 2735, 7976, 550, 3042, 6, 4, 10895] | total_tokens=248
#       [TOKEN] id=019e5677… | raw[0:60]='Huệ Tông Hoàng Đế Tên huý là Sảm [1], con trưởng của Cao Tôn'
#               seg[0:60]='Huệ Tông_Hoàng_Đế Tên húy là Sảm , con trưởng của Cao_Tông ,'
#               ids[:8]=[0, 7674, 21018, 384, 23366, 454, 11193, 1298] | total_tokens=318
#       [TOKEN] id=019e5677… | raw[0:60]='Tân Mùi, [Kiến Gia] năm thứ 1 [1211], (Tống Gia Định năm thứ'
#               seg[0:60]='Tân_Mùi , [_Kiến_Gia_] năm thứ 1 [ 1211 ] , ( Tống_Gia_Định'
#               ids[:8]=[0, 49320, 454, 594, 65934, 6, 4, 378] | total_tokens=355
#       [TOKEN] id=019e5677… | raw[0:60]='Bấy giờ thừa hưởng thái bình đã lâu ngày, giường mối dần bỏ,'
#               seg[0:60]='Bấy_giờ thừa_hưởng thái_bình đã lâu ngày , giường mối dần bỏ'
#               ids[:8]=[0, 335, 249999, 53, 454, 735, 58677, 84813] | total_tokens=175
#       [TOKEN] id=019e5677… | raw[0:60]='Nhâm Thân, [Kiến Gia] năm thứ 2 [1212], (Tống Gia Định năm'
#               seg[0:60]='Nhâm_Thân , [_Kiến_Gia_] năm thứ 2 [ 1212 ] , ( Tống_Gia_Địn'
#               ids[:8]=[0, 33101, 27253, 454, 618, 150388, 6, 4] | total_tokens=351
#       [TOKEN] id=019e5677… | raw[0:60]='Quý Dậu, [Kiến Gia] nămthứ 3 [1213], (Tống Gia Định năm thứ'
#               seg[0:60]='Quý_Dậu , [_Kiến_Gia_] nămthứ 3 [ 1213 ] , ( Tống_Gia_Định n'
#               ids[:8]=[0, 78309, 454, 397, 85284, 6, 4, 378] | total_tokens=208
#       [TOKEN] id=019e5677… | raw[0:60]='Giáp Tuất, [Kiến Gia] năm thứ 4 [1214], (Tống Gia Định năm t'
#               seg[0:60]='Giáp_Tuất , [_Kiến_Gia_] năm thứ 4 [ 1214 ] , ( Tống_Gia_Địn'
#               ids[:8]=[0, 42906, 254, 454, 15665, 249999, 18, 6] | total_tokens=277
#       [TOKEN] id=019e5677… | raw[0:60]='Mùa hạ, tháng 5, Tự Khánh đánh Đinh Khả và Bùi Đô ở châu Đại'
#               seg[0:60]='Mùa hạ , tháng 5 , Tự_Khánh đánh Đinh_Khả và Bùi_Đô ở châu_Đ'
#               ids[:8]=[0, 220174, 36771, 6, 4, 7973, 190, 6] | total_tokens=428
#       [TOKEN] id=019e5677… | raw[0:60]='Vua mới đỗ lại ở bãi Cửu Liên [2]. Truyền cho Tự Khánh đến'
#               seg[0:60]='Vua mới đỗ lại ở bãi Cửu_Liên . Truyền cho Tự_Khánh đến chầu'
#               ids[:8]=[0, 35443, 11, 3633, 232548, 1917, 2059, 136419] | total_tokens=258
#       [TOKEN] id=019e5677… | raw[0:60]='Vua có bệnh trúng phong, chũa thuốc không khỏi mà chưa có th'
#               seg[0:60]='Vua có bệnh trúng_phong , chũa thuốc không khỏi mà chưa có t'
#               ids[:8]=[0, 35443, 11, 524, 7417, 186458, 454, 254] | total_tokens=326
#       [TOKEN] id=019e5677… | raw[0:60]='Mậu Dần, [Kiến Gia] năm thứ 8 [1218], (Tống Gia Định năm thứ'
#               seg[0:60]='Mậu_Dần , [_Kiến_Gia_] năm thứ 8 [ 1218 ] , ( Tống_Gia_Định'
#               ids[:8]=[0, 276, 85284, 454, 397, 249994, 19, 6] | total_tokens=367
#       [TOKEN] id=019e5677… | raw[0:60]='Kỷ Mão, [Kiến Gia] năm thứ 9 [1219], (Tống Gia Định năm thứ'
#               seg[0:60]='Kỷ_Mão , [_Kiến_Gia_] năm thứ 9 [ 1219 ] , ( Tống_Gia_Định n'
#               ids[:8]=[0, 341, 60479, 454, 594, 3680, 6, 4] | total_tokens=169
#       [TOKEN] id=019e5677… | raw[0:60]='Canh Thìn, [Kiến Gia] năm thứ 10 [1220], (Tống Gia Định năm'
#               seg[0:60]='Canh_Thìn , [_Kiến_Gia_] năm thứ 10 [ 1220 ] , ( Tống_Gia_Đị'
#               ids[:8]=[0, 4171, 127, 454, 618, 64269, 19, 6] | total_tokens=314
#       [TOKEN] id=019e5677… | raw[0:60]='Nhâm Ngọ, [Kiến Gia] năm thứ 12 [1222], (Tống Gia Định năm'
#               seg[0:60]='Nhâm_Ngọ , [_Kiến_Gia_] năm thứ 12 [ 1222 ] , ( Tống_Gia_Địn'
#               ids[:8]=[0, 33101, 27253, 454, 69656, 19030, 6, 4] | total_tokens=311
#       [TOKEN] id=019e5677… | raw[0:60]='Sử thần Ngô Sĩ Liên nói: Năm đầu niên hiệu Kiến Gia, giặc cư'
#               seg[0:60]='Sử_thần Ngô_Sĩ_Liên nói : Năm_đầu niên_hiệu Kiến_Gia , giặc'
#               ids[:8]=[0, 63034, 454, 927, 249994, 19, 90542, 454] | total_tokens=278
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW    2/50 | pages=[156, 157, 158, 159] | chars=8,554
#       [STRUCT] 5 structural boundaries | book='Đại Việt Sử Ký Toàn Thư'
#     [MINI-CHUNK] window chars=8,554 → 76 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
# {"split_after_indices":[3,15,17,32,42,51,62,67,73]}
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=76 → splits=[3, 8, 15, 17, 22, 32, 37, 42, 51, 56, 62, 67, 73]
# llm trả về
#  [3, 8, 15, 17, 22, 32, 37, 42, 51, 56, 62, 67, 73]
#
#
#
#     [MERGE] 76 mini-chunks + 13 splits → 14 semantic groups
#       [TOKEN] id=019e5677… | raw[0:60]='Giáp Thân, [Kiến Gia] năm thứ 14 [1224], (Từ tháng 10 về sau'
#               seg[0:60]='Giáp_Thân , [_Kiến_Gia_] năm thứ 14 [ 1224 ] , ( Từ tháng 10'
#               ids[:8]=[0, 42906, 254, 454, 618, 150388, 6, 4] | total_tokens=322
#       [TOKEN] id=019e5677… | raw[0:60]='Chiêu Thánh lên ngôi, đổi niên hiệu là Thiên Chương Hữu Đạo'
#               seg[0:60]='Chiêu_Thánh lên_ngôi , đổi niên_hiệu là Thiên_Chương_Hữu_Đạo'
#               ids[:8]=[0, 3751, 56540, 454, 20800, 1665, 127, 4494] | total_tokens=242
#       [TOKEN] id=019e5677… | raw[0:60]='đều là xử trí lúc biến mà không mất phép thường cả. Đời sau'
#               seg[0:60]='đều là xử_trí lúc biến mà không mất_phép thường cả . Đời sau'
#               ids[:8]=[0, 9338, 580, 28085, 454, 103405, 10305, 15038] | total_tokens=322
#       [TOKEN] id=019e5677… | raw[0:60]='Chiêu Hoàng Trước tên huý là Phật kim, sau đổi là Thiên Hinh'
#               seg[0:60]='Chiêu_Hoàng Trước tên húy là Phật_kim , sau đổi là Thiên_Hin'
#               ids[:8]=[0, 3751, 56540, 454, 11193, 1298, 449, 69388] | total_tokens=140
#       [TOKEN] id=019e5677… | raw[0:60]='Ất Dậu, Thiên Chương Hữu Đạo năm thứ 2 [1125], (Từ tháng 12'
#               seg[0:60]='Ất_Dậu , Thiên_Chương_Hữu_Đạo năm thứ 2 [ 1125 ] , ( Từ thán'
#               ids[:8]=[0, 6, 249975, 18, 454, 397, 85284, 6] | total_tokens=323
#       [TOKEN] id=019e5677… | raw[0:60]='Một hôm phải giữ việc bưng nước rửa, nhân thế vào hầu bên t'
#               seg[0:60]='Một hôm phải giữ việc bưng nước_rửa , nhân_thế vào hầu bên t'
#               ids[:8]=[0, 14921, 26094, 2334, 26148, 2735, 176760, 449] | total_tokens=494
#       [TOKEN] id=019e5677… | raw[0:60]='Xuống chiếu rằng: "Từ xưa nước Nam Việt ta đã có đế vương t'
#               seg[0:60]='Xuống chiếu rằng : " Từ xưa nước Nam_Việt ta đã có đế vương_'
#               ids[:8]=[0, 19032, 32379, 80062, 10371, 152, 44, 30947] | total_tokens=345
#       [TOKEN] id=019e5677… | raw[0:60]='Kinh thi có nói "Quân tử tìm bạn, tìm mãi không được, thức'
#               seg[0:60]='Kinh thi có nói " Quân_tử tìm bạn , tìm mãi không được , thứ'
#               ids[:8]=[0, 31588, 6117, 524, 2872, 44, 101390, 454] | total_tokens=267
#       [TOKEN] id=019e5677… | raw[0:60]='Tháng 12, ngày mồng một Mậu Dần, Chiêu Hoàng mở hội lớn ở đ'
#               seg[0:60]='Tháng 12 , ngày mồng một Mậu_Dần , Chiêu_Hoàng mở_hội lớn ở'
#               ids[:8]=[0, 77833, 427, 6, 4, 3063, 347, 32773] | total_tokens=512
#       [TOKEN] id=019e5677… | raw[0:60]='Sử thần Ngô Sĩ Liên nói: "Đến thời Huệ Tông, cái độc hại ch'
#               seg[0:60]='Sử_thần Ngô_Sĩ_Liên nói : " Đến thời Huệ_Tông , cái độc_hại'
#               ids[:8]=[0, 63034, 454, 927, 249994, 19, 90542, 454] | total_tokens=248
#       [TOKEN] id=019e5677… | raw[0:60]='"Nhất bất công đức thủy, Tuỳ duyên hoa thế gian. Quang quan'
#               seg[0:60]='" Nhất bất_công_đức thủy , Tùy_duyên hoa thế_gian . Quang_qu'
#               ids[:8]=[0, 44, 118264, 9985, 454, 238, 23366, 454] | total_tokens=322
#       [TOKEN] id=019e5677… | raw[0:60]='Trở lên triều Lý, 9 vua, từ Thái Tổ năm canh Tuất [1010] đến'
#               seg[0:60]='Trở lên triều_Lý , 9 vua , từ Thái_Tổ năm canh_Tuất [ 1010 ]'
#               ids[:8]=[0, 5454, 26332, 4494, 221089, 454, 866, 1673] | total_tokens=308
#       [TOKEN] id=019e5677… | raw[0:60]='Trước kia, tổ tiên vua là người đất Mân (có người nói là ngư'
#               seg[0:60]='Trước_kia , tổ_tiên vua là người đất Mân ( có người nói là n'
#               ids[:8]=[0, 69388, 454, 15565, 6, 4, 12158, 454] | total_tokens=438
#       [TOKEN] id=019e5677… | raw[0:60]='Bính Tuất, Kiến Trung năm thứ 2 [ 1266], (Tống Bảo Khánh năm'
#               seg[0:60]='Bính_Tuất , Kiến_Trung năm thứ 2 [ 1266 ] , ( Tống_Bảo_Khánh'
#               ids[:8]=[0, 34023, 6457, 454, 15665, 249999, 18, 6] | total_tokens=148
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW    3/50 | pages=[159, 160, 161, 162] | chars=8,825
#       [STRUCT] 10 structural boundaries | book='Đại Việt Sử Ký Toàn Thư'
#     [MINI-CHUNK] window chars=8,825 → 81 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
# {"split_after_indices":[4,16,29,41,49,56,61,68,78]}
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=81 → splits=[4, 9, 16, 21, 29, 34, 41, 49, 56, 61, 68, 73, 78]
# llm trả về
#  [4, 9, 16, 21, 29, 34, 41, 49, 56, 61, 68, 73, 78]
#
#
#
#     [MERGE] 81 mini-chunks + 13 splits → 14 semantic groups
#       [TOKEN] id=019e5677… | raw[0:60]='Tháng 2, định luật lệnh, điều lệ.\nSai Trần Thủ Độ đem quân đ'
#               seg[0:60]='Tháng 2 , định luật_lệnh , điều_lệ . Sai Trần_Thủ_Độ đem quâ'
#               ids[:8]=[0, 77833, 116, 6, 4, 2931, 18179, 454] | total_tokens=303
#       [TOKEN] id=019e5677… | raw[0:60]='Mùa hạ, tháng 5, phong em là Nhật Hiệu làm khâm Thiên Đại Vư'
#               seg[0:60]='Mùa hạ , tháng 5 , phong_em là Nhật_Hiệu làm khâm_Thiên_Đại_'
#               ids[:8]=[0, 220174, 36771, 6, 4, 7973, 190, 6] | total_tokens=282
#       [TOKEN] id=019e5677… | raw[0:60]='Có lẫn Thủ Độ qua trước cửa chùa, thấ Huệ Tông ngồi xổm nhổ'
#               seg[0:60]='Có lẫn Thủ_Độ qua trước cửa chùa , thấ Huệ_Tông ngồi_xổm nhổ'
#               ids[:8]=[0, 11302, 111903, 40797, 454, 13347, 27350, 2799] | total_tokens=411
#       [TOKEN] id=019e5677… | raw[0:60]='Giáng hoàng hậu của Huệ Tông làm Thiên Cực công chúa, gả ch'
#               seg[0:60]='Giáng_hoàng_hậu của Huệ_Tông làm Thiên_Cực công_chúa , gả ch'
#               ids[:8]=[0, 42906, 449, 454, 497, 1298, 449, 454] | total_tokens=248
#       [TOKEN] id=019e5677… | raw[0:60]='Đó là do nhân sâu ơn dày của tổ tông để lại mãi đến đời sau'
#               seg[0:60]='Đó là do nhân sâu_ơn dày của tổ_tông để lại mãi đến đời sau'
#               ids[:8]=[0, 62578, 580, 54, 3090, 36963, 454, 12435] | total_tokens=350
#       [TOKEN] id=019e5677… | raw[0:60]='Mùa đông, tháng 10, tôn cha là Thừa làm Thượng hoàng, ở cung'
#               seg[0:60]='Mùa đông , tháng 10 , tôn_cha là Thừa_làm Thượng_hoàng , ở c'
#               ids[:8]=[0, 220174, 37127, 6, 4, 7973, 209, 6] | total_tokens=289
#       [TOKEN] id=019e5677… | raw[0:60]='Sử thần Ngô Sĩ Liên nói: Ban tước cho người là quyễn của thi'
#               seg[0:60]='Sử_thần Ngô_Sĩ_Liên nói : Ban tước cho người là quyễn của th'
#               ids[:8]=[0, 63034, 454, 927, 249994, 19, 90542, 454] | total_tokens=317
#       [TOKEN] id=019e5677… | raw[0:60]='Đinh Hợi [Kiến Trung] năm thứ 3 [1227], (Tống Bảo Khánh năm'
#               seg[0:60]='Đinh_Hợi [_Kiến Trung_] năm thứ 3 [ 1227 ] , ( Tống_Bảo_Khán'
#               ids[:8]=[0, 224564, 454, 841, 30599, 14, 378, 454] | total_tokens=472
#       [TOKEN] id=019e5677… | raw[0:60]='Mậu Tý, [Kiến Trung] năm thứ 4 [1228]. (Tống Thiệu Định năm'
#               seg[0:60]='Mậu_Tý , [_Kiến Trung_] năm thứ 4 [ 1228 ] . ( Tống_Thiệu_Đị'
#               ids[:8]=[0, 276, 85284, 454, 618, 1673, 6, 4] | total_tokens=427
#       [TOKEN] id=019e5677… | raw[0:60]='Tháng 12, Nguyễn Nộn đánh giết Đoàn Thượng.\nNộn đã phá được'
#               seg[0:60]='Tháng 12 , Nguyễn_Nộn đánh giết Đoàn_Thượng . Nộn đã phá đượ'
#               ids[:8]=[0, 77833, 427, 6, 4, 19098, 454, 839] | total_tokens=266
#       [TOKEN] id=019e5677… | raw[0:60]='Kỷ Sửu,[Kiến Trung] năm thứ 5[1229], (Tống Thiệu Định năm th'
#               seg[0:60]='Kỷ_Sửu , [_Kiến Trung_] năm thứ 5 [ 1229 ] , ( Tống_Thiệu_Đị'
#               ids[:8]=[0, 341, 60479, 454, 294, 46535, 34, 6] | total_tokens=413
#       [TOKEN] id=019e5677… | raw[0:60]='Canh Dần, [Kiến Trung] năm thứ 5 [1230], (Tống Thiệu Đinh n'
#               seg[0:60]='Canh_Dần , [_Kiến Trung_] năm thứ 5 [ 1230 ] , ( Tống_Thiệu'
#               ids[:8]=[0, 4171, 127, 454, 397, 249994, 19, 6] | total_tokens=299
#       [TOKEN] id=019e5677… | raw[0:60]='Định các phường về hai bên tả hữu của kinh thành, bắt chước'
#               seg[0:60]='Định các phường về hai bên tả_hữu của kinh_thành , bắt_chước'
#               ids[:8]=[0, 124818, 925, 140630, 1893, 1337, 7669, 85245] | total_tokens=299
#       [TOKEN] id=019e5677… | raw[0:60]='Mùa xuân, tháng 7, xuống chiếu rằng phàm người coi tục đi đ'
#               seg[0:60]='Mùa xuân , tháng 7 , xuống chiếu rằng phàm người coi_tục đi'
#               ids[:8]=[0, 220174, 173887, 6, 4, 7973, 361, 6] | total_tokens=93
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW    4/50 | pages=[162, 163, 164, 165] | chars=8,203
#       [STRUCT] 10 structural boundaries | book='Đại Việt Sử Ký Toàn Thư'
#     [MINI-CHUNK] window chars=8,203 → 77 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
# {"split_after_indices":[10,20,25,36,46,66,76]}
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=77 → splits=[4, 10, 15, 20, 25, 30, 36, 41, 46, 51, 59, 66, 75]
# llm trả về
#  [4, 10, 15, 20, 25, 30, 36, 41, 46, 51, 59, 66, 75]
#
#
#
#     [MERGE] 77 mini-chunks + 13 splits → 14 semantic groups
#       [TOKEN] id=019e5677… | raw[0:60]='Tân Mão, [Kiến Trung] năm thứ 7 [1231], (Tống Thiệu Định năm'
#               seg[0:60]='Tân_Mão , [_Kiến Trung_] năm thứ 7 [ 1231 ] , ( Tống_Thiệu_Đ'
#               ids[:8]=[0, 49320, 454, 594, 3680, 6, 4, 378] | total_tokens=239
#       [TOKEN] id=019e5677… | raw[0:60]='Thượng hoàng xuống chiếu rằng trong nước hễ chổ nào có đình'
#               seg[0:60]='Thượng_hoàng xuống chiếu rằng trong nước hễ chổ nào có đình'
#               ids[:8]=[0, 146182, 454, 497, 1298, 449, 19398, 80062] | total_tokens=286
#       [TOKEN] id=019e5677… | raw[0:60]='Nhâm Thìn, [Kiến Trung] năm thứ 8 [1232], (Từ tháng 7 về sau'
#               seg[0:60]='Nhâm Thìn , [_Kiến Trung_] năm thứ 8 [ 1232 ] , ( Từ tháng 7'
#               ids[:8]=[0, 33101, 27253, 384, 64269, 19, 6, 4] | total_tokens=259
#       [TOKEN] id=019e5677… | raw[0:60]='Một hôm, bà Liệt đánh cầu với người trong đội, người kia vậ'
#               seg[0:60]='Một hôm , bà Liệt đánh_cầu với người trong đội , người kia_v'
#               ids[:8]=[0, 14921, 26094, 6, 4, 15409, 1261, 33340] | total_tokens=303
#       [TOKEN] id=019e5677… | raw[0:60]='Tháng 8, gió lớn, dân gian phát dịch lệ, nhiều người chết.\nT'
#               seg[0:60]='Tháng 8 , gió lớn , dân_gian phát dịch_lệ , nhiều người chết'
#               ids[:8]=[0, 77833, 382, 6, 4, 82342, 7976, 6] | total_tokens=274
#       [TOKEN] id=019e5677… | raw[0:60]='Quý Tỵ,Thiên Ứng Chính Bình năm thứ 2 [1233], (Tống Thiệu Đị'
#               seg[0:60]='Quý_Tỵ , Thiên_Ứng_Chính_Bình năm thứ 2 [ 1233 ] , ( Tống_Th'
#               ids[:8]=[0, 78309, 454, 618, 162874, 6, 4, 40776] | total_tokens=365
#       [TOKEN] id=019e5677… | raw[0:60]='Miếu hiệu là Huy Tông, tên thụy là Khai Vận Lập Cực Hoằng N'
#               seg[0:60]='Miếu_hiệu là Huy_Tông , tên thụy là Khai_Vận Lập_Cực Hoằng_N'
#               ids[:8]=[0, 1208, 63513, 454, 127, 100345, 580, 88238] | total_tokens=405
#       [TOKEN] id=019e5677… | raw[0:60]='Ất Mùi, [Thiên Ứng Chính Bình] năm thứ 4 [1236], (Tống Đoan'
#               seg[0:60]='Ất_Mùi , [_Thiên_Ứng_Chính Bình_] năm thứ 4 [ 1236 ] , ( Tốn'
#               ids[:8]=[0, 6, 249975, 18, 454, 594, 65934, 6] | total_tokens=294
#       [TOKEN] id=019e5677… | raw[0:60]='đều kiêm hàm Kiểm hiệu đặc tiến nghi đồng tam ty bình chươn'
#               seg[0:60]='đều kiêm hàm Kiểm_hiệu đặc_tiến nghi đồng tam_ty bình_chương'
#               ids[:8]=[0, 9338, 200, 13033, 126215, 94712, 39, 454] | total_tokens=406
#       [TOKEN] id=019e5677… | raw[0:60]='Đinh Dậu, [ Thiên Ứng Chính Bình] năm thứ 6 [1237], (Tống Gi'
#               seg[0:60]='Đinh_Dậu , [_Thiên_Ứng_Chính Bình_] năm thứ 6 [ 1237 ] , ( T'
#               ids[:8]=[0, 224564, 454, 397, 85284, 6, 4, 378] | total_tokens=242
#       [TOKEN] id=019e5677… | raw[0:60]='Trần Thủ Độ và công chúa Thiên Cực bàn kính với vua là nên'
#               seg[0:60]='Trần_Thủ_Độ và công_chúa Thiên_Cực bàn_kính với vua là nên m'
#               ids[:8]=[0, 42974, 454, 20800, 39470, 454, 13347, 27350] | total_tokens=373
#       [TOKEN] id=019e5677… | raw[0:60]='"Bệ hạ nên gấp quay xa giá trở về, chớ để làm hại núi rừng c'
#               seg[0:60]='" Bệ_hạ nên gấp quay xa giá trở về , chớ để làm hại núi_rừng'
#               ids[:8]=[0, 44, 335, 21018, 454, 127, 12976, 3809] | total_tokens=375
#       [TOKEN] id=019e5677… | raw[0:60]='Phan Phu Tiên nói: Tam cương ngũ thường là luân lý lớn của l'
#               seg[0:60]='Phan_Phu_Tiên nói : Tam_cương_ngũ thường là luân_lý lớn của'
#               ids[:8]=[0, 95581, 454, 683, 1132, 454, 16734, 1732] | total_tokens=429
#       [TOKEN] id=019e5677… | raw[0:60]='Các quan dâng tôn hiệu là Thống Thiên Ngự Cực Long Công Hậu'
#               seg[0:60]='Các quan_dâng tôn_hiệu là Thống_Thiên_Ngự Cực_Long_Công_Hậu_'
#               ids[:8]=[0, 9211, 2261, 454, 71, 63858, 77990, 454] | total_tokens=72
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW    5/50 | pages=[165, 166, 167, 168] | chars=7,084
#       [STRUCT] 20 structural boundaries | book='Đại Việt Sử Ký Toàn Thư'
#     [MINI-CHUNK] window chars=7,084 → 65 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
# {"split_after_indices":[2,5,8,13,18,24,32,37,40,43,49,52,57,62]}
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=65 → splits=[2, 5, 8, 13, 18, 24, 32, 37, 40, 43, 49, 52, 57, 62]
# llm trả về
#  [2, 5, 8, 13, 18, 24, 32, 37, 40, 43, 49, 52, 57, 62]
#
#
#
#     [MERGE] 65 mini-chunks + 14 splits → 15 semantic groups
#       [TOKEN] id=019e5677… | raw[0:60]='Ban yến cho các quan ở điện Thiên An.Tháng 2, dời dựng điện'
#               seg[0:60]='Ban yến cho các quan ở điện Thiên_An . Tháng 2 , dời dựng đi'
#               ids[:8]=[0, 5458, 113, 26532, 681, 925, 2261, 2059] | total_tokens=297
#       [TOKEN] id=019e5677… | raw[0:60]='Mậu Tuất, [Thiên Ứng Chính Bình] năm thứ 7 [1238], (Tống Gia'
#               seg[0:60]='Mậu_Tuất , [_Thiên_Ứng_Chính Bình_] năm thứ 7 [ 1238 ] , ( T'
#               ids[:8]=[0, 276, 85284, 454, 15665, 249999, 18, 6] | total_tokens=322
#       [TOKEN] id=019e5677… | raw[0:60]='Kỷ Hợi, [Thiên Ứng Chính Bình] năm thứ 8 [1239], (Tống Gia H'
#               seg[0:60]='Kỷ_Hợi , [_Thiên_Ứng_Chính Bình_] năm thứ 8 [ 1239 ] , ( Tốn'
#               ids[:8]=[0, 341, 60479, 454, 841, 30599, 14, 6] | total_tokens=283
#       [TOKEN] id=019e5677… | raw[0:60]='Canh Tý, [Thiên Ứng Chính Bình] năm thứ 9 [1240], (Tống Gia'
#               seg[0:60]='Canh_Tý , [_Thiên_Ứng_Chính Bình_] năm thứ 9 [ 1240 ] , ( Tố'
#               ids[:8]=[0, 4171, 127, 454, 618, 1673, 6, 4] | total_tokens=276
#       [TOKEN] id=019e5677… | raw[0:60]='Tân Sửu, [Thiên Ứng Chính Bình] năm thứ 10 [1241], (Tống Thu'
#               seg[0:60]='Tân_Sửu , [_Thiên_Ứng_Chính Bình_] năm thứ 10 [ 1241 ] , ( T'
#               ids[:8]=[0, 49320, 454, 294, 46535, 34, 6, 4] | total_tokens=264
#       [TOKEN] id=019e5677… | raw[0:60]='Hoàng tử thứ ba Quang Khải sinh, là em cùng mẹ với thái tử H'
#               seg[0:60]='Hoàng_tử thứ ba_Quang Khải_sinh , là em cùng mẹ với thái_tử_'
#               ids[:8]=[0, 38356, 454, 18, 46535, 11847, 961, 454] | total_tokens=353
#       [TOKEN] id=019e5677… | raw[0:60]='Nhâm Dần, [Thiên Ứng Chính Bình] năm thứ 11 [1242], (Tống Th'
#               seg[0:60]='Nhâm Dần , [_Thiên_Ứng_Chính Bình_] năm thứ 11 [ 1242 ] , ('
#               ids[:8]=[0, 33101, 27253, 391, 249994, 19, 6, 4] | total_tokens=423
#       [TOKEN] id=019e5677… | raw[0:60]='Mùa hạ, tháng 4, sai Thân vệ tướng quân Trần Khuê Kình đem q'
#               seg[0:60]='Mùa hạ , tháng 4 , sai Thân_vệ tướng_quân Trần_Khuê_Kình đem'
#               ids[:8]=[0, 220174, 36771, 6, 4, 7973, 201, 6] | total_tokens=313
#       [TOKEN] id=019e5677… | raw[0:60]='Tháng 5, tháng 6, hạn hán, soát tù, đại xá.\nMùa thu, tháng 7'
#               seg[0:60]='Tháng 5 , tháng 6 , hạn_hán , soát tù , đại_xá . Mùa thu , t'
#               ids[:8]=[0, 77833, 190, 6, 4, 7973, 305, 6] | total_tokens=188
#       [TOKEN] id=019e5677… | raw[0:60]='Quý Mão, [Thiên Ứng Chính Bình] năm thứ 2 [1243], (Tống Thuầ'
#               seg[0:60]='Quý_Mão , [_Thiên_Ứng_Chính Bình_] năm thứ 2 [ 1243 ] , ( Tố'
#               ids[:8]=[0, 78309, 454, 594, 3680, 6, 4, 378] | total_tokens=245
#       [TOKEN] id=019e5677… | raw[0:60]='Giáp Thìn, [Thiên Ưng Chính Bình] năm thứ 13 [1244], (Tống T'
#               seg[0:60]='Giáp_Thìn , [_Thiên_Ưng_Chính Bình_] năm thứ 13 [ 1244 ] , ('
#               ids[:8]=[0, 42906, 254, 454, 618, 64269, 19, 6] | total_tokens=376
#       [TOKEN] id=019e5677… | raw[0:60]='Mùa đông, tháng 10, qui định lương bổng cho các quan làm việ'
#               seg[0:60]='Mùa đông , tháng 10 , quy_định lương_bổng cho các quan làm_v'
#               ids[:8]=[0, 220174, 37127, 6, 4, 7973, 209, 6] | total_tokens=238
#       [TOKEN] id=019e5677… | raw[0:60]='Bính Ngọ, [Thiên Ứng Chính Bình] năm thứ 15 [1246], (Tống Th'
#               seg[0:60]='Bính_Ngọ , [_Thiên_Ứng_Chính Bình_] năm thứ 15 [ 1246 ] , ('
#               ids[:8]=[0, 34023, 6457, 454, 69656, 19030, 6, 4] | total_tokens=349
#       [TOKEN] id=019e5677… | raw[0:60]='Tháng 3, xét duyệt các quan văn, võ, trong ngoài. .\nCứ 15 nă'
#               seg[0:60]='Tháng 3 , xét_duyệt các quan_văn , võ , trong ngoài . . Cứ 1'
#               ids[:8]=[0, 77833, 138, 6, 4, 31462, 454, 693] | total_tokens=309
#       [TOKEN] id=019e5677… | raw[0:60]='Mùa hạ, thạng, tháp trên núi Long Đội đổ.\nMùa thu, tháng 7,'
#               seg[0:60]='Mùa hạ , thạng , tháp trên núi Long_Đội đổ . Mùa thu , tháng'
#               ids[:8]=[0, 220174, 36771, 6, 4, 5675, 12976, 449] | total_tokens=88
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW    6/50 | pages=[168, 169, 170, 171] | chars=8,000
#       [STRUCT] 13 structural boundaries | book='Đại Việt Sử Ký Toàn Thư'
#     [MINI-CHUNK] window chars=8,000 → 71 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
# {"split_after_indices":[4,11,20,26,39,46,52,58,61,67]}
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=71 → splits=[4, 11, 20, 26, 31, 39, 46, 52, 58, 61, 67]
# llm trả về
#  [4, 11, 20, 26, 31, 39, 46, 52, 58, 61, 67]
#
#
#
#     [MERGE] 71 mini-chunks + 11 splits → 12 semantic groups
#       [TOKEN] id=019e5677… | raw[0:60]='Đinh Mùi, [Thiên Ứng Chính Bình] năm thứ 16 [1247], (Tống Th'
#               seg[0:60]='Đinh_Mùi , [_Thiên_Ứng_Chính Bình_] năm thứ 16 [ 1247 ] , ('
#               ids[:8]=[0, 224564, 454, 594, 65934, 6, 4, 378] | total_tokens=350
#       [TOKEN] id=019e5677… | raw[0:60]='Mậu Thân, [Thiên Ứng Chính Bình] năm thứ 17 [1248], (Tống Th'
#               seg[0:60]='Mậu_Thân , [_Thiên_Ứng_Chính Bình_] năm thứ 17 [ 1248 ] , ('
#               ids[:8]=[0, 276, 85284, 454, 618, 150388, 6, 4] | total_tokens=343
#       [TOKEN] id=019e5677… | raw[0:60]='Sai các nhà phong thủy đi xem khắp núi sông cả nước, chỗ nào'
#               seg[0:60]='Sai các nhà_phong thủy đi xem khắp núi sông cả nước , chỗ nà'
#               ids[:8]=[0, 19319, 925, 2455, 454, 254, 30434, 58740] | total_tokens=420
#       [TOKEN] id=019e5677… | raw[0:60]='Kỷ Dậu, [ Thiên Ứng Chính bình] năm thứ 18 [1249], (Tống Thu'
#               seg[0:60]='Kỷ_Dậu , [_Thiên_Ứng Chính_bình ] năm thứ 18 [ 1249 ] , ( Tố'
#               ids[:8]=[0, 341, 60479, 454, 397, 85284, 6, 4] | total_tokens=406
#       [TOKEN] id=019e5677… | raw[0:60]='Tân Hợi, [Thiên Ứng Chính Bình] năm thứ 20 [1251] (Từ tháng'
#               seg[0:60]='Tân_Hợi , [_Thiên_Ứng_Chính Bình_] năm thứ 20 [ 1251 ] ( Từ'
#               ids[:8]=[0, 49320, 454, 841, 30599, 14, 6, 4] | total_tokens=323
#       [TOKEN] id=019e5677… | raw[0:60]='Trước đó, vua cho công chúa Thiên Thành đến ở trong dinh Nhâ'
#               seg[0:60]='Trước đó , vua cho công_chúa Thiên_Thành đến ở trong dinh_Nh'
#               ids[:8]=[0, 69388, 2275, 6, 4, 86729, 681, 1871] | total_tokens=471
#       [TOKEN] id=019e5677… | raw[0:60]='Sử thần Ngô Sĩ Liên nói: Con gái vua lấy kẻ bề dưới tất phải'
#               seg[0:60]='Sử_thần Ngô_Sĩ_Liên nói : Con gái vua lấy kẻ_bề dưới tất phả'
#               ids[:8]=[0, 63034, 454, 927, 249994, 19, 90542, 454] | total_tokens=383
#       [TOKEN] id=019e5677… | raw[0:60]='Sử thần Ngô Sĩ Liên nói: Xem thế đủ thấy, tuy bấy giờ vua t'
#               seg[0:60]='Sử_thần Ngô_Sĩ_Liên nói : Xem thế đủ thấy , tuy bấy_giờ vua'
#               ids[:8]=[0, 63034, 454, 927, 249994, 19, 90542, 454] | total_tokens=296
#       [TOKEN] id=019e5677… | raw[0:60]='Nhâm Tý, Nguyên Phong năm thứ 2 [1252], (Tống Thuần Hựu năm'
#               seg[0:60]='Nhâm_Tý , Nguyên_Phong năm thứ 2 [ 1252 ] , ( Tống_Thuần Hựu'
#               ids[:8]=[0, 33101, 27253, 454, 618, 1673, 6, 4] | total_tokens=462
#       [TOKEN] id=019e5677… | raw[0:60]='Quý Sửu, Nguyên Phong năm thứ 3 [1253], (Tống Bảo Hựu năm th'
#               seg[0:60]='Quý_Sửu , Nguyên_Phong năm thứ 3 [ 1253 ] , ( Tống_Bảo_Hựu n'
#               ids[:8]=[0, 78309, 454, 294, 46535, 34, 6, 4] | total_tokens=236
#       [TOKEN] id=019e5677… | raw[0:60]='Giáp Dần, [Nguyên Phong] năm thứ 4 [1254], (Tống Bảo Hựu năm'
#               seg[0:60]='Giáp_Dần , [_Nguyên_Phong ] năm thứ 4 [ 1254 ] , ( Tống_Bảo_'
#               ids[:8]=[0, 42906, 254, 454, 397, 249994, 19, 6] | total_tokens=393
#       [TOKEN] id=019e5677… | raw[0:60]='Bấy giờ các vương hầu phần nhiều coi việc đánh nhau bằng tay'
#               seg[0:60]='Bấy_giờ các vương_hầu phần_nhiều coi việc đánh nhau bằng tay'
#               ids[:8]=[0, 335, 249999, 53, 454, 735, 58677, 925] | total_tokens=136
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW    7/50 | pages=[171, 172, 173, 174] | chars=7,626
#       [STRUCT] 10 structural boundaries | book='Đại Việt Sử Ký Toàn Thư'
#     [MINI-CHUNK] window chars=7,626 → 68 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
# {"split_after_indices":[5,8,12,16,21,23,27,31,36,42,46,48,52,57,60,64]}
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=68 → splits=[5, 8, 12, 16, 21, 23, 27, 31, 36, 42, 46, 48, 52, 57, 60, 64]
# llm trả về
#  [5, 8, 12, 16, 21, 23, 27, 31, 36, 42, 46, 48, 52, 57, 60, 64]
#
#
#
#     [MERGE] 68 mini-chunks + 16 splits → 17 semantic groups
#       [TOKEN] id=019e5677… | raw[0:60]='Tháng 6, bán ruộng công [2], mỗi diện là 5 quan tiền (bấy gi'
#               seg[0:60]='Tháng 6 , bán ruộng_công , mỗi diện là 5 quan tiền ( bấy_giờ'
#               ids[:8]=[0, 77833, 305, 6, 4, 8713, 3114, 27350] | total_tokens=427
#       [TOKEN] id=019e5677… | raw[0:60]='Ất Mão, [Nguyên Phong] năm thứ 5 [1255], (Tống Bảo Hựu năm t'
#               seg[0:60]='Ất_Mão , [_Nguyên_Phong ] năm thứ 5 [ 1255 ] , ( Tống_Bảo_Hự'
#               ids[:8]=[0, 6, 249975, 18, 454, 594, 3680, 6] | total_tokens=305
#       [TOKEN] id=019e5677… | raw[0:60]='Trước đó, đạo sĩ cung Thái Thanh tên là Thậm cầu tự cho vua.'
#               seg[0:60]='Trước đó , đạo_sĩ cung_Thái_Thanh tên là Thậm_cầu tự cho vua'
#               ids[:8]=[0, 69388, 2275, 6, 4, 14822, 454, 7] | total_tokens=268
#       [TOKEN] id=019e5677… | raw[0:60]='Đến năm [Nhật Duật] 48 tuổi, bị ốm hơn 1 tháng, các con ông'
#               seg[0:60]='Đến năm [ Nhật_Duật ] 48 tuổi , bị ốm hơn 1 tháng , các con'
#               ids[:8]=[0, 93433, 2933, 378, 28269, 454, 17726, 57273] | total_tokens=250
#       [TOKEN] id=019e5677… | raw[0:60]='Sử thần Ngô Sĩ Liên nói: Việc đaọ sĩ cầu tự, cho là đúng nh'
#               seg[0:60]='Sử_thần Ngô_Sĩ_Liên nói : Việc đạo_sĩ cầu tự , cho là đúng n'
#               ids[:8]=[0, 63034, 454, 927, 249994, 19, 90542, 454] | total_tokens=292
#       [TOKEN] id=019e5677… | raw[0:60]='Tháng 5, trồng 500 trượng toàn cây muỗm (suốt từ bến Hồng đế'
#               seg[0:60]='Tháng 5 , trồng 500 trượng toàn cây muỗm ( suốt từ bến Hồng'
#               ids[:8]=[0, 77833, 190, 6, 4, 85460, 2101, 4307] | total_tokens=141
#       [TOKEN] id=019e5677… | raw[0:60]='Bính Thìn, [Nguyên Phong] năm thứ 6 [1256], (Tống BẢo Hựu nă'
#               seg[0:60]='Bính Thìn , [_Nguyên_Phong ] năm thứ 6 [ 1256 ] , ( Tống_BẢo'
#               ids[:8]=[0, 34023, 6457, 384, 64269, 19, 6, 4] | total_tokens=322
#       [TOKEN] id=019e5677… | raw[0:60]='Tháng 3, nhuận, đúc 330 quả chuông.\nMùa hạ, tháng 5, sét đán'
#               seg[0:60]='Tháng 3 , nhuận , đúc 330 quả chuông . Mùa_hạ , tháng 5 , sé'
#               ids[:8]=[0, 77833, 138, 6, 4, 142924, 6, 4] | total_tokens=265
#       [TOKEN] id=019e5677… | raw[0:60]='Đinh Tỵ, [Nguyên Phong] năm thứ 7 [1257], (Tống Bảo Hựu năm'
#               seg[0:60]='Đinh_Tỵ , [_Nguyên_Phong ] năm thứ 7 [ 1257 ] , ( Tống_Bảo_H'
#               ids[:8]=[0, 224564, 454, 618, 162874, 6, 4, 378] | total_tokens=289
#       [TOKEN] id=019e5677… | raw[0:60]='Vua thân hành đốc chiến, xông pha tên đạn. Quan quân hơi nún'
#               seg[0:60]='Vua thân_hành đốc_chiến , xông_pha tên đạn . Quan_quân hơi n'
#               ids[:8]=[0, 35443, 11, 10807, 454, 127, 62012, 66837] | total_tokens=356
#       [TOKEN] id=019e5677… | raw[0:60]='Vua ngự thuyền nhỏ đến thuyền Thái úy Nhật Hiệu hỏi kế sách'
#               seg[0:60]='Vua ngự thuyền nhỏ đến thuyền Thái_úy Nhật_Hiệu hỏi kế_sách'
#               ids[:8]=[0, 35443, 11, 234, 52449, 169666, 14162, 1885] | total_tokens=263
#       [TOKEN] id=019e5677… | raw[0:60]='Sử thần Ngô Sĩ Liên nói: Nhật Hiệu là đại thần cùng họ với v'
#               seg[0:60]='Sử_thần Ngô_Sĩ_Liên nói : Nhật_Hiệu là đại_thần cùng họ với'
#               ids[:8]=[0, 63034, 454, 927, 249994, 19, 90542, 454] | total_tokens=210
#       [TOKEN] id=019e5677… | raw[0:60]='Ngày 24, vua và Thái Tử ngự lâu thuyền, tiến quân đến Đông B'
#               seg[0:60]='Ngày 24 , vua và Thái_Tử_ngự lâu thuyền , tiến_quân đến Đông'
#               ids[:8]=[0, 42812, 744, 6, 4, 86729, 544, 37347] | total_tokens=209
#       [TOKEN] id=019e5677… | raw[0:60]='Trước kia có lần vua ban xoài cho những người hầu cận, Cự Đà'
#               seg[0:60]='Trước_kia có lần vua ban_xoài cho những người hầu_cận , Cự_Đ'
#               ids[:8]=[0, 69388, 454, 15565, 524, 9230, 86729, 4599] | total_tokens=377
#       [TOKEN] id=019e5677… | raw[0:60]='Khi vua thân hành thống lĩnh sáu quân đi chống giặc, quan gi'
#               seg[0:60]='Khi vua thân_hành_thống_lĩnh sáu quân đi chống giặc , quan_g'
#               ids[:8]=[0, 16584, 86729, 10807, 454, 127, 62012, 454] | total_tokens=175
#       [TOKEN] id=019e5677… | raw[0:60]='Mậu Ngọ, [Nguyên Phong] na8m thứ 8 [1258], (Từ tháng 3 về sa'
#               seg[0:60]='Mậu_Ngọ , [_Nguyên_Phong ]_na8m thứ 8 [ 1258 ] , ( Từ tháng'
#               ids[:8]=[0, 276, 85284, 454, 69656, 19030, 6, 4] | total_tokens=363
#       [TOKEN] id=019e5677… | raw[0:60]='Sai sứ sang thông hiếu với nhà Tống.\nSai Lê Phụ Trần, Chu Bá'
#               seg[0:60]='Sai sứ sang thông_hiếu với nhà_Tống . Sai Lê_Phụ_Trần , Chu'
#               ids[:8]=[0, 19319, 108327, 6079, 4225, 454, 979, 63513] | total_tokens=123
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW    8/50 | pages=[174, 175, 176, 177] | chars=7,305
#       [STRUCT] 11 structural boundaries | book='Đại Việt Sử Ký Toàn Thư'
#     [MINI-CHUNK] window chars=7,305 → 65 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
# {"split_after_indices":[7,10,16,20,27,30,36,41,44,51,56,60]}
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=65 → splits=[7, 10, 16, 20, 27, 30, 36, 41, 44, 51, 56, 60]
# llm trả về
#  [7, 10, 16, 20, 27, 30, 36, 41, 44, 51, 56, 60]
#
#
#
#     [MERGE] 65 mini-chunks + 12 splits → 13 semantic groups
#       [TOKEN] id=019e5677… | raw[0:60]='Tháng 2, ngày 24, vua nhường ngôi cho Hoàng thái tử Hoảng, l'
#               seg[0:60]='Tháng 2 , ngày 24 , vua nhường_ngôi cho Hoàng_thái_tử_Hoảng'
#               ids[:8]=[0, 77833, 116, 6, 4, 3063, 744, 6] | total_tokens=512
#       [TOKEN] id=019e5677… | raw[0:60]='Các quan dâng tôn hiệu là Hiến Thiên Thể Đạo Đại Minh Quang'
#               seg[0:60]='Các quan_dâng tôn_hiệu là Hiến_Thiên_Thể_Đạo Đại_Minh_Quang_'
#               ids[:8]=[0, 9211, 2261, 454, 71, 63858, 77990, 454] | total_tokens=199
#       [TOKEN] id=019e5677… | raw[0:60]='THÁNH TÔNG HOÀNG ĐẾ Tên húy là Hoảng, con trưởng dòng đích'
#               seg[0:60]='THÁNH_TÔNG_HOÀNG_ĐẾ Tên húy là Hoảng , con trưởng dòng đích'
#               ids[:8]=[0, 12232, 27096, 841, 454, 618, 62958, 8066] | total_tokens=400
#       [TOKEN] id=019e5677… | raw[0:60]='Kỷ Mùi, Thiệu Long năm thứ 2 [1259], (Tống Khai Khánh năm th'
#               seg[0:60]='Kỷ_Mùi , Thiệu_Long năm thứ 2 [ 1259 ] , ( Tống_Khai_Khánh n'
#               ids[:8]=[0, 341, 60479, 454, 594, 65934, 6, 4] | total_tokens=255
#       [TOKEN] id=019e5677… | raw[0:60]='Sử thần Ngô Sĩ Liên nói: Linh Từ trước lấy Lý Huệ Tông là bấ'
#               seg[0:60]='Sử_thần Ngô_Sĩ_Liên nói : Linh Từ trước lấy Lý_Huệ_Tông là b'
#               ids[:8]=[0, 63034, 454, 927, 249994, 19, 90542, 454] | total_tokens=478
#       [TOKEN] id=019e5677… | raw[0:60]='Mùa hạ, tháng 6, cho Nguyên Giới Huân làm Đại hành khiển, Th'
#               seg[0:60]='Mùa hạ , tháng 6 , cho Nguyên_Giới Huân làm Đại_hành_khiển ,'
#               ids[:8]=[0, 220174, 36771, 6, 4, 7973, 305, 6] | total_tokens=224
#       [TOKEN] id=019e5677… | raw[0:60]='Canh Thân,[Thiệu Long] năm thứ 3 [1260], (Tống Cảnh Định năm'
#               seg[0:60]='Canh_Thân , [_Thiệu Long_] năm thứ 3 [ 1260 ] , ( Tống_Cảnh_'
#               ids[:8]=[0, 4171, 127, 454, 618, 150388, 6, 4] | total_tokens=326
#       [TOKEN] id=019e5677… | raw[0:60]='Mùa hạ, tháng 6, nhà Nguyễn sai Lễ bộ lang trung Mạnh Giáp,'
#               seg[0:60]='Mùa hạ , tháng 6 , nhà Nguyễn_sai_Lễ bộ lang_trung_Mạnh_Giáp'
#               ids[:8]=[0, 220174, 36771, 6, 4, 7973, 305, 6] | total_tokens=391
#       [TOKEN] id=019e5677… | raw[0:60]='Sai Thông thị đại phu Trần Phụng Công, Chư vệ ký ban Nguyễn'
#               seg[0:60]='Sai Thông_thị đại_phu Trần_Phụng_Công , Chư_vệ ký ban Nguyễn'
#               ids[:8]=[0, 19319, 18619, 454, 927, 51721, 7899, 454] | total_tokens=220
#       [TOKEN] id=019e5677… | raw[0:60]='Sử thần Ngô Sĩ Liên nói: Theo quy chế nhà Trần, các vương hầ'
#               seg[0:60]='Sử_thần Ngô_Sĩ_Liên nói : Theo quy_chế nhà Trần , các vương_'
#               ids[:8]=[0, 63034, 454, 927, 249994, 19, 90542, 454] | total_tokens=360
#       [TOKEN] id=019e5677… | raw[0:60]='Nhâm Tuất, [Thiệu Long] năm thứ 5 [1262], (Tống Cảnh Định n'
#               seg[0:60]='Nhâm Tuất , [_Thiệu Long_] năm thứ 5 [ 1262 ] , ( Tống_Cảnh_'
#               ids[:8]=[0, 33101, 27253, 1371, 249999, 18, 6, 4] | total_tokens=382
#       [TOKEN] id=019e5677… | raw[0:60]='Tháng 3, xuống chiếu cho các quân chế tạo vũ khí, chiến thuy'
#               seg[0:60]='Tháng 3 , xuống chiếu cho các quân_chế_tạo vũ_khí , chiến_th'
#               ids[:8]=[0, 77833, 138, 6, 4, 19398, 80062, 681] | total_tokens=241
#       [TOKEN] id=019e5677… | raw[0:60]='Quý Hợi, [Thiệu Long ] năm thứ 6 [1263], (Tống Cảnh Định năm'
#               seg[0:60]='Quý_Hợi , [_Thiệu Long_] năm thứ 6 [ 1263 ] , ( Tống_Cảnh_Đị'
#               ids[:8]=[0, 78309, 454, 841, 30599, 14, 6, 4] | total_tokens=188
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW    9/50 | pages=[177, 178, 179, 180] | chars=6,231
#       [STRUCT] 14 structural boundaries | book='Đại Việt Sử Ký Toàn Thư'
#     [MINI-CHUNK] window chars=6,231 → 61 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
# {"split_after_indices":[1,23,30,36,43,46,53,58]}
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=61 → splits=[1, 6, 14, 23, 30, 36, 43, 46, 53, 58]
# llm trả về
#  [1, 6, 14, 23, 30, 36, 43, 46, 53, 58]
#
#
#
#     [MERGE] 61 mini-chunks + 10 splits → 11 semantic groups
#       [TOKEN] id=019e5677… | raw[0:60]='Tháng 9, có bệnh dịch Mùa đông, tháng 12, gió lớn, mưa to.\nT'
#               seg[0:60]='Tháng 9 , có bệnh_dịch Mùa đông , tháng 12 , gió lớn , mưa t'
#               ids[:8]=[0, 77833, 483, 6, 4, 524, 7417, 454] | total_tokens=124
#       [TOKEN] id=019e5677… | raw[0:60]='Giáp tý,[ Thiệu Long] năm thứ 7 [1264], (Tống Cảnh Định năm'
#               seg[0:60]='Giáp_tý , [_Thiệu Long_] năm thứ 7 [ 1264 ] , ( Tống_Cảnh_Đị'
#               ids[:8]=[0, 42906, 254, 454, 13949, 6, 4, 378] | total_tokens=286
#       [TOKEN] id=019e5677… | raw[0:60]='Thái Tông lập tức lệnh xe ngự đến dinh Thủ Độ, bắt cả người'
#               seg[0:60]='Thái_Tông lập_tức lệnh xe_ngự đến dinh Thủ_Độ , bắt cả người'
#               ids[:8]=[0, 37347, 454, 618, 23366, 12552, 454, 18] | total_tokens=362
#       [TOKEN] id=019e5677… | raw[0:60]='Khi xét duyệt đến xã ấy, hỏi tên mỗ ở đâu, người đó mừng rỡ'
#               seg[0:60]='Khi xét_duyệt đến xã ấy , hỏi tên mỗ ở đâu , người đó mừng_r'
#               ids[:8]=[0, 16584, 31462, 454, 693, 53, 33340, 1885] | total_tokens=373
#       [TOKEN] id=019e5677… | raw[0:60]='Tháng 2, sao Chổi hiện ở phương đông bắc.\nTháng 3, lấy Khâm'
#               seg[0:60]='Tháng 2 , sao Chổi hiện ở phương đông bắc . Tháng 3 , lấy Kh'
#               ids[:8]=[0, 77833, 116, 6, 4, 6284, 3751, 25091] | total_tokens=323
#       [TOKEN] id=019e5677… | raw[0:60]='Tháng 10, mùa đông năm ấy, vua Tống băng.\nẤt Sửu, [ Thiệu Lo'
#               seg[0:60]='Tháng 10 , mùa đông năm ấy , vua Tống_băng . Ất_Sửu , [_Thiệ'
#               ids[:8]=[0, 77833, 209, 6, 4, 45591, 37127, 2933] | total_tokens=331
#       [TOKEN] id=019e5677… | raw[0:60]='Bính Dần,[Thiệu Long]năm thứ 9 [1266],(Tống Hàm Thuần năm th'
#               seg[0:60]='Bính Dần , [_Thiệu Long_] năm thứ 9 [ 1266 ] , ( Tống_Hàm_Th'
#               ids[:8]=[0, 34023, 6457, 391, 249994, 19, 6, 4] | total_tokens=482
#       [TOKEN] id=019e5677… | raw[0:60]='Tháng 2, thủy quân lộ Đông Hải đi tuần biên giới đến núi Ô L'
#               seg[0:60]='Tháng 2 , thủy quân_lộ Đông_Hải đi tuần biên_giới đến núi Ô_'
#               ids[:8]=[0, 77833, 116, 6, 4, 58740, 29225, 454] | total_tokens=204
#       [TOKEN] id=019e5677… | raw[0:60]='Đinh Mão,[Thiệu Long]năm thứ 10 [1267], (Tống Hàm Thuần năm'
#               seg[0:60]='Đinh_Mão , [_Thiệu Long_] năm thứ 10 [ 1267 ] , ( Tống_Hàm_T'
#               ids[:8]=[0, 224564, 454, 594, 3680, 6, 4, 378] | total_tokens=439
#       [TOKEN] id=019e5677… | raw[0:60]='Tháng 5, phong em là Ích Tắc làm Chiêu Quốc Vương.\nÍch Tắc l'
#               seg[0:60]='Tháng 5 , phong_em là Ích_Tắc làm Chiêu_Quốc_Vương . Ích_Tắc'
#               ids[:8]=[0, 77833, 190, 6, 4, 22510, 454, 195] | total_tokens=310
#       [TOKEN] id=019e5677… | raw[0:60]='Mùa thu, tháng 8, xuống chiếu định quân ngũ, mỗi quân 30 đô,'
#               seg[0:60]='Mùa thu , tháng 8 , xuống chiếu_định quân_ngũ , mỗi quân 30'
#               ids[:8]=[0, 220174, 4911, 6, 4, 7973, 382, 6] | total_tokens=113
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW   10/50 | pages=[180, 181, 182, 183] | chars=8,402
#       [STRUCT] 19 structural boundaries | book='Đại Việt Sử Ký Toàn Thư'
#     [MINI-CHUNK] window chars=8,402 → 79 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
# {"split_after_indices":[8,15,21,26,30,40,47,51,57,62,73]}
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=79 → splits=[8, 15, 21, 26, 30, 35, 40, 47, 51, 57, 62, 67, 73]
# llm trả về
#  [8, 15, 21, 26, 30, 35, 40, 47, 51, 57, 62, 67, 73]
#
#
#
#     [MERGE] 79 mini-chunks + 13 splits → 14 semantic groups
#       [TOKEN] id=019e5677… | raw[0:60]='Mậu Thìn, [Thiệu Long] năm thứ 11 [1269], (Tống Hàm Thuần nă'
#               seg[0:60]='Mậu_Thìn , [_Thiệu Long_] năm thứ 11 [ 1269 ] , ( Tống_Hàm_T'
#               ids[:8]=[0, 276, 85284, 454, 618, 64269, 19, 6] | total_tokens=463
#       [TOKEN] id=019e5677… | raw[0:60]='Ngoại thích là Lý Cát phạm tội ngồi vào ngai vua ở điện Thiê'
#               seg[0:60]='Ngoại_thích là Lý_Cát_phạm_tội ngồi vào ngai vua ở điện Thiê'
#               ids[:8]=[0, 141715, 454, 927, 10767, 580, 44980, 454] | total_tokens=425
#       [TOKEN] id=019e5677… | raw[0:60]='Kỷ Tỵ, [Thiệu Long] năm thứ 12 [1269], (Tống Hàm Thuần năm t'
#               seg[0:60]='Kỷ_Tỵ , [_Thiệu Long_] năm thứ 12 [ 1269 ] , ( Tống_Hàm_Thuầ'
#               ids[:8]=[0, 341, 60479, 454, 618, 162874, 6, 4] | total_tokens=303
#       [TOKEN] id=019e5677… | raw[0:60]='Canh Ngọ,[Thiệu Long] năm thứ 13 [1270], (Tống Hàm Thuần năm'
#               seg[0:60]='Canh_Ngọ , [_Thiệu Long_] năm thứ 13 [ 1270 ] , ( Tống_Hàm_T'
#               ids[:8]=[0, 4171, 127, 454, 69656, 19030, 6, 4] | total_tokens=378
#       [TOKEN] id=019e5677… | raw[0:60]='Tân Mùi, [Thiệu Long] năm thứ 14 [1271], (Tống Hàm Thuần năm'
#               seg[0:60]='Tân_Mùi , [_Thiệu Long_] năm thứ 14 [ 1271 ] , ( Tống_Hàm_Th'
#               ids[:8]=[0, 49320, 454, 594, 65934, 6, 4, 378] | total_tokens=284
#       [TOKEN] id=019e5677… | raw[0:60]='Nhâm Thân, [Thiệu Long] năm thứ 15 [1272], (Tống Hàm Thuần n'
#               seg[0:60]='Nhâm_Thân , [_Thiệu Long_] năm thứ 15 [ 1272 ] , ( Tống_Hàm_'
#               ids[:8]=[0, 33101, 27253, 454, 618, 150388, 6, 4] | total_tokens=356
#       [TOKEN] id=019e5677… | raw[0:60]='[Phu] trở về nói rằng, cột đồng Mã Viện dựng lâu năm đã bị'
#               seg[0:60]='[ Phu_] trở về nói rằng , cột đồng Mã_Viện dựng lâu năm đã b'
#               ids[:8]=[0, 378, 13000, 34, 454, 268, 9293, 1893] | total_tokens=218
#       [TOKEN] id=019e5677… | raw[0:60]='Quý dậu, Bảo Phù năm thứ 1 [1273], (Tống Hàm Thuần năm thứ 9'
#               seg[0:60]='Quý_dậu , Bảo_Phù năm thứ 1 [ 1273 ] , ( Tống_Hàm_Thuần năm'
#               ids[:8]=[0, 78309, 454, 71, 85284, 6, 4, 46585] | total_tokens=512
#       [TOKEN] id=019e5677… | raw[0:60]='Tháng 12, sách phong hoàng trưởng tử Khâm làm hoàng thái tử,'
#               seg[0:60]='Tháng 12 , sách_phong_hoàng_trưởng tử_Khâm làm_hoàng_thái_tử'
#               ids[:8]=[0, 77833, 427, 6, 4, 11481, 454, 254] | total_tokens=250
#       [TOKEN] id=019e5677… | raw[0:60]='Ất Hợi, [Bảo Phù] năm thứ 3 [1275], (Tống Cung Đế Hiền Đức H'
#               seg[0:60]='Ất_Hợi , [_Bảo Phù_] năm thứ 3 [ 1275 ] , ( Tống_Cung_Đế Hiề'
#               ids[:8]=[0, 6, 249975, 18, 454, 841, 30599, 14] | total_tokens=348
#       [TOKEN] id=019e5677… | raw[0:60]='[5]Bính Tý, [Bảo Phù] năm thứ 4 [1276], (Tống Đức Hựu năm t'
#               seg[0:60]='Bính Tý , [_Bảo Phù_] năm thứ 4 [ 1276 ] , ( Tống_Đức_Hựu nă'
#               ids[:8]=[0, 34023, 6457, 384, 1673, 6, 4, 378] | total_tokens=345
#       [TOKEN] id=019e5677… | raw[0:60]='Đinh Sửu, [Bảo Phù] năm thứ 5 [1277], (Tống Cảnh Viêm năm th'
#               seg[0:60]='Đinh_Sửu , [_Bảo Phù_] năm thứ 5 [ 1277 ] , ( Tống_Cảnh Viêm'
#               ids[:8]=[0, 224564, 454, 294, 46535, 34, 6, 4] | total_tokens=285
#       [TOKEN] id=019e5677… | raw[0:60]='Hôm sau Mặc lão tâu : "Thấy một chiếc hòm vuông bốn mặt đều'
#               seg[0:60]='Hôm sau Mặc_lão tâu : " Thấy một chiếc hòm vuông bốn mặt đều'
#               ids[:8]=[0, 144779, 858, 105167, 454, 141, 3680, 6] | total_tokens=286
#       [TOKEN] id=019e5677… | raw[0:60]='Sử thần Ngô Sĩ Liên nói : Điềm lành hay tai họa, chỉ có ngườ'
#               seg[0:60]='Sử_thần Ngô_Sĩ_Liên nói : Điềm_lành hay tai_họa , chỉ có ngư'
#               ids[:8]=[0, 63034, 454, 927, 249994, 19, 90542, 454] | total_tokens=231
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW   11/50 | pages=[183, 184, 185, 186] | chars=7,114
#       [STRUCT] 7 structural boundaries | book='Đại Việt Sử Ký Toàn Thư'
#     [MINI-CHUNK] window chars=7,114 → 66 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
# {"split_after_indices":[10,15,20,31,37,41,48,53,63]}
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=66 → splits=[4, 10, 15, 20, 25, 31, 37, 41, 48, 53, 58, 63]
# llm trả về
#  [4, 10, 15, 20, 25, 31, 37, 41, 48, 53, 58, 63]
#
#
#
#     [MERGE] 66 mini-chunks + 12 splits → 13 semantic groups
#       [TOKEN] id=019e5677… | raw[0:60]='Tháng 5, nước to. Đất nứt sâu 7 trượng (chưa rõ chỗ nào), sú'
#               seg[0:60]='Tháng 5 , nước to . Đất nứt sâu 7 trượng ( chưa rõ chỗ nào )'
#               ids[:8]=[0, 77833, 190, 6, 4, 3042, 47, 6] | total_tokens=283
#       [TOKEN] id=019e5677… | raw[0:60]='(Sáng nghiệp Việt Đường hai Thái Tông Kia xưng Trinh Quán, t'
#               seg[0:60]='( Sáng_nghiệp Việt_Đường hai Thái_Tông Kia xưng Trinh_Quán ,'
#               ids[:8]=[0, 15, 147211, 454, 19, 18651, 21018, 254] | total_tokens=302
#       [TOKEN] id=019e5677… | raw[0:60]='Hôm thượng hoàng băng, công chúa Thiều Dương (con gái thứ củ'
#               seg[0:60]='Hôm thượng_hoàng băng , công_chúa Thiều_Dương ( con gái thứ'
#               ids[:8]=[0, 144779, 117357, 454, 497, 1298, 449, 116752] | total_tokens=284
#       [TOKEN] id=019e5677… | raw[0:60]='Bấy giờ Uy Văn Vương Toại lấy con gái của Thượng Hhàng là cô'
#               seg[0:60]='Bấy_giờ Uy_Văn_Vương Toại lấy con gái của Thượng_Hhàng là cô'
#               ids[:8]=[0, 335, 249999, 53, 454, 735, 58677, 58039] | total_tokens=306
#       [TOKEN] id=019e5677… | raw[0:60]='Mậu Dần, [Bảo Phù] năm thứ 6 [1278], (Tống Cảnh Viêm năm thứ'
#               seg[0:60]='Mậu_Dần , [_Bảo Phù_] năm thứ 6 [ 1278 ] , ( Tống_Cảnh Viêm'
#               ids[:8]=[0, 276, 85284, 454, 397, 249994, 19, 6] | total_tokens=252
#       [TOKEN] id=019e5677… | raw[0:60]='Khung trả lời :" Thần ấn đầu người nào mà thấy mồ hôi thấm t'
#               seg[0:60]='Khung trả_lời : " Thần_ấn đầu người nào mà thấy mồ_hôi thấm_'
#               ids[:8]=[0, 26966, 449, 18035, 454, 141, 110771, 152] | total_tokens=261
#       [TOKEN] id=019e5677… | raw[0:60]='Tháng 3, phu nhân Lê Phụ Trần là công chúa Chiêu Thánh Lý th'
#               seg[0:60]='Tháng 3 , phu_nhân Lê_Phụ_Trần là công_chúa Chiêu_Thánh_Lý_t'
#               ids[:8]=[0, 77833, 138, 6, 4, 103429, 454, 19] | total_tokens=431
#       [TOKEN] id=019e5677… | raw[0:60]='Vua Nguyên nghe tin Thái Tông băng, có ý mưa tính nước ta, s'
#               seg[0:60]='Vua Nguyên nghe tin Thái_Tông băng , có ý mưa tính nước ta ,'
# ...
#               ids[:8]=[0, 69388, 454, 15565, 6, 4, 12908, 29099] | total_tokens=339
#       [TOKEN] id=019e567b… | raw[0:60]='Tân Tỵ, [1410], (Hồ Hán Thương Thiệu Thành năm thứ 1, Minh K'
#               seg[0:60]='Tân_Tỵ , [ 1410 ] , ( Hồ_Hán_Thương Thiệu_Thành năm thứ 1 ,'
#               ids[:8]=[0, 49320, 454, 618, 162874, 6, 4, 378] | total_tokens=237
#       [TOKEN] id=019e567b… | raw[0:60]='Mùa hạ, tháng 4, Hán Thương sai làm sổ hộ tịch trong cả nước'
#               seg[0:60]='Mùa hạ , tháng 4 , Hán_Thương sai làm sổ hộ_tịch trong cả nư'
#               ids[:8]=[0, 220174, 36771, 6, 4, 7973, 201, 6] | total_tokens=290
#       [TOKEN] id=019e567b… | raw[0:60]='Hán Thương lập phép hạn chế gia nô, chiếu theo phẩm cấp được'
#               seg[0:60]='Hán_Thương lập_phép hạn_chế gia_nô , chiếu theo_phẩm cấp đượ'
#               ids[:8]=[0, 29099, 19, 454, 20800, 43672, 12552, 454] | total_tokens=344
#       [TOKEN] id=019e567b… | raw[0:60]='Hồ Tùng đi đánh Chiêm Thành, nghe lời Đình Đại Trung, cho qu'
#               seg[0:60]='Hồ_Tùng đi đánh Chiêm_Thành , nghe lời_Đình_Đại_Trung , cho'
#               ids[:8]=[0, 21433, 454, 618, 34335, 2467, 13868, 5585] | total_tokens=325
#       [TOKEN] id=019e567b… | raw[0:60]='Hán Thương hạ lệnh cho các lộ nung gạch để dùng vào việc xây'
#               seg[0:60]='Hán_Thương hạ_lệnh cho các lộ nung gạch để dùng vào việc xây'
#               ids[:8]=[0, 29099, 19, 454, 20800, 43672, 36771, 454] | total_tokens=198
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW   48/50 | pages=[298, 299, 300, 301] | chars=7,981
#       [STRUCT] 4 structural boundaries | book='Đại Việt Sử Ký Toàn Thư'
#     [MINI-CHUNK] window chars=7,981 → 72 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
# {"split_after_indices":[2,7,12,20,27,33,38,44,47,53,60,63,68]}
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=72 → splits=[2, 7, 12, 20, 27, 33, 38, 44, 47, 53, 60, 63, 68]
# llm trả về
#  [2, 7, 12, 20, 27, 33, 38, 44, 47, 53, 60, 63, 68]
#
#
#
#     [MERGE] 72 mini-chunks + 13 splits → 14 semantic groups
#       [TOKEN] id=019e567b… | raw[0:60]='Tháng 3, Hán Thương đắp sửa đường sá từ thành Tây Đô đến Hóa'
#               seg[0:60]='Tháng 3 , Hán_Thương đắp sửa đường_sá từ thành Tây_Đô đến Hó'
#               ids[:8]=[0, 77833, 138, 6, 4, 29099, 19, 454] | total_tokens=232
#       [TOKEN] id=019e567b… | raw[0:60]='Đại quân sắp tới đất Chiêm, Đinh Đại Trung cưỡi ngựa đi trướ'
#               seg[0:60]='Đại_quân sắp tới đất Chiêm , Đinh_Đại_Trung_cưỡi ngựa đi trư'
#               ids[:8]=[0, 18832, 454, 5490, 7453, 61260, 7067, 11472] | total_tokens=295
#       [TOKEN] id=019e567b… | raw[0:60]='Hán Thương điều An phủ sứ lộ Thuận Hóa Nguyễn Cảnh Chân làm'
#               seg[0:60]='Hán_Thương điều An_phủ sứ_lộ Thuận_Hóa Nguyễn_Cảnh_Chân làm'
#               ids[:8]=[0, 29099, 19, 454, 20800, 43672, 4069, 893] | total_tokens=285
#       [TOKEN] id=019e567b… | raw[0:60]='Đặt nhã nhạc, lấy con các quan văn làm kinh vĩ lang, con các'
#               seg[0:60]='Đặt nhã_nhạc , lấy con các quan_văn làm kinh_vĩ_lang , con c'
#               ids[:8]=[0, 167176, 653, 84284, 454, 6457, 61787, 6] | total_tokens=407
#       [TOKEN] id=019e567b… | raw[0:60]='Nhưng vì khi dâng chén rượu, [Hán Thương] run tay, rượu bị'
#               seg[0:60]='Nhưng vì khi dâng chén rượu , [ Hán_Thương ] run_tay , rượu'
#               ids[:8]=[0, 19751, 5396, 1907, 5912, 177, 3863, 2746] | total_tokens=333
#       [TOKEN] id=019e567b… | raw[0:60]='Sĩ nhân Nguyễn Bẩm dâng thư cho rằng Tiền Hồ [1] nên nhường'
#               seg[0:60]='Sĩ_nhân Nguyễn_Bẩm_dâng thư cho rằng Tiền_Hồ nên nhường_ngôi'
#               ids[:8]=[0, 159, 32606, 454, 19, 150388, 19098, 454] | total_tokens=330
#       [TOKEN] id=019e567b… | raw[0:60]='Hán Thương mộ dân nộp trâu để cấp cho dân mới dời đến ở Thăn'
#               seg[0:60]='Hán Thương_mộ dân nộp trâu để cấp cho dân mới dời đến ở Thăn'
#               ids[:8]=[0, 29099, 19, 81629, 454, 39, 27350, 5912] | total_tokens=322
#       [TOKEN] id=019e567b… | raw[0:60]='Hán Thương cấm người tôn thất và cung nhân không được xưng q'
#               seg[0:60]='Hán_Thương cấm người tôn_thất và cung_nhân không được xưng q'
#               ids[:8]=[0, 29099, 19, 454, 20800, 43672, 153887, 1008] | total_tokens=379
#       [TOKEN] id=019e567b… | raw[0:60]='Hán Thương dựng miếu ở các lăng tẩm tại Thiên Xương, để thờ'
#               seg[0:60]='Hán_Thương dựng miếu ở các lăng_tẩm tại Thiên_Xương , để thờ'
#               ids[:8]=[0, 29099, 19, 454, 20800, 43672, 13291, 324] | total_tokens=182
#       [TOKEN] id=019e567b… | raw[0:60]='Nhà Minh sai Ổ Tu [8] sang báo việc Thái Tông lên ngôi và đổ'
#               seg[0:60]='Nhà_Minh sai Ổ_Tu sang báo việc Thái_Tông lên_ngôi và đổi ni'
#               ids[:8]=[0, 19491, 454, 59076, 127, 5630, 6, 99973] | total_tokens=369
#       [TOKEN] id=019e567b… | raw[0:60]='Có người bảo là Giải Tấn làm bài thơ đó cho nên bị tại họa ['
#               seg[0:60]='Có người bảo là Giải_Tấn làm bài thơ đó cho_nên bị tại họa .'
#               ids[:8]=[0, 11302, 1008, 6122, 580, 67954, 454, 618] | total_tokens=441
#       [TOKEN] id=019e567b… | raw[0:60]='Đỗ Nguyên Thác vì trái lệnh của đô tướng, tha tội chết, bị'
#               seg[0:60]='Đỗ_Nguyên_Thác vì trái_lệnh của đô_tướng , tha_tội chết , bị'
#               ids[:8]=[0, 215925, 454, 839, 1234, 12357, 454, 20800] | total_tokens=280
#       [TOKEN] id=019e567b… | raw[0:60]='Phan Phu Tiên nói: Nguyên Khôi vốn không có tài làm tướng, c'
#               seg[0:60]='Phan_Phu_Tiên nói : Nguyên_Khôi vốn không có tài làm tướng ,'
#               ids[:8]=[0, 95581, 454, 683, 1132, 454, 16734, 1732] | total_tokens=316
#       [TOKEN] id=019e567b… | raw[0:60]='Đại Năng xảo trá, có sức khoẻ, có thể bắn được nỏ cứng. Sau'
#               seg[0:60]='Đại_Năng_xảo trá , có sức khỏe , có_thể bắn được nỏ cứng . S'
#               ids[:8]=[0, 18832, 454, 839, 44473, 454, 425, 17195] | total_tokens=138
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW   49/50 | pages=[301, 302, 303, 304] | chars=6,586
#       [STRUCT] 3 structural boundaries | book='Đại Việt Sử Ký Toàn Thư'
#     [MINI-CHUNK] window chars=6,586 → 62 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
# {"split_after_indices":[5,10,15,21,26,30,34,43,48,52,56,60]}
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=62 → splits=[5, 10, 15, 21, 26, 30, 34, 43, 48, 52, 56, 60]
# llm trả về
#  [5, 10, 15, 21, 26, 30, 34, 43, 48, 52, 56, 60]
#
#
#
#     [MERGE] 62 mini-chunks + 12 splits → 13 semantic groups
#       [TOKEN] id=019e567b… | raw[0:60]='Mùa đông, tháng 10, Hán Thương giết thân thuộc của bọn Nguyễ'
#               seg[0:60]='Mùa đông , tháng 10 , Hán_Thương giết thân_thuộc của bọn Ngu'
#               ids[:8]=[0, 220174, 37127, 6, 4, 7973, 209, 6] | total_tokens=348
#       [TOKEN] id=019e567b… | raw[0:60]='Giáp Thân, [1404], (Hán Thương Khai Đại năm thứ 2, Minh Vĩn'
#               seg[0:60]='Giáp_Thân , [ 1404 ] , ( Hán_Thương Khai_Đại năm thứ 2 , Min'
#               ids[:8]=[0, 42906, 254, 454, 618, 150388, 6, 4] | total_tokens=297
#       [TOKEN] id=019e567b… | raw[0:60]='Hán Thương định thể thức thi chọn nhân tài: Cứ tháng 8 năm n'
#               seg[0:60]='Hán Thương_định_thể thức thi chọn nhân_tài : Cứ tháng 8 năm'
#               ids[:8]=[0, 29099, 19, 81629, 454, 18643, 147809, 454] | total_tokens=249
#       [TOKEN] id=019e567b… | raw[0:60]='Trước đây, năm Nhâm Ngọ [1402], chọn tráng đinh, người nghèo'
#               seg[0:60]='Trước_đây , năm Nhâm_Ngọ [ 1402 ] , chọn tráng đinh , người'
#               ids[:8]=[0, 69388, 454, 18643, 38746, 6, 4, 2933] | total_tokens=390
#       [TOKEN] id=019e567b… | raw[0:60]='Trước đó, Tùng đã bị giải chức, xin bán các đồ khí giới của'
#               seg[0:60]='Trước đó , Tùng đã bị giải_chức , xin bán các đồ khí_giới củ'
#               ids[:8]=[0, 69388, 2275, 6, 4, 384, 34335, 1408] | total_tokens=294
#       [TOKEN] id=019e567b… | raw[0:60]='Kỳ tự quyền làm oai làm phúc, đánh đập các quan bạn tống và'
#               seg[0:60]='Kỳ tự_quyền làm oai làm_phúc , đánh_đập các quan bạn tống và'
#               ids[:8]=[0, 50572, 5208, 454, 5490, 53, 32809, 19] | total_tokens=312
#       [TOKEN] id=019e567b… | raw[0:60]='Hán Thương ra lệnh cho các quan viên không được đi hia, chỉ'
#               seg[0:60]='Hán_Thương ra_lệnh cho các quan_viên không được đi hia , chỉ'
#               ids[:8]=[0, 29099, 19, 454, 20800, 43672, 673, 454] | total_tokens=204
#       [TOKEN] id=019e567b… | raw[0:60]='Ất Dậu, [1405], (Hán Thương Khai Đại năm thứ 3, Minh Vĩnh Lạ'
#               seg[0:60]='Ất_Dậu , [ 1405 ] , ( Hán_Thương Khai_Đại năm thứ 3 , Minh_V'
#               ids[:8]=[0, 6, 249975, 18, 454, 397, 85284, 6] | total_tokens=512
#       [TOKEN] id=019e567b… | raw[0:60]='Nhà Minh sai sứ sang đòi cắt đất Lộc Châu ở Lạng Sơn.\n(Bấy g'
#               seg[0:60]='Nhà_Minh sai sứ sang đòi cắt đất Lộc_Châu ở Lạng_Sơn . ( Bấy'
#               ids[:8]=[0, 19491, 454, 59076, 127, 5630, 108327, 6079] | total_tokens=321
#       [TOKEN] id=019e567b… | raw[0:60]='Hán Thương lệnh cho những nơi đầu nguồn ở các trấn nộp gỗ là'
#               seg[0:60]='Hán Thương_lệnh cho những nơi đầu nguồn ở các trấn nộp gỗ là'
#               ids[:8]=[0, 29099, 19, 81629, 454, 141, 21018, 6457] | total_tokens=238
#       [TOKEN] id=019e567b… | raw[0:60]='Mùa hạ, tháng 6, sét đánh và Đông cung (tên nô cùng vú nuôi'
#               seg[0:60]='Mùa hạ , tháng 6 , sét đánh và Đông_cung ( tên nô cùng vú nu'
#               ids[:8]=[0, 220174, 36771, 6, 4, 7973, 305, 6] | total_tokens=319
#       [TOKEN] id=019e567b… | raw[0:60]='Mùa thu, tháng 7, Quý Ly và Hán Thương đi tuần tra xem xét n'
#               seg[0:60]='Mùa thu , tháng 7 , Quý_Ly và Hán_Thương đi tuần_tra xem_xét'
#               ids[:8]=[0, 220174, 4911, 6, 4, 7973, 361, 6] | total_tokens=192
#       [TOKEN] id=019e567b… | raw[0:60]='(Tư Thiện đường vốn là tên nhà học của thái tử triều Trần).'
#               seg[0:60]='( Tư_Thiện đường vốn là tên nhà_học của thái_tử triều_Trần )'
#               ids[:8]=[0, 15, 35191, 454, 20800, 93801, 7590, 28550] | total_tokens=48
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW   50/50 | pages=[304, 305, 306, 307] | chars=10,475
#       [STRUCT] 6 structural boundaries | book='Đại Việt Sử Ký Toàn Thư'
#     [MINI-CHUNK] window chars=10,475 → 94 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
# {"split_after_indices":[2,10,15,20,27,36,41,45,49,53,57,62,68,77,82,86,91]}
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=94 → splits=[2, 10, 15, 20, 27, 36, 41, 45, 49, 53, 57, 62, 68, 77, 82, 86, 91]
# llm trả về
#  [2, 10, 15, 20, 27, 36, 41, 45, 49, 53, 57, 62, 68, 77, 82, 86, 91]
#
#
#
#     [MERGE] 94 mini-chunks + 17 splits → 18 semantic groups
#       [TOKEN] id=019e567b… | raw[0:60]='Tháng 9, Hán Thương sai thi lại viên.\nHán Thương định quân N'
#               seg[0:60]='Tháng 9 , Hán_Thương sai thi lại viên . Hán Thương_định quân'
#               ids[:8]=[0, 77833, 483, 6, 4, 29099, 19, 454] | total_tokens=166
#       [TOKEN] id=019e567b… | raw[0:60]='Hán Thương sai tả Hình bộ lang trung Phạm Canh sang nhà Minh'
#               seg[0:60]='Hán_Thương sai_tả Hình_bộ lang_trung_Phạm_Canh sang nhà_Minh'
#               ids[:8]=[0, 29099, 19, 454, 20800, 43672, 5630, 454] | total_tokens=442
#       [TOKEN] id=019e567b… | raw[0:60]='Quý Ly thấy mình tuổi đã 70, ban cho phụ lão các lộ từ 70 tu'
#               seg[0:60]='Quý_Ly thấy mình tuổi đã 70 , ban cho phụ_lão các lộ từ 70 t'
#               ids[:8]=[0, 78309, 454, 133011, 4913, 3087, 13856, 1408] | total_tokens=312
#       [TOKEN] id=019e567b… | raw[0:60]='Hán Thương chiếu truyền An phủ sứ lộ về triều, cùng với các'
#               seg[0:60]='Hán Thương_chiếu truyền_An_phủ sứ_lộ về triều , cùng_với các'
#               ids[:8]=[0, 29099, 19, 81629, 454, 1861, 63513, 18099] | total_tokens=301
#       [TOKEN] id=019e567b… | raw[0:60]='Bính Tuất, [1406], (Hán Thương Khai Đại năm thứ 4, Minh Vĩnh'
#               seg[0:60]='Bính Tuất , [ 1406 ] , ( Hán_Thương Khai_Đại năm thứ 4 , Min'
#               ids[:8]=[0, 34023, 6457, 1371, 249999, 18, 6, 4] | total_tokens=348
#       [TOKEN] id=019e567b… | raw[0:60]='Tả tướng quốc Trừng bỏ thuyền lên bờ, suýt bị vây, có người'
#               seg[0:60]='Tả_tướng quốc_Trừng bỏ thuyền lên bờ , suýt bị vây , có ngườ'
#               ids[:8]=[0, 384, 17195, 454, 18, 103180, 10895, 454] | total_tokens=460
#       [TOKEN] id=019e567b… | raw[0:60]='Hồ Xạ cho phép. Vì thế, tuy bắt bắt được nhiều tù binh mà ng'
#               seg[0:60]='Hồ_Xạ cho_phép . Vì_thế , tuy bắt bắt được nhiều tù_binh mà'
#               ids[:8]=[0, 21433, 454, 1542, 12976, 681, 454, 11727] | total_tokens=291
#       [TOKEN] id=019e567b… | raw[0:60]='Nội cẩm y vệ nhà Minh Phạm Chất nói với Hán Thương rằng Lưu'
#               seg[0:60]='Nội_cẩm y_vệ nhà_Minh Phạm_Chất nói với Hán_Thương rằng Lưu_'
#               ids[:8]=[0, 9435, 454, 238, 249989, 39, 113, 454] | total_tokens=280
#       [TOKEN] id=019e567b… | raw[0:60]='Khi quân Minh mới vào cõi, ra lệnh cho nhân dân đều phá bỏ h'
#               seg[0:60]='Khi quân_Minh mới vào cõi , ra_lệnh cho nhân_dân đều phá_bỏ'
#               ids[:8]=[0, 16584, 29225, 454, 59076, 127, 3633, 2249] | total_tokens=330
#       [TOKEN] id=019e567b… | raw[0:60]='Hán Thương gọi Tuyên phủ sứ Thăng Hoa Nguyễn Ngạn Quang về l'
#               seg[0:60]='Hán_Thương gọi Tuyên_phủ sứ_Thăng_Hoa Nguyễn_Ngạn_Quang về l'
#               ids[:8]=[0, 29099, 19, 454, 20800, 43672, 19605, 1371] | total_tokens=347
#       [TOKEN] id=019e567b… | raw[0:60]='Tháng 6, đỉnh tháp Báo Thiên đổ, An phủ sứ Đông Đô Lê Khải k'
#               seg[0:60]='Tháng 6 , đỉnh tháp Báo Thiên_đổ , An_phủ sứ_Đông_Đô Lê_Khải'
#               ids[:8]=[0, 77833, 305, 6, 4, 127013, 221555, 54192] | total_tokens=248
#       [TOKEN] id=019e567b… | raw[0:60]='Quý Ly chiêm bao thấy thần nhân ngâm bài thơ rằng:\nNhị nguyệ'
#               seg[0:60]='Quý Ly_chiêm bao thấy thần nhân_ngâm bài thơ rằng : Nhị_nguy'
#               ids[:8]=[0, 78309, 18118, 454, 1861, 13033, 8609, 4913] | total_tokens=338
#       [TOKEN] id=019e567b… | raw[0:60]='Hán Thương gọi các quan cũ chờ lệnh bổ dụng.Tháng 9, nhà Min'
#               seg[0:60]='Hán_Thương gọi các quan cũ chờ lệnh bổ_dụng . Tháng 9 , nhà_'
#               ids[:8]=[0, 29099, 19, 454, 20800, 43672, 19605, 925] | total_tokens=280
#       [TOKEN] id=019e567b… | raw[0:60]='Tháng 11 [quân Minh] hội ở sông Bạch Hạc, bày doanh trại bờ'
#               seg[0:60]='Tháng 11 [ quân_Minh ]_hội ở sông Bạch_Hạc , bày_doanh trại'
#               ids[:8]=[0, 77833, 534, 378, 29225, 454, 59076, 127] | total_tokens=512
#       [TOKEN] id=019e567b… | raw[0:60]='Mùa đông, tháng 10, người Minh lại đến. Từ sông Lô trở lên b'
#               seg[0:60]='Mùa đông , tháng 10 , người Minh lại đến . Từ sông Lô trở lê'
#               ids[:8]=[0, 220174, 37127, 6, 4, 7973, 209, 6] | total_tokens=348
#       [TOKEN] id=019e567b… | raw[0:60]='Đêm ngày mồng 9, quân Minh đánh úp quân họ Hồ ở bãi Mộc Hoàn'
#               seg[0:60]='Đêm ngày mồng 9 , quân_Minh đánh úp_quân họ Hồ ở bãi Mộc_Hoà'
#               ids[:8]=[0, 4428, 13033, 3063, 347, 32773, 483, 6] | total_tokens=243
#       [TOKEN] id=019e567b… | raw[0:60]='Quân Minh liền vượt sông làm cầu phao để sang.\nSáng ngày 12'
#               seg[0:60]='Quân_Minh liền vượt sông làm cầu_phao để sang . Sáng ngày 12'
#               ids[:8]=[0, 101390, 454, 59076, 127, 37015, 63179, 90677] | total_tokens=309
#       [TOKEN] id=019e567b… | raw[0:60]='Người Minh vào Đông Đô bắt cướp con gái, ngọc lụa, thống kê'
#               seg[0:60]='Người Minh vào Đông_Đô bắt cướp con gái , ngọc_lụa , thống_k'
#               ids[:8]=[0, 19167, 13985, 2249, 35116, 454, 13347, 4470] | total_tokens=99
#
# [SAVE] Writing 682 points → 'full_DVSK_data_aiteamvn_512.json'…
# [SAVE] Done. 2070.9 KB written.

# %%
# with open("full_test_bkai_256.json", "r", encoding="utf-8") as fh:
#     loaded_chunks = json.load(fh)
# for chunk in loaded_chunks:
#     print(chunk["token_count"])
# # print(loaded_chunks)
#     # tok_count = inspect_tokens(chunk["raw_text"], chunk["embed_input"], tokenizer, chunk["chunk_id"])
#     # print (tok_count)
#     # print("\n\n")

# %% [markdown]
# # Chạy Khâm Định Việt Sử Thông Giám Cương Mục

# %%
# @title

import os
from google.colab import userdata


# JSON_PATH = "full_DVSK_data.json"           # Đại Việt Sử Ký Toàn Thư
JSON_PATH = "full_KhamDinh_data.json"        # Khâm Định Việt Sử Thông Giám Cương Mục
# JSON_PATH = "full_VietSu_data.json"                 # Việt Sử Toàn Thư
# JSON_PATH = "full_VTT_data.json"                  # Vương Triều Trần
# JSON_PATH = "full_test.json"
# JSON_PATH = "full_test_VTT.json"


OUTPUT_PATH = JSON_PATH.replace(".json", f"_qdrant_points_{CHUNK_CONTEXT_LENGTH}.json")


def _load_key(colab_secret: str, env_var: str) -> str:
    try:
        from google.colab import userdata as _ud
        val = _ud.get(colab_secret)
        if val:
            print(f"[KEY] '{colab_secret}' loaded from Colab Secrets.")
            return val
    except Exception:
        pass
    val = os.environ.get(env_var, "")
    if val:
        print(f"[KEY] '{env_var}' loaded from environment variable.")
    return val

GROQ_API_KEY   = _load_key("grok_key",  "grok_key")
GEMINI_API_KEY = _load_key("GEMINI_API_KEY", "GEMINI_API_KEY")

if not GROQ_API_KEY and not GEMINI_API_KEY:
    print("[KEY] ⚠  No API keys found. "
          "Add GROQ_API_KEY and/or GOOGLE_API_KEY to Colab Secrets.")


LLM_BACKENDS:       list[LLMBackend]                  = []

# if GROQ_API_KEY:
#     LLM_BACKENDS.append(GroqBackend(GROQ_API_KEY, GROQ_MODEL_LLAMA_70B))
#     LLM_BACKENDS.append(GroqBackend(GROQ_API_KEY, GROQ_MODEL_LLAMA_8B))
#     LLM_BACKENDS.append(GroqBackend(GROQ_API_KEY, GROQ_MODEL_QWEN))

if GEMINI_API_KEY:
    try:
        LLM_BACKENDS.append(GeminiBackend(GEMINI_API_KEY, GEMINI_MODEL_ID))
        print(f"[INIT] GeminiBackend added: {GEMINI_MODEL_ID}")
    except Exception as exc:
        print(f"[INIT] GeminiBackend skipped ({type(exc).__name__}: {exc})")


if not LLM_BACKENDS:
    raise RuntimeError(
        "LLM_BACKENDS is empty. Provide GROQ_API_KEY and/or GEMINI_API_KEY."
    )


print(f"[INIT] Sync LLM chain ready ({len(LLM_BACKENDS)} backend(s)):")
for i, backend in enumerate(LLM_BACKENDS, start=1):
    print(f"   [{i}] {backend.label}")

print()

# Load input JSON
print(f"[LOAD] Reading '{JSON_PATH}'…")

with open(JSON_PATH, "r", encoding="utf-8") as fh:
    input_data: dict = json.load(fh)


assert "book_name" in input_data, "Missing key: book_name"
assert "full_text" in input_data, "Missing key: full_text"
assert "page_footnotes_map" in input_data, "Missing key: page_footnotes_map"

assert isinstance(input_data["book_name"], str), "book_name must be str"
assert isinstance(input_data["full_text"], str), "full_text must be str"
assert isinstance(input_data["page_footnotes_map"], dict), "page_footnotes_map must be dict"

print("[LOAD] Input validation passed ✓")


# Run pipeline
qdrant_points: list[dict] = run_pipeline(
    input_data,
    backends=LLM_BACKENDS,
)


# Save local output
print(f"\n[SAVE] Writing {len(qdrant_points):,} points → '{OUTPUT_PATH}'…")

with open(OUTPUT_PATH, "w", encoding="utf-8") as fh:
    json.dump(qdrant_points, fh, ensure_ascii=False, indent=2)

kb = os.path.getsize(OUTPUT_PATH) / 1024
print(f"[SAVE] Done. {kb:.1f} KB written.")
# Out:
# [KEY] 'grok_key' loaded from Colab Secrets.
# [KEY] 'GEMINI_API_KEY' loaded from Colab Secrets.
# [INIT] GeminiBackend added: gemini-3.1-flash-lite
# [INIT] Sync LLM chain ready (1 backend(s)):
#    [1] gemini-sync/gemini-3.1-flash-lite
#
# [LOAD] Reading 'full_KhamDinh_data.json'…
# [LOAD] Input validation passed ✓
#
# ════════════════════════════════════════════════════════════════════════
#   [PHASE 1] RUN CHUNKING PIPELINE — 'Khâm Định Việt Sử Thông Giám Cương Mục'
#   Using Context Length Target: 512
# ════════════════════════════════════════════════════════════════════════
#
# [WINDOWS] book='Khâm Định Việt Sử Thông Giám Cương Mục' | window_size=3 pages
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW    1/54 | pages=[187, 188, 189] | chars=7,089
#       [STRUCT] 2 structural boundaries | book='Khâm Định Việt Sử Thông Giám Cương '
#     [MINI-CHUNK] window chars=7,089 → 63 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
# {"split_after_indices":[5,13,19,27,35,40,43,48,53,58]}
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=63 → splits=[5, 13, 19, 27, 35, 40, 43, 48, 53, 58]
# llm trả về
#  [5, 13, 19, 27, 35, 40, 43, 48, 53, 58]
#
#
#
#     [MERGE] 63 mini-chunks + 10 splits → 11 semantic groups
#       [TOKEN] id=019e567b… | raw[0:60]='Tháng 10, mùa đông. Lập con gái là Phật Kim làm Thái tử.\nNhà'
#               seg[0:60]='Tháng 10 , mùa đông . Lập con gái là Phật_Kim_làm Thái_tử .'
#               ids[:8]=[0, 77833, 209, 6, 4, 45591, 37127, 6] | total_tokens=354
#       [TOKEN] id=019e567b… | raw[0:60]='Ất Dậu (1225). (Lý Chiêu Hoàng, năm Thiên chương hữu đạo thứ'
#               seg[0:60]='Ất_Dậu ( 1225 ) . ( Lý_Chiêu_Hoàng , năm Thiên_chương hữu_đạ'
#               ids[:8]=[0, 6, 249975, 18, 454, 397, 85284, 15] | total_tokens=396
#       [TOKEN] id=019e567b… | raw[0:60]='Tháng 12. Nội thị chính thủ Trần Cảnh tự xưng Hoàng đế (tức'
#               seg[0:60]='Tháng 12 . Nội_thị chính_thủ Trần_Cảnh tự_xưng Hoàng_đế ( tứ'
#               ids[:8]=[0, 77833, 427, 6, 5, 9435, 454, 927] | total_tokens=347
#       [TOKEN] id=019e567b… | raw[0:60]='Ngày 21 tháng 12, bầy tôi tiến triều, lạy mừng. Nhà vua xuố'
#               seg[0:60]='Ngày 21 tháng 12 , bầy tôi tiến_triều , lạy_mừng . Nhà_vua x'
#               ids[:8]=[0, 42812, 952, 7973, 427, 6, 4, 876] | total_tokens=427
#       [TOKEN] id=019e567b… | raw[0:60]='Trần Cảnh lên ngôi ở điện Thiên An, đổi niên hiệu; đại xá. B'
#               seg[0:60]='Trần_Cảnh lên_ngôi ở điện Thiên_An , đổi niên_hiệu ; đại_xá'
#               ids[:8]=[0, 42974, 454, 441, 17195, 6457, 4494, 454] | total_tokens=418
#       [TOKEN] id=019e567b… | raw[0:60]='Lời phê - Thực là việc lạ, suốt nghìn xưa chưa hề có. Các tr'
#               seg[0:60]='Lời phê - Thực_là việc lạ , suốt nghìn xưa chưa hề có . Các'
#               ids[:8]=[0, 157214, 57679, 20, 59747, 454, 16161, 2735] | total_tokens=337
#       [TOKEN] id=019e567b… | raw[0:60]='Đây trở lên, nhà Lý từ Thái Tổ năm Canh Tuất (1010) đến Huệ'
#               seg[0:60]='Đây trở lên , nhà_Lý từ Thái_Tổ năm Canh_Tuất ( 1010 ) đến H'
#               ids[:8]=[0, 37540, 9293, 4494, 6, 4, 2455, 454] | total_tokens=288
#       [TOKEN] id=019e567b… | raw[0:60]='(cid:148) Bính Tuất (1226), Trần Thái Tông hoàng đế năm Kiến'
#               seg[0:60]='( cid : 148 ) Bính_Tuất ( 1226 ) , Trần_Thái_Tông_hoàng_đế n'
#               ids[:8]=[0, 15, 94845, 152, 76277, 1388, 34023, 6457] | total_tokens=330
#       [TOKEN] id=019e567b… | raw[0:60]='Giáng truất Thượng hoàng nhà Lý [1] làm Huệ Quang Đại sư.\nTh'
#               seg[0:60]='Giáng_truất Thượng_hoàng nhà Lý_làm Huệ_Quang Đại_sư . Thượn'
#               ids[:8]=[0, 42906, 449, 454, 9774, 249999, 18, 146182] | total_tokens=272
#       [TOKEN] id=019e567b… | raw[0:60]='Tháng 2. Định ra luật lệnh.\nSai Trần Thủ Độ đi đánh Nguyễn N'
#               seg[0:60]='Tháng 2 . Định ra luật_lệnh . Sai Trần_Thủ_Độ đi đánh Nguyễn'
#               ids[:8]=[0, 77833, 116, 6, 5, 124818, 673, 18179] | total_tokens=291
#       [TOKEN] id=019e567b… | raw[0:60]='Lời chua - Quảng Oai: Xem Lý Huệ Tông, năm Kiến Gia thứ 8 (C'
#               seg[0:60]='Lời chua - Quảng_Oai : Xem Lý_Huệ_Tông , năm Kiến_Gia thứ 8'
#               ids[:8]=[0, 157214, 116284, 20, 56767, 454, 670, 508] | total_tokens=244
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW    2/54 | pages=[189, 190, 191, 192] | chars=7,841
#       [STRUCT] 2 structural boundaries | book='Khâm Định Việt Sử Thông Giám Cương '
#     [MINI-CHUNK] window chars=7,841 → 66 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
# {"split_after_indices":[7,13,16,23,26,29,35,39,42,45,52,53,60,64]}
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=66 → splits=[7, 13, 16, 23, 26, 29, 35, 39, 42, 45, 52, 53, 60, 64]
# llm trả về
#  [7, 13, 16, 23, 26, 29, 35, 39, 42, 45, 52, 53, 60, 64]
#
#
#
#     [MERGE] 66 mini-chunks + 14 splits → 15 semantic groups
#       [TOKEN] id=019e567c… | raw[0:60]='Tháng 8, mùa thu. Trần Thủ Độ giết Thượng hoàng nhà Lý ở chù'
#               seg[0:60]='Tháng 8 , mùa thu . Trần_Thủ_Độ giết_Thượng_hoàng nhà_Lý ở c'
#               ids[:8]=[0, 77833, 382, 6, 4, 45591, 4911, 6] | total_tokens=403
#       [TOKEN] id=019e567c… | raw[0:60]='Thủ Độ bắt các quan đến khóc viếng, đào tường phía nam thành'
#               seg[0:60]='Thủ_Độ bắt các quan đến khóc viếng , đào tường phía nam thàn'
#               ids[:8]=[0, 40797, 454, 13347, 27350, 13363, 925, 2261] | total_tokens=406
#       [TOKEN] id=019e567c… | raw[0:60]='Lời phê - Thủ Độ là công thần nhà Trần, tức là tội nhân nhà'
#               seg[0:60]='Lời phê - Thủ_Độ là công_thần nhà Trần , tức_là tội_nhân nhà'
#               ids[:8]=[0, 157214, 57679, 20, 40797, 454, 13347, 27350] | total_tokens=195
#       [TOKEN] id=019e567c… | raw[0:60]='Tháng 10, mùa đông. Suy tôn bố đẻ là Thừa làm Thượng hoàng;'
#               seg[0:60]='Tháng 10 , mùa đông . Suy_tôn_bố đẻ là Thừa_làm Thượng_hoàng'
#               ids[:8]=[0, 77833, 209, 6, 4, 45591, 37127, 6] | total_tokens=485
#       [TOKEN] id=019e567c… | raw[0:60]='Định thể lệ tiền tệ.\nDân gian nộp tiền thượng cung, thì cứ m'
#               seg[0:60]='Định_thể_lệ tiền_tệ . Dân_gian nộp tiền thượng_cung , thì cứ'
#               ids[:8]=[0, 124818, 454, 927, 35895, 454, 141, 21018] | total_tokens=223
#       [TOKEN] id=019e567c… | raw[0:60]='Dùng Phùng Tá Chi Tri phủ Nghệ An.Tá Chu trước làm quan triề'
#               seg[0:60]='Dùng Phùng_Tá Chi_Tri phủ Nghệ_An . Tá_Chu trước làm quan tr'
#               ids[:8]=[0, 204596, 13000, 34335, 454, 110439, 5585, 454] | total_tokens=162
#       [TOKEN] id=019e567c… | raw[0:60]='Đinh Hợi, năm thứ 3 (1227). (Tống, năm Bảo Khánh thứ 3).\nThá'
#               seg[0:60]='Đinh_Hợi , năm thứ 3 ( 1227 ) . ( Tống , năm Bảo_Khánh thứ 3'
#               ids[:8]=[0, 224564, 454, 841, 30599, 14, 6, 4] | total_tokens=325
#       [TOKEN] id=019e567c… | raw[0:60]='Từ năm nay trở đi, năm nào cũng cử hành lễ này. Ngày hôm ấy'
#               seg[0:60]='Từ năm nay trở đi , năm nào cũng cử hành_lễ này . Ngày hôm ấ'
#               ids[:8]=[0, 30947, 2933, 7630, 9293, 2467, 6, 4] | total_tokens=370
#       [TOKEN] id=019e567c… | raw[0:60]='Tháng giêng, mùa xuân. Gia phong Nhật Hiệu làm Khâm Thiên đạ'
#               seg[0:60]='Tháng giêng , mùa xuân . Gia_phong Nhật_Hiệu làm Khâm_Thiên_'
#               ids[:8]=[0, 77833, 3016, 28498, 6, 4, 45591, 173887] | total_tokens=294
#       [TOKEN] id=019e567c… | raw[0:60]='Tháng 8, mùa thu. Phong cho anh là Liễu làm Thái uý.\nLiễu, đ'
#               seg[0:60]='Tháng 8 , mùa thu . Phong cho anh là Liễu làm Thái_úy . Liễu'
#               ids[:8]=[0, 77833, 382, 6, 4, 45591, 4911, 6] | total_tokens=183
#       [TOKEN] id=019e567c… | raw[0:60]='Xét trướng tịch ở Thanh Hóa.\nTheo chế độ nhà Lý, hằng năm sa'
#               seg[0:60]='Xét trướng_tịch ở Thanh_Hóa . Theo chế_độ nhà_Lý , hằng năm'
#               ids[:8]=[0, 1193, 2305, 4307, 103180, 454, 18, 166231] | total_tokens=462
#       [TOKEN] id=019e567c… | raw[0:60]='Tháng 10, mùa đông. Nước Chiêm Thành sai người đến cống hiến'
#               seg[0:60]='Tháng 10 , mùa đông . Nước Chiêm_Thành sai người đến cống_hi'
#               ids[:8]=[0, 77833, 209, 6, 4, 45591, 37127, 6] | total_tokens=123
#       [TOKEN] id=019e567c… | raw[0:60]='Nguyễn Nộn đánh giết được Đoàn Thượng. Nhà vua đem Ngoạn Thi'
#               seg[0:60]='Nguyễn_Nộn đánh giết được Đoàn_Thượng . Nhà_vua đem Ngoạn_Th'
#               ids[:8]=[0, 19098, 454, 839, 27350, 19, 13868, 86730] | total_tokens=417
#       [TOKEN] id=019e567c… | raw[0:60]='Yên (An) Nhân: Tên xã, thuộc tỉnh Hải Dương bây giờ [2].\nKỷ'
#               seg[0:60]='Yên ( An ) Nhân : Tên xã , thuộc tỉnh Hải_Dương bây_giờ . Kỷ'
#               ids[:8]=[0, 79308, 15, 893, 1388, 56025, 152, 102010] | total_tokens=332
#       [TOKEN] id=019e567c… | raw[0:60]='Nhà vua đã được nhà Lý truyền ngôi cho, nên mới sai sứ sang'
#               seg[0:60]='Nhà_vua đã được nhà_Lý_truyền ngôi cho , nên mới sai sứ sang'
#               ids[:8]=[0, 19491, 454, 1783, 11, 1408, 912, 2455] | total_tokens=76
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW    3/54 | pages=[192, 193, 194, 195] | chars=6,692
#       [STRUCT] 2 structural boundaries | book='Khâm Định Việt Sử Thông Giám Cương '
#     [MINI-CHUNK] window chars=6,692 → 59 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
# {"split_after_indices":[7,13,17,22,27,34,40,47,53,57]}
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=59 → splits=[7, 13, 17, 22, 27, 34, 40, 47, 53, 57]
# llm trả về
#  [7, 13, 17, 22, 27, 34, 40, 47, 53, 57]
#
#
#
#     [MERGE] 59 mini-chunks + 10 splits → 11 semantic groups
#       [TOKEN] id=019e567c… | raw[0:60]='Tháng 3, mùa xuân. Định thể lệ làm ra sách Thông chế và các'
#               seg[0:60]='Tháng 3 , mùa xuân . Định_thể_lệ làm ra sách Thông_chế và cá'
#               ids[:8]=[0, 77833, 138, 6, 4, 45591, 173887, 6] | total_tokens=385
#       [TOKEN] id=019e567c… | raw[0:60]='Nhân nền thành cũ của nhà Lý mà đắp thêm cho được kiên cố. T'
#               seg[0:60]='Nhân nền thành cũ của nhà_Lý mà đắp thêm cho được kiên_cố .'
#               ids[:8]=[0, 56025, 44565, 2781, 56667, 550, 2455, 454] | total_tokens=416
#       [TOKEN] id=019e567c… | raw[0:60]='Mục Chức quan chí trong Tấn thư chép rằng: Quan Đình úy giữ'
#               seg[0:60]='Mục_Chức quan_chí trong Tấn_thư chép rằng : Quan_Đình_úy giữ'
#               ids[:8]=[0, 133259, 454, 15982, 48021, 2261, 454, 206] | total_tokens=207
#       [TOKEN] id=019e567c… | raw[0:60]='Tháng 9, mùa thu. Quốc Thánh Hoàng Thái hậu là Lê Thị mất, t'
#               seg[0:60]='Tháng 9 , mùa thu . Quốc_Thánh_Hoàng Thái_hậu là Lê_Thị_mất'
#               ids[:8]=[0, 77833, 483, 6, 4, 45591, 4911, 6] | total_tokens=327
#       [TOKEN] id=019e567c… | raw[0:60]='Tháng 8, mùa thu. Nhà vua về thăm làng Tức Mặc, ban yến và t'
#               seg[0:60]='Tháng 8 , mùa thu . Nhà_vua về thăm làng Tức_Mặc , ban yến v'
#               ids[:8]=[0, 77833, 382, 6, 4, 45591, 4911, 6] | total_tokens=278
#       [TOKEN] id=019e567c… | raw[0:60]='Nhâm Thìn, năm Thiên Ứng chính bình thứ 1 (1232). (Tống, năm'
#               seg[0:60]='Nhâm Thìn , năm Thiên_Ứng_chính bình thứ 1 ( 1232 ) . ( Tống'
#               ids[:8]=[0, 33101, 27253, 384, 64269, 19, 6, 4] | total_tokens=397
#       [TOKEN] id=019e567c… | raw[0:60]='Bà Liệt: Tên thôn.\nTháng 2. Thi khoa Thái học sinh.\nTrước ki'
#               seg[0:60]='Bà_Liệt : Tên thôn . Tháng 2 . Thi_khoa Thái_học_sinh . Trướ'
#               ids[:8]=[0, 39914, 454, 9506, 33340, 152, 102010, 115020] | total_tokens=323
#       [TOKEN] id=019e567c… | raw[0:60]='Tháng 4, mùa hạ. Ban chữ huý về tiên tổ nhà vua thờ ở các mi'
#               seg[0:60]='Tháng 4 , mùa hạ . Ban chữ_húy về tiên_tổ nhà_vua thờ ở các'
#               ids[:8]=[0, 77833, 201, 6, 4, 45591, 36771, 6] | total_tokens=389
#       [TOKEN] id=019e567c… | raw[0:60]='Quý Tị, năm thứ 2 (1233). (Tống, năm Thiệu Định thứ 6).\nSai'
#               seg[0:60]='Quý_Tị , năm thứ 2 ( 1233 ) . ( Tống , năm Thiệu_Định thứ 6'
#               ids[:8]=[0, 78309, 454, 618, 51721, 6, 4, 2933] | total_tokens=496
#       [TOKEN] id=019e567c… | raw[0:60]='Phong cho Phùng Tá Chu tước Hưng Nhân vương và bổ dụng Phạm'
#               seg[0:60]='Phong cho Phùng_Tá Chu_tước Hưng_Nhân_vương và bổ_dụng Phạm_'
#               ids[:8]=[0, 55110, 681, 13000, 34335, 454, 110439, 15521] | total_tokens=276
#       [TOKEN] id=019e567c… | raw[0:60]='Tháng 2, mùa xuân. Sét đánh 30 chỗ ở trong kinh thành. Nhà v'
#               seg[0:60]='Tháng 2 , mùa xuân . Sét đánh 30 chỗ ở trong kinh_thành . Nh'
#               ids[:8]=[0, 77833, 116, 6, 4, 45591, 173887, 6] | total_tokens=69
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW    4/54 | pages=[195, 196, 197, 198] | chars=8,966
#       [STRUCT] 2 structural boundaries | book='Khâm Định Việt Sử Thông Giám Cương '
#     [MINI-CHUNK] window chars=8,966 → 83 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
# {"split_after_indices":[2,6,11,13,16,19,22,25,36,45,51,57,62,68,71,75,78,81]}
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=83 → splits=[2, 6, 11, 13, 16, 19, 22, 25, 30, 36, 45, 51, 57, 62, 68, 71, 75, 78, 81]
# llm trả về
#  [2, 6, 11, 13, 16, 19, 22, 25, 30, 36, 45, 51, 57, 62, 68, 71, 75, 78, 81]
#
#
#
#     [MERGE] 83 mini-chunks + 19 splits → 20 semantic groups
#       [TOKEN] id=019e567c… | raw[0:60]='Tháng 2, mùa xuân. Định quan hàm các bậc đại thần.\nPhàm nhữn'
#               seg[0:60]='Tháng 2 , mùa xuân . Định quan_hàm các bậc đại_thần . Phàm n'
#               ids[:8]=[0, 77833, 116, 6, 4, 45591, 173887, 6] | total_tokens=264
#       [TOKEN] id=019e567c… | raw[0:60]='Lời cẩn án - Sách Lịch triều hiến chương của Phan Huy Chú ch'
#               seg[0:60]='Lời cẩn_án - Sách Lịch_triều hiến_chương của Phan_Huy_Chú ch'
#               ids[:8]=[0, 157214, 137756, 454, 1665, 20, 159, 5687] | total_tokens=195
#       [TOKEN] id=019e567c… | raw[0:60]='Về hàng quan văn ở kinh thì có: các viên chức sáu bộ, như: T'
#               seg[0:60]='Về hàng quan_văn ở kinh thì có : các viên_chức sáu bộ , như'
#               ids[:8]=[0, 66863, 2508, 2261, 454, 19297, 19, 2059] | total_tokens=390
#       [TOKEN] id=019e567c… | raw[0:60]='Về quan chức ở ngoài thì có: An phủ sứ, Tri phủ, Thông phán,'
#               seg[0:60]='Về quan_chức ở ngoài thì có : An_phủ sứ , Tri_phủ , Thông_ph'
#               ids[:8]=[0, 66863, 2261, 454, 206, 48021, 2059, 10610] | total_tokens=192
#       [TOKEN] id=019e567c… | raw[0:60]='Hàng quan võ ở trong kinh thì có: Phiêu kỵ Thượng tướng quân'
#               seg[0:60]='Hàng_quan võ ở trong kinh thì có : Phiêu_kỵ Thượng_tướng quâ'
#               ids[:8]=[0, 67656, 454, 13722, 19, 24193, 2059, 1000] | total_tokens=242
#       [TOKEN] id=019e567c… | raw[0:60]='Chức quan võ ở ngoài các lộ thì có: Kinh lược sứ, Phòng ngự'
#               seg[0:60]='Chức_quan võ ở ngoài các lộ thì_có : Kinh_lược sứ , Phòng ng'
#               ids[:8]=[0, 213275, 454, 13722, 19, 24193, 2059, 10610] | total_tokens=313
#       [TOKEN] id=019e567c… | raw[0:60]='Tháng 6, mùa hạ. Nước to, chảy tràn vào cung Lệ Thiên. Hiểu'
#               seg[0:60]='Tháng 6 , mùa hạ . Nước to , chảy tràn vào cung_Lệ_Thiên . H'
#               ids[:8]=[0, 77833, 305, 6, 4, 45591, 36771, 6] | total_tokens=309
#       [TOKEN] id=019e567c… | raw[0:60]='Tháng 10, mùa đông. Bổ dụng Phạm Ứng Thần làm Thượng thư, ki'
#               seg[0:60]='Tháng 10 , mùa đông . Bổ_dụng Phạm_Ứng_Thần làm Thượng_thư ,'
#               ids[:8]=[0, 77833, 209, 6, 4, 45591, 37127, 6] | total_tokens=207
#       [TOKEN] id=019e567c… | raw[0:60]='Đinh Dậu, năm thứ 6 (1237). (Tống, năm Gia Hy thứ 1).\nTháng'
#               seg[0:60]='Đinh_Dậu , năm thứ 6 ( 1237 ) . ( Tống , năm Gia_Hy thứ 1 )'
#               ids[:8]=[0, 224564, 454, 397, 85284, 6, 4, 2933] | total_tokens=287
#       [TOKEN] id=019e567c… | raw[0:60]='Ngày hôm sau, Thủ Độ đem bầy tôi đến đón xa giá về kinh. Nh'
#               seg[0:60]='Ngày hôm sau , Thủ_Độ đem bầy tôi đến đón xa_giá về kinh . N'
#               ids[:8]=[0, 42812, 26094, 858, 6, 4, 40797, 454] | total_tokens=293
#       [TOKEN] id=019e567c… | raw[0:60]='Bấy giờ nhà vua mới trở về kinh thành. Trần Liễu ở ngoài bi'
#               seg[0:60]='Bấy_giờ nhà_vua mới trở về kinh_thành . Trần_Liễu ở ngoài bi'
#               ids[:8]=[0, 335, 249999, 53, 454, 735, 58677, 2455] | total_tokens=414
#       [TOKEN] id=019e567c… | raw[0:60]='còn những người theo Trần Liễu khởi loạn ở sông Cái đều bị'
#               seg[0:60]='còn những người theo Trần_Liễu_khởi_loạn ở sông_Cái đều bị g'
#               ids[:8]=[0, 3531, 1358, 1008, 3790, 42974, 454, 9506] | total_tokens=321
#       [TOKEN] id=019e567c… | raw[0:60]='Lời bàn của Phan Phu Tiên - Tam cương [1] ngũ thường [2], đó'
#               seg[0:60]='Lời bàn của Phan_Phu_Tiên - Tam_cương_ngũ thường , đó là luâ'
#               ids[:8]=[0, 157214, 18747, 550, 95581, 454, 683, 1132] | total_tokens=299
#       [TOKEN] id=019e567c… | raw[0:60]='Lời chua - Núi Yên Tử: Ở huyện Đông Triều, tỉnh Hải Dương; t'
#               seg[0:60]='Lời chua - Núi_Yên_Tử : Ở huyện Đông_Triều , tỉnh Hải_Dương'
#               ids[:8]=[0, 157214, 116284, 20, 40115, 14, 454, 1723] | total_tokens=315
#       [TOKEN] id=019e567c… | raw[0:60]='Mậu Tuất, năm thứ 7 (1238). (Tống, năm Gia Hy thứ 2).\nTháng'
#               seg[0:60]='Mậu_Tuất , năm thứ 7 ( 1238 ) . ( Tống , năm Gia_Hy thứ 2 )'
#               ids[:8]=[0, 276, 85284, 454, 15665, 249999, 18, 6] | total_tokens=465
#       [TOKEN] id=019e567c… | raw[0:60]='Tháng 8. Định quy chế dùng thuyền và xe cho vương hầu tôn th'
#               seg[0:60]='Tháng 8 . Định quy_chế dùng thuyền và xe cho vương_hầu tôn_t'
#               ids[:8]=[0, 77833, 382, 6, 5, 124818, 8317, 454] | total_tokens=235
#       [TOKEN] id=019e567c… | raw[0:60]='Tháng 3. Tuyển lính.\nTuyển dân đinh người nào khoẻ mạnh làm'
#               seg[0:60]='Tháng 3 . Tuyển lính . Tuyển dân đinh người nào khỏe mạnh là'
#               ids[:8]=[0, 77833, 138, 6, 5, 182556, 181889, 6] | total_tokens=345
#       [TOKEN] id=019e567c… | raw[0:60]='Đến nay, lại sinh con là Hoảng, mới lập làm Hoàng thái tử.'
#               seg[0:60]='Đến nay , lại sinh con là Hoảng , mới lập làm Hoàng_thái_tử'
#               ids[:8]=[0, 93433, 7630, 6, 4, 1917, 3811, 158] | total_tokens=291
#       [TOKEN] id=019e567c… | raw[0:60]='Lời chua - Lạng Giang: Tức Lạng Sơn bây giờ. Xem Lê Thánh Tô'
#               seg[0:60]='Lời chua - Lạng_Giang : Tức_Lạng_Sơn bây_giờ . Xem Lê_Thánh_'
#               ids[:8]=[0, 157214, 116284, 20, 339, 12976, 449, 454] | total_tokens=209
#       [TOKEN] id=019e567c… | raw[0:60]='Núi ở các lộ sụt xuống; đất liền ở phường Thịnh Quang ngoài'
#               seg[0:60]='Núi ở các lộ sụt xuống ; đất_liền ở phường Thịnh_Quang ngoài'
#               ids[:8]=[0, 40115, 14, 2059, 925, 32228, 91, 25070] | total_tokens=37
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW    5/54 | pages=[198, 199, 200, 201] | chars=7,322
#       [STRUCT] 2 structural boundaries | book='Khâm Định Việt Sử Thông Giám Cương '
#     [MINI-CHUNK] window chars=7,322 → 69 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
# {"split_after_indices":[8,15,27,38,45,50,57,64]}
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=69 → splits=[8, 15, 20, 27, 32, 38, 45, 50, 57, 64]
# llm trả về
#  [8, 15, 20, 27, 32, 38, 45, 50, 57, 64]
#
#
#
#     [MERGE] 69 mini-chunks + 10 splits → 11 semantic groups
#       [TOKEN] id=019e567c… | raw[0:60]='Tháng 10, mùa đông. Người Thổ, Mán nhà Tống sang cướp ở biên'
#               seg[0:60]='Tháng 10 , mùa đông . Người Thổ , Mán nhà Tống sang cướp ở b'
#               ids[:8]=[0, 77833, 209, 6, 4, 45591, 37127, 6] | total_tokens=455
#       [TOKEN] id=019e567c… | raw[0:60]='Nhâm Dần, năm thứ 11 (1242). (Tống, năm Thuần Hựu thứ 2).\nTh'
#               seg[0:60]='Nhâm Dần , năm thứ 11 ( 1242 ) . ( Tống , năm Thuần_Hựu thứ'
#               ids[:8]=[0, 33101, 27253, 391, 249994, 19, 6, 4] | total_tokens=263
#       [TOKEN] id=019e567c… | raw[0:60]='Về thuế: nhân đinh, ai có ruộng đất thì phải nộp tiền, thóc:'
#               seg[0:60]='Về thuế : nhân đinh , ai có ruộng_đất thì phải nộp tiền , th'
#               ids[:8]=[0, 66863, 39552, 152, 3090, 2467, 6457, 6] | total_tokens=266
#       [TOKEN] id=019e567c… | raw[0:60]='2) Ruộng thác đao: nhất đẳng, mỗi mẫu thu một thạch thóc; nh'
#               seg[0:60]='2 ) Ruộng_thác đao : nhất_đẳng , mỗi mẫu thu một thạch_thóc'
#               ids[:8]=[0, 116, 1388, 4518, 27350, 449, 454, 927] | total_tokens=333
#       [TOKEN] id=019e567c… | raw[0:60]='Lời chua - Mười hai lộ: Sử cũ không chép rõ, nhưng căn cứ nh'
#               seg[0:60]='Lời chua - Mười hai lộ : Sử cũ không chép rõ , nhưng căn_cứ'
#               ids[:8]=[0, 157214, 116284, 20, 191549, 1337, 32228, 152] | total_tokens=306
#       [TOKEN] id=019e567c… | raw[0:60]='Khi khải hoàn, nhà vua xét thưởng cho người có công đánh gi'
#               seg[0:60]='Khi khải_hoàn , nhà_vua xét_thưởng cho người có công đánh gi'
#               ids[:8]=[0, 16584, 23056, 14, 454, 497, 40974, 6] | total_tokens=257
#       [TOKEN] id=019e567c… | raw[0:60]='Xã, sách: Cũng như xã, thôn.Lời phê [1] - Nói rất mơ hồ.\nThá'
#               seg[0:60]='Xã , sách : Cũng như xã , thôn . Lời_phê - Nói rất mơ_hồ . T'
#               ids[:8]=[0, 133577, 6, 4, 11481, 152, 6, 105728] | total_tokens=399
#       [TOKEN] id=019e567c… | raw[0:60]='Đại hạn từ tháng 5 đến tháng 6. Nhà vua hạ lệnh xét lại tội'
#               seg[0:60]='Đại_hạn từ tháng 5 đến tháng 6 . Nhà_vua hạ_lệnh xét lại tội'
#               ids[:8]=[0, 18832, 454, 127, 12976, 19, 2368, 7973] | total_tokens=376
#       [TOKEN] id=019e567c… | raw[0:60]='Tháng giêng, mùa xuân. Bổ quan văn đi cai trị các lộ và phủ.'
#               seg[0:60]='Tháng giêng , mùa xuân . Bổ_quan văn_đi cai_trị các lộ và ph'
#               ids[:8]=[0, 77833, 3016, 28498, 6, 4, 45591, 173887] | total_tokens=336
#       [TOKEN] id=019e567c… | raw[0:60]='Tháng 3. Ban cho Phùng Tá Thang chức Tả giai [2] Đạo lục [3]'
#               seg[0:60]='Tháng 3 . Ban cho Phùng_Tá Thang_chức Tả giai_Đạo_lục , được'
#               ids[:8]=[0, 77833, 138, 6, 5, 5458, 681, 13000] | total_tokens=340
#       [TOKEN] id=019e567c… | raw[0:60]='Ất Tị, năm thứ 14 (1245). (Tống, năm Thuần Hựu thứ 5). Tháng'
#               seg[0:60]='Ất_Tị , năm thứ 14 ( 1245 ) . ( Tống , năm Thuần_Hựu thứ 5 )'
#               ids[:8]=[0, 6, 249975, 18, 454, 618, 51721, 6] | total_tokens=197
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW    6/54 | pages=[201, 202, 203, 204] | chars=7,650
#       [STRUCT] 2 structural boundaries | book='Khâm Định Việt Sử Thông Giám Cương '
#     [MINI-CHUNK] window chars=7,650 → 69 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
# {"split_after_indices":[3,14,22,29,39,44,48,54,62]}
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=69 → splits=[3, 8, 14, 22, 29, 34, 39, 44, 48, 54, 62]
# llm trả về
#  [3, 8, 14, 22, 29, 34, 39, 44, 48, 54, 62]
#
#
#
#     [MERGE] 69 mini-chunks + 11 splits → 12 semantic groups
#       [TOKEN] id=019e567c… | raw[0:60]='Tháng 2, mùa xuân. Định danh hiệu quân đội.\nTuyển lấy những'
#               seg[0:60]='Tháng 2 , mùa xuân . Định danh_hiệu quân_đội . Tuyển lấy nhữ'
#               ids[:8]=[0, 77833, 116, 6, 4, 45591, 173887, 6] | total_tokens=269
#       [TOKEN] id=019e567c… | raw[0:60]='Hạng thứ ba là đoàn đội chèo thuyền.\nLời cẩn án - Sách Lịch'
#               seg[0:60]='Hạng thứ ba là đoàn đội chèo thuyền . Lời cẩn_án - Sách Lịch'
#               ids[:8]=[0, 69625, 449, 11847, 961, 580, 27088, 25738] | total_tokens=228
#       [TOKEN] id=019e567c… | raw[0:60]='Nhưng số quân điều động lúc ấy cũng chỉ mới có mấy lộ về mặ'
#               seg[0:60]='Nhưng số quân điều_động lúc ấy cũng chỉ mới có mấy lộ về mặt'
#               ids[:8]=[0, 19751, 3030, 29225, 4069, 454, 18643, 27350] | total_tokens=289
#       [TOKEN] id=019e567c… | raw[0:60]='Lời chua - Tứ thiên, Tứ thánh, Tứ thần: Đều là tên quân túc'
#               seg[0:60]='Lời chua - Tứ_thiên , Tứ_thánh , Tứ_thần : Đều là tên quân_t'
#               ids[:8]=[0, 157214, 116284, 20, 384, 30342, 454, 4450] | total_tokens=392
#       [TOKEN] id=019e567c… | raw[0:60]='Hồng Lộ: Tức Hồng Châu. Xem thuộc Đường, Chiêu Tuyên đế, năm'
#               seg[0:60]='Hồng_Lộ : Tức_Hồng_Châu . Xem thuộc Đường , Chiêu Tuyên_đế ,'
#               ids[:8]=[0, 83361, 454, 866, 27350, 152, 384, 48021] | total_tokens=385
#       [TOKEN] id=019e567c… | raw[0:60]='Bấy giờ trong nước thái bình vô sự, nhân dân yên vui. Người'
#               seg[0:60]='Bấy_giờ trong nước thái_bình vô_sự , nhân_dân yên_vui . Ngườ'
#               ids[:8]=[0, 335, 249999, 53, 454, 735, 58677, 1000] | total_tokens=273
#       [TOKEN] id=019e567c… | raw[0:60]='Còn về chức tể tướng thì chọn những người trong họ tôn thất'
#               seg[0:60]='Còn về chức tể_tướng thì chọn những người trong họ tôn_thất'
#               ids[:8]=[0, 68662, 1893, 7211, 808, 35895, 454, 18] | total_tokens=271
#       [TOKEN] id=019e567c… | raw[0:60]='Tháng 7, mùa thu. Mới định niên hạn thi đại tị [1].Bấy giờ t'
#               seg[0:60]='Tháng 7 , mùa thu . Mới_định niên_hạn thi đại_tị . Bấy_giờ t'
#               ids[:8]=[0, 77833, 361, 6, 4, 45591, 4911, 6] | total_tokens=332
#       [TOKEN] id=019e567c… | raw[0:60]='Lê Văn Hưu [4]: Người Đông Sơn, Thanh Hóa.\nĐặng Ma La: Người'
#               seg[0:60]='Lê_Văn_Hưu : Người Đông_Sơn , Thanh_Hóa . Đặng_Ma_La : Người'
#               ids[:8]=[0, 16389, 454, 856, 451, 19, 454, 841] | total_tokens=313
#       [TOKEN] id=019e567c… | raw[0:60]='Vũ Vị Phủ: Người ở Hồng Châu.\nMậu Thân, năm thứ 17 (1248). ('
#               seg[0:60]='Vũ_Vị_Phủ : Người ở Hồng_Châu . Mậu_Thân , năm thứ 17 ( 1248'
#               ids[:8]=[0, 58979, 454, 856, 51721, 454, 45689, 39470] | total_tokens=334
#       [TOKEN] id=019e567c… | raw[0:60]='Tháng 4, mùa hạ. Dựng cầu Lâm Ba.Dựng cầu ở chùa Chân Giáo.'
#               seg[0:60]='Tháng 4 , mùa hạ . Dựng_cầu Lâm_Ba . Dựng cầu ở chùa Chân_Gi'
#               ids[:8]=[0, 77833, 201, 6, 4, 45591, 36771, 6] | total_tokens=425
#       [TOKEN] id=019e567c… | raw[0:60]='Thủ Độ sai những người tinh nghề phong thủy [3] xem xét núi'
#               seg[0:60]='Thủ_Độ sai những người tinh_nghề phong_thủy xem_xét núi sông'
#               ids[:8]=[0, 40797, 454, 13347, 27350, 5630, 1358, 1008] | total_tokens=315
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW    7/54 | pages=[204, 205, 206, 207] | chars=6,757
#       [STRUCT] 2 structural boundaries | book='Khâm Định Việt Sử Thông Giám Cương '
#     [MINI-CHUNK] window chars=6,757 → 62 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
# {"split_after_indices":[2,6,12,18,21,25,29,34,37,43,48,55,57]}
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=62 → splits=[2, 6, 12, 18, 21, 25, 29, 34, 37, 43, 48, 55, 57]
# llm trả về
#  [2, 6, 12, 18, 21, 25, 29, 34, 37, 43, 48, 55, 57]
#
#
#
#     [MERGE] 62 mini-chunks + 13 splits → 14 semantic groups
#       [TOKEN] id=019e567c… | raw[0:60]='Kỷ Dậu, năm thứ 18 (1249). (Tống, năm Thuần Hựu thứ 9).\nThán'
#               seg[0:60]='Kỷ_Dậu , năm thứ 18 ( 1249 ) . ( Tống , năm Thuần_Hựu thứ 9'
#               ids[:8]=[0, 341, 60479, 454, 397, 85284, 6, 4] | total_tokens=296
#       [TOKEN] id=019e567c… | raw[0:60]='Vì có nạn động đất, nên hạ chiếu cho thiên hạ gọi vua là "qu'
#               seg[0:60]='Vì có nạn động_đất , nên hạ_chiếu cho thiên_hạ gọi vua là "'
#               ids[:8]=[0, 32061, 524, 63303, 2613, 454, 18643, 249999] | total_tokens=242
#       [TOKEN] id=019e567c… | raw[0:60]='Lê Phụ Trần: Tên cũ là Lê Tần, người ở Ái Châu.\nTân Hợi, năm'
#               seg[0:60]='Lê_Phụ_Trần : Tên cũ là Lê_Tần , người ở Ái_Châu . Tân_Hợi ,'
#               ids[:8]=[0, 16389, 454, 45689, 25070, 454, 55487, 249994] | total_tokens=321
#       [TOKEN] id=019e567c… | raw[0:60]='Trước ngày cưới, nhà vua cho công chúa sang ở nhà của Nhân'
#               seg[0:60]='Trước ngày cưới , nhà_vua cho công_chúa sang ở nhà của Nhân_'
#               ids[:8]=[0, 69388, 3063, 89481, 6, 4, 2455, 454] | total_tokens=393
#       [TOKEN] id=019e567c… | raw[0:60]='Nhà vua bất đắc dĩ đem Thiên Thành công chúa gả cho Quốc Tu'
#               seg[0:60]='Nhà_vua bất_đắc_dĩ đem Thiên_Thành_công_chúa gả cho Quốc_Tuấ'
#               ids[:8]=[0, 19491, 454, 1783, 11, 9985, 454, 18643] | total_tokens=293
#       [TOKEN] id=019e567c… | raw[0:60]='Lời chua - Thiên Thành [5]: Con gái Thượng hoàng [6].\nQuốc T'
#               seg[0:60]='Lời chua - Thiên_Thành : Con gái Thượng_hoàng . Quốc_Tuấn :'
#               ids[:8]=[0, 157214, 116284, 20, 40776, 454, 20800, 62012] | total_tokens=204
#       [TOKEN] id=019e567c… | raw[0:60]='lúc ấy hai họ đều đưa ra những đồ vóc, lụa, trâm cài tóc và'
#               seg[0:60]='lúc ấy hai họ đều đưa ra những đồ_vóc , lụa , trâm cài_tóc v'
#               ids[:8]=[0, 10305, 14112, 1337, 7424, 9338, 15995, 673] | total_tokens=253
#       [TOKEN] id=019e567c… | raw[0:60]='Nhâm Tí, năm thứ 2 (1252). (Tống, năm Thuần Hựu thứ 12).\nThá'
#               seg[0:60]='Nhâm_Tí , năm thứ 2 ( 1252 ) . ( Tống , năm Thuần_Hựu thứ 12'
#               ids[:8]=[0, 33101, 27253, 454, 618, 430, 6, 4] | total_tokens=360
#       [TOKEN] id=019e567c… | raw[0:60]='bắt được vợ vua nước ấy là Bố Gia La và những thần thiếp nh'
#               seg[0:60]='bắt được vợ vua nước ấy là Bố_Gia_La và những thần_thiếp nhâ'
#               ids[:8]=[0, 13363, 912, 37435, 86729, 3042, 14112, 580] | total_tokens=209
#       [TOKEN] id=019e567c… | raw[0:60]='Tháng 8, mùa thu. Lập nhà giảng vũ.\nTháng 9. Hạ chiếu cho họ'
#               seg[0:60]='Tháng 8 , mùa thu . Lập nhà giảng_vũ . Tháng 9 . Hạ_chiếu ch'
#               ids[:8]=[0, 77833, 382, 6, 4, 45591, 4911, 6] | total_tokens=304
#       [TOKEN] id=019e567c… | raw[0:60]='Lời chua - Chỉ nha: Sách An nam chí nguyên của Cao Hùng Trưn'
#               seg[0:60]='Lời chua - Chỉ nha : Sách_An_nam chí_nguyên của Cao_Hùng_Trư'
#               ids[:8]=[0, 157214, 116284, 20, 36402, 92247, 152, 159] | total_tokens=266
#       [TOKEN] id=019e567c… | raw[0:60]='Tháng 10, mùa đông. Nhà vua bắt Phạm Ứng Mộng tự thiến mình'
#               seg[0:60]='Tháng 10 , mùa đông . Nhà_vua bắt_Phạm_Ứng_Mộng tự thiến mìn'
#               ids[:8]=[0, 77833, 209, 6, 4, 45591, 37127, 6] | total_tokens=376
#       [TOKEN] id=019e567c… | raw[0:60]='Lời phê - Huyền hoặc! Ví thế nào được như việc Thượng đế cho'
#               seg[0:60]='Lời phê - Huyền_hoặc !_Ví thế_nào được như việc Thượng_đế ch'
#               ids[:8]=[0, 157214, 57679, 20, 219163, 454, 497, 64514] | total_tokens=177
#       [TOKEN] id=019e567c… | raw[0:60]='Phạm Ứng Mộng: Người huyện Thanh Miện, thuộc Hồng châu [3].'
#               seg[0:60]='Phạm_Ứng_Mộng : Người huyện Thanh_Miện , thuộc Hồng_châu . Ấ'
#               ids[:8]=[0, 93855, 454, 249968, 449, 454, 594, 27350] | total_tokens=196
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW    8/54 | pages=[207, 208, 209, 210] | chars=8,218
#       [STRUCT] 2 structural boundaries | book='Khâm Định Việt Sử Thông Giám Cương '
#     [MINI-CHUNK] window chars=8,218 → 78 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
# {"split_after_indices":[7,13,19,24,28,33,46,50,55,66,77]}
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=78 → splits=[7, 13, 19, 24, 28, 33, 38, 46, 50, 55, 60, 66, 75]
# llm trả về
#  [7, 13, 19, 24, 28, 33, 38, 46, 50, 55, 60, 66, 75]
#
#
#
#     [MERGE] 78 mini-chunks + 13 splits → 14 semantic groups
#       [TOKEN] id=019e567c… | raw[0:60]='Tháng 8, mùa thu. Nước to, nhà vua ra chơi Hồ Tây.\nLời bàn c'
#               seg[0:60]='Tháng 8 , mùa thu . Nước to , nhà_vua ra chơi Hồ_Tây . Lời b'
#               ids[:8]=[0, 77833, 382, 6, 4, 45591, 4911, 6] | total_tokens=381
#       [TOKEN] id=019e567c… | raw[0:60]='Bính Thìn, năm thứ 6 (1256). (Tống, năm Bảo Hựu thứ 4).\nThán'
#               seg[0:60]='Bính Thìn , năm thứ 6 ( 1256 ) . ( Tống , năm Bảo_Hựu thứ 4'
#               ids[:8]=[0, 34023, 6457, 384, 64269, 19, 6, 4] | total_tokens=332
#       [TOKEN] id=019e567c… | raw[0:60]='Tháng 3 nhuận. Đúc 330 quả chuông bằng đồng.\nLời bàn của Ngô'
#               seg[0:60]='Tháng 3 nhuận . Đúc 330 quả chuông bằng đồng . Lời bàn của N'
#               ids[:8]=[0, 77833, 138, 142924, 6, 5, 4428, 39882] | total_tokens=296
#       [TOKEN] id=019e567c… | raw[0:60]='Tháng 7, mùa thu. Vũ Thành vương tên là Doãn chạy sang đất n'
#               seg[0:60]='Tháng 7 , mùa thu . Vũ_Thành_vương tên là Doãn chạy sang đất'
#               ids[:8]=[0, 77833, 361, 6, 4, 45591, 4911, 6] | total_tokens=277
#       [TOKEN] id=019e567c… | raw[0:60]='Lời chua - Tư Minh: Tên phủ (?), thuộc phủ Thái Bình tỉnh Qu'
#               seg[0:60]='Lời chua - Tư_Minh : Tên phủ ( ? ) , thuộc phủ Thái_Bình tỉn'
#               ids[:8]=[0, 157214, 116284, 20, 35191, 454, 59076, 127] | total_tokens=381
#       [TOKEN] id=019e567c… | raw[0:60]='Tháng 9. Hạ mệnh lệnh cho Quốc Tuấn đem quân trấn ngự biên t'
#               seg[0:60]='Tháng 9 . Hạ_mệnh_lệnh cho Quốc_Tuấn đem quân trấn_ngự biên_'
#               ids[:8]=[0, 77833, 483, 6, 5, 69625, 454, 39] | total_tokens=278
#       [TOKEN] id=019e567c… | raw[0:60]='Tháng 12. Quân của Mông Cổ xâm phạm đến địa phận sông Thao,'
#               seg[0:60]='Tháng 12 . Quân của Mông_Cổ xâm_phạm đến địa_phận sông Thao'
#               ids[:8]=[0, 77833, 427, 6, 5, 101390, 550, 276] | total_tokens=277
#       [TOKEN] id=019e567c… | raw[0:60]='Lê Phụ Trần can rằng: "Nếu bây giờ bệ hạ làm như thế, thì c'
#               seg[0:60]='Lê_Phụ_Trần_can rằng : " Nếu bây_giờ bệ_hạ làm như_thế , thì'
#               ids[:8]=[0, 16389, 454, 45689, 25070, 454, 55487, 249994] | total_tokens=512
#       [TOKEN] id=019e567c… | raw[0:60]='Lời chua - Sông Thao: Xem Lý Nhân Tông, năm Hội Phong thứ 5'
#               seg[0:60]='Lời chua - Sông_Thao : Xem Lý_Nhân_Tông , năm Hội_Phong thứ'
#               ids[:8]=[0, 157214, 116284, 20, 159, 23366, 454, 78122] | total_tokens=279
#       [TOKEN] id=019e567c… | raw[0:60]='Nhà vua đánh tan được quân Mông Cổ ở Đông Bộ Đầu. Quân Mông'
#               seg[0:60]='Nhà_vua đánh_tan được quân Mông_Cổ ở Đông_Bộ Đầu . Quân_Mông'
#               ids[:8]=[0, 19491, 454, 1783, 11, 13868, 454, 1076] | total_tokens=298
#       [TOKEN] id=019e567c… | raw[0:60]='Lời cẩn án - Trận này thế giặc rất mạnh, thế mà Sử cũ chỉ ch'
#               seg[0:60]='Lời cẩn_án - Trận này thế giặc rất mạnh , thế_mà Sử cũ chỉ c'
#               ids[:8]=[0, 157214, 137756, 454, 1665, 20, 5454, 69421] | total_tokens=233
#       [TOKEN] id=019e567c… | raw[0:60]='người nào cũng bị những thanh tre bó chặt vào mình sát hẳn'
#               seg[0:60]='người nào cũng bị những thanh tre bó chặt vào mình sát hẳn đ'
#               ids[:8]=[0, 1008, 3941, 1943, 2504, 1358, 15402, 1360] | total_tokens=308
#       [TOKEN] id=019e567c… | raw[0:60]='Tha tội cho người tiểu hiệu là Hoàng Cự Đà.\nTrước kia, nhà v'
#               seg[0:60]='Tha_tội cho người tiểu_hiệu là Hoàng_Cự_Đà . Trước_kia , nhà'
#               ids[:8]=[0, 5971, 454, 18, 65166, 681, 1008, 41699] | total_tokens=442
#       [TOKEN] id=019e567c… | raw[0:60]='Lời phê [2] - Đây cũng chỉ là hiếu danh mà thôi, không được'
#               seg[0:60]='Lời phê - Đây cũng chỉ là hiếu_danh mà thôi , không được chí'
#               ids[:8]=[0, 157214, 57679, 20, 37540, 1943, 2524, 580] | total_tokens=92
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW    9/54 | pages=[210, 211, 212, 213] | chars=7,062
#       [STRUCT] 2 structural boundaries | book='Khâm Định Việt Sử Thông Giám Cương '
#     [MINI-CHUNK] window chars=7,062 → 61 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
# {"split_after_indices":[4,7,14,20,25,31,40,48,59]}
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=61 → splits=[4, 7, 14, 20, 25, 31, 40, 48, 53, 59]
# llm trả về
#  [4, 7, 14, 20, 25, 31, 40, 48, 53, 59]
#
#
#
#     [MERGE] 61 mini-chunks + 10 splits → 11 semantic groups
#       [TOKEN] id=019e567c… | raw[0:60]='Mậu Ngọ, năm thứ 8 (1258). (Từ tháng 3 trở về sau thuộc niên'
#               seg[0:60]='Mậu_Ngọ , năm thứ 8 ( 1258 ) . ( Từ tháng 3 trở về sau thuộc'
#               ids[:8]=[0, 276, 85284, 454, 69656, 19030, 6, 4] | total_tokens=419
#       [TOKEN] id=019e567c… | raw[0:60]='Sai sứ sang nhà Tống.\nNhà vua đã thu phục được kinh thành, t'
#               seg[0:60]='Sai sứ sang nhà_Tống . Nhà_vua đã thu_phục được kinh_thành ,'
#               ids[:8]=[0, 19319, 108327, 6079, 2455, 454, 618, 32379] | total_tokens=197
#       [TOKEN] id=019e567c… | raw[0:60]='Tháng 2. Nhà vua truyền ngôi cho Hoàng Thái tử là Hoảng. Sau'
#               seg[0:60]='Tháng 2 . Nhà_vua truyền_ngôi cho Hoàng_Thái_tử là Hoảng . S'
#               ids[:8]=[0, 77833, 116, 6, 5, 19491, 454, 1783] | total_tokens=409
#       [TOKEN] id=019e567c… | raw[0:60]='Lời phê - Phép truyền ngôi vua này của nhà Trần cũng hay, có'
#               seg[0:60]='Lời phê - Phép_truyền ngôi vua này của nhà_Trần cũng hay , c'
#               ids[:8]=[0, 157214, 57679, 20, 13000, 32185, 454, 9774] | total_tokens=386
#       [TOKEN] id=019e567c… | raw[0:60]='K h âm Đị nh V i ệ t S ử Th ông Gi ám C ươn g Mụ c Chính Biê'
#               seg[0:60]='K h âm_Đị nh V i ệ t S_ử Th ông Gi_ám_C ươn_g Mụ c Chính_Biê'
#               ids[:8]=[0, 341, 1096, 25589, 454, 13347, 51721, 12203] | total_tokens=317
#       [TOKEN] id=019e567c… | raw[0:60]='Canh Thân, năm thứ 3 (1260). (Tống, năm Cảnh Định thứ 1; Môn'
#               seg[0:60]='Canh_Thân , năm thứ 3 ( 1260 ) . ( Tống , năm Cảnh_Định thứ'
#               ids[:8]=[0, 4171, 127, 454, 618, 150388, 6, 4] | total_tokens=377
#       [TOKEN] id=019e567c… | raw[0:60]='Tháng 6, mùa hạ. Sứ thần nước Mông Cổ sang.\nTrước đây Hiến T'
#               seg[0:60]='Tháng 6 , mùa hạ . Sứ_thần nước Mông_Cổ sang . Trước_đây Hiế'
#               ids[:8]=[0, 77833, 305, 6, 4, 45591, 36771, 6] | total_tokens=425
#       [TOKEN] id=019e567c… | raw[0:60]='Khi bọn Mạnh Giáp đã đến nơi, nhà vua ban yến ở cung Thánh'
#               seg[0:60]='Khi bọn Mạnh_Giáp đã đến_nơi , nhà_vua ban yến ở cung_Thánh_'
#               ids[:8]=[0, 16584, 47772, 276, 109811, 454, 37735, 50731] | total_tokens=510
#       [TOKEN] id=019e567c… | raw[0:60]='Bổ dụng Chiêu Minh đại vương là Quang Khải làm Thái uý.\nNgườ'
#               seg[0:60]='Bổ_dụng Chiêu_Minh đại_vương là Quang_Khải làm Thái_úy . Ngư'
#               ids[:8]=[0, 335, 25091, 454, 71, 25070, 449, 3751] | total_tokens=232
#       [TOKEN] id=019e567c… | raw[0:60]='như thế thì người chức nhỏ làm giữ việc nặng, người chức lớ'
#               seg[0:60]='như thế thì người chức nhỏ làm giữ việc nặng , người chức lớ'
#               ids[:8]=[0, 1641, 3061, 2579, 1008, 7211, 14162, 1839] | total_tokens=340
#       [TOKEN] id=019e567c… | raw[0:60]='Nhâm Tuất, năm thứ 5 (1262). (Tống, năm Cảnh Định thứ 3; Môn'
#               seg[0:60]='Nhâm Tuất , năm thứ 5 ( 1262 ) . ( Tống , năm Cảnh_Định thứ'
#               ids[:8]=[0, 33101, 27253, 1371, 249999, 18, 6, 4] | total_tokens=48
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW   10/54 | pages=[213, 214, 215, 216] | chars=7,472
#       [STRUCT] 2 structural boundaries | book='Khâm Định Việt Sử Thông Giám Cương '
#     [MINI-CHUNK] window chars=7,472 → 68 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
# {"split_after_indices":[5,8,12,14,21,29,32,35,38,44,47,54,57,63]}
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=68 → splits=[5, 8, 12, 14, 21, 29, 32, 35, 38, 44, 47, 54, 57, 63]
# llm trả về
#  [5, 8, 12, 14, 21, 29, 32, 35, 38, 44, 47, 54, 57, 63]
#
#
#
#     [MERGE] 68 mini-chunks + 14 splits → 15 semantic groups
#       [TOKEN] id=019e567c… | raw[0:60]='Tháng 2, mùa xuân. Đem làng Tức Mặc thăng lên làm phủ Thiên'
#               seg[0:60]='Tháng 2 , mùa xuân . Đem làng Tức_Mặc_thăng lên làm phủ Thiê'
#               ids[:8]=[0, 77833, 116, 6, 4, 45591, 173887, 6] | total_tokens=394
#       [TOKEN] id=019e567c… | raw[0:60]='Lời chua - Tức Mặc: Xem Trần Thái Tông, năm Kiến Trung thứ 2'
#               seg[0:60]='Lời chua - Tức_Mặc : Xem Trần_Thái_Tông , năm Kiến_Trung thứ'
#               ids[:8]=[0, 157214, 116284, 20, 384, 48021, 454, 594] | total_tokens=299
#       [TOKEN] id=019e567c… | raw[0:60]='Tháng 6, mùa hạ. Sứ thần nhà Tống sang.\nNhà Tống thấy nhà vu'
#               seg[0:60]='Tháng 6 , mùa hạ . Sứ_thần nhà Tống_sang . Nhà_Tống thấy nhà'
#               ids[:8]=[0, 77833, 305, 6, 4, 45591, 36771, 6] | total_tokens=282
#       [TOKEN] id=019e567c… | raw[0:60]='Quý Hợi, năm thứ 6 (1263). (Tống, năm Cảnh Định thứ 4; Mông'
#               seg[0:60]='Quý_Hợi , năm thứ 6 ( 1263 ) . ( Tống , năm Cảnh_Định thứ 4'
#               ids[:8]=[0, 78309, 454, 841, 30599, 14, 6, 4] | total_tokens=207
#       [TOKEN] id=019e567c… | raw[0:60]='Giáp Tí, năm thứ 7 (1264). (Tống, năm Cảnh Định thứ 5; Mông'
#               seg[0:60]='Giáp_Tí , năm thứ 7 ( 1264 ) . ( Tống , năm Cảnh_Định thứ 5'
#               ids[:8]=[0, 42906, 254, 454, 618, 430, 6, 4] | total_tokens=357
#       [TOKEN] id=019e567c… | raw[0:60]='Thái Tông thường có ý muốn cho anh ruột Thủ Độ là An Quốc là'
#               seg[0:60]='Thái Tông_thường có ý_muốn cho anh ruột Thủ_Độ là An_Quốc là'
#               ids[:8]=[0, 37347, 384, 23366, 454, 927, 57078, 524] | total_tokens=459
#       [TOKEN] id=019e567c… | raw[0:60]='Tháng 3. Bổ dụng Khâm Thiên đại vương là Nhật Hiệu làm Tướng'
#               seg[0:60]='Tháng 3 . Bổ_dụng Khâm_Thiên_đại_vương là Nhật_Hiệu làm Tướn'
#               ids[:8]=[0, 77833, 138, 6, 5, 335, 25091, 454] | total_tokens=236
#       [TOKEN] id=019e567c… | raw[0:60]='Lời chua - Việc viết chữ vào mạn thuyền: Xem Trần Thái Tông,'
#               seg[0:60]='Lời chua - Việc viết chữ vào mạn thuyền : Xem Trần_Thái_Tông'
#               ids[:8]=[0, 157214, 116284, 20, 57253, 11545, 50735, 2249] | total_tokens=308
#       [TOKEN] id=019e567c… | raw[0:60]='Tháng 10 năm ấy, vua nhà Tống mất.\nLời phê - Câu nói này cũ'
#               seg[0:60]='Tháng 10 năm ấy , vua nhà Tống_mất . Lời_phê - Câu nói này c'
#               ids[:8]=[0, 77833, 209, 2933, 14112, 6, 4, 86729] | total_tokens=189
#       [TOKEN] id=019e567c… | raw[0:60]='Tháng 2, mùa xuân. Nước Chiêm Thành sai sứ thần sang cống.\nN'
#               seg[0:60]='Tháng 2 , mùa xuân . Nước Chiêm_Thành sai sứ_thần sang cống'
#               ids[:8]=[0, 77833, 116, 6, 4, 45591, 173887, 6] | total_tokens=376
#       [TOKEN] id=019e567c… | raw[0:60]='Cách đề bạt như thế, là có ý coi trọng chức quan đứng đầu đ'
#               seg[0:60]='Cách đề_bạt như_thế , là có ý coi_trọng chức_quan đứng đầu đ'
#               ids[:8]=[0, 40014, 6248, 454, 275, 63409, 1641, 454] | total_tokens=213
#       [TOKEN] id=019e567c… | raw[0:60]='Bính Dần, năm thứ 9 (1266). (Tống, năm Hàm Thuần thứ 2; Mông'
#               seg[0:60]='Bính Dần , năm thứ 9 ( 1266 ) . ( Tống , năm Hàm_Thuần thứ 2'
#               ids[:8]=[0, 34023, 6457, 391, 249994, 19, 6, 4] | total_tokens=439
#       [TOKEN] id=019e567c… | raw[0:60]='Tháng 10, mùa đông. Hạ chiếu cho vương hầu được phép đặt điề'
#               seg[0:60]='Tháng 10 , mùa đông . Hạ_chiếu cho vương_hầu được phép đặt đ'
#               ids[:8]=[0, 77833, 209, 6, 4, 45591, 37127, 6] | total_tokens=218
#       [TOKEN] id=019e567c… | raw[0:60]='Tháng 3, mùa xuân. Định thể lệ phong ấm cho những người tron'
#               seg[0:60]='Tháng 3 , mùa xuân . Định_thể_lệ phong_ấm cho những người tr'
#               ids[:8]=[0, 77833, 138, 6, 4, 45591, 173887, 6] | total_tokens=414
#       [TOKEN] id=019e567c… | raw[0:60]='Tháng 4, mùa hạ. Kén chọn học trò lấy người nào có tài năng'
#               seg[0:60]='Tháng 4 , mùa hạ . Kén chọn học_trò lấy người nào có tài_năn'
#               ids[:8]=[0, 77833, 201, 6, 4, 45591, 36771, 6] | total_tokens=157
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW   11/54 | pages=[216, 217, 218, 219] | chars=7,938
#       [STRUCT] 2 structural boundaries | book='Khâm Định Việt Sử Thông Giám Cương '
#     [MINI-CHUNK] window chars=7,938 → 67 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
# {"split_after_indices":[4,9,16,23,36,46,51,57,62]}
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=67 → splits=[4, 9, 16, 23, 28, 36, 41, 46, 51, 57, 62]
# llm trả về
#  [4, 9, 16, 23, 28, 36, 41, 46, 51, 57, 62]
#
#
#
#     [MERGE] 67 mini-chunks + 11 splits → 12 semantic groups
#       [TOKEN] id=019e567c… | raw[0:60]='Tháng 5. Phong cho em là Ích Tắc tước Chiêu Quốc vương.\nÍch'
#               seg[0:60]='Tháng 5 . Phong cho em là Ích Tắc_tước Chiêu_Quốc_vương . Íc'
#               ids[:8]=[0, 77833, 190, 6, 5, 55110, 681, 352] | total_tokens=249
#       [TOKEN] id=019e567c… | raw[0:60]='Lời chua - Đĩnh Chi: Người ở Chí Linh thuộc Hải Dương.Bùi Ph'
#               seg[0:60]='Lời chua - Đĩnh_Chi : Người ở Chí_Linh thuộc Hải_Dương . Bùi'
#               ids[:8]=[0, 157214, 116284, 20, 4428, 32606, 6457, 454] | total_tokens=311
#       [TOKEN] id=019e567c… | raw[0:60]='Mậu Thìn, năm thứ 11 (1268). (Tống, năm Hàm Thuần thứ 4; Môn'
#               seg[0:60]='Mậu_Thìn , năm thứ 11 ( 1268 ) . ( Tống , năm Hàm_Thuần thứ'
#               ids[:8]=[0, 276, 85284, 454, 618, 64269, 19, 6] | total_tokens=371
#       [TOKEN] id=019e567c… | raw[0:60]='Đến nay nhà vua hạ chiếu cho tước vương, tước hầu trong họ'
#               seg[0:60]='Đến nay nhà_vua hạ_chiếu cho tước_vương , tước_hầu trong họ'
#               ids[:8]=[0, 93433, 7630, 2455, 454, 1783, 11, 36771] | total_tokens=425
#       [TOKEN] id=019e567c… | raw[0:60]='Tháng 6, mùa hạ. Đại hạn.\nTháng 7, mùa thu. Nước to.\nTướng q'
#               seg[0:60]='Tháng 6 , mùa hạ . Đại_hạn . Tháng 7 , mùa thu . Nước to . T'
#               ids[:8]=[0, 77833, 305, 6, 4, 45591, 36771, 6] | total_tokens=285
#       [TOKEN] id=019e567c… | raw[0:60]='Sau việc này, vua Mông Cổ sai trung thư gửi công điệp sang'
#               seg[0:60]='Sau việc này , vua Mông_Cổ sai trung_thư gửi công_điệp sang'
#               ids[:8]=[0, 6987, 2735, 1617, 6, 4, 86729, 276] | total_tokens=454
#       [TOKEN] id=019e567c… | raw[0:60]='Kỷ Tị, năm thứ 12 (1269). (Tống, năm Hàm Thuần thứ 5; Mông C'
#               seg[0:60]='Kỷ_Tị , năm thứ 12 ( 1269 ) . ( Tống , năm Hàm_Thuần thứ 5 ;'
#               ids[:8]=[0, 341, 60479, 454, 618, 51721, 6, 4] | total_tokens=276
#       [TOKEN] id=019e567c… | raw[0:60]='Quốc Khang nói: "Quý nhất là ngôi hoàng đế, tôi đã không tr'
#               seg[0:60]='Quốc_Khang nói : " Quý nhất là ngôi hoàng_đế , tôi đã không'
#               ids[:8]=[0, 8735, 454, 605, 8467, 2872, 152, 44] | total_tokens=282
#       [TOKEN] id=019e567c… | raw[0:60]='Canh Ngọ, năm thứ 13 (1270). (Tống, năm Hàm Thuần thứ 6; Môn'
#               seg[0:60]='Canh_Ngọ , năm thứ 13 ( 1270 ) . ( Tống , năm Hàm_Thuần thứ'
#               ids[:8]=[0, 4171, 127, 454, 69656, 19030, 6, 4] | total_tokens=361
#       [TOKEN] id=019e567c… | raw[0:60]='Nhâm Thân, năm thứ 15 (1272). (Tống, năm Hàm Thuần thứ 8; Ng'
#               seg[0:60]='Nhâm_Thân , năm thứ 15 ( 1272 ) . ( Tống , năm Hàm_Thuần thứ'
#               ids[:8]=[0, 33101, 27253, 454, 618, 150388, 6, 4] | total_tokens=381
#       [TOKEN] id=019e567c… | raw[0:60]='Khi bấy giờ nhà Tống giữ được một xó đất ở Lâm An, thường b'
#               seg[0:60]='Khi bấy_giờ nhà Tống_giữ được một xó đất ở Lâm_An , thường b'
#               ids[:8]=[0, 16584, 876, 249999, 53, 454, 735, 58677] | total_tokens=323
#       [TOKEN] id=019e567c… | raw[0:60]='Quý Dậu, năm Bảo Phù thứ 1 (1273). (Tống, năm Hàm Thuần thứ'
#               seg[0:60]='Quý_Dậu , năm Bảo Phù_thứ 1 ( 1273 ) . ( Tống , năm Hàm_Thuầ'
# ...
#               seg[0:60]='Trương_Phụ và Mộc_Thạnh dẫn_quân về nước , để viên giữ_ti Đô'
#               ids[:8]=[0, 181005, 454, 45689, 25070, 544, 276, 81373] | total_tokens=213
#       [TOKEN] id=019e5680… | raw[0:60]='Tháng 10, mùa đông. Giản Định vương nhà Trần là Ngỗi khởi bi'
#               seg[0:60]='Tháng 10 , mùa đông . Giản_Định vương nhà Trần_là Ngỗi khởi_'
#               ids[:8]=[0, 77833, 209, 6, 4, 45591, 37127, 6] | total_tokens=481
#       [TOKEN] id=019e5680… | raw[0:60]='Lời chua - Bến Yên Mô: Nay ở xã Yên Mô, huyện Yên Mô, tỉnh N'
#               seg[0:60]='Lời chua - Bến_Yên_Mô : Nay ở xã Yên_Mô , huyện Yên_Mô , tỉn'
#               ids[:8]=[0, 157214, 116284, 20, 335, 26532, 454, 1723] | total_tokens=258
#       [TOKEN] id=019e5680… | raw[0:60]='Trước đây, Bùi Bá Kỳ, tì tướng Trần Khát Chân, tự xưng là "N'
#               seg[0:60]='Trước_đây , Bùi_Bá_Kỳ , tì_tướng Trần_Khát_Chân , tự_xưng là'
#               ids[:8]=[0, 69388, 454, 18643, 38746, 6, 4, 335] | total_tokens=250
#       [TOKEN] id=019e5680… | raw[0:60]='giằn giọc lo lắng hàng mấy năm, nay mới được trông thấy mặt'
#               seg[0:60]='giằn giọc lo_lắng hàng mấy năm , nay mới được trông thấy mặt'
#               ids[:8]=[0, 3016, 207721, 19, 3016, 53459, 459, 454] | total_tokens=348
#       [TOKEN] id=019e5680… | raw[0:60]='Đến lúc nhà Minh đưa Thiêm Bình về nước ta, hỏi nên dùng ba'
#               seg[0:60]='Đến lúc nhà_Minh đưa Thiêm_Bình về nước ta , hỏi nên dùng ba'
#               ids[:8]=[0, 93433, 10305, 2455, 454, 59076, 127, 15995] | total_tokens=451
#       [TOKEN] id=019e5680… | raw[0:60]='Tháng 12. Đế Ngỗi sai bọn Trần Nguyên Tôn thu thập quân lính'
#               seg[0:60]='Tháng 12 . Đế Ngỗi sai bọn Trần_Nguyên_Tôn thu_thập quân_lín'
#               ids[:8]=[0, 77833, 427, 6, 5, 4428, 54073, 9487] | total_tokens=394
#       [TOKEN] id=019e5680… | raw[0:60]='Mậu Tí (1408). (Trần, năm Hưng Khánh thứ 2; Minh, năm Vĩnh L'
#               seg[0:60]='Mậu_Tí ( 1408 ) . ( Trần , năm Hưng_Khánh thứ 2 ; Minh , năm'
#               ids[:8]=[0, 276, 85284, 454, 618, 430, 15, 616] | total_tokens=428
#       [TOKEN] id=019e5680… | raw[0:60]='Tháng 6, mùa hạ. Đặng Tất nhà Trần đánh tan được quân Phạm T'
#               seg[0:60]='Tháng 6 , mùa hạ . Đặng_Tất_nhà Trần_đánh_tan được quân Phạm'
#               ids[:8]=[0, 77833, 305, 6, 4, 45591, 36771, 6] | total_tokens=266
#       [TOKEN] id=019e5680… | raw[0:60]='Lời chua - Cửa biển Nhật Lệ: Xem Trần Duệ Tông, năm Long Khá'
#               seg[0:60]='Lời chua - Cửa_biển Nhật_Lệ : Xem Trần_Duệ_Tông , năm Long_K'
#               ids[:8]=[0, 157214, 116284, 20, 199152, 454, 275, 206654] | total_tokens=275
#       [TOKEN] id=019e5680… | raw[0:60]='Lòng người phấn khởi, thế quân mạnh thêm.\nTrước đây, lúc Đế'
#               seg[0:60]='Lòng người phấn_khởi , thế_quân mạnh thêm . Trước_đây , lúc'
#               ids[:8]=[0, 339, 92827, 1008, 156753, 454, 10684, 26332] | total_tokens=399
#       [TOKEN] id=019e5680… | raw[0:60]='thì thế nào cũng phá được". Đặng Tất nói: "Hãy bắt hết bọn'
#               seg[0:60]='thì thế_nào cũng phá được " . Đặng_Tất nói : " Hãy bắt hết b'
#               ids[:8]=[0, 2579, 3061, 454, 19, 1298, 31, 1943] | total_tokens=408
#       [TOKEN] id=019e5680… | raw[0:60]='Kỷ Sửu (1409). (Trần, năm Hưng Khánh thứ 3. Từ tháng 3 trở v'
#               seg[0:60]='Kỷ_Sửu ( 1409 ) . ( Trần , năm Hưng_Khánh thứ 3 . Từ tháng 3'
#               ids[:8]=[0, 341, 60479, 454, 294, 46535, 34, 15] | total_tokens=398
#       [TOKEN] id=019e5680… | raw[0:60]='Lời phê - Đương lúc điên bái lưu ly, vua tôi cùng lòng cùng'
#               seg[0:60]='Lời phê - Đương_lúc điên_bái lưu_ly , vua tôi cùng lòng cùng'
#               ids[:8]=[0, 157214, 57679, 20, 4428, 43672, 454, 12646] | total_tokens=120
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW   52/54 | pages=[342, 343, 344, 345] | chars=9,584
#       [STRUCT] 2 structural boundaries | book='Khâm Định Việt Sử Thông Giám Cương '
#     [MINI-CHUNK] window chars=9,584 → 85 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
# {"split_after_indices":[10,12,19,33,43,54,63,80]}
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=85 → splits=[4, 10, 12, 19, 24, 33, 38, 43, 48, 54, 63, 68, 80]
# llm trả về
#  [4, 10, 12, 19, 24, 33, 38, 43, 48, 54, 63, 68, 80]
#
#
#
#     [MERGE] 85 mini-chunks + 13 splits → 14 semantic groups
#       [TOKEN] id=019e5680… | raw[0:60]='Tháng 3. Bọn Nguyễn Cảnh Dị và Đặng Nhu rước Trần Quý Khoáng'
#               seg[0:60]='Tháng 3 . Bọn Nguyễn_Cảnh_Dị và Đặng_Nhu_rước Trần_Quý_Khoán'
#               ids[:8]=[0, 77833, 138, 6, 5, 335, 19030, 19] | total_tokens=288
#       [TOKEN] id=019e5680… | raw[0:60]='Nguyễn Chương làm Tư mã.Bấy giờ Đế Ngỗi ở thành Ngự Thiên,'
#               seg[0:60]='Nguyễn_Chương làm Tư_mã . Bấy_giờ Đế_Ngỗi ở thành Ngự_Thiên'
#               ids[:8]=[0, 19098, 454, 15982, 43672, 1839, 35191, 454] | total_tokens=367
#       [TOKEN] id=019e5680… | raw[0:60]='Lời chua - Ngự Thiên: Tên huyện, tức làng Đa Cương xưa, mộ t'
#               seg[0:60]='Lời chua - Ngự_Thiên : Tên huyện , tức làng Đa_Cương xưa , m'
#               ids[:8]=[0, 157214, 116284, 20, 9487, 52449, 454, 117177] | total_tokens=142
#       [TOKEN] id=019e5680… | raw[0:60]='Tháng 7, mùa thu. Quân nhà Minh đến Mỹ Lương, bắt được Đế Ng'
#               seg[0:60]='Tháng 7 , mùa thu . Quân nhà_Minh đến Mỹ_Lương , bắt được Đế'
#               ids[:8]=[0, 77833, 361, 6, 4, 45591, 4911, 6] | total_tokens=401
#       [TOKEN] id=019e5680… | raw[0:60]='Tháng 8. Quân nhà Minh tiến đánh cửa Hàm Tử, Đế Quý Khoáng n'
#               seg[0:60]='Tháng 8 . Quân nhà_Minh_tiến đánh cửa Hàm_Tử , Đế_Quý_Khoáng'
#               ids[:8]=[0, 77833, 382, 6, 5, 101390, 2455, 454] | total_tokens=259
#       [TOKEN] id=019e5680… | raw[0:60]='Trương Phụ thắng trận, đi đến đâu chém giết thả cửa, hoặc x'
#               seg[0:60]='Trương_Phụ_thắng trận , đi đến đâu_chém giết thả cửa , hoặc'
#               ids[:8]=[0, 181005, 454, 45689, 25070, 454, 927, 249990] | total_tokens=512
#       [TOKEN] id=019e5680… | raw[0:60]='Tháng giêng, mùa xuân. Trương Phụ nhà Minh đặt đồn điền.\nTrư'
#               seg[0:60]='Tháng giêng , mùa xuân . Trương_Phụ nhà Minh_đặt đồn_điền .'
#               ids[:8]=[0, 77833, 3016, 28498, 6, 4, 45591, 173887] | total_tokens=236
#       [TOKEN] id=019e5680… | raw[0:60]='Đế Quý Khoáng đem bọn Nguyễn Cảnh Dị lại tiến quân đến Hồng'
#               seg[0:60]='Đế Quý_Khoáng đem bọn Nguyễn_Cảnh_Dị lại tiến_quân đến Hồng_'
#               ids[:8]=[0, 4428, 54073, 78309, 454, 605, 497, 67392] | total_tokens=316
#       [TOKEN] id=019e5680… | raw[0:60]='Đế Quý Khoáng lại dẫn quân về Nghệ An.\nTân Mão (1411). (Trầ'
#               seg[0:60]='Đế Quý_Khoáng lại dẫn_quân về Nghệ_An . Tân_Mão ( 1411 ) . ('
#               ids[:8]=[0, 4428, 54073, 78309, 454, 605, 497, 67392] | total_tokens=267
#       [TOKEN] id=019e5680… | raw[0:60]='Những người ấy một lúc đi theo giặc, trẫm nghe tin chúng ph'
#               seg[0:60]='Những người ấy một lúc đi theo giặc , trẫm nghe tin chúng ph'
#               ids[:8]=[0, 13836, 1008, 14112, 889, 10305, 2467, 3790] | total_tokens=338
#       [TOKEN] id=019e5680… | raw[0:60]='mà lại còn được quan tước hiển vinh là khác nữa".\nTháng 9,'
#               seg[0:60]='mà_lại còn được quan_tước hiển_vinh là khác nữa " . Tháng 9'
#               ids[:8]=[0, 2232, 454, 141, 12976, 14, 3531, 912] | total_tokens=512
#       [TOKEN] id=019e5680… | raw[0:60]='Lời phê [1] - Sự thể đã đến như thế, mà còn thỉnh cầu càn dỡ'
#               seg[0:60]='Lời phê - Sự_thể đã đến như_thế , mà_còn thỉnh_cầu càn_dỡ mã'
#               ids[:8]=[0, 157214, 57679, 20, 49161, 454, 927, 35895] | total_tokens=280
#       [TOKEN] id=019e5680… | raw[0:60]='Đầu niên hiệu Hưng Khánh [4], Cảnh Tuân dâng cho tham nghị'
#               seg[0:60]='Đầu niên_hiệu Hưng_Khánh , Cảnh Tuân_dâng cho tham_nghị Bùi_'
#               ids[:8]=[0, 79592, 55113, 454, 127, 100345, 129801, 454] | total_tokens=512
#       [TOKEN] id=019e5680… | raw[0:60]='sau hai cha con đều bị bệnh chết.\nNhâm Thìn (1412), (Trần,'
#               seg[0:60]='sau hai cha_con đều bị bệnh chết . Nhâm_Thìn ( 1412 ) , ( Tr'
#               ids[:8]=[0, 858, 1337, 1608, 454, 2271, 9338, 2504] | total_tokens=189
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW   53/54 | pages=[345, 346, 347, 348] | chars=9,187
#       [STRUCT] 2 structural boundaries | book='Khâm Định Việt Sử Thông Giám Cương '
#     [MINI-CHUNK] window chars=9,187 → 82 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
# {"split_after_indices":[2,16,25,33,42,51,61,65,73]}
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=82 → splits=[2, 7, 16, 25, 33, 42, 51, 56, 61, 65, 73]
# llm trả về
#  [2, 7, 16, 25, 33, 42, 51, 56, 61, 65, 73]
#
#
#
#     [MERGE] 82 mini-chunks + 11 splits → 12 semantic groups
#       [TOKEN] id=019e5680… | raw[0:60]='Tháng 7, mùa thu. Nhà Minh sai Hàn Quan sang trấn thủ.\nVua n'
#               seg[0:60]='Tháng 7 , mùa thu . Nhà_Minh sai Hàn_Quan sang trấn_thủ . Vu'
#               ids[:8]=[0, 77833, 361, 6, 4, 45591, 4911, 6] | total_tokens=157
#       [TOKEN] id=019e5680… | raw[0:60]='Đại lược tờ chiếu nói: "Trẫm vâng mệnh trời, thống trị thiên'
#               seg[0:60]='Đại_lược tờ chiếu nói : " Trẫm_vâng mệnh_trời , thống_trị th'
#               ids[:8]=[0, 18832, 454, 141, 95449, 90641, 80062, 2872] | total_tokens=287
#       [TOKEN] id=019e5680… | raw[0:60]='Nay các ngươi đều là bầy tôi trung lương, cần phải thể theo'
#               seg[0:60]='Nay các ngươi đều là bầy tôi trung_lương , cần phải thể theo'
#               ids[:8]=[0, 353, 53, 925, 22625, 9338, 580, 876] | total_tokens=488
#       [TOKEN] id=019e5680… | raw[0:60]='Quý Tị (1413). (Trần, năm Trùng Quang thứ 5; Minh, năm Vĩnh'
#               seg[0:60]='Quý_Tị ( 1413 ) . ( Trần , năm Trùng_Quang thứ 5 ; Minh , nă'
#               ids[:8]=[0, 78309, 454, 618, 51721, 15, 616, 2681] | total_tokens=445
#       [TOKEN] id=019e5680… | raw[0:60]='Lời chua - Nguyễn Biểu: Người ở Bình Hồ, La Sơn, Nghệ An.\nTh'
#               seg[0:60]='Lời chua - Nguyễn_Biểu : Người ở Bình_Hồ , La_Sơn , Nghệ_An'
#               ids[:8]=[0, 157214, 116284, 20, 19098, 454, 16882, 35895] | total_tokens=413
#       [TOKEN] id=019e5680… | raw[0:60]='Tháng 9, mùa thu. Đặng Dung, quan Bình Chương nhà Trần, đánh'
#               seg[0:60]='Tháng 9 , mùa thu . Đặng_Dung , quan_Bình_Chương nhà Trần ,'
#               ids[:8]=[0, 77833, 483, 6, 4, 45591, 4911, 6] | total_tokens=434
#       [TOKEN] id=019e5680… | raw[0:60]='Tháng 12, mùa đông. Đế Quý Khoáng cùng các tướng Đặng Dung,'
#               seg[0:60]='Tháng 12 , mùa đông . Đế Quý_Khoáng cùng các tướng Đặng_Dung'
#               ids[:8]=[0, 77833, 427, 6, 4, 45591, 37127, 6] | total_tokens=512
#       [TOKEN] id=019e5680… | raw[0:60]='Giáp Ngọ (1414). (Minh, năm Vĩnh Lạc thứ 12).\nTháng giêng, m'
#               seg[0:60]='Giáp_Ngọ ( 1414 ) . ( Minh , năm Vĩnh_Lạc thứ 12 ) . Tháng_g'
#               ids[:8]=[0, 42906, 254, 454, 69656, 19030, 15, 616] | total_tokens=301
#       [TOKEN] id=019e5680… | raw[0:60]='Trương Phụ đã bắt được Đế Quý Khoáng và Dung, Súy, bèn dẫn q'
#               seg[0:60]='Trương_Phụ đã bắt được Đế Quý_Khoáng và Dung , Súy , bèn dẫn'
#               ids[:8]=[0, 181005, 454, 45689, 25070, 1408, 13363, 912] | total_tokens=374
#       [TOKEN] id=019e5680… | raw[0:60]='Tháng 8, mùa thu. Trương Phụ nhà Minh về nước.\nPhụ chia quân'
#               seg[0:60]='Tháng 8 , mùa thu . Trương_Phụ nhà_Minh về nước . Phụ chia q'
#               ids[:8]=[0, 77833, 382, 6, 4, 45591, 4911, 6] | total_tokens=202
#       [TOKEN] id=019e5680… | raw[0:60]='Tháng 9. Nhà Minh lập Văn Miếu và đàn thờ bạch thần.\nHoàng P'
#               seg[0:60]='Tháng 9 . Nhà_Minh lập_Văn_Miếu và đàn thờ bạch_thần . Hoàng'
#               ids[:8]=[0, 77833, 483, 6, 5, 19491, 454, 59076] | total_tokens=424
#       [TOKEN] id=019e5680… | raw[0:60]='Ất Mùi (1415). (Minh, năm Vĩnh Lạc thứ 13).\nTháng 4, mùa hạ.'
#               seg[0:60]='Ất_Mùi ( 1415 ) . ( Minh , năm Vĩnh_Lạc thứ 13 ) . Tháng 4 ,'
#               ids[:8]=[0, 6, 249975, 18, 454, 594, 65934, 15] | total_tokens=390
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW   54/54 | pages=[348, 349, 350, 351] | chars=5,716
#       [STRUCT] 2 structural boundaries | book='Khâm Định Việt Sử Thông Giám Cương '
#     [MINI-CHUNK] window chars=5,716 → 50 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
# {"split_after_indices":[4,7,11,15,26,32,38,43,48]}
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=50 → splits=[4, 7, 11, 15, 20, 26, 32, 38, 43, 48]
# llm trả về
#  [4, 7, 11, 15, 20, 26, 32, 38, 43, 48]
#
#
#
#     [MERGE] 50 mini-chunks + 10 splits → 11 semantic groups
#       [TOKEN] id=019e5680… | raw[0:60]='Tháng 8, mùa thu. Nhà Minh mở trường thu vàng bạc.Phàm chỗ đ'
#               seg[0:60]='Tháng 8 , mùa thu . Nhà_Minh mở trường thu vàng_bạc . Phàm c'
#               ids[:8]=[0, 77833, 382, 6, 4, 45591, 4911, 6] | total_tokens=268
#       [TOKEN] id=019e5680… | raw[0:60]='Lời phê - Cái tệ khai mỏ, có phải đến mạt thế mới có đâu? Gâ'
#               seg[0:60]='Lời phê - Cái_tệ khai_mỏ , có phải đến mạt_thế mới có đâu ?'
#               ids[:8]=[0, 157214, 57679, 20, 109966, 454, 18, 21018] | total_tokens=212
#       [TOKEN] id=019e5680… | raw[0:60]='Các phủ, huyện và châu đều đặt quan giữ công việc ti Thuế k'
#               seg[0:60]='Các phủ , huyện và châu đều đặt quan_giữ công_việc ti Thuế_k'
#               ids[:8]=[0, 9211, 29798, 6, 4, 62633, 544, 67312] | total_tokens=267
#       [TOKEN] id=019e5680… | raw[0:60]='Lời chua - Vạn Ninh: Xem Trần Thuận Tông, năm Quang Thái thứ'
#               seg[0:60]='Lời chua - Vạn_Ninh : Xem Trần_Thuận_Tông , năm Quang_Thái t'
#               ids[:8]=[0, 157214, 116284, 20, 310, 12976, 19, 454] | total_tokens=336
#       [TOKEN] id=019e5680… | raw[0:60]='Tháng giêng. Mùa xuân. Nhà Minh bổ Nguyễn Huân làm bố chính'
#               seg[0:60]='Tháng_giêng . Mùa xuân . Nhà_Minh_bổ Nguyễn_Huân làm bố chín'
#               ids[:8]=[0, 77833, 454, 735, 28498, 6, 5, 220174] | total_tokens=269
#       [TOKEN] id=019e5680… | raw[0:60]='"Trước kia, lúc bình định được Giao Chỉ, chúng bay đã hết l'
#               seg[0:60]='" Trước_kia , lúc bình_định được Giao_Chỉ , chúng bay đã hết'
#               ids[:8]=[0, 44, 69388, 454, 15565, 6, 4, 10305] | total_tokens=289
#       [TOKEN] id=019e5680… | raw[0:60]='Lời phê [1] - Mất hết lương tâm, nay một lũ người Nam Kỳ cũn'
#               seg[0:60]='Lời phê - Mất hết lương_tâm , nay một lũ người Nam_Kỳ cũng g'
#               ids[:8]=[0, 157214, 57679, 20, 276, 249999, 18, 14445] | total_tokens=379
#       [TOKEN] id=019e5680… | raw[0:60]='Tháng 2, mùa xuân. Nhà Minh triệu trấn thủ Trương Phụ về nướ'
#               seg[0:60]='Tháng 2 , mùa xuân . Nhà_Minh triệu trấn_thủ Trương_Phụ về n'
#               ids[:8]=[0, 77833, 116, 6, 4, 45591, 173887, 6] | total_tokens=363
#       [TOKEN] id=019e5680… | raw[0:60]='Nhà Minh định thể lệ hằng năm cống nộp sinh viên.\nTrước đây,'
#               seg[0:60]='Nhà Minh_định_thể_lệ hằng năm cống nộp sinh_viên . Trước_đây'
#               ids[:8]=[0, 19491, 13985, 454, 18643, 147809, 454, 927] | total_tokens=230
#       [TOKEN] id=019e5680… | raw[0:60]='Nhà Minh xét quan lại bằng cách sát hạch công việc đã làm.\nN'
#               seg[0:60]='Nhà_Minh_xét quan_lại bằng cách sát_hạch công_việc đã làm .'
#               ids[:8]=[0, 19491, 454, 59076, 127, 454, 425, 2305] | total_tokens=291
#       [TOKEN] id=019e5680… | raw[0:60]='Nhà Minh chiếm cứ nước ta từ Giáp Ngọ (1414), Thành Tổ, năm'
#               seg[0:60]='Nhà_Minh chiếm cứ nước ta từ Giáp_Ngọ ( 1414 ) , Thành_Tổ ,'
#               ids[:8]=[0, 19491, 454, 59076, 127, 89370, 17363, 3042] | total_tokens=68
#
# [SAVE] Writing 709 points → 'full_KhamDinh_data_qdrant_points_512.json'…
# [SAVE] Done. 2228.6 KB written.

# %% [markdown]
# # Run Việt Sử Toàn Thư

# %%
# @title

import os
from google.colab import userdata


# JSON_PATH = "full_DVSK_data.json"           # Đại Việt Sử Ký Toàn Thư
# JSON_PATH = "full_KhamDinh_data.json"        # Khâm Định Việt Sử Thông Giám Cương Mục
JSON_PATH = "full_VietSu_data.json"                 # Việt Sử Toàn Thư
# JSON_PATH = "full_VTT_data.json"                  # Vương Triều Trần
# JSON_PATH = "full_test.json"
# JSON_PATH = "full_test_VTT.json"


OUTPUT_PATH = JSON_PATH.replace(".json", f"_qdrant_points_{CHUNK_CONTEXT_LENGTH}.json")


def _load_key(colab_secret: str, env_var: str) -> str:
    try:
        from google.colab import userdata as _ud
        val = _ud.get(colab_secret)
        if val:
            print(f"[KEY] '{colab_secret}' loaded from Colab Secrets.")
            return val
    except Exception:
        pass
    val = os.environ.get(env_var, "")
    if val:
        print(f"[KEY] '{env_var}' loaded from environment variable.")
    return val

GROQ_API_KEY   = _load_key("grok_key",  "grok_key")
GEMINI_API_KEY = _load_key("GEMINI_API_KEY", "GEMINI_API_KEY")

if not GROQ_API_KEY and not GEMINI_API_KEY:
    print("[KEY] ⚠  No API keys found. "
          "Add GROQ_API_KEY and/or GOOGLE_API_KEY to Colab Secrets.")


LLM_BACKENDS:       list[LLMBackend]                  = []

# if GROQ_API_KEY:
#     LLM_BACKENDS.append(GroqBackend(GROQ_API_KEY, GROQ_MODEL_LLAMA_70B))
#     LLM_BACKENDS.append(GroqBackend(GROQ_API_KEY, GROQ_MODEL_LLAMA_8B))
#     LLM_BACKENDS.append(GroqBackend(GROQ_API_KEY, GROQ_MODEL_QWEN))

if GEMINI_API_KEY:
    try:
        LLM_BACKENDS.append(GeminiBackend(GEMINI_API_KEY, GEMINI_MODEL_ID))
        print(f"[INIT] GeminiBackend added: {GEMINI_MODEL_ID}")
    except Exception as exc:
        print(f"[INIT] GeminiBackend skipped ({type(exc).__name__}: {exc})")


if not LLM_BACKENDS:
    raise RuntimeError(
        "LLM_BACKENDS is empty. Provide GROQ_API_KEY and/or GEMINI_API_KEY."
    )


print(f"[INIT] Sync LLM chain ready ({len(LLM_BACKENDS)} backend(s)):")
for i, backend in enumerate(LLM_BACKENDS, start=1):
    print(f"   [{i}] {backend.label}")

print()

# Load input JSON
print(f"[LOAD] Reading '{JSON_PATH}'…")

with open(JSON_PATH, "r", encoding="utf-8") as fh:
    input_data: dict = json.load(fh)


assert "book_name" in input_data, "Missing key: book_name"
assert "full_text" in input_data, "Missing key: full_text"
assert "page_footnotes_map" in input_data, "Missing key: page_footnotes_map"

assert isinstance(input_data["book_name"], str), "book_name must be str"
assert isinstance(input_data["full_text"], str), "full_text must be str"
assert isinstance(input_data["page_footnotes_map"], dict), "page_footnotes_map must be dict"

print("[LOAD] Input validation passed ✓")


# Run pipeline
qdrant_points: list[dict] = run_pipeline(
    input_data,
    backends=LLM_BACKENDS,
)


# Save local output
print(f"\n[SAVE] Writing {len(qdrant_points):,} points → '{OUTPUT_PATH}'…")

with open(OUTPUT_PATH, "w", encoding="utf-8") as fh:
    json.dump(qdrant_points, fh, ensure_ascii=False, indent=2)

kb = os.path.getsize(OUTPUT_PATH) / 1024
print(f"[SAVE] Done. {kb:.1f} KB written.")
# Out:
# [KEY] 'grok_key' loaded from Colab Secrets.
# [KEY] 'GEMINI_API_KEY' loaded from Colab Secrets.
# [INIT] GeminiBackend added: gemini-3.1-flash-lite
# [INIT] Sync LLM chain ready (1 backend(s)):
#    [1] gemini-sync/gemini-3.1-flash-lite
#
# [LOAD] Reading 'full_VietSu_data.json'…
# [LOAD] Input validation passed ✓
#
# ════════════════════════════════════════════════════════════════════════
#   [PHASE 1] RUN CHUNKING PIPELINE — 'Việt Sử Toàn Thư'
#   Using Context Length Target: 512
# ════════════════════════════════════════════════════════════════════════
#
# [WINDOWS] book='Việt Sử Toàn Thư' | window_size=3 pages
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW    1/28 | pages=[161, 162, 163] | chars=6,972
#       [STRUCT] 19 structural boundaries | book='Việt Sử Toàn Thư'
#     [MINI-CHUNK] window chars=6,972 → 65 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
# {"split_after_indices":[2,14,25,31,49,58]}
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=65 → splits=[2, 7, 14, 19, 25, 31, 36, 44, 49, 58]
# llm trả về
#  [2, 7, 14, 19, 25, 31, 36, 44, 49, 58]
#
#
#
#     [MERGE] 65 mini-chunks + 10 splits → 11 semantic groups
#       [TOKEN] id=019e5681… | raw[0:60]='Phần 3 - Chương 7 Nhà Trần (1225-1413) Nước Việt Nam Dưới Đờ'
#               seg[0:60]='Phần 3 - Chương 7 Nhà_Trần ( 1225 - 1413 ) Nước Việt_Nam Dướ'
#               ids[:8]=[0, 82666, 138, 20, 40691, 361, 19491, 454] | total_tokens=313
#       [TOKEN] id=019e5681… | raw[0:60]='Lý Huệ Tông và Chiêu Hoàng tuy bị gạt ra ngoài lề sân khấu c'
#               seg[0:60]='Lý_Huệ_Tông và Chiêu_Hoàng tuy bị gạt ra ngoài_lề sân_khấu c'
#               ids[:8]=[0, 44980, 454, 30513, 21018, 454, 618, 23366] | total_tokens=295
#       [TOKEN] id=019e5681… | raw[0:60]='Một hôm Thủ Độ đi qua chùa Chân Giáo thấy Huệ Tông đang ngồi'
#               seg[0:60]='Một hôm Thủ_Độ đi qua chùa Chân_Giáo thấy Huệ_Tông đang ngồi'
#               ids[:8]=[0, 14921, 26094, 40797, 454, 13347, 27350, 2467] | total_tokens=408
#       [TOKEN] id=019e5681… | raw[0:60]='2- Đảo Lộn Nhân Luân Chiêu Thánh lấy Trần Thái Tông 12 năm v'
#               seg[0:60]='2 - Đảo_Lộn Nhân_Luân Chiêu_Thánh lấy Trần_Thái_Tông 12 năm'
#               ids[:8]=[0, 116, 20, 4428, 17195, 31, 454, 866] | total_tokens=222
#       [TOKEN] id=019e5681… | raw[0:60]='chị họ của Thủ Độ khi đó đã giáng xuống làm Thiên Cực công'
#               seg[0:60]='chị họ của Thủ_Độ khi đó đã giáng xuống làm Thiên_Cực công_c'
#               ids[:8]=[0, 17483, 7424, 550, 40797, 454, 13347, 27350] | total_tokens=361
#       [TOKEN] id=019e5681… | raw[0:60]='Về phần vua Thái Tông đối với sự áp chế của Trần Thủ Độ cũng'
#               seg[0:60]='Về phần vua Thái_Tông đối_với sự áp_chế của Trần_Thủ_Độ cũng'
#               ids[:8]=[0, 66863, 8192, 86729, 37347, 454, 618, 23366] | total_tokens=290
#       [TOKEN] id=019e5681… | raw[0:60]='3- Việc Đánh Dẹp Trong Nước Việc họ Trần cướp ngai vàng của'
#               seg[0:60]='3 - Việc Đánh_Dẹp Trong Nước Việc họ Trần_cướp ngai_vàng của'
#               ids[:8]=[0, 138, 20, 57253, 141454, 454, 397, 45743] | total_tokens=260
#       [TOKEN] id=019e5681… | raw[0:60]='Giặc cướp nổi lên bốn phương. Tại Quốc Oai thuộc tỉnh Sơn T'
#               seg[0:60]='Giặc cướp nổi lên bốn_phương . Tại Quốc_Oai thuộc tỉnh Sơn_T'
#               ids[:8]=[0, 5174, 64514, 182174, 18844, 4494, 126437, 454] | total_tokens=425
#       [TOKEN] id=019e5681… | raw[0:60]='Hoặc giả Thủ Độ e dè cái tiêu bài chính nghĩa "Phù Lý diệt'
#               seg[0:60]='Hoặc giả Thủ_Độ e_dè cái tiêu_bài chính_nghĩa " Phù_Lý_diệt'
#               ids[:8]=[0, 2291, 64514, 22643, 40797, 454, 13347, 27350] | total_tokens=249
#       [TOKEN] id=019e5681… | raw[0:60]='Trừ được mọi mối loạn, Thủ Độ cũng theo tục nhà Lý hằng năm'
#               seg[0:60]='Trừ được mọi mối_loạn , Thủ_Độ cũng theo tục nhà Lý_hằng năm'
#               ids[:8]=[0, 5454, 56906, 912, 10900, 70254, 454, 365] | total_tokens=512
#       [TOKEN] id=019e5681… | raw[0:60]='Thủ Độ chia nước Nam làm 12 lộ (tỉnh). Mỗi lộ có nhiều xã. C'
#               seg[0:60]='Thủ_Độ chia nước Nam làm 12 lộ ( tỉnh ) . Mỗi lộ có nhiều xã'
#               ids[:8]=[0, 40797, 454, 13347, 27350, 16455, 3042, 2096] | total_tokens=215
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW    2/28 | pages=[163, 164, 165, 166] | chars=7,436
#       [STRUCT] 34 structural boundaries | book='Việt Sử Toàn Thư'
#     [MINI-CHUNK] window chars=7,436 → 72 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
# {"split_after_indices":[10,17,24,30,43,52,63]}
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=72 → splits=[4, 10, 17, 24, 30, 35, 43, 52, 57, 63]
# llm trả về
#  [4, 10, 17, 24, 30, 35, 43, 52, 57, 63]
#
#
#
#     [MERGE] 72 mini-chunks + 10 splits → 11 semantic groups
#       [TOKEN] id=019e5681… | raw[0:60]='Phàm mỗi làng có bao nhiêu người đi làm quan văn, võ, thư lạ'
#               seg[0:60]='Phàm mỗi làng có bao_nhiêu người đi làm quan_văn , võ , thư'
#               ids[:8]=[0, 13000, 1298, 39, 17356, 112258, 524, 8609] | total_tokens=324
#       [TOKEN] id=019e5681… | raw[0:60]='chính trị và thuế khóa ở mỗi Lộ.\nMười hai lộ dưới đời nhà Tr'
#               seg[0:60]='chính_trị và thuế_khóa ở mỗi Lộ . Mười hai lộ dưới đời nhà T'
#               ids[:8]=[0, 3178, 454, 4448, 51721, 544, 39552, 454] | total_tokens=279
#       [TOKEN] id=019e5681… | raw[0:60]='Chính thể dưới đời Trần có tính cách phong kiến triệt để. Đứ'
#               seg[0:60]='Chính_thể dưới đời Trần_có tính_cách phong_kiến triệt_để . Đ'
#               ids[:8]=[0, 17654, 454, 927, 35895, 17858, 16774, 42974] | total_tokens=326
#       [TOKEN] id=019e5681… | raw[0:60]='Tước phong thì có Đại vương, Vương, Quốc công, Công và Hầu..'
#               seg[0:60]='Tước_phong thì có Đại_vương , Vương , Quốc_công , Công và Hầ'
#               ids[:8]=[0, 384, 68507, 454, 254, 30434, 2579, 524] | total_tokens=418
#       [TOKEN] id=019e5681… | raw[0:60]='Việc thăng chức theo niên hạn sau đây: Mười năm lên một hàm,'
#               seg[0:60]='Việc thăng_chức theo niên_hạn sau đây : Mười năm lên một hàm'
#               ids[:8]=[0, 57253, 188498, 454, 206, 48021, 3790, 55113] | total_tokens=263
#       [TOKEN] id=019e5681… | raw[0:60]='5. Việc Binh Chế và Lực Lượng Quân Đội Đời Trần Sơ Nhà Trần'
#               seg[0:60]='5 . Việc Binh_Chế và Lực_Lượng Quân_Đội Đời Trần_Sơ_Nhà_Trần'
#               ids[:8]=[0, 190, 6, 5, 57253, 16666, 127, 454] | total_tokens=287
#       [TOKEN] id=019e5681… | raw[0:60]='quânThánh đức và quân Thần sách. Chữ Tứ (4) chắc là mỗi quâ'
#               seg[0:60]='quânThánh_đức và quân Thần_sách . Chữ_Tứ ( 4 ) chắc là mỗi q'
#               ids[:8]=[0, 29225, 20800, 1665, 127, 454, 18643, 48021] | total_tokens=423
#       [TOKEN] id=019e5681… | raw[0:60]='Tháng tám, năm Đinh Mão (1267) quân lính chia ra như sau:\nQu'
#               seg[0:60]='Tháng tám , năm Đinh_Mão ( 1267 ) quân_lính chia ra như sau'
#               ids[:8]=[0, 77833, 4254, 39, 6, 4, 2933, 224564] | total_tokens=389
#       [TOKEN] id=019e5681… | raw[0:60]='Số lượng quân nhà Trần lúc thường không có tới 10 vạn, nhưng'
#               seg[0:60]='Số_lượng quân nhà Trần_lúc thường không có tới 10 vạn , nhưn'
#               ids[:8]=[0, 48003, 454, 141, 75188, 29225, 2455, 42974] | total_tokens=288
#       [TOKEN] id=019e5681… | raw[0:60]='đã huy động các dân Bằng Hà (thuộc tỉnh Hải Dương), Na Sầm'
#               seg[0:60]='đã huy_động các dân Bằng_Hà ( thuộc tỉnh Hải_Dương ) , Na_Sầ'
#               ids[:8]=[0, 1408, 58854, 454, 18643, 27350, 449, 925] | total_tokens=331
#       [TOKEN] id=019e5681… | raw[0:60]='6- Kinh Tế và Xã Hội Kinh tế dưới đời nhà Trần vẫn là kinh t'
#               seg[0:60]='6 - Kinh_Tế và Xã_Hội Kinh_tế dưới đời nhà Trần_vẫn là kinh_'
#               ids[:8]=[0, 305, 20, 31588, 454, 618, 54073, 544] | total_tokens=359
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW    3/28 | pages=[166, 167, 168, 169] | chars=7,818
#       [STRUCT] 32 structural boundaries | book='Việt Sử Toàn Thư'
#     [MINI-CHUNK] window chars=7,818 → 74 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
# {"split_after_indices":[6,12,16,21,26,29,34,41,44,48,55,60,65,67,73]}
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=74 → splits=[6, 12, 16, 21, 26, 29, 34, 41, 44, 48, 55, 60, 65, 67]
# llm trả về
#  [6, 12, 16, 21, 26, 29, 34, 41, 44, 48, 55, 60, 65, 67]
#
#
#
#     [MERGE] 74 mini-chunks + 14 splits → 15 semantic groups
#       [TOKEN] id=019e5681… | raw[0:60]='Nhân dân hàng năm phải nộp tiền "thân dịch", quà tết tháng g'
#               seg[0:60]='Nhân_dân hàng năm phải nộp tiền " thân_dịch " , quà tết thán'
#               ids[:8]=[0, 56025, 454, 71, 7453, 2508, 2933, 2334] | total_tokens=273
#       [TOKEN] id=019e5681… | raw[0:60]='Thuế điền nộp bằng thóc, theo tỷ lệ: mỗi mẫu phải nộp 100 th'
#               seg[0:60]='Thuế_điền nộp bằng thóc , theo tỷ_lệ : mỗi mẫu phải nộp 100'
#               ids[:8]=[0, 12613, 54073, 454, 18643, 37199, 113592, 6567] | total_tokens=363
#       [TOKEN] id=019e5681… | raw[0:60]='Ngoài các thứ thuế trọng yếu trên đây, còn có các thứ thuế l'
#               seg[0:60]='Ngoài các thứ thuế trọng_yếu trên đây , còn có các thứ thuế'
#               ids[:8]=[0, 46158, 925, 11847, 39552, 9899, 454, 53] | total_tokens=186
#       [TOKEN] id=019e5681… | raw[0:60]='Bàn đến nông nghiệp dưới đời Trần chúng ta đã thấy có sự mở'
#               seg[0:60]='Bàn đến nông_nghiệp dưới đời Trần_chúng_ta đã thấy có sự mở_'
#               ids[:8]=[0, 39914, 19, 1885, 49708, 454, 19, 18651] | total_tokens=360
#       [TOKEN] id=019e5681… | raw[0:60]='Về công nghiệp sinh hoạt hay thương nghiệp sinh hoạt chúng t'
#               seg[0:60]='Về công_nghiệp sinh_hoạt hay thương_nghiệp sinh_hoạt chúng_t'
#               ids[:8]=[0, 66863, 1871, 454, 19, 18651, 21018, 254] | total_tokens=327
#       [TOKEN] id=019e5681… | raw[0:60]='Nhà Trần bảo vệ nhiệt liệt chế độ tư hữu của dân gian. Việc'
#               seg[0:60]='Nhà Trần_bảo_vệ nhiệt_liệt chế_độ tư_hữu của dân_gian . Việc'
#               ids[:8]=[0, 19491, 42974, 454, 275, 17195, 31, 454] | total_tokens=234
#       [TOKEN] id=019e5681… | raw[0:60]='Theo trên đây, chúng ta biết dưới Trần triều chế độ phong ki'
#               seg[0:60]='Theo trên đây , chúng_ta biết dưới Trần_triều_chế_độ phong_k'
#               ids[:8]=[0, 19635, 2479, 4600, 6, 4, 4006, 454] | total_tokens=264
#       [TOKEN] id=019e5681… | raw[0:60]='Những kẻ vô sản vào làm nô (tớ trai) tì (tớ gái) cho các nhà'
#               seg[0:60]='Những kẻ vô_sản vào làm nô ( tớ_trai ) tì ( tớ gái ) cho các'
#               ids[:8]=[0, 13836, 52180, 11181, 454, 7, 17195, 19] | total_tokens=416
#       [TOKEN] id=019e5681… | raw[0:60]='Một tính cách phong kiến nữa dưới Trần triều là chế độ tập ấ'
#               seg[0:60]='Một tính_cách phong_kiến nữa dưới Trần_triều là chế_độ tập_ấ'
#               ids[:8]=[0, 14921, 6745, 454, 238, 5687, 22510, 454] | total_tokens=280
#       [TOKEN] id=019e5681… | raw[0:60]='Hàng năm triều đình cho xã quan khai báo nhân khẩu gọi là "d'
#               seg[0:60]='Hàng năm triều_đình cho xã quan khai_báo nhân_khẩu gọi_là "'
#               ids[:8]=[0, 67656, 2933, 221089, 454, 18643, 119518, 681] | total_tokens=204
#       [TOKEN] id=019e5681… | raw[0:60]='7- Phong Tục Phong tục của dân Việt Nam vào triều đại nhà Tr'
#               seg[0:60]='7 - Phong_Tục Phong_tục của dân Việt_Nam vào triều_đại nhà T'
#               ids[:8]=[0, 361, 20, 55110, 454, 618, 66223, 55110] | total_tokens=368
#       [TOKEN] id=019e5681… | raw[0:60]='Đúng ngày lập xuân, vua cắt người tông trưởng cầm roi vụt và'
#               seg[0:60]='Đúng ngày lập xuân , vua cắt người tông_trưởng cầm roi vụt v'
#               ids[:8]=[0, 4428, 971, 449, 3063, 12552, 173887, 6] | total_tokens=257
#       [TOKEN] id=019e5681… | raw[0:60]='Việc cưới xin thường hay chọn vào tháng xuân để làm lễ vấn d'
#               seg[0:60]='Việc cưới_xin thường hay chọn vào tháng xuân để làm lễ_vấn_d'
#               ids[:8]=[0, 57253, 89481, 454, 35815, 6840, 2054, 10009] | total_tokens=366
#       [TOKEN] id=019e5681… | raw[0:60]='Hằng năm mồng 1 tháng 10 có tết "cơm mới" hoặc "xôi mới" từ'
#               seg[0:60]='Hằng năm mồng 1 tháng 10 có tết " cơm mới " hoặc " xôi mới "'
#               ids[:8]=[0, 572, 114186, 2933, 347, 32773, 106, 7973] | total_tokens=133
#       [TOKEN] id=019e5681… | raw[0:60]='Y phục đời bấy giờ như sau đây: vương hầu và thứ dân thường'
#               seg[0:60]='Y_phục đời bấy_giờ như sau đây : vương_hầu và thứ dân_thường'
#               ids[:8]=[0, 990, 454, 11727, 66223, 16774, 876, 249999] | total_tokens=203
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW    4/28 | pages=[169, 170, 171, 172] | chars=8,912
#       [STRUCT] 20 structural boundaries | book='Việt Sử Toàn Thư'
#     [MINI-CHUNK] window chars=8,912 → 77 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
# {"split_after_indices":[3,11,16,23,26,32,42,49,55,60,71]}
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=77 → splits=[3, 11, 16, 23, 26, 32, 37, 42, 49, 55, 60, 65, 71]
# llm trả về
#  [3, 11, 16, 23, 26, 32, 37, 42, 49, 55, 60, 65, 71]
#
#
#
#     [MERGE] 77 mini-chunks + 13 splits → 14 semantic groups
#       [TOKEN] id=019e5681… | raw[0:60]='Về hình phạt của Trần triều xét ra nghiêm ngặt hơn Lý triều.'
#               seg[0:60]='Về hình_phạt của Trần_triều_xét ra nghiêm_ngặt hơn Lý_triều'
#               ids[:8]=[0, 66863, 4609, 454, 11727, 63409, 550, 42974] | total_tokens=274
#       [TOKEN] id=019e5681… | raw[0:60]='8- Văn Hóa Cùng một nhịp với các ngành chính trị, quân sự, k'
#               seg[0:60]='8 - Văn_Hóa Cùng một nhịp với các ngành chính_trị , quân_sự'
#               ids[:8]=[0, 382, 20, 14176, 454, 841, 849, 11] | total_tokens=361
#       [TOKEN] id=019e5681… | raw[0:60]='Nói vậy không phải là nhà Trần đã triệt để dùng chữ Nôm. Các'
#               seg[0:60]='Nói vậy không phải là nhà_Trần đã triệt_để dùng chữ Nôm . Cá'
#               ids[:8]=[0, 94230, 6239, 687, 2334, 580, 2455, 454] | total_tokens=282
#       [TOKEN] id=019e5681… | raw[0:60]='Để tỏ sự tiến triển của văn hóa đời Trần, trong mục phong tụ'
#               seg[0:60]='Để tỏ sự tiến_triển của văn_hóa đời Trần , trong mục phong_t'
#               ids[:8]=[0, 32390, 52237, 2550, 19743, 454, 4448, 206654] | total_tokens=429
#       [TOKEN] id=019e5681… | raw[0:60]='Nhà Trần xuất hiện trên sân khấu chính trị Việt Nam được 2 n'
#               seg[0:60]='Nhà Trần_xuất_hiện trên sân_khấu chính_trị Việt_Nam được 2 n'
#               ids[:8]=[0, 19491, 42974, 454, 16220, 249999, 18, 454] | total_tokens=211
#       [TOKEN] id=019e5681… | raw[0:60]='Có nên nói rằng ngay trong thời Trần Sơ, Hán văn đã lên tới'
#               seg[0:60]='Có nên nói rằng ngay trong thời Trần_Sơ , Hán_văn đã lên tới'
#               ids[:8]=[0, 11302, 3809, 2872, 10371, 13841, 1000, 4194] | total_tokens=316
#       [TOKEN] id=019e5681… | raw[0:60]='Nhà Trần lại cho nghiên cứu và học tập cả tiếng Mán, tiếng T'
#               seg[0:60]='Nhà Trần_lại cho nghiên_cứu và học_tập cả tiếng Mán , tiếng'
#               ids[:8]=[0, 19491, 42974, 454, 141, 12976, 14, 681] | total_tokens=325
#       [TOKEN] id=019e5681… | raw[0:60]='là "thành nhân" (theo lời Hoa Bằng) thì tinh thần tranh đấu'
#               seg[0:60]='là " thành_nhân " ( theo lời Hoa_Bằng ) thì tinh_thần tranh_'
#               ids[:8]=[0, 580, 44, 2781, 454, 19, 150388, 44] | total_tokens=310
#       [TOKEN] id=019e5681… | raw[0:60]='Đối với chúng nhân, câu "Dân vi quý" của Mạnh Tử được thi hà'
#               seg[0:60]='Đối_với chúng_nhân , câu " Dân vi_quý " của Mạnh_Tử được thi'
#               ids[:8]=[0, 59893, 454, 334, 81397, 4006, 454, 19] | total_tokens=328
#       [TOKEN] id=019e5681… | raw[0:60]='Trạng thái ấy lại càng rõ rệt giữa khi chống Nguyên, ngay c'
#               seg[0:60]='Trạng_thái ấy lại càng rõ_rệt giữa khi chống Nguyên , ngay c'
#               ids[:8]=[0, 5454, 12976, 449, 454, 927, 51917, 14112] | total_tokens=405
#       [TOKEN] id=019e5681… | raw[0:60]='- Thành tích chiến đấu của quân Mông Cổ - Cuộc xâm lăng thứ'
#               seg[0:60]='- Thành_tích chiến_đấu của quân Mông_Cổ - Cuộc xâm_lăng thứ'
#               ids[:8]=[0, 20, 22049, 454, 18, 10767, 16791, 454] | total_tokens=241
#       [TOKEN] id=019e5681… | raw[0:60]='Dân số Mông Cổ có gần 3 triệu, đa số là dân du mục. Nhà cửa'
#               seg[0:60]='Dân_số Mông_Cổ có gần 3 triệu , đa_số là dân du_mục . Nhà_cử'
#               ids[:8]=[0, 100612, 454, 7, 54030, 276, 23366, 454] | total_tokens=313
#       [TOKEN] id=019e5681… | raw[0:60]='săn bắn như nhiều dân tộc khác về cổ thời. Và tương đối với'
#               seg[0:60]='săn_bắn như nhiều dân_tộc khác về cổ_thời . Và tương_đối_với'
#               ids[:8]=[0, 772, 19, 454, 275, 249990, 19, 1641] | total_tokens=365
#       [TOKEN] id=019e5681… | raw[0:60]='Tổ tiên của họ là giống Hung Nô. Tài nguyên của họ là những'
#               seg[0:60]='Tổ_tiên của họ là giống Hung_Nô . Tài_nguyên của họ là những'
#               ids[:8]=[0, 68127, 454, 118, 1732, 550, 7424, 580] | total_tokens=241
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW    5/28 | pages=[172, 173, 174, 175] | chars=7,592
#       [STRUCT] 28 structural boundaries | book='Việt Sử Toàn Thư'
#     [MINI-CHUNK] window chars=7,592 → 73 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
# {"split_after_indices":[9,12,20,26,30,33,36,42,45,59,66,70]}
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=73 → splits=[4, 9, 12, 20, 26, 30, 33, 36, 42, 45, 50, 59, 66, 70]
# llm trả về
#  [4, 9, 12, 20, 26, 30, 33, 36, 42, 45, 50, 59, 66, 70]
#
#
#
#     [MERGE] 73 mini-chunks + 14 splits → 15 semantic groups
#       [TOKEN] id=019e5681… | raw[0:60]='1) Bộ trong gồm các quân Túc vệ.2) Bộ ngoài là các quân Trấn'
#               seg[0:60]='1 ) Bộ trong gồm các quân_Túc_vệ . 2 ) Bộ ngoài là các quân'
#               ids[:8]=[0, 106, 1388, 13843, 1000, 33256, 925, 29225] | total_tokens=276
#       [TOKEN] id=019e5681… | raw[0:60]='Khiếp tiết dùng vào việc bảo vệ Thiên tử, là thân quân tron'
#               seg[0:60]='Khiếp_tiết dùng vào việc bảo_vệ Thiên_tử , là thân_quân tron'
#               ids[:8]=[0, 341, 122384, 454, 118, 27106, 8456, 2249] | total_tokens=370
#       [TOKEN] id=019e5681… | raw[0:60]='Lối đánh của Mông Cổ là khi lâm trận, đạo kỵ binh lưu động c'
#               seg[0:60]='Lối đánh của Mông_Cổ là khi lâm_trận , đạo kỵ_binh lưu_động'
#               ids[:8]=[0, 339, 28151, 13868, 550, 276, 23366, 454] | total_tokens=146
#       [TOKEN] id=019e5681… | raw[0:60]='2- Thành Tích Chiến Đấu Của Quân Mông Cổ Đây những thành tíc'
#               seg[0:60]='2 - Thành_Tích Chiến_Đấu_Của Quân_Mông Cổ_Đây những thành_tí'
#               ids[:8]=[0, 116, 20, 22049, 454, 618, 10767, 140910] | total_tokens=440
#       [TOKEN] id=019e5681… | raw[0:60]='Thắng Kim xong, Thành Cát Tư Hãn quay sang Tây phương tấn cô'
#               seg[0:60]='Thắng Kim_xong , Thành_Cát Tư_Hãn quay sang Tây_phương tấn_c'
#               ids[:8]=[0, 217897, 8268, 454, 425, 4021, 6, 4] | total_tokens=391
#       [TOKEN] id=019e5681… | raw[0:60]='Đầu thế kỷ thứ XIII, Hồi quốc đang thịnh đạt và là đế quốc k'
#               seg[0:60]='Đầu thế_kỷ thứ XIII , Hồi_quốc đang thịnh_đạt và là đế_quốc'
#               ids[:8]=[0, 79592, 3061, 454, 92, 60479, 11847, 49430] | total_tokens=232
#       [TOKEN] id=019e5681… | raw[0:60]='Tháng chạp năm 1237 tới tháng năm 1238 bốn phần năm lĩnh thổ'
#               seg[0:60]='Tháng_chạp năm 1237 tới tháng năm 1238 bốn phần năm lĩnh thổ'
#               ids[:8]=[0, 77833, 454, 206, 82830, 2933, 427, 10945] | total_tokens=199
#       [TOKEN] id=019e5681… | raw[0:60]='Về phía Á Đông, trong khoảng thời gian đánh Đông dẹp Tây thì'
#               seg[0:60]='Về phía Á_Đông , trong khoảng thời_gian đánh_Đông dẹp_Tây th'
#               ids[:8]=[0, 66863, 25403, 3566, 454, 13347, 23366, 6] | total_tokens=148
#       [TOKEN] id=019e5681… | raw[0:60]='Trong khi chinh phục Tây Hạ thì chúa Mông Cổ mất, con là A L'
#               seg[0:60]='Trong khi chinh_phục Tây_Hạ thì chúa Mông_Cổ mất , con là A_'
#               ids[:8]=[0, 12818, 1907, 1658, 6457, 454, 11727, 66223] | total_tokens=402
#       [TOKEN] id=019e5681… | raw[0:60]='Xét ra về diện tích đế quốc này gần già nửa phần thế giới l'
#               seg[0:60]='Xét ra về diện_tích đế_quốc này gần già nửa phần thế_giới là'
#               ids[:8]=[0, 1193, 2305, 673, 1893, 18491, 454, 18] | total_tokens=188
#       [TOKEN] id=019e5681… | raw[0:60]='3- Cuộc Xâm Lăng Thứ Nhất Của Mông Cổ Khi Mông Kha còn sống,'
#               seg[0:60]='3 - Cuộc Xâm_Lăng_Thứ Nhất_Của Mông_Cổ Khi Mông_Kha còn sống'
#               ids[:8]=[0, 138, 20, 121833, 1193, 27253, 454, 866] | total_tokens=233
#       [TOKEN] id=019e5681… | raw[0:60]='Thái Tông liền phái Trần Quốc Tuấn động binh trấn giữ các n'
#               seg[0:60]='Thái_Tông liền phái Trần_Quốc_Tuấn_động_binh trấn_giữ các nơ'
#               ids[:8]=[0, 37347, 454, 618, 23366, 37015, 97716, 42974] | total_tokens=442
#       [TOKEN] id=019e5681… | raw[0:60]='Thành Thăng Long bỏ ngỏ. Quân Mông Cổ vào thấy ba người sứ c'
#               seg[0:60]='Thành_Thăng_Long bỏ_ngỏ . Quân Mông_Cổ vào thấy ba người sứ'
#               ids[:8]=[0, 22049, 454, 20800, 44473, 454, 866, 4021] | total_tokens=391
#       [TOKEN] id=019e5681… | raw[0:60]='Được ít lâu quân Mông Cổ mỏi mệt vì không chịu được thủy thổ'
#               seg[0:60]='Được ít_lâu quân Mông_Cổ_mỏi mệt vì không chịu được thủy_thổ'
#               ids[:8]=[0, 74409, 24323, 454, 54489, 34, 29225, 276] | total_tokens=272
#       [TOKEN] id=019e5681… | raw[0:60]='Mùa xuân năm Mậu Ngọ (1258) vua Thái Tông nhường ngôi cho co'
#               seg[0:60]='Mùa xuân năm Mậu_Ngọ ( 1258 ) vua Thái_Tông nhường_ngôi cho'
#               ids[:8]=[0, 220174, 173887, 2933, 276, 85284, 454, 69656] | total_tokens=79
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW    6/28 | pages=[175, 176, 177, 178] | chars=7,164
#       [STRUCT] 22 structural boundaries | book='Việt Sử Toàn Thư'
#     [MINI-CHUNK] window chars=7,164 → 69 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
# {"split_after_indices":[9,19,33,51,62]}
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=69 → splits=[4, 9, 14, 19, 24, 33, 38, 46, 51, 56, 62]
# llm trả về
#  [4, 9, 14, 19, 24, 33, 38, 46, 51, 56, 62]
#
#
#
#     [MERGE] 69 mini-chunks + 11 splits → 12 semantic groups
#       [TOKEN] id=019e5681… | raw[0:60]='Thái Tông trị vì được 33 năm, làm Thái Thượng Hoàng được 19'
#               seg[0:60]='Thái Tông_trị_vì được 33 năm , làm Thái_Thượng_Hoàng được 19'
#               ids[:8]=[0, 37347, 384, 23366, 454, 4448, 51721, 454] | total_tokens=262
#       [TOKEN] id=019e5681… | raw[0:60]='Hoàng đệ là Trần Ích Tắc có tiếng là người trí thức trong n'
#               seg[0:60]='Hoàng_đệ là Trần_Ích_Tắc có tiếng là người trí_thức trong nư'
#               ids[:8]=[0, 38356, 454, 18643, 21018, 580, 42974, 454] | total_tokens=319
#       [TOKEN] id=019e5681… | raw[0:60]='2- Việc Ngoại Giao Với Mông Cổ Mông Cổ tuy thua nhưng vẫn kh'
#               seg[0:60]='2 - Việc Ngoại_Giao Với Mông_Cổ_Mông_Cổ tuy_thua nhưng vẫn k'
#               ids[:8]=[0, 116, 20, 57253, 141715, 454, 724, 399] | total_tokens=276
#       [TOKEN] id=019e5681… | raw[0:60]='"Xưa ta sai sứ sang thông hiếu, các ngươi mê man không tỉnh'
#               seg[0:60]='" Xưa ta sai sứ sang thông_hiếu , các ngươi mê_man không tỉn'
#               ids[:8]=[0, 44, 1193, 11479, 11, 308, 5630, 108327] | total_tokens=251
#       [TOKEN] id=019e5681… | raw[0:60]='Ví bằng vẫn còn không chịu thì cứ bảo rõ cho ta biết".\nVua'
#               seg[0:60]='Ví bằng vẫn còn không chịu thì cứ bảo rõ cho ta biết " . Vua'
#               ids[:8]=[0, 21483, 6567, 8123, 3531, 687, 22396, 2579] | total_tokens=230
#       [TOKEN] id=019e5681… | raw[0:60]='Mông Cổ sai sứ sang yêu sách hết điều này đến điều nọ, vua'
#               seg[0:60]='Mông_Cổ sai sứ sang yêu_sách hết điều này đến_điều nọ , vua'
#               ids[:8]=[0, 276, 23366, 454, 441, 25091, 5630, 108327] | total_tokens=512
#       [TOKEN] id=019e5681… | raw[0:60]='Trong giai đoạn hòa hiếu khá dài này, Trần triều lợi dụng yế'
#               seg[0:60]='Trong giai_đoạn hòa_hiếu khá dài này , Trần_triều_lợi_dụng y'
#               ids[:8]=[0, 12818, 66856, 454, 18643, 31, 12976, 19] | total_tokens=254
#       [TOKEN] id=019e5681… | raw[0:60]='Cuộc áp bức bằng quân lực năm Đinh Tị (1257) đã không thành'
#               seg[0:60]='Cuộc áp_bức bằng quân_lực năm Đinh_Tị ( 1257 ) đã không thàn'
#               ids[:8]=[0, 121833, 21243, 454, 275, 48021, 6567, 29225] | total_tokens=466
#       [TOKEN] id=019e5681… | raw[0:60]='Cái chước lùi để tiến của Trần triều rõ rệt là một thủ đoạn'
#               seg[0:60]='Cái_chước lùi để tiến của Trần_triều rõ_rệt là một thủ_đoạn'
#               ids[:8]=[0, 109966, 454, 206, 68507, 169534, 1498, 19743] | total_tokens=231
#       [TOKEN] id=019e5681… | raw[0:60]='Cuộc xô xát giữa đôi bên ra sao?Ba năm sau tức là năm Bính D'
#               seg[0:60]='Cuộc xô_xát giữa đôi bên ra sao ?_Ba năm sau tức_là năm Bính'
#               ids[:8]=[0, 121833, 1022, 4470, 454, 425, 1699, 19865] | total_tokens=306
#       [TOKEN] id=019e5681… | raw[0:60]='Hồi đó lực lượng của ta chưa dồi dào nên phải tạm nhận khoả'
#               seg[0:60]='Hồi đó lực_lượng của ta chưa dồi_dào nên phải tạm nhận khoản'
#               ids[:8]=[0, 21433, 14, 2275, 9611, 454, 141, 75188] | total_tokens=262
#       [TOKEN] id=019e5681… | raw[0:60]='1) Tháng một năm Đinh Mão (1267) Mông Cổ đòi trao trả hai tê'
#               seg[0:60]='1 ) Tháng một năm Đinh_Mão ( 1267 ) Mông_Cổ đòi trao_trả hai'
#               ids[:8]=[0, 106, 1388, 77833, 889, 2933, 224564, 454] | total_tokens=251
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW    7/28 | pages=[178, 179, 180, 181, 182] | chars=9,048
#       [STRUCT] 33 structural boundaries | book='Việt Sử Toàn Thư'
#     [MINI-CHUNK] window chars=9,048 → 84 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
# {"split_after_indices":[2,10,13,23,26,32,43,45,52,56,59,63,67,72,79]}
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=84 → splits=[2, 10, 13, 18, 23, 26, 32, 37, 43, 45, 52, 56, 59, 63, 67, 72, 79]
# llm trả về
#  [2, 10, 13, 18, 23, 26, 32, 37, 43, 45, 52, 56, 59, 63, 67, 72, 79]
#
#
#
#     [MERGE] 84 mini-chunks + 17 splits → 18 semantic groups
#       [TOKEN] id=019e5682… | raw[0:60]='Vua Trần Thánh Tông trả lời qua Trung thư sảnh nhà Nguyên: "'
#               seg[0:60]='Vua Trần_Thánh_Tông trả_lời qua Trung_thư sảnh nhà_Nguyên :'
#               ids[:8]=[0, 35443, 11, 42974, 454, 20800, 1665, 127] | total_tokens=172
#       [TOKEN] id=019e5682… | raw[0:60]='(Tháng chạp năm Canh Thân (1260) Mông Cổ do chính sách mềm'
#               seg[0:60]='( Tháng_chạp năm Canh_Thân ( 1260 ) Mông_Cổ do chính_sách mề'
#               ids[:8]=[0, 15, 77833, 454, 206, 82830, 2933, 4171] | total_tokens=447
#       [TOKEN] id=019e5682… | raw[0:60]='" Năm Tân Mùi (1271) Hốt Tất Liệt cho sứ qua dụ vua Thánh Tô'
#               seg[0:60]='" Năm_Tân_Mùi ( 1271 ) Hốt Tất_Liệt cho sứ qua dụ vua Thánh_'
#               ids[:8]=[0, 44, 65832, 454, 618, 7453, 454, 594] | total_tokens=184
#       [TOKEN] id=019e5682… | raw[0:60]='"Dẫu được ba năm một lần cống, sứ bộ qua lại đổi thay đi về'
#               seg[0:60]='" Dẫu được ba năm một lần cống , sứ_bộ qua_lại đổi_thay đi v'
#               ids[:8]=[0, 44, 391, 249988, 34, 912, 961, 2933] | total_tokens=256
#       [TOKEN] id=019e5682… | raw[0:60]='đứng làm phên dậu một phương mà lại còn lập Đạt Lỗ Cát Tề c'
#               seg[0:60]='đứng làm phên_dậu một phương mà_lại còn lập Đạt_Lỗ Cát_Tề ca'
#               ids[:8]=[0, 29004, 1839, 57679, 19, 454, 71, 85284] | total_tokens=328
#       [TOKEN] id=019e5682… | raw[0:60]='Năm Đinh Sửu (1277) Thái Thượng Hoàng mất ở Thiên Trường phủ'
#               seg[0:60]='Năm Đinh_Sửu ( 1277 ) Thái_Thượng_Hoàng mất ở Thiên_Trường_p'
#               ids[:8]=[0, 65832, 224564, 454, 294, 46535, 34, 15] | total_tokens=157
#       [TOKEN] id=019e5682… | raw[0:60]='Trần Nhân Tông (1279 - 1293) Mông Cổ Gây Hấn Lần Thứ Hai -'
#               seg[0:60]='Trần_Nhân_Tông ( 1279 - 1293 ) Mông_Cổ Gây_Hấn Lần Thứ_Hai -'
#               ids[:8]=[0, 42974, 454, 839, 150388, 454, 618, 23366] | total_tokens=365
#       [TOKEN] id=019e5682… | raw[0:60]='Ngoài sự Mông Cổ luôn luôn qua lại hạch sách dưới đời vua Nh'
#               seg[0:60]='Ngoài sự Mông_Cổ luôn_luôn qua_lại hạch_sách dưới đời vua Nh'
#               ids[:8]=[0, 46158, 2550, 276, 23366, 454, 441, 25091] | total_tokens=230
#       [TOKEN] id=019e5682… | raw[0:60]='Chúng ta đã dùng nhiều "lý sự " trong các biểu chương gửi q'
#               seg[0:60]='Chúng_ta đã dùng nhiều " lý_sự " trong các biểu_chương gửi q'
#               ids[:8]=[0, 33756, 454, 102, 1408, 8456, 2558, 44] | total_tokens=385
#       [TOKEN] id=019e5682… | raw[0:60]='Năm Quí Tị (1293) vua Nhân Tông truyền ngôi cho Thái Tử Thuy'
#               seg[0:60]='Năm Quí_Tị ( 1293 ) vua Nhân_Tông truyền ngôi cho Thái_Tử_Th'
#               ids[:8]=[0, 65832, 10022, 430, 454, 618, 51721, 15] | total_tokens=140
#       [TOKEN] id=019e5682… | raw[0:60]='Tháng chạp năm Mậu Dần (1278) Mông Cổ cử bọn Sài Xuân (có sá'
#               seg[0:60]='Tháng_chạp năm Mậu_Dần ( 1278 ) Mông_Cổ_cử bọn Sài_Xuân ( có'
#               ids[:8]=[0, 77833, 454, 206, 82830, 2933, 276, 85284] | total_tokens=419
#       [TOKEN] id=019e5682… | raw[0:60]='Năm Canh Thìn (1280) vua Trần Nhân Tông cử chú họ là Trần Di'
#               seg[0:60]='Năm Canh_Thìn ( 1280 ) vua Trần_Nhân_Tông_cử chú họ là Trần_'
#               ids[:8]=[0, 65832, 4171, 127, 454, 618, 64269, 19] | total_tokens=299
#       [TOKEN] id=019e5682… | raw[0:60]='Cuộc ngoại giao từ đấy tan vỡ.\nTrần triều cương quyết lấy gư'
#               seg[0:60]='Cuộc ngoại_giao từ đấy tan_vỡ . Trần_triều_cương_quyết lấy g'
#               ids[:8]=[0, 121833, 35109, 454, 7366, 31, 2368, 32492] | total_tokens=197
#       [TOKEN] id=019e5682… | raw[0:60]='Tháng bảy năm sau (năm Quí Mùi 1283) vua Trần Nhân Tông lại'
#               seg[0:60]='Tháng bảy năm sau ( năm Quí_Mùi 1283 ) vua Trần_Nhân_Tông lạ'
#               ids[:8]=[0, 77833, 196127, 2933, 858, 15, 2933, 10022] | total_tokens=335
#       [TOKEN] id=019e5682… | raw[0:60]='Trần triều vẫn tiếp tục chước ngoại giao vì việc binh đao đố'
#               seg[0:60]='Trần_triều vẫn tiếp_tục chước ngoại_giao vì việc binh_đao đố'
#               ids[:8]=[0, 42974, 454, 4448, 86630, 8123, 6998, 454] | total_tokens=227
#       [TOKEN] id=019e5682… | raw[0:60]='2- Huyết Chiến Giữa Việt Nam và Mông Cổ Từ khi Sài Xuân bị t'
#               seg[0:60]='2 - Huyết_Chiến Giữa Việt_Nam và Mông_Cổ Từ khi Sài_Xuân bị_'
#               ids[:8]=[0, 116, 20, 88238, 27106, 454, 51379, 26532] | total_tokens=337
#       [TOKEN] id=019e5682… | raw[0:60]='Hội Nghị Bình Than Tháng 10 năm Nhâm Ngọ (1282) Trần triều t'
#               seg[0:60]='Hội_Nghị Bình_Than Tháng 10 năm Nhâm_Ngọ ( 1282 ) Trần_triều'
#               ids[:8]=[0, 22394, 454, 839, 9486, 51721, 20515, 454] | total_tokens=489
#       [TOKEN] id=019e5682… | raw[0:60]='Một chuyện đáng chú ý trong cuộc hội nghị tại Bình Than là H'
#               seg[0:60]='Một chuyện đáng chú_ý trong cuộc hội_nghị tại Bình_Than là H'
#               ids[:8]=[0, 14921, 11260, 25333, 18051, 454, 1673, 1000] | total_tokens=128
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW    8/28 | pages=[182, 183, 184, 185] | chars=8,437
#       [STRUCT] 37 structural boundaries | book='Việt Sử Toàn Thư'
#     [MINI-CHUNK] window chars=8,437 → 85 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
# {"split_after_indices":[4,8,12,17,21,25,29,35,40,44,46,50,54,58,63,70,73]}
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=85 → splits=[4, 8, 12, 17, 21, 25, 29, 35, 40, 44, 46, 50, 54, 58, 63, 70, 73, 82]
# llm trả về
#  [4, 8, 12, 17, 21, 25, 29, 35, 40, 44, 46, 50, 54, 58, 63, 70, 73, 82]
#
#
#
#     [MERGE] 85 mini-chunks + 18 splits → 19 semantic groups
#       [TOKEN] id=019e5682… | raw[0:60]='Cuộc chiến đấu đã quyết định vào tháng 10 năm sau (Quí Mùi 1'
#               seg[0:60]='Cuộc chiến_đấu đã quyết_định vào tháng 10 năm sau ( Quí_Mùi'
#               ids[:8]=[0, 121833, 16791, 454, 18643, 249999, 34, 1408] | total_tokens=370
#       [TOKEN] id=019e5682… | raw[0:60]='Rồi quân đội của ta chia đóng các nơi cổ họng và then chốt'
#               seg[0:60]='Rồi quân_đội của ta chia đóng các nơi cổ_họng và then_chốt c'
#               ids[:8]=[0, 190273, 29225, 454, 18643, 65166, 550, 308] | total_tokens=291
#       [TOKEN] id=019e5682… | raw[0:60]='[38]Việc binh tiến mạnh nhưng việc ngoại giao vẫn tiếp tục'
#               seg[0:60]='Việc binh_tiến mạnh nhưng việc ngoại_giao vẫn tiếp_tục để hò'
#               ids[:8]=[0, 57253, 91756, 454, 118, 26532, 14463, 4255] | total_tokens=271
#       [TOKEN] id=019e5682… | raw[0:60]='Lần này họ huy động tới 50 vạn binh sĩ đặt dưới quyền các d'
#               seg[0:60]='Lần này họ huy_động tới 50 vạn binh_sĩ đặt dưới quyền các da'
#               ids[:8]=[0, 339, 249994, 19, 1617, 7424, 58854, 454] | total_tokens=344
#       [TOKEN] id=019e5682… | raw[0:60]='Đáng để ý một điều là vấn đề tấn công vào Việt Nam của Mông'
#               seg[0:60]='Đáng để_ý một điều là vấn_đề tấn_công vào Việt_Nam của Mông_'
#               ids[:8]=[0, 153646, 449, 1498, 454, 1673, 889, 4069] | total_tokens=312
#       [TOKEN] id=019e5682… | raw[0:60]='Khi nghe tin đại quân Mông Cổ họp ở Hồ Quảng sắp sang, vua N'
#               seg[0:60]='Khi nghe tin_đại_quân Mông_Cổ họp ở Hồ_Quảng_sắp sang , vua'
#               ids[:8]=[0, 16584, 18049, 2478, 454, 18643, 12976, 14] | total_tokens=274
#       [TOKEN] id=019e5682… | raw[0:60]='Quân bản bộ của Thoát Hoan đến cửa Nam Quan thì ngừng lại. T'
#               seg[0:60]='Quân bản_bộ của Thoát Hoan đến cửa Nam_Quan thì ngừng lại .'
#               ids[:8]=[0, 101390, 5857, 454, 275, 27350, 550, 32238] | total_tokens=207
#       [TOKEN] id=019e5682… | raw[0:60]='Hưng Đạo Vương Trần Quốc Tuấn nổi giận đuổi sứ Nguyên, chia'
#               seg[0:60]='Hưng_Đạo_Vương Trần_Quốc_Tuấn nổi giận_đuổi sứ_Nguyên , chia'
#               ids[:8]=[0, 129801, 454, 13347, 77248, 454, 856, 43672] | total_tokens=373
#       [TOKEN] id=019e5682… | raw[0:60]='3) Quân của Toa Đô tiến vào Chiêm Thành do thủy đạo (trên đã'
#               seg[0:60]='3 ) Quân của Toa Đô_tiến vào Chiêm_Thành do thủy_đạo ( trên'
#               ids[:8]=[0, 138, 1388, 101390, 550, 717, 11, 130716] | total_tokens=324
#       [TOKEN] id=019e5682… | raw[0:60]='Hưng Đạo Vương chống nhau với Thoát Hoan ở ải Nội Bàng, ngày'
#               seg[0:60]='Hưng_Đạo_Vương chống nhau với Thoát Hoan ở ải Nội_Bàng , ngà'
#               ids[:8]=[0, 129801, 454, 13347, 77248, 454, 856, 43672] | total_tokens=250
#       [TOKEN] id=019e5682… | raw[0:60]='Chiến lược Mông Cổ bấy giờ là dùng thế gọng kìm xiết chặt qu'
#               seg[0:60]='Chiến_lược Mông_Cổ bấy_giờ là dùng thế gọng kìm_xiết chặt qu'
#               ids[:8]=[0, 140910, 454, 141, 95449, 276, 23366, 454] | total_tokens=215
#       [TOKEN] id=019e5682… | raw[0:60]='Quân Nam Rút Lui Theo Kế Hoạch Tại trận tuyến Lạng Sơn buổi'
#               seg[0:60]='Quân_Nam_Rút_Lui Theo Kế_Hoạch Tại trận_tuyến Lạng_Sơn buổi'
#               ids[:8]=[0, 101390, 454, 124197, 454, 1052, 12776, 454] | total_tokens=320
#       [TOKEN] id=019e5682… | raw[0:60]='Vua Nhân Tông được tin Hưng Đạo Vương lui quân khỏi Lạng Sơn'
#               seg[0:60]='Vua Nhân_Tông được tin Hưng_Đạo_Vương_lui quân khỏi Lạng_Sơn'
#               ids[:8]=[0, 35443, 11, 56025, 454, 618, 23366, 912] | total_tokens=298
#       [TOKEN] id=019e5682… | raw[0:60]='Nhà vua được lời cương quyết và trung liệt ấy lại vững lòng.'
#               seg[0:60]='Nhà_vua được lời cương_quyết và trung_liệt ấy lại vững_lòng'
#               ids[:8]=[0, 19491, 454, 1783, 11, 912, 11178, 132734] | total_tokens=197
#       [TOKEN] id=019e5682… | raw[0:60]='Hội Nghị Quân Sự Ở Vạn Kiếp Hội nghị này được nhóm họp để ch'
#               seg[0:60]='Hội_Nghị Quân_Sự Ở Vạn_Kiếp Hội_nghị này được nhóm_họp để ch'
#               ids[:8]=[0, 22394, 454, 839, 9486, 51721, 101390, 454] | total_tokens=367
#       [TOKEN] id=019e5682… | raw[0:60]='Ta nhận thấy Hưng Đạo Vương và Trần triều đã áp dụng một phư'
#               seg[0:60]='Ta nhận thấy Hưng_Đạo_Vương và Trần_triều đã áp_dụng một phư'
#               ids[:8]=[0, 1218, 5031, 4913, 129801, 454, 13347, 77248] | total_tokens=424
#       [TOKEN] id=019e5682… | raw[0:60]='Nhận thức rõ ràng chiến pháp và tình thế của địch, Hưng Đạo'
#               seg[0:60]='Nhận_thức rõ_ràng chiến_pháp và tình_thế của địch , Hưng_Đạo'
#               ids[:8]=[0, 115359, 454, 927, 48021, 15235, 454, 3139] | total_tokens=153
#       [TOKEN] id=019e5682… | raw[0:60]='Ngài lại đưa ra một bản hịch để hiệu triệu tướng sĩ nhân dân'
#               seg[0:60]='Ngài lại đưa ra một bản_hịch để hiệu triệu tướng_sĩ nhân_dân'
#               ids[:8]=[0, 101199, 1917, 15995, 673, 889, 5857, 454] | total_tokens=335
#       [TOKEN] id=019e5682… | raw[0:60]='Những người kia nếu chẳng liều, Chết xuông như đám nữ lưu xó'
#               seg[0:60]='Những người kia nếu chẳng liều , Chết_xuông như đám nữ lưu_x'
#               ids[:8]=[0, 13836, 1008, 19176, 11094, 28121, 96, 86630] | total_tokens=54
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW    9/28 | pages=[185, 186, 187, 188, 189] | chars=6,617
#       [STRUCT] 76 structural boundaries | book='Việt Sử Toàn Thư'
#     [MINI-CHUNK] window chars=6,617 → 91 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
# {"split_after_indices":[9,20,33,46,57,66,76,86]}
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=91 → splits=[4, 9, 14, 20, 25, 33, 38, 46, 51, 57, 66, 71, 76, 81, 86]
# llm trả về
#  [4, 9, 14, 20, 25, 33, 38, 46, 51, 57, 66, 71, 76, 81, 86]
#
#
#
#     [MERGE] 91 mini-chunks + 15 splits → 16 semantic groups
#       [TOKEN] id=019e5682… | raw[0:60]='Các ngươi dòng dõi vũ thần,Xưa nay nào có hiểu văn nghĩa gì.'
#               seg[0:60]='Các ngươi dòng dõi vũ_thần , Xưa_nay nào có hiểu văn_nghĩa g'
#               ids[:8]=[0, 9211, 22625, 42827, 86917, 72417, 454, 927] | total_tokens=239
#       [TOKEN] id=019e5682… | raw[0:60]='Điếu Ngư thằng bé tèo teo, Chống quân Mông Cổ ồn ào trăm muô'
#               seg[0:60]='Điếu Ngư_thằng bé tèo_teo , Chống quân Mông_Cổ ồn_ào trăm mu'
#               ids[:8]=[0, 114279, 63513, 9487, 11479, 454, 927, 114186] | total_tokens=268
#       [TOKEN] id=019e5682… | raw[0:60]='Ta với ngươi sinh vào đời loạn, Vừa gặp cơn vận hạn gian nan'
#               seg[0:60]='Ta với ngươi_sinh vào đời_loạn , Vừa gặp cơn vận_hạn gian_na'
#               ids[:8]=[0, 1218, 1116, 22625, 454, 1596, 127, 2249] | total_tokens=270
#       [TOKEN] id=019e5682… | raw[0:60]='Thịt nuôi hùm đói mãi a?\nSao cho thoát khỏi lo xa sau này?\nT'
#               seg[0:60]='Thịt nuôi hùm đói mãi_a ?_Sao cho thoát khỏi lo xa sau_này ?'
#               ids[:8]=[0, 39844, 18, 57017, 6, 117849, 39, 2275] | total_tokens=243
#       [TOKEN] id=019e5682… | raw[0:60]='Các ngươi vốn là người môn thuộc, Được trông nom mọi việc bi'
#               seg[0:60]='Các ngươi vốn là người môn thuộc , Được trông_nom mọi việc b'
#               ids[:8]=[0, 9211, 22625, 28550, 580, 1008, 37496, 16781] | total_tokens=196
#       [TOKEN] id=019e5682… | raw[0:60]='So Vương Kiên với Ngột Lang, Đãi chư tỳ tướng, mọi đường kém'
#               seg[0:60]='So Vương_Kiên với Ngột_Lang , Đãi_chư tỳ_tướng , mọi đường k'
#               ids[:8]=[0, 1061, 78435, 454, 19717, 1732, 1116, 9487] | total_tokens=302
#       [TOKEN] id=019e5682… | raw[0:60]='Đúng lúc có quân Mông Thát tới, Cựa gà không chọc nổi áo da.'
#               seg[0:60]='Đúng lúc có quân_Mông Thát tới , Cựa gà không chọc nổi áo da'
#               ids[:8]=[0, 4428, 971, 449, 10305, 524, 29225, 454] | total_tokens=175
#       [TOKEN] id=019e5682… | raw[0:60]='Chó săn đâu đủ sức khua giặc trời.\nRượu ngon khó làm mồi bả'
#               seg[0:60]='Chó săn đâu đủ sức khua giặc trời . Rượu ngon_khó làm mồi bả'
#               ids[:8]=[0, 3751, 849, 772, 19, 16922, 15221, 12641] | total_tokens=259
#       [TOKEN] id=019e5682… | raw[0:60]='Nhà các ngươi cũng đều mang tiếng, Không khỏi làm những tướn'
#               seg[0:60]='Nhà các ngươi cũng đều mang_tiếng , Không khỏi làm những tướ'
#               ids[:8]=[0, 19491, 925, 22625, 1943, 9338, 5219, 454] | total_tokens=326
#       [TOKEN] id=019e5682… | raw[0:60]='Tước ấp ta chăn thường ấm chỗ, Bổng lộc ngươi hưởng có trọn'
#               seg[0:60]='Tước ấp ta chăn thường ấm chỗ , Bổng lộc_ngươi hưởng có trọn'
#               ids[:8]=[0, 384, 68507, 6, 249999, 254, 308, 185344] | total_tokens=232
#       [TOKEN] id=019e5682… | raw[0:60]='Này binh pháp soạn theo đời trước, Là "Binh thư yếu lược" ba'
#               seg[0:60]='Này binh_pháp soạn theo đời trước , Là " Binh_thư yếu_lược "'
#               ids[:8]=[0, 6, 233997, 91756, 454, 11727, 50731, 154561] | total_tokens=256
#       [TOKEN] id=019e5682… | raw[0:60]='3- Mông Cổ Tấn Công Trên Các Mặt Trận Ngày mồng 6 tháng giên'
#               seg[0:60]='3 - Mông_Cổ_Tấn_Công Trên Các Mặt_Trận Ngày mồng 6 tháng_giê'
#               ids[:8]=[0, 138, 20, 276, 23366, 454, 441, 25091] | total_tokens=300
#       [TOKEN] id=019e5682… | raw[0:60]='Ngày 12 tháng giêng, giặc đến Kinh Bắc (Bắc Ninh) tàn phá cá'
#               seg[0:60]='Ngày 12 tháng_giêng , giặc đến Kinh_Bắc ( Bắc_Ninh ) tàn_phá'
#               ids[:8]=[0, 42812, 427, 7973, 454, 735, 28498, 6] | total_tokens=259
#       [TOKEN] id=019e5682… | raw[0:60]='Để đối phó với quân ta đóng giữ ở phía Nam ngạn sông Nhị Hà,'
#               seg[0:60]='Để đối_phó với quân ta đóng giữ ở phía Nam ngạn sông Nhị_Hà'
#               ids[:8]=[0, 32390, 5715, 454, 254, 34282, 1116, 29225] | total_tokens=302
#       [TOKEN] id=019e5682… | raw[0:60]='Châu châu đá xe rồi đây sẽ ra sao?" Khắc Chung trả lời: "Hi'
#               seg[0:60]='Châu châu_đá xe rồi_đây sẽ ra sao ? " Khắc_Chung trả_lời : "'
#               ids[:8]=[0, 62105, 67312, 454, 18643, 709, 4449, 6348] | total_tokens=298
#       [TOKEN] id=019e5682… | raw[0:60]='Khi về đến trại bên ta vào giờ Mão ngày 13 tháng giêng. Giặ'
#               seg[0:60]='Khi về đến trại bên ta vào giờ Mão ngày 13 tháng_giêng . Giặ'
#               ids[:8]=[0, 16584, 1893, 1885, 168214, 7669, 308, 2249] | total_tokens=191
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW   10/28 | pages=[189, 190, 191, 192] | chars=8,246
#       [STRUCT] 24 structural boundaries | book='Việt Sử Toàn Thư'
#     [MINI-CHUNK] window chars=8,246 → 75 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
# {"split_after_indices":[7,14,19,25,31,34,41,46,54,60,65,70]}
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=75 → splits=[7, 14, 19, 25, 31, 34, 41, 46, 54, 60, 65, 70]
# llm trả về
#  [7, 14, 19, 25, 31, 34, 41, 46, 54, 60, 65, 70]
#
#
#
#     [MERGE] 75 mini-chunks + 12 splits → 13 semantic groups
#       [TOKEN] id=019e5682… | raw[0:60]='Mặt Trận Đông Nam Hưng Đạo Vương chuyển quân chủ lực về Thiê'
#               seg[0:60]='Mặt_Trận Đông_Nam_Hưng_Đạo_Vương chuyển_quân chủ_lực về Thiê'
#               ids[:8]=[0, 109699, 454, 55487, 69421, 35116, 454, 124197] | total_tokens=447
#       [TOKEN] id=019e5682… | raw[0:60]='Ngày mồng một tháng hai năm Ất Dậu (1285) bọn Trần Kiện, Lê'
#               seg[0:60]='Ngày mồng một tháng hai năm Ất_Dậu ( 1285 ) bọn Trần_Kiện ,'
#               ids[:8]=[0, 42812, 347, 32773, 889, 7973, 1337, 2933] | total_tokens=399
#       [TOKEN] id=019e5682… | raw[0:60]='Để hòa hoãn trong khi tình thế quá cấp bách và đen tối, vua'
#               seg[0:60]='Để hòa_hoãn trong khi tình_thế quá cấp_bách và đen_tối , vua'
#               ids[:8]=[0, 32390, 37294, 454, 497, 6073, 19, 1000] | total_tokens=197
#       [TOKEN] id=019e5682… | raw[0:60]='Bảo Nghĩa vương Trần Bình Trọng đóng ở Thiên Trường, ngày 21'
#               seg[0:60]='Bảo_Nghĩa vương_Trần_Bình_Trọng_đóng ở Thiên_Trường , ngày 2'
#               ids[:8]=[0, 46585, 454, 839, 9486, 32606, 11, 161105] | total_tokens=296
#       [TOKEN] id=019e5682… | raw[0:60]='Mồng 9 tháng ba, bọn Giảo Kỳ và Đường Cổ Đới đem chu sư (thu'
#               seg[0:60]='Mồng 9 tháng ba , bọn Giảo_Kỳ và Đường_Cổ_Đới đem chu_sư ( t'
#               ids[:8]=[0, 276, 32773, 483, 7973, 961, 6, 4] | total_tokens=422
#       [TOKEN] id=019e5682… | raw[0:60]='Ngày 15 tháng ba, bọn Chiêu Quốc vương Trần Ích Tắc (con thứ'
#               seg[0:60]='Ngày 15 tháng ba , bọn Chiêu_Quốc_vương Trần_Ích_Tắc ( con t'
#               ids[:8]=[0, 42812, 423, 7973, 961, 6, 4, 47772] | total_tokens=205
#       [TOKEN] id=019e5682… | raw[0:60]='Toa Đô thắng trận dễ dàng từ Nghệ An ra Thanh Hóa mở cuộc ch'
#               seg[0:60]='Toa Đô_thắng trận dễ_dàng từ Nghệ_An ra Thanh_Hóa mở cuộc ch'
#               ids[:8]=[0, 717, 11, 130716, 454, 927, 249990, 449] | total_tokens=331
#       [TOKEN] id=019e5682… | raw[0:60]='Cuộc Tổng Phản Công Của Việt Nam Từ tháng tư khí hậu của miề'
#               seg[0:60]='Cuộc Tổng_Phản_Công_Của Việt_Nam Từ tháng tư khí_hậu của miề'
#               ids[:8]=[0, 121833, 25481, 454, 45689, 17195, 19, 454] | total_tokens=292
#       [TOKEN] id=019e5682… | raw[0:60]='Dưới sức nóng "cháy mây hun đá" cuộc phản công bắt đầu. Về p'
#               seg[0:60]='Dưới sức nóng " cháy mây hun_đá " cuộc phản_công bắt_đầu . V'
#               ids[:8]=[0, 194823, 12641, 50541, 44, 84634, 57695, 53] | total_tokens=435
#       [TOKEN] id=019e5682… | raw[0:60]='Chiêu Văn Vương Trần Nhật Duật được cử làm tướng, Hoài Văn'
#               seg[0:60]='Chiêu_Văn_Vương Trần_Nhật_Duật được cử làm tướng , Hoài_Văn_'
#               ids[:8]=[0, 3751, 56540, 454, 856, 451, 19, 454] | total_tokens=409
#       [TOKEN] id=019e5682… | raw[0:60]='Hai vua Trần và Hưng Đạo Vương lúc này đang đóng bộ tham mưu'
#               seg[0:60]='Hai vua Trần_và Hưng_Đạo_Vương lúc này đang đóng_bộ tham_mưu'
#               ids[:8]=[0, 4368, 86729, 42974, 454, 334, 1298, 129801] | total_tokens=317
#       [TOKEN] id=019e5682… | raw[0:60]='Quân Ta Thu Phục Được Thăng Long Lúc này lục quân của Thoát'
#               seg[0:60]='Quân Ta_Thu Phục_Được Thăng_Long Lúc này lục_quân của Thoát'
#               ids[:8]=[0, 101390, 1218, 454, 20800, 34, 70487, 238] | total_tokens=298
#       [TOKEN] id=019e5682… | raw[0:60]='Quân ta đổ bộ đuổi quân Nguyên về tới thành Thăng Long (tín'
#               seg[0:60]='Quân ta đổ_bộ đuổi quân_Nguyên về tới thành Thăng_Long ( tín'
#               ids[:8]=[0, 101390, 308, 85428, 454, 275, 27350, 142926] | total_tokens=179
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW   11/28 | pages=[192, 193, 194, 195] | chars=7,231
#       [STRUCT] 23 structural boundaries | book='Việt Sử Toàn Thư'
#     [MINI-CHUNK] window chars=7,231 → 70 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
# {"split_after_indices":[6,13,19,27,33,44,48,55,63]}
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=70 → splits=[6, 13, 19, 27, 33, 38, 44, 48, 55, 63]
# llm trả về
#  [6, 13, 19, 27, 33, 38, 44, 48, 55, 63]
#
#
#
#     [MERGE] 70 mini-chunks + 10 splits → 11 semantic groups
#       [TOKEN] id=019e5682… | raw[0:60]='Việc khắc phục thành Thăng Long tức là việc thắng trận Chươn'
#               seg[0:60]='Việc khắc_phục thành Thăng_Long tức_là việc thắng trận Chươn'
#               ids[:8]=[0, 57253, 54403, 454, 11727, 66223, 2781, 6003] | total_tokens=324
# ...
#               seg[0:60]='Căn_cứ vào lời Mộc_Thạnh bàn với Trương_Phụ thì quân_Minh bấ'
#               ids[:8]=[0, 115760, 454, 238, 30342, 2249, 11178, 276] | total_tokens=273
#       [TOKEN] id=019e5683… | raw[0:60]='Thành Đa Bang Thất Thủ Thành Đa Bang đáng kể là kiên cố do t'
#               seg[0:60]='Thành Đa_Bang Thất_Thủ_Thành Đa_Bang đáng_kể là kiên_cố do t'
#               ids[:8]=[0, 22049, 83746, 454, 571, 1463, 6003, 249999] | total_tokens=272
#       [TOKEN] id=019e5683… | raw[0:60]='Quân Minh đánh ào ạt vào thành, quân nhà Hồ chịu không nổi'
#               seg[0:60]='Quân_Minh đánh ào_ạt vào thành , quân nhà Hồ_chịu không nổi_'
#               ids[:8]=[0, 101390, 454, 59076, 127, 13868, 253, 31] | total_tokens=331
#       [TOKEN] id=019e5683… | raw[0:60]='Trận Mộc Phàm Giang Cuộc bại trận của nhà Hồ từ Sơn Tây về T'
#               seg[0:60]='Trận Mộc_Phàm_Giang Cuộc bại_trận của nhà_Hồ từ Sơn_Tây về T'
#               ids[:8]=[0, 5454, 69421, 276, 81373, 454, 683, 64509] | total_tokens=280
#       [TOKEN] id=019e5683… | raw[0:60]='Tại bến Bình Than (huyện Chí Linh, tỉnh Hải Dương), hai bên'
#               seg[0:60]='Tại bến Bình_Than ( huyện Chí_Linh , tỉnh Hải_Dương ) , hai'
#               ids[:8]=[0, 44100, 200663, 19, 20515, 454, 618, 1121] | total_tokens=370
#       [TOKEN] id=019e5683… | raw[0:60]='Trận Hàm Tử Quan Lực lượng thủy lục của quân Hồ bấy giờ có t'
#               seg[0:60]='Trận Hàm_Tử_Quan Lực_lượng thủy_lục của quân_Hồ bấy_giờ có t'
#               ids[:8]=[0, 5454, 69421, 8548, 39, 454, 618, 46535] | total_tokens=368
#       [TOKEN] id=019e5683… | raw[0:60]='Sau trận này, đại quân của nhà Hồ tan rã gần hết. An phủ sứ'
#               seg[0:60]='Sau trận này , đại_quân của nhà Hồ_tan_rã gần hết . An_phủ s'
#               ids[:8]=[0, 6987, 48581, 1617, 6, 4, 7899, 454] | total_tokens=250
#       [TOKEN] id=019e5683… | raw[0:60]='Tháng 5 năm ấy (1407), Quý Ly và Hán Thương đến cửa Kỳ La ('
#               seg[0:60]='Tháng 5 năm ấy ( 1407 ) , Quý_Ly và Hán_Thương đến cửa Kỳ_La'
#               ids[:8]=[0, 77833, 190, 2933, 14112, 15, 616, 8368] | total_tokens=257
#       [TOKEN] id=019e5683… | raw[0:60]='Tương truyền ngày xưa vua Hùng Vương đi chơi qua đấy nghe t'
#               seg[0:60]='Tương_truyền ngày_xưa vua Hùng_Vương đi chơi qua đấy nghe ti'
#               ids[:8]=[0, 384, 43672, 454, 9774, 53, 32809, 19] | total_tokens=319
#       [TOKEN] id=019e5683… | raw[0:60]='Bọn Trần Nhật Chiêu, Nguyễn Phi Khanh, Nguyễn Cẩn, Đỗ Mãn đã'
#               seg[0:60]='Bọn Trần_Nhật_Chiêu , Nguyễn_Phi_Khanh , Nguyễn_Cẩn , Đỗ_Mãn'
#               ids[:8]=[0, 335, 19030, 19, 42974, 454, 839, 127] | total_tokens=375
#       [TOKEN] id=019e5683… | raw[0:60]='- Giết vua cướp nước có phải là đạo bề tôi không?\nQuý Ly khô'
#               seg[0:60]='- Giết vua cướp nước có phải là đạo_bề tôi không ?_Quý_Ly kh'
#               ids[:8]=[0, 20, 5174, 27106, 86729, 182174, 3042, 524] | total_tokens=189
#       [TOKEN] id=019e5683… | raw[0:60]='Cũng khoảng tháng sáu, bình định xong nước Việt, người Minh'
#               seg[0:60]='Cũng khoảng tháng sáu , bình_định xong nước Việt , người Min'
#               ids[:8]=[0, 6, 105728, 22567, 7973, 151871, 6, 4] | total_tokens=414
#       [TOKEN] id=019e5683… | raw[0:60]='Vì đâu họ Hồ đã đi tới cái kết quả bi đát đó? Các vua chúa m'
#               seg[0:60]='Vì đâu họ Hồ đã đi tới cái kết_quả bi_đát đó ?_Các vua_chúa'
#               ids[:8]=[0, 32061, 16922, 7424, 21433, 1408, 2467, 7067] | total_tokens=172
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW   26/28 | pages=[239, 240, 241, 242] | chars=8,424
#       [STRUCT] 22 structural boundaries | book='Việt Sử Toàn Thư'
#     [MINI-CHUNK] window chars=8,424 → 80 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
# {"split_after_indices":[4,8,12,20,25,30,38,44,54,61,72]}
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=80 → splits=[4, 8, 12, 20, 25, 30, 38, 44, 49, 54, 61, 66, 72]
# llm trả về
#  [4, 8, 12, 20, 25, 30, 38, 44, 49, 54, 61, 66, 72]
#
#
#
#     [MERGE] 80 mini-chunks + 13 splits → 14 semantic groups
#       [TOKEN] id=019e5683… | raw[0:60]='1) Họ Hồ đã tiến quá nhanh trên con đường danh vọng, quyền t'
#               seg[0:60]='1 ) Họ Hồ đã tiến quá nhanh trên con đường danh_vọng , quyền'
#               ids[:8]=[0, 106, 1388, 61428, 21433, 1408, 19743, 6526] | total_tokens=361
#       [TOKEN] id=019e5683… | raw[0:60]='2) Việc cải cách tăng đạo cũng có tính cách hạn chế ảnh hưởn'
#               seg[0:60]='2 ) Việc cải_cách tăng đạo cũng có tính_cách hạn_chế ảnh_hưở'
#               ids[:8]=[0, 116, 1388, 57253, 49734, 454, 238, 5687] | total_tokens=265
#       [TOKEN] id=019e5683… | raw[0:60]='4) Việc giết hại con cháu nhà Trần, nhất là vua Thuận Thông,'
#               seg[0:60]='4 ) Việc giết_hại con_cháu nhà Trần , nhất_là vua Thuận_Thôn'
#               ids[:8]=[0, 201, 1388, 57253, 86730, 454, 127, 12976] | total_tokens=251
#       [TOKEN] id=019e5683… | raw[0:60]='Nhân dân vào đời Lý, Trần lại đang được hun đúc trong cái l'
#               seg[0:60]='Nhân_dân vào đời Lý , Trần_lại đang được hun_đúc trong cái l'
#               ids[:8]=[0, 56025, 454, 71, 7453, 2249, 16774, 44980] | total_tokens=439
#       [TOKEN] id=019e5683… | raw[0:60]='Bàn về việc đàn áp phong kiến đời bấy giờ, ta nghĩ thế nào v'
#               seg[0:60]='Bàn về_việc đàn_áp phong_kiến đời bấy_giờ , ta nghĩ thế_nào'
#               ids[:8]=[0, 39914, 19, 1893, 454, 686, 21018, 238] | total_tokens=284
#       [TOKEN] id=019e5683… | raw[0:60]='Nói một cách khác, xã hội Việt Nam bấy giờ đang bị một bạo b'
#               seg[0:60]='Nói một_cách khác , xã_hội Việt_Nam bấy_giờ đang bị một bạo_'
#               ids[:8]=[0, 94230, 889, 454, 238, 5687, 4546, 6] | total_tokens=268
#       [TOKEN] id=019e5683… | raw[0:60]='Hồ Quý Ly Có Làm Mất Nước Không?\nBình luận về Hồ Quý Ly, Trầ'
#               seg[0:60]='Hồ_Quý_Ly_Có Làm Mất_Nước Không ? Bình_luận về Hồ_Quý_Ly , T'
#               ids[:8]=[0, 21433, 454, 31583, 1673, 454, 133011, 454] | total_tokens=317
#       [TOKEN] id=019e5683… | raw[0:60]='Nhưng đấy là một cái tội làm hại riêng cho một họ Hồ mà thôi'
#               seg[0:60]='Nhưng đấy là một cái tội làm hại riêng cho một họ Hồ mà thôi'
#               ids[:8]=[0, 19751, 32492, 580, 889, 5472, 51305, 1839] | total_tokens=316
#       [TOKEN] id=019e5683… | raw[0:60]='Câu hỏi trên nhắc ta rằng khi nhà Hồ ra đời, Minh Thành Tổ đ'
#               seg[0:60]='Câu_hỏi trên nhắc ta rằng khi nhà_Hồ ra_đời , Minh_Thành_Tổ'
#               ids[:8]=[0, 81000, 454, 127, 28494, 14, 2479, 85880] | total_tokens=311
#       [TOKEN] id=019e5683… | raw[0:60]='Một việc xâm lăng bao giờ cũng phải tính toán đầy đủ điều k'
#               seg[0:60]='Một việc xâm_lăng bao_giờ cũng phải tính_toán đầy_đủ điều_ki'
#               ids[:8]=[0, 14921, 2735, 154614, 454, 141, 44473, 8609] | total_tokens=260
#       [TOKEN] id=019e5683… | raw[0:60]='Có thể nhà Minh hiểu thực lực nước ta bị suy giảm từ lâu, l'
#               seg[0:60]='Có_thể nhà_Minh hiểu thực_lực nước ta bị suy_giảm từ lâu , l'
#               ids[:8]=[0, 11302, 454, 927, 35895, 2455, 454, 59076] | total_tokens=357
#       [TOKEN] id=019e5683… | raw[0:60]='Trong Nam Sử Liệt Truyện khảo cứu ở Tạp chí Nam Phong số 10'
#               seg[0:60]='Trong Nam_Sử_Liệt Truyện_khảo_cứu ở Tạp_chí Nam_Phong số 100'
#               ids[:8]=[0, 12818, 2096, 454, 294, 46535, 454, 9506] | total_tokens=269
#       [TOKEN] id=019e5683… | raw[0:60]='"Tư tưởng và hành vi của nhà độc tài ấy có thể sánh với Vươn'
#               seg[0:60]='" Tư_tưởng và hành_vi của nhà độc_tài ấy có_thể sánh với Vươ'
#               ids[:8]=[0, 44, 35191, 454, 18, 103593, 544, 4893] | total_tokens=312
#       [TOKEN] id=019e5683… | raw[0:60]='" Tin Mới số 1406 ra ngày 31-10-1944, trong bài Đọc Sử ông T'
#               seg[0:60]='" Tin_Mới số 1406 ra ngày 31-10-1944 , trong bài Đọc Sử ông'
#               ids[:8]=[0, 44, 8081, 454, 594, 81397, 3030, 616] | total_tokens=270
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW   27/28 | pages=[242, 243, 244, 245, 246] | chars=8,586
#       [STRUCT] 24 structural boundaries | book='Việt Sử Toàn Thư'
#     [MINI-CHUNK] window chars=8,586 → 77 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
# {"split_after_indices":[2,10,16,22,26,34,46,50,57,63,72]}
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=77 → splits=[2, 10, 16, 22, 26, 34, 39, 46, 50, 57, 63, 72]
# llm trả về
#  [2, 10, 16, 22, 26, 34, 39, 46, 50, 57, 63, 72]
#
#
#
#     [MERGE] 77 mini-chunks + 12 splits → 13 semantic groups
#       [TOKEN] id=019e5683… | raw[0:60]='"Nhưng đem reo rắc vào một đám dân chúng chưa giác ngộ, nhữn'
#               seg[0:60]='" Nhưng đem reo_rắc vào một đám dân_chúng chưa giác_ngộ , nh'
#               ids[:8]=[0, 44, 19751, 42070, 456, 31, 454, 42] | total_tokens=156
#       [TOKEN] id=019e5683… | raw[0:60]='Phần 3 - Chương 9 Bắc Thuộc Lần Thứ Năm Nhà Hậu Trần (1407-1'
#               seg[0:60]='Phần 3 - Chương 9 Bắc_Thuộc Lần Thứ Năm_Nhà Hậu_Trần ( 1407'
#               ids[:8]=[0, 82666, 138, 20, 40691, 483, 38262, 454] | total_tokens=411
#       [TOKEN] id=019e5683… | raw[0:60]='Giờ đây, họ dùng hai thủ đoạn chính trị:\n1) Họ treo bảng kêu'
#               seg[0:60]='Giờ_đây , họ dùng hai thủ_đoạn chính_trị : 1 ) Họ treo bảng'
#               ids[:8]=[0, 192386, 454, 18643, 38746, 6, 4, 7424] | total_tokens=272
#       [TOKEN] id=019e5683… | raw[0:60]='Đây là hai hành động mâu thuẫn nhau. Bằng việc trên, thực dâ'
#               seg[0:60]='Đây là hai hành_động mâu_thuẫn nhau . Bằng việc trên , thực_'
#               ids[:8]=[0, 37540, 580, 1337, 4893, 454, 18643, 27350] | total_tokens=405
#       [TOKEN] id=019e5683… | raw[0:60]='Ở những nơi trọng yếu, họ đặt 12 vệ tức là 12 đạo quân binh'
#               seg[0:60]='Ở những nơi trọng_yếu , họ đặt 12 vệ tức_là 12 đạo quân_binh'
#               ids[:8]=[0, 71717, 1358, 13426, 9899, 454, 53, 63513] | total_tokens=231
#       [TOKEN] id=019e5683… | raw[0:60]='Bộ máy hành chính và quân sự bắt đầu quay thì người Minh đã'
#               seg[0:60]='Bộ_máy hành_chính và quân_sự bắt_đầu quay thì người_Minh đã'
#               ids[:8]=[0, 13843, 454, 12003, 53, 4893, 454, 206] | total_tokens=421
#       [TOKEN] id=019e5683… | raw[0:60]='Lữ Nghị và Hoàng Phúc được đặc ủy mọi việc quân chính sau đó'
#               seg[0:60]='Lữ_Nghị và Hoàng_Phúc được đặc_ủy mọi việc quân_chính sau đó'
#               ids[:8]=[0, 339, 42451, 454, 839, 9486, 51721, 544] | total_tokens=337
#       [TOKEN] id=019e5683… | raw[0:60]='Hưng Thực Lục của vua Trần Nhân Tông (2 quyển)11) Thi Tập (1'
#               seg[0:60]='Hưng Thực_Lục của vua Trần_Nhân_Tông ( 2 quyển ) 11 ) Thi_Tậ'
#               ids[:8]=[0, 129801, 59747, 454, 866, 66223, 550, 86729] | total_tokens=512
#       [TOKEN] id=019e5683… | raw[0:60]='các triều đại trước trong 10 thế kỷ đô hộ xưa, họ rất lưu tâ'
#               seg[0:60]='các triều_đại trước trong 10 thế_kỷ đô_hộ xưa , họ rất lưu_t'
#               ids[:8]=[0, 925, 221089, 454, 18643, 12976, 14, 5179] | total_tokens=229
#       [TOKEN] id=019e5683… | raw[0:60]='Sau việc gột rửa cái tinh thần cố hữu là căn bản của mọi cá'
#               seg[0:60]='Sau việc gột_rửa cái tinh_thần cố_hữu là căn_bản của mọi cá_'
#               ids[:8]=[0, 6987, 2735, 706, 89058, 454, 42, 46535] | total_tokens=366
#       [TOKEN] id=019e5683… | raw[0:60]='Tại Vân Đồn, họ đặt một cơ sở kiếm hạt trai. Mỗi ngày hàng n'
#               seg[0:60]='Tại Vân_Đồn , họ đặt một cơ_sở kiếm hạt trai . Mỗi ngày hàng'
#               ids[:8]=[0, 44100, 64263, 454, 13347, 51635, 6, 4] | total_tokens=322
#       [TOKEN] id=019e5683… | raw[0:60]='Về việc cai trị, các đơn vị hành chính được đặt ra như sau:'
#               seg[0:60]='Về việc cai_trị , các đơn_vị hành_chính được đặt ra như sau'
#               ids[:8]=[0, 66863, 2735, 39755, 454, 4448, 51721, 6] | total_tokens=479
#       [TOKEN] id=019e5683… | raw[0:60]='Chính sách đô hộ kể đã chu đáo và việc bóc lột nhân dân đến'
#               seg[0:60]='Chính_sách đô_hộ kể đã chu_đáo và việc bóc_lột nhân_dân đến'
#               ids[:8]=[0, 17654, 454, 7, 5687, 29349, 454, 127] | total_tokens=187
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW   28/28 | pages=[246, 247, 248, 249] | chars=9,089
#       [STRUCT] 20 structural boundaries | book='Việt Sử Toàn Thư'
#     [MINI-CHUNK] window chars=9,089 → 82 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
# {"split_after_indices":[8,16,24,33,41,46,52,59,65,72]}
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=82 → splits=[8, 16, 24, 33, 41, 46, 52, 59, 65, 72]
# llm trả về
#  [8, 16, 24, 33, 41, 46, 52, 59, 65, 72]
#
#
#
#     [MERGE] 82 mini-chunks + 10 splits → 11 semantic groups
#       [TOKEN] id=019e5683… | raw[0:60]='Nhân dân đau khổ hết chỗ nói nhất là với bọn Lý Bân, Mã Kỳ đ'
#               seg[0:60]='Nhân_dân đau_khổ hết chỗ nói nhất_là với bọn Lý_Bân , Mã_Kỳ'
#               ids[:8]=[0, 56025, 454, 71, 7453, 24859, 454, 10684] | total_tokens=407
#       [TOKEN] id=019e5683… | raw[0:60]='Phong trào khởi nghĩa không thắng lợi buổi đầu vì thực lực c'
#               seg[0:60]='Phong_trào khởi_nghĩa không thắng_lợi buổi đầu vì thực_lực c'
#               ids[:8]=[0, 55110, 454, 18, 3139, 31, 58403, 454] | total_tokens=490
#       [TOKEN] id=019e5683… | raw[0:60]='Xét tình thế có thể nghiêm trọng, bọn quan lại nhà Minh gửi'
#               seg[0:60]='Xét tình_thế có_thể nghiêm_trọng , bọn quan_lại nhà_Minh gửi'
#               ids[:8]=[0, 1193, 2305, 6066, 454, 18, 132892, 524] | total_tokens=459
#       [TOKEN] id=019e5683… | raw[0:60]='3- Trần Quý Khoách Nối Tiếp Cuộc Cách Mạng (1409-1413) Sự vụ'
#               seg[0:60]='3 - Trần_Quý_Khoách Nối_Tiếp_Cuộc Cách_Mạng ( 1409 - 1413 )'
#               ids[:8]=[0, 138, 20, 42974, 454, 31583, 1673, 454] | total_tokens=416
#       [TOKEN] id=019e5683… | raw[0:60]='Được tin Mộc Thạnh thua trận, quân cách mạng đang đánh mạnh,'
#               seg[0:60]='Được tin Mộc_Thạnh thua_trận , quân cách_mạng đang đánh mạnh'
#               ids[:8]=[0, 74409, 2478, 276, 81373, 454, 20800, 109811] | total_tokens=401
#       [TOKEN] id=019e5683… | raw[0:60]='Do cuộc bại trận của phái phong kiến mà nhân dân thêm một ph'
#               seg[0:60]='Do cuộc bại_trận của phái phong_kiến mà nhân_dân thêm một ph'
#               ids[:8]=[0, 984, 9568, 119407, 454, 4448, 69421, 550] | total_tokens=271
#       [TOKEN] id=019e5683… | raw[0:60]='Năm sau (Canh Dần 1410), quân Kháng chiến lại tiến đánh Hồng'
#               seg[0:60]='Năm sau ( Canh_Dần 1410 ) , quân Kháng_chiến lại tiến đánh H'
#               ids[:8]=[0, 65832, 858, 15, 4171, 127, 454, 397] | total_tokens=351
#       [TOKEN] id=019e5683… | raw[0:60]='Quý Khoách mấy phen cho người sang Tàu cầu phong với Minh Đế'
#               seg[0:60]='Quý_Khoách mấy phen cho người sang Tàu cầu_phong với Minh_Đế'
#               ids[:8]=[0, 78309, 454, 605, 497, 5687, 34794, 6] | total_tokens=383
#       [TOKEN] id=019e5683… | raw[0:60]='Mặc dầu Mộc Thạnh cản ngăn rằng Hóa Châu hiểm trở vì núi ca'
#               seg[0:60]='Mặc_dầu Mộc_Thạnh_cản ngăn rằng Hóa_Châu hiểm_trở vì núi cao'
#               ids[:8]=[0, 105167, 454, 71, 249994, 34, 276, 81373] | total_tokens=293
#       [TOKEN] id=019e5683… | raw[0:60]='Để kỷ niệm họ Đặng có lòng trung quân ái quốc, nhân dân có đ'
#               seg[0:60]='Để kỷ_niệm họ Đặng_có lòng trung_quân ái_quốc , nhân_dân có'
#               ids[:8]=[0, 32390, 50009, 454, 19, 120050, 7424, 4428] | total_tokens=381
#       [TOKEN] id=019e5683… | raw[0:60]='Ngoài ra, nhân dân Việt Nam đã ủng hộ cuộc kháng chiến của h'
#               seg[0:60]='Ngoài_ra , nhân_dân Việt_Nam đã ủng_hộ cuộc kháng_chiến của'
#               ids[:8]=[0, 46158, 454, 219, 6, 4, 3090, 454] | total_tokens=398
#
# [SAVE] Writing 372 points → 'full_VietSu_data_qdrant_points_512.json'…
# [SAVE] Done. 1101.9 KB written.

# %% [markdown]
# # Run Vương Trều Trần

# %%
# @title

import os
from google.colab import userdata


# JSON_PATH = "full_DVSK_data.json"           # Đại Việt Sử Ký Toàn Thư
# JSON_PATH = "full_KhamDinh_data.json"        # Khâm Định Việt Sử Thông Giám Cương Mục
# JSON_PATH = "full_VietSu_data.json"                 # Việt Sử Toàn Thư
JSON_PATH = "full_VTT_data.json"                  # Vương Triều Trần
# JSON_PATH = "full_test.json"
# JSON_PATH = "full_test_VTT.json"


OUTPUT_PATH = JSON_PATH.replace(".json", f"_qdrant_points_{CHUNK_CONTEXT_LENGTH}.json")


def _load_key(colab_secret: str, env_var: str) -> str:
    try:
        from google.colab import userdata as _ud
        val = _ud.get(colab_secret)
        if val:
            print(f"[KEY] '{colab_secret}' loaded from Colab Secrets.")
            return val
    except Exception:
        pass
    val = os.environ.get(env_var, "")
    if val:
        print(f"[KEY] '{env_var}' loaded from environment variable.")
    return val

GROQ_API_KEY   = _load_key("grok_key",  "grok_key")
GEMINI_API_KEY = _load_key("GEMINI_API_KEY", "GEMINI_API_KEY")

if not GROQ_API_KEY and not GEMINI_API_KEY:
    print("[KEY] ⚠  No API keys found. "
          "Add GROQ_API_KEY and/or GOOGLE_API_KEY to Colab Secrets.")


LLM_BACKENDS:       list[LLMBackend]                  = []

# if GROQ_API_KEY:
#     LLM_BACKENDS.append(GroqBackend(GROQ_API_KEY, GROQ_MODEL_LLAMA_70B))
#     LLM_BACKENDS.append(GroqBackend(GROQ_API_KEY, GROQ_MODEL_LLAMA_8B))
#     LLM_BACKENDS.append(GroqBackend(GROQ_API_KEY, GROQ_MODEL_QWEN))

if GEMINI_API_KEY:
    try:
        LLM_BACKENDS.append(GeminiBackend(GEMINI_API_KEY, GEMINI_MODEL_ID))
        print(f"[INIT] GeminiBackend added: {GEMINI_MODEL_ID}")
    except Exception as exc:
        print(f"[INIT] GeminiBackend skipped ({type(exc).__name__}: {exc})")


if not LLM_BACKENDS:
    raise RuntimeError(
        "LLM_BACKENDS is empty. Provide GROQ_API_KEY and/or GEMINI_API_KEY."
    )


print(f"[INIT] Sync LLM chain ready ({len(LLM_BACKENDS)} backend(s)):")
for i, backend in enumerate(LLM_BACKENDS, start=1):
    print(f"   [{i}] {backend.label}")

print()

# Load input JSON
print(f"[LOAD] Reading '{JSON_PATH}'…")

with open(JSON_PATH, "r", encoding="utf-8") as fh:
    input_data: dict = json.load(fh)


assert "book_name" in input_data, "Missing key: book_name"
assert "full_text" in input_data, "Missing key: full_text"
assert "page_footnotes_map" in input_data, "Missing key: page_footnotes_map"

assert isinstance(input_data["book_name"], str), "book_name must be str"
assert isinstance(input_data["full_text"], str), "full_text must be str"
assert isinstance(input_data["page_footnotes_map"], dict), "page_footnotes_map must be dict"

print("[LOAD] Input validation passed ✓")


# Run pipeline
qdrant_points: list[dict] = run_pipeline(
    input_data,
    backends=LLM_BACKENDS,
)


# Save local output
print(f"\n[SAVE] Writing {len(qdrant_points):,} points → '{OUTPUT_PATH}'…")

with open(OUTPUT_PATH, "w", encoding="utf-8") as fh:
    json.dump(qdrant_points, fh, ensure_ascii=False, indent=2)

kb = os.path.getsize(OUTPUT_PATH) / 1024
print(f"[SAVE] Done. {kb:.1f} KB written.")
# Out:
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
#       [TOKEN] id=019e568a… | raw[0:60]='Như thế có thể thấy, ruộng của nhà chùa chiếm số lượng khá l'
#               seg[0:60]='Như_thế có_thể thấy , ruộng của nhà_chùa chiếm số_lượng khá'
#               ids[:8]=[0, 58737, 454, 18, 132892, 524, 454, 927] | total_tokens=193
#       [TOKEN] id=019e568a… | raw[0:60]='Vì vậy, đến năm 1396, triều đình xuống chiếu ra lệnh thải bớ'
#               seg[0:60]='Vì_vậy , đến năm 1396 , triều_đình xuống chiếu ra_lệnh thải'
#               ids[:8]=[0, 32061, 454, 334, 118806, 6, 4, 1885] | total_tokens=367
#       [TOKEN] id=019e568a… | raw[0:60]='Vào nửa cuối thế kỷ XTV, sự tiến triển của ruộng tư và sự ph'
#               seg[0:60]='Vào nửa cuối thế_kỷ XTV , sự tiến_triển của ruộng_tư và sự p'
#               ids[:8]=[0, 23598, 31, 80537, 25939, 3061, 454, 92] | total_tokens=465
#       [TOKEN] id=019e568a… | raw[0:60]='1. [1]. [3]. Phân phong ruộng đất Ruộng đất công làng xã dùn'
#               seg[0:60]='1 . . . Phân_phong ruộng_đất Ruộng_đất công làng_xã dùng để'
#               ids[:8]=[0, 106, 6, 5, 6, 5, 6, 5] | total_tokens=293
#       [TOKEN] id=019e568a… | raw[0:60]='Sử cũ không cho chúng ta biết số liệu ruộng đất cụ thể mà t'
#               seg[0:60]='Sử cũ không cho chúng_ta biết số_liệu ruộng_đất cụ_thể mà tr'
#               ids[:8]=[0, 63034, 56667, 687, 681, 4006, 454, 102] | total_tokens=433
#       [TOKEN] id=019e568a… | raw[0:60]='Kết hợp các nguồn tư hệu, chúng tôi thống kê được 15 thái ấ'
#               seg[0:60]='Kết_hợp các nguồn tư_hệu , chúng_tôi thống_kê được 15 thái ấ'
#               ids[:8]=[0, 77577, 454, 127, 30599, 254, 925, 24557] | total_tokens=313
#       [TOKEN] id=019e568a… | raw[0:60]='Tư liệu địa phương cho biết, đền thờ Trần Quốc Chẩn ở xã Vă'
#               seg[0:60]='Tư_liệu địa_phương cho biết , đền thờ Trần_Quốc_Chẩn ở xã Vă'
#               ids[:8]=[0, 35191, 454, 141, 100345, 11800, 454, 11727] | total_tokens=345
#       [TOKEN] id=019e568a… | raw[0:60]='4. Ở Chí Lảnh cồn có thái ấp của Trần Phó Duyệt. Đại Việt sử'
#               seg[0:60]='4 . Ở Chí_Lảnh cồn có thái_ấp của Trần_Phó_Duyệt . Đại_Việt_'
#               ids[:8]=[0, 201, 6, 5, 71717, 33872, 454, 866] | total_tokens=157
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW   66/152 | pages=[332, 333, 334, 335, 336, 337] | chars=7,134
#       [STRUCT] 28 structural boundaries | book='Vương Triều Trần (1226-1400)'
#     [MINI-CHUNK] window chars=7,134 → 70 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
# {"split_after_indices":[4,8,15,18,25,28,38,42,51,59,65]}
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=70 → splits=[4, 8, 15, 18, 25, 28, 33, 38, 42, 51, 59, 65]
# llm trả về
#  [4, 8, 15, 18, 25, 28, 33, 38, 42, 51, 59, 65]
#
#
#
#     [MERGE] 70 mini-chunks + 12 splits → 13 semantic groups
#       [TOKEN] id=019e568a… | raw[0:60]='6. Thái ấp của Trần Khắc Chung ở huyện Đông Triểều, tỉnhQuản'
#               seg[0:60]='6 . Thái_ấp của Trần_Khắc_Chung ở huyện Đông_Triểều , tỉnhQu'
#               ids[:8]=[0, 305, 6, 5, 37347, 454, 249999, 254] | total_tokens=340
#       [TOKEN] id=019e568a… | raw[0:60]='7. Thanh Hóa, thái ấp của Chiêu Văn vương Trần Nhật Duật.\n8.'
#               seg[0:60]='7 . Thanh_Hóa , thái_ấp của Chiêu_Văn_vương Trần_Nhật_Duật .'
#               ids[:8]=[0, 361, 6, 5, 27316, 454, 841, 849] | total_tokens=222
#       [TOKEN] id=019e568a… | raw[0:60]='11. Cổ Mai (còn gọi là Kẻ Mơ) (nay là các làng Hoàng Mai, Tư'
#               seg[0:60]='11 . Cổ_Mai ( còn gọi_là Kẻ_Mơ ) ( nay là các làng Hoàng_Mai'
#               ids[:8]=[0, 534, 6, 5, 84538, 454, 113439, 15] | total_tokens=421
#       [TOKEN] id=019e568a… | raw[0:60]='Các thái ấp trên đây phần lớn nằm ở phía Nam và Đông Bắc Thă'
#               seg[0:60]='Các thái_ấp trên đây phần_lớn nằm ở phía Nam và Đông_Bắc_Thă'
#               ids[:8]=[0, 9211, 40391, 454, 249999, 254, 2479, 4600] | total_tokens=200
#       [TOKEN] id=019e568a… | raw[0:60]='Điều đáng chú ý là, có hai con đường rnước quan trọng được n'
#               seg[0:60]='Điều đáng chú_ý là , có hai con đường rnước quan_trọng được'
#               ids[:8]=[0, 17108, 25333, 18051, 454, 1673, 580, 6] | total_tokens=408
#       [TOKEN] id=019e568a… | raw[0:60]='Thực ấp (ấp thang mộc) được triều đình nhà Trần phong cấp ch'
#               seg[0:60]='Thực_ấp ( ấp thang_mộc ) được triều_đình nhà Trần_phong_cấp'
#               ids[:8]=[0, 59747, 454, 249999, 254, 15, 6, 249999] | total_tokens=210
#       [TOKEN] id=019e568a… | raw[0:60]='Giống nhau ở chỗ, thái ấp cũng như thang mộc ấp, thực ấp, t'
#               seg[0:60]='Giống nhau ở chỗ , thái_ấp cũng như thang mộc_ấp , thực_ấp ,'
#               ids[:8]=[0, 5174, 32379, 10218, 2059, 33257, 6, 4] | total_tokens=317
#       [TOKEN] id=019e568a… | raw[0:60]='mức tô thuế trên các loại ruộng công như quốc khố điền và t'
#               seg[0:60]='mức tô thuế trên các loại ruộng_công như quốc_khố điền và th'
#               ids[:8]=[0, 22701, 29163, 39552, 2479, 925, 7323, 3114] | total_tokens=335
#       [TOKEN] id=019e568a… | raw[0:60]='1. [2]. Nông nghiệp 1. [2]. [1]. Nghề trồng trọt Trồng lúø.'
#               seg[0:60]='1 . . Nông_nghiệp 1 . . . Nghề trồng_trọt Trồng lúø . Lúa là'
#               ids[:8]=[0, 106, 6, 5, 6, 5, 146843, 454] | total_tokens=215
#       [TOKEN] id=019e568a… | raw[0:60]='Nếu như vào thời Đông Hán,đất Giao Chỉ được chép trong Hậu'
#               seg[0:60]='Nếu_như vào thời Đông_Hán , đất Giao_Chỉ được chép trong Hậu'
#               ids[:8]=[0, 14532, 454, 6457, 11479, 2249, 4194, 35116] | total_tokens=397
#       [TOKEN] id=019e568a… | raw[0:60]='Hoàng Cự Đà vì không được ăn xoài do vua ban mà không tích'
#               seg[0:60]='Hoàng_Cự_Đà vì không được ăn_xoài do vua ban mà không tích_c'
#               ids[:8]=[0, 38356, 454, 441, 52449, 454, 13347, 1298] | total_tokens=393
#       [TOKEN] id=019e568a… | raw[0:60]='Quýt vàng ở Thiên Trường được chép trong chính sử gắn với sự'
#               seg[0:60]='Quýt vàng ở Thiên_Trường được chép trong chính_sử gắn với sự'
#               ids[:8]=[0, 78309, 18, 33537, 2059, 40776, 454, 55487] | total_tokens=373
#       [TOKEN] id=019e568a… | raw[0:60]='Những thập niên cuối thế ký XIV, sử chép đến một số sự kiện'
#               seg[0:60]='Những thập_niên cuối thế ký XIV , sử_chép đến một_số sự_kiện'
#               ids[:8]=[0, 13836, 140072, 454, 93, 1732, 25939, 3061] | total_tokens=210
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW   67/152 | pages=[337, 338, 339, 340, 341, 342] | chars=7,611
#       [STRUCT] 22 structural boundaries | book='Vương Triều Trần (1226-1400)'
#     [MINI-CHUNK] window chars=7,611 → 80 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
# {"split_after_indices":[4,13,16,24,30,38,43,48,53,56,61,68,72,75]}
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=80 → splits=[4, 13, 16, 24, 30, 38, 43, 48, 53, 56, 61, 68, 72, 75]
# llm trả về
#  [4, 13, 16, 24, 30, 38, 43, 48, 53, 56, 61, 68, 72, 75]
#
#
#
#     [MERGE] 80 mini-chunks + 14 splits → 15 semantic groups
#       [TOKEN] id=019e568a… | raw[0:60]='1. [2]. [2]. Chăn nuôi Trâu, bò, ngựa, gà là những vật nuôi'
#               seg[0:60]='1 . . . Chăn_nuôi Trâu , bò , ngựa , gà là những vật_nuôi th'
#               ids[:8]=[0, 106, 6, 5, 6, 5, 6, 5] | total_tokens=290
#       [TOKEN] id=019e568a… | raw[0:60]='1. [2]. [3]. Thủy sản Có thể kể đến khá nhiều loại như tôm,'
#               seg[0:60]='1 . . . Thủy_sản Có_thể kể đến khá nhiều loại như tôm , cua'
#               ids[:8]=[0, 106, 6, 5, 6, 5, 6, 5] | total_tokens=507
#       [TOKEN] id=019e568a… | raw[0:60]='Các thứ cá, tôm, rau, quả đều phải nộp thuế do viên quan chu'
#               seg[0:60]='Các thứ cá , tôm , rau , quả đều phải nộp thuế do_viên quan'
#               ids[:8]=[0, 9211, 11847, 8707, 6, 4, 29163, 39] | total_tokens=137
#       [TOKEN] id=019e568a… | raw[0:60]='1. [9]. [4]. Đắp đê đào sông ngòi Một trong những biện pháp'
#               seg[0:60]='1 . . . Đắp đê đào sông ngòi_Một trong những biện_pháp để bả'
#               ids[:8]=[0, 106, 6, 5, 6, 5, 6, 5] | total_tokens=330
#       [TOKEN] id=019e568a… | raw[0:60]='Năm 1248, Trần Thái Tông ra lệnh cho các lộ đắp đê giữ nước'
#               seg[0:60]='Năm 1248 , Trần_Thái_Tông ra_lệnh cho các lộ đắp đê giữ nước'
#               ids[:8]=[0, 65832, 427, 9285, 6, 4, 42974, 454] | total_tokens=286
#       [TOKEN] id=019e568a… | raw[0:60]='Việc đắp đê là vấn đề cốt yếu không chỉ có Trần Thái Tông v'
#               seg[0:60]='Việc đắp đê là vấn_đề cốt_yếu không_chỉ có Trần_Thái_Tông và'
#               ids[:8]=[0, 57253, 220516, 99697, 580, 8529, 454, 18643] | total_tokens=378
#       [TOKEN] id=019e568a… | raw[0:60]='Đấp đê ngăn nước mặn được tiến hành ở ven biển, nơi các quý'
#               seg[0:60]='Đấp đê ngăn nước_mặn được tiến_hành ở ven biển , nơi các quý'
#               ids[:8]=[0, 4428, 249999, 254, 99697, 64846, 3042, 454] | total_tokens=371
#       [TOKEN] id=019e568a… | raw[0:60]='Tham gia đắp đê gồm đủ các tầng lớp nhân dân, “không phân sa'
#               seg[0:60]='Tham_gia đắp đê gồm đủ các tầng_lớp nhân_dân , “ không phân'
#               ids[:8]=[0, 99321, 454, 7366, 220516, 99697, 33256, 15221] | total_tokens=308
#       [TOKEN] id=019e568a… | raw[0:60]='Lần đầu tiên trong lịch sử, trong bộ máy nhà nước đã hình t'
#               seg[0:60]='Lần đầu_tiên trong lịch_sử , trong bộ_máy nhà_nước đã hình_t'
#               ids[:8]=[0, 339, 249994, 19, 2494, 454, 118, 1732] | total_tokens=305
#       [TOKEN] id=019e568a… | raw[0:60]='Quá trình củng cố và xây dựng đất nước trên các lĩnh vực tro'
#               seg[0:60]='Quá_trình củng_cố và xây_dựng đất_nước trên các lĩnh_vực tro'
#               ids[:8]=[0, 160638, 454, 4448, 119518, 146936, 449, 454] | total_tokens=339
#       [TOKEN] id=019e568a… | raw[0:60]='2. Thủ công nghiệp 2. [1]. Thủ công nghiệp nhờ nước Gốồm nhữ'
#               seg[0:60]='2 . Thủ_công_nghiệp 2 . . Thủ_công_nghiệp nhờ nước Gốồm nhữn'
#               ids[:8]=[0, 116, 6, 5, 40797, 454, 238, 23366] | total_tokens=261
#       [TOKEN] id=019e568a… | raw[0:60]='Theo tài liệu khảo cổ học và gia phả họ Cao ở Nho Lâm (Diễn'
#               seg[0:60]='Theo tài_liệu khảo_cổ_học và gia_phả họ Cao_ở Nho_Lâm ( Diễn'
#               ids[:8]=[0, 19635, 7378, 454, 141, 100345, 50537, 454] | total_tokens=371
#       [TOKEN] id=019e568a… | raw[0:60]='2. [2]. Thủ công nghiệp nhân dân Gồm các nghề chính sau:\n2.'
#               seg[0:60]='2 . . Thủ_công_nghiệp nhân_dân Gồm các nghề chính sau : 2 .'
#               ids[:8]=[0, 116, 6, 5, 6, 5, 40797, 454] | total_tokens=296
#       [TOKEN] id=019e568a… | raw[0:60]='Làng gốm Bát Tràng do dân Bồ Bát (Tam Điệp, Ninh Bình) di cư'
#               seg[0:60]='Làng gốm Bát_Tràng do dân Bồ_Bát ( Tam_Điệp , Ninh_Bình ) di'
#               ids[:8]=[0, 40155, 449, 706, 54030, 39, 335, 1699] | total_tokens=260
#       [TOKEN] id=019e568a… | raw[0:60]='Làng gốm Thổ Hà? và Phù Lãng (Bắc Ninh) thường sản xuất các'
#               seg[0:60]='Làng gốm Thổ_Hà ? và Phù_Lãng ( Bắc_Ninh ) thường sản_xuất c'
#               ids[:8]=[0, 40155, 449, 706, 54030, 39, 6003, 25091] | total_tokens=201
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW   68/152 | pages=[342, 343, 344, 345, 346, 347] | chars=8,489
#       [STRUCT] 18 structural boundaries | book='Vương Triều Trần (1226-1400)'
#     [MINI-CHUNK] window chars=8,489 → 76 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
# {"split_after_indices":[13,24,34,46,58,68]}
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=76 → splits=[4, 13, 18, 24, 29, 34, 39, 46, 51, 58, 63, 68]
# llm trả về
#  [4, 13, 18, 24, 29, 34, 39, 46, 51, 58, 63, 68]
#
#
#
#     [MERGE] 76 mini-chunks + 12 splits → 13 semantic groups
#       [TOKEN] id=019e568a… | raw[0:60]='Kết quả khai quật khảo cổ tại Hoàng thành Thăng Long (khu vự'
#               seg[0:60]='Kết_quả khai_quật khảo_cổ tại Hoàng_thành Thăng_Long ( khu_v'
#               ids[:8]=[0, 77577, 454, 5490, 17195, 18960, 454, 5490] | total_tokens=272
#       [TOKEN] id=019e568a… | raw[0:60]='Đồng thời cũng hình thành những làng chuyên sản xuất đồ gốm'
#               seg[0:60]='Đồng_thời cũng hình_thành những làng chuyên sản_xuất đồ_gốm'
#               ids[:8]=[0, 35733, 454, 927, 110771, 1943, 4609, 454] | total_tokens=512
#       [TOKEN] id=019e568a… | raw[0:60]='9. [2]. [2]. Nghề rèn Đã hình thành một số làng rèn như làng'
#               seg[0:60]='9 . . . Nghề rèn Đã hình_thành một_số làng rèn như làng Nho_'
#               ids[:8]=[0, 483, 6, 5, 6, 5, 6, 5] | total_tokens=323
#       [TOKEN] id=019e568a… | raw[0:60]='xây dựng phủ đệ và nhà cửa cho nhân dân như rền dao, rựa, c'
#               seg[0:60]='xây_dựng phủ_đệ và nhà_cửa cho nhân_dân như rền_dao , rựa ,'
#               ids[:8]=[0, 14948, 454, 71, 52449, 449, 29798, 454] | total_tokens=338
#       [TOKEN] id=019e568a… | raw[0:60]='2. [2]. [3]. Nghề dệt Nghề dệt thời Trần phát triển và tồn t'
#               seg[0:60]='2 . . . Nghề dệt Nghề dệt thời Trần_phát_triển và tồn_tại ở'
#               ids[:8]=[0, 116, 6, 5, 6, 5, 6, 5] | total_tokens=364
#       [TOKEN] id=019e568a… | raw[0:60]='Ở Vũ Lâm, hành cung thời Trần, nghề thêu đan được ra đời từ'
#               seg[0:60]='Ở Vũ_Lâm , hành_cung thời_Trần , nghề thêu đan được ra_đời t'
#               ids[:8]=[0, 71717, 58979, 454, 866, 27253, 6, 4] | total_tokens=229
#       [TOKEN] id=019e568a… | raw[0:60]='9. [2]. [4]. Nghề chạm hbhắc đá Thời Lý - Trần, làng chạm kh'
#               seg[0:60]='9 . . . Nghề chạm hbhắc đá Thời_Lý - Trần , làng chạm_khắc đ'
#               ids[:8]=[0, 483, 6, 5, 6, 5, 6, 5] | total_tokens=307
#       [TOKEN] id=019e568a… | raw[0:60]='Hổ đá ở đền thờ Trần Thủ Độ trong khu vực thái ấp Quắc Hươn'
#               seg[0:60]='Hổ đá ở đền thờ Trần_Thủ_Độ trong khu_vực thái_ấp Quắc_Hương'
#               ids[:8]=[0, 572, 25091, 24690, 2059, 6248, 19, 119730] | total_tokens=351
#       [TOKEN] id=019e568a… | raw[0:60]='2. [2]. [5]. Nghề khai bhoáng luyện kím Nghề khai khoáng, lu'
#               seg[0:60]='2 . . . Nghề khai bhoáng_luyện kím Nghề khai_khoáng , luyện'
#               ids[:8]=[0, 116, 6, 5, 6, 5, 6, 5] | total_tokens=320
#       [TOKEN] id=019e568a… | raw[0:60]='“ . Địa phương có nguồn kim loại quý là Việt Bắc, vùng đồi n'
#               seg[0:60]='“ . Địa_phương có nguồn kim_loại quý là Việt_Bắc , vùng đồi_'
#               ids[:8]=[0, 52, 6, 5, 43166, 454, 11727, 43672] | total_tokens=363
#       [TOKEN] id=019e568a… | raw[0:60]='2. [92]. [6]. Nghề đúc đồng Tháng 3 nhuận, năm Bính Thìn (nă'
#               seg[0:60]='2 . . . Nghề đúc đồng_Tháng 3 nhuận , năm Bính_Thìn ( năm 12'
#               ids[:8]=[0, 116, 6, 5, 6, 5, 6, 5] | total_tokens=283
#       [TOKEN] id=019e568a… | raw[0:60]='Ba lần đổi niên hiệu đều đúc tiền như Kiến Trung Thông Bảo,'
#               seg[0:60]='Ba lần đổi niên_hiệu đều đúc tiền như Kiến_Trung_Thông_Bảo ,'
#               ids[:8]=[0, 1853, 9230, 10688, 55113, 454, 127, 100345] | total_tokens=354
#       [TOKEN] id=019e568a… | raw[0:60]='9. [2]. [7]. Nghề chạm khắc gỗ Nghề chạm khắc gỗ nói chung b'
#               seg[0:60]='9 . . . Nghề chạm_khắc gỗ Nghề chạm_khắc gỗ nói_chung bao_gồ'
#               ids[:8]=[0, 483, 6, 5, 6, 5, 6, 5] | total_tokens=320
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW   69/152 | pages=[347, 348, 349, 350, 351, 352] | chars=7,885
#       [STRUCT] 20 structural boundaries | book='Vương Triều Trần (1226-1400)'
#     [MINI-CHUNK] window chars=7,885 → 72 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
# {"split_after_indices":[2,11,14,23,29,35,40,46,54,63]}
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=72 → splits=[2, 11, 14, 23, 29, 35, 40, 46, 54, 63]
# llm trả về
#  [2, 11, 14, 23, 29, 35, 40, 46, 54, 63]
#
#
#
#     [MERGE] 72 mini-chunks + 10 splits → 11 semantic groups
#       [TOKEN] id=019e568a… | raw[0:60]='Thợ khắc gỗ từng được vua sai khắc lại ấn báu bị thất lạc do'
#               seg[0:60]='Thợ_khắc gỗ từng được vua sai_khắc lại ấn_báu bị thất_lạc do'
#               ids[:8]=[0, 6003, 30599, 454, 92, 59710, 75364, 16036] | total_tokens=180
#       [TOKEN] id=019e568a… | raw[0:60]='Năm 1974, xã viên hợp tác xã thôn Liêm Trại, xã Mỹ Thịnh, n'
#               seg[0:60]='Năm 1974 , xã_viên hợp_tác_xã thôn_Liêm_Trại , xã Mỹ_Thịnh ,'
#               ids[:8]=[0, 65832, 27898, 6, 4, 14352, 454, 686] | total_tokens=455
#       [TOKEN] id=019e568a… | raw[0:60]='2. [2]. [8]. Nghề làm nón Có lẽ nối tiếng là nón Ma Lôi. Loạ'
#               seg[0:60]='2 . . . Nghề làm nón Có_lẽ nối tiếng là nón Ma_Lôi . Loại nó'
#               ids[:8]=[0, 116, 6, 5, 6, 5, 6, 5] | total_tokens=210
#       [TOKEN] id=019e568a… | raw[0:60]='2. [2]. [9]. Nghề sơn Sử cũ ghi chép một số sự kiện liên qua'
#               seg[0:60]='2 . . . Nghề sơn_Sử cũ ghi_chép một_số sự_kiện liên_quan đến'
#               ids[:8]=[0, 116, 6, 5, 6, 5, 6, 5] | total_tokens=484
#       [TOKEN] id=019e568a… | raw[0:60]='Năm 1977, cán bộ Viện Khảo cổ học đã khai quật ngôi mộ thời'
#               seg[0:60]='Năm 1977 , cán_bộ Viện Khảo_cổ_học đã khai_quật ngôi mộ thời'
#               ids[:8]=[0, 65832, 27193, 6, 4, 58044, 454, 275] | total_tokens=334
#       [TOKEN] id=019e568a… | raw[0:60]='Nhà nước có những quy định rất nghiêm ngặt về việc sử dụng đ'
#               seg[0:60]='Nhà_nước có những quy_định rất nghiêm_ngặt về việc sử_dụng đ'
#               ids[:8]=[0, 19491, 454, 19, 68507, 524, 1358, 8317] | total_tokens=338
#       [TOKEN] id=019e568a… | raw[0:60]='3. Thương nghiệp và đô thị 2. [1]. Thương nghiệp 2. [1]. [1]'
#               seg[0:60]='3 . Thương_nghiệp và đô_thị 2 . . Thương_nghiệp 2 . . . Giơo'
#               ids[:8]=[0, 138, 6, 5, 81629, 454, 19, 18651] | total_tokens=276
#       [TOKEN] id=019e568a… | raw[0:60]='Không thấy có một chính sách ức thương nào dưới thời Trần.\nN'
#               seg[0:60]='Không thấy có một chính_sách ức_thương nào dưới thời Trần .'
#               ids[:8]=[0, 13887, 4913, 524, 889, 3178, 454, 7] | total_tokens=264
#       [TOKEN] id=019e568a… | raw[0:60]='Ö các địa phương thì chợ và bến sông là nơi trao đổi, buôn b'
#               seg[0:60]='Ö các địa_phương thì chợ và bến sông là nơi trao_đổi , buôn_'
#               ids[:8]=[0, 5973, 925, 11800, 454, 11727, 43672, 2579] | total_tokens=356
#       [TOKEN] id=019e568a… | raw[0:60]='Tiền được dùng để trao đổi hàng hóa, mua bán ruộng đất và nộ'
#               seg[0:60]='Tiền được dùng để trao_đổi hàng hóa , mua_bán ruộng_đất và n'
#               ids[:8]=[0, 144765, 912, 8456, 1498, 79283, 454, 18643] | total_tokens=512
#       [TOKEN] id=019e568a… | raw[0:60]='Tiền đời (Trần) Dương Nhật Lễ (1369 - 1370) có tiền Đại Địn'
#               seg[0:60]='Tiền_đời ( Trần )_Dương Nhật_Lễ ( 1369 - 1370 ) có tiền Đại_'
#               ids[:8]=[0, 144765, 454, 18643, 110771, 15, 42974, 1388] | total_tokens=449
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW   70/152 | pages=[352, 353, 354, 355, 356, 357] | chars=7,442
#       [STRUCT] 13 structural boundaries | book='Vương Triều Trần (1226-1400)'
#     [MINI-CHUNK] window chars=7,442 → 71 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
# {"split_after_indices":[4,11,19,30,39,48,56,63]}
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=71 → splits=[4, 11, 19, 24, 30, 39, 48, 56, 63]
# llm trả về
#  [4, 11, 19, 24, 30, 39, 48, 56, 63]
#
#
#
#     [MERGE] 71 mini-chunks + 9 splits → 10 semantic groups
#       [TOKEN] id=019e568a… | raw[0:60]='Năm 1379 vì sợ nạn người Chiêm cướp phá, triều đình Trần đã'
#               seg[0:60]='Năm 1379 vì sợ nạn người Chiêm cướp_phá , triều_đình Trần đã'
#               ids[:8]=[0, 65832, 702, 22377, 5396, 30491, 63303, 1008] | total_tokens=339
#       [TOKEN] id=019e568a… | raw[0:60]='Đơn vị đo chiều dài, đo diện tích được nhà nước quy định thố'
#               seg[0:60]='Đơn_vị đo chiều dài , đo diện_tích được nhà_nước quy_định th'
#               ids[:8]=[0, 161182, 454, 334, 51721, 91146, 47151, 19018] | total_tokens=355
#       [TOKEN] id=019e568a… | raw[0:60]='Lý giải vì sao lại có tên gọi Vân Đồn, Phan Huy Chú chép: “'
#               seg[0:60]='Lý_giải vì sao lại có tên gọi Vân_Đồn , Phan_Huy_Chú chép :'
#               ids[:8]=[0, 44980, 454, 735, 52249, 5396, 6284, 1917] | total_tokens=475
#       [TOKEN] id=019e568a… | raw[0:60]='Tác giảá Đỗ Văn Ninh dựa trên tư liệu khảo cổ học đã nhấn mạ'
#               seg[0:60]='Tác_giảá Đỗ_Văn_Ninh dựa trên tư_liệu khảo_cổ_học đã nhấn_mạ'
#               ids[:8]=[0, 149432, 454, 735, 17195, 709, 215925, 454] | total_tokens=258
#       [TOKEN] id=019e568a… | raw[0:60]='bến Cống Cái, bến Con Quy (đáo Hải Vân); đảo Ngọc Vừng; đảo'
#               seg[0:60]='bến Cống_Cái , bến Con_Quy ( đáo Hải_Vân ) ; đảo Ngọc_Vừng ;'
#               ids[:8]=[0, 200663, 19, 313, 32379, 454, 441, 51917] | total_tokens=315
#       [TOKEN] id=019e568a… | raw[0:60]='Tại đây đã phát hiện được những mảnh gốm vỡ các loại, phần l'
#               seg[0:60]='Tại đây đã phát_hiện được những mảnh gốm vỡ các loại , phần_'
#               ids[:8]=[0, 44100, 4600, 1408, 5152, 454, 127, 93801] | total_tokens=448
#       [TOKEN] id=019e568a… | raw[0:60]='Đại; Việt sử bý toàn thư chép: “Tháng 11 (năm 1349), đặt qu'
#               seg[0:60]='Đại ; Việt sử_bý toàn thư_chép : “ Tháng 11 ( năm 1349 ) , đ'
#               ids[:8]=[0, 18832, 2819, 3763, 5034, 454, 47454, 6252] | total_tokens=389
#       [TOKEN] id=019e568a… | raw[0:60]='Người Vân Đồn phần lớn làm nghề buôn, cách ăn mặc đều giống'
#               seg[0:60]='Người Vân_Đồn phần_lớn làm nghề buôn , cách ăn_mặc đều giống'
#               ids[:8]=[0, 19167, 64263, 454, 13347, 51635, 8192, 454] | total_tokens=388
#       [TOKEN] id=019e568a… | raw[0:60]='Như vậy, trong nước, các trung tâầm thương mại lớn hình thàn'
#               seg[0:60]='Như_vậy , trong nước , các trung_tâầm thương_mại lớn hình_th'
#               ids[:8]=[0, 58737, 454, 334, 118806, 6, 4, 1000] | total_tokens=335
#       [TOKEN] id=019e568a… | raw[0:60]='Giơo thương uới Chămpe (Chiêm Thành) Chămpa có quan hệ gần g'
#               seg[0:60]='Giơo thương_uới Chămpe ( Chiêm_Thành ) Chămpa có quan_hệ gần'
#               ids[:8]=[0, 5174, 12435, 31, 9246, 454, 34, 81397] | total_tokens=289
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW   71/152 | pages=[357, 358, 359, 360, 361, 362] | chars=8,740
#       [STRUCT] 15 structural boundaries | book='Vương Triều Trần (1226-1400)'
#     [MINI-CHUNK] window chars=8,740 → 80 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] Error (attempt 1/3): ServerError: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.', 'status': 'UNAVAILABLE'}}
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] Waiting 2s…
# llm trả lời
# {"split_after_indices":[4,12,17,25,32,37,44,54,63,68,74]}
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=2 | chunks=80 → splits=[4, 12, 17, 25, 32, 37, 44, 49, 54, 63, 68, 74]
# llm trả về
#  [4, 12, 17, 25, 32, 37, 44, 49, 54, 63, 68, 74]
#
#
#
#     [MERGE] 80 mini-chunks + 12 splits → 13 semantic groups
#       [TOKEN] id=019e568a… | raw[0:60]='Cống phẩm của Chămpa phần lớn là voi trắng, sư tử, ngoài ra'
#               seg[0:60]='Cống_phẩm của Chămpa phần_lớn là voi trắng , sư_tử , ngoài_r'
#               ids[:8]=[0, 313, 32379, 454, 11727, 249989, 39, 550] | total_tokens=281
#       [TOKEN] id=019e568a… | raw[0:60]='Không chỉ bằng con đường giao thương mà dưới hình thức cống'
#               seg[0:60]='Không_chỉ bằng con đường giao_thương mà dưới hình_thức cống_'
#               ids[:8]=[0, 13887, 454, 206, 31204, 6567, 158, 7590] | total_tokens=442
#       [TOKEN] id=019e568a… | raw[0:60]='nhà Nguyên đòi Đại Việt phải tiến cống hàng năm và tăng thê'
#               seg[0:60]='nhà Nguyên_đòi Đại_Việt phải tiến cống hàng năm và tăng thêm'
#               ids[:8]=[0, 2455, 51358, 454, 18643, 2516, 14, 18832] | total_tokens=260
#       [TOKEN] id=019e568a… | raw[0:60]='Hai năm sau, trong chuyến sang nước Nguyên đáp lễ của sứ đoà'
#               seg[0:60]='Hai năm sau , trong chuyến sang nước Nguyên_đáp lễ của sứ_đo'
#               ids[:8]=[0, 4368, 2933, 858, 6, 4, 1000, 82538] | total_tokens=485
#       [TOKEN] id=019e568a… | raw[0:60]='Triều đình nhà Trần còn định lệ thưởng cho những người đi s'
#               seg[0:60]='Triều_đình nhà Trần_còn định_lệ thưởng cho những người đi sứ'
#               ids[:8]=[0, 165734, 454, 18643, 119518, 2455, 42974, 454] | total_tokens=332
#       [TOKEN] id=019e568a… | raw[0:60]='Lê Quý Đôn trong Vậên Đài loại ngữ đã chép: “Đời nhà Trần, t'
#               seg[0:60]='Lê_Quý_Đôn trong Vậên_Đài loại_ngữ đã chép : “ Đời nhà Trần'
#               ids[:8]=[0, 16389, 454, 31583, 1673, 454, 13347, 24306] | total_tokens=276
#       [TOKEN] id=019e568a… | raw[0:60]='Sử chép: “Năm 1302, bấy giờ có người đạo sĩ phương Bắc tên l'
#               seg[0:60]='Sử_chép : “ Năm 1302 , bấy_giờ có người đạo_sĩ phương_Bắc tê'
#               ids[:8]=[0, 63034, 454, 12640, 254, 152, 52, 65832] | total_tokens=331
#       [TOKEN] id=019e568a… | raw[0:60]='Tuy nhiên, có một thực tế là, nếu như việc buôn bán ở biên g'
#               seg[0:60]='Tuy_nhiên , có một thực_tế là , nếu_như việc buôn_bán ở biên'
#               ids[:8]=[0, 21857, 454, 19, 979, 1732, 6, 4] | total_tokens=322
#       [TOKEN] id=019e568a… | raw[0:60]='và thuyền buôn các nước muốn đến đó phần lớn đều phải ghé q'
#               seg[0:60]='và thuyền buôn các nước muốn đến đó phần_lớn đều phải ghé qu'
#               ids[:8]=[0, 544, 169666, 154701, 925, 3042, 6542, 1885] | total_tokens=251
#       [TOKEN] id=019e568a… | raw[0:60]='Giao thương uới đaug Œrdo Oø, Qua Oa) Java là một “thể chế b'
#               seg[0:60]='Giao_thương uới đaug Œrdo_Oø , Qua Oa ) Java là một “ thể_ch'
#               ids[:8]=[0, 110365, 454, 927, 43672, 75, 81397, 24859] | total_tokens=475
#       [TOKEN] id=019e568a… | raw[0:60]='Java, thời Lý, Trần gọi là Trảo Oa, Qua Oa, Đại Oa. Thương n'
#               seg[0:60]='Java , thời_Lý , Trần_gọi_là Trảo_Oa , Qua Oa , Đại_Oa . Thư'
#               ids[:8]=[0, 41925, 6, 4, 4194, 454, 866, 1673] | total_tokens=285
#       [TOKEN] id=019e568a… | raw[0:60]='Tuy nhiên dưới thời Trần, khoảng thời gian trước, trong và n'
#               seg[0:60]='Tuy_nhiên dưới thời Trần , khoảng thời_gian trước , trong và'
#               ids[:8]=[0, 21857, 454, 19, 979, 1732, 17858, 4194] | total_tokens=328
#       [TOKEN] id=019e568a… | raw[0:60]='Về phía Đại Việt cũng có những lý do để có thể lý giải sự ng'
#               seg[0:60]='Về phía Đại_Việt cũng có những lý_do để có_thể lý_giải sự ng'
#               ids[:8]=[0, 66863, 25403, 18832, 454, 6609, 33340, 1943] | total_tokens=207
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW   72/152 | pages=[362, 363, 364, 365, 366, 367] | chars=8,727
#       [STRUCT] 18 structural boundaries | book='Vương Triều Trần (1226-1400)'
#     [MINI-CHUNK] window chars=8,727 → 79 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
# {"split_after_indices":[7,14,23,29,40,50,57,67,73]}
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=79 → splits=[7, 14, 23, 29, 34, 40, 45, 50, 57, 62, 67, 73]
# llm trả về
#  [7, 14, 23, 29, 34, 40, 45, 50, 57, 62, 67, 73]
#
#
#
#     [MERGE] 79 mini-chunks + 12 splits → 13 semantic groups
#       [TOKEN] id=019e568a… | raw[0:60]='Từ nửa cuối thế kỷ XIV, để đuy trì quan hệ lâu dài và thường'
#               seg[0:60]='Từ nửa cuối thế_kỷ XIV , để đuy_trì quan_hệ lâu_dài và thườn'
#               ids[:8]=[0, 30947, 80537, 25939, 3061, 454, 92, 60479] | total_tokens=389
#       [TOKEN] id=019e568a… | raw[0:60]='G:;ao thương uới các rước bhớc Ngoài những nước có quan hệ b'
#               seg[0:60]='G : ; ao thương_uới các rước bhớc Ngoài những nước có quan_h'
#               ids[:8]=[0, 527, 152, 2819, 940, 9246, 454, 34] | total_tokens=329
#       [TOKEN] id=019e568a… | raw[0:60]='Sử cũ còn cho biết, vua Nguyên từng đòi vua Trần phải nộp nh'
#               seg[0:60]='Sử cũ còn cho biết , vua_Nguyên từng đòi vua Trần_phải nộp n'
#               ids[:8]=[0, 63034, 56667, 3531, 681, 4022, 6, 4] | total_tokens=461
#       [TOKEN] id=019e568a… | raw[0:60]='Riêng nước Chân Lạp là một hiện tượng đặc biệt, bởi, vào đầu'
#               seg[0:60]='Riêng nước Chân_Lạp là một hiện_tượng đặc_biệt , bởi , vào đ'
#               ids[:8]=[0, 2975, 28498, 3042, 205443, 454, 866, 82830] | total_tokens=332
#       [TOKEN] id=019e568b… | raw[0:60]='Tham gia hoạt động ngoại thương là những người thuộc nhiều t'
#               seg[0:60]='Tham_gia hoạt_động ngoại_thương là những người thuộc nhiều t'
#               ids[:8]=[0, 99321, 454, 7366, 9975, 454, 18643, 27350] | total_tokens=282
#       [TOKEN] id=019e568b… | raw[0:60]='Lúc đầu là tập trung nón ở cảng (thực ra là đã sai người nh'
#               seg[0:60]='Lúc đầu là tập_trung nón ở cảng ( thực_ra là đã sai người_nh'
#               ids[:8]=[0, 89411, 2494, 580, 9400, 454, 18, 18988] | total_tokens=335
#       [TOKEN] id=019e568b… | raw[0:60]='Đại Việt không phải là nước “hướng ngoại” nhưng lại có nguồn'
#               seg[0:60]='Đại_Việt không phải là nước “ hướng_ngoại ” nhưng lại có ngu'
#               ids[:8]=[0, 18832, 454, 6609, 33340, 687, 2334, 580] | total_tokens=315
#       [TOKEN] id=019e568b… | raw[0:60]='sự thỉnh suy của nó đã tác động mạnh mẽ đến văn hóa, xã hội'
#               seg[0:60]='sự thỉnh_suy của nó đã tác_động mạnh_mẽ đến văn_hóa , xã_hội'
#               ids[:8]=[0, 2550, 5675, 156604, 454, 1159, 53, 550] | total_tokens=288
#       [TOKEN] id=019e568b… | raw[0:60]='Trong các công trình nghiên cứu trước đã cho rằng, kinh tế t'
#               seg[0:60]='Trong các công_trình nghiên_cứu trước đã cho rằng , kinh_tế'
#               ids[:8]=[0, 12818, 925, 1871, 454, 4448, 119518, 34956] | total_tokens=483
#       [TOKEN] id=019e568b… | raw[0:60]='3. [2]. Đô thị 3. [2]. [1]. Thăng Longl Kinh đô Thăng Long v'
#               seg[0:60]='3 . . Đô_thị 3 . . . Thăng_Longl Kinh_đô Thăng_Long vừa là t'
#               ids[:8]=[0, 138, 6, 5, 6, 5, 130716, 454] | total_tokens=269
#       [TOKEN] id=019e568b… | raw[0:60]='Trong 61 phường ở Thăng Long, có các phường thủ công nổi ti'
#               seg[0:60]='Trong 61 phường ở Thăng_Long , có các phường thủ_công nổi_ti'
#               ids[:8]=[0, 12818, 11716, 140630, 2059, 6003, 44473, 454] | total_tokens=280
#       [TOKEN] id=019e568b… | raw[0:60]='“Thăng Long thời Trần là trung tâm đất nước, Kẻ Chợ của toà'
#               seg[0:60]='“ Thăng_Long thời Trần_là trung_tâm đất_nước , Kẻ_Chợ của to'
#               ids[:8]=[0, 52, 6003, 44473, 454, 866, 4021, 4194] | total_tokens=407
#       [TOKEN] id=019e568b… | raw[0:60]='Thăng Long là trung tâm đất nước, hội tụ được các tầng lớp n'
#               seg[0:60]='Thăng_Long là trung_tâm đất_nước , hội_tụ được các tầng_lớp'
#               ids[:8]=[0, 6003, 44473, 454, 866, 4021, 580, 13375] | total_tokens=270
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW   73/152 | pages=[367, 368, 369, 370, 371, 372] | chars=7,472
#       [STRUCT] 13 structural boundaries | book='Vương Triều Trần (1226-1400)'
#     [MINI-CHUNK] window chars=7,472 → 71 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
# {"split_after_indices":[7,11,16,22,24,29,39,47,53,56,59,64]}
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=71 → splits=[7, 11, 16, 22, 24, 29, 34, 39, 47, 53, 56, 59, 64]
# llm trả về
#  [7, 11, 16, 22, 24, 29, 34, 39, 47, 53, 56, 59, 64]
#
#
#
#     [MERGE] 71 mini-chunks + 13 splits → 14 semantic groups
#       [TOKEN] id=019e568b… | raw[0:60]='Các phường ở Thăng Long không hoàn toàn đơn thuần chỉ có thợ'
#               seg[0:60]='Các phường ở Thăng_Long không hoàn_toàn đơn_thuần chỉ có thợ'
#               ids[:8]=[0, 9211, 140630, 2059, 6003, 44473, 454, 866] | total_tokens=512
#       [TOKEN] id=019e568b… | raw[0:60]='Quân sĩ là lực lượng quan trọng trong lớp cư dân đô thị Thă'
#               seg[0:60]='Quân_sĩ là lực_lượng quan_trọng trong lớp cư_dân đô_thị Thăn'
#               ids[:8]=[0, 101390, 454, 7, 32606, 580, 9611, 454] | total_tokens=300
#       [TOKEN] id=019e568b… | raw[0:60]='Phố phường, danh lam thắng cảnh tạo nên một Thăng Long cổ kí'
#               seg[0:60]='Phố_phường , danh_lam_thắng_cảnh tạo nên một Thăng_Long cổ_k'
#               ids[:8]=[0, 172102, 454, 11727, 57078, 6, 4, 26422] | total_tokens=258
#       [TOKEN] id=019e568b… | raw[0:60]='Bên trong lòng hồ tìm thấy rất nhiều tàn tích thực vật, chứn'
#               seg[0:60]='Bên trong lòng hồ tìm thấy rất nhiều tàn_tích thực_vật , chứ'
#               ids[:8]=[0, 83326, 1000, 11553, 19698, 10040, 4913, 3967] | total_tokens=430
#       [TOKEN] id=019e568b… | raw[0:60]='Người dân Thăng Long rất thích ăn trầu. Vườn dân trong kinh'
#               seg[0:60]='Người_dân Thăng_Long rất thích ăn_trầu . Vườn_dân trong kinh'
#               ids[:8]=[0, 19167, 454, 71, 7453, 6003, 44473, 454] | total_tokens=166
#       [TOKEN] id=019e568b… | raw[0:60]='&ử đã chép tới việc vua ban cho Phạm Ngũ Lão “vườn cau tron'
#               seg[0:60]='& ử đã chép tới việc vua ban cho Phạm_Ngũ_Lão “ vườn_cau tro'
#               ids[:8]=[0, 619, 6, 46535, 1408, 176272, 7067, 2735] | total_tokens=422
#       [TOKEN] id=019e568b… | raw[0:60]='3. [2]. [2]. Thiên Trường?\nThăng Long và Thiên Trường là hai'
#               seg[0:60]='3 . . . Thiên_Trường ?_Thăng_Long và Thiên_Trường là hai tru'
#               ids[:8]=[0, 138, 6, 5, 6, 5, 6, 5] | total_tokens=257
#       [TOKEN] id=019e568b… | raw[0:60]='nơi có Tiên miếu để các thế hệ con chầu về đây hương khói.'
#               seg[0:60]='nơi có Tiên_miếu để các thế_hệ con chầu về đây hương_khói .'
#               ids[:8]=[0, 13426, 524, 111226, 454, 266, 63513, 1498] | total_tokens=249
#       [TOKEN] id=019e568b… | raw[0:60]='Thiện Trường chưa phải là đô thị được chú ý xây dựng ngay từ'
#               seg[0:60]='Thiện_Trường chưa phải là đô_thị được chú_ý xây_dựng ngay từ'
#               ids[:8]=[0, 6003, 93801, 454, 55487, 57078, 9958, 2334] | total_tokens=363
#       [TOKEN] id=019e568b… | raw[0:60]='Nhiều năm sau, vào năm 1239, Thiên Trường được triều đình đ'
#               seg[0:60]='Nhiều năm sau , vào năm 1239 , Thiên_Trường được triều_đình'
#               ids[:8]=[0, 89898, 2933, 858, 6, 4, 2249, 2933] | total_tokens=431
#       [TOKEN] id=019e568b… | raw[0:60]='Về mặt tổ chức hành chính, chức quan quản lý Thăng Long và T'
#               seg[0:60]='Về mặt tổ_chức hành_chính , chức_quan quản_lý Thăng_Long và'
#               ids[:8]=[0, 66863, 5493, 12158, 454, 206, 48021, 4893] | total_tokens=231
#       [TOKEN] id=019e568b… | raw[0:60]='Về vai trò, vị trí của đô thị Thiên Trường, có thể khái quát'
#               seg[0:60]='Về vai_trò , vị_trí của đô_thị Thiên_Trường , có_thể khái_qu'
#               ids[:8]=[0, 66863, 1347, 454, 18, 23017, 6, 4] | total_tokens=188
#       [TOKEN] id=019e568b… | raw[0:60]='- Đô thị Thiện Trường ra đời xuất phát từ nhu cầu riêng củat'
#               seg[0:60]='- Đô_thị_Thiện Trường ra_đời xuất_phát từ nhu_cầu riêng củat'
#               ids[:8]=[0, 20, 130716, 454, 927, 51721, 454, 20800] | total_tokens=318
#       [TOKEN] id=019e568b… | raw[0:60]='- Thăng Long vừa là trung tâm chính trị, kinh tế, văn hóa, q'
#               seg[0:60]='- Thăng_Long vừa là trung_tâm chính_trị , kinh_tế , văn_hóa'
#               ids[:8]=[0, 20, 6003, 44473, 454, 866, 4021, 11880] | total_tokens=222
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW   74/152 | pages=[372, 373, 374, 375, 376, 377] | chars=8,769
#       [STRUCT] 15 structural boundaries | book='Vương Triều Trần (1226-1400)'
#     [MINI-CHUNK] window chars=8,769 → 76 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
# {"split_after_indices":[5,9,26,34,44,49,61,66]}
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=76 → splits=[5, 9, 14, 26, 34, 39, 44, 49, 54, 61, 66]
# llm trả về
#  [5, 9, 14, 26, 34, 39, 44, 49, 54, 61, 66]
#
#
#
#     [MERGE] 76 mini-chunks + 11 splits → 12 semantic groups
#       [TOKEN] id=019e568b… | raw[0:60]='- Thiên Trường vừa là trung tâm quyền lực của hoàng tộc lại'
#               seg[0:60]='- Thiên_Trường vừa là trung_tâm quyền_lực của hoàng_tộc lại'
#               ids[:8]=[0, 20, 40776, 454, 55487, 57078, 11880, 580] | total_tokens=411
#       [TOKEN] id=019e568b… | raw[0:60]='Triều đình còn bảo vệ Thiên Trường bằng vị trí các thái ấp'
#               seg[0:60]='Triều_đình còn bảo_vệ Thiên_Trường bằng vị_trí các thái_ấp d'
#               ids[:8]=[0, 165734, 454, 18643, 119518, 3531, 6122, 454] | total_tokens=301
#       [TOKEN] id=019e568b… | raw[0:60]='HI. VĂN MINH ĐẠI VIỆT - VĂN HÓA THĂNG LONG 1. Thăng Long - Đ'
#               seg[0:60]='HI._VĂN_MINH_ĐẠI_VIỆT - VĂN_HÓA THĂNG_LONG 1 . Thăng_Long -'
#               ids[:8]=[0, 35848, 5, 454, 856, 15835, 839, 454] | total_tokens=282
#       [TOKEN] id=019e568b… | raw[0:60]='“Ở giữa khu vực trời đất, có thế rồng cuộn hổ ngồi, ở giữa'
#               seg[0:60]='“ Ở giữa khu_vực trời_đất , có thế rồng cuộn hổ ngồi , ở giữ'
#               ids[:8]=[0, 52, 71717, 19865, 8086, 454, 334, 74345] | total_tokens=512
#       [TOKEN] id=019e568b… | raw[0:60]='Nếu xét về chức năng thì chúng ta có thể phân chia kinh đô T'
#               seg[0:60]='Nếu xét về chức_năng thì chúng_ta có_thể phân_chia kinh_đô T'
#               ids[:8]=[0, 14532, 31462, 1893, 7211, 454, 19, 44473] | total_tokens=457
#       [TOKEN] id=019e568b… | raw[0:60]='Không chỉ tái cấu trúc lại các đơn vị hành chính, nhà Trần c'
#               seg[0:60]='Không_chỉ tái_cấu_trúc lại các đơn_vị hành_chính , nhà Trần_'
#               ids[:8]=[0, 13887, 454, 206, 31204, 75626, 454, 238] | total_tokens=277
#       [TOKEN] id=019e568b… | raw[0:60]='phải đủ lệ khao duyệt về làm ÁAn phủ sứ phủ Thiên Trường (q'
#               seg[0:60]='phải đủ lệ khao_duyệt về làm ÁAn_phủ sứ_phủ Thiên_Trường ( q'
#               ids[:8]=[0, 2334, 15221, 32524, 19631, 31, 454, 693] | total_tokens=304
#       [TOKEN] id=019e568b… | raw[0:60]='Là trung tâm chính trị, hành chính của cả nước, Thăng Long t'
#               seg[0:60]='Là trung_tâm chính_trị , hành_chính của cả nước , Thăng_Long'
#               ids[:8]=[0, 40155, 13375, 454, 18, 27253, 3178, 454] | total_tokens=323
#       [TOKEN] id=019e568b… | raw[0:60]='Từ một trung tâm chính trị, Thăng Long phát triển thành một'
#               seg[0:60]='Từ một trung_tâm chính_trị , Thăng_Long phát_triển thành một'
#               ids[:8]=[0, 30947, 889, 13375, 454, 18, 27253, 3178] | total_tokens=397
#       [TOKEN] id=019e568b… | raw[0:60]='Trần; hay sự kiện năm 1282, vua Trần Thánh Tông đi xe từ kin'
#               seg[0:60]='Trần ; hay sự_kiện năm 1282 , vua Trần_Thánh_Tông đi xe từ k'
#               ids[:8]=[0, 42974, 2819, 2054, 2550, 454, 92, 93801] | total_tokens=290
#       [TOKEN] id=019e568b… | raw[0:60]='Nếu như các thành thị phong kiến phương Tây tồn tại và phát'
#               seg[0:60]='Nếu_như các thành_thị phong_kiến phương Tây tồn_tại và phát_'
#               ids[:8]=[0, 14532, 454, 6457, 11479, 925, 2781, 454] | total_tokens=315
#       [TOKEN] id=019e568b… | raw[0:60]='Không chỉ là trung tâm kinh tế của nhân dân trong nướốc, Thă'
#               seg[0:60]='Không_chỉ là trung_tâm kinh_tế của nhân_dân trong nướốc , Th'
#               ids[:8]=[0, 13887, 454, 206, 31204, 580, 13375, 454] | total_tokens=457
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW   75/152 | pages=[377, 378, 379, 380, 381, 382] | chars=9,584
#       [STRUCT] 18 structural boundaries | book='Vương Triều Trần (1226-1400)'
#     [MINI-CHUNK] window chars=9,584 → 88 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
# {"split_after_indices":[10,21,31,45,52,58,63,76,82]}
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=88 → splits=[4, 10, 15, 21, 26, 31, 36, 45, 52, 58, 63, 68, 76, 82]
# llm trả về
#  [4, 10, 15, 21, 26, 31, 36, 45, 52, 58, 63, 68, 76, 82]
#
#
#
#     [MERGE] 88 mini-chunks + 14 splits → 15 semantic groups
#       [TOKEN] id=019e568b… | raw[0:60]='Từ đây, như một hệ quả tất yếu của sự phát triển kinh tế côn'
#               seg[0:60]='Từ đây , như một hệ_quả tất_yếu của sự phát_triển kinh_tế cô'
#               ids[:8]=[0, 30947, 4600, 6, 4, 1641, 889, 7099] | total_tokens=234
#       [TOKEN] id=019e568b… | raw[0:60]='Đây vừa là biểu hiện sinh động cho sự phát triển của thành'
#               seg[0:60]='Đây vừa là biểu_hiện sinh_động cho sự phát_triển của thành_t'
#               ids[:8]=[0, 37540, 11880, 580, 23907, 454, 127, 93801] | total_tokens=307
#       [TOKEN] id=019e568b… | raw[0:60]='Không chỉ là trung tâm chính trị, quân sự, kinh tế của cả nư'
#               seg[0:60]='Không_chỉ là trung_tâm chính_trị , quân_sự , kinh_tế của cả'
#               ids[:8]=[0, 13887, 454, 206, 31204, 580, 13375, 454] | total_tokens=303
#       [TOKEN] id=019e568b… | raw[0:60]='hai đồng văn hóa ấy lại đạt đến sự đăng đối, cân bằng như t'
#               seg[0:60]='hai đồng văn_hóa ấy lại đạt đến sự đăng_đối , cân_bằng như_t'
#               ids[:8]=[0, 1337, 4570, 9040, 454, 34282, 11, 14112] | total_tokens=347
#       [TOKEN] id=019e568b… | raw[0:60]='Thăng Long thời Trần còn là nơi dung hòa các giá trị văn hóa'
#               seg[0:60]='Thăng_Long thời Trần_còn là nơi dung_hòa các giá_trị văn_hóa'
#               ids[:8]=[0, 6003, 44473, 454, 866, 4021, 4194, 42974] | total_tokens=394
#       [TOKEN] id=019e568b… | raw[0:60]='vừa phản ánh sự tiếp nhận và cải biến mang tính bản địa hóa'
#               seg[0:60]='vừa phản_ánh sự tiếp_nhận và cải_biến mang tính bản_địa_hóa'
#               ids[:8]=[0, 11880, 33294, 454, 1665, 127, 2550, 6998] | total_tokens=253
#       [TOKEN] id=019e568b… | raw[0:60]='Đặc biệt, sức sống củửa uốn manh Đại Việt - uăn hóa Thăng Lo'
#               seg[0:60]='Đặc_biệt , sức_sống củửa uốn_manh Đại_Việt - uăn hóa Thăng_L'
#               ids[:8]=[0, 93872, 454, 964, 33340, 6, 4, 12641] | total_tokens=244
#       [TOKEN] id=019e568b… | raw[0:60]='ba lần chúng vào được mảnh đất Thăng Long nhưng cả ba lần T'
#               seg[0:60]='ba lần chúng vào được mảnh đất Thăng_Long nhưng cả ba lần Th'
#               ids[:8]=[0, 961, 9230, 4006, 2249, 912, 170032, 11472] | total_tokens=462
#       [TOKEN] id=019e568b… | raw[0:60]='Để làm nên một Thăng Long đẹp đẽ, rực rõỡ và hào hùng thuở ấ'
#               seg[0:60]='Để làm_nên một Thăng_Long đẹp_đẽ , rực_rõỡ và hào_hùng thuở'
#               ids[:8]=[0, 32390, 1839, 454, 19, 1732, 889, 6003] | total_tokens=441
#       [TOKEN] id=019e568b… | raw[0:60]='Tuy nhiên, đến năm 1397 (thời Trần Phế Ðẽ), sau gần 400 năm'
#               seg[0:60]='Tuy_nhiên , đến năm 1397 ( thời Trần_Phế_Đẽ ) , sau gần 400'
#               ids[:8]=[0, 21857, 454, 19, 979, 1732, 6, 4] | total_tokens=353
#       [TOKEN] id=019e568b… | raw[0:60]='Vậy lờ, trải qua bao biến thiên lịch sử và biến động xã hội,'
#               seg[0:60]='Vậy_lờ , trải qua bao biến_thiên lịch_sử và biến_động xã_hội'
#               ids[:8]=[0, 87563, 454, 141, 58677, 6, 4, 60365] | total_tokens=341
#       [TOKEN] id=019e568b… | raw[0:60]='2. Thành tựu giáo dục và khoa cử Phan Huy Chú trong Lịch tri'
#               seg[0:60]='2 . Thành_tựu giáo_dục và khoa cử Phan_Huy_Chú trong Lịch tr'
#               ids[:8]=[0, 116, 6, 5, 22049, 454, 18, 52449] | total_tokens=234
#       [TOKEN] id=019e568b… | raw[0:60]='là thời đại phục hưng dân tộc trong lịch sử chế độ phong ki'
#               seg[0:60]='là thời_đại_phục_hưng dân_tộc trong lịch_sử chế_độ phong_kiế'
#               ids[:8]=[0, 580, 4194, 454, 18643, 12976, 14, 454] | total_tokens=487
#       [TOKEN] id=019e568b… | raw[0:60]='Bấy giờ, nhà Trần đã chú trọng biện toàn, phát triển hệ thốn'
#               seg[0:60]='Bấy_giờ , nhà_Trần đã chú_trọng biện_toàn , phát_triển hệ_th'
#               ids[:8]=[0, 335, 249999, 53, 454, 735, 58677, 6] | total_tokens=362
#       [TOKEN] id=019e568b… | raw[0:60]='Đúng như Ngô Thời Gĩ trong Việt sử tiêu án Ôđã viết: “Vua l'
#               seg[0:60]='Đúng như Ngô_Thời_Gĩ trong Việt_sử tiêu_án Ôđã viết : “ Vua'
#               ids[:8]=[0, 4428, 971, 449, 1641, 90542, 454, 20800] | total_tokens=245
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW   76/152 | pages=[382, 383, 384, 385, 386, 387] | chars=8,753
#       [STRUCT] 28 structural boundaries | book='Vương Triều Trần (1226-1400)'
#     [MINI-CHUNK] window chars=8,753 → 86 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
# {"split_after_indices":[5,8,16,24,32,44,51,57,66,71]}
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=86 → splits=[5, 8, 16, 24, 32, 37, 44, 51, 57, 66, 71, 80]
# llm trả về
#  [5, 8, 16, 24, 32, 37, 44, 51, 57, 66, 71, 80]
#
#
#
#     [MERGE] 86 mini-chunks + 12 splits → 13 semantic groups
#       [TOKEN] id=019e568b… | raw[0:60]='Hơn một thế kỷ sau, vào tháng 5 năm 1397, vua Trần Thuận Tôn'
#               seg[0:60]='Hơn một thế_kỷ sau , vào tháng 5 năm 1397 , vua Trần_Thuận_T'
#               ids[:8]=[0, 147045, 889, 3061, 454, 92, 60479, 858] | total_tokens=387
#       [TOKEN] id=019e568b… | raw[0:60]='Ở Việt Nam, chế độ khoa cử bắt đầu từ thời Lý và được nhà Tr'
#               seg[0:60]='Ở Việt_Nam , chế_độ khoa_cử bắt_đầu từ thời Lý và được nhà_T'
#               ids[:8]=[0, 71717, 3763, 454, 124197, 6, 4, 12240] | total_tokens=127
#       [TOKEN] id=019e568b… | raw[0:60]='Xét về đại thể, thời Trần có hai loại khoa thi là thi Thái h'
#               seg[0:60]='Xét về đại_thể , thời Trần_có hai loại khoa thi là thi Thái_'
#               ids[:8]=[0, 1193, 2305, 1893, 7899, 454, 927, 35895] | total_tokens=452
#       [TOKEN] id=019e568b… | raw[0:60]='Khoa thi Nho học đầu tiên được tổ chức dưới thời Trần vào nă'
#               seg[0:60]='Khoa thi Nho_học đầu_tiên được tổ_chức dưới thời Trần_vào nă'
#               ids[:8]=[0, 67766, 6117, 541, 497, 454, 127, 53459] | total_tokens=402
#       [TOKEN] id=019e568b… | raw[0:60]='Năm 1261, vua Trần Thánh Tông tiếp tục cho mở khoa thi Thái'
#               seg[0:60]='Năm 1261 , vua Trần_Thánh_Tông tiếp_tục cho mở khoa thi Thái'
#               ids[:8]=[0, 65832, 427, 11540, 6, 4, 86729, 42974] | total_tokens=354
#       [TOKEN] id=019e568b… | raw[0:60]='Đến năm 1374, vua Trần Duệ Tông cho mở khoa thi Thái học sin'
#               seg[0:60]='Đến năm 1374 , vua Trần_Duệ_Tông cho mở khoa thi Thái_học_si'
#               ids[:8]=[0, 93433, 2933, 702, 16360, 6, 4, 86729] | total_tokens=251
#       [TOKEN] id=019e568b… | raw[0:60]='người đỗ thì vua ra đề thi một bài văn sách để xếp bậc [1],'
#               seg[0:60]='người đỗ thì vua ra đề_thi một bài văn_sách để xếp bậc , Như'
#               ids[:8]=[0, 1008, 232548, 2579, 86729, 673, 6248, 454] | total_tokens=336
#       [TOKEN] id=019e568b… | raw[0:60]='Hai kỳ thi Hội, thi Đình thường được tổ chức liền nhau. Tuy'
#               seg[0:60]='Hai kỳ thi Hội , thi_Đình thường được tổ_chức liền nhau . Tu'
#               ids[:8]=[0, 4368, 13850, 6117, 22394, 6, 4, 6117] | total_tokens=332
#       [TOKEN] id=019e568b… | raw[0:60]='Những người đỗ đạt sẽ được bổ nhiệm vào giữ các chức vụ quan'
#               seg[0:60]='Những người đỗ_đạt sẽ được bổ_nhiệm vào giữ các chức_vụ quan'
#               ids[:8]=[0, 13836, 1008, 232548, 454, 18643, 63409, 2129] | total_tokens=326
#       [TOKEN] id=019e568b… | raw[0:60]='Ngoài những kỳ thi nói trên, căn cứ theo sách Đạ; Việt sử ký'
#               seg[0:60]='Ngoài những kỳ thi nói trên , căn_cứ theo sách_Đạ ; Việt_sử'
#               ids[:8]=[0, 46158, 1358, 13850, 6117, 2872, 2479, 6] | total_tokens=485
# ...
#               seg[0:60]='Về chính_trị , nhà_vua Lý - Trần đã tập_trung các quyền lập_'
#               ids[:8]=[0, 66863, 3178, 454, 4448, 51721, 6, 4] | total_tokens=468
#       [TOKEN] id=019e5692… | raw[0:60]='Để cụ thể hóa và hình tượng hóa cái quyền uy tập trung vô th'
#               seg[0:60]='Để cụ_thể hóa và hình_tượng hóa cái quyền uy_tập_trung vô_th'
#               ids[:8]=[0, 32390, 24399, 454, 927, 35895, 9432, 544] | total_tokens=374
#       [TOKEN] id=019e5692… | raw[0:60]='Nhưng phải chăng như một số người thường quan niệm, các vua'
#               seg[0:60]='Nhưng phải_chăng như một_số người thường quan_niệm , các vua'
#               ids[:8]=[0, 19751, 2334, 454, 206, 44473, 1641, 889] | total_tokens=334
#       [TOKEN] id=019e5692… | raw[0:60]='Trên thực tế, các vua Lý Trần đã tự xắc định cho mình một tr'
#               seg[0:60]='Trên thực_tế , các vua Lý_Trần đã tự xắc_định cho mình một t'
#               ids[:8]=[0, 85319, 3839, 454, 18, 54073, 6, 4] | total_tokens=285
#       [TOKEN] id=019e5692… | raw[0:60]='Vì thế, ngoài chức năng tế tự của nhà vua phản ánh một trách'
#               seg[0:60]='Vì_thế , ngoài chức_năng tế_tự của nhà_vua phản_ánh một trác'
#               ids[:8]=[0, 32061, 454, 18, 132892, 6, 4, 10610] | total_tokens=512
#       [TOKEN] id=019e5692… | raw[0:60]='Qua đó nhà vua có thể trực tiếp thấy được cuộc sống lao động'
#               seg[0:60]='Qua đó nhà_vua có_thể trực_tiếp thấy được cuộc_sống lao_động'
#               ids[:8]=[0, 19559, 2275, 2455, 454, 1783, 11, 524] | total_tokens=284
#       [TOKEN] id=019e5692… | raw[0:60]='Một trách nhiệm nặng nề khác của nhà vua là bảo vệ nhân dân'
#               seg[0:60]='Một trách_nhiệm nặng_nề khác của nhà_vua là bảo_vệ nhân_dân'
#               ids[:8]=[0, 14921, 24581, 454, 6457, 120050, 55315, 454] | total_tokens=512
#       [TOKEN] id=019e5692… | raw[0:60]='Cuối cùng, dưới triều Trần, tục lệ nhường ngôi của các nhà v'
#               seg[0:60]='Cuối_cùng , dưới triều Trần , tục_lệ nhường_ngôi của các nhà'
#               ids[:8]=[0, 180603, 454, 238, 34335, 6, 4, 17858] | total_tokens=283
#       [TOKEN] id=019e5692… | raw[0:60]='Một vấn đề đặt ra là: tại sao một kẻ đứng đầu giai cấp phong'
#               seg[0:60]='Một vấn_đề đặt ra là : tại_sao một kẻ đứng đầu giai_cấp phon'
#               ids[:8]=[0, 14921, 8529, 454, 18643, 32809, 15422, 673] | total_tokens=173
#       [TOKEN] id=019e5692… | raw[0:60]='Chúng ta thấy rằng trong mô hình lý tưởng của chế độ phong k'
#               seg[0:60]='Chúng_ta thấy rằng trong mô_hình lý_tưởng của chế_độ phong_k'
#               ids[:8]=[0, 33756, 454, 102, 4913, 10371, 1000, 23110] | total_tokens=449
#       [TOKEN] id=019e5692… | raw[0:60]='Tuy nhiên, thời Lý - Trần chế độ phong kiến quân chủ tập tru'
#               seg[0:60]='Tuy_nhiên , thời_Lý - Trần_chế_độ phong_kiến quân_chủ tập_tr'
#               ids[:8]=[0, 21857, 454, 19, 979, 1732, 6, 4] | total_tokens=264
#       [TOKEN] id=019e5692… | raw[0:60]='+ Quan liêu Giúp việc gần gũi các vua Lý Trần và cũng là tập'
#               seg[0:60]='+ Quan_liêu Giúp_việc gần_gũi các vua Lý_Trần_và cũng là tập'
#               ids[:8]=[0, 997, 38738, 454, 141, 56540, 5174, 74427] | total_tokens=286
#       [TOKEN] id=019e5692… | raw[0:60]='Lúc ban đầu, tập đoàn quan liêu thời LýTrần chủ yếu bao gồm'
#               seg[0:60]='Lúc ban_đầu , tập_đoàn quan_liêu thời_LýTrần chủ_yếu bao_gồm'
#               ids[:8]=[0, 89411, 4599, 454, 18643, 249994, 34, 6] | total_tokens=506
#       [TOKEN] id=019e5692… | raw[0:60]='Nhưng cùng với sự phát triển của đất nước (bờ cõi mở rộng, d'
#               seg[0:60]='Nhưng cùng_với sự phát_triển của đất_nước ( bờ cõi mở_rộng ,'
#               ids[:8]=[0, 19751, 4770, 454, 334, 81397, 2550, 5152] | total_tokens=110
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW  150/152 | pages=[753, 754, 755, 756, 757, 758] | chars=10,294
#       [STRUCT] 14 structural boundaries | book='Vương Triều Trần (1226-1400)'
#     [MINI-CHUNK] window chars=10,294 → 91 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
# {"split_after_indices":[7,18,23,31,39,47,56,68,89]}
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=91 → splits=[7, 12, 18, 23, 31, 39, 47, 56, 61, 68, 73, 81, 89]
# llm trả về
#  [7, 12, 18, 23, 31, 39, 47, 56, 61, 68, 73, 81, 89]
#
#
#
#     [MERGE] 91 mini-chunks + 13 splits → 14 semantic groups
#       [TOKEN] id=019e5692… | raw[0:60]='Trước hết là một biện pháp “quý tộc hóa” dề dặt đối với một'
#               seg[0:60]='Trước_hết là một biện_pháp “ quý_tộc hóa ” dề_dặt đối_với mộ'
#               ids[:8]=[0, 69388, 454, 132892, 18, 580, 889, 80793] | total_tokens=478
#       [TOKEN] id=019e5692… | raw[0:60]='Tuy nhiên, với quy mô ngày càng lớn của bộ máy quan liêu và'
#               seg[0:60]='Tuy_nhiên , với quy_mô ngày_càng lớn của bộ_máy quan_liêu và'
#               ids[:8]=[0, 21857, 454, 19, 979, 1732, 6, 4] | total_tokens=354
#       [TOKEN] id=019e5692… | raw[0:60]='từ những chức quan chuyên môn ở các sảnh, cục, viện tiến lê'
#               seg[0:60]='từ những chức_quan_chuyên_môn ở các sảnh , cục , viện tiến l'
#               ids[:8]=[0, 2368, 1358, 7211, 454, 13722, 19, 454] | total_tokens=361
#       [TOKEN] id=019e5692… | raw[0:60]='Cuối cùng, cũng phải kể đến một con đường khác vốn ít được c'
#               seg[0:60]='Cuối_cùng , cũng phải kể đến một con đường khác vốn ít được'
#               ids[:8]=[0, 180603, 454, 238, 34335, 6, 4, 1943] | total_tokens=268
#       [TOKEN] id=019e5692… | raw[0:60]='Các vua Lý Trần đã cố gắng đảm bảo cho tiêu chuẩn dòng họ c'
#               seg[0:60]='Các vua Lý_Trần đã cố_gắng đảm_bảo cho tiêu_chuẩn dòng_họ ch'
#               ids[:8]=[0, 9211, 86729, 44980, 454, 55487, 249994, 19] | total_tokens=400
#       [TOKEN] id=019e5692… | raw[0:60]='Trong bậc thang xã hội, quan liêu thời Lý Trần là một đẳng c'
#               seg[0:60]='Trong bậc_thang xã_hội , quan_liêu thời Lý_Trần_là một đẳng_'
#               ids[:8]=[0, 12818, 107692, 454, 18, 8467, 14352, 454] | total_tokens=446
#       [TOKEN] id=019e5692… | raw[0:60]='Về mặt kinh tế, đẳng cấp quan liêu đã được miễn trừ các nghĩ'
#               seg[0:60]='Về mặt kinh_tế , đẳng_cấp quan_liêu đã được miễn_trừ các ngh'
#               ids[:8]=[0, 66863, 5493, 5890, 454, 18, 54073, 6] | total_tokens=410
#       [TOKEN] id=019e5692… | raw[0:60]='Cuối cùng, để khẳng định quyền uy đẳng cấp của mình và nhất'
#               seg[0:60]='Cuối_cùng , để khẳng_định quyền uy_đẳng_cấp của mình và nhất'
#               ids[:8]=[0, 180603, 454, 238, 34335, 6, 4, 1498] | total_tokens=512
#       [TOKEN] id=019e5692… | raw[0:60]='Quan liêu thời Lý Trần là một đẳng cấp thống trị, nằm trong'
#               seg[0:60]='Quan_liêu thời Lý_Trần_là một đẳng_cấp thống_trị , nằm trong'
#               ids[:8]=[0, 38738, 454, 141, 56540, 4194, 44980, 454] | total_tokens=271
#       [TOKEN] id=019e5692… | raw[0:60]='Đối với các quan liêu khác, tính chất quý tộc lại gắn liền'
#               seg[0:60]='Đối_với các quan_liêu khác , tính_chất quý_tộc lại gắn liền'
#               ids[:8]=[0, 59893, 454, 334, 81397, 925, 2261, 454] | total_tokens=335
#       [TOKEN] id=019e5692… | raw[0:60]='Thứ hai, quan liêu thời Lý Trần cũng không phải là những lãn'
#               seg[0:60]='Thứ hai , quan_liêu thời Lý_Trần cũng không phải là những lã'
#               ids[:8]=[0, 93056, 1337, 6, 4, 2261, 454, 141] | total_tokens=306
#       [TOKEN] id=019e5692… | raw[0:60]='Mặt khác, trong khuôn khổ một nhà nước phong kiến tập quyền'
#               seg[0:60]='Mặt_khác , trong khuôn_khổ một nhà_nước phong_kiến tập_quyền'
#               ids[:8]=[0, 109699, 454, 10684, 18778, 6, 4, 1000] | total_tokens=470
#       [TOKEN] id=019e5692… | raw[0:60]='Trần Quốc Khang đã từng xây dựng phủ đệ lộng lẫy ở châu Diễ'
#               seg[0:60]='Trần_Quốc_Khang đã từng xây_dựng phủ đệ lộng_lẫy ở châu_Diễn'
#               ids[:8]=[0, 42974, 454, 31583, 32876, 454, 605, 8467] | total_tokens=411
#       [TOKEN] id=019e5692… | raw[0:60]='Cuối cùng, trong thời Lý Trần, bộ máy quan liêu chưa có điều'
#               seg[0:60]='Cuối_cùng , trong thời Lý_Trần , bộ_máy quan_liêu chưa có đi'
#               ids[:8]=[0, 180603, 454, 238, 34335, 6, 4, 1000] | total_tokens=41
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW  151/152 | pages=[758, 759, 760, 761, 762, 763] | chars=9,620
#       [STRUCT] 21 structural boundaries | book='Vương Triều Trần (1226-1400)'
#     [MINI-CHUNK] window chars=9,620 → 92 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
# {"split_after_indices":[7,15,22,32,49,56,73,86]}
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=92 → splits=[7, 15, 22, 27, 32, 37, 49, 56, 61, 73, 78, 86]
# llm trả về
#  [7, 15, 22, 27, 32, 37, 49, 56, 61, 73, 78, 86]
#
#
#
#     [MERGE] 92 mini-chunks + 12 splits → 13 semantic groups
#       [TOKEN] id=019e5692… | raw[0:60]='Từ khi khoa cử phát triển, quan liêu còn được tuyển chọn tro'
#               seg[0:60]='Từ khi khoa_cử phát_triển , quan_liêu còn được tuyển_chọn tr'
#               ids[:8]=[0, 30947, 1907, 19002, 454, 238, 46535, 5152] | total_tokens=455
#       [TOKEN] id=019e5692… | raw[0:60]='Tóm lại, quan liêu thời Lý Trần là bộ phận chủ yếu của đẳng'
#               seg[0:60]='Tóm_lại , quan_liêu thời Lý_Trần_là bộ_phận chủ_yếu của đẳng'
#               ids[:8]=[0, 72094, 39, 454, 141, 12976, 14, 6] | total_tokens=401
#       [TOKEN] id=019e5692… | raw[0:60]='+ Nông dân làng xã Nông dân làng xã là thành phần chủ thể ch'
#               seg[0:60]='+ Nông_dân làng_xã Nông_dân làng_xã là thành_phần chủ_thể ch'
#               ids[:8]=[0, 997, 146843, 454, 71, 7453, 112258, 454] | total_tokens=412
#       [TOKEN] id=019e5692… | raw[0:60]='Chúng ta được biết rất ít những chi tiết cụ thể về đời sống'
#               seg[0:60]='Chúng_ta được biết rất ít những chi_tiết cụ_thể về đời_sống'
#               ids[:8]=[0, 33756, 454, 102, 912, 4022, 3967, 24323] | total_tokens=278
#       [TOKEN] id=019e5692… | raw[0:60]='Trong làng xã, đông đảo nông dân cày cấy ruộng công (quan đi'
#               seg[0:60]='Trong làng_xã , đông_đảo nông_dân cày_cấy ruộng_công ( quan_'
#               ids[:8]=[0, 12818, 112258, 454, 425, 6073, 6, 4] | total_tokens=280
#       [TOKEN] id=019e5692… | raw[0:60]='Nhà nước phong kiến đã sớm lập sổ hộ khẩu để kiểm soát dân đ'
#               seg[0:60]='Nhà_nước phong_kiến đã sớm lập sổ hộ_khẩu để kiểm_soát dân_đ'
#               ids[:8]=[0, 19491, 454, 19, 68507, 22510, 454, 301] | total_tokens=303
#       [TOKEN] id=019e5692… | raw[0:60]='Bên cạnh hệ thống chính quyền đó, ta thấy tầng lớp bô lão l'
#               seg[0:60]='Bên_cạnh hệ_thống chính_quyền đó , ta thấy tầng_lớp bô_lão l'
#               ids[:8]=[0, 83326, 454, 238, 109811, 7099, 454, 927] | total_tokens=512
#       [TOKEN] id=019e5692… | raw[0:60]='Trong khung cảnh của các làng xã tự trị đó có thể suy đoán v'
#               seg[0:60]='Trong khung_cảnh của các làng_xã tự_trị đó có_thể suy_đoán v'
#               ids[:8]=[0, 12818, 146241, 454, 238, 17195, 6457, 550] | total_tokens=460
#       [TOKEN] id=019e5692… | raw[0:60]='Vậy tại sao người nông dân làng xã Việt Nam thời Lý Trần, lạ'
#               seg[0:60]='Vậy tại_sao người nông_dân làng_xã Việt_Nam thời Lý_Trần , l'
#               ids[:8]=[0, 87563, 2251, 454, 433, 31, 1008, 49708] | total_tokens=243
#       [TOKEN] id=019e5692… | raw[0:60]='Như chúng ta đã xét, ngay trong các thái ấp của quan liêu qu'
#               seg[0:60]='Như chúng_ta đã xét , ngay trong các thái_ấp của quan_liêu q'
#               ids[:8]=[0, 58737, 4006, 454, 102, 1408, 31462, 6] | total_tokens=512
#       [TOKEN] id=019e5692… | raw[0:60]='Sau cùng về mặt xã hội và tư tưởng, người nông dân Lý Trần đ'
#               seg[0:60]='Sau_cùng về mặt xã_hội và tư_tưởng , người nông_dân Lý_Trần'
#               ids[:8]=[0, 6987, 454, 238, 34335, 1893, 5493, 14352] | total_tokens=215
#       [TOKEN] id=019e5692… | raw[0:60]='Họ cũng đã tự xác định là những thần dân của một nhà vua dư'
#               seg[0:60]='Họ cũng đã tự xác_định là những thần_dân của một nhà_vua dướ'
#               ids[:8]=[0, 61428, 1943, 1408, 5208, 16859, 454, 18643] | total_tokens=435
#       [TOKEN] id=019e5692… | raw[0:60]='Sau khi đã xét đến thiết chế chính trị, xã hội Việt Nam thời'
#               seg[0:60]='Sau khi đã xét đến thiết_chế chính_trị , xã_hội Việt_Nam thờ'
#               ids[:8]=[0, 6987, 1907, 1408, 31462, 1885, 7062, 454] | total_tokens=220
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW  152/152 | pages=[763, 764, 765, 766] | chars=5,971
#       [STRUCT] 15 structural boundaries | book='Vương Triều Trần (1226-1400)'
#     [MINI-CHUNK] window chars=5,971 → 56 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
# {"split_after_indices":[6,9,16,22,26,33,38,43,50]}
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=56 → splits=[6, 9, 16, 22, 26, 33, 38, 43, 50]
# llm trả về
#  [6, 9, 16, 22, 26, 33, 38, 43, 50]
#
#
#
#     [MERGE] 56 mini-chunks + 9 splits → 10 semantic groups
#       [TOKEN] id=019e5692… | raw[0:60]='- Thứ nhất, đó là sự ổn định về cơ sở và thiết chế, về nền t'
#               seg[0:60]='- Thứ nhất , đó là sự ổn_định về cơ_sở và thiết_chế , về nền'
#               ids[:8]=[0, 20, 93056, 2671, 6, 4, 2275, 580] | total_tokens=512
#       [TOKEN] id=019e5692… | raw[0:60]='- Thứ hai, đó là sự ổn định trong cấu trúc nội tại của hệ th'
#               seg[0:60]='- Thứ hai , đó là sự ổn_định trong cấu_trúc nội_tại của hệ_t'
#               ids[:8]=[0, 20, 93056, 1337, 6, 4, 2275, 580] | total_tokens=180
#       [TOKEN] id=019e5692… | raw[0:60]='- Thứ ba, đó là sự ổn định trong cấu trúc nội tại của những'
#               seg[0:60]='- Thứ ba , đó là sự ổn_định trong cấu_trúc nội_tại của những'
#               ids[:8]=[0, 20, 93056, 961, 6, 4, 2275, 580] | total_tokens=383
#       [TOKEN] id=019e5692… | raw[0:60]='Cuối cùng, ở thời Lý Trần, ta cũng còn thấy có sự ổn định tr'
#               seg[0:60]='Cuối_cùng , ở thời Lý_Trần , ta cũng còn thấy có sự ổn_định'
#               ids[:8]=[0, 180603, 454, 238, 34335, 6, 4, 2059] | total_tokens=422
#       [TOKEN] id=019e5692… | raw[0:60]='Tóm lại, sự cân bằng ổn định trong kết cấu đẳng cấp của thiế'
#               seg[0:60]='Tóm_lại , sự cân_bằng ổn_định trong kết_cấu đẳng_cấp của thi'
#               ids[:8]=[0, 72094, 39, 454, 141, 12976, 14, 6] | total_tokens=230
#       [TOKEN] id=019e5692… | raw[0:60]='Chính một kết cấu đắng cấp của thiết chế chính trị - xã hội'
#               seg[0:60]='Chính một kết_cấu đắng cấp của thiết_chế chính_trị - xã_hội'
#               ids[:8]=[0, 17654, 889, 6301, 454, 238, 249999, 34] | total_tokens=479
#       [TOKEN] id=019e5692… | raw[0:60]='Ở đây, có một mối liên hệ hai chiều. Nhà nước trung ương thờ'
#               seg[0:60]='Ở đây , có một mối liên_hệ hai chiều . Nhà_nước trung_ương t'
#               ids[:8]=[0, 71717, 4600, 6, 4, 524, 889, 70254] | total_tokens=275
#       [TOKEN] id=019e5692… | raw[0:60]='Đó chính là ý nghĩa mà Trần Hưng Đạo đã tổng hết thành một'
#               seg[0:60]='Đó chính là ý_nghĩa mà Trần_Hưng_Đạo đã tổng hết thành một n'
#               ids[:8]=[0, 62578, 3178, 580, 5604, 454, 449, 127] | total_tokens=254
#       [TOKEN] id=019e5692… | raw[0:60]='Tuy nhiên, sự cân bằng ổn định về mặt xã hội học của cơ chế'
#               seg[0:60]='Tuy_nhiên , sự cân_bằng ổn_định về mặt xã_hội_học của cơ_chế'
#               ids[:8]=[0, 21857, 454, 19, 979, 1732, 6, 4] | total_tokens=446
#       [TOKEN] id=019e5692… | raw[0:60]='Nhưng một khi cùng một lúc, nhiều yếu tổ hài hòa bị phá võ,'
#               seg[0:60]='Nhưng một_khi cùng một lúc , nhiều yếu tổ hài_hòa bị phá võ'
#               ids[:8]=[0, 19751, 889, 454, 52568, 4770, 889, 10305] | total_tokens=216
#
# [SAVE] Writing 2,002 points → 'full_VTT_data_qdrant_points_512.json'…
# [SAVE] Done. 6429.1 KB written.
