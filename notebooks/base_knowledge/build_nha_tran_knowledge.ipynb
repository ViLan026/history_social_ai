# %%
# !pip install -q google-genai underthesea transformers torch numpy qdrant-client uuid6
# !pip install qdrant-client sentence-transformers -q
# !pip install -q groq  pydantic

# %% [markdown]
# # Mục mới

# %%
# str(uuid6.uuid7())

# %% [markdown]
# ### import and config
# import, danh sách can chi, check can chi trong văn bản (đầu trang hoặc đầu dòng (\n))
#
# Số lượng trang cho từng lần gọi api
#
# Các kí hiệu chọn để ngắt dòng (RecursiveCharacterTextSplitter )
#
# Số lượng word, min and max overlap, max context lenght của model embedding

# %%
from __future__ import annotations

import abc
import json
import os
import pathlib
import re
import time
import urllib.request
import uuid6
from dataclasses import dataclass
from typing import Optional

import numpy as np
import torch
from pydantic import BaseModel
from transformers import AutoModel, AutoTokenizer
from underthesea import word_tokenize
from google.colab import userdata
from qdrant_client import QdrantClient, models
from qdrant_client.http.models import Distance, VectorParams, PointStruct

# 60-cycle sexagenary calendar names (Giáp Tý → Quý Hợi)
CAN_CHI_60: list[str] = [
    "Giáp Tý",  "Ất Sửu",  "Bính Dần", "Đinh Mão", "Mậu Thìn", "Kỷ Tỵ",
    "Canh Ngọ", "Tân Mùi", "Nhâm Thân","Quý Dậu",  "Giáp Tuất","Ất Hợi",
    "Bính Tý",  "Đinh Sửu","Mậu Dần",  "Kỷ Mão",   "Canh Thìn","Tân Tỵ",
    "Nhâm Ngọ", "Quý Mùi", "Giáp Thân","Ất Dậu",   "Bính Tuất","Đinh Hợi",
    "Mậu Tý",   "Kỷ Sửu",  "Canh Dần", "Tân Mão",  "Nhâm Thìn","Quý Tỵ",
    "Giáp Ngọ", "Ất Mùi",  "Bính Thân","Đinh Dậu", "Mậu Tuất", "Kỷ Hợi",
    "Canh Tý",  "Tân Sửu", "Nhâm Dần", "Quý Mão",  "Giáp Thìn","Ất Tỵ",
    "Bính Ngọ", "Đinh Mùi","Mậu Thân", "Kỷ Dậu",   "Canh Tuất","Tân Hợi",
    "Nhâm Tý",  "Quý Sửu", "Giáp Dần", "Ất Mão",   "Bính Thìn","Đinh Tỵ",
    "Mậu Ngọ",  "Kỷ Mùi",  "Canh Thân","Tân Dậu",  "Nhâm Tuất","Quý Hợi",
]


# Sort longest-first to prevent sub-string matches (e.g. "Giáp" before "Giáp Tý")
_CAN_CHI_PATTERN: str = "|".join(
    re.escape(cc) for cc in sorted(CAN_CHI_60, key=len, reverse=True)
)
print(f"in can chi nè : {_CAN_CHI_PATTERN}\n")


# Danh sách tên các tháng trong năm (Tháng 1 → Tháng 12)
MONTHS_LIST: list[str] = [
    "Tháng 1", "Tháng 2", "Tháng 3", "Tháng 4", "Tháng 5", "Tháng 6",
    "Tháng 7", "Tháng 8", "Tháng 9", "Tháng 10", "Tháng 11", "Tháng 12"
]

# Tạo Pattern mẫu dạng: (Tháng 1|Tháng 2|...|Tháng 12)
_MONTHS_PATTERN: str = "|".join(MONTHS_LIST)

# Regex nhận diện Tháng ở đầu dòng (hỗ trợ cả trường hợp có mã [54a] hoặc không)
# MONTHS_LINE_START_RE: re.Pattern = re.compile(
#     r"^(?:\[\d{2}[ab]\]\s+)?(" + _MONTHS_PATTERN + r")(?=\s*|\,|[\[\(\.]|$)",
#     re.MULTILINE
# )


# Regex hỗ trợ cả: [Mã]? + [Năm]? + [Can Chi hoặc Tháng] + [Nhìn trước]
CAN_CHI_MONTH_RE: re.Pattern = re.compile(
    r"^(?:\[\d{1,2}[ab]\]\s+)?(?:Năm\s+)?(?:" + _CAN_CHI_PATTERN + r"|" + _MONTHS_PATTERN + r")(?=\s*|\,|[\[\(\.]|$)",
    re.MULTILINE
)



# Tìm thẻ và trang trong văn bản [1], [2], …  , [PAGE:12]
FOOTNOTE_REF_RE: re.Pattern = re.compile(r"\[(\d{1,2})\]")
PAGE_MARKER_RE: re.Pattern = re.compile(r"\n\s*\[\[\[PAGE:(\d+)\]\]\]\s*\n")


# Separator priority list for word-aware text splitting
SEPARATORS: list[str] = ["\n\n", "\n", ".", "?", "!", ";", ":", ",", " ", ""]


# Sliding-window page counts per book
BOOK_WINDOW_SIZES: dict[str, int] = {
    "Đại Việt Sử Ký Toàn Thư":                3,
    "Khâm Định Việt Sử Thông Giám Cương Mục":   3,
    "Việt Sử Toàn Thư":                        3,
    "Vương Triều Trần":                         5
}
DEFAULT_WINDOW_SIZE: int = 5


# Mini-chunk & merge sizing
MINI_CHUNK_WORDS: int  = 35     # ≈ 55-70 BPE tokens for classical Vietnamese
OVERLAP_TOK_MIN:  int  = 20
OVERLAP_TOK_MAX:  int  = 30
MAX_EMBED_TOKENS: int  = 256    # hard limit for BKAI bi-encoder


# Model IDs
EMBED_MODEL_ID:  str = "bkai-foundation-models/vietnamese-bi-encoder"
# GEMINI_MODEL_ID: str = "gemini-2.5-flash"
GEMINI_MODEL_ID: str = "gemini-3.1-flash-lite"

GROQ_MODEL_LLAMA_70B = "llama-3.3-70b-versatile"
GROQ_MODEL_LLAMA_8B  = "llama-3.1-8b-instant"
GROQ_MODEL_QWEN      = "qwen/qwen3-32b"



# Lấy cấu hình bảo mật từ Secrets của Colab
QDRANT_URL = userdata.get('QDRANT_URL')
API_KEY = userdata.get('QDRANT_API_KEY')

client = QdrantClient(url=QDRANT_URL, api_key=API_KEY)

COLLECTION_NAME = "history_social"
VECTOR_SIZE = 768  # Expected vector size from the embedding model

# Check if collection exists and its configuration matches
if client.collection_exists(collection_name=COLLECTION_NAME):
    collection_info = client.get_collection(collection_name=COLLECTION_NAME).config
    current_vector_size = collection_info.params.vectors.size

    if current_vector_size != VECTOR_SIZE:
        print(f"Lỗi: Collection '{COLLECTION_NAME}' đã tồn tại với kích thước vector {current_vector_size}, "
              f"nhưng đang mong đợi {VECTOR_SIZE}. Đang xóa và tạo lại collection...")
        client.delete_collection(collection_name=COLLECTION_NAME)
        client.create_collection(
            collection_name=COLLECTION_NAME,
            vectors_config=VectorParams(size=VECTOR_SIZE, distance=Distance.COSINE)
        )
        print(f"Đã tạo lại collection: {COLLECTION_NAME} với kích thước vector {VECTOR_SIZE}.")
    else:
        print(f"Collection '{COLLECTION_NAME}' đã tồn tại và kích thước vector khớp ({VECTOR_SIZE}).")
else:
    # Collection does not exist, create it
    client.create_collection(
        collection_name=COLLECTION_NAME,
        vectors_config=VectorParams(size=VECTOR_SIZE, distance=Distance.COSINE)
    )
    print(f"Đã khởi tạo collection mới: {COLLECTION_NAME} với kích thước vector {VECTOR_SIZE}.")
# Out:
# in can chi nè : Nhâm\ Thân|Giáp\ Tuất|Canh\ Thìn|Giáp\ Thân|Bính\ Tuất|Nhâm\ Thìn|Bính\ Thân|Giáp\ Thìn|Canh\ Tuất|Bính\ Thìn|Canh\ Thân|Nhâm\ Tuất|Bính\ Dần|Đinh\ Mão|Mậu\ Thìn|Canh\ Ngọ|Đinh\ Sửu|Nhâm\ Ngọ|Đinh\ Hợi|Canh\ Dần|Giáp\ Ngọ|Đinh\ Dậu|Mậu\ Tuất|Nhâm\ Dần|Bính\ Ngọ|Đinh\ Mùi|Mậu\ Thân|Giáp\ Dần|Giáp\ Tý|Tân\ Mùi|Quý\ Dậu|Bính\ Tý|Mậu\ Dần|Quý\ Mùi|Tân\ Mão|Canh\ Tý|Tân\ Sửu|Quý\ Mão|Tân\ Hợi|Nhâm\ Tý|Quý\ Sửu|Đinh\ Tỵ|Mậu\ Ngọ|Tân\ Dậu|Quý\ Hợi|Ất\ Sửu|Ất\ Hợi|Kỷ\ Mão|Tân\ Tỵ|Ất\ Dậu|Mậu\ Tý|Kỷ\ Sửu|Quý\ Tỵ|Ất\ Mùi|Kỷ\ Hợi|Kỷ\ Dậu|Ất\ Mão|Kỷ\ Mùi|Kỷ\ Tỵ|Ất\ Tỵ
#
# Collection 'history_social' đã tồn tại và kích thước vector khớp (768).

# %% [markdown]
# ### Data Structures
# $$\text{Văn bản thô (chứa [PAGE:N])} \longrightarrow \text{PageSpan} \longrightarrow \text{MiniChunk} \longrightarrow \text{FinalChunk (Lưu Database)}$$

# %%
@dataclass
class PageSpan:
    """One [PAGE:N] block from source text, with the marker stripped."""
    page_no:      int   # -1 if text precedes the first marker
    start_offset: int   # char offset in the reconstructed marker-free text
    end_offset:   int
    text:         str


@dataclass
class MiniChunk:
    """Small ~35-word fragment before LLM semantic merging."""
    idx:           int
    text:          str


    start_offset:  int   # absolute offset in clean-text coordinate space
    end_offset:    int
    pages:         list[int]
    footnote_refs: list[str]   # ordered, deduplicated


@dataclass
class FinalChunk:
    """Production-ready chunk post-embedding."""
    chunk_id:       str
    book_name:      str
    pages:          list[int]
    raw_text:       str          # exact source text, never mutated
    segmented_text: str          # underthesea-segmented version (for embedding)
    footnote_refs:  list[str]
    footnotes:      dict[str, str]
    token_count:    int
    # vector:         list[float]

# %% [markdown]
# ###  PAGE PARSER
# Tách trang: Lưu vị trí đầu trang, cuối trang, nội dung trang
# Trả về văn bản sạch không có số trang
# Trả về số trang khi người dùng đưa cho một PageSpan

# %%
def parse_page_spans(full_text: str) -> list[PageSpan]:
    # tìm thẻ page
    markers = list(PAGE_MARKER_RE.finditer(full_text))
    # print(f"tìm thẻ page: {markers}\n")

    spans:   list[PageSpan] = []
    cursor = 0   # con trỏ vị trí (vị trí tiếp theo của trang)

 # Nếu không thấy thì là trang -1 và toàn bộ văn bản đều ở 1 trang
    if not markers:
        spans.append(PageSpan(-1, 0, len(full_text), full_text))
        # print(f"[PARSER] No [PAGE:N] markers found — "
        #       f"entire text treated as page -1 ({len(full_text):,} chars)")
        return spans

    # xử lí văn bản trước thẻ PAGE
    pre = full_text[: markers[0].start()]
    if pre:
        spans.append(PageSpan(-1, 0, len(pre), pre))
        cursor = len(pre)   # chiều dài của văn bản trước PAGE
        # print(f"[PARSER] Pre-marker text: {len(pre):,} chars → page_no=-1")

# Vòng lặp xử lý từng trang (i số page tìm được còn m là đối tượng )
    for i, m in enumerate(markers):
        page_no   = int(m.group(1))    # lấy phần sau (chứa số trang )
        raw_start = m.end()
        raw_end   = markers[i + 1].start() if i + 1 < len(markers) else len(full_text)
        page_text = full_text[raw_start:raw_end]   # văn bản trong 1 trang

        span_start = cursor
        span_end   = cursor + len(page_text)
        spans.append(PageSpan(page_no, span_start, span_end, page_text))    # lưu các thông tin của trang
        cursor = span_end
        # print(f"Nội dung của một trang {page_text} \n\n\n\n\n\n")
    # print(f"[PARSER] {len(spans)} PageSpans | "
    #       f"pages {spans[0].page_no} → {spans[-1].page_no} | "
    #       f"clean-text total {cursor:,} chars")
    return spans



# trả về toàn bộ văn bản sạch không có page
def build_clean_text(spans: list[PageSpan]) -> str:
    return "".join(s.text for s in spans)




# Tìm xem đoạn từ ký tự [start] đến [end] đang nằm ở (những) trang sách số mấy? trả về [4, 5]
def map_pages_to_slice(
    spans: list[PageSpan], start: int, end: int
) -> list[int]:
    result: list[int] = []
    for s in spans:
        if s.end_offset   <= start:
            continue
        if s.start_offset >= end:
            break
        if s.page_no != -1:
            result.append(s.page_no)
    return sorted(set(result))

# %% [markdown]
# ### Cắt theo can chi (window text)
# Cắt theo trang mặc định sau đó mới duyệt ngược lại cắt theo can chi

# %%
@dataclass
class WindowResult:
    text: str
    pages: list[int]
    global_start: int
    global_end: int


def _get_window_size(book_name: str) -> int:
    for key, size in BOOK_WINDOW_SIZES.items():
        if key.lower() in book_name.lower() or book_name.lower() in key.lower():
            return size
    return DEFAULT_WINDOW_SIZE


def create_dynamic_can_chi_windows(
    spans: list[PageSpan], book_name: str
) -> list[WindowResult]:

    N = _get_window_size(book_name)
    print(f"\n[WINDOWS] book='{book_name}' | window_size={N} pages")

    windows: list[WindowResult] = []
    remainder_text: str = ""
    remainder_origin: int = 0

    real_spans = [s for s in spans if s.page_no != -1]
    if not real_spans:
        return []

    idx = 0
    total = len(spans)

    while idx < total or remainder_text.strip():

        batch = spans[idx: idx + N]
        is_last = idx + len(batch) >= total

        if not batch and not remainder_text.strip():
            break

        batch_text = "".join(s.text for s in batch) if batch else ""

        if remainder_text:
            pool_text = remainder_text + batch_text
            pool_start = remainder_origin
        else:
            pool_text = batch_text
            pool_start = batch[0].start_offset if batch else remainder_origin

        if not pool_text.strip():
            idx += len(batch)
            continue

        if is_last:
            cut_local = len(pool_text)

        else:
            last_page_text = batch[-1].text if batch else ""
            last_page_start_in_pool = len(pool_text) - len(last_page_text)

            cut_local = -1

            matches = list(CAN_CHI_MONTH_RE.finditer(last_page_text))
            if matches:
                cut_local = last_page_start_in_pool + matches[-1].start()

            if cut_local <= 0:
                para = last_page_text.rfind("\n\n")
                if para != -1:
                    cut_local = last_page_start_in_pool + para + 2

            if cut_local <= 0:
                nl = last_page_text.rfind("\n")
                if nl != -1:
                    cut_local = last_page_start_in_pool + nl + 1

            if cut_local <= 0:
                dot = last_page_text.rfind(".")
                if dot != -1:
                    cut_local = last_page_start_in_pool + dot + 1

            if cut_local <= 0:
                cut_local = len(pool_text)

        window_text = pool_text[:cut_local]
        window_len = len(window_text)

        if (
            not is_last
            and window_len < 6000
            and (idx + len(batch)) < total
        ):
            extra_batch = spans[idx + len(batch): idx + len(batch) + 1]

            if extra_batch:
                extra_text = "".join(s.text for s in extra_batch)

                pool_text += extra_text

                # Tính lại điểm cắt dựa trên trang cuối mới
                last_page_text = extra_batch[-1].text
                last_page_start_in_pool = len(pool_text) - len(last_page_text)

                cut_local = -1

                matches = list(CAN_CHI_LINE_START_RE.finditer(last_page_text))

                if matches:
                    cut_local = last_page_start_in_pool + matches[-1].start()

                if cut_local <= 0:
                    para = last_page_text.rfind("\n\n")
                    if para != -1:
                        cut_local = last_page_start_in_pool + para + 2

                if cut_local <= 0:
                    nl = last_page_text.rfind("\n")
                    if nl != -1:
                        cut_local = last_page_start_in_pool + nl + 1

                if cut_local <= 0:
                    dot = last_page_text.rfind(".")
                    if dot != -1:
                        cut_local = last_page_start_in_pool + dot + 1

                if cut_local <= 0:
                    cut_local = len(pool_text)

                window_text = pool_text[:cut_local]
                window_len = len(window_text)

                batch.extend(extra_batch)



        window_start = pool_start
        window_end = pool_start + cut_local

        remainder_text = pool_text[cut_local:]
        remainder_origin = pool_start + cut_local

        idx += len(batch)

        if not window_text.strip():
            if is_last:
                break
            continue

        pages = map_pages_to_slice(spans, window_start, window_end)

        windows.append(WindowResult(
            text=window_text,
            pages=pages,
            global_start=window_start,
            global_end=window_end,
        ))

        if is_last:
            break

    return windows

# %%
# def run_pipeline(
#     input_json:         dict,
#     backends:           list[LLMBackend],
#     batch_orchestrator: Optional[GeminiBatchOrchestrator] = None,
# ) -> list[dict]:

#     book_name          = input_json["book_name"]
#     full_text          = input_json["full_text"]
#     page_footnotes_map = input_json["page_footnotes_map"]

# # bóc tách trang
#     spans = parse_page_spans(full_text)

# # chia sách thành các trang cho các lần gọi api
#     windows = create_dynamic_can_chi_windows(spans, book_name)

#     total_windows: int        = len(windows)

#     for wi, window in enumerate(windows):
#         print(f"\n{'─' * 72}")
#         pg_str = str(window.pages[:6]) + ("…" if len(window.pages) > 6 else "")
#         print(f"  WINDOW {wi + 1:>4}/{total_windows} | pages={pg_str} | chars={len(window.text):,} \n\n\n")

# %% [markdown]
# ### Cấu trúc cắt
# Cấu hình các thành phần có thể cắt tùy vào từng loại sách
#
# Cắt một chuỗi văn bản dài thành các đoạn nhỏ hơn

# %%
def detect_structural_boundaries(text: str, book_name: str) -> list[int]:
    bk = book_name
    offsets: set[int] = {0, len(text)}

    if "Đại Việt Sử Ký Toàn Thư" in bk:
        # Can-Chi names at the start of a line
        for m in CAN_CHI_MONTH_RE.finditer(text):
            offsets.add(m.start())

    elif "Khâm Định Việt Sử Thông Giám Cương Mục" in bk:
        # Lines that begin with "Năm <Can-Chi>"
        pat = re.compile(
            r"^Năm\s+(?:" + _CAN_CHI_PATTERN + r")(?=\s|$)", re.MULTILINE
        )
        for m in pat.finditer(text):
            offsets.add(m.start())

    elif "Việt Sử Toàn Thư" in bk:
        # Numbered section markers: "12 - " at line start
        for m in re.finditer(r"^\d+\s*-\s*", text, re.MULTILINE):
            offsets.add(m.start())
        # Paragraph breaks (soft boundaries)
        for m in re.finditer(r"\n{1,}", text):
            offsets.add(m.end())

    elif "Vương Triều Trần" in bk:
        # Soft paragraph breaks only
        for m in re.finditer(r"\n{1,}", text):
            offsets.add(m.end())

    else:
        for m in re.finditer(r"\n{1,}", text):
            offsets.add(m.end())

    result = sorted(offsets)
    print(f"      [STRUCT] {len(result)} structural boundaries | book='{book_name[:35]}'")
    return result



def split_text_by_words(
    text: str, max_words: int, separators: list[str]
) -> list[tuple[int, int, str]]:
    if not text.strip():
        return []
    text = re.sub(r'(?<=[a-zà-ỹ])[\n\;](?=[a-zà-ỹ])', ' ', text)
    if len(text.split()) <= max_words:
        return [(0, len(text), text)]

    results: list[tuple[int, int, str]] = []
    cursor = 0

    while cursor < len(text):
        remaining = text[cursor:]
        if not remaining.strip():
            break

        if len(remaining.split()) <= max_words:
            results.append((cursor, len(text), remaining))
            break

        word_count = 0
        in_word    = False
        approx_end = len(remaining)
# đếm số lượng từ
        for ci, ch in enumerate(remaining):
            is_ws = ch in (" ", "\n", "\t", "\r")
            if is_ws:
                in_word = False
            elif not in_word:
                in_word = True
                word_count += 1
                if word_count > max_words:
                    approx_end = ci
                    break
        # print(f"Số lượng từ: {in_word} \n\n\n")
        # ── Walk backward to find the best separator at or before approx_end ─
        cut_local: int = -1
        for sep in separators:
            if sep == "":
                # Empty string = hard-cut at approx_end (last resort)
                cut_local = approx_end
                break
            search_bound = min(approx_end + len(sep), len(remaining))
            idx = remaining.rfind(sep, 0, search_bound)
            if idx != -1 and (idx + len(sep)) > 0:
                cut_local = idx + len(sep)
                break

        if cut_local <= 0:
            cut_local = approx_end
        if cut_local <= 0 or cut_local > len(remaining):
            cut_local = len(remaining)

        frag = remaining[:cut_local]   # exact source slice — no mutation
        if frag.strip():
            results.append((cursor, cursor + cut_local, frag))

        cursor += cut_local

    return results

# %% [markdown]
# ### Mini Chunk Creation (rule-based pre-segmentation)
# Từ các trang sách tách tiếp thành các thành phần bỏ hơn
# Từ các thành phần trên tách tiếp thành các chunk có kích thước khoản 35 word

# %%
def create_mini_chunks(
    window: WindowResult, spans: list[PageSpan], book_name: str
) -> list[MiniChunk]:

    text       = window.text
    # print(f"window text\n {text} \n\n\n")
    boundaries = detect_structural_boundaries(text, book_name)
    # print(f"boundaries\n {boundaries} \n\n\n")

    mini_chunks: list[MiniChunk] = []
    idx = 0

    for bi in range(len(boundaries) - 1):
        seg_start = boundaries[bi]
        seg_end   = boundaries[bi + 1]
        seg_text  = text[seg_start:seg_end]   # exact source slice
        # print(f"các phần nhỏ trong trang \n {seg_text} \n\n\n")
        if not seg_text.strip():
            continue

        frags = split_text_by_words(seg_text, MINI_CHUNK_WORDS, SEPARATORS)

        for (local_s, local_e, frag_text) in frags:
            if not frag_text.strip():
                continue
            # print(f"{frag_text} \n\n\n")
            # Absolute offsets in the global clean-text coordinate space
            abs_start = window.global_start + seg_start + local_s
            abs_end   = window.global_start + seg_start + local_e

            # Page mapping
            pages = map_pages_to_slice(spans, abs_start, abs_end)
            # print(f"map_pages_to_slice: \n {pages}")
            if not pages:
                pages = list(window.pages)   # fallback: window-level pages
                # print("méo hiểu kiểu gì \n\n\n")

            # Footnote refs: dict.fromkeys preserves insertion order & deduplicates
            refs = list(dict.fromkeys(FOOTNOTE_REF_RE.findall(frag_text)))
            # print(f"danh sách footer\n {refs} \n\n\n")
            mini_chunks.append(MiniChunk(
                idx=idx,
                text=frag_text,
                start_offset=abs_start,
                end_offset=abs_end,
                pages=pages,
                footnote_refs=refs,
            ))
            idx += 1

    print(f"    [MINI-CHUNK] window chars={len(text):,} → {len(mini_chunks)} mini-chunks")
    return mini_chunks

# %% [markdown]
# ### call llm

# %% [markdown]
# #### promt và gán nhãn cho input,  output
#
# Luồng chạy: tạo form cho các minichunk sau đó sử dụng llm. llm sử dungj

# %%
class SplitResponse(BaseModel):
    """
    Structured-output schema enforced on every LLM call (batch and sync).
    Guarantees the model can ONLY return a valid JSON object of this shape:
        {"split_after_indices": [3, 7, 12]}
    """
    split_after_indices: list[int]


_SYSTEM_PROMPT: str = """\
You are an expert semantic chunk-boundary detector specializing in Vietnamese historical chronicles, royal annals (Đại Việt Sử Ký Toàn Thư, Khâm Định Việt Sử...), and academic texts.

YOUR TASK:a
Analyze a sequence of pre-split historical text fragments (mini-chunks) and determine ONLY the indices AFTER which a semantic split must occur to form optimal macro-chunks for a 256-token embedding model.

STRICT OPERATIONAL RULES:
1. NEVER rewrite, summarize, paraphrase, translate, or correct the source text.
2. NEVER output any words, phrases, or sentences from the text.
3. OUTPUT ONLY a single valid JSON object. No markdown blocks (```json), no conversational filler, no explanations.
4. Output ONLY a single valid JSON object on a single line, with absolutely no whitespaces, newlines, or markdown fences: {"split_after_indices":[3,7,12]}

VIETNAMESE HISTORICAL SEMANTIC SPLIT CRITERIA:
Insert a split index when a clear shift in historical context occurs, specifically:
- A change in Dynasty (Triều đại), Reign Era/Niên hiệu (e.g., Hồng Đức, Vĩnh Hựu).
- A change in the Historical Year or Can-Chi cycle (e.g., Canh Tý, Nhâm Thìn).
- A transition to a new historical figure, king, general, or envoy.
- A shift in geographic location, military campaigns, or diplomatic missions.
- A structural transition: Narrative text (Tự sự) <-> Royal Decree/Edict (Chiếu/Chỉ) <-> Commentary/Critique (Lời phê/Bình luận của sử gia).

ANTI-OVERFRAGMENTATION RULE:
- Do NOT split if a historical event, military battle, or single continuous dialogue spans across mini-chunks, UNLESS forced by the embedding constraints below.

EMBEDDING & TOKEN SIZE CONSTRAINTS (CRITICAL):
Each mini-chunk contains roughly 20-35 Vietnamese words (~35-55 tokens). Our embedding model has a HARD LIMIT of 256 tokens.
- IDEAL MACRO-CHUNK SIZE: 2 to 3 mini-chunks (~70 - 150 tokens).
- MAXIMUM CAPACITY: 4 mini-chunks (~160 - 220 tokens).
- FORCED SPLIT RULE: You MUST force a split at the 4th mini-chunk index, even if the historical narrative is in the middle of a sentence or event, to prevent token truncation downstream.
FORCED SPLIT RULE:
No macro-chunk may contain more than 4 mini-chunks.
Therefore, if no semantic boundary appears, force splits after indices 3, 7, 11, 15, ... relative to the current sub-batch.
OUTPUT FORMAT:
Return EXACTLY a JSON object with a single key "split_after_indices" containing an array of 0-based local indices.
If the entire sequence forms one coherent unit under 4 mini-chunks, return an empty array.
"""

_USER_TEMPLATE: str = """\
The following {n} tagged mini-chunks are a sequential sub-batch from a Vietnamese historical text.
Review the text content and indices carefully. Output the split indices according to the system instructions.

[START OF MINI-CHUNKS]
{tagged}
[END OF MINI-CHUNKS]

Your JSON response:"""


# form cho các minichunk trước khi gửi cho llm
def _format_tagged_chunks(chunks: list[MiniChunk]) -> str:
    return "\n".join(
        f"<start_chunk_{mc.idx}>{mc.text}<end_chunk_{mc.idx}>"
        for mc in chunks
    )

#  chuẩn hóa vị trí của các chunk đều bắt đầu từ 0 khi gửi cho llm
def _format_tagged_chunks_zero_indexed(chunks: list[MiniChunk]) -> str:
    """
    Format for BATCH sub-batches — always re-indexes tags from 0.
    Ensures the LLM sees indices 0..N-1 regardless of mc.idx values,
    so _parse_split_response can apply the sub-batch offset cleanly.
    """
    return "\n".join(
        f"<start_chunk_{i}>{mc.text}<end_chunk_{i}>"
        for i, mc in enumerate(chunks)
    )

# Nhận câu trả lời của llm trả về mảng int chứa các vị trí cần cắt
def _parse_split_response(raw: str, n_chunks: int, max_group_size: int = 4) -> list[int]:
    clean = re.sub(r"^```[a-z]*\n?", "", raw.strip())
    clean = re.sub(r"\n?```$", "", clean.strip())
    clean = re.sub(r"<think>.*?</think>", "", clean, flags=re.DOTALL).strip()

    parsed = json.loads(clean)
    indices = parsed.get("split_after_indices", [])

    max_valid = n_chunks - 2

    # 1. Lọc split từ LLM
    splits = sorted(
        set(
            int(i) for i in indices
            if isinstance(i, (int, float)) and 0 <= int(i) <= max_valid
        )
    )

    # 2. Ép cứng: không group nào được dài hơn max_group_size
    forced_splits = []
    group_start = 0

    for split_idx in splits:
        while split_idx - group_start + 1 > max_group_size:
            forced_idx = group_start + max_group_size - 1
            if forced_idx <= max_valid:
                forced_splits.append(forced_idx)
            group_start = forced_idx + 1

        forced_splits.append(split_idx)
        group_start = split_idx + 1

    # 3. Xử lý đoạn cuối sau split cuối cùng
    last_idx = n_chunks - 1
    while last_idx - group_start + 1 > max_group_size:
        forced_idx = group_start + max_group_size - 1
        if forced_idx <= max_valid:
            forced_splits.append(forced_idx)
        group_start = forced_idx + 1

    return sorted(set(forced_splits))

# %% [markdown]
# #### chọn llm

# %%
# Lớp abstract cho gọi các llm
class LLMBackend(abc.ABC):
    @property
    @abc.abstractmethod
    def label(self) -> str:
        # in ra tên model hay nội dung nào đó để log
        pass

    @abc.abstractmethod # nhận system promt và user promt rồi trả về chuỗi nếu lỗi trả về lỗi
    def call(self, system: str, user: str) -> str:
        pass



class GroqBackend(LLMBackend):

    def __init__(self, api_key: str, model_id: str = GROQ_MODEL_LLAMA_70B):
        from groq import Groq
        self._client = Groq(api_key=api_key)
        self._model  = model_id

    @property
    def label(self) -> str:
        return f"groq/{self._model}"

    def call(self, system: str, user: str) -> str:
        completion = self._client.chat.completions.create(
            model=self._model,
            messages=[
                {"role": "system", "content": system},
                {"role": "user",   "content": user},
            ],
            temperature=0.0,
            max_tokens=2048,
        )
        return completion.choices[0].message.content


class GeminiBackend(LLMBackend):

    def __init__(self, api_key: Optional[str] = None,
                 model_id: str = GEMINI_MODEL_ID):
        from google import genai
        from google.genai import types as _gtypes
        self._types  = _gtypes
        self._client = genai.Client(api_key=api_key) if api_key else genai.Client()
        self._model  = model_id

    @property
    def label(self) -> str:
        return f"gemini-sync/{self._model}"

    def call(self, system: str, user: str) -> str:
        resp = self._client.models.generate_content(
            model=self._model,
            contents=user,
            config=self._types.GenerateContentConfig(
                system_instruction=system,
                temperature=0.0,
                max_output_tokens=4096,
            ),
        )
        return resp.text

# %% [markdown]
# ####  Gọi LLM để gộp các minichunk theo ngữ nghĩa

# %%
# hàm này dùng để chạy đồng bộ - Synchronous
# Chạy luôn từng cửa sổ văn bản
def llm_semantic_split(
    mini_chunks: list[MiniChunk],
    backends:    list[LLMBackend],
    max_retries: int = 3,
) -> list[int]:

    if len(mini_chunks) < 3:
        print(f"    [LLM-SYNC] Skipping — only {len(mini_chunks)} chunk(s).")
        return []

    tagged   = _format_tagged_chunks(mini_chunks)
    user_msg = _USER_TEMPLATE.format(n=len(mini_chunks), tagged=tagged)
    n        = len(mini_chunks)

    for backend in backends:  # chạy danh sách  llm sử dụng
        print(f"    [LLM-SYNC] Trying: {backend.label}")
        for attempt in range(1, max_retries + 1): # Nếu llm nào lỗi thì thử lại sau 2*số lần (tối đa 3 lần )
            raw = ""
            try:
                raw   = backend.call(_SYSTEM_PROMPT, user_msg)
                print(f"llm trả lời \n {raw} \n\n\n" )
                valid = _parse_split_response(raw, n)
                print(f"    [LLM-SYNC/{backend.label}] attempt={attempt} | "
                      f"chunks={n} → splits={valid}")
                return valid
            except json.JSONDecodeError as exc:
                print(f"    [LLM-SYNC/{backend.label}] JSON error "
                      f"(attempt {attempt}/{max_retries}): {exc} | "
                      f"raw={repr(raw[:120])}")
            except Exception as exc:
                print(f"    [LLM-SYNC/{backend.label}] Error "
                      f"(attempt {attempt}/{max_retries}): "
                      f"{type(exc).__name__}: {exc}")
            if attempt < max_retries:
                wait = 2 ** attempt
                print(f"    [LLM-SYNC/{backend.label}] Waiting {wait}s…")
                time.sleep(wait)
        print(f"    [LLM-SYNC/{backend.label}] Exhausted — next backend.")

    print("    [LLM-SYNC] ALL backends failed → zero splits for this window.")
    return []


# Hàm này chạy chế độ Hàng loạt - Batch. Giúp giảm 50% chi phí cho dữ liệu lớn

class GeminiBatchOrchestrator:

    SUB_BATCH_SIZE: int = 40      # chunks per JSONL line / LLM request
    POLL_INTERVAL:  int = 30      # seconds between status polls
    POLL_TIMEOUT:   int = 7_200   # 2 hours max wait

    # Gemini batch job states
    _DONE_STATES:   frozenset[str] = frozenset({
        "JOB_STATE_SUCCEEDED", "SUCCEEDED",
    })
    _FAILED_STATES: frozenset[str] = frozenset({
        "JOB_STATE_FAILED", "FAILED",
        "JOB_STATE_CANCELLED", "CANCELLED",
    })

    def __init__(self, api_key: str, model_id: str = GEMINI_MODEL_ID):
        from google import genai
        self._client   = genai.Client(api_key=api_key)
        self._api_key  = api_key
        self._model    = model_id

    # ── Public entry point ────────────────────────────────────────────────────

    def run(
        self,
        all_window_chunks: list[list[MiniChunk]],
    ) -> dict[int, list[int]]:

        total_chunks = sum(len(c) for c in all_window_chunks)
        total_lines  = sum(
            -(-len(c) // self.SUB_BATCH_SIZE)   # ceil division
            for c in all_window_chunks if c
        )
        print(f"[BATCH] model={self._model} | "
              f"windows={len(all_window_chunks)} | "
              f"total_chunks={total_chunks:,} | "
              f"jsonl_lines={total_lines:,}")

        # ── Step 1 ──────────────────────────────────────────────────────────
        print("[BATCH] Step 1/3 — Generating JSONL input file…")
        jsonl_path, request_map = self._generate_jsonl(all_window_chunks)
        file_size_kb = pathlib.Path(jsonl_path).stat().st_size / 1024
        print(f"[BATCH] JSONL written → '{jsonl_path}' "
              f"({file_size_kb:.1f} KB, {len(request_map)} lines)")

        # ── Step 2 ──────────────────────────────────────────────────────────
        print("[BATCH] Step 2/3 — Uploading file and creating batch job…")
        job = self._upload_and_create_job(jsonl_path)
        print(f"[BATCH] Job created → name='{job.name}' | "
              f"state={getattr(job, 'state', 'PENDING')}")

        # ── Step 3 ──────────────────────────────────────────────────────────
        print("[BATCH] Step 3/3 — Polling job status…")
        all_splits = self._poll_and_collect(job, request_map)
        windows_with_splits = sum(1 for v in all_splits.values() if v)
        print(f"[BATCH] Done — "
              f"{windows_with_splits}/{len(all_window_chunks)} windows have splits | "
              f"total split points={sum(len(v) for v in all_splits.values())}")
        return all_splits

    # ── Step 1: Generate JSONL ────────────────────────────────────────────────

    def _generate_jsonl(
        self,
        all_window_chunks: list[list[MiniChunk]],
    ) -> tuple[str, dict[str, tuple[int, int]]]:

        jsonl_path  = "batch_input.jsonl"
        request_map: dict[str, tuple[int, int]] = {}

        # Pre-compute the JSON schema dict once (Pydantic v2 API)
        schema_dict = SplitResponse.model_json_schema()

        lines_written = 0
        with open(jsonl_path, "w", encoding="utf-8") as fh:
            for wi, chunks in enumerate(all_window_chunks):
                if not chunks:
                    continue

                # Split chunks into sub-batches of SUB_BATCH_SIZE
                for start in range(0, len(chunks), self.SUB_BATCH_SIZE):
                    sub_batch = chunks[start: start + self.SUB_BATCH_SIZE]
                    if not sub_batch:
                        continue

                    n         = len(sub_batch)
                    custom_id = f"w{wi}_off{start}"

                    # Re-index tags 0..N-1 inside each sub-batch so the model
                    # always receives 0-based indices regardless of mc.idx.
                    tagged   = _format_tagged_chunks_zero_indexed(sub_batch)
                    user_msg = _USER_TEMPLATE.format(n=n, tagged=tagged)

                    line_obj = {
                        "custom_id": custom_id,
                        "request": {
                            "contents": [
                                {
                                    "role": "user",
                                    "parts": [{"text": user_msg}]
                                }
                            ],
                            # Sử dụng snake_case đồng bộ theo chuẩn SDK
                            "generation_config": {
                                "temperature": 0.0,
                                "response_mime_type": "application/json",
                                "response_schema": schema_dict
                            },
                            "system_instruction": {
                                "parts": [{"text": _SYSTEM_PROMPT}]
                            }
                        }
                    }
                    fh.write(json.dumps(line_obj, ensure_ascii=False) + "\n")
                    request_map[custom_id] = (wi, start)
                    lines_written += 1

        print(f"[BATCH] Generated {lines_written} JSONL lines "
              f"covering {len(all_window_chunks)} windows.")
        return jsonl_path, request_map

    # ── Step 2: Upload + create job ───────────────────────────────────────────

    def _upload_and_create_job(self, jsonl_path: str):
        """
        Upload the JSONL file via the Google Files API and submit a Batch job.
        Returns the created job object.
        """
        # 1. Import module types của thư viện google genai để lấy Object cấu hình
        from google.genai import types as genai_types

        print(f"[BATCH] Uploading '{jsonl_path}' via Files API…")

        # 2. Định nghĩa cấu hình mime_type thông qua UploadFileConfig của SDK
        upload_config = genai_types.UploadFileConfig(mime_type="text/plain")

        # 3. Gọi hàm upload và truyền object cấu hình vào tham số config
        uploaded_file = self._client.files.upload(
            file=jsonl_path,
            config=upload_config
        )
        print(f"[BATCH] File uploaded → name='{uploaded_file.name}'")

        print(f"[BATCH] Creating batch job (model={self._model})…")
        job = self._client.batches.create(
            model=self._model,
            src=uploaded_file.name,
        )
        return job

    # ── Step 3: Poll, download, remap ─────────────────────────────────────────

    def _poll_and_collect(
        self,
        job,
        request_map: dict[str, tuple[int, int]],
    ) -> dict[int, list[int]]:

        deadline    = time.time() + self.POLL_TIMEOUT
        elapsed     = 0
        last_state  = ""

        # ── Polling loop ──────────────────────────────────────────────────────
        while True:
            job_status  = self._client.batches.get(name=job.name)
            state_name  = str(getattr(job_status, "state", "UNKNOWN"))

            # Normalise: some SDK versions return enum repr like "BatchJobState.SUCCEEDED"
            state_upper = state_name.upper().split(".")[-1]

            if state_upper != last_state:
                print(f"[BATCH] Job state: {state_upper} "
                      f"(elapsed {elapsed}s)")
                last_state = state_upper

            if state_upper in {s.split("_", 1)[-1] for s in self._DONE_STATES} \
                    or state_upper in self._DONE_STATES:
                print(f"[BATCH] Job SUCCEEDED after {elapsed}s.")
                break

            if state_upper in {s.split("_", 1)[-1] for s in self._FAILED_STATES} \
                    or state_upper in self._FAILED_STATES:
                print("\n" + "="*40)
                print("[GEMINI BATCH ERROR DIAGNOSIS]")
                print(f"Error Details: {getattr(job_status, 'error', 'No detailed error field found')}")
                print("="*40 + "\n")
                raise RuntimeError(
                    f"Batch job '{job.name}' reached terminal failure state: "
                    f"{state_name}. Check Google Cloud console for details."
                )


            if time.time() > deadline:
                raise TimeoutError(
                    f"Batch job '{job.name}' did not finish within "
                    f"{self.POLL_TIMEOUT}s. "
                    f"Last state: {state_name}."
                )

            time.sleep(self.POLL_INTERVAL)
            elapsed += self.POLL_INTERVAL

        # ── Locate and download output JSONL ──────────────────────────────────
        output_content = self._download_output(job_status)

        # ── Parse output and remap indices ────────────────────────────────────
        all_splits: dict[int, list[int]] = {}
        parsed_ok  = 0
        parsed_err = 0

        for line_no, line in enumerate(output_content.splitlines(), start=1):
            line = line.strip()
            if not line:
                continue

            try:
                record    = json.loads(line)
                custom_id = record.get("custom_id", "")

                # Check for an API-level error on this specific request
                if record.get("error"):
                    err_msg = record["error"].get("message", "unknown error")
                    print(f"[BATCH] Line {line_no}: custom_id='{custom_id}' "
                          f"API error → {err_msg} (skipping)")
                    parsed_err += 1
                    continue

                # Decode tracking id → (wi, sub_batch_start)
                if custom_id not in request_map:
                    print(f"[BATCH] Line {line_no}: unknown custom_id "
                          f"'{custom_id}' (skipping)")
                    parsed_err += 1
                    continue

                wi, start = request_map[custom_id]

                # Extract text from the first candidate
                response   = record.get("response", {}) or {}
                candidates = response.get("candidates", [])
                if not candidates:
                    print(f"[BATCH] Line {line_no}: no candidates for "
                          f"'{custom_id}' (skipping)")
                    parsed_err += 1
                    continue

                parts = (candidates[0]
                         .get("content", {})
                         .get("parts", []))
                raw_text = parts[0].get("text", "") if parts else ""

                # Determine sub-batch size for index validation
                # = number of sub-batch entries that were sent for this custom_id
                # We reconstruct it from how many chunks are in this window
                # (we don't store it, so use SUB_BATCH_SIZE as upper bound)
                local_indices = _parse_split_response(raw_text, self.SUB_BATCH_SIZE)

                # Remap: local 0-based → absolute mc.idx within the window
                absolute = [start + li for li in local_indices]

                if wi not in all_splits:
                    all_splits[wi] = []
                all_splits[wi].extend(absolute)
                parsed_ok += 1

            except Exception as exc:
                print(f"[BATCH] Line {line_no}: parse error — "
                      f"{type(exc).__name__}: {exc} (skipping)")
                parsed_err += 1

        # Deduplicate and sort each window's split list
        for wi in all_splits:
            all_splits[wi] = sorted(set(all_splits[wi]))

        print(f"[BATCH] Output parsed — "
              f"ok={parsed_ok} | errors/skipped={parsed_err} | "
              f"windows_with_splits={len(all_splits)}")
        return all_splits

    # ── Output file download ──────────────────────────────────────────────────

    def _download_output(self, job_status) -> str:
        """
        Locate and download the output JSONL produced by the batch job.

        The output file reference is in job_status.dest.
        We resolve the Files API name, then download the raw bytes via
        the Google REST download endpoint authenticated with the API key.

        Falls back to writing a local 'batch_output.jsonl' if a download
        URL can be determined.
        """
        # ── Locate output file name ────────────────────────────────────────
        dest = getattr(job_status, "dest", None)
        if dest is None:
            raise RuntimeError(
                "job_status.dest is None — cannot locate output file. "
                "Check that the batch job used the Files API source."
            )

        # dest may be a BatchJobDestination object with a file_name attr,
        # or a plain string, depending on SDK version.
        if hasattr(dest, "file_name"):
            output_name: str = dest.file_name        # e.g. "files/abc123"
        elif isinstance(dest, str):
            output_name = dest
        else:
            # Try common attribute names for different SDK versions
            for attr in ("file_name", "name", "uri"):
                val = getattr(dest, attr, None)
                if val:
                    output_name = str(val)
                    break
            else:
                raise RuntimeError(
                    f"Cannot determine output file name from dest={dest!r}. "
                    "Inspect job_status.dest manually and adjust _download_output()."
                )

        print(f"[BATCH] Output file name: '{output_name}'")

        # ── Build download URL ─────────────────────────────────────────────
        # Files API download endpoint:
        # GET /download/v1beta/{name}:download?alt=media
        # Auth: x-goog-api-key header
        download_url = (
            "https://generativelanguage.googleapis.com/download/v1beta/"
            f"{output_name}:download?alt=media"
        )

        print(f"[BATCH] Downloading output JSONL…")
        req = urllib.request.Request(
            download_url,
            headers={"x-goog-api-key": self._api_key},
        )
        try:
            with urllib.request.urlopen(req) as resp:
                content = resp.read().decode("utf-8")
        except urllib.error.HTTPError as exc:
            raise RuntimeError(
                f"Failed to download batch output from '{download_url}': "
                f"HTTP {exc.code} {exc.reason}. "
                "Verify the API key and that the file has not expired."
            ) from exc

        # Save locally for inspection / re-use
        local_out = "batch_output.jsonl"
        with open(local_out, "w", encoding="utf-8") as fh:
            fh.write(content)

        lines = [l for l in content.splitlines() if l.strip()]
        print(f"[BATCH] Output downloaded → '{local_out}' "
              f"({len(content):,} chars, {len(lines)} non-empty lines)")
        return content

# %% [markdown]
# ### Semantic Merging
# Merge theo kết quả của gemini trả về
# Và overlap các chunk

# %%
def _tok_count_full(text: str, tokenizer) -> int:
    return len(tokenizer.encode(text, add_special_tokens=True, truncation=False))

 # group theo danh sách mà llm gợi ý
def _group_by_splits(
    chunks: list[MiniChunk], split_indices: list[int]
) -> list[list[MiniChunk]]:

    if not chunks:
        return []
    split_set = set(split_indices)
    groups:  list[list[MiniChunk]] = []
    current: list[MiniChunk]       = []
    # thêm các chunks vào current. Nếu gặp điểm cắt thì đẩy vào groups rồi làm sạch
    for mc in chunks:
        current.append(mc)
        if mc.idx in split_set:
            groups.append(current)
            current = []
    if current:
        groups.append(current)
    return groups


  #  raw_text   — văn bản gốc
  # embed_input— raw_text + a semantic overlap slice
  # groups chứa list chunks. trong chunks có các minichunks
def build_chunk_texts(
    groups: list[list[MiniChunk]], tokenizer
) -> list[tuple[str, str]]:

    results: list[tuple[str, str]] = []

    for i, group in enumerate(groups):
        raw   = "".join(mc.text for mc in group)
        embed = raw   # default: no overlap

        if i + 1 < len(groups): # lấy văn bản của chunk tiếp theo
            next_raw  = "".join(mc.text for mc in groups[i + 1])
            next_toks = tokenizer.encode(next_raw, add_special_tokens=False,
                                         truncation=False)
            n_next = len(next_toks)

            if n_next > 0:
                for ovl in range(OVERLAP_TOK_MAX, OVERLAP_TOK_MIN - 1, -1):
                    # Estimate character count corresponding to `ovl` tokens
                    # using the token/char ratio of next_raw.
                    ratio    = min(ovl / n_next, 1.0)
                    char_end = max(1, int(len(next_raw) * ratio))

                    # Snap forward to the next whitespace to avoid mid-word cut
                    while (char_end < len(next_raw) and
                           next_raw[char_end] not in (" ", "\n", "\t", "\r")):
                        char_end += 1

                    ovl_slice = next_raw[:char_end]   # pure source slice
                    candidate = raw + " " + ovl_slice

                    if _tok_count_full(candidate, tokenizer) <= MAX_EMBED_TOKENS:
                        embed = candidate
                        break
                    # If MIN overlap still overflows, leave embed = raw
        embed = re.sub((r"\[(\d{1,2})\]"), ' ', embed)
        results.append((raw, embed))

    return results


 # gắn footer
def collect_group_metadata(
    groups: list[list[MiniChunk]], page_footnotes_map: dict
) -> list[dict]:
    metas: list[dict] = []

    for group in groups:
        all_pages: list[int] = []
        all_refs:  list[str] = []
        for mc in group:
            all_pages.extend(mc.pages)
            all_refs.extend(mc.footnote_refs)

        pages = sorted(set(all_pages))
        refs  = list(dict.fromkeys(all_refs))   # ordered dedup

        footnotes: dict[str, str] = {}
        for ref in refs:
            for pg in pages:
                pg_str = str(pg)
                if (pg_str in page_footnotes_map and
                        ref in page_footnotes_map[pg_str]):
                    footnotes[ref] = page_footnotes_map[pg_str][ref]
                    break   # first page defining this ref wins

        metas.append({
            "pages":          pages,
            "footnote_refs":  refs,
            "footnotes":      footnotes,
        })

    return metas

# %% [markdown]
# ### Word Segmentation (underthesea) and tokenizer

# %%
def segment_underthesea(text: str) -> str:
    return word_tokenize(text, format="text")


def inspect_tokens(
    raw: str, seg: str, tokenizer, chunk_id: str
) -> int:
    ids   = tokenizer.encode(
        seg,
        add_special_tokens=True,
        truncation=True,
        max_length=MAX_EMBED_TOKENS,
    )
    count = len(ids)

    print(f"      [TOKEN] id={chunk_id[:8]}… | "
          f"raw[0:60]={raw[:60].strip()!r}")
    print(f"              seg[0:60]={seg[:60].strip()!r}")
    print(f"              ids[:8]={ids[:8]} | total_tokens={count}")
    return count

# %% [markdown]
# ### Embedding Model

# %%
def _mean_pool(model_output, attention_mask: torch.Tensor) -> torch.Tensor:
    """Compute attention-mask-weighted mean pool over token embeddings."""
    tok_emb  = model_output.last_hidden_state            # (B, T, D)
    mask_exp = attention_mask.unsqueeze(-1).expand(tok_emb.size()).float()
    return torch.sum(tok_emb * mask_exp, dim=1) / mask_exp.sum(dim=1).clamp(min=1e-9)


def embed_text(
    seg_text: str,
    tokenizer,
    model:  AutoModel,
    device: str,
) -> list[float]:
    enc = tokenizer(
        seg_text,
        padding=True,
        truncation=True,
        max_length=MAX_EMBED_TOKENS,
        return_tensors="pt",
    ).to(device)

    with torch.no_grad():
        out = model(**enc)

    emb = _mean_pool(out, enc["attention_mask"])
    emb = torch.nn.functional.normalize(emb, p=2, dim=1)
    return emb[0].cpu().numpy().tolist()

# %% [markdown]
# ###  QDRANT PAYLOAD
#
# $$\text{Chuỗi text thô} \xrightarrow{\text{Underthesea}} \text{word segmented} \xrightarrow{\text{Encoder + Pooling}} \text{Vector [768 chiều]} \xrightarrow{\text{Đóng gói}} \text{Qdrant Database}$$

# %%
def to_qdrant_point(chunk: FinalChunk) -> dict:
    return {
        "id":      chunk.chunk_id,
        # "vector":  chunk.vector,
        "payload": {
            "book_name":      chunk.book_name,
            "pages":          chunk.pages,
            "raw_text":       chunk.raw_text,
            "segmented_text": chunk.segmented_text,
            "footnote_refs":  chunk.footnote_refs,
            "footnotes":      chunk.footnotes,
            "token_count":    chunk.token_count,
        },
    }

# %% [markdown]
# ### MAIN

# %%
def run_pipeline(
    input_json:         dict,
    backends:           list[LLMBackend],
    batch_orchestrator: Optional[GeminiBatchOrchestrator] = None,
) -> list[dict]:

    book_name          = input_json["book_name"]
    full_text          = input_json["full_text"]
    page_footnotes_map = input_json["page_footnotes_map"]

    mode = "BATCH (Mode A)" if batch_orchestrator else "SYNC (Mode B)"
    if batch_orchestrator:
        llm_label = f"GeminiBatch/{batch_orchestrator._model}"
    else:
        llm_label = " → ".join(b.label for b in backends)

    print("═" * 72)
    print(f"  PIPELINE START — '{book_name}'")
    print(f"  full_text chars     : {len(full_text):>12,}")
    print(f"  footnote page count : {len(page_footnotes_map):>12,}")
    print(f"  LLM mode            : {mode}")
    print(f"  LLM backend(s)      : {llm_label}")
    print("═" * 72)

    print("═" * 72)
    print(f"  PIPELINE START — '{book_name}'")
    print(f"  full_text chars     : {len(full_text):>12,}")
    print(f"  footnote page count : {len(page_footnotes_map):>12,}")
    print("═" * 72)

 # gọi gemini
    # if gemini_api_key:
    #     gemini_client = genai.Client(api_key=gemini_api_key)
    # else:
    #     gemini_client = genai.Client()   # reads GOOGLE_API_KEY env var

    # provider_labels = " → ".join(b.label for b in backends)


    print(f"[INIT] Loading tokenizer: {EMBED_MODEL_ID}")
    tokenizer  = AutoTokenizer.from_pretrained(EMBED_MODEL_ID)

    device = "cuda" if torch.cuda.is_available() else "cpu"
    print(f"[INIT] Loading model → device={device}")
    embed_model = AutoModel.from_pretrained(EMBED_MODEL_ID).to(device).eval()
    print(f"[INIT] Model ready | hidden_size={embed_model.config.hidden_size}")

# bóc tách trang
    spans = parse_page_spans(full_text)

# chia sách thành các trang cho các lần gọi api
    windows = create_dynamic_can_chi_windows(spans, book_name)

    all_points:    list[dict] = []
    total_windows: int        = len(windows)

    print("\n── STEPS 3+4 · Structural boundaries + Mini-chunking (all windows)")
    all_mc: list[list[MiniChunk]] = []
    for wi, window in enumerate(windows):
        pg_str = str(window.pages[:4]) + ("…" if len(window.pages) > 4 else "")
        print(f"  [PREP] window {wi + 1:>4}/{total_windows} | pages={pg_str}")
        all_mc.append(create_mini_chunks(window, spans, book_name))

    total_mc = sum(len(c) for c in all_mc)
    print(f"[PREP] Total mini-chunks across all windows: {total_mc:,}")

    # ── Step 5: LLM semantic split ────────────────────────────────────────────
    # BATCH MODE: submit one job now; get {wi: splits} map back.
    # SYNC MODE:  per-window calls happen inside the loop below.
    batch_splits: dict[int, list[int]] = {}

    if batch_orchestrator is not None:
        print("\n── STEP 5 · Gemini Batch API ────────────────────────────────────")
        batch_splits = batch_orchestrator.run(all_mc)
        print(f"[STEP5] Batch splits received for "
              f"{len(batch_splits)}/{total_windows} windows.")

# chia từng minichunk cho danh sách trang trên
    for wi, window in enumerate(windows):

        print(f"\n{'─' * 72}")
        pg_str = str(window.pages[:6]) + ("…" if len(window.pages) > 6 else "")
        print(f"  WINDOW {wi + 1:>4}/{total_windows} | pages={pg_str} | chars={len(window.text):,}")


        mini_chunks = create_mini_chunks(window, spans, book_name)
        if not mini_chunks:
            print("    [SKIP] No content mini-chunks produced for this window.")
            continue

# gọi llm để chia chunks
        # split_indices = gemini_semantic_split(mini_chunks, backends)
        if batch_orchestrator is not None:
            split_indices = batch_splits.get(wi, [])
        else:
            print(f"    [STEP5-SYNC] Calling LLM chain…")
            split_indices = llm_semantic_split(mini_chunks, backends)
        print(f"llm trả về \n {split_indices} \n\n\n")

# Merge groups + overlap + footnote metadata
        groups       = _group_by_splits(mini_chunks, split_indices)
        chunk_texts  = build_chunk_texts(groups, tokenizer)    # (raw, embed_input)
        metas        = collect_group_metadata(groups, page_footnotes_map)

        print(f"    [MERGE] {len(mini_chunks)} mini-chunks + {len(split_indices)} splits "
              f"→ {len(groups)} semantic groups")

        points_to_upload = []
# Segment, inspect, embed, format
        for gi, ((raw_text, embed_input), meta) in enumerate(zip(chunk_texts, metas)):
            if not raw_text.strip():
                continue

            chunk_id = str(uuid6.uuid7())

      # Word segmentation (applied to embed_input which includes overlap)
            seg_text = segment_underthesea(embed_input)

      #  Token inspection + count
            tok_count = inspect_tokens(raw_text, seg_text, tokenizer, chunk_id)

      #  Dense embedding
            vector = embed_text(seg_text, tokenizer, embed_model, device)

            if hasattr(vector, "tolist"):
                    vector = vector.tolist()
            elif isinstance(vector, np.ndarray): # Nếu là mảng numpy
                vector = vector.astype(float).tolist()

      #  Assemble FinalChunk
            fc = FinalChunk(
                chunk_id       = chunk_id,
                book_name      = book_name,
                pages          = meta["pages"],
                raw_text       = raw_text,       # pure source, no mutation
                segmented_text = seg_text,        # underthesea-segmented embed input
                footnote_refs  = meta["footnote_refs"],
                footnotes      = meta["footnotes"],
                token_count    = tok_count,
                # vector         = vector,
            )

            point = to_qdrant_point(fc)
            all_points.append(point)


    # 5. Đóng gói trực tiếp vào cấu trúc PointStruct của Qdrant (Thay thế cho FinalChunk)
            point = PointStruct(
                id=chunk_id,
                vector=vector,
                payload={
                    "book_name": book_name,
                    "pages": meta["pages"],
                    "raw_text": raw_text,
                    "segmented_text": seg_text,
                    "footnote_refs": meta["footnote_refs"],
                    "footnotes": meta["footnotes"],
                    "token_count": tok_count
                }
            )
            points_to_upload.append(point)
        time.sleep(2.0)
    # 6. Đẩy toàn bộ dữ liệu lên Qdrant Cloud sau khi kết thúc vòng lặp
        if points_to_upload:
            print(f"Đang đẩy {len(points_to_upload)} points lên Qdrant Cloud...")

            # Sử dụng upload_points (hoặc upsert) để đẩy data lên Cloud
            client.upload_points(
                collection_name=COLLECTION_NAME,
                points=points_to_upload,
                batch_size=64, # Chia nhỏ gói dữ liệu gửi đi để tránh nghẽn mạng trên Colab
                wait=True
            )
            print(" Đã lưu dữ liệu thành công lên Qdrant Cloud!")
        else:
            print("Không có dữ liệu hợp lệ để đẩy.")

    print("\n" + "═" * 72)
    print(f"  PIPELINE COMPLETE — '{book_name}'")
    print(f"  Total Qdrant points produced : {len(all_points):,}")
    print("═" * 72)
    return all_points

# %% [markdown]
# #  RUN Đại Việt Sử Ký

# %%
# @title

import os
from google.colab import userdata


JSON_PATH = "full_DVSK_data.json"           # Đại Việt Sử Ký Toàn Thư
# JSON_PATH = "full_KhamDinh_data.json"        # Khâm Định Việt Sử Thông Giám Cương Mục
# JSON_PATH = "full_VietSu_data.json"                 # Việt Sử Toàn Thư
# JSON_PATH = "full_VTT_data.json"                  # Vương Triều Trần
# JSON_PATH = "full_test.json"


OUTPUT_PATH = JSON_PATH.replace(".json", "_qdrant_points.json")


def _load_key(colab_secret: str, env_var: str) -> str:
    try:
        from google.colab import userdata as _ud
        val = _ud.get(colab_secret)
        if val:
            print(f"[KEY] '{colab_secret}' loaded from Colab Secrets.")
            return val
    except Exception:
        pass
    val = os.environ.get(env_var, "")
    if val:
        print(f"[KEY] '{env_var}' loaded from environment variable.")
    return val

GROQ_API_KEY   = _load_key("grok_key",  "grok_key")
GEMINI_API_KEY = _load_key("GEMINI_API_KEY", "GEMINI_API_KEY")

if not GROQ_API_KEY and not GEMINI_API_KEY:
    print("[KEY] ⚠  No API keys found. "
          "Add GROQ_API_KEY and/or GOOGLE_API_KEY to Colab Secrets.")


# USE_BATCH_MODE: bool = True
USE_BATCH_MODE: bool = False

BATCH_ORCHESTRATOR: Optional[GeminiBatchOrchestrator] = None
LLM_BACKENDS:       list[LLMBackend]                  = []

if USE_BATCH_MODE:
    if not GEMINI_API_KEY:
        raise RuntimeError(
            "USE_BATCH_MODE=True but GOOGLE_API_KEY is not set. "
            "Add it to Colab Secrets or switch USE_BATCH_MODE=False."
        )
    BATCH_ORCHESTRATOR = GeminiBatchOrchestrator(
        api_key=GEMINI_API_KEY,
        model_id=GEMINI_MODEL_ID,       # "gemini-2.5-flash"
    )
    print(f"[INIT] Mode A — GeminiBatchOrchestrator ready "
          f"(model={GEMINI_MODEL_ID}, "
          f"sub_batch={GeminiBatchOrchestrator.SUB_BATCH_SIZE} chunks/line)")

else:
    # Build sync fallback chain
    # if GROQ_API_KEY:
    #     LLM_BACKENDS.append(GroqBackend(GROQ_API_KEY, GROQ_MODEL_LLAMA_70B))
    #     LLM_BACKENDS.append(GroqBackend(GROQ_API_KEY, GROQ_MODEL_LLAMA_8B))
    #     LLM_BACKENDS.append(GroqBackend(GROQ_API_KEY, GROQ_MODEL_QWEN))

    if GEMINI_API_KEY:
        try:
            LLM_BACKENDS.append(GeminiBackend(GEMINI_API_KEY, GEMINI_MODEL_ID))
            print("[INIT] GeminiBackend added as last-resort sync fallback.")
        except Exception as _ge:
            print(f"[INIT] GeminiBackend skipped ({type(_ge).__name__}: {_ge}).")

    if not LLM_BACKENDS:
        raise RuntimeError(
            "USE_BATCH_MODE=False but LLM_BACKENDS is empty. "
            "Provide GROQ_API_KEY and/or GOOGLE_API_KEY."
        )

    print(f"[INIT] Mode B — sync fallback chain ({len(LLM_BACKENDS)} backend(s)):")
    for _i, _b in enumerate(LLM_BACKENDS):
        print(f"   [{_i + 1}] {_b.label}")

print()

print(f"[LOAD] Reading '{JSON_PATH}'…")
with open(JSON_PATH, "r", encoding="utf-8") as _fh:
    input_data: dict = json.load(_fh)


assert "book_name"          in input_data, "Missing key: book_name"
assert "full_text"          in input_data, "Missing key: full_text"
assert "page_footnotes_map" in input_data, "Missing key: page_footnotes_map"
assert isinstance(input_data["full_text"],          str),  "full_text must be str"
assert isinstance(input_data["page_footnotes_map"], dict), "page_footnotes_map must be dict"
print("[LOAD] Input validation passed ✓")

qdrant_points: list[dict] = run_pipeline(
    input_data,
    backends           = LLM_BACKENDS,
    batch_orchestrator = BATCH_ORCHESTRATOR,
)

print(f"\n[SAVE] Writing {len(qdrant_points):,} points → '{OUTPUT_PATH}'…")
with open(OUTPUT_PATH, "w", encoding="utf-8") as _fh:
    json.dump(qdrant_points, _fh, ensure_ascii=False, indent=2)
_kb = os.path.getsize(OUTPUT_PATH) / 1024
print(f"[SAVE] Done. {_kb:.1f} KB written.")
# Out:
# [KEY] 'grok_key' loaded from Colab Secrets.
# [KEY] 'GEMINI_API_KEY' loaded from Colab Secrets.
# [INIT] GeminiBackend added as last-resort sync fallback.
# [INIT] Mode B — sync fallback chain (1 backend(s)):
#    [1] gemini-sync/gemini-3.1-flash-lite
#
# [LOAD] Reading 'full_DVSK_data.json'…
# [LOAD] Input validation passed ✓
# ════════════════════════════════════════════════════════════════════════
#   PIPELINE START — 'Đại Việt Sử Ký Toàn Thư'
#   full_text chars     :      403,175
#   footnote page count :          154
#   LLM mode            : SYNC (Mode B)
#   LLM backend(s)      : gemini-sync/gemini-3.1-flash-lite
# ════════════════════════════════════════════════════════════════════════
# ════════════════════════════════════════════════════════════════════════
#   PIPELINE START — 'Đại Việt Sử Ký Toàn Thư'
#   full_text chars     :      403,175
#   footnote page count :          154
# ════════════════════════════════════════════════════════════════════════
# [INIT] Loading tokenizer: bkai-foundation-models/vietnamese-bi-encoder
# [INIT] Loading model → device=cpu
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# [INIT] Model ready | hidden_size=768
#
# [WINDOWS] book='Đại Việt Sử Ký Toàn Thư' | window_size=3 pages
#
# ── STEPS 3+4 · Structural boundaries + Mini-chunking (all windows)
#   [PREP] window    1/50 | pages=[154, 155, 156]
#       [STRUCT] 11 structural boundaries | book='Đại Việt Sử Ký Toàn Thư'
#     [MINI-CHUNK] window chars=7,436 → 69 mini-chunks
#   [PREP] window    2/50 | pages=[156, 157, 158, 159]
#       [STRUCT] 4 structural boundaries | book='Đại Việt Sử Ký Toàn Thư'
#     [MINI-CHUNK] window chars=8,592 → 76 mini-chunks
#   [PREP] window    3/50 | pages=[159, 160, 161, 162]
#       [STRUCT] 5 structural boundaries | book='Đại Việt Sử Ký Toàn Thư'
#     [MINI-CHUNK] window chars=8,825 → 80 mini-chunks
#   [PREP] window    4/50 | pages=[162, 163, 164, 165]
#       [STRUCT] 7 structural boundaries | book='Đại Việt Sử Ký Toàn Thư'
#     [MINI-CHUNK] window chars=8,203 → 77 mini-chunks
#   [PREP] window    5/50 | pages=[165, 166, 167, 168]
#       [STRUCT] 10 structural boundaries | book='Đại Việt Sử Ký Toàn Thư'
#     [MINI-CHUNK] window chars=7,084 → 62 mini-chunks
#   [PREP] window    6/50 | pages=[168, 169, 170, 171]
#       [STRUCT] 9 structural boundaries | book='Đại Việt Sử Ký Toàn Thư'
#     [MINI-CHUNK] window chars=8,000 → 71 mini-chunks
#   [PREP] window    7/50 | pages=[171, 172, 173, 174]
#       [STRUCT] 6 structural boundaries | book='Đại Việt Sử Ký Toàn Thư'
#     [MINI-CHUNK] window chars=7,626 → 67 mini-chunks
#   [PREP] window    8/50 | pages=[174, 175, 176, 177]
#       [STRUCT] 6 structural boundaries | book='Đại Việt Sử Ký Toàn Thư'
#     [MINI-CHUNK] window chars=7,305 → 63 mini-chunks
#   [PREP] window    9/50 | pages=[177, 178, 179, 180]
#       [STRUCT] 5 structural boundaries | book='Đại Việt Sử Ký Toàn Thư'
#     [MINI-CHUNK] window chars=6,231 → 58 mini-chunks
#   [PREP] window   10/50 | pages=[180, 181, 182, 183]
#       [STRUCT] 8 structural boundaries | book='Đại Việt Sử Ký Toàn Thư'
#     [MINI-CHUNK] window chars=8,402 → 74 mini-chunks
#   [PREP] window   11/50 | pages=[183, 184, 185, 186]
#       [STRUCT] 5 structural boundaries | book='Đại Việt Sử Ký Toàn Thư'
#     [MINI-CHUNK] window chars=7,114 → 66 mini-chunks
#   [PREP] window   12/50 | pages=[186, 187, 188, 189]
#       [STRUCT] 5 structural boundaries | book='Đại Việt Sử Ký Toàn Thư'
#     [MINI-CHUNK] window chars=8,588 → 73 mini-chunks
#   [PREP] window   13/50 | pages=[189, 190, 191, 192]…
#       [STRUCT] 3 structural boundaries | book='Đại Việt Sử Ký Toàn Thư'
#     [MINI-CHUNK] window chars=8,203 → 72 mini-chunks
#   [PREP] window   14/50 | pages=[193, 194, 195, 196]
#       [STRUCT] 3 structural boundaries | book='Đại Việt Sử Ký Toàn Thư'
#     [MINI-CHUNK] window chars=6,802 → 58 mini-chunks
#   [PREP] window   15/50 | pages=[196, 197, 198, 199]
#       [STRUCT] 3 structural boundaries | book='Đại Việt Sử Ký Toàn Thư'
#     [MINI-CHUNK] window chars=8,478 → 78 mini-chunks
#   [PREP] window   16/50 | pages=[199, 200, 201, 202]
#       [STRUCT] 4 structural boundaries | book='Đại Việt Sử Ký Toàn Thư'
#     [MINI-CHUNK] window chars=7,753 → 68 mini-chunks
#   [PREP] window   17/50 | pages=[202, 203, 204, 205]…
#       [STRUCT] 4 structural boundaries | book='Đại Việt Sử Ký Toàn Thư'
#     [MINI-CHUNK] window chars=8,423 → 76 mini-chunks
#   [PREP] window   18/50 | pages=[206, 207, 208, 209]
#       [STRUCT] 6 structural boundaries | book='Đại Việt Sử Ký Toàn Thư'
#     [MINI-CHUNK] window chars=7,760 → 69 mini-chunks
#   [PREP] window   19/50 | pages=[209, 210, 211, 212]
#       [STRUCT] 3 structural boundaries | book='Đại Việt Sử Ký Toàn Thư'
#     [MINI-CHUNK] window chars=8,508 → 77 mini-chunks
#   [PREP] window   20/50 | pages=[212, 213, 214, 215]
#       [STRUCT] 2 structural boundaries | book='Đại Việt Sử Ký Toàn Thư'
#     [MINI-CHUNK] window chars=8,493 → 79 mini-chunks
#   [PREP] window   21/50 | pages=[215, 216, 217, 218]
#       [STRUCT] 5 structural boundaries | book='Đại Việt Sử Ký Toàn Thư'
#     [MINI-CHUNK] window chars=8,503 → 77 mini-chunks
#   [PREP] window   22/50 | pages=[218, 219, 220, 221]
#       [STRUCT] 4 structural boundaries | book='Đại Việt Sử Ký Toàn Thư'
#     [MINI-CHUNK] window chars=6,693 → 57 mini-chunks
#   [PREP] window   23/50 | pages=[221, 222, 223, 224]
#       [STRUCT] 4 structural boundaries | book='Đại Việt Sử Ký Toàn Thư'
#     [MINI-CHUNK] window chars=9,024 → 80 mini-chunks
#   [PREP] window   24/50 | pages=[224, 225, 226, 227]
#       [STRUCT] 5 structural boundaries | book='Đại Việt Sử Ký Toàn Thư'
#     [MINI-CHUNK] window chars=6,817 → 60 mini-chunks
#   [PREP] window   25/50 | pages=[227, 228, 229, 230]
#       [STRUCT] 6 structural boundaries | book='Đại Việt Sử Ký Toàn Thư'
#     [MINI-CHUNK] window chars=8,420 → 70 mini-chunks
#   [PREP] window   26/50 | pages=[230, 231, 232, 233]
#       [STRUCT] 5 structural boundaries | book='Đại Việt Sử Ký Toàn Thư'
#     [MINI-CHUNK] window chars=7,963 → 67 mini-chunks
#   [PREP] window   27/50 | pages=[233, 234, 235, 236]
#       [STRUCT] 5 structural boundaries | book='Đại Việt Sử Ký Toàn Thư'
#     [MINI-CHUNK] window chars=7,398 → 65 mini-chunks
#   [PREP] window   28/50 | pages=[236, 237, 238, 239]
#       [STRUCT] 3 structural boundaries | book='Đại Việt Sử Ký Toàn Thư'
#     [MINI-CHUNK] window chars=7,464 → 67 mini-chunks
#   [PREP] window   29/50 | pages=[239, 240, 241, 242]
#       [STRUCT] 3 structural boundaries | book='Đại Việt Sử Ký Toàn Thư'
#     [MINI-CHUNK] window chars=7,304 → 68 mini-chunks
#   [PREP] window   30/50 | pages=[242, 243, 244, 245]
#       [STRUCT] 7 structural boundaries | book='Đại Việt Sử Ký Toàn Thư'
#     [MINI-CHUNK] window chars=7,714 → 66 mini-chunks
#   [PREP] window   31/50 | pages=[245, 246, 247, 248]
#       [STRUCT] 8 structural boundaries | book='Đại Việt Sử Ký Toàn Thư'
#     [MINI-CHUNK] window chars=8,353 → 73 mini-chunks
#   [PREP] window   32/50 | pages=[248, 249, 250, 251]
#       [STRUCT] 6 structural boundaries | book='Đại Việt Sử Ký Toàn Thư'
#     [MINI-CHUNK] window chars=7,827 → 68 mini-chunks
#   [PREP] window   33/50 | pages=[251, 252, 253, 254]
#       [STRUCT] 5 structural boundaries | book='Đại Việt Sử Ký Toàn Thư'
#     [MINI-CHUNK] window chars=8,607 → 79 mini-chunks
#   [PREP] window   34/50 | pages=[254, 255, 256, 257]
#       [STRUCT] 8 structural boundaries | book='Đại Việt Sử Ký Toàn Thư'
#     [MINI-CHUNK] window chars=7,893 → 71 mini-chunks
#   [PREP] window   35/50 | pages=[257, 258, 259, 260]
#       [STRUCT] 5 structural boundaries | book='Đại Việt Sử Ký Toàn Thư'
#     [MINI-CHUNK] window chars=7,315 → 67 mini-chunks
#   [PREP] window   36/50 | pages=[260, 261, 262, 263]…
#       [STRUCT] 3 structural boundaries | book='Đại Việt Sử Ký Toàn Thư'
#     [MINI-CHUNK] window chars=12,278 → 109 mini-chunks
#   [PREP] window   37/50 | pages=[264, 265, 266, 267]
#       [STRUCT] 4 structural boundaries | book='Đại Việt Sử Ký Toàn Thư'
#     [MINI-CHUNK] window chars=7,742 → 68 mini-chunks
#   [PREP] window   38/50 | pages=[267, 268, 269, 270]
#       [STRUCT] 5 structural boundaries | book='Đại Việt Sử Ký Toàn Thư'
#     [MINI-CHUNK] window chars=8,967 → 82 mini-chunks
#   [PREP] window   39/50 | pages=[270, 271, 272, 273]…
#       [STRUCT] 5 structural boundaries | book='Đại Việt Sử Ký Toàn Thư'
#     [MINI-CHUNK] window chars=8,176 → 75 mini-chunks
#   [PREP] window   40/50 | pages=[274, 275, 276, 277]
#       [STRUCT] 4 structural boundaries | book='Đại Việt Sử Ký Toàn Thư'
#     [MINI-CHUNK] window chars=7,698 → 70 mini-chunks
#   [PREP] window   41/50 | pages=[277, 278, 279, 280]
#       [STRUCT] 5 structural boundaries | book='Đại Việt Sử Ký Toàn Thư'
#     [MINI-CHUNK] window chars=9,234 → 85 mini-chunks
#   [PREP] window   42/50 | pages=[280, 281, 282, 283]
#       [STRUCT] 3 structural boundaries | book='Đại Việt Sử Ký Toàn Thư'
#     [MINI-CHUNK] window chars=8,939 → 79 mini-chunks
#   [PREP] window   43/50 | pages=[283, 284, 285, 286]
#       [STRUCT] 4 structural boundaries | book='Đại Việt Sử Ký Toàn Thư'
#     [MINI-CHUNK] window chars=6,710 → 58 mini-chunks
#   [PREP] window   44/50 | pages=[286, 287, 288, 289]
#       [STRUCT] 5 structural boundaries | book='Đại Việt Sử Ký Toàn Thư'
#     [MINI-CHUNK] window chars=6,278 → 57 mini-chunks
#   [PREP] window   45/50 | pages=[289, 290, 291, 292]
#       [STRUCT] 2 structural boundaries | book='Đại Việt Sử Ký Toàn Thư'
#     [MINI-CHUNK] window chars=8,350 → 77 mini-chunks
#   [PREP] window   46/50 | pages=[292, 293, 294, 295]
#       [STRUCT] 2 structural boundaries | book='Đại Việt Sử Ký Toàn Thư'
#     [MINI-CHUNK] window chars=8,374 → 75 mini-chunks
#   [PREP] window   47/50 | pages=[295, 296, 297, 298]
#       [STRUCT] 3 structural boundaries | book='Đại Việt Sử Ký Toàn Thư'
#     [MINI-CHUNK] window chars=7,802 → 74 mini-chunks
#   [PREP] window   48/50 | pages=[298, 299, 300, 301]
#       [STRUCT] 3 structural boundaries | book='Đại Việt Sử Ký Toàn Thư'
#     [MINI-CHUNK] window chars=7,981 → 72 mini-chunks
#   [PREP] window   49/50 | pages=[301, 302, 303, 304]
#       [STRUCT] 3 structural boundaries | book='Đại Việt Sử Ký Toàn Thư'
#     [MINI-CHUNK] window chars=6,586 → 62 mini-chunks
#   [PREP] window   50/50 | pages=[304, 305, 306, 307]
#       [STRUCT] 3 structural boundaries | book='Đại Việt Sử Ký Toàn Thư'
#     [MINI-CHUNK] window chars=10,475 → 93 mini-chunks
# [PREP] Total mini-chunks across all windows: 3,584
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW    1/50 | pages=[154, 155, 156] | chars=7,436
#       [STRUCT] 11 structural boundaries | book='Đại Việt Sử Ký Toàn Thư'
#     [MINI-CHUNK] window chars=7,436 → 69 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
#  {"split_after_indices":[3,7,11,15,19,23,27,31,35,39,43,47,51,55,59,63,67]}
#
#
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=69 → splits=[3, 7, 11, 15, 19, 23, 27, 31, 35, 39, 43, 47, 51, 55, 59, 63, 67]
# llm trả về
#  [3, 7, 11, 15, 19, 23, 27, 31, 35, 39, 43, 47, 51, 55, 59, 63, 67]
#
#
#
#     [MERGE] 69 mini-chunks + 17 splits → 18 semantic groups
#       [TOKEN] id=019e40b2… | raw[0:60]='việc lớn của nước, quốc sử không thể không chép được. Có lẽ'
#               seg[0:60]='việc lớn của nước , quốc_sử không_thể không chép được . Có_l'
#               ids[:8]=[0, 49, 103, 7, 58, 4, 28564, 19374] | total_tokens=121
#       [TOKEN] id=019e40b2… | raw[0:60]='Sai sứ cáo phó với nhà Tống, nhà Tống sai người sang làm lễ'
#               seg[0:60]='Sai sứ_cáo phó với nhà_Tống , nhà Tống_sai người sang làm lễ'
#               ids[:8]=[0, 24664, 58442, 9866, 2185, 15, 9096, 10251] | total_tokens=140
#       [TOKEN] id=019e40b2… | raw[0:60]='Vua gặp buổi loạn lạc, giặc cướp tứ tung, mình bị bệnh nặng'
#               seg[0:60]='Vua gặp buổi loạn_lạc , giặc cướp tứ_tung , mình bị bệnh nặn'
#               ids[:8]=[0, 6933, 243, 391, 40156, 4, 6845, 1675] | total_tokens=146
#       [TOKEN] id=019e40b2… | raw[0:60]='Đến khi Đỗ Quang bị thua, vua sai Bố và Trung Từ đón Trần t'
#               seg[0:60]='Đến khi Đỗ_Quang bị thua , vua sai_Bố và Trung_Từ đón Trần_t'
#               ids[:8]=[0, 608, 26, 3237, 2276, 45, 1156, 4] | total_tokens=113
#       [TOKEN] id=019e40b2… | raw[0:60]='Dĩ Mông là người không có học thức, không có mưu thuật, lại'
#               seg[0:60]='Dĩ_Mông là người không có học_thức , không có mưu_thuật , lạ'
#               ids[:8]=[0, 992, 19637, 42313, 8, 18, 17, 10] | total_tokens=136
#       [TOKEN] id=019e40b2… | raw[0:60]='không ai dám nói gì. Sau tội trạng tỏ rõ, bị các quan hặc,'
#               seg[0:60]='không ai dám nói gì . Sau tội_trạng tỏ rõ , bị các quan_hặc'
#               ids[:8]=[0, 17, 277, 1469, 96, 148, 5, 162] | total_tokens=155
#       [TOKEN] id=019e40b2… | raw[0:60]='Giáp Tuất, [Kiến Gia] năm thứ 4 [1214], (Tống Gia Định năm t'
#               seg[0:60]='Giáp_Tuất , [_Kiến_Gia_] năm thứ 4 [ 1214 ] , ( Tống_Gia_Địn'
#               ids[:8]=[0, 16501, 12190, 4, 63576, 1751, 12106, 4134] | total_tokens=134
#       [TOKEN] id=019e40b2… | raw[0:60]='Vua cũng chưa tin, lại cùng với thái hậu và ngự nữ chạy san'
#               seg[0:60]='Vua cũng chưa tin , lại cùng_với thái_hậu và ngự_nữ chạy san'
#               ids[:8]=[0, 6933, 32, 102, 200, 4, 44, 40876] | total_tokens=132
#       [TOKEN] id=019e40b2… | raw[0:60]='lại sai người nói với phu nhân bảo phải tự sát. Vua biết mớ'
#               seg[0:60]='lại sai người nói với phu_nhân bảo phải tự_sát . Vua biết mớ'
#               ids[:8]=[0, 44, 1069, 18, 96, 15, 6141, 1218] | total_tokens=139
#       [TOKEN] id=019e40b2… | raw[0:60]='Vua mới đỗ lại ở bãi Cửu Liên [2]. Truyền cho Tự Khánh đến'
#               seg[0:60]='Vua mới đỗ lại ở bãi Cửu_Liên . Truyền cho Tự_Khánh đến chầu'
#               ids[:8]=[0, 6933, 60, 1875, 44, 25, 1162, 15591] | total_tokens=133
#       [TOKEN] id=019e40b2… | raw[0:60]='Vua có bệnh trúng phong, chũa thuốc không khỏi mà chưa có th'
#               seg[0:60]='Vua có bệnh trúng_phong , chũa thuốc không khỏi mà chưa có t'
#               ids[:8]=[0, 6933, 10, 326, 26169, 3448, 4, 1347] | total_tokens=121
#       [TOKEN] id=019e40b2… | raw[0:60]='đùa múa từ sớm đến chiều không nghỉ, khi thôi đùa nghịch th'
#               seg[0:60]='đùa múa từ sớm đến chiều không nghỉ , khi thôi đùa nghịch th'
#               ids[:8]=[0, 4996, 3366, 39, 471, 30, 405, 17] | total_tokens=149
#       [TOKEN] id=019e40b2… | raw[0:60]='Tháng 9, hoàng thứ nữ sinh, sau phong làm công chúa Chiêu Th'
#               seg[0:60]='Tháng 9 , hoàng_thứ nữ_sinh , sau phong làm công_chúa Chiêu_'
#               ids[:8]=[0, 1641, 426, 4, 28739, 7575, 3323, 4] | total_tokens=160
#       [TOKEN] id=019e40b2… | raw[0:60]='Mùa đông, tháng 10, sai Nguyễn Nộn đem quân đi đánh người M'
#               seg[0:60]='Mùa đông , tháng 10 , sai Nguyễn_Nộn đem quân đi đánh người'
#               ids[:8]=[0, 2822, 553, 4, 78, 210, 4, 1069] | total_tokens=135
#       [TOKEN] id=019e40b2… | raw[0:60]='Tân Tỵ, [Kiến Gia] năm thứ 11 [1221], (Tống Gia Định năm thứ'
#               seg[0:60]='Tân_Tỵ , [_Kiến_Gia_] năm thứ 11 [ 1221 ] , ( Tống_Gia_Định'
#               ids[:8]=[0, 2535, 14640, 4, 63576, 1751, 12106, 4134] | total_tokens=157
#       [TOKEN] id=019e40b2… | raw[0:60]='Làm đồ binh khí và ghe thuyền để tuần bắt giặc cướp.\nQuý Mùi'
#               seg[0:60]='Làm đồ_binh_khí và ghe_thuyền để tuần bắt giặc cướp . Quý_Mù'
#               ids[:8]=[0, 2590, 23722, 45646, 6, 37660, 46173, 24] | total_tokens=145
#       [TOKEN] id=019e40b2… | raw[0:60]='Trần Tự Khánh vì cớ Huệ hậu bị thái hậu làm khổ mà đem quân'
#               seg[0:60]='Trần_Tự_Khánh vì cớ Huệ_hậu bị thái_hậu làm khổ mà đem quân_'
#               ids[:8]=[0, 1359, 11446, 3081, 90, 6750, 31598, 60903] | total_tokens=126
#       [TOKEN] id=019e40b2… | raw[0:60]='Thế là việc tuy là trái nhưng tình thì thuận, sử chép không'
#               seg[0:60]='Thế_là việc tuy là trái nhưng tình thì thuận , sử_chép không'
#               ids[:8]=[0, 7057, 49, 2442, 8, 732, 51, 939] | total_tokens=39
# Đang đẩy 18 points lên Qdrant Cloud...
#  Đã lưu dữ liệu thành công lên Qdrant Cloud!
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW    2/50 | pages=[156, 157, 158, 159] | chars=8,592
#       [STRUCT] 4 structural boundaries | book='Đại Việt Sử Ký Toàn Thư'
#     [MINI-CHUNK] window chars=8,592 → 76 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
#  {"split_after_indices":[3,7,11,15,17,21,25,29,32,36,42,46,51,55,59,62,65,68,72,75]}
#
#
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=76 → splits=[3, 7, 11, 15, 17, 21, 25, 29, 32, 36, 40, 42, 46, 50, 51, 55, 59, 62, 65, 68, 72]
# llm trả về
#  [3, 7, 11, 15, 17, 21, 25, 29, 32, 36, 40, 42, 46, 50, 51, 55, 59, 62, 65, 68, 72]
#
#
#
#     [MERGE] 76 mini-chunks + 21 splits → 22 semantic groups
#       [TOKEN] id=019e40b2… | raw[0:60]='Giáp Thân, [Kiến Gia] năm thứ 14 [1224], (Từ tháng 10 về sau'
#               seg[0:60]='Giáp_Thân , [_Kiến_Gia_] năm thứ 14 [ 1224 ] , ( Từ tháng 10'
#               ids[:8]=[0, 16501, 6022, 4, 63576, 1751, 12106, 4134] | total_tokens=142
#       [TOKEN] id=019e40b2… | raw[0:60]='Chiêu Thánh lên ngôi, đổi niên hiệu là Thiên Chương Hữu Đạo'
#               seg[0:60]='Chiêu_Thánh lên_ngôi , đổi niên_hiệu là Thiên_Chương_Hữu_Đạo'
#               ids[:8]=[0, 12982, 9755, 4773, 4, 1361, 23629, 8] | total_tokens=120
#       [TOKEN] id=019e40b2… | raw[0:60]='Thương Quân con vua Thuấn là kẻ bất tiếu không thể truyền n'
#               seg[0:60]='Thương Quân con vua Thuấn là kẻ bất_tiếu không_thể truyền_ng'
#               ids[:8]=[0, 3999, 2842, 73, 1692, 17936, 8, 963] | total_tokens=130
#       [TOKEN] id=019e40b2… | raw[0:60]='Lý Nhân Tông đã làm như thế rồi, Huệ Tông sao không xét việ'
#               seg[0:60]='Lý_Nhân_Tông đã làm như_thế rồi , Huệ_Tông_sao không xét việ'
#               ids[:8]=[0, 2878, 44332, 14, 47, 1488, 182, 4] | total_tokens=115
#       [TOKEN] id=019e40b2… | raw[0:60]='Chiêu Hoàng Trước tên huý là Phật kim, sau đổi là Thiên Hinh'
#               seg[0:60]='Chiêu_Hoàng Trước tên húy là Phật_kim , sau đổi là Thiên_Hin'
#               ids[:8]=[0, 12982, 1955, 347, 221, 42245, 1231, 8] | total_tokens=89
#       [TOKEN] id=019e40b2… | raw[0:60]='Ất Dậu, Thiên Chương Hữu Đạo năm thứ 2 [1125], (Từ tháng 12'
#               seg[0:60]='Ất_Dậu , Thiên_Chương_Hữu_Đạo năm thứ 2 [ 1125 ] , ( Từ thán'
#               ids[:8]=[0, 37259, 10968, 4, 3545, 15431, 4416, 7977] | total_tokens=162
#       [TOKEN] id=019e40b2… | raw[0:60]='Trần Cảnh làm Chính thủ (Cảnh sau là Trần Thái Tông). Cảnh'
#               seg[0:60]='Trần_Cảnh làm Chính_thủ ( Cảnh sau là Trần_Thái_Tông ) . Cản'
#               ids[:8]=[0, 1359, 4391, 47, 12355, 3, 20, 4391] | total_tokens=135
#       [TOKEN] id=019e40b2… | raw[0:60]='đến khi Cảnh bưng khăn trầu thì lấy khăn ném cho Cảnh. Cảnh'
#               seg[0:60]='đến khi Cảnh_bưng khăn trầu thì lấy khăn ném cho Cảnh . Cảnh'
#               ids[:8]=[0, 30, 26, 9497, 17591, 3866, 12970, 54] | total_tokens=139
#       [TOKEN] id=019e40b2… | raw[0:60]='Thủ độ sợ việc tiết lộ thì bị giết cả, bấy giờ mới tự đem gi'
#               seg[0:60]='Thủ_độ sợ việc tiết_lộ thì bị giết cả , bấy_giờ mới tự đem g'
#               ids[:8]=[0, 18187, 378, 1080, 49, 1212, 54, 45] | total_tokens=112
#       [TOKEN] id=019e40b2… | raw[0:60]='Xuống chiếu rằng: "Từ xưa nước Nam Việt ta đã có đế vương t'
#               seg[0:60]='Xuống chiếu rằng : " Từ xưa nước Nam_Việt ta đã có đế vương_'
#               ids[:8]=[0, 32383, 1914, 87, 27, 22, 404, 2389] | total_tokens=145
#       [TOKEN] id=019e40b2… | raw[0:60]='Trẫm dậy sớm thức khuya, chỉ sợ không cáng đáng nổi, vẫn ng'
#               seg[0:60]='Trẫm dậy sớm_thức khuya , chỉ sợ không cáng_đáng nổi , vẫn n'
#               ids[:8]=[0, 2062, 18244, 1764, 1302, 20110, 62627, 5842] | total_tokens=139
#       [TOKEN] id=019e40b2… | raw[0:60]='Sớm hôm nghĩ chín từ lâu nghiệm xem nên nhường ngôi báu, để'
#               seg[0:60]='Sớm hôm nghĩ chín từ lâu_nghiệm xem nên nhường ngôi báu , để'
#               ids[:8]=[0, 19028, 654, 487, 1988, 39, 58578, 12151] | total_tokens=82
#       [TOKEN] id=019e40b2… | raw[0:60]='Tháng 12, ngày mồng một Mậu Dần, Chiêu Hoàng mở hội lớn ở đ'
#               seg[0:60]='Tháng 12 , ngày mồng một Mậu_Dần , Chiêu_Hoàng mở_hội lớn ở'
#               ids[:8]=[0, 1641, 445, 4, 43, 12331, 16, 16656] | total_tokens=136
#       [TOKEN] id=019e40b2… | raw[0:60]='Thủ Độ nói: "Hiện nay giặc cướp đều nổi, họa loạn ngày tăng'
#               seg[0:60]='Thủ_Độ nói : " Hiện_nay giặc cướp đều nổi , họa_loạn ngày tă'
#               ids[:8]=[0, 61156, 96, 27, 22, 1541, 6845, 1675] | total_tokens=169
#       [TOKEN] id=019e40b2… | raw[0:60]='một hai năm sau thiên hạ nhất thống, lại giao quyền chính c'
#               seg[0:60]='một hai năm sau thiên_hạ nhất_thống , lại giao quyền chính c'
#               ids[:8]=[0, 16, 82, 29, 53, 9099, 55178, 2308] | total_tokens=61
#       [TOKEN] id=019e40b2… | raw[0:60]='Sử thần Ngô Sĩ Liên nói: "Đến thời Huệ Tông, cái độc hại ch'
#               seg[0:60]='Sử_thần Ngô_Sĩ_Liên nói : " Đến thời Huệ_Tông , cái độc_hại'
#               ids[:8]=[0, 24679, 20066, 2929, 27640, 24002, 96, 27] | total_tokens=111
#       [TOKEN] id=019e40b2… | raw[0:60]='Tục truyền rằng Lý [Thái] Tổ khi mới được thiên hạ, xa giá'
#               seg[0:60]='Tục_truyền rằng Lý_[_Thái ]_Tổ khi mới được thiên_hạ , xa_gi'
#               ids[:8]=[0, 982, 13714, 20944, 23214, 87, 2878, 63576] | total_tokens=157
#       [TOKEN] id=019e40b2… | raw[0:60]='Người đời truyền tụng, không ai biết thơ ấy nói thế nào. Đến'
#               seg[0:60]='Người_đời truyền_tụng , không ai biết thơ ấy nói thế_nào . Đ'
#               ids[:8]=[0, 22051, 733, 48504, 4, 17, 277, 55] | total_tokens=101
#       [TOKEN] id=019e40b2… | raw[0:60]='Trở lên triều Lý, 9 vua, từ Thái Tổ năm canh Tuất [1010] đến'
#               seg[0:60]='Trở lên triều_Lý , 9 vua , từ Thái_Tổ năm canh_Tuất [ 1010 ]'
#               ids[:8]=[0, 11947, 72, 51161, 3272, 4, 426, 1692] | total_tokens=128
#       [TOKEN] id=019e40b2… | raw[0:60]='nhường ngôi 19 năm, thọ 60 tuổi [1218- 1277] băng ở cung Vạ'
#               seg[0:60]='nhường ngôi 19 năm , thọ 60 tuổi [ 1218 - 1277 ] băng ở cung'
#               ids[:8]=[0, 4729, 642, 1195, 29, 4, 10723, 1296] | total_tokens=101
#       [TOKEN] id=019e40b2… | raw[0:60]='Trước kia, tổ tiên vua là người đất Mân (có người nói là ngư'
#               seg[0:60]='Trước_kia , tổ_tiên vua là người đất Mân ( có người nói là n'
#               ids[:8]=[0, 15501, 4, 7065, 1692, 8, 18, 179] | total_tokens=160
#       [TOKEN] id=019e40b2… | raw[0:60]='Chiêu Hoàng thấy vua thì ưa.\nNăm Ất Dậu [1225], mùa đông, th'
#               seg[0:60]='Chiêu_Hoàng thấy vua thì ưa . Năm Ất_Dậu [ 1225 ] , mùa đông'
#               ids[:8]=[0, 12982, 1955, 108, 1692, 54, 6616, 5] | total_tokens=112
# Đang đẩy 22 points lên Qdrant Cloud...
#  Đã lưu dữ liệu thành công lên Qdrant Cloud!
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW    3/50 | pages=[159, 160, 161, 162] | chars=8,825
#       [STRUCT] 5 structural boundaries | book='Đại Việt Sử Ký Toàn Thư'
#     [MINI-CHUNK] window chars=8,825 → 80 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
#  {"split_after_indices":[3,7,11,15,19,23,27,31,35,39,43,47,51,55,59,63,67,71,75,79]}
#
#
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=80 → splits=[3, 7, 11, 15, 19, 23, 27, 31, 35, 39, 43, 47, 51, 55, 59, 63, 67, 71, 75]
# llm trả về
#  [3, 7, 11, 15, 19, 23, 27, 31, 35, 39, 43, 47, 51, 55, 59, 63, 67, 71, 75]
#
#
#
#     [MERGE] 80 mini-chunks + 19 splits → 20 semantic groups
#       [TOKEN] id=019e40b2… | raw[0:60]='Tháng 2, định luật lệnh, điều lệ.\nSai Trần Thủ Độ đem quân đ'
#               seg[0:60]='Tháng 2 , định luật_lệnh , điều_lệ . Sai Trần_Thủ_Độ đem quâ'
#               ids[:8]=[0, 1641, 76, 4, 2608, 24472, 1422, 4] | total_tokens=147
#       [TOKEN] id=019e40b2… | raw[0:60]='Đông Ngạn [5] cũng hẹn phong làm vương cho Thượng định ngày'
#               seg[0:60]='Đông_Ngạn cũng hẹn_phong làm vương cho Thượng_định ngày đến'
#               ids[:8]=[0, 2711, 22925, 32, 46531, 3448, 47, 3774] | total_tokens=138
#       [TOKEN] id=019e40b2… | raw[0:60]='Thủ Độ sợ lòng người nhớ vua cũ, sinh biến loạn, cho dời đế'
#               seg[0:60]='Thủ_Độ sợ_lòng người nhớ vua cũ , sinh biến_loạn , cho dời đ'
#               ids[:8]=[0, 61156, 58321, 35197, 18, 723, 1692, 633] | total_tokens=141
#       [TOKEN] id=019e40b2… | raw[0:60]='Thượng hoàng nhà Lý nói: "Ta tụng kinh xong sẽ tự tử".\nNói r'
#               seg[0:60]='Thượng_hoàng nhà_Lý nói : " Ta_tụng kinh xong sẽ tự_tử " . N'
#               ids[:8]=[0, 6293, 4567, 9096, 3272, 96, 27, 22] | total_tokens=123
#       [TOKEN] id=019e40b2… | raw[0:60]='chứa xương vào tháp chùa Bảo Quang, tôn miếu hiệu là Huệ Tô'
#               seg[0:60]='chứa xương vào tháp chùa Bảo_Quang , tôn miếu_hiệu là Huệ_Tô'
#               ids[:8]=[0, 814, 1986, 33, 3186, 1568, 4320, 2276] | total_tokens=108
#       [TOKEN] id=019e40b2… | raw[0:60]='Nhà Hạ nếu không có Kiệt, nhà Thương có Trụ, thì việc truyề'
#               seg[0:60]='Nhà_Hạ nếu không có Kiệt , nhà_Thương có Trụ , thì việc truy'
#               ids[:8]=[0, 7029, 5392, 183, 17, 10, 8910, 4] | total_tokens=123
#       [TOKEN] id=019e40b2… | raw[0:60]='chắc là ơn trạch của tiên vương đến đây là hết rồi, cho nên'
#               seg[0:60]='chắc là ơn_trạch của tiên_vương đến đây là hết rồi , cho_nên'
#               ids[:8]=[0, 1508, 8, 9479, 11463, 10073, 7, 22384] | total_tokens=113
#       [TOKEN] id=019e40b2… | raw[0:60]='Thủ Độ coi việc đó là hết lòng trung, lo việc nước, nhưng c'
#               seg[0:60]='Thủ_Độ coi việc đó là hết_lòng trung , lo việc nước , nhưng'
#               ids[:8]=[0, 61156, 774, 49, 37, 8, 8770, 2765] | total_tokens=146
#       [TOKEN] id=019e40b2… | raw[0:60]='Xuống chiếu cho dân gian dùng tiễn "tỉnh bách"3 mỗi tiễn là'
#               seg[0:60]='Xuống chiếu cho dân_gian dùng tiễn " tỉnh bách " 3 mỗi tiễn'
#               ids[:8]=[0, 32383, 1914, 13, 3467, 175, 12201, 22] | total_tokens=141
#       [TOKEN] id=019e40b2… | raw[0:60]='Phùng Tá Chu là bề tôi cũ triều Lý, không có việc cần phải'
#               seg[0:60]='Phùng Tá_Chu là bề tôi cũ triều_Lý , không có việc cần phải'
#               ids[:8]=[0, 17282, 35789, 8478, 8, 5719, 70, 633] | total_tokens=117
#       [TOKEN] id=019e40b2… | raw[0:60]='Giữa lúc giặc Hỗ vào cướp, cầm quân chuyên chế, lấy thóc củ'
#               seg[0:60]='Giữa lúc giặc Hỗ vào cướp , cầm_quân chuyên_chế , lấy thóc c'
#               ids[:8]=[0, 4419, 219, 6845, 1125, 16006, 33, 1675] | total_tokens=127
#       [TOKEN] id=019e40b2… | raw[0:60]='Tuyên bố các điều khoản lễ minh thệ, theo như lệ cũ của triề'
#               seg[0:60]='Tuyên_bố các điều_khoản lễ minh_thệ , theo như_lệ cũ của tri'
#               ids[:8]=[0, 5524, 9, 4811, 586, 4604, 17193, 10200] | total_tokens=139
#       [TOKEN] id=019e40b2… | raw[0:60]='Quan Trung thư kiểm chính tuyên đọc lời thề rằng:\n"Làm tôi'
#               seg[0:60]='Quan Trung_thư kiểm_chính tuyên đọc lời thề rằng : " Làm tôi'
#               ids[:8]=[0, 8046, 2062, 1178, 25639, 159, 5795, 987] | total_tokens=172
#       [TOKEN] id=019e40b2… | raw[0:60]='Lệ cũ, hằng năm vào đầu mùa xuân, xã quan (nay là xã trưởng)'
#               seg[0:60]='Lệ cũ , hằng năm vào đầu mùa xuân , xã quan ( nay là xã trưở'
#               ids[:8]=[0, 9125, 633, 4, 2416, 29, 33, 127] | total_tokens=171
#       [TOKEN] id=019e40b2… | raw[0:60]='Mùa đông, tháng 10, nước Chiêm Thành sang cống.\nTháng 12, Ng'
#               seg[0:60]='Mùa đông , tháng 10 , nước Chiêm_Thành sang cống . Tháng 12'
#               ids[:8]=[0, 2822, 553, 4, 78, 210, 4, 58] | total_tokens=121
#       [TOKEN] id=019e40b2… | raw[0:60]='đưa công chúa Ngoạn Thiềm gả cho hắn để ngầm dò la tin tức.'
#               seg[0:60]='đưa công_chúa Ngoạn Thiềm_gả cho hắn để ngầm dò_la tin_tức .'
#               ids[:8]=[0, 111, 5154, 47315, 1827, 30349, 18251, 13] | total_tokens=166
#       [TOKEN] id=019e40b2… | raw[0:60]='Đến khi ốm nặng, vua sai nội nhân tớihỏi thăm, Nộn cố gượng'
#               seg[0:60]='Đến khi ốm nặng , vua sai nội_nhân tớihỏi thăm , Nộn_cố gượn'
#               ids[:8]=[0, 608, 26, 5528, 534, 4, 1692, 1069] | total_tokens=149
#       [TOKEN] id=019e40b2… | raw[0:60]='Canh Dần, [Kiến Trung] năm thứ 5 [1230], (Tống Thiệu Đinh n'
#               seg[0:60]='Canh_Dần , [_Kiến Trung_] năm thứ 5 [ 1230 ] , ( Tống_Thiệu'
#               ids[:8]=[0, 19303, 4, 63576, 5151, 14519, 3484, 2705] | total_tokens=130
#       [TOKEN] id=019e40b2… | raw[0:60]='mỗi năm phải nộp 300 thăng thóc.\nLoại bị đồ làm Lao thành b'
#               seg[0:60]='mỗi năm phải nộp 300 thăng_thóc . Loại bị đồ làm Lao thành_b'
#               ids[:8]=[0, 205, 29, 41, 1140, 1570, 1981, 57282] | total_tokens=136
#       [TOKEN] id=019e40b2… | raw[0:60]='Trong thành dựng cung, điện, lầu, các và nhà lang vũ ở hai b'
#               seg[0:60]='Trong thành dựng cung , điện , lầu , các và nhà lang_vũ ở ha'
#               ids[:8]=[0, 92, 302, 2289, 1820, 4, 462, 4] | total_tokens=122
# Đang đẩy 20 points lên Qdrant Cloud...
#  Đã lưu dữ liệu thành công lên Qdrant Cloud!
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW    4/50 | pages=[162, 163, 164, 165] | chars=8,203
#       [STRUCT] 7 structural boundaries | book='Đại Việt Sử Ký Toàn Thư'
#     [MINI-CHUNK] window chars=8,203 → 77 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
#  {"split_after_indices":[3,7,10,14,17,20,24,28,31,35,39,42,45,49,53,57,60,63,66,69,72,75]}
#
#
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=77 → splits=[3, 7, 10, 14, 17, 20, 24, 28, 31, 35, 39, 42, 45, 49, 53, 57, 60, 63, 66, 69, 72, 75]
# llm trả về
#  [3, 7, 10, 14, 17, 20, 24, 28, 31, 35, 39, 42, 45, 49, 53, 57, 60, 63, 66, 69, 72, 75]
#
#
#
#     [MERGE] 77 mini-chunks + 22 splits → 23 semantic groups
#       [TOKEN] id=019e40b2… | raw[0:60]='Tân Mão, [Kiến Trung] năm thứ 7 [1231], (Tống Thiệu Định năm'
#               seg[0:60]='Tân_Mão , [_Kiến Trung_] năm thứ 7 [ 1231 ] , ( Tống_Thiệu_Đ'
#               ids[:8]=[0, 27079, 4, 63576, 5151, 14519, 3484, 2705] | total_tokens=109
#       [TOKEN] id=019e40b2… | raw[0:60]='Mùa thu, tháng 8, vua ngự đến hành cung Tức Mặc, dâng lễ hưở'
#               seg[0:60]='Mùa thu , tháng 8 , vua_ngự đến hành_cung Tức_Mặc , dâng lễ_'
#               ids[:8]=[0, 2822, 369, 4, 78, 358, 4, 56515] | total_tokens=131
#       [TOKEN] id=019e40b2… | raw[0:60]='"Người trẻ tuổi này ngày sau sẽ đại quý". Nói xong thì không'
#               seg[0:60]='" Người trẻ tuổi này ngày sau sẽ đại_quý " . Nói xong thì kh'
#               ids[:8]=[0, 22, 345, 177, 126, 23, 43, 53] | total_tokens=116
#       [TOKEN] id=019e40b2… | raw[0:60]='Nhâm Thìn, [Kiến Trung] năm thứ 8 [1232], (Từ tháng 7 về sau'
#               seg[0:60]='Nhâm Thìn , [_Kiến Trung_] năm thứ 8 [ 1232 ] , ( Từ tháng 7'
#               ids[:8]=[0, 23075, 9939, 4, 63576, 5151, 14519, 3484] | total_tokens=135
#       [TOKEN] id=019e40b2… | raw[0:60]='Lớn lên Bà Liệt khôi ngô, giỏi võ nghệ, xin sung vào đội đán'
#               seg[0:60]='Lớn lên Bà_Liệt khôi_ngô , giỏi võ_nghệ , xin sung vào đội đ'
#               ids[:8]=[0, 7406, 72, 13796, 19622, 51335, 4, 1544] | total_tokens=104
#       [TOKEN] id=019e40b2… | raw[0:60]='Tháng 2, thi thái học sinh. Đỗ đệ nhất giáp là Trương Hanh,'
#               seg[0:60]='Tháng 2 , thi_thái học_sinh . Đỗ_đệ_nhất giáp là Trương_Hanh'
#               ids[:8]=[0, 1641, 76, 4, 60415, 7255, 400, 5] | total_tokens=111
#       [TOKEN] id=019e40b2… | raw[0:60]='Tháng 8, gió lớn, dân gian phát dịch lệ, nhiều người chết.\nT'
#               seg[0:60]='Tháng 8 , gió lớn , dân_gian phát dịch_lệ , nhiều người chết'
#               ids[:8]=[0, 1641, 358, 4, 1273, 103, 4, 3467] | total_tokens=122
#       [TOKEN] id=019e40b2… | raw[0:60]='(Xét thời Trần Anh Tông còn có người họ Lý làm tướng, hơn nữ'
#               seg[0:60]='( Xét_thời Trần_Anh_Tông còn có người họ Lý làm_tướng , hơn_'
#               ids[:8]=[0, 20, 1646, 4827, 19944, 8915, 19402, 6483] | total_tokens=166
#       [TOKEN] id=019e40b2… | raw[0:60]='Giáp Ngọ, [Thiên Ứng Chính Bình] năm thứ 3 [1234], (Tống Đoa'
#               seg[0:60]='Giáp_Ngọ , [_Thiên_Ứng_Chính Bình_] năm thứ 3 [ 1234 ] , ( T'
#               ids[:8]=[0, 27514, 4, 63576, 1751, 3545, 27677, 1008] | total_tokens=150
#       [TOKEN] id=019e40b2… | raw[0:60]='Lấy thái úy [ Trần] Liễu làm phụ chính, sách phong làm Hiển'
#               seg[0:60]='Lấy thái_úy [ Trần_]_Liễu làm phụ_chính , sách_phong làm Hiể'
#               ids[:8]=[0, 5127, 32284, 10615, 1231, 2735, 1359, 3] | total_tokens=127
#       [TOKEN] id=019e40b2… | raw[0:60]='Gia phong thái phó triều Lý là Phùng Tá Chu làm Hưng Nhân Vư'
#               seg[0:60]='Gia_phong_thái phó triều_Lý là Phùng_Tá_Chu làm Hưng_Nhân_Vư'
#               ids[:8]=[0, 4134, 14324, 2185, 51161, 3272, 8, 6237] | total_tokens=156
#       [TOKEN] id=019e40b2… | raw[0:60]='Tháng 2, định quan hàm cho các đại thần.\nPhàm người tôn thất'
#               seg[0:60]='Tháng 2 , định quan_hàm cho các đại_thần . Phàm người tôn_th'
#               ids[:8]=[0, 1641, 76, 4, 2608, 19748, 5618, 13] | total_tokens=104
#       [TOKEN] id=019e40b2… | raw[0:60]='Bấy giờ Hiển Hoàng [Trần] Liễu làm tri Thánh Từ cung, nhân n'
#               seg[0:60]='Bấy_giờ Hiển_Hoàng_[ Trần_]_Liễu làm tri_Thánh Từ_cung , nhâ'
#               ids[:8]=[0, 31326, 23517, 1826, 2735, 1359, 3, 2678] | total_tokens=134
#       [TOKEN] id=019e40b2… | raw[0:60]='Gia phong Hưng Nhân Vương Phùng Tá Chu làm Đại Vương; Quan'
#               seg[0:60]='Gia_phong_Hưng_Nhân_Vương Phùng_Tá_Chu làm Đại_Vương ; Quan_'
#               ids[:8]=[0, 4134, 19340, 6381, 6974, 4379, 6237, 35789] | total_tokens=122
#       [TOKEN] id=019e40b2… | raw[0:60]='Lập công chúa Thuận Thiên họ Lý, là vợ của Hoài Vương Liễu,'
#               seg[0:60]='Lập công_chúa Thuận_Thiên họ Lý , là vợ của Hoài_Vương_Liễu'
#               ids[:8]=[0, 6081, 5154, 8788, 5013, 86, 3272, 4] | total_tokens=108
#       [TOKEN] id=019e40b2… | raw[0:60]='Vua trong lòng áy náy, ban đêm, ra khỏi kinh thành đến chỗ q'
#               seg[0:60]='Vua trong lòng áy_náy , ban_đêm , ra khỏi kinh_thành đến chỗ'
#               ids[:8]=[0, 6933, 12, 605, 28322, 4, 4893, 4] | total_tokens=115
#       [TOKEN] id=019e40b2… | raw[0:60]='Thủ Độ cố nài xin nhiều lần vẫn chưa được vua nghe, mới bảo'
#               seg[0:60]='Thủ_Độ cố_nài xin nhiều lần vẫn chưa được vua nghe , mới bảo'
#               ids[:8]=[0, 61156, 23478, 29486, 611, 36, 101, 74] | total_tokens=117
#       [TOKEN] id=019e40b2… | raw[0:60]='Vua bèn trở về kinh đô. Được hai tuần, Liễu tự lượng thế cô,'
#               seg[0:60]='Vua bèn trở về kinh_đô . Được hai tuần , Liễu tự_lượng thế c'
#               ids[:8]=[0, 6933, 8711, 682, 28, 12114, 5, 815] | total_tokens=121
#       [TOKEN] id=019e40b2… | raw[0:60]='"Ta chỉ là con chó săn thôi, biết đâu anh em các người thuận'
#               seg[0:60]='" Ta chỉ là con chó săn thôi , biết_đâu anh_em các người thu'
#               ids[:8]=[0, 22, 8051, 66, 8, 73, 1658, 2587] | total_tokens=106
#       [TOKEN] id=019e40b2… | raw[0:60]='Phan Phu Tiên nói: Tam cương ngũ thường là luân lý lớn của l'
#               seg[0:60]='Phan_Phu_Tiên nói : Tam_cương_ngũ thường là luân_lý lớn của'
#               ids[:8]=[0, 2790, 24068, 5040, 96, 27, 5012, 55025] | total_tokens=114
#       [TOKEN] id=019e40b2… | raw[0:60]='Có người bảo Thái Tông không giết anh, thế là nhân, nhưng t'
#               seg[0:60]='Có người bảo Thái_Tông không giết anh , thế_là nhân , nhưng'
#               ids[:8]=[0, 503, 18, 1218, 27024, 17, 1460, 83] | total_tokens=93
#       [TOKEN] id=019e40b2… | raw[0:60]='Sử thần Ngô Sĩ Liên nói: Thái Tông mạo nhận con của anh làm'
#               seg[0:60]='Sử_thần Ngô_Sĩ_Liên nói : Thái_Tông_mạo nhận con của anh làm'
#               ids[:8]=[0, 24679, 20066, 2929, 27640, 24002, 96, 27] | total_tokens=86
#       [TOKEN] id=019e40b2… | raw[0:60]='Các quan dâng tôn hiệu là Thống Thiên Ngự Cực Long Công Hậu'
#               seg[0:60]='Các quan_dâng tôn_hiệu là Thống_Thiên_Ngự Cực_Long_Công_Hậu_'
#               ids[:8]=[0, 146, 19748, 2882, 32041, 3256, 8, 36490] | total_tokens=28
# Đang đẩy 23 points lên Qdrant Cloud...
#  Đã lưu dữ liệu thành công lên Qdrant Cloud!
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW    5/50 | pages=[165, 166, 167, 168] | chars=7,084
#       [STRUCT] 10 structural boundaries | book='Đại Việt Sử Ký Toàn Thư'
#     [MINI-CHUNK] window chars=7,084 → 62 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
#  {"split_after_indices":[2,6,9,12,16,20,23,27,31,35,37,40,43,46,49,54,59]}
#
#
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=62 → splits=[2, 6, 9, 12, 16, 20, 23, 27, 31, 35, 37, 40, 43, 46, 49, 53, 54, 58, 59]
# llm trả về
#  [2, 6, 9, 12, 16, 20, 23, 27, 31, 35, 37, 40, 43, 46, 49, 53, 54, 58, 59]
#
#
#
#     [MERGE] 62 mini-chunks + 19 splits → 20 semantic groups
#       [TOKEN] id=019e40b3… | raw[0:60]='Ban yến cho các quan ở điện Thiên An.Tháng 2, dời dựng điện'
#               seg[0:60]='Ban yến cho các quan ở điện Thiên_An . Tháng 2 , dời dựng đi'
#               ids[:8]=[0, 440, 8252, 13, 9, 2665, 25, 462] | total_tokens=132
#       [TOKEN] id=019e40b3… | raw[0:60]='Mậu Tuất, [Thiên Ứng Chính Bình] năm thứ 7 [1238], (Tống Gia'
#               seg[0:60]='Mậu_Tuất , [_Thiên_Ứng_Chính Bình_] năm thứ 7 [ 1238 ] , ( T'
#               ids[:8]=[0, 8528, 4, 63576, 1751, 3545, 27677, 1008] | total_tokens=170
#       [TOKEN] id=019e40b3… | raw[0:60]='Sai [Chu] về hương Tức Mặc xây dựng nhà cửa, cung điện.\nThá'
#               seg[0:60]='Sai [ Chu_] về hương Tức_Mặc xây_dựng nhà_cửa , cung_điện .'
#               ids[:8]=[0, 24664, 2735, 4376, 2705, 28, 2263, 48005] | total_tokens=132
#       [TOKEN] id=019e40b3… | raw[0:60]='Mùa thu, tháng 7, gió lớn, mưa to, động đất.\nTháng 9, ngày 2'
#               seg[0:60]='Mùa thu , tháng 7 , gió lớn , mưa to , động_đất . Tháng 9 ,'
#               ids[:8]=[0, 2822, 369, 4, 78, 317, 4, 1273] | total_tokens=114
#       [TOKEN] id=019e40b3… | raw[0:60]='Tân Sửu, [Thiên Ứng Chính Bình] năm thứ 10 [1241], (Tống Thu'
#               seg[0:60]='Tân_Sửu , [_Thiên_Ứng_Chính Bình_] năm thứ 10 [ 1241 ] , ( T'
#               ids[:8]=[0, 2535, 10801, 4, 63576, 1751, 3545, 27677] | total_tokens=135
#       [TOKEN] id=019e40b3… | raw[0:60]='Mùa đông, tháng 10, người Man phương bắc đến cướp biên giới.'
#               seg[0:60]='Mùa đông , tháng 10 , người Man_phương bắc đến cướp biên_giớ'
#               ids[:8]=[0, 2822, 553, 4, 78, 210, 4, 18] | total_tokens=132
#       [TOKEN] id=019e40b3… | raw[0:60]='Vua thân hành cầm quân đi đánh các trại Vĩnh An, Vĩnh Bình ['
#               seg[0:60]='Vua thân_hành cầm quân đi đánh các trại Vĩnh_An , Vĩnh_Bình'
#               ids[:8]=[0, 6933, 18311, 2537, 1287, 829, 57, 480] | total_tokens=135
#       [TOKEN] id=019e40b3… | raw[0:60]='Nhâm Dần, [Thiên Ứng Chính Bình] năm thứ 11 [1242], (Tống Th'
#               seg[0:60]='Nhâm Dần , [_Thiên_Ứng_Chính Bình_] năm thứ 11 [ 1242 ] , ('
#               ids[:8]=[0, 23075, 9585, 4, 63576, 1751, 3545, 27677] | total_tokens=143
#       [TOKEN] id=019e40b3… | raw[0:60]='Làm đơn số [2] hộ khẩu. Con trai lớn gọi là đại hoàng nam, c'
#               seg[0:60]='Làm đơn số hộ_khẩu . Con trai lớn gọi_là đại_hoàng nam , con'
#               ids[:8]=[0, 2590, 807, 100, 7275, 5, 1322, 443] | total_tokens=124
#       [TOKEN] id=019e40b3… | raw[0:60]='Mùa hạ, tháng 4, sai Thân vệ tướng quân Trần Khuê Kình đem q'
#               seg[0:60]='Mùa hạ , tháng 4 , sai Thân_vệ tướng_quân Trần_Khuê_Kình đem'
#               ids[:8]=[0, 2822, 1269, 4, 78, 163, 4, 1069] | total_tokens=133
#       [TOKEN] id=019e40b3… | raw[0:60]='Đến nay, sai tướng chống giữ, đánh chiếm mới thông hiếu đượ'
#               seg[0:60]='Đến nay , sai_tướng chống giữ , đánh chiếm mới thông_hiếu đư'
#               ids[:8]=[0, 608, 136, 4, 4101, 53719, 335, 300] | total_tokens=109
#       [TOKEN] id=019e40b3… | raw[0:60]='Quý Mão, [Thiên Ứng Chính Bình] năm thứ 2 [1243], (Tống Thuầ'
#               seg[0:60]='Quý_Mão , [_Thiên_Ứng_Chính Bình_] năm thứ 2 [ 1243 ] , ( Tố'
#               ids[:8]=[0, 7901, 12673, 4, 63576, 1751, 3545, 27677] | total_tokens=152
#       [TOKEN] id=019e40b3… | raw[0:60]='Giáp Thìn, [Thiên Ưng Chính Bình] năm thứ 13 [1244], (Tống T'
#               seg[0:60]='Giáp_Thìn , [_Thiên_Ưng_Chính Bình_] năm thứ 13 [ 1244 ] , ('
#               ids[:8]=[0, 16501, 9939, 4, 63576, 1751, 3545, 45511] | total_tokens=115
#       [TOKEN] id=019e40b3… | raw[0:60]='Tháng 3, cho Phùng Tá Khang, cha Phùng Tá Chu, làm tả nhai đ'
#               seg[0:60]='Tháng 3 , cho Phùng_Tá_Khang , cha Phùng_Tá_Chu , làm tả nha'
#               ids[:8]=[0, 1641, 107, 4, 13, 6237, 35789, 5195] | total_tokens=109
#       [TOKEN] id=019e40b3… | raw[0:60]='Mùa đông, tháng 10, qui định lương bổng cho các quan làm việ'
#               seg[0:60]='Mùa đông , tháng 10 , quy_định lương_bổng cho các quan làm_v'
#               ids[:8]=[0, 2822, 553, 4, 78, 210, 4, 209] | total_tokens=135
#       [TOKEN] id=019e40b3… | raw[0:60]='Bính Ngọ, [Thiên Ứng Chính Bình] năm thứ 15 [1246], (Tống Th'
#               seg[0:60]='Bính_Ngọ , [_Thiên_Ứng_Chính Bình_] năm thứ 15 [ 1246 ] , ('
#               ids[:8]=[0, 31504, 10566, 4, 63576, 1751, 3545, 27677] | total_tokens=150
#       [TOKEN] id=019e40b3… | raw[0:60]='Còn các lộ khác thì sung vào cấm quân trong Cấm vệ. Hạng th'
#               seg[0:60]='Còn các lộ khác thì sung vào cấm_quân trong Cấm_vệ . Hạng th'
#               ids[:8]=[0, 631, 9, 1776, 85, 54, 9324, 33] | total_tokens=65
#       [TOKEN] id=019e40b3… | raw[0:60]='Tháng 3, xét duyệt các quan văn, võ, trong ngoài. .\nCứ 15 nă'
#               seg[0:60]='Tháng 3 , xét_duyệt các quan_văn , võ , trong ngoài . . Cứ 1'
#               ids[:8]=[0, 1641, 107, 4, 12056, 9, 19748, 2958] | total_tokens=123
#       [TOKEN] id=019e40b3… | raw[0:60]='cục 15 năm mới được xuất thân, chức tể tướng thì chọn người'
#               seg[0:60]='cục 15 năm mới được xuất_thân , chức tể_tướng thì chọn người'
#               ids[:8]=[0, 3686, 613, 29, 60, 11, 7971, 4] | total_tokens=61
#       [TOKEN] id=019e40b3… | raw[0:60]='Mùa hạ, thạng, tháp trên núi Long Đội đổ.\nMùa thu, tháng 7,'
#               seg[0:60]='Mùa hạ , thạng , tháp trên núi Long_Đội đổ . Mùa thu , tháng'
#               ids[:8]=[0, 2822, 1269, 4, 1981, 18834, 4, 3186] | total_tokens=59
# Đang đẩy 20 points lên Qdrant Cloud...
#  Đã lưu dữ liệu thành công lên Qdrant Cloud!
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW    6/50 | pages=[168, 169, 170, 171] | chars=8,000
#       [STRUCT] 9 structural boundaries | book='Đại Việt Sử Ký Toàn Thư'
#     [MINI-CHUNK] window chars=8,000 → 71 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
#  {"split_after_indices":[4,8,11,14,20,22,26,31,35,39,43,46,50,52,55,58,61,67]}
#
#
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=71 → splits=[3, 4, 8, 11, 14, 18, 20, 22, 26, 30, 31, 35, 39, 43, 46, 50, 52, 55, 58, 61, 65, 67]
# llm trả về
#  [3, 4, 8, 11, 14, 18, 20, 22, 26, 30, 31, 35, 39, 43, 46, 50, 52, 55, 58, 61, 65, 67]
#
#
#
#     [MERGE] 71 mini-chunks + 22 splits → 23 semantic groups
#       [TOKEN] id=019e40b3… | raw[0:60]='Đinh Mùi, [Thiên Ứng Chính Bình] năm thứ 16 [1247], (Tống Th'
#               seg[0:60]='Đinh_Mùi , [_Thiên_Ứng_Chính Bình_] năm thứ 16 [ 1247 ] , ('
#               ids[:8]=[0, 3912, 7371, 4, 63576, 1751, 3545, 27677] | total_tokens=164
#       [TOKEN] id=019e40b3… | raw[0:60]='Ngô Tần (người Trà Lô [0] đỗ giáp khoa, Đào Diễn, Hoàng Hoa'
#               seg[0:60]='Ngô_Tần ( người Trà_Lô đỗ giáp_khoa , Đào_Diễn , Hoàng_Hoan'
#               ids[:8]=[0, 2929, 11414, 20, 18, 11432, 9466, 1875] | total_tokens=67
#       [TOKEN] id=019e40b3… | raw[0:60]='Mậu Thân, [Thiên Ứng Chính Bình] năm thứ 17 [1248], (Tống Th'
#               seg[0:60]='Mậu_Thân , [_Thiên_Ứng_Chính Bình_] năm thứ 17 [ 1248 ] , ('
#               ids[:8]=[0, 24163, 4, 63576, 1751, 3545, 27677, 1008] | total_tokens=136
#       [TOKEN] id=019e40b3… | raw[0:60]='Đắp đê quai vạc là bắt đầu từ đó.\nMùa hạ, tháng 4, làm cầu'
#               seg[0:60]='Đắp đê quai_vạc là bắt_đầu từ đó . Mùa_hạ , tháng 4 , làm cầ'
#               ids[:8]=[0, 28923, 4331, 43648, 29933, 8, 403, 39] | total_tokens=88
#       [TOKEN] id=019e40b3… | raw[0:60]='Sai các nhà phong thủy đi xem khắp núi sông cả nước, chỗ nào'
#               seg[0:60]='Sai các nhà_phong thủy đi xem khắp núi sông cả nước , chỗ nà'
#               ids[:8]=[0, 24664, 9, 9096, 3448, 26255, 1231, 57] | total_tokens=97
#       [TOKEN] id=019e40b3… | raw[0:60]='Sứ thần Ngô Sĩ Liên nói: Từ khi có trời đất này, thì đã có n'
#               seg[0:60]='Sứ_thần Ngô_Sĩ_Liên nói : Từ khi có trời_đất này , thì đã có'
#               ids[:8]=[0, 870, 14786, 20066, 2929, 27640, 24002, 96] | total_tokens=148
#       [TOKEN] id=019e40b3… | raw[0:60]='Ví như Tần Thủy Hoàng biết là phương đông nam có vượng khí'
#               seg[0:60]='Ví_như Tần_Thủy Hoàng_biết là phương đông_nam có vượng khí_t'
#               ids[:8]=[0, 17821, 15795, 56250, 1231, 1826, 55, 8] | total_tokens=70
#       [TOKEN] id=019e40b3… | raw[0:60]='Kỷ Dậu, [ Thiên Ứng Chính bình] năm thứ 18 [1249], (Tống Thu'
#               seg[0:60]='Kỷ_Dậu , [_Thiên_Ứng Chính_bình ] năm thứ 18 [ 1249 ] , ( Tố'
#               ids[:8]=[0, 16200, 10968, 4, 63576, 1751, 3545, 22790] | total_tokens=107
#       [TOKEN] id=019e40b3… | raw[0:60]='Canh Tuất, [Thiên Ứng Chính Bình] năm thứ 19 [1250], (Tống T'
#               seg[0:60]='Canh_Tuất , [_Thiên_Ứng_Chính Bình_] năm thứ 19 [ 1250 ] , ('
#               ids[:8]=[0, 17508, 12190, 4, 63576, 1751, 3545, 27677] | total_tokens=166
#       [TOKEN] id=019e40b3… | raw[0:60]='Tân Hợi, [Thiên Ứng Chính Bình] năm thứ 20 [1251] (Từ tháng'
#               seg[0:60]='Tân_Hợi , [_Thiên_Ứng_Chính Bình_] năm thứ 20 [ 1251 ] ( Từ'
#               ids[:8]=[0, 2535, 10500, 4, 63576, 1751, 3545, 27677] | total_tokens=172
#       [TOKEN] id=019e40b3… | raw[0:60]='ý muốn cho công chúa Thiên Thành là lễ kết tóc với Trung Th'
#               seg[0:60]='ý_muốn cho công_chúa Thiên_Thành là lễ kết_tóc với Trung_Thà'
#               ids[:8]=[0, 6693, 13, 5154, 3545, 1206, 8, 586] | total_tokens=43
#       [TOKEN] id=019e40b3… | raw[0:60]='Trước đó, vua cho công chúa Thiên Thành đến ở trong dinh Nhâ'
#               seg[0:60]='Trước đó , vua cho công_chúa Thiên_Thành đến ở trong dinh_Nh'
#               ids[:8]=[0, 347, 37, 4, 1692, 13, 5154, 3545] | total_tokens=125
#       [TOKEN] id=019e40b3… | raw[0:60]='"Không ngờ Quốc Tuấn ngông cuồng càn rỡ, đang đêm lẻn vào ch'
#               seg[0:60]='" Không ngờ_Quốc_Tuấn ngông_cuồng càn_rỡ , đang đêm lẻn vào'
#               ids[:8]=[0, 22, 453, 42305, 16747, 31659, 45399, 19509] | total_tokens=167
#       [TOKEN] id=019e40b3… | raw[0:60]='Sử thần Ngô Sĩ Liên nói: Con gái vua lấy kẻ bề dưới tất phải'
#               seg[0:60]='Sử_thần Ngô_Sĩ_Liên nói : Con gái vua lấy kẻ_bề dưới tất phả'
#               ids[:8]=[0, 24679, 20066, 2929, 27640, 24002, 96, 27] | total_tokens=145
#       [TOKEN] id=019e40b3… | raw[0:60]='Vua ban yến ở nội điện, các quan đều dự. Đến khi say, mọi ng'
#               seg[0:60]='Vua ban yến ở nội_điện , các quan đều dự . Đến khi say , mọi'
#               ids[:8]=[0, 6933, 718, 8252, 25, 27310, 462, 4] | total_tokens=125
#       [TOKEN] id=019e40b3… | raw[0:60]='Sử thần Ngô Sĩ Liên nói: Xem thế đủ thấy, tuy bấy giờ vua t'
#               seg[0:60]='Sử_thần Ngô_Sĩ_Liên nói : Xem thế đủ thấy , tuy bấy_giờ vua'
#               ids[:8]=[0, 24679, 20066, 2929, 27640, 24002, 96, 27] | total_tokens=113
#       [TOKEN] id=019e40b3… | raw[0:60]='đã không nói thì thôi, lại còn vào hùa với họ thì kỷ cương'
#               seg[0:60]='đã không nói thì_thôi , lại còn vào hùa với họ thì kỷ_cương'
#               ids[:8]=[0, 14, 17, 96, 33429, 4, 44, 50] | total_tokens=91
#       [TOKEN] id=019e40b3… | raw[0:60]='Nhâm Tý, Nguyên Phong năm thứ 2 [1252], (Tống Thuần Hựu năm'
#               seg[0:60]='Nhâm_Tý , Nguyên_Phong năm thứ 2 [ 1252 ] , ( Tống_Thuần Hựu'
# ...
#               seg[0:60]='Hán_Thương đóng thuyền đinh nhỏ để đánh Chiêm_Thành , dự_địn'
#               ids[:8]=[0, 12144, 3999, 580, 2374, 6358, 239, 24] | total_tokens=131
#       [TOKEN] id=019e40bf… | raw[0:60]='Ai ra trận àm sợ giặc thì bị chém, vợ con, điền sản bị tịch'
#               seg[0:60]='Ai ra trận àm sợ giặc thì bị chém , vợ_con , điền_sản bị tịc'
#               ids[:8]=[0, 2679, 40, 196, 17390, 1080, 6845, 54] | total_tokens=134
#       [TOKEN] id=019e40bf… | raw[0:60]='Người Minh bảo Nguyên Khôi rằng phải mau rút quân về, không'
#               seg[0:60]='Người Minh_bảo Nguyên_Khôi rằng phải mau rút quân về , không'
#               ids[:8]=[0, 345, 2775, 1218, 7299, 7133, 87, 41] | total_tokens=65
#       [TOKEN] id=019e40bf… | raw[0:60]='Phan Phu Tiên nói: Nguyên Khôi vốn không có tài làm tướng, c'
#               seg[0:60]='Phan_Phu_Tiên nói : Nguyên_Khôi vốn không có tài làm tướng ,'
#               ids[:8]=[0, 2790, 24068, 5040, 96, 27, 7299, 7133] | total_tokens=89
#       [TOKEN] id=019e40bf… | raw[0:60]='Phương sĩ Nguyễn Đại Năng người Giáp Sơn dùng lửa cứu, kim c'
#               seg[0:60]='Phương_sĩ Nguyễn_Đại_Năng người Giáp_Sơn dùng lửa_cứu , kim_'
#               ids[:8]=[0, 4074, 9031, 1035, 2847, 15492, 18, 16501] | total_tokens=73
#       [TOKEN] id=019e40bf… | raw[0:60]='Đại Năng xảo trá, có sức khoẻ, có thể bắn được nỏ cứng. Sau'
#               seg[0:60]='Đại_Năng_xảo trá , có sức khỏe , có_thể bắn được nỏ cứng . S'
#               ids[:8]=[0, 2847, 24056, 28461, 2127, 6992, 4, 10] | total_tokens=79
# Đang đẩy 23 points lên Qdrant Cloud...
#  Đã lưu dữ liệu thành công lên Qdrant Cloud!
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW   49/50 | pages=[301, 302, 303, 304] | chars=6,586
#       [STRUCT] 3 structural boundaries | book='Đại Việt Sử Ký Toàn Thư'
#     [MINI-CHUNK] window chars=6,586 → 62 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
#  {"split_after_indices":[3,5,8,10,15,19,21,25,30,34,38,43,48,52,55,58,61]}
#
#
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=62 → splits=[3, 5, 8, 10, 14, 15, 19, 21, 25, 29, 30, 34, 38, 42, 43, 47, 48, 52, 55, 58]
# llm trả về
#  [3, 5, 8, 10, 14, 15, 19, 21, 25, 29, 30, 34, 38, 42, 43, 47, 48, 52, 55, 58]
#
#
#
#     [MERGE] 62 mini-chunks + 20 splits → 21 semantic groups
#       [TOKEN] id=019e40bf… | raw[0:60]='Mùa đông, tháng 10, Hán Thương giết thân thuộc của bọn Nguyễ'
#               seg[0:60]='Mùa đông , tháng 10 , Hán_Thương giết thân_thuộc của bọn Ngu'
#               ids[:8]=[0, 2822, 553, 4, 78, 210, 4, 12144] | total_tokens=133
#       [TOKEN] id=019e40bf… | raw[0:60]='nếu có quân phương Bắc sang thì dựng cờ vàng, ghi là thân t'
#               seg[0:60]='nếu có quân_phương Bắc sang thì dựng cờ vàng , ghi là thân_t'
#               ids[:8]=[0, 183, 10, 10035, 1607, 908, 295, 54] | total_tokens=81
#       [TOKEN] id=019e40bf… | raw[0:60]='Giáp Thân, [1404], (Hán Thương Khai Đại năm thứ 2, Minh Vĩn'
#               seg[0:60]='Giáp_Thân , [ 1404 ] , ( Hán_Thương Khai_Đại năm thứ 2 , Min'
#               ids[:8]=[0, 16501, 6022, 4, 2735, 3012, 4980, 2705] | total_tokens=99
#       [TOKEN] id=019e40bf… | raw[0:60]='Hán Thương sai Phan Hòa Phủ đem biếu nhà Minh hai con voi đe'
#               seg[0:60]='Hán_Thương sai Phan_Hòa_Phủ đem biếu nhà_Minh hai con voi đe'
#               ids[:8]=[0, 12144, 3999, 1069, 2790, 58953, 1684, 9972] | total_tokens=86
#       [TOKEN] id=019e40bf… | raw[0:60]='Hán Thương định thể thức thi chọn nhân tài: Cứ tháng 8 năm n'
#               seg[0:60]='Hán Thương_định_thể thức thi chọn nhân_tài : Cứ tháng 8 năm'
#               ids[:8]=[0, 5463, 14311, 18150, 36001, 2908, 201, 437] | total_tokens=128
#       [TOKEN] id=019e40bf… | raw[0:60]='Quan nhân, người làm trò, kẻ phạm tội đều không được dự bổ.'
#               seg[0:60]='Quan_nhân , người làm_trò , kẻ phạm_tội đều không được dự_bổ'
#               ids[:8]=[0, 8616, 1362, 4, 18, 25394, 4, 963] | total_tokens=43
#       [TOKEN] id=019e40bf… | raw[0:60]='Trước đây, năm Nhâm Ngọ [1402], chọn tráng đinh, người nghèo'
#               seg[0:60]='Trước_đây , năm Nhâm_Ngọ [ 1402 ] , chọn tráng đinh , người'
#               ids[:8]=[0, 3099, 4, 29, 22907, 10566, 2735, 3012] | total_tokens=147
#       [TOKEN] id=019e40bf… | raw[0:60]='Hán Thương đóng thuyền đinh sắt để phòng giặc phương Bắc, có'
#               seg[0:60]='Hán_Thương đóng thuyền đinh sắt để phòng giặc phương_Bắc , c'
#               ids[:8]=[0, 12144, 3999, 580, 2374, 6358, 2082, 24] | total_tokens=102
#       [TOKEN] id=019e40bf… | raw[0:60]='Trước đó, Tùng đã bị giải chức, xin bán các đồ khí giới của'
#               seg[0:60]='Trước đó , Tùng đã bị giải_chức , xin bán các đồ khí_giới củ'
#               ids[:8]=[0, 347, 37, 4, 2319, 14, 45, 20557] | total_tokens=124
#       [TOKEN] id=019e40bf… | raw[0:60]='Việc bị tiết lộ, Tùng và con gái Quý đều bị xử tử.\nNhà Minh'
#               seg[0:60]='Việc bị tiết_lộ , Tùng và con gái Quý đều bị xử_tử . Nhà_Min'
#               ids[:8]=[0, 519, 45, 1212, 4, 2319, 6, 73] | total_tokens=133
#       [TOKEN] id=019e40bf… | raw[0:60]='Kỳ hặc tâu [với vua Minh] là họ Hồ xưng đế và làm thơ có nh'
#               seg[0:60]='Kỳ hặc tâu_[ với vua Minh_] là họ Hồ_xưng_đế và làm thơ có n'
#               ids[:8]=[0, 2654, 1340, 13411, 1187, 24760, 2735, 15] | total_tokens=54
#       [TOKEN] id=019e40bf… | raw[0:60]='Hán Thương ra lệnh cho các quan viên không được đi hia, chỉ'
#               seg[0:60]='Hán_Thương ra_lệnh cho các quan_viên không được đi hia , chỉ'
#               ids[:8]=[0, 12144, 3999, 4833, 13, 9, 46746, 17] | total_tokens=131
#       [TOKEN] id=019e40bf… | raw[0:60]='Ất Dậu, [1405], (Hán Thương Khai Đại năm thứ 3, Minh Vĩnh Lạ'
#               seg[0:60]='Ất_Dậu , [ 1405 ] , ( Hán_Thương Khai_Đại năm thứ 3 , Minh_V'
#               ids[:8]=[0, 37259, 10968, 4, 2735, 3012, 4753, 2705] | total_tokens=180
#       [TOKEN] id=019e40bf… | raw[0:60]='Học sinh trong phủ của Trừng là Nguyễn Cẩm và Nguyễn Nhữ Mi'
#               seg[0:60]='Học_sinh trong phủ của Trừng là Nguyễn_Cẩm và Nguyễn_Nhữ_Min'
#               ids[:8]=[0, 5958, 12, 2149, 7, 51202, 8, 1035] | total_tokens=151
#       [TOKEN] id=019e40bf… | raw[0:60]='Vài tháng sau, Tử Triệt bỗng mắc bạo bệnh, đòi lấy bút viết'
#               seg[0:60]='Vài tháng sau , Tử_Triệt_bỗng mắc bạo_bệnh , đòi lấy bút viế'
#               ids[:8]=[0, 5600, 78, 53, 4, 12958, 58732, 4502] | total_tokens=66
#       [TOKEN] id=019e40bf… | raw[0:60]='Nhà Minh sai sứ sang đòi cắt đất Lộc Châu ở Lạng Sơn.\n(Bấy g'
#               seg[0:60]='Nhà_Minh sai sứ sang đòi cắt đất Lộc_Châu ở Lạng_Sơn . ( Bấy'
#               ids[:8]=[0, 14413, 14317, 1069, 4986, 295, 1652, 919] | total_tokens=115
#       [TOKEN] id=019e40bf… | raw[0:60]='Những thổ quan do bên kia đặt, [Quý Ly] đều bí mật sai thổ'
#               seg[0:60]='Những thổ_quan do bên kia đặt , [_Quý Ly_] đều bí_mật sai th'
#               ids[:8]=[0, 217, 26265, 2665, 91, 145, 1357, 320] | total_tokens=55
#       [TOKEN] id=019e40bf… | raw[0:60]='Hán Thương lệnh cho những nơi đầu nguồn ở các trấn nộp gỗ là'
#               seg[0:60]='Hán Thương_lệnh cho những nơi đầu nguồn ở các trấn nộp gỗ là'
#               ids[:8]=[0, 5463, 14311, 1422, 13, 21, 189, 127] | total_tokens=124
#       [TOKEN] id=019e40bf… | raw[0:60]='Mùa hạ, tháng 6, sét đánh và Đông cung (tên nô cùng vú nuôi'
#               seg[0:60]='Mùa hạ , tháng 6 , sét đánh và Đông_cung ( tên nô cùng vú nu'
#               ids[:8]=[0, 2822, 1269, 4, 78, 245, 4, 6142] | total_tokens=116
#       [TOKEN] id=019e40bf… | raw[0:60]='Hán Thương đăt 4 kho quân khí. Không kể là quân hay dân, hễ'
#               seg[0:60]='Hán Thương_đăt 4 kho quân_khí . Không kể là quân hay dân , h'
#               ids[:8]=[0, 5463, 14311, 3438, 49615, 163, 1910, 10035] | total_tokens=92
#       [TOKEN] id=019e40bf… | raw[0:60]='Hán Thương sai bộ Lễ thi chọn nhân tài, đỗ được 170 người. L'
#               seg[0:60]='Hán_Thương sai_bộ Lễ thi chọn nhân_tài , đỗ được 170 người .'
#               ids[:8]=[0, 12144, 3999, 33772, 215, 2220, 201, 437] | total_tokens=69
# Đang đẩy 21 points lên Qdrant Cloud...
#  Đã lưu dữ liệu thành công lên Qdrant Cloud!
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW   50/50 | pages=[304, 305, 306, 307] | chars=10,475
#       [STRUCT] 3 structural boundaries | book='Đại Việt Sử Ký Toàn Thư'
#     [MINI-CHUNK] window chars=10,475 → 93 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
#  {"split_after_indices":[3,7,11,15,19,23,27,31,35,39,43,47,51,55,59,63,67,71,75,79,83,87,91]}
#
#
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=93 → splits=[3, 7, 11, 15, 19, 23, 27, 31, 35, 39, 43, 47, 51, 55, 59, 63, 67, 71, 75, 79, 83, 87, 91]
# llm trả về
#  [3, 7, 11, 15, 19, 23, 27, 31, 35, 39, 43, 47, 51, 55, 59, 63, 67, 71, 75, 79, 83, 87, 91]
#
#
#
#     [MERGE] 93 mini-chunks + 23 splits → 24 semantic groups
#       [TOKEN] id=019e40bf… | raw[0:60]='Tháng 9, Hán Thương sai thi lại viên.\nHán Thương định quân N'
#               seg[0:60]='Tháng 9 , Hán_Thương sai thi lại viên . Hán Thương_định quân'
#               ids[:8]=[0, 1641, 426, 4, 12144, 3999, 1069, 201] | total_tokens=137
#       [TOKEN] id=019e40bf… | raw[0:60]='Nhà Minh chỉ giữ một mình Canh ở lại mà cho Quang Đình trở'
#               seg[0:60]='Nhà_Minh chỉ giữ một_mình Canh ở lại mà cho Quang_Đình trở v'
#               ids[:8]=[0, 14413, 14317, 66, 300, 2595, 11613, 25] | total_tokens=143
#       [TOKEN] id=019e40bf… | raw[0:60]='Cần lao vật vị vô tri giả, Tứ mục nguyên phi tế miện lưu.\n(T'
#               seg[0:60]='Cần_lao vật_vị vô_tri giả , Tứ_mục nguyên phi_tế miện_lưu .'
#               ids[:8]=[0, 17634, 1750, 22974, 626, 14776, 45423, 1163] | total_tokens=141
#       [TOKEN] id=019e40bf… | raw[0:60]='Ở kinh thành thì ban tước và ban tiệc rượu.\nHán Thương sai'
#               seg[0:60]='Ở kinh_thành thì ban_tước và ban tiệc rượu . Hán_Thương sai'
#               ids[:8]=[0, 635, 18021, 54, 3, 3113, 6, 718] | total_tokens=165
#       [TOKEN] id=019e40bf… | raw[0:60]='Hán Thương chiếu truyền An phủ sứ lộ về triều, cùng với các'
#               seg[0:60]='Hán Thương_chiếu truyền_An_phủ sứ_lộ về triều , cùng_với các'
#               ids[:8]=[0, 5463, 14311, 1914, 47001, 3187, 2149, 57741] | total_tokens=168
#       [TOKEN] id=019e40bf… | raw[0:60]='Hán Thương cấm nấu rượu, vì lãng phí thóc gạo.\nHán Thương bã'
#               seg[0:60]='Hán_Thương cấm nấu rượu , vì lãng_phí thóc_gạo . Hán_Thương'
#               ids[:8]=[0, 12144, 3999, 1018, 1872, 1184, 4, 90] | total_tokens=113
#       [TOKEN] id=019e40bf… | raw[0:60]='Trung đem 10 vạn quân ở Quảng Tây sang xâm lược, mượn cớ đưa'
#               seg[0:60]='Trung đem 10 vạn quân ở Quảng_Tây sang xâm_lược , mượn cớ đư'
#               ids[:8]=[0, 1007, 873, 210, 3972, 829, 25, 13836] | total_tokens=134
#       [TOKEN] id=019e40bf… | raw[0:60]='Tả tướng quốc Trừng bỏ thuyền lên bờ, suýt bị vây, có người'
#               seg[0:60]='Tả_tướng quốc_Trừng bỏ thuyền lên bờ , suýt bị vây , có ngườ'
#               ids[:8]=[0, 982, 15250, 22438, 15335, 51202, 338, 2374] | total_tokens=131
#       [TOKEN] id=019e40bf… | raw[0:60]='Quân Minh bèn đưa giải Thiêm Bình cho ta và sai quân y Cao'
#               seg[0:60]='Quân_Minh bèn đưa giải Thiêm_Bình cho ta và sai quân_y Cao_C'
#               ids[:8]=[0, 8995, 1612, 8711, 111, 248, 1827, 24126] | total_tokens=110
#       [TOKEN] id=019e40bf… | raw[0:60]='Nay lui quan quân về tâu với triều đình thì bị quan ải dọc'
#               seg[0:60]='Nay_lui quan_quân về tâu với triều_đình thì bị quan_ải dọc đ'
#               ids[:8]=[0, 1086, 6366, 8340, 19748, 829, 28, 34824] | total_tokens=143
#       [TOKEN] id=019e40bf… | raw[0:60]='Thiêm Bình là gia nô của Trần Nguyên Huy, tức là Nguyễn Khan'
#               seg[0:60]='Thiêm_Bình là gia_nô của Trần_Nguyên_Huy , tức_là Nguyễn_Kha'
#               ids[:8]=[0, 1827, 24126, 1832, 8, 14127, 21280, 7] | total_tokens=115
#       [TOKEN] id=019e40bf… | raw[0:60]='Hồ Xạ vì nghe kế người Minh bắt giải Thiêm Bình để đến nỗi'
#               seg[0:60]='Hồ_Xạ vì nghe kế người Minh_bắt giải Thiêm_Bình để đến_nỗi b'
#               ids[:8]=[0, 5367, 1646, 3628, 90, 523, 3900, 18] | total_tokens=137
#       [TOKEN] id=019e40bf… | raw[0:60]='Hán Thương sai An phủ sứ Tam Giang là Trần Cung Túc sang nhà'
#               seg[0:60]='Hán_Thương sai An_phủ sứ Tam_Giang là Trần_Cung_Túc sang nhà'
#               ids[:8]=[0, 12144, 3999, 1069, 3187, 2149, 4986, 26371] | total_tokens=150
#       [TOKEN] id=019e40bf… | raw[0:60]='Đỗ Mãn thôi chức Thượng thư lệnh hữu tham tri chính sự, lấy'
#               seg[0:60]='Đỗ_Mãn thôi_chức Thượng_thư lệnh_hữu tham_tri chính_sự , lấy'
#               ids[:8]=[0, 48739, 21906, 55411, 1766, 31602, 1494, 55254] | total_tokens=135
#       [TOKEN] id=019e40bf… | raw[0:60]='lấy Thiêm tri nội mật kiêm tri Thẩm hình viện sự Nguyễn Cẩn'
#               seg[0:60]='lấy Thiêm_tri nội_mật kiêm tri Thẩm_hình_viện sự Nguyễn_Cẩn_'
#               ids[:8]=[0, 273, 53782, 19156, 1111, 27310, 3621, 2854] | total_tokens=157
#       [TOKEN] id=019e40bf… | raw[0:60]='Mùa thu, tháng 7, Hán Thương ra lệnh cho các lộ đóng cọc gỗ'
#               seg[0:60]='Mùa thu , tháng 7 , Hán_Thương ra_lệnh cho các lộ đóng cọc g'
#               ids[:8]=[0, 2822, 369, 4, 78, 317, 4, 12144] | total_tokens=108
#       [TOKEN] id=019e40bf… | raw[0:60]='Tháng 9, nhà Minh sai ChinhDi hữu phó tướng quân đeo ấn Chin'
#               seg[0:60]='Tháng 9 , nhà_Minh sai ChinhDi_hữu phó tướng quân đeo ấn_Chi'
#               ids[:8]=[0, 1641, 426, 4, 9096, 1612, 1069, 5845] | total_tokens=136
#       [TOKEN] id=019e40bf… | raw[0:60]='Hai đạo quân tổng cộng là 80 vạn.\nTháng 11 [quân Minh] hội'
#               seg[0:60]='Hai đạo_quân tổng_cộng là 80 vạn . Tháng 11 [ quân_Minh ]_hộ'
#               ids[:8]=[0, 716, 17848, 829, 3106, 8, 1917, 3972] | total_tokens=157
#       [TOKEN] id=019e40bf… | raw[0:60]='Năng đến phủ Thái Bình ở Quảng Tây thì chết. Trước đó Năng'
#               seg[0:60]='Năng đến phủ Thái_Bình ở Quảng_Tây thì chết . Trước đó Năng'
#               ids[:8]=[0, 15492, 30, 2149, 2872, 25, 13836, 54] | total_tokens=158
#       [TOKEN] id=019e40bf… | raw[0:60]='Sau Thúy làm đến tham chính; Địch làm đến chỉ huy sứ; Viễn'
#               seg[0:60]='Sau Thúy làm đến tham_chính ; Địch làm đến chỉ_huy sứ ; Viễn'
#               ids[:8]=[0, 162, 58935, 1231, 47, 30, 26148, 159] | total_tokens=144
#       [TOKEN] id=019e40bf… | raw[0:60]='Đêm mồng 7, người Minh cho khiêng thuyền ra bờ phía bắc bãi'
#               seg[0:60]='Đêm mồng 7 , người Minh cho khiêng thuyền ra bờ phía bắc bãi'
#               ids[:8]=[0, 3015, 12331, 317, 4, 18, 1612, 13] | total_tokens=121
#       [TOKEN] id=019e40c0… | raw[0:60]='lặng im không có tiếng động của chiến trận. Thủy quân ở phí'
#               seg[0:60]='lặng_im không có tiếng_động của chiến_trận . Thủy_quân ở phí'
#               ids[:8]=[0, 32410, 17, 10, 13302, 7, 37558, 5] | total_tokens=99
#       [TOKEN] id=019e40c0… | raw[0:60]='Mộc Thạnh dẫn bọn đề đốc Trần Tuấn, tiến công phí đông nam'
#               seg[0:60]='Mộc_Thạnh dẫn bọn đề_đốc Trần_Tuấn , tiến công_phí đông nam_'
#               ids[:8]=[0, 16852, 7615, 376, 3129, 30475, 6488, 42951] | total_tokens=148
#       [TOKEN] id=019e40c0… | raw[0:60]='Chúng thiến hoạn nhiều con trai nhỏ tuổi và thu lấy tiền đồ'
#               seg[0:60]='Chúng thiến_hoạn nhiều con trai nhỏ_tuổi và thu lấy tiền_đồn'
#               ids[:8]=[0, 2460, 41064, 2799, 55164, 36, 73, 443] | total_tokens=27
# Đang đẩy 24 points lên Qdrant Cloud...
#  Đã lưu dữ liệu thành công lên Qdrant Cloud!
#
# ════════════════════════════════════════════════════════════════════════
#   PIPELINE COMPLETE — 'Đại Việt Sử Ký Toàn Thư'
#   Total Qdrant points produced : 1,024
# ════════════════════════════════════════════════════════════════════════
#
# [SAVE] Writing 1,024 points → 'full_DVSK_data_qdrant_points.json'…
# [SAVE] Done. 1575.2 KB written.

# %% [markdown]
# # Chạy Khâm Định Việt Sử Thông Giám Cương Mục

# %%
# @title

import os
from google.colab import userdata


# JSON_PATH = "full_DVSK_data.json"           # Đại Việt Sử Ký Toàn Thư
JSON_PATH = "full_KhamDinh_data.json"        # Khâm Định Việt Sử Thông Giám Cương Mục
# JSON_PATH = "full_VietSu_data.json"                 # Việt Sử Toàn Thư
# JSON_PATH = "full_VTT_data.json"                  # Vương Triều Trần
# JSON_PATH = "full_test.json"


OUTPUT_PATH = JSON_PATH.replace(".json", "_qdrant_points.json")


def _load_key(colab_secret: str, env_var: str) -> str:
    try:
        from google.colab import userdata as _ud
        val = _ud.get(colab_secret)
        if val:
            print(f"[KEY] '{colab_secret}' loaded from Colab Secrets.")
            return val
    except Exception:
        pass
    val = os.environ.get(env_var, "")
    if val:
        print(f"[KEY] '{env_var}' loaded from environment variable.")
    return val

GROQ_API_KEY   = _load_key("grok_key",  "grok_key")
GEMINI_API_KEY = _load_key("GEMINI_API_KEY", "GEMINI_API_KEY")

if not GROQ_API_KEY and not GEMINI_API_KEY:
    print("[KEY] ⚠  No API keys found. "
          "Add GROQ_API_KEY and/or GOOGLE_API_KEY to Colab Secrets.")


# USE_BATCH_MODE: bool = True
USE_BATCH_MODE: bool = False

BATCH_ORCHESTRATOR: Optional[GeminiBatchOrchestrator] = None
LLM_BACKENDS:       list[LLMBackend]                  = []

if USE_BATCH_MODE:
    if not GEMINI_API_KEY:
        raise RuntimeError(
            "USE_BATCH_MODE=True but GOOGLE_API_KEY is not set. "
            "Add it to Colab Secrets or switch USE_BATCH_MODE=False."
        )
    BATCH_ORCHESTRATOR = GeminiBatchOrchestrator(
        api_key=GEMINI_API_KEY,
        model_id=GEMINI_MODEL_ID,       # "gemini-2.5-flash"
    )
    print(f"[INIT] Mode A — GeminiBatchOrchestrator ready "
          f"(model={GEMINI_MODEL_ID}, "
          f"sub_batch={GeminiBatchOrchestrator.SUB_BATCH_SIZE} chunks/line)")

else:
    # Build sync fallback chain
    # if GROQ_API_KEY:
    #     LLM_BACKENDS.append(GroqBackend(GROQ_API_KEY, GROQ_MODEL_LLAMA_70B))
    #     LLM_BACKENDS.append(GroqBackend(GROQ_API_KEY, GROQ_MODEL_LLAMA_8B))
    #     LLM_BACKENDS.append(GroqBackend(GROQ_API_KEY, GROQ_MODEL_QWEN))

    if GEMINI_API_KEY:
        try:
            LLM_BACKENDS.append(GeminiBackend(GEMINI_API_KEY, GEMINI_MODEL_ID))
            print("[INIT] GeminiBackend added as last-resort sync fallback.")
        except Exception as _ge:
            print(f"[INIT] GeminiBackend skipped ({type(_ge).__name__}: {_ge}).")

    if not LLM_BACKENDS:
        raise RuntimeError(
            "USE_BATCH_MODE=False but LLM_BACKENDS is empty. "
            "Provide GROQ_API_KEY and/or GOOGLE_API_KEY."
        )

    print(f"[INIT] Mode B — sync fallback chain ({len(LLM_BACKENDS)} backend(s)):")
    for _i, _b in enumerate(LLM_BACKENDS):
        print(f"   [{_i + 1}] {_b.label}")

print()

print(f"[LOAD] Reading '{JSON_PATH}'…")
with open(JSON_PATH, "r", encoding="utf-8") as _fh:
    input_data: dict = json.load(_fh)


assert "book_name"          in input_data, "Missing key: book_name"
assert "full_text"          in input_data, "Missing key: full_text"
assert "page_footnotes_map" in input_data, "Missing key: page_footnotes_map"
assert isinstance(input_data["full_text"],          str),  "full_text must be str"
assert isinstance(input_data["page_footnotes_map"], dict), "page_footnotes_map must be dict"
print("[LOAD] Input validation passed ✓")

qdrant_points: list[dict] = run_pipeline(
    input_data,
    backends           = LLM_BACKENDS,
    batch_orchestrator = BATCH_ORCHESTRATOR,
)

print(f"\n[SAVE] Writing {len(qdrant_points):,} points → '{OUTPUT_PATH}'…")
with open(OUTPUT_PATH, "w", encoding="utf-8") as _fh:
    json.dump(qdrant_points, _fh, ensure_ascii=False, indent=2)
_kb = os.path.getsize(OUTPUT_PATH) / 1024
print(f"[SAVE] Done. {_kb:.1f} KB written.")
# Out:
# [KEY] 'grok_key' loaded from Colab Secrets.
# [KEY] 'GEMINI_API_KEY' loaded from Colab Secrets.
# [INIT] GeminiBackend added as last-resort sync fallback.
# [INIT] Mode B — sync fallback chain (1 backend(s)):
#    [1] gemini-sync/gemini-3.1-flash-lite
#
# [LOAD] Reading 'full_KhamDinh_data.json'…
# [LOAD] Input validation passed ✓
# ════════════════════════════════════════════════════════════════════════
#   PIPELINE START — 'Khâm Định Việt Sử Thông Giám Cương Mục'
#   full_text chars     :      434,220
#   footnote page count :          165
#   LLM mode            : SYNC (Mode B)
#   LLM backend(s)      : gemini-sync/gemini-3.1-flash-lite
# ════════════════════════════════════════════════════════════════════════
# ════════════════════════════════════════════════════════════════════════
#   PIPELINE START — 'Khâm Định Việt Sử Thông Giám Cương Mục'
#   full_text chars     :      434,220
#   footnote page count :          165
# ════════════════════════════════════════════════════════════════════════
# [INIT] Loading tokenizer: bkai-foundation-models/vietnamese-bi-encoder
# [INIT] Loading model → device=cpu
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# [INIT] Model ready | hidden_size=768
#
# [WINDOWS] book='Khâm Định Việt Sử Thông Giám Cương Mục' | window_size=3 pages
#
# ── STEPS 3+4 · Structural boundaries + Mini-chunking (all windows)
#   [PREP] window    1/54 | pages=[187, 188, 189]
#       [STRUCT] 2 structural boundaries | book='Khâm Định Việt Sử Thông Giám Cương '
#     [MINI-CHUNK] window chars=7,089 → 63 mini-chunks
#   [PREP] window    2/54 | pages=[189, 190, 191, 192]
#       [STRUCT] 2 structural boundaries | book='Khâm Định Việt Sử Thông Giám Cương '
#     [MINI-CHUNK] window chars=7,841 → 66 mini-chunks
#   [PREP] window    3/54 | pages=[192, 193, 194, 195]
#       [STRUCT] 2 structural boundaries | book='Khâm Định Việt Sử Thông Giám Cương '
#     [MINI-CHUNK] window chars=6,692 → 59 mini-chunks
#   [PREP] window    4/54 | pages=[195, 196, 197, 198]
#       [STRUCT] 2 structural boundaries | book='Khâm Định Việt Sử Thông Giám Cương '
#     [MINI-CHUNK] window chars=8,966 → 83 mini-chunks
#   [PREP] window    5/54 | pages=[198, 199, 200, 201]
#       [STRUCT] 2 structural boundaries | book='Khâm Định Việt Sử Thông Giám Cương '
#     [MINI-CHUNK] window chars=7,322 → 69 mini-chunks
#   [PREP] window    6/54 | pages=[201, 202, 203, 204]
#       [STRUCT] 2 structural boundaries | book='Khâm Định Việt Sử Thông Giám Cương '
#     [MINI-CHUNK] window chars=7,650 → 69 mini-chunks
#   [PREP] window    7/54 | pages=[204, 205, 206, 207]
#       [STRUCT] 2 structural boundaries | book='Khâm Định Việt Sử Thông Giám Cương '
#     [MINI-CHUNK] window chars=6,757 → 62 mini-chunks
#   [PREP] window    8/54 | pages=[207, 208, 209, 210]
#       [STRUCT] 2 structural boundaries | book='Khâm Định Việt Sử Thông Giám Cương '
#     [MINI-CHUNK] window chars=8,218 → 78 mini-chunks
#   [PREP] window    9/54 | pages=[210, 211, 212, 213]
#       [STRUCT] 2 structural boundaries | book='Khâm Định Việt Sử Thông Giám Cương '
#     [MINI-CHUNK] window chars=7,062 → 61 mini-chunks
#   [PREP] window   10/54 | pages=[213, 214, 215, 216]
#       [STRUCT] 2 structural boundaries | book='Khâm Định Việt Sử Thông Giám Cương '
#     [MINI-CHUNK] window chars=7,472 → 68 mini-chunks
#   [PREP] window   11/54 | pages=[216, 217, 218, 219]
#       [STRUCT] 2 structural boundaries | book='Khâm Định Việt Sử Thông Giám Cương '
#     [MINI-CHUNK] window chars=7,938 → 67 mini-chunks
#   [PREP] window   12/54 | pages=[219, 220, 221, 222]
#       [STRUCT] 2 structural boundaries | book='Khâm Định Việt Sử Thông Giám Cương '
#     [MINI-CHUNK] window chars=7,091 → 63 mini-chunks
#   [PREP] window   13/54 | pages=[222, 223, 224, 225]
#       [STRUCT] 2 structural boundaries | book='Khâm Định Việt Sử Thông Giám Cương '
#     [MINI-CHUNK] window chars=10,380 → 93 mini-chunks
#   [PREP] window   14/54 | pages=[225, 226, 227, 228]
#       [STRUCT] 2 structural boundaries | book='Khâm Định Việt Sử Thông Giám Cương '
#     [MINI-CHUNK] window chars=7,892 → 72 mini-chunks
#   [PREP] window   15/54 | pages=[228, 229, 230, 231]
#       [STRUCT] 2 structural boundaries | book='Khâm Định Việt Sử Thông Giám Cương '
#     [MINI-CHUNK] window chars=6,464 → 57 mini-chunks
#   [PREP] window   16/54 | pages=[231, 232, 233, 234]
#       [STRUCT] 2 structural boundaries | book='Khâm Định Việt Sử Thông Giám Cương '
#     [MINI-CHUNK] window chars=7,898 → 71 mini-chunks
#   [PREP] window   17/54 | pages=[234, 235, 236, 237]
#       [STRUCT] 2 structural boundaries | book='Khâm Định Việt Sử Thông Giám Cương '
#     [MINI-CHUNK] window chars=10,404 → 93 mini-chunks
#   [PREP] window   18/54 | pages=[237, 238, 239, 240]
#       [STRUCT] 2 structural boundaries | book='Khâm Định Việt Sử Thông Giám Cương '
#     [MINI-CHUNK] window chars=9,659 → 85 mini-chunks
#   [PREP] window   19/54 | pages=[240, 241, 242, 243]
#       [STRUCT] 2 structural boundaries | book='Khâm Định Việt Sử Thông Giám Cương '
#     [MINI-CHUNK] window chars=8,043 → 74 mini-chunks
#   [PREP] window   20/54 | pages=[243, 244, 245, 246]
#       [STRUCT] 2 structural boundaries | book='Khâm Định Việt Sử Thông Giám Cương '
#     [MINI-CHUNK] window chars=7,335 → 65 mini-chunks
#   [PREP] window   21/54 | pages=[246, 247, 248, 249]
#       [STRUCT] 2 structural boundaries | book='Khâm Định Việt Sử Thông Giám Cương '
#     [MINI-CHUNK] window chars=11,410 → 107 mini-chunks
#   [PREP] window   22/54 | pages=[249, 250, 251, 252]
#       [STRUCT] 2 structural boundaries | book='Khâm Định Việt Sử Thông Giám Cương '
#     [MINI-CHUNK] window chars=7,298 → 71 mini-chunks
#   [PREP] window   23/54 | pages=[252, 253, 254, 255]
#       [STRUCT] 2 structural boundaries | book='Khâm Định Việt Sử Thông Giám Cương '
#     [MINI-CHUNK] window chars=6,318 → 56 mini-chunks
#   [PREP] window   24/54 | pages=[255, 256, 257, 258]…
#       [STRUCT] 2 structural boundaries | book='Khâm Định Việt Sử Thông Giám Cương '
#     [MINI-CHUNK] window chars=8,263 → 75 mini-chunks
#   [PREP] window   25/54 | pages=[259, 260, 261, 262]
#       [STRUCT] 2 structural boundaries | book='Khâm Định Việt Sử Thông Giám Cương '
#     [MINI-CHUNK] window chars=7,181 → 67 mini-chunks
#   [PREP] window   26/54 | pages=[262, 263, 264, 265]
#       [STRUCT] 2 structural boundaries | book='Khâm Định Việt Sử Thông Giám Cương '
#     [MINI-CHUNK] window chars=8,540 → 78 mini-chunks
#   [PREP] window   27/54 | pages=[265, 266, 267, 268]
#       [STRUCT] 2 structural boundaries | book='Khâm Định Việt Sử Thông Giám Cương '
#     [MINI-CHUNK] window chars=7,747 → 73 mini-chunks
#   [PREP] window   28/54 | pages=[268, 269, 270, 271]
#       [STRUCT] 2 structural boundaries | book='Khâm Định Việt Sử Thông Giám Cương '
#     [MINI-CHUNK] window chars=7,598 → 66 mini-chunks
#   [PREP] window   29/54 | pages=[271, 272, 273, 274]
#       [STRUCT] 2 structural boundaries | book='Khâm Định Việt Sử Thông Giám Cương '
#     [MINI-CHUNK] window chars=10,109 → 88 mini-chunks
#   [PREP] window   30/54 | pages=[274, 275, 276, 277]
#       [STRUCT] 2 structural boundaries | book='Khâm Định Việt Sử Thông Giám Cương '
#     [MINI-CHUNK] window chars=7,052 → 64 mini-chunks
#   [PREP] window   31/54 | pages=[277, 278, 279, 280]…
#       [STRUCT] 2 structural boundaries | book='Khâm Định Việt Sử Thông Giám Cương '
#     [MINI-CHUNK] window chars=6,635 → 60 mini-chunks
#   [PREP] window   32/54 | pages=[281, 282, 283, 284]
#       [STRUCT] 2 structural boundaries | book='Khâm Định Việt Sử Thông Giám Cương '
#     [MINI-CHUNK] window chars=9,737 → 84 mini-chunks
#   [PREP] window   33/54 | pages=[284, 285, 286, 287]
#       [STRUCT] 2 structural boundaries | book='Khâm Định Việt Sử Thông Giám Cương '
#     [MINI-CHUNK] window chars=7,114 → 67 mini-chunks
#   [PREP] window   34/54 | pages=[287, 288, 289, 290]
#       [STRUCT] 2 structural boundaries | book='Khâm Định Việt Sử Thông Giám Cương '
#     [MINI-CHUNK] window chars=8,361 → 72 mini-chunks
#   [PREP] window   35/54 | pages=[290, 291, 292, 293]
#       [STRUCT] 2 structural boundaries | book='Khâm Định Việt Sử Thông Giám Cương '
#     [MINI-CHUNK] window chars=9,960 → 87 mini-chunks
#   [PREP] window   36/54 | pages=[293, 294, 295, 296]
#       [STRUCT] 2 structural boundaries | book='Khâm Định Việt Sử Thông Giám Cương '
#     [MINI-CHUNK] window chars=6,935 → 59 mini-chunks
#   [PREP] window   37/54 | pages=[296, 297, 298, 299]
#       [STRUCT] 2 structural boundaries | book='Khâm Định Việt Sử Thông Giám Cương '
#     [MINI-CHUNK] window chars=9,141 → 86 mini-chunks
#   [PREP] window   38/54 | pages=[299, 300, 301, 302]
#       [STRUCT] 2 structural boundaries | book='Khâm Định Việt Sử Thông Giám Cương '
#     [MINI-CHUNK] window chars=6,883 → 57 mini-chunks
#   [PREP] window   39/54 | pages=[302, 303, 304, 305]
#       [STRUCT] 2 structural boundaries | book='Khâm Định Việt Sử Thông Giám Cương '
#     [MINI-CHUNK] window chars=6,434 → 57 mini-chunks
#   [PREP] window   40/54 | pages=[305, 306, 307, 308]
#       [STRUCT] 2 structural boundaries | book='Khâm Định Việt Sử Thông Giám Cương '
#     [MINI-CHUNK] window chars=8,373 → 72 mini-chunks
#   [PREP] window   41/54 | pages=[308, 309, 310, 311]
#       [STRUCT] 2 structural boundaries | book='Khâm Định Việt Sử Thông Giám Cương '
#     [MINI-CHUNK] window chars=9,010 → 80 mini-chunks
#   [PREP] window   42/54 | pages=[311, 312, 313, 314]
#       [STRUCT] 2 structural boundaries | book='Khâm Định Việt Sử Thông Giám Cương '
#     [MINI-CHUNK] window chars=6,492 → 57 mini-chunks
#   [PREP] window   43/54 | pages=[314, 315, 316, 317]
#       [STRUCT] 2 structural boundaries | book='Khâm Định Việt Sử Thông Giám Cương '
#     [MINI-CHUNK] window chars=7,293 → 66 mini-chunks
#   [PREP] window   44/54 | pages=[317, 318, 319, 320]
#       [STRUCT] 2 structural boundaries | book='Khâm Định Việt Sử Thông Giám Cương '
#     [MINI-CHUNK] window chars=8,245 → 80 mini-chunks
#   [PREP] window   45/54 | pages=[320, 321, 322, 323]
#       [STRUCT] 2 structural boundaries | book='Khâm Định Việt Sử Thông Giám Cương '
#     [MINI-CHUNK] window chars=7,695 → 65 mini-chunks
#   [PREP] window   46/54 | pages=[323, 324, 325, 326]
#       [STRUCT] 2 structural boundaries | book='Khâm Định Việt Sử Thông Giám Cương '
#     [MINI-CHUNK] window chars=7,133 → 61 mini-chunks
#   [PREP] window   47/54 | pages=[326, 327, 328, 329]…
#       [STRUCT] 2 structural boundaries | book='Khâm Định Việt Sử Thông Giám Cương '
#     [MINI-CHUNK] window chars=7,812 → 72 mini-chunks
#   [PREP] window   48/54 | pages=[330, 331, 332, 333]
#       [STRUCT] 2 structural boundaries | book='Khâm Định Việt Sử Thông Giám Cương '
#     [MINI-CHUNK] window chars=7,421 → 65 mini-chunks
#   [PREP] window   49/54 | pages=[333, 334, 335, 336]
#       [STRUCT] 2 structural boundaries | book='Khâm Định Việt Sử Thông Giám Cương '
#     [MINI-CHUNK] window chars=9,415 → 86 mini-chunks
#   [PREP] window   50/54 | pages=[336, 337, 338, 339]
#       [STRUCT] 2 structural boundaries | book='Khâm Định Việt Sử Thông Giám Cương '
#     [MINI-CHUNK] window chars=8,165 → 75 mini-chunks
#   [PREP] window   51/54 | pages=[339, 340, 341, 342]
#       [STRUCT] 2 structural boundaries | book='Khâm Định Việt Sử Thông Giám Cương '
#     [MINI-CHUNK] window chars=9,150 → 83 mini-chunks
#   [PREP] window   52/54 | pages=[342, 343, 344, 345]
#       [STRUCT] 2 structural boundaries | book='Khâm Định Việt Sử Thông Giám Cương '
#     [MINI-CHUNK] window chars=9,584 → 85 mini-chunks
#   [PREP] window   53/54 | pages=[345, 346, 347, 348]
#       [STRUCT] 2 structural boundaries | book='Khâm Định Việt Sử Thông Giám Cương '
#     [MINI-CHUNK] window chars=9,187 → 82 mini-chunks
#   [PREP] window   54/54 | pages=[348, 349, 350, 351]
#       [STRUCT] 2 structural boundaries | book='Khâm Định Việt Sử Thông Giám Cương '
#     [MINI-CHUNK] window chars=5,716 → 50 mini-chunks
# [PREP] Total mini-chunks across all windows: 3,871
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW    1/54 | pages=[187, 188, 189] | chars=7,089
#       [STRUCT] 2 structural boundaries | book='Khâm Định Việt Sử Thông Giám Cương '
#     [MINI-CHUNK] window chars=7,089 → 63 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
#  {"split_after_indices":[3,7,11,15,19,23,27,31,35,39,43,47,51,55,59]}
#
#
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=63 → splits=[3, 7, 11, 15, 19, 23, 27, 31, 35, 39, 43, 47, 51, 55, 59]
# llm trả về
#  [3, 7, 11, 15, 19, 23, 27, 31, 35, 39, 43, 47, 51, 55, 59]
#
#
#
#     [MERGE] 63 mini-chunks + 15 splits → 16 semantic groups
#       [TOKEN] id=019e40c0… | raw[0:60]='Tháng 10, mùa đông. Lập con gái là Phật Kim làm Thái tử.\nNhà'
#               seg[0:60]='Tháng 10 , mùa đông . Lập con gái là Phật_Kim_làm Thái_tử .'
#               ids[:8]=[0, 1641, 210, 4, 303, 553, 5, 6081] | total_tokens=149
#       [TOKEN] id=019e40c0… | raw[0:60]='Nhà vua ở ngôi 14 năm, rồi truyền cho Chiêu Hoàng, về sau, b'
#               seg[0:60]='Nhà_vua ở ngôi 14 năm , rồi truyền cho Chiêu_Hoàng , về sau'
#               ids[:8]=[0, 16353, 25, 642, 948, 29, 4, 182] | total_tokens=122
#       [TOKEN] id=019e40c0… | raw[0:60]='năm Bảo Khánh thứ 1 - năm này nhà Lý mất).\nTháng 10, mùa đô'
#               seg[0:60]='năm Bảo_Khánh thứ 1 - năm này nhà Lý_mất ) . Tháng 10 , mùa'
#               ids[:8]=[0, 29, 33555, 129, 99, 31, 29, 23] | total_tokens=124
#       [TOKEN] id=019e40c0… | raw[0:60]='Trần Thiêm làm Chi hậu cục [4]; Trần Cảnh làm Chính thủ [5]'
#               seg[0:60]='Trần_Thiêm làm Chi hậu_cục ; Trần_Cảnh làm Chính_thủ . Lời_c'
#               ids[:8]=[0, 1359, 29899, 47, 3378, 19636, 3686, 65] | total_tokens=128
#       [TOKEN] id=019e40c0… | raw[0:60]='Trần Cảnh đem việc đó mách bảo Thủ Độ. Thủ Độ nói: "Nếu quả'
#               seg[0:60]='Trần_Cảnh đem việc đó mách_bảo Thủ_Độ . Thủ_Độ nói : " Nếu q'
#               ids[:8]=[0, 1359, 4391, 873, 49, 37, 27690, 61156] | total_tokens=153
#       [TOKEN] id=019e40c0… | raw[0:60]='Ngày 21 tháng 12, bầy tôi tiến triều, lạy mừng. Nhà vua xuố'
#               seg[0:60]='Ngày 21 tháng 12 , bầy tôi tiến_triều , lạy_mừng . Nhà_vua x'
#               ids[:8]=[0, 319, 1298, 78, 445, 4, 9010, 70] | total_tokens=128
#       [TOKEN] id=019e40c0… | raw[0:60]='Trẫm xét thấy ngôi báu rất là trọng đại mà trẫm là vua đàn'
#               seg[0:60]='Trẫm xét thấy ngôi báu rất là trọng_đại mà trẫm là vua đàn_b'
#               ids[:8]=[0, 2062, 18244, 1522, 108, 642, 9226, 59] | total_tokens=135
#       [TOKEN] id=019e40c0… | raw[0:60]='Trần Cảnh lên ngôi ở điện Thiên An, đổi niên hiệu; đại xá. B'
#               seg[0:60]='Trần_Cảnh lên_ngôi ở điện Thiên_An , đổi niên_hiệu ; đại_xá'
#               ids[:8]=[0, 1359, 4391, 4773, 25, 462, 23800, 4] | total_tokens=136
#       [TOKEN] id=019e40c0… | raw[0:60]='Vả, đương buổi vận nước mới mở mang, lòng dân chưa thống nh'
#               seg[0:60]='Vả , đương_buổi vận_nước mới mở_mang , lòng dân chưa thống_n'
#               ids[:8]=[0, 1117, 7936, 4, 54474, 391, 43339, 58] | total_tokens=127
#       [TOKEN] id=019e40c0… | raw[0:60]='Lời phê - Thực là việc lạ, suốt nghìn xưa chưa hề có. Các tr'
#               seg[0:60]='Lời phê - Thực_là việc lạ , suốt nghìn xưa chưa hề có . Các'
#               ids[:8]=[0, 4190, 11083, 31, 24951, 8, 49, 1410] | total_tokens=143
#       [TOKEN] id=019e40c0… | raw[0:60]='Cho nên nhà Trần không có miếu hiệu là Thái tổ. Cái cớ làm'
#               seg[0:60]='Cho_nên nhà Trần không có miếu_hiệu là Thái_tổ . Cái_cớ làm'
#               ids[:8]=[0, 7363, 69, 3212, 17, 10, 58652, 58797] | total_tokens=172
#       [TOKEN] id=019e40c0… | raw[0:60]='(cid:148) Bính Tuất (1226), Trần Thái Tông hoàng đế năm Kiến'
#               seg[0:60]='( cid : 148 ) Bính_Tuất ( 1226 ) , Trần_Thái_Tông_hoàng_đế n'
#               ids[:8]=[0, 20, 52881, 27, 14526, 19, 31504, 12190] | total_tokens=104
#       [TOKEN] id=019e40c0… | raw[0:60]='khi nhà vua mới được Chiêu Hoàng truyền ngôi cho, đã phong'
#               seg[0:60]='khi nhà_vua mới được Chiêu_Hoàng_truyền ngôi cho , đã phong_'
#               ids[:8]=[0, 26, 9084, 60, 11, 12982, 13761, 11097] | total_tokens=131
#       [TOKEN] id=019e40c0… | raw[0:60]='Lời cẩn án - Lý Huệ Tông đã truyền ngôi cho con gái, liền ra'
#               seg[0:60]='Lời cẩn_án - Lý_Huệ_Tông đã truyền ngôi cho con gái , liền r'
#               ids[:8]=[0, 4190, 3, 565, 31, 2878, 13471, 6483] | total_tokens=131
#       [TOKEN] id=019e40c0… | raw[0:60]='Thủ Độ điều khiển quân đi dẹp yên được; duy còn Nguyễn Nộn'
#               seg[0:60]='Thủ_Độ điều_khiển quân đi dẹp yên được ; duy còn Nguyễn_Nộn_'
#               ids[:8]=[0, 61156, 1303, 829, 57, 7166, 3440, 11] | total_tokens=157
#       [TOKEN] id=019e40c0… | raw[0:60]='Hồng Châu: Xem thuộc Đường, Chiêu Tuyên, năm Thiên Hựu thứ 3'
#               seg[0:60]='Hồng_Châu : Xem thuộc Đường , Chiêu_Tuyên , năm Thiên_Hựu th'
#               ids[:8]=[0, 50861, 27, 2457, 187, 2080, 4, 12982] | total_tokens=94
# Đang đẩy 16 points lên Qdrant Cloud...
#  Đã lưu dữ liệu thành công lên Qdrant Cloud!
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW    2/54 | pages=[189, 190, 191, 192] | chars=7,841
#       [STRUCT] 2 structural boundaries | book='Khâm Định Việt Sử Thông Giám Cương '
#     [MINI-CHUNK] window chars=7,841 → 66 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
#  {"split_after_indices":[3,7,11,13,16,21,23,26,29,33,36,39,42,45,49,53,57,60,64]}
#
#
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=66 → splits=[3, 7, 11, 13, 16, 20, 21, 23, 26, 29, 33, 36, 39, 42, 45, 49, 53, 57, 60, 64]
# llm trả về
#  [3, 7, 11, 13, 16, 20, 21, 23, 26, 29, 33, 36, 39, 42, 45, 49, 53, 57, 60, 64]
#
#
#
#     [MERGE] 66 mini-chunks + 20 splits → 21 semantic groups
#       [TOKEN] id=019e40c0… | raw[0:60]='Tháng 8, mùa thu. Trần Thủ Độ giết Thượng hoàng nhà Lý ở chù'
#               seg[0:60]='Tháng 8 , mùa thu . Trần_Thủ_Độ giết_Thượng_hoàng nhà_Lý ở c'
#               ids[:8]=[0, 1641, 358, 4, 303, 369, 5, 39303] | total_tokens=149
#       [TOKEN] id=019e40c0… | raw[0:60]='Đến nay, Thủ Độ sai người đem hương hoa đến dâng và nói rằn'
#               seg[0:60]='Đến nay , Thủ_Độ sai người đem hương_hoa đến dâng và nói rằn'
#               ids[:8]=[0, 608, 136, 4, 61156, 1069, 18, 873] | total_tokens=112
#       [TOKEN] id=019e40c0… | raw[0:60]='Thủ Độ bắt các quan đến khóc viếng, đào tường phía nam thành'
#               seg[0:60]='Thủ_Độ bắt các quan đến khóc viếng , đào tường phía nam thàn'
#               ids[:8]=[0, 61156, 537, 9, 2665, 30, 1521, 7842] | total_tokens=134
#       [TOKEN] id=019e40c0… | raw[0:60]='Gặp lúc ấy trong nước loạn lạc, Hoàng hậu mới cùng với Thủ'
#               seg[0:60]='Gặp lúc ấy trong nước loạn_lạc , Hoàng_hậu mới cùng với Thủ_'
#               ids[:8]=[0, 6837, 219, 241, 12, 58, 40156, 4] | total_tokens=70
#       [TOKEN] id=019e40c0… | raw[0:60]='Lời phê - Thủ Độ là công thần nhà Trần, tức là tội nhân nhà'
#               seg[0:60]='Lời phê - Thủ_Độ là công_thần nhà Trần , tức_là tội_nhân nhà'
#               ids[:8]=[0, 4190, 11083, 31, 61156, 8, 23284, 69] | total_tokens=111
#       [TOKEN] id=019e40c0… | raw[0:60]='Tháng 10, mùa đông. Suy tôn bố đẻ là Thừa làm Thượng hoàng;'
#               seg[0:60]='Tháng 10 , mùa đông . Suy_tôn_bố đẻ là Thừa_làm Thượng_hoàng'
#               ids[:8]=[0, 1641, 210, 4, 303, 553, 5, 39659] | total_tokens=135
#       [TOKEN] id=019e40c0… | raw[0:60]='Khi nhà vua được Chiêu Hoàng truyền ngôi cho, thì Trần Thừa'
#               seg[0:60]='Khi nhà_vua được Chiêu_Hoàng_truyền ngôi cho , thì Trần_Thừa'
#               ids[:8]=[0, 251, 9084, 11, 12982, 13761, 11097, 23214] | total_tokens=50
#       [TOKEN] id=019e40c0… | raw[0:60]='Đến nay, suy tôn làm Thượng hoàng, ở cung Phụ Thiên, nếu tro'
#               seg[0:60]='Đến nay , suy_tôn làm Thượng_hoàng , ở cung Phụ_Thiên , nếu'
#               ids[:8]=[0, 608, 136, 4, 42611, 47, 6293, 4567] | total_tokens=97
#       [TOKEN] id=019e40c0… | raw[0:60]='Định thể lệ tiền tệ.\nDân gian nộp tiền thượng cung, thì cứ m'
#               seg[0:60]='Định_thể_lệ tiền_tệ . Dân_gian nộp tiền thượng_cung , thì cứ'
#               ids[:8]=[0, 32792, 17193, 18658, 53473, 4375, 5, 30309] | total_tokens=100
#       [TOKEN] id=019e40c0… | raw[0:60]='Dùng Phùng Tá Chi Tri phủ Nghệ An.Tá Chu trước làm quan triề'
#               seg[0:60]='Dùng Phùng_Tá Chi_Tri phủ Nghệ_An . Tá_Chu trước làm quan tr'
#               ids[:8]=[0, 3960, 6237, 31146, 8470, 23062, 2149, 1295] | total_tokens=109
#       [TOKEN] id=019e40c0… | raw[0:60]='Đinh Hợi, năm thứ 3 (1227). (Tống, năm Bảo Khánh thứ 3).\nThá'
#               seg[0:60]='Đinh_Hợi , năm thứ 3 ( 1227 ) . ( Tống , năm Bảo_Khánh thứ 3'
#               ids[:8]=[0, 3912, 10500, 4, 29, 129, 107, 20] | total_tokens=133
#       [TOKEN] id=019e40c0… | raw[0:60]='"Người làm tôi phải hết lòng trung với vua, người làm quan'
#               seg[0:60]='" Người làm tôi phải hết_lòng trung với vua , người làm_quan'
#               ids[:8]=[0, 22, 345, 47, 70, 41, 8770, 2765] | total_tokens=129
#       [TOKEN] id=019e40c0… | raw[0:60]='Lời phê - Nhà Lý, nhà Trần lấy được nước, đều không theo chí'
#               seg[0:60]='Lời phê - Nhà_Lý , nhà Trần_lấy được nước , đều không theo c'
#               ids[:8]=[0, 4190, 11083, 31, 7029, 3272, 4, 69] | total_tokens=135
#       [TOKEN] id=019e40c0… | raw[0:60]='Tháng giêng, mùa xuân. Gia phong Nhật Hiệu làm Khâm Thiên đạ'
#               seg[0:60]='Tháng giêng , mùa xuân . Gia_phong Nhật_Hiệu làm Khâm_Thiên_'
#               ids[:8]=[0, 1641, 2667, 55140, 4, 303, 2184, 5] | total_tokens=122
#       [TOKEN] id=019e40c0… | raw[0:60]='Tháng 8, mùa thu. Phong cho anh là Liễu làm Thái uý.\nLiễu, đ'
#               seg[0:60]='Tháng 8 , mùa thu . Phong cho anh là Liễu làm Thái_úy . Liễu'
#               ids[:8]=[0, 1641, 358, 4, 303, 369, 5, 2352] | total_tokens=111
#       [TOKEN] id=019e40c0… | raw[0:60]='Xét trướng tịch ở Thanh Hóa.\nTheo chế độ nhà Lý, hằng năm sa'
#               seg[0:60]='Xét trướng_tịch ở Thanh_Hóa . Theo chế_độ nhà_Lý , hằng năm'
#               ids[:8]=[0, 6380, 55427, 7858, 13383, 25, 2841, 1125] | total_tokens=150
#       [TOKEN] id=019e40c0… | raw[0:60]='Việc này, triều nhà Trần cũng thi hành theo như phép triều'
#               seg[0:60]='Việc này , triều nhà Trần cũng thi_hành theo như phép triều'
#               ids[:8]=[0, 519, 23, 4, 5228, 69, 3212, 32] | total_tokens=184
#       [TOKEN] id=019e40c0… | raw[0:60]='Nguyễn Nộn đánh giết được Đoàn Thượng. Nhà vua đem Ngoạn Thi'
#               seg[0:60]='Nguyễn_Nộn đánh giết được Đoàn_Thượng . Nhà_vua đem Ngoạn_Th'
#               ids[:8]=[0, 1035, 1086, 22245, 480, 1460, 11, 6356] | total_tokens=137
#       [TOKEN] id=019e40c0… | raw[0:60]='Bấy giờ uy thanh Nguyễn Nộn lừng lẫy, Thủ Độ lấy làm lo lắm'
#               seg[0:60]='Bấy_giờ uy_thanh Nguyễn_Nộn lừng_lẫy , Thủ_Độ lấy_làm lo lắm'
#               ids[:8]=[0, 31326, 7441, 6698, 83, 1035, 1086, 22245] | total_tokens=128
#       [TOKEN] id=019e40c0… | raw[0:60]='Yên (An) Nhân: Tên xã, thuộc tỉnh Hải Dương bây giờ [2].\nKỷ'
#               seg[0:60]='Yên ( An ) Nhân : Tên xã , thuộc tỉnh Hải_Dương bây_giờ . Kỷ'
#               ids[:8]=[0, 4572, 20, 2234, 19, 2936, 27, 4473] | total_tokens=171
#       [TOKEN] id=019e40c0… | raw[0:60]='Nhà vua đã được nhà Lý truyền ngôi cho, nên mới sai sứ sang'
#               seg[0:60]='Nhà_vua đã được nhà_Lý_truyền ngôi cho , nên mới sai sứ sang'
#               ids[:8]=[0, 16353, 14, 11, 9096, 26542, 47188, 642] | total_tokens=45
# Đang đẩy 21 points lên Qdrant Cloud...
#  Đã lưu dữ liệu thành công lên Qdrant Cloud!
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW    3/54 | pages=[192, 193, 194, 195] | chars=6,692
#       [STRUCT] 2 structural boundaries | book='Khâm Định Việt Sử Thông Giám Cương '
#     [MINI-CHUNK] window chars=6,692 → 59 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
#  {"split_after_indices":[3,7,11,14,17,21,25,27,30,33,37,40,42,45,47,50,53,56]}
#
#
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=59 → splits=[3, 7, 11, 14, 17, 21, 25, 27, 30, 33, 37, 40, 42, 45, 47, 50, 53, 56]
# llm trả về
#  [3, 7, 11, 14, 17, 21, 25, 27, 30, 33, 37, 40, 42, 45, 47, 50, 53, 56]
#
#
#
#     [MERGE] 59 mini-chunks + 18 splits → 19 semantic groups
#       [TOKEN] id=019e40c1… | raw[0:60]='Tháng 3, mùa xuân. Định thể lệ làm ra sách Thông chế và các'
#               seg[0:60]='Tháng 3 , mùa xuân . Định_thể_lệ làm ra sách Thông_chế và cá'
#               ids[:8]=[0, 1641, 107, 4, 303, 2184, 5, 32792] | total_tokens=108
#       [TOKEN] id=019e40c1… | raw[0:60]='ai phải đày đi làm người "hoành" ở Tảo xã, thì thích sáu ch'
#               seg[0:60]='ai phải đày đi làm người " hoành " ở Tảo_xã , thì thích sáu'
#               ids[:8]=[0, 277, 41, 23819, 57, 47, 18, 22] | total_tokens=153
#       [TOKEN] id=019e40c1… | raw[0:60]='Nhân nền thành cũ của nhà Lý mà đắp thêm cho được kiên cố. T'
#               seg[0:60]='Nhân nền thành cũ của nhà_Lý mà đắp thêm cho được kiên_cố .'
#               ids[:8]=[0, 2936, 568, 302, 633, 7, 9096, 3272] | total_tokens=150
#       [TOKEN] id=019e40c1… | raw[0:60]='cung Quan Triều, chỗ Hoàng đế ở.\nTi Bình Bạc: Tức chức quan'
#               seg[0:60]='cung Quan_Triều , chỗ Hoàng_đế ở . Ti Bình_Bạc : Tức_chức_qu'
#               ids[:8]=[0, 1820, 8616, 6185, 4, 683, 9332, 25] | total_tokens=95
#       [TOKEN] id=019e40c1… | raw[0:60]='Đặt chức An phủ sứ [1] ở các lộ.\nMỗi lộ đặt hai viên, Chánh'
#               seg[0:60]='Đặt chức An_phủ sứ ở các lộ . Mỗi lộ đặt hai_viên , Chánh và'
#               ids[:8]=[0, 8209, 1766, 3187, 2149, 4986, 25, 9] | total_tokens=79
#       [TOKEN] id=019e40c1… | raw[0:60]='Tháng 9, mùa thu. Quốc Thánh Hoàng Thái hậu là Lê Thị mất, t'
#               seg[0:60]='Tháng 9 , mùa thu . Quốc_Thánh_Hoàng Thái_hậu là Lê_Thị_mất'
#               ids[:8]=[0, 1641, 426, 4, 303, 369, 5, 4049] | total_tokens=151
#       [TOKEN] id=019e40c1… | raw[0:60]='Lời chua - Diễn Châu: Xem thuộc Đường, Cao Tông, năm Điều Lộ'
#               seg[0:60]='Lời chua - Diễn_Châu : Xem thuộc Đường , Cao_Tông , năm Điều'
#               ids[:8]=[0, 4190, 5344, 31, 10435, 27, 2457, 187] | total_tokens=143
#       [TOKEN] id=019e40c1… | raw[0:60]='Thượng hoàng lúc còn hàn vi, thường ngồi nghỉ ở dịch đình;'
#               seg[0:60]='Thượng_hoàng lúc còn hàn_vi , thường ngồi nghỉ ở dịch_đình ;'
#               ids[:8]=[0, 6293, 4567, 219, 50, 36009, 5237, 4] | total_tokens=98
#       [TOKEN] id=019e40c1… | raw[0:60]='Nhâm Thìn, năm Thiên Ứng chính bình thứ 1 (1232). (Tống, năm'
#               seg[0:60]='Nhâm Thìn , năm Thiên_Ứng_chính bình thứ 1 ( 1232 ) . ( Tống'
#               ids[:8]=[0, 23075, 9939, 4, 29, 3545, 27677, 159] | total_tokens=107
#       [TOKEN] id=019e40c1… | raw[0:60]='Thượng hoàng không nhìn nhận gì đến. Người con trai ấy lúc'
#               seg[0:60]='Thượng_hoàng không nhìn_nhận gì đến . Người con trai ấy lúc'
#               ids[:8]=[0, 6293, 4567, 17, 3620, 148, 30, 5] | total_tokens=131
#       [TOKEN] id=019e40c1… | raw[0:60]='Lời chua - Tây Chân: Từ đời Trần trở về trước là tên huyện;'
#               seg[0:60]='Lời chua - Tây_Chân : Từ đời Trần_trở về trước là tên huyện'
#               ids[:8]=[0, 4190, 5344, 31, 3848, 6054, 27, 404] | total_tokens=147
#       [TOKEN] id=019e40c1… | raw[0:60]='Lời chua - Thái học sinh: Tức khoa Tiến sữ, nhưng lúc bấy gi'
#               seg[0:60]='Lời chua - Thái_học_sinh : Tức_khoa Tiến_sữ , nhưng lúc bấy_'
#               ids[:8]=[0, 4190, 5344, 31, 3264, 400, 27, 48005] | total_tokens=103
#       [TOKEN] id=019e40c1… | raw[0:60]='Tháng 4, mùa hạ. Ban chữ huý về tiên tổ nhà vua thờ ở các mi'
#               seg[0:60]='Tháng 4 , mùa hạ . Ban chữ_húy về tiên_tổ nhà_vua thờ ở các'
#               ids[:8]=[0, 1641, 163, 4, 303, 1269, 5, 440] | total_tokens=89
#       [TOKEN] id=019e40c1… | raw[0:60]='Tháng 8, mùa thu. Gió bão to. Dân gian phát sinh bệnh dịch.'
#               seg[0:60]='Tháng 8 , mùa thu . Gió_bão to . Dân_gian phát_sinh bệnh_dịc'
#               ids[:8]=[0, 1641, 358, 4, 303, 369, 5, 23778] | total_tokens=108
#       [TOKEN] id=019e40c1… | raw[0:60]='chôn sống hết tôn thất nhà Lý.\nLời phê - Thảm quá! Nhưng gi'
#               seg[0:60]='chôn sống hết tôn_thất nhà_Lý . Lời phê - Thảm quá !_Nhưng g'
#               ids[:8]=[0, 4238, 235, 351, 15359, 49299, 9096, 3272] | total_tokens=98
#       [TOKEN] id=019e40c1… | raw[0:60]='Quý Tị, năm thứ 2 (1233). (Tống, năm Thiệu Định thứ 6).\nSai'
#               seg[0:60]='Quý_Tị , năm thứ 2 ( 1233 ) . ( Tống , năm Thiệu_Định thứ 6'
#               ids[:8]=[0, 7901, 52031, 4, 29, 129, 76, 20] | total_tokens=169
#       [TOKEN] id=019e40c1… | raw[0:60]='Lời chua - Thọ Lăng: Ở làng Tinh Cương, phủ Long Hưng.\nSách'
#               seg[0:60]='Lời chua - Thọ_Lăng : Ở làng Tinh_Cương , phủ Long_Hưng . Sá'
#               ids[:8]=[0, 4190, 5344, 31, 1827, 54996, 8795, 27] | total_tokens=113
#       [TOKEN] id=019e40c1… | raw[0:60]='Phong cho Phùng Tá Chu tước Hưng Nhân vương và bổ dụng Phạm'
#               seg[0:60]='Phong cho Phùng_Tá Chu_tước Hưng_Nhân_vương và bổ_dụng Phạm_'
#               ids[:8]=[0, 2352, 13, 6237, 31146, 1735, 14279, 3113] | total_tokens=94
#       [TOKEN] id=019e40c1… | raw[0:60]='Sau này lại gia phong Tá Chu làm Đại vương, Kính Ân làm Thá'
#               seg[0:60]='Sau_này lại gia_phong Tá_Chu làm Đại_vương , Kính_Ân làm Thá'
#               ids[:8]=[0, 5933, 44, 14127, 3448, 35789, 8478, 47] | total_tokens=86
# Đang đẩy 19 points lên Qdrant Cloud...
#  Đã lưu dữ liệu thành công lên Qdrant Cloud!
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW    4/54 | pages=[195, 196, 197, 198] | chars=8,966
#       [STRUCT] 2 structural boundaries | book='Khâm Định Việt Sử Thông Giám Cương '
#     [MINI-CHUNK] window chars=8,966 → 83 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
#  {"split_after_indices":[3,7,11,15,19,23,25,29,33,37,41,45,49,53,57,61,65,69,73,77,81]}
#
#
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=83 → splits=[3, 7, 11, 15, 19, 23, 25, 29, 33, 37, 41, 45, 49, 53, 57, 61, 65, 69, 73, 77, 81]
# llm trả về
#  [3, 7, 11, 15, 19, 23, 25, 29, 33, 37, 41, 45, 49, 53, 57, 61, 65, 69, 73, 77, 81]
#
#
#
#     [MERGE] 83 mini-chunks + 21 splits → 22 semantic groups
#       [TOKEN] id=019e40c1… | raw[0:60]='Tháng 2, mùa xuân. Định quan hàm các bậc đại thần.\nPhàm nhữn'
#               seg[0:60]='Tháng 2 , mùa xuân . Định quan_hàm các bậc đại_thần . Phàm n'
#               ids[:8]=[0, 1641, 76, 4, 303, 2184, 5, 5631] | total_tokens=111
#       [TOKEN] id=019e40c1… | raw[0:60]='Quan chế nhà Trần, đại yếu lấy tam công [1], tam thiếu [2]'
#               seg[0:60]='Quan_chế nhà Trần , đại_yếu lấy tam_công , tam_thiếu Thái_úy'
#               ids[:8]=[0, 8616, 3056, 69, 3212, 4, 7250, 1783] | total_tokens=115
#       [TOKEN] id=019e40c1… | raw[0:60]='Thượng thư, Thị lang, Lang trung, Viên ngoại lang, Trung th'
#               seg[0:60]='Thượng_thư , Thị_lang , Lang_trung , Viên ngoại_lang , Trung'
#               ids[:8]=[0, 31602, 4, 33844, 50745, 4, 6454, 11097] | total_tokens=168
#       [TOKEN] id=019e40c1… | raw[0:60]='Về quan chức ở ngoài thì có: An phủ sứ, Tri phủ, Thông phán,'
#               seg[0:60]='Về quan_chức ở ngoài thì có : An_phủ sứ , Tri_phủ , Thông_ph'
#               ids[:8]=[0, 674, 1480, 25, 227, 54, 10, 27] | total_tokens=127
#       [TOKEN] id=019e40c1… | raw[0:60]='Đô thống chế.\nChức quan võ ở ngoài các lộ thì có: Kinh lược'
#               seg[0:60]='Đô_thống_chế . Chức_quan võ ở ngoài các lộ thì_có : Kinh_lượ'
#               ids[:8]=[0, 25487, 6698, 57456, 5, 55557, 2665, 4901] | total_tokens=131
#       [TOKEN] id=019e40c1… | raw[0:60]='Tháng 6, mùa hạ. Nước to, chảy tràn vào cung Lệ Thiên. Hiểu'
#               seg[0:60]='Tháng 6 , mùa hạ . Nước to , chảy tràn vào cung_Lệ_Thiên . H'
#               ids[:8]=[0, 1641, 245, 4, 303, 1269, 5, 2837] | total_tokens=164
#       [TOKEN] id=019e40c1… | raw[0:60]='Lời cẩn án - Sách Cương mục tục biên [Trung Quốc] chép: Năm'
#               seg[0:60]='Lời cẩn_án - Sách Cương_mục_tục biên_[ Trung_Quốc ]_chép : N'
#               ids[:8]=[0, 4190, 3, 565, 31, 6042, 28763, 36739] | total_tokens=81
#       [TOKEN] id=019e40c1… | raw[0:60]='Đinh Dậu, năm thứ 6 (1237). (Tống, năm Gia Hy thứ 1).\nTháng'
#               seg[0:60]='Đinh_Dậu , năm thứ 6 ( 1237 ) . ( Tống , năm Gia_Hy thứ 1 )'
#               ids[:8]=[0, 9920, 4, 29, 129, 245, 20, 2789] | total_tokens=127
#       [TOKEN] id=019e40c1… | raw[0:60]='Nhà vua lấy làm áy náy không yên lòng, đêm lẻn sang núi Yên'
#               seg[0:60]='Nhà_vua lấy_làm áy_náy không yên_lòng , đêm lẻn sang núi Yên'
#               ids[:8]=[0, 16353, 11184, 28322, 17, 28031, 4, 396] | total_tokens=110
#       [TOKEN] id=019e40c1… | raw[0:60]='Thủ Độ cố mời, nhưng vua vẫn chưa nhận lời. Thủ Độ ra bảo vớ'
#               seg[0:60]='Thủ_Độ cố mời , nhưng vua vẫn chưa nhận_lời . Thủ_Độ ra bảo'
#               ids[:8]=[0, 61156, 2105, 844, 4, 51, 1692, 74] | total_tokens=121
#       [TOKEN] id=019e40c1… | raw[0:60]='Trần Liễu ở ngoài biển được hai tuần [3], tự biết việc mình'
#               seg[0:60]='Trần_Liễu ở ngoài biển được hai tuần , tự biết việc mình làm'
#               ids[:8]=[0, 1359, 11191, 25, 227, 262, 11, 82] | total_tokens=132
#       [TOKEN] id=019e40c1… | raw[0:60]='Miệng nói, nhưng lấy mình che đỡ cho Trần Liễu. Thủ Độ giận'
#               seg[0:60]='Miệng nói , nhưng lấy mình che đỡ cho Trần_Liễu . Thủ_Độ giậ'
#               ids[:8]=[0, 29675, 96, 4, 51, 273, 68, 3057] | total_tokens=131
#       [TOKEN] id=019e40c1… | raw[0:60]='còn những người theo Trần Liễu khởi loạn ở sông Cái đều bị'
#               seg[0:60]='còn những người theo Trần_Liễu_khởi_loạn ở sông_Cái đều bị g'
#               ids[:8]=[0, 50, 21, 18, 63, 1359, 21088, 45904] | total_tokens=110
#       [TOKEN] id=019e40c1… | raw[0:60]='Vả lại, lúc mới khai quốc, vua còn thơ ấu, lòng người còn n'
#               seg[0:60]='Vả_lại , lúc mới khai_quốc , vua còn thơ_ấu , lòng người còn'
#               ids[:8]=[0, 25198, 4, 219, 60, 20898, 3705, 4] | total_tokens=146
#       [TOKEN] id=019e40c1… | raw[0:60]='như thế chả phải tự mình làm trái luân thường để mở đầu cái'
#               seg[0:60]='như thế chả phải tự mình làm trái luân_thường để mở_đầu cái'
#               ids[:8]=[0, 42, 570, 4071, 41, 385, 68, 47] | total_tokens=124
#       [TOKEN] id=019e40c1… | raw[0:60]='Lời chua - Núi Yên Tử: Ở huyện Đông Triều, tỉnh Hải Dương; t'
#               seg[0:60]='Lời chua - Núi_Yên_Tử : Ở huyện Đông_Triều , tỉnh Hải_Dương'
#               ids[:8]=[0, 4190, 5344, 31, 44169, 12369, 27, 635] | total_tokens=128
#       [TOKEN] id=019e40c1… | raw[0:60]='Bầy tôi xin dâng tôn hiệu là: Thống thiên ngự cực long công'
#               seg[0:60]='Bầy tôi xin dâng tôn_hiệu là : Thống_thiên_ngự cực long công'
#               ids[:8]=[0, 27398, 70, 611, 2882, 32041, 3256, 8] | total_tokens=191
#       [TOKEN] id=019e40c1… | raw[0:60]='Việc làm trướng tịch, duy có Thanh Hóa là làm trước và tườn'
#               seg[0:60]='Việc_làm trướng_tịch , duy có Thanh_Hóa là làm trước và tườn'
#               ids[:8]=[0, 9854, 55427, 7858, 13383, 4, 22986, 10] | total_tokens=150
#       [TOKEN] id=019e40c1… | raw[0:60]='Tháng giêng, mùa xuân. Dựng cung điện ở làng Tức Mặc.Nhà vua'
#               seg[0:60]='Tháng giêng , mùa xuân . Dựng cung_điện ở làng Tức_Mặc . Nhà'
#               ids[:8]=[0, 1641, 2667, 55140, 4, 303, 2184, 5] | total_tokens=164
#       [TOKEN] id=019e40c1… | raw[0:60]='Tháng 7, mùa thu. Mưa to, gió lớn; nước tràn lên cao; đất độ'
#               seg[0:60]='Tháng 7 , mùa thu . Mưa to , gió lớn ; nước tràn lên cao ; đ'
#               ids[:8]=[0, 1641, 317, 4, 303, 369, 5, 7937] | total_tokens=150
#       [TOKEN] id=019e40c1… | raw[0:60]='Vì thế, nhà vua sai Bùi Khâm đi trù liệu sắp xếp việc này.'
#               seg[0:60]='Vì_thế , nhà_vua sai Bùi_Khâm đi trù_liệu sắp_xếp việc này .'
#               ids[:8]=[0, 1999, 4, 9084, 1069, 3177, 29455, 57] | total_tokens=132
#       [TOKEN] id=019e40c1… | raw[0:60]='Núi ở các lộ sụt xuống; đất liền ở phường Thịnh Quang ngoài'
#               seg[0:60]='Núi ở các lộ sụt xuống ; đất_liền ở phường Thịnh_Quang ngoài'
#               ids[:8]=[0, 6092, 25, 9, 1776, 6658, 307, 65] | total_tokens=21
# Đang đẩy 22 points lên Qdrant Cloud...
#  Đã lưu dữ liệu thành công lên Qdrant Cloud!
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW    5/54 | pages=[198, 199, 200, 201] | chars=7,322
#       [STRUCT] 2 structural boundaries | book='Khâm Định Việt Sử Thông Giám Cương '
#     [MINI-CHUNK] window chars=7,322 → 69 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
#  {"split_after_indices":[3,7,8,11,15,18,22,27,30,33,38,43,45,47,49,53,57,61,64,67]}
#
#
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=69 → splits=[3, 7, 8, 11, 15, 18, 22, 26, 27, 30, 33, 37, 38, 42, 43, 45, 47, 49, 53, 57, 61, 64, 67]
# llm trả về
#  [3, 7, 8, 11, 15, 18, 22, 26, 27, 30, 33, 37, 38, 42, 43, 45, 47, 49, 53, 57, 61, 64, 67]
#
#
#
#     [MERGE] 69 mini-chunks + 23 splits → 24 semantic groups
#       [TOKEN] id=019e40c2… | raw[0:60]='Tháng 10, mùa đông. Người Thổ, Mán nhà Tống sang cướp ở biên'
#               seg[0:60]='Tháng 10 , mùa đông . Người Thổ , Mán nhà Tống sang cướp ở b'
#               ids[:8]=[0, 1641, 210, 4, 303, 553, 5, 345] | total_tokens=129
#       [TOKEN] id=019e40c2… | raw[0:60]='Ban đầu, người ở châu ấy không biết tình hình thế nào, đều'
#               seg[0:60]='Ban_đầu , người ở châu ấy không biết tình_hình thế_nào , đều'
#               ids[:8]=[0, 4163, 4, 18, 25, 2935, 241, 17] | total_tokens=115
#       [TOKEN] id=019e40c2… | raw[0:60]='Khâm: Tên châu, xem Lê Đại Hành, năm Ứng Thiên thứ 10 (Chb.'
#               seg[0:60]='Khâm : Tên châu , xem Lê_Đại_Hành , năm Ứng_Thiên_thứ 10 ( C'
#               ids[:8]=[0, 29455, 27, 4473, 2935, 4, 305, 26094] | total_tokens=80
#       [TOKEN] id=019e40c2… | raw[0:60]='Nhâm Dần, năm thứ 11 (1242). (Tống, năm Thuần Hựu thứ 2).\nTh'
#               seg[0:60]='Nhâm Dần , năm thứ 11 ( 1242 ) . ( Tống , năm Thuần_Hựu thứ'
#               ids[:8]=[0, 23075, 9585, 4, 29, 129, 624, 20] | total_tokens=96
#       [TOKEN] id=019e40c2… | raw[0:60]='ngũ phẩm trở lên làm quan đại tư xã, lục phẩm trở xuống làm'
#               seg[0:60]='ngũ_phẩm trở lên làm quan đại_tư xã , lục_phẩm trở xuống làm'
#               ids[:8]=[0, 34893, 3884, 682, 72, 47, 2665, 26310] | total_tokens=107
#       [TOKEN] id=019e40c2… | raw[0:60]='Về thuế: nhân đinh, ai có ruộng đất thì phải nộp tiền, thóc:'
#               seg[0:60]='Về thuế : nhân đinh , ai có ruộng_đất thì phải nộp tiền , th'
#               ids[:8]=[0, 674, 578, 27, 1362, 6358, 4, 277] | total_tokens=106
#       [TOKEN] id=019e40c2… | raw[0:60]='Ruộng công điền nhà Trần có hai hạng; mỗi hạng chia ra làm b'
#               seg[0:60]='Ruộng công_điền nhà Trần_có hai hạng ; mỗi hạng chia ra làm'
#               ids[:8]=[0, 38526, 7173, 7932, 69, 1359, 10, 82] | total_tokens=154
#       [TOKEN] id=019e40c2… | raw[0:60]='Lại tham khảo lời chua tập thơ An Nam tức sự của Trần Cương'
#               seg[0:60]='Lại tham_khảo lời chua_tập thơ An_Nam tức_sự của Trần_Cương_'
#               ids[:8]=[0, 6289, 2981, 278, 7304, 12013, 4581, 1924] | total_tokens=129
#       [TOKEN] id=019e40c2… | raw[0:60]='Nhưng đây cũng chỉ biết đại lược mà thôi, còn chi tiết rõ r'
#               seg[0:60]='Nhưng đây cũng chỉ biết đại_lược mà thôi , còn chi_tiết rõ_r'
#               ids[:8]=[0, 293, 97, 32, 66, 55, 7250, 8536] | total_tokens=44
#       [TOKEN] id=019e40c2… | raw[0:60]='Lời chua - Mười hai lộ: Sử cũ không chép rõ, nhưng căn cứ nh'
#               seg[0:60]='Lời chua - Mười hai lộ : Sử cũ không chép rõ , nhưng căn_cứ'
#               ids[:8]=[0, 4190, 5344, 31, 7006, 82, 1776, 27] | total_tokens=119
#       [TOKEN] id=019e40c2… | raw[0:60]='Hoàng nam: 18 tuổi là tiểu hoàng nam, 20 tuổi là đại hoàng n'
#               seg[0:60]='Hoàng_nam : 18 tuổi là tiểu_hoàng nam , 20 tuổi là đại_hoàng'
#               ids[:8]=[0, 1826, 542, 27, 890, 126, 8, 26496] | total_tokens=89
#       [TOKEN] id=019e40c2… | raw[0:60]='Phụng Hiểu nói: Không muốn thưởng quan tước, chỉ xin đứng t'
#               seg[0:60]='Phụng Hiểu nói : Không muốn thưởng quan_tước , chỉ xin đứng'
#               ids[:8]=[0, 8082, 9946, 96, 27, 453, 202, 1740] | total_tokens=101
#       [TOKEN] id=019e40c2… | raw[0:60]='Lý Thái Tông liền đem đất làng Đa My ban cho Phụng Hiểu, th'
#               seg[0:60]='Lý_Thái_Tông liền đem đất làng Đa_My ban cho Phụng Hiểu , th'
#               ids[:8]=[0, 2878, 27024, 1228, 873, 179, 632, 10180] | total_tokens=70
#       [TOKEN] id=019e40c2… | raw[0:60]='Xã, sách: Cũng như xã, thôn.Lời phê [1] - Nói rất mơ hồ.\nThá'
#               seg[0:60]='Xã , sách : Cũng như xã , thôn . Lời_phê - Nói rất mơ_hồ . T'
#               ids[:8]=[0, 3074, 4, 713, 27, 670, 42, 176] | total_tokens=147
#       [TOKEN] id=019e40c2… | raw[0:60]='Vì thế, nhà vua sai Khuê Kình đem quân đi trấn ngự, đánh ch'
#               seg[0:60]='Vì_thế , nhà_vua sai Khuê_Kình đem quân đi trấn_ngự , đánh c'
#               ids[:8]=[0, 1999, 4, 9084, 1069, 23153, 46125, 873] | total_tokens=54
#       [TOKEN] id=019e40c2… | raw[0:60]='Lời chua - Ung Châu: Xem Đinh Đế Toàn, năm Thái Bình thứ 2 ('
#               seg[0:60]='Lời chua - Ung_Châu : Xem Đinh_Đế_Toàn , năm Thái_Bình thứ 2'
#               ids[:8]=[0, 4190, 5344, 31, 28200, 2365, 27, 2457] | total_tokens=85
#       [TOKEN] id=019e40c2… | raw[0:60]='Đại hạn từ tháng 5 đến tháng 6. Nhà vua hạ lệnh xét lại tội'
#               seg[0:60]='Đại_hạn từ tháng 5 đến tháng 6 . Nhà_vua hạ_lệnh xét lại tội'
#               ids[:8]=[0, 2847, 2559, 39, 78, 173, 30, 78] | total_tokens=105
#       [TOKEN] id=019e40c2… | raw[0:60]='Tháng giêng, mùa xuân. Hạ lệnh cho các lộ làm sổ dân đinh.\nT'
#               seg[0:60]='Tháng giêng , mùa xuân . Hạ_lệnh cho các lộ làm sổ dân đinh'
#               ids[:8]=[0, 1641, 2667, 55140, 4, 303, 2184, 5] | total_tokens=104
#       [TOKEN] id=019e40c2… | raw[0:60]='Tháng 8, mùa thu. Nước to, chảy tràn vào kinh thành.\nGiáp Th'
#               seg[0:60]='Tháng 8 , mùa thu . Nước to , chảy tràn vào kinh_thành . Giá'
#               ids[:8]=[0, 1641, 358, 4, 303, 369, 5, 2837] | total_tokens=122
#       [TOKEN] id=019e40c2… | raw[0:60]='Lời cẩn án - Sách Lịch triều hiến chương của Phan Huy Chú ch'
#               seg[0:60]='Lời cẩn_án - Sách Lịch_triều hiến_chương của Phan_Huy_Chú ch'
#               ids[:8]=[0, 4190, 3, 565, 31, 6042, 59497, 1347] | total_tokens=129
#       [TOKEN] id=019e40c2… | raw[0:60]='Tháng 3. Ban cho Phùng Tá Thang chức Tả giai [2] Đạo lục [3]'
#               seg[0:60]='Tháng 3 . Ban cho Phùng_Tá Thang_chức Tả giai_Đạo_lục , được'
#               ids[:8]=[0, 1641, 107, 5, 440, 13, 6237, 31146] | total_tokens=127
#       [TOKEN] id=019e40c2… | raw[0:60]='Lời chua - Tá Thang: Là thân phụ Tá Chu.\nTháng 10, mùa đông.'
#               seg[0:60]='Lời chua - Tá_Thang : Là thân phụ Tá_Chu . Tháng 10 , mùa đô'
#               ids[:8]=[0, 4190, 5344, 31, 35789, 30694, 27, 1589] | total_tokens=115
#       [TOKEN] id=019e40c2… | raw[0:60]='Ất Tị, năm thứ 14 (1245). (Tống, năm Thuần Hựu thứ 5). Tháng'
#               seg[0:60]='Ất_Tị , năm thứ 14 ( 1245 ) . ( Tống , năm Thuần_Hựu thứ 5 )'
#               ids[:8]=[0, 37259, 52031, 4, 29, 129, 948, 20] | total_tokens=134
#       [TOKEN] id=019e40c2… | raw[0:60]='Bính Ngọ, năm thứ 15 (1246). (Tống, năm Thuần Hựu thứ 6).'
#               seg[0:60]='Bính_Ngọ , năm thứ 15 ( 1246 ) . ( Tống , năm Thuần_Hựu thứ'
#               ids[:8]=[0, 31504, 10566, 4, 29, 129, 613, 20] | total_tokens=23
# Đang đẩy 24 points lên Qdrant Cloud...
#  Đã lưu dữ liệu thành công lên Qdrant Cloud!
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW    6/54 | pages=[201, 202, 203, 204] | chars=7,650
#       [STRUCT] 2 structural boundaries | book='Khâm Định Việt Sử Thông Giám Cương '
#     [MINI-CHUNK] window chars=7,650 → 69 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
#  {"split_after_indices":[3,7,11,15,19,23,27,31,35,39,43,47,51,55,59,63,67]}
#
#
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=69 → splits=[3, 7, 11, 15, 19, 23, 27, 31, 35, 39, 43, 47, 51, 55, 59, 63, 67]
# llm trả về
#  [3, 7, 11, 15, 19, 23, 27, 31, 35, 39, 43, 47, 51, 55, 59, 63, 67]
#
#
#
#     [MERGE] 69 mini-chunks + 17 splits → 18 semantic groups
#       [TOKEN] id=019e40c2… | raw[0:60]='Tháng 2, mùa xuân. Định danh hiệu quân đội.\nTuyển lấy những'
#               seg[0:60]='Tháng 2 , mùa xuân . Định danh_hiệu quân_đội . Tuyển lấy nhữ'
#               ids[:8]=[0, 1641, 76, 4, 303, 2184, 5, 5631] | total_tokens=125
#       [TOKEN] id=019e40c2… | raw[0:60]='Hạng thứ ba là đoàn đội chèo thuyền.\nLời cẩn án - Sách Lịch'
#               seg[0:60]='Hạng thứ ba là đoàn đội chèo thuyền . Lời cẩn_án - Sách Lịch'
#               ids[:8]=[0, 10484, 129, 346, 8, 639, 226, 6595] | total_tokens=121
#       [TOKEN] id=019e40c2… | raw[0:60]='Có lẽ vì chế độ nhà Trần, các tước vương cũng được chiêu mộ'
#               seg[0:60]='Có_lẽ vì chế_độ nhà_Trần , các tước_vương cũng được chiêu_mộ'
#               ids[:8]=[0, 2909, 90, 1150, 9096, 3212, 4, 9] | total_tokens=112
#       [TOKEN] id=019e40c2… | raw[0:60]='Đại để khi trong nước không có việc, thì cho quân lính về l'
#               seg[0:60]='Đại để khi trong nước không có việc , thì cho quân_lính về l'
#               ids[:8]=[0, 3449, 24, 26, 12, 58, 17, 10] | total_tokens=116
#       [TOKEN] id=019e40c2… | raw[0:60]='Nhà Trần khởi lên từ lộ Thiên Trường, cho nên lấy quân ở bả'
#               seg[0:60]='Nhà Trần_khởi_lên từ lộ Thiên_Trường , cho_nên lấy quân ở bả'
#               ids[:8]=[0, 1706, 1359, 45904, 72, 39, 1776, 28695] | total_tokens=105
#       [TOKEN] id=019e40c2… | raw[0:60]='rồi lại dùng hai chữ "Thiên Trường" đứng đầulộ ấy gọi là Th'
#               seg[0:60]='rồi lại dùng hai chữ " Thiên_Trường " đứng đầulộ ấy gọi_là T'
#               ids[:8]=[0, 182, 44, 175, 82, 1196, 22, 28695] | total_tokens=160
#       [TOKEN] id=019e40c2… | raw[0:60]='Kiến Xương: Chưa rõ đặt ra từ đời nào. Nhà Trần gọi là lộ; đ'
#               seg[0:60]='Kiến_Xương : Chưa rõ đặt ra từ đời nào . Nhà_Trần gọi_là lộ'
#               ids[:8]=[0, 35459, 27, 2066, 297, 320, 40, 39] | total_tokens=115
#       [TOKEN] id=019e40c2… | raw[0:60]='VIII, 12- 13), tên Thiên Trường mới đặt từ năm Thiệu Long t'
#               seg[0:60]='VIII , 12 - 13 ) , tên Thiên_Trường mới đặt từ năm Thiệu_Lon'
#               ids[:8]=[0, 11046, 4, 445, 31, 964, 19, 4] | total_tokens=143
#       [TOKEN] id=019e40c2… | raw[0:60]='Chức quan nào khuyết, thì đem người chánh kiêm làm công việ'
#               seg[0:60]='Chức_quan nào khuyết , thì đem người chánh kiêm làm công_việ'
#               ids[:8]=[0, 55557, 2665, 142, 11986, 4, 54, 873] | total_tokens=140
#       [TOKEN] id=019e40c2… | raw[0:60]='Lời phê - Nói quá đáng, không đủ tin [8]. Vả lại, định niên'
#               seg[0:60]='Lời phê - Nói quá_đáng , không đủ tin . Vả_lại , định_niên_h'
#               ids[:8]=[0, 4190, 11083, 31, 1950, 15775, 4, 17] | total_tokens=118
#       [TOKEN] id=019e40c2… | raw[0:60]='Tháng 7, mùa thu. Mới định niên hạn thi đại tị [1].Bấy giờ t'
#               seg[0:60]='Tháng 7 , mùa thu . Mới_định niên_hạn thi đại_tị . Bấy_giờ t'
#               ids[:8]=[0, 1641, 317, 4, 303, 369, 5, 47918] | total_tokens=144
#       [TOKEN] id=019e40c2… | raw[0:60]='Còn 48 người đỗ Thái học sinh đều được xuất thân [3] theo t'
#               seg[0:60]='Còn 48 người đỗ Thái_học_sinh đều được xuất_thân theo thứ_tự'
#               ids[:8]=[0, 631, 3020, 18, 1875, 3264, 400, 131] | total_tokens=159
#       [TOKEN] id=019e40c2… | raw[0:60]='Năm ấy, lấy Ngô Tần đỗ giáp khoa; Đào Diễn, Hoàng Hoan, Vũ'
#               seg[0:60]='Năm ấy , lấy Ngô_Tần_đỗ giáp_khoa ; Đào_Diễn , Hoàng_Hoan ,'
#               ids[:8]=[0, 434, 241, 4, 273, 2929, 982, 21288] | total_tokens=150
#       [TOKEN] id=019e40c2… | raw[0:60]='Nhà vua hạ lệnh cho các lộ đắp đê tự đầu nguồn đến bãi biển,'
#               seg[0:60]='Nhà_vua hạ_lệnh cho các lộ đắp đê tự đầu nguồn đến bãi biển'
#               ids[:8]=[0, 16353, 32871, 13, 9, 1776, 4253, 4331] | total_tokens=150
# ...
#               ids[:8]=[0, 1641, 2667, 55140, 4, 303, 2184, 5] | total_tokens=118
#       [TOKEN] id=019e40d0… | raw[0:60]='Tháng 5, mùa hạ. Đế Quý Khoáng đánh nhau với quân nhà Minh ở'
#               seg[0:60]='Tháng 5 , mùa hạ . Đế Quý_Khoáng đánh nhau với quân nhà_Minh'
#               ids[:8]=[0, 1641, 173, 4, 303, 1269, 5, 9326] | total_tokens=130
#       [TOKEN] id=019e40d0… | raw[0:60]='Đế Quý Khoáng trao cho Mặc quản trị phủ Thanh Hóa. Lại có b'
#               seg[0:60]='Đế Quý_Khoáng trao cho Mặc_quản_trị phủ Thanh_Hóa . Lại có b'
#               ids[:8]=[0, 9326, 7901, 39072, 906, 13, 22085, 3411] | total_tokens=100
#       [TOKEN] id=019e40d0… | raw[0:60]='Đế Quý Khoáng lại dẫn quân về Nghệ An.\nTân Mão (1411). (Trầ'
#               seg[0:60]='Đế Quý_Khoáng lại dẫn_quân về Nghệ_An . Tân_Mão ( 1411 ) . ('
#               ids[:8]=[0, 9326, 7901, 39072, 44, 40926, 829, 28] | total_tokens=126
#       [TOKEN] id=019e40d0… | raw[0:60]='Vua nhà Minh lại dụ bọn quan lại, quân và dân rằng: "Người'
#               seg[0:60]='Vua nhà_Minh lại dụ bọn quan_lại , quân và dân rằng : " Ngườ'
#               ids[:8]=[0, 6933, 9096, 1612, 44, 11536, 3129, 23123] | total_tokens=158
#       [TOKEN] id=019e40d0… | raw[0:60]='bị người khác làm cho lầm lẫn, chứ không phải bản tâm chúng'
#               seg[0:60]='bị người khác làm cho lầm_lẫn , chứ không phải bản_tâm chúng'
#               ids[:8]=[0, 45, 18, 85, 47, 13, 1494, 55483] | total_tokens=127
#       [TOKEN] id=019e40d0… | raw[0:60]='mà lại còn được quan tước hiển vinh là khác nữa".\nTháng 9,'
#               seg[0:60]='mà_lại còn được quan_tước hiển_vinh là khác nữa " . Tháng 9'
#               ids[:8]=[0, 5666, 50, 11, 55214, 3113, 60710, 28898] | total_tokens=147
#       [TOKEN] id=019e40d0… | raw[0:60]='Khi bọn Nghiện Thần đến Yên Kinh, vua Minh sai Hồ Nguyên Tr'
#               seg[0:60]='Khi bọn Nghiện_Thần đến Yên_Kinh , vua Minh_sai Hồ_Nguyên_Tr'
#               ids[:8]=[0, 251, 3129, 3305, 25294, 7543, 30, 5562] | total_tokens=133
#       [TOKEN] id=019e40d0… | raw[0:60]='Đế Quý Khoáng bèn bắt giam Nghiện Thần rồi giết đi.\nLời phê'
#               seg[0:60]='Đế Quý_Khoáng bèn bắt giam Nghiện_Thần rồi giết đi . Lời_phê'
#               ids[:8]=[0, 9326, 7901, 39072, 8711, 537, 2943, 3305] | total_tokens=79
#       [TOKEN] id=019e40d0… | raw[0:60]='Năm Khai Đại thứ 3 (1405) đời Hồ Hán Thương, Nghiện Thần đư'
#               seg[0:60]='Năm_Khai Đại_thứ 3 ( 1405 ) đời Hồ_Hán_Thương , Nghiện_Thần'
#               ids[:8]=[0, 28888, 14050, 28318, 55107, 107, 20, 3012] | total_tokens=145
#       [TOKEN] id=019e40d0… | raw[0:60]='Đại lược ba kế sách nói: "Nhà Minh đã ra sắc lệnh cho Các h'
#               seg[0:60]='Đại_lược ba kế_sách nói : " Nhà_Minh đã ra sắc_lệnh cho Các'
#               ids[:8]=[0, 2847, 8536, 346, 35077, 96, 27, 22] | total_tokens=128
#       [TOKEN] id=019e40d0… | raw[0:60]='đấy là thượng sách. Nếu không được như thế, thì từ bỏ quan'
#               seg[0:60]='đấy là thượng_sách . Nếu không được như_thế , thì từ_bỏ quan'
#               ids[:8]=[0, 1582, 8, 16191, 713, 5, 313, 17] | total_tokens=56
#       [TOKEN] id=019e40d0… | raw[0:60]='Còn như cứ quyến luyến quan cao lộc hậu thì là hạ sách.\n"Nế'
#               seg[0:60]='Còn như cứ quyến_luyến quan_cao lộc_hậu thì là hạ_sách . " N'
#               ids[:8]=[0, 631, 42, 658, 51288, 19748, 84, 1494] | total_tokens=139
#       [TOKEN] id=019e40d0… | raw[0:60]='Đến khi nhà Minh tịch thu nhà Bá Kỳ [6], bắt được bức thư nà'
#               seg[0:60]='Đến khi nhà_Minh_tịch_thu nhà Bá_Kỳ , bắt được bức thư này ,'
#               ids[:8]=[0, 608, 26, 9096, 4272, 12641, 15490, 57827] | total_tokens=100
#       [TOKEN] id=019e40d0… | raw[0:60]='sau hai cha con đều bị bệnh chết.\nNhâm Thìn (1412), (Trần,'
#               seg[0:60]='sau hai cha_con đều bị bệnh chết . Nhâm_Thìn ( 1412 ) , ( Tr'
#               ids[:8]=[0, 53, 82, 8217, 131, 45, 326, 366] | total_tokens=124
# Đang đẩy 25 points lên Qdrant Cloud...
#  Đã lưu dữ liệu thành công lên Qdrant Cloud!
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW   53/54 | pages=[345, 346, 347, 348] | chars=9,187
#       [STRUCT] 2 structural boundaries | book='Khâm Định Việt Sử Thông Giám Cương '
#     [MINI-CHUNK] window chars=9,187 → 82 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
#  {"split_after_indices":[3,7,11,15,19,23,26,30,33,37,41,45,49,53,57,61,65,69,73,77]}
#
#
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=82 → splits=[3, 7, 11, 15, 19, 23, 26, 30, 33, 37, 41, 45, 49, 53, 57, 61, 65, 69, 73, 77]
# llm trả về
#  [3, 7, 11, 15, 19, 23, 26, 30, 33, 37, 41, 45, 49, 53, 57, 61, 65, 69, 73, 77]
#
#
#
#     [MERGE] 82 mini-chunks + 20 splits → 21 semantic groups
#       [TOKEN] id=019e40d0… | raw[0:60]='Tháng 7, mùa thu. Nhà Minh sai Hàn Quan sang trấn thủ.\nVua n'
#               seg[0:60]='Tháng 7 , mùa thu . Nhà_Minh sai Hàn_Quan sang trấn_thủ . Vu'
#               ids[:8]=[0, 1641, 317, 4, 303, 369, 5, 14413] | total_tokens=116
#       [TOKEN] id=019e40d0… | raw[0:60]='Giao Chỉ ở xa ngoài bãi biển, đất ấy trước kia thuộc về Tru'
#               seg[0:60]='Giao_Chỉ ở xa ngoài bãi biển , đất ấy trước_kia thuộc về Tru'
#               ids[:8]=[0, 16520, 843, 25, 604, 227, 1162, 262] | total_tokens=142
#       [TOKEN] id=019e40d0… | raw[0:60]='Nay các ngươi đều là bầy tôi trung lương, cần phải thể theo'
#               seg[0:60]='Nay các ngươi đều là bầy tôi trung_lương , cần phải thể theo'
#               ids[:8]=[0, 6993, 9, 20419, 131, 8, 9010, 70] | total_tokens=160
#       [TOKEN] id=019e40d1… | raw[0:60]='đều theo tính trời, không trái với lễ, chớ làm việc trộm cư'
#               seg[0:60]='đều theo tính trời , không trái với lễ , chớ làm_việc trộm_c'
#               ids[:8]=[0, 131, 63, 294, 1027, 4, 17, 732] | total_tokens=104
#       [TOKEN] id=019e40d1… | raw[0:60]='sự nghiệp các ngươi sánh với người quan lại hiền tài đời cổ'
#               seg[0:60]='sự_nghiệp các ngươi_sánh với người quan_lại hiền_tài đời cổ'
#               ids[:8]=[0, 1115, 9, 57034, 2193, 8370, 15, 18] | total_tokens=151
#       [TOKEN] id=019e40d1… | raw[0:60]='Vân Đồn cùng các bãi biển để lấy lương ăn, và đánh bọn lính'
#               seg[0:60]='Vân_Đồn cùng các bãi biển để lấy lương ăn , và đánh bọn lính'
#               ids[:8]=[0, 9521, 81, 9, 1162, 262, 24, 273] | total_tokens=108
#       [TOKEN] id=019e40d1… | raw[0:60]='"Trong bụng toan tính việc đánh chiếm nước người ta, ngoài'
#               seg[0:60]='" Trong bụng toan_tính việc đánh chiếm nước người ta , ngoài'
#               ids[:8]=[0, 22, 92, 1569, 13410, 49, 480, 724] | total_tokens=112
#       [TOKEN] id=019e40d1… | raw[0:60]='Trước đây, quân của Trương Phụ kéo đến Nghệ An, Thái bảo nhà'
#               seg[0:60]='Trước_đây , quân của Trương_Phụ_kéo đến Nghệ_An , Thái bảo n'
#               ids[:8]=[0, 3099, 4, 829, 7, 2743, 19566, 1300] | total_tokens=167
#       [TOKEN] id=019e40d1… | raw[0:60]='Phụ nói: "Tôi có sống được là ở Hóa Châu, tôi có chết cũng'
#               seg[0:60]='Phụ nói : " Tôi có sống được là ở Hóa_Châu , tôi có chết cũn'
#               ids[:8]=[0, 16002, 96, 27, 22, 218, 10, 235] | total_tokens=107
#       [TOKEN] id=019e40d1… | raw[0:60]='Tháng 9, mùa thu. Đặng Dung, quan Bình Chương nhà Trần, đánh'
#               seg[0:60]='Tháng 9 , mùa thu . Đặng_Dung , quan_Bình_Chương nhà Trần ,'
#               ids[:8]=[0, 1641, 426, 4, 303, 369, 5, 3209] | total_tokens=126
#       [TOKEN] id=019e40d1… | raw[0:60]='Quân nhà Minh một lần nữa bị tan vỡ, thuyền bè, quân khí phầ'
#               seg[0:60]='Quân nhà_Minh một lần nữa bị tan_vỡ , thuyền_bè , quân_khí p'
#               ids[:8]=[0, 2842, 9096, 1612, 16, 101, 348, 45] | total_tokens=125
#       [TOKEN] id=019e40d1… | raw[0:60]='Theo Minh sử và Minh sử kỷ sự của Cốc Ứng Thái chép về việc'
#               seg[0:60]='Theo Minh_sử và Minh_sử kỷ_sự của Cốc_Ứng Thái_chép về việc'
#               ids[:8]=[0, 79, 2775, 5717, 6, 2775, 5717, 59390] | total_tokens=166
#       [TOKEN] id=019e40d1… | raw[0:60]='Đế Quý Khoáng chạy sang Lão Qua, Nguyễn Súy chạy sang Minh'
#               seg[0:60]='Đế Quý_Khoáng chạy sang Lão_Qua , Nguyễn_Súy chạy sang Minh_'
#               ids[:8]=[0, 9326, 7901, 39072, 397, 295, 26287, 1326] | total_tokens=130
#       [TOKEN] id=019e40d1… | raw[0:60]='Đây trở lên, nhà Trần từ Bính Tuất (1226), Trần Thái Tông, n'
#               seg[0:60]='Đây trở lên , nhà Trần_từ Bính_Tuất ( 1226 ) , Trần_Thái_Tôn'
#               ids[:8]=[0, 282, 682, 72, 4, 69, 2062, 43399] | total_tokens=208
#       [TOKEN] id=019e40d1… | raw[0:60]='Rồi lại cho rằng đất ấy giáp giới Chiêm Thành, đất đai vừa'
#               seg[0:60]='Rồi lại cho rằng đất ấy giáp_giới Chiêm_Thành , đất_đai vừa'
#               ids[:8]=[0, 3036, 44, 13, 87, 179, 241, 29924] | total_tokens=142
#       [TOKEN] id=019e40d1… | raw[0:60]='Khi đi đến giữa đường, Đế Quý Khoáng nhảy xuống sông chết;'
#               seg[0:60]='Khi đi đến giữa đường , Đế_Quý_Khoáng nhảy xuống sông chết ;'
#               ids[:8]=[0, 251, 57, 30, 147, 109, 4, 28473] | total_tokens=152
#       [TOKEN] id=019e40d1… | raw[0:60]='Tháng 8, mùa thu. Trương Phụ nhà Minh về nước.\nPhụ chia quân'
#               seg[0:60]='Tháng 8 , mùa thu . Trương_Phụ nhà_Minh về nước . Phụ chia q'
#               ids[:8]=[0, 1641, 358, 4, 303, 369, 5, 2743] | total_tokens=119
#       [TOKEN] id=019e40d1… | raw[0:60]='Tháng 9. Nhà Minh lập Văn Miếu và đàn thờ bạch thần.\nHoàng P'
#               seg[0:60]='Tháng 9 . Nhà_Minh lập_Văn_Miếu và đàn thờ bạch_thần . Hoàng'
#               ids[:8]=[0, 1641, 426, 5, 14413, 14317, 22121, 10034] | total_tokens=128
#       [TOKEN] id=019e40d1… | raw[0:60]='trao cho quan chức để giữ việc dạy học ở các trường. Lại cấ'
#               seg[0:60]='trao cho quan_chức để giữ việc dạy_học ở các trường . Lại cấ'
#               ids[:8]=[0, 906, 13, 1480, 24, 300, 49, 4519] | total_tokens=150
#       [TOKEN] id=019e40d1… | raw[0:60]='Ất Mùi (1415). (Minh, năm Vĩnh Lạc thứ 13).\nTháng 4, mùa hạ.'
#               seg[0:60]='Ất_Mùi ( 1415 ) . ( Minh , năm Vĩnh_Lạc thứ 13 ) . Tháng 4 ,'
#               ids[:8]=[0, 19327, 20, 3012, 613, 19, 5, 20] | total_tokens=146
#       [TOKEN] id=019e40d1… | raw[0:60]='Nhưng chỗ đất ấy Chiêm Thành vẫn có người trưởng quản, nhà'
#               seg[0:60]='Nhưng chỗ đất ấy Chiêm_Thành vẫn có người trưởng_quản , nhà_'
#               ids[:8]=[0, 293, 683, 179, 241, 34831, 74, 10] | total_tokens=108
# Đang đẩy 21 points lên Qdrant Cloud...
#  Đã lưu dữ liệu thành công lên Qdrant Cloud!
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW   54/54 | pages=[348, 349, 350, 351] | chars=5,716
#       [STRUCT] 2 structural boundaries | book='Khâm Định Việt Sử Thông Giám Cương '
#     [MINI-CHUNK] window chars=5,716 → 50 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
#  {"split_after_indices":[3,7,11,15,19,25,28,32,35,38,43,48]}
#
#
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=50 → splits=[3, 7, 11, 15, 19, 23, 25, 28, 32, 35, 38, 42, 43, 47, 48]
# llm trả về
#  [3, 7, 11, 15, 19, 23, 25, 28, 32, 35, 38, 42, 43, 47, 48]
#
#
#
#     [MERGE] 50 mini-chunks + 15 splits → 16 semantic groups
#       [TOKEN] id=019e40d1… | raw[0:60]='Tháng 8, mùa thu. Nhà Minh mở trường thu vàng bạc.Phàm chỗ đ'
#               seg[0:60]='Tháng 8 , mùa thu . Nhà_Minh mở trường thu vàng_bạc . Phàm c'
#               ids[:8]=[0, 1641, 358, 4, 303, 369, 5, 14413] | total_tokens=110
#       [TOKEN] id=019e40d1… | raw[0:60]='Lúc ấy thuế khóa cao, đóng góp nặng, sức lực và của cải của'
#               seg[0:60]='Lúc ấy thuế khóa cao , đóng_góp nặng , sức_lực và của_cải củ'
#               ids[:8]=[0, 1254, 241, 578, 37289, 1517, 84, 4] | total_tokens=152
#       [TOKEN] id=019e40d1… | raw[0:60]='Các phủ, huyện và châu đều đặt quan giữ công việc ti Thuế k'
#               seg[0:60]='Các phủ , huyện và châu đều đặt quan_giữ công_việc ti Thuế_k'
#               ids[:8]=[0, 146, 2149, 4, 149, 6, 2935, 131] | total_tokens=160
#       [TOKEN] id=019e40d1… | raw[0:60]='Lời chua - Vạn Ninh: Xem Trần Thuận Tông, năm Quang Thái thứ'
#               seg[0:60]='Lời chua - Vạn_Ninh : Xem Trần_Thuận_Tông , năm Quang_Thái t'
#               ids[:8]=[0, 4190, 5344, 31, 23729, 27, 2457, 1359] | total_tokens=160
#       [TOKEN] id=019e40d1… | raw[0:60]='Tháng giêng. Mùa xuân. Nhà Minh bổ Nguyễn Huân làm bố chính'
#               seg[0:60]='Tháng_giêng . Mùa xuân . Nhà_Minh_bổ Nguyễn_Huân làm bố chín'
#               ids[:8]=[0, 1827, 57558, 5, 2822, 2184, 5, 14413] | total_tokens=142
#       [TOKEN] id=019e40d1… | raw[0:60]='Nhân đấy vua Minh dụ bảo chúng rằng: "Trước kia, lúc bình đị'
#               seg[0:60]='Nhân đấy vua Minh_dụ bảo chúng rằng : " Trước_kia , lúc bình'
#               ids[:8]=[0, 2936, 1582, 1692, 2775, 11536, 1218, 572] | total_tokens=98
#       [TOKEN] id=019e40d1… | raw[0:60]='đối với dân thì yên ủy yêu đương, để cho dân một phương đều'
#               seg[0:60]='đối_với dân thì yên_ủy yêu_đương , để cho dân một phương đều'
#               ids[:8]=[0, 190, 452, 54, 22801, 21356, 1231, 8405] | total_tokens=70
#       [TOKEN] id=019e40d1… | raw[0:60]='Sau đó bọn tên Huân lại sai người sang Yên Kinh xây dựng cu'
#               seg[0:60]='Sau đó bọn tên Huân lại sai người sang Yên_Kinh xây_dựng cun'
#               ids[:8]=[0, 162, 37, 3129, 221, 9043, 44, 1069] | total_tokens=138
#       [TOKEN] id=019e40d1… | raw[0:60]='Các hộ ở dân gian cứ ba người lấy một người, mỗi hộ tính the'
#               seg[0:60]='Các hộ ở dân_gian cứ ba người lấy một người , mỗi hộ tính th'
#               ids[:8]=[0, 146, 506, 25, 3467, 658, 346, 18] | total_tokens=155
#       [TOKEN] id=019e40d1… | raw[0:60]='Tháng 2, mùa xuân. Nhà Minh triệu trấn thủ Trương Phụ về nướ'
#               seg[0:60]='Tháng 2 , mùa xuân . Nhà_Minh triệu trấn_thủ Trương_Phụ về n'
#               ids[:8]=[0, 1641, 76, 4, 303, 2184, 5, 14413] | total_tokens=106
#       [TOKEN] id=019e40d1… | raw[0:60]='Từ đấy nhà Minh mới sai giám sát ngự sử chia ra từng ti đi'
#               seg[0:60]='Từ đấy nhà_Minh mới sai giám_sát ngự_sử chia ra từng ti đi t'
#               ids[:8]=[0, 404, 1582, 9096, 1612, 60, 1069, 929] | total_tokens=101
#       [TOKEN] id=019e40d1… | raw[0:60]='Nhà Minh định thể lệ hằng năm cống nộp sinh viên.\nTrước đây,'
#               seg[0:60]='Nhà Minh_định_thể_lệ hằng năm cống nộp sinh_viên . Trước_đây'
#               ids[:8]=[0, 1706, 2775, 18150, 17193, 18658, 53473, 2416] | total_tokens=113
#       [TOKEN] id=019e40d1… | raw[0:60]='Sau định lại: Trường ở phủ mỗi năm cống 1 người; trường ở c'
#               seg[0:60]='Sau định lại : Trường ở phủ mỗi năm cống 1 người ; trường ở'
#               ids[:8]=[0, 162, 2608, 44, 27, 622, 25, 2149] | total_tokens=55
#       [TOKEN] id=019e40d1… | raw[0:60]='Nhà Minh xét quan lại bằng cách sát hạch công việc đã làm.\nN'
#               seg[0:60]='Nhà_Minh_xét quan_lại bằng cách sát_hạch công_việc đã làm .'
#               ids[:8]=[0, 14413, 20079, 1522, 23123, 121, 139, 11820] | total_tokens=123
#       [TOKEN] id=019e40d1… | raw[0:60]='chiểu theo các hạng hộ, khẩu, điền, lương trong 3 năm, làm'
#               seg[0:60]='chiểu theo các hạng hộ , khẩu , điền , lương trong 3 năm , l'
#               ids[:8]=[0, 36919, 63, 9, 1094, 506, 4, 3183] | total_tokens=62
#       [TOKEN] id=019e40d1… | raw[0:60]='Nhà Minh chiếm cứ nước ta từ Giáp Ngọ (1414), Thành Tổ, năm'
#               seg[0:60]='Nhà_Minh chiếm cứ nước ta từ Giáp_Ngọ ( 1414 ) , Thành_Tổ ,'
#               ids[:8]=[0, 14413, 14317, 724, 658, 58, 237, 39] | total_tokens=44
# Đang đẩy 16 points lên Qdrant Cloud...
#  Đã lưu dữ liệu thành công lên Qdrant Cloud!
#
# ════════════════════════════════════════════════════════════════════════
#   PIPELINE COMPLETE — 'Khâm Định Việt Sử Thông Giám Cương Mục'
#   Total Qdrant points produced : 1,110
# ════════════════════════════════════════════════════════════════════════
#
# [SAVE] Writing 1,110 points → 'full_KhamDinh_data_qdrant_points.json'…
# [SAVE] Done. 1723.1 KB written.

# %% [markdown]
# # Run Việt Sử Toàn Thư

# %%
# @title

import os
from google.colab import userdata


# JSON_PATH = "full_DVSK_data.json"           # Đại Việt Sử Ký Toàn Thư
# JSON_PATH = "full_KhamDinh_data.json"        # Khâm Định Việt Sử Thông Giám Cương Mục
JSON_PATH = "full_VietSu_data.json"                 # Việt Sử Toàn Thư
# JSON_PATH = "full_VTT_data.json"                  # Vương Triều Trần
# JSON_PATH = "full_test.json"


OUTPUT_PATH = JSON_PATH.replace(".json", "_qdrant_points.json")


def _load_key(colab_secret: str, env_var: str) -> str:
    try:
        from google.colab import userdata as _ud
        val = _ud.get(colab_secret)
        if val:
            print(f"[KEY] '{colab_secret}' loaded from Colab Secrets.")
            return val
    except Exception:
        pass
    val = os.environ.get(env_var, "")
    if val:
        print(f"[KEY] '{env_var}' loaded from environment variable.")
    return val

GROQ_API_KEY   = _load_key("grok_key",  "grok_key")
GEMINI_API_KEY = _load_key("GEMINI_API_KEY", "GEMINI_API_KEY")

if not GROQ_API_KEY and not GEMINI_API_KEY:
    print("[KEY] ⚠  No API keys found. "
          "Add GROQ_API_KEY and/or GOOGLE_API_KEY to Colab Secrets.")


# USE_BATCH_MODE: bool = True
USE_BATCH_MODE: bool = False

BATCH_ORCHESTRATOR: Optional[GeminiBatchOrchestrator] = None
LLM_BACKENDS:       list[LLMBackend]                  = []

if USE_BATCH_MODE:
    if not GEMINI_API_KEY:
        raise RuntimeError(
            "USE_BATCH_MODE=True but GOOGLE_API_KEY is not set. "
            "Add it to Colab Secrets or switch USE_BATCH_MODE=False."
        )
    BATCH_ORCHESTRATOR = GeminiBatchOrchestrator(
        api_key=GEMINI_API_KEY,
        model_id=GEMINI_MODEL_ID,       # "gemini-2.5-flash"
    )
    print(f"[INIT] Mode A — GeminiBatchOrchestrator ready "
          f"(model={GEMINI_MODEL_ID}, "
          f"sub_batch={GeminiBatchOrchestrator.SUB_BATCH_SIZE} chunks/line)")

else:
    # Build sync fallback chain
    # if GROQ_API_KEY:
    #     LLM_BACKENDS.append(GroqBackend(GROQ_API_KEY, GROQ_MODEL_LLAMA_70B))
    #     LLM_BACKENDS.append(GroqBackend(GROQ_API_KEY, GROQ_MODEL_LLAMA_8B))
    #     LLM_BACKENDS.append(GroqBackend(GROQ_API_KEY, GROQ_MODEL_QWEN))

    if GEMINI_API_KEY:
        try:
            LLM_BACKENDS.append(GeminiBackend(GEMINI_API_KEY, GEMINI_MODEL_ID))
            print("[INIT] GeminiBackend added as last-resort sync fallback.")
        except Exception as _ge:
            print(f"[INIT] GeminiBackend skipped ({type(_ge).__name__}: {_ge}).")

    if not LLM_BACKENDS:
        raise RuntimeError(
            "USE_BATCH_MODE=False but LLM_BACKENDS is empty. "
            "Provide GROQ_API_KEY and/or GOOGLE_API_KEY."
        )

    print(f"[INIT] Mode B — sync fallback chain ({len(LLM_BACKENDS)} backend(s)):")
    for _i, _b in enumerate(LLM_BACKENDS):
        print(f"   [{_i + 1}] {_b.label}")

print()

print(f"[LOAD] Reading '{JSON_PATH}'…")
with open(JSON_PATH, "r", encoding="utf-8") as _fh:
    input_data: dict = json.load(_fh)


assert "book_name"          in input_data, "Missing key: book_name"
assert "full_text"          in input_data, "Missing key: full_text"
assert "page_footnotes_map" in input_data, "Missing key: page_footnotes_map"
assert isinstance(input_data["full_text"],          str),  "full_text must be str"
assert isinstance(input_data["page_footnotes_map"], dict), "page_footnotes_map must be dict"
print("[LOAD] Input validation passed ✓")

qdrant_points: list[dict] = run_pipeline(
    input_data,
    backends           = LLM_BACKENDS,
    batch_orchestrator = BATCH_ORCHESTRATOR,
)

print(f"\n[SAVE] Writing {len(qdrant_points):,} points → '{OUTPUT_PATH}'…")
with open(OUTPUT_PATH, "w", encoding="utf-8") as _fh:
    json.dump(qdrant_points, _fh, ensure_ascii=False, indent=2)
_kb = os.path.getsize(OUTPUT_PATH) / 1024
print(f"[SAVE] Done. {_kb:.1f} KB written.")
# Out:
# [KEY] 'grok_key' loaded from Colab Secrets.
# [KEY] 'GEMINI_API_KEY' loaded from Colab Secrets.
# [INIT] GeminiBackend added as last-resort sync fallback.
# [INIT] Mode B — sync fallback chain (1 backend(s)):
#    [1] gemini-sync/gemini-3.1-flash-lite
#
# [LOAD] Reading 'full_VietSu_data.json'…
# [LOAD] Input validation passed ✓
# ════════════════════════════════════════════════════════════════════════
#   PIPELINE START — 'Việt Sử Toàn Thư'
#   full_text chars     :      220,437
#   footnote page count :           89
#   LLM mode            : SYNC (Mode B)
#   LLM backend(s)      : gemini-sync/gemini-3.1-flash-lite
# ════════════════════════════════════════════════════════════════════════
# ════════════════════════════════════════════════════════════════════════
#   PIPELINE START — 'Việt Sử Toàn Thư'
#   full_text chars     :      220,437
#   footnote page count :           89
# ════════════════════════════════════════════════════════════════════════
# [INIT] Loading tokenizer: bkai-foundation-models/vietnamese-bi-encoder
# [INIT] Loading model → device=cpu
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# [INIT] Model ready | hidden_size=768
#
# [WINDOWS] book='Việt Sử Toàn Thư' | window_size=3 pages
#
# ── STEPS 3+4 · Structural boundaries + Mini-chunking (all windows)
#   [PREP] window    1/28 | pages=[161, 162, 163]
#       [STRUCT] 19 structural boundaries | book='Việt Sử Toàn Thư'
#     [MINI-CHUNK] window chars=6,972 → 65 mini-chunks
#   [PREP] window    2/28 | pages=[163, 164, 165, 166]
#       [STRUCT] 34 structural boundaries | book='Việt Sử Toàn Thư'
#     [MINI-CHUNK] window chars=7,436 → 72 mini-chunks
#   [PREP] window    3/28 | pages=[166, 167, 168, 169]
#       [STRUCT] 32 structural boundaries | book='Việt Sử Toàn Thư'
#     [MINI-CHUNK] window chars=7,818 → 74 mini-chunks
#   [PREP] window    4/28 | pages=[169, 170, 171, 172]
#       [STRUCT] 20 structural boundaries | book='Việt Sử Toàn Thư'
#     [MINI-CHUNK] window chars=8,912 → 77 mini-chunks
#   [PREP] window    5/28 | pages=[172, 173, 174, 175]
#       [STRUCT] 28 structural boundaries | book='Việt Sử Toàn Thư'
#     [MINI-CHUNK] window chars=7,592 → 73 mini-chunks
#   [PREP] window    6/28 | pages=[175, 176, 177, 178]
#       [STRUCT] 22 structural boundaries | book='Việt Sử Toàn Thư'
#     [MINI-CHUNK] window chars=7,164 → 69 mini-chunks
#   [PREP] window    7/28 | pages=[178, 179, 180, 181]…
#       [STRUCT] 33 structural boundaries | book='Việt Sử Toàn Thư'
#     [MINI-CHUNK] window chars=9,048 → 84 mini-chunks
#   [PREP] window    8/28 | pages=[182, 183, 184, 185]
#       [STRUCT] 37 structural boundaries | book='Việt Sử Toàn Thư'
#     [MINI-CHUNK] window chars=8,437 → 85 mini-chunks
#   [PREP] window    9/28 | pages=[185, 186, 187, 188]…
#       [STRUCT] 76 structural boundaries | book='Việt Sử Toàn Thư'
#     [MINI-CHUNK] window chars=6,617 → 91 mini-chunks
#   [PREP] window   10/28 | pages=[189, 190, 191, 192]
#       [STRUCT] 24 structural boundaries | book='Việt Sử Toàn Thư'
#     [MINI-CHUNK] window chars=8,246 → 75 mini-chunks
#   [PREP] window   11/28 | pages=[192, 193, 194, 195]
#       [STRUCT] 23 structural boundaries | book='Việt Sử Toàn Thư'
#     [MINI-CHUNK] window chars=7,231 → 70 mini-chunks
#   [PREP] window   12/28 | pages=[195, 196, 197, 198]
#       [STRUCT] 35 structural boundaries | book='Việt Sử Toàn Thư'
#     [MINI-CHUNK] window chars=7,816 → 77 mini-chunks
#   [PREP] window   13/28 | pages=[198, 199, 200, 201]
#       [STRUCT] 27 structural boundaries | book='Việt Sử Toàn Thư'
#     [MINI-CHUNK] window chars=8,141 → 75 mini-chunks
#   [PREP] window   14/28 | pages=[201, 202, 203, 204]
#       [STRUCT] 24 structural boundaries | book='Việt Sử Toàn Thư'
#     [MINI-CHUNK] window chars=8,328 → 80 mini-chunks
#   [PREP] window   15/28 | pages=[204, 205, 206, 207]
#       [STRUCT] 34 structural boundaries | book='Việt Sử Toàn Thư'
#     [MINI-CHUNK] window chars=6,516 → 72 mini-chunks
#   [PREP] window   16/28 | pages=[207, 208, 209, 210]
#       [STRUCT] 12 structural boundaries | book='Việt Sử Toàn Thư'
#     [MINI-CHUNK] window chars=6,236 → 56 mini-chunks
#   [PREP] window   17/28 | pages=[210, 211, 212, 213]
#       [STRUCT] 14 structural boundaries | book='Việt Sử Toàn Thư'
#     [MINI-CHUNK] window chars=6,183 → 57 mini-chunks
#   [PREP] window   18/28 | pages=[213, 214, 215, 216]
#       [STRUCT] 13 structural boundaries | book='Việt Sử Toàn Thư'
#     [MINI-CHUNK] window chars=6,294 → 61 mini-chunks
#   [PREP] window   19/28 | pages=[216, 217, 218, 219]
#       [STRUCT] 24 structural boundaries | book='Việt Sử Toàn Thư'
#     [MINI-CHUNK] window chars=8,984 → 87 mini-chunks
#   [PREP] window   20/28 | pages=[219, 220, 221, 222]…
#       [STRUCT] 30 structural boundaries | book='Việt Sử Toàn Thư'
#     [MINI-CHUNK] window chars=8,498 → 81 mini-chunks
#   [PREP] window   21/28 | pages=[223, 224, 225, 226]
#       [STRUCT] 30 structural boundaries | book='Việt Sử Toàn Thư'
#     [MINI-CHUNK] window chars=6,939 → 69 mini-chunks
#   [PREP] window   22/28 | pages=[226, 227, 228, 229]
#       [STRUCT] 23 structural boundaries | book='Việt Sử Toàn Thư'
#     [MINI-CHUNK] window chars=8,108 → 76 mini-chunks
#   [PREP] window   23/28 | pages=[229, 230, 231, 232]
#       [STRUCT] 28 structural boundaries | book='Việt Sử Toàn Thư'
#     [MINI-CHUNK] window chars=7,950 → 76 mini-chunks
#   [PREP] window   24/28 | pages=[232, 233, 234, 235]…
#       [STRUCT] 30 structural boundaries | book='Việt Sử Toàn Thư'
#     [MINI-CHUNK] window chars=9,315 → 84 mini-chunks
#   [PREP] window   25/28 | pages=[236, 237, 238, 239]
#       [STRUCT] 26 structural boundaries | book='Việt Sử Toàn Thư'
#     [MINI-CHUNK] window chars=8,133 → 80 mini-chunks
#   [PREP] window   26/28 | pages=[239, 240, 241, 242]
#       [STRUCT] 22 structural boundaries | book='Việt Sử Toàn Thư'
#     [MINI-CHUNK] window chars=8,424 → 80 mini-chunks
#   [PREP] window   27/28 | pages=[242, 243, 244, 245]…
#       [STRUCT] 24 structural boundaries | book='Việt Sử Toàn Thư'
#     [MINI-CHUNK] window chars=8,586 → 77 mini-chunks
#   [PREP] window   28/28 | pages=[246, 247, 248, 249]
#       [STRUCT] 20 structural boundaries | book='Việt Sử Toàn Thư'
#     [MINI-CHUNK] window chars=9,089 → 82 mini-chunks
# [PREP] Total mini-chunks across all windows: 2,105
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW    1/28 | pages=[161, 162, 163] | chars=6,972
#       [STRUCT] 19 structural boundaries | book='Việt Sử Toàn Thư'
#     [MINI-CHUNK] window chars=6,972 → 65 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
#  {"split_after_indices":[2,6,10,14,18,21,25,29,31,35,39,43,46,49,53,57,60,63]}
#
#
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=65 → splits=[2, 6, 10, 14, 18, 21, 25, 29, 31, 35, 39, 43, 46, 49, 53, 57, 60, 63]
# llm trả về
#  [2, 6, 10, 14, 18, 21, 25, 29, 31, 35, 39, 43, 46, 49, 53, 57, 60, 63]
#
#
#
#     [MERGE] 65 mini-chunks + 18 splits → 19 semantic groups
#       [TOKEN] id=019e40d1… | raw[0:60]='Phần 3 - Chương 7 Nhà Trần (1225-1413) Nước Việt Nam Dưới Đờ'
#               seg[0:60]='Phần 3 - Chương 7 Nhà_Trần ( 1225 - 1413 ) Nước Việt_Nam Dướ'
#               ids[:8]=[0, 2918, 107, 31, 6041, 317, 7029, 3212] | total_tokens=191
#       [TOKEN] id=019e40d1… | raw[0:60]='Lý Huệ Tông và Chiêu Hoàng tuy bị gạt ra ngoài lề sân khấu c'
#               seg[0:60]='Lý_Huệ_Tông và Chiêu_Hoàng tuy bị gạt ra ngoài_lề sân_khấu c'
#               ids[:8]=[0, 2878, 13471, 6483, 6, 12982, 1955, 2442] | total_tokens=116
#       [TOKEN] id=019e40d1… | raw[0:60]='Thủ Độ lại có tính rất cương quyết để làm những việc tàn ác'
#               seg[0:60]='Thủ_Độ lại có tính rất cương_quyết để làm những việc tàn_ác'
#               ids[:8]=[0, 61156, 44, 10, 294, 59, 11250, 24] | total_tokens=146
#       [TOKEN] id=019e40d1… | raw[0:60]='Năm Nhâm Thìn (1232) trong dịp các tông thất nhà Lý làm lễ t'
#               seg[0:60]='Năm Nhâm_Thìn ( 1232 ) trong dịp các tông_thất nhà_Lý làm lễ'
#               ids[:8]=[0, 434, 33400, 20, 2789, 2038, 19, 12] | total_tokens=138
#       [TOKEN] id=019e40d1… | raw[0:60]='2- Đảo Lộn Nhân Luân Chiêu Thánh lấy Trần Thái Tông 12 năm v'
#               seg[0:60]='2 - Đảo_Lộn Nhân_Luân Chiêu_Thánh lấy Trần_Thái_Tông 12 năm'
#               ids[:8]=[0, 76, 31, 39022, 1042, 22245, 6974, 6547] | total_tokens=105
#       [TOKEN] id=019e40d1… | raw[0:60]='Rồi Thủ Độ thi hành ý tưởng này trước nhất, bằng sự kết duy'
#               seg[0:60]='Rồi Thủ_Độ thi_hành ý_tưởng này trước nhất , bằng sự kết_duy'
#               ids[:8]=[0, 3036, 61156, 2116, 1847, 23, 71, 67] | total_tokens=94
#       [TOKEN] id=019e40d1… | raw[0:60]='Trần Liễu uất ức không chịu được đem quân làm loạn nhưng kh'
#               seg[0:60]='Trần_Liễu_uất_ức không chịu được đem quân làm_loạn nhưng khô'
#               ids[:8]=[0, 1359, 21088, 24029, 17, 551, 11, 873] | total_tokens=120
#       [TOKEN] id=019e40d1… | raw[0:60]='Về phần vua Thái Tông đối với sự áp chế của Trần Thủ Độ cũng'
#               seg[0:60]='Về phần vua Thái_Tông đối_với sự áp_chế của Trần_Thủ_Độ cũng'
#               ids[:8]=[0, 674, 230, 1692, 27024, 190, 61, 47639] | total_tokens=95
#       [TOKEN] id=019e40d1… | raw[0:60]='Thủ Độ liền bảo các quan: Hoàng thượng ở đâu thì triều đình'
#               seg[0:60]='Thủ_Độ liền bảo các quan : Hoàng_thượng ở đâu thì triều_đình'
#               ids[:8]=[0, 61156, 1228, 1218, 9, 2665, 27, 40855] | total_tokens=68
#       [TOKEN] id=019e40d1… | raw[0:60]='3- Việc Đánh Dẹp Trong Nước Việc họ Trần cướp ngai vàng của'
#               seg[0:60]='3 - Việc Đánh_Dẹp Trong Nước Việc họ Trần_cướp ngai_vàng của'
#               ids[:8]=[0, 107, 31, 519, 19185, 992, 21237, 92] | total_tokens=117
#       [TOKEN] id=019e40d1… | raw[0:60]='Nhưng phải công bằng mà nhận rằng nhân tâm bắt đầu rối ren'
#               seg[0:60]='Nhưng phải công_bằng mà nhận rằng nhân_tâm bắt_đầu rối_ren k'
#               ids[:8]=[0, 293, 41, 3130, 64, 154, 87, 46691] | total_tokens=140
#       [TOKEN] id=019e40d1… | raw[0:60]='Thủ Độ đem quân dẹp bọn Mường xong liền mở cuộc giảnh hòa ch'
#               seg[0:60]='Thủ_Độ đem quân_dẹp bọn Mường_xong liền mở cuộc giảnh hòa ch'
#               ids[:8]=[0, 61156, 873, 10035, 7166, 3129, 10361, 954] | total_tokens=109
#       [TOKEN] id=019e40d1… | raw[0:60]='tài đảm lược đâu có thể cùng đứng chung mãi một cõi với Đoàn'
#               seg[0:60]='tài đảm_lược đâu có_thể cùng đứng chung mãi một cõi với Đoàn'
#               ids[:8]=[0, 1941, 41402, 8536, 602, 62, 81, 414] | total_tokens=98
#       [TOKEN] id=019e40d1… | raw[0:60]='Năm Mậu Tí (1228) giữa Đoàn Thượng và Nguyễn Nộn có sự xung'
#               seg[0:60]='Năm Mậu_Tí ( 1228 ) giữa Đoàn_Thượng và Nguyễn_Nộn có sự xun'
#               ids[:8]=[0, 434, 16656, 35902, 20, 2789, 1745, 19] | total_tokens=98
#       [TOKEN] id=019e40d1… | raw[0:60]='Trừ được mọi mối loạn, Thủ Độ cũng theo tục nhà Lý hằng năm'
#               seg[0:60]='Trừ được mọi mối_loạn , Thủ_Độ cũng theo tục nhà Lý_hằng năm'
#               ids[:8]=[0, 15320, 11, 207, 48858, 6519, 4, 61156] | total_tokens=115
#       [TOKEN] id=019e40d1… | raw[0:60]='Ở mỗi làng có quan của nhà vua bổ về cai trị, nên có công đ'
#               seg[0:60]='Ở mỗi làng có quan của nhà_vua bổ về cai_trị , nên có công_đ'
#               ids[:8]=[0, 635, 205, 632, 10, 2665, 7, 9084] | total_tokens=145
#       [TOKEN] id=019e40d1… | raw[0:60]='Để đền bù vào công khó nhọc, đình trưởng được quyền sai phá'
#               seg[0:60]='Để đền_bù vào công khó_nhọc , đình_trưởng được quyền sai_phá'
#               ids[:8]=[0, 483, 3707, 33, 675, 25908, 4, 52176] | total_tokens=107
#       [TOKEN] id=019e40d1… | raw[0:60]='(Chức này có thể ví như tri phủ, tri huyện bấy giờ).\nCác qu'
#               seg[0:60]='( Chức này có_thể ví_như tri_phủ , tri huyện bấy_giờ ) . Các'
#               ids[:8]=[0, 20, 19709, 23, 62, 7777, 25129, 2149] | total_tokens=75
#       [TOKEN] id=019e40d1… | raw[0:60]='Để kiểm tra dân số toàn quốc, Trần Thủ Độ đặt ra sổ trướng t'
#               seg[0:60]='Để kiểm_tra dân_số toàn_quốc , Trần_Thủ_Độ đặt ra sổ trướng_'
#               ids[:8]=[0, 483, 342, 1352, 1918, 4, 39303, 320] | total_tokens=20
# Đang đẩy 19 points lên Qdrant Cloud...
#  Đã lưu dữ liệu thành công lên Qdrant Cloud!
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW    2/28 | pages=[163, 164, 165, 166] | chars=7,436
#       [STRUCT] 34 structural boundaries | book='Việt Sử Toàn Thư'
#     [MINI-CHUNK] window chars=7,436 → 72 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
#  {"split_after_indices":[3,7,11,15,19,23,27,30,33,37,41,45,49,53,57,60,63,67,71]}
#
#
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=72 → splits=[3, 7, 11, 15, 19, 23, 27, 30, 33, 37, 41, 45, 49, 53, 57, 60, 63, 67]
# llm trả về
#  [3, 7, 11, 15, 19, 23, 27, 30, 33, 37, 41, 45, 49, 53, 57, 60, 63, 67]
#
#
#
#     [MERGE] 72 mini-chunks + 18 splits → 19 semantic groups
#       [TOKEN] id=019e40d1… | raw[0:60]='Phàm mỗi làng có bao nhiêu người đi làm quan văn, võ, thư lạ'
#               seg[0:60]='Phàm mỗi làng có bao_nhiêu người đi làm quan_văn , võ , thư'
#               ids[:8]=[0, 34197, 205, 632, 10, 1823, 18, 57] | total_tokens=125
#       [TOKEN] id=019e40d1… | raw[0:60]='Sổ trướng tịch lại còn một công dụng bậc nhất trong những dị'
#               seg[0:60]='Sổ trướng_tịch lại còn một công_dụng bậc nhất trong những dị'
#               ids[:8]=[0, 28964, 55427, 7858, 13383, 44, 50, 16] | total_tokens=131
#       [TOKEN] id=019e40d1… | raw[0:60]='Ở các nơi biên viễn thì có Trại.\nĐơn vị dưới cùng là xã và'
#               seg[0:60]='Ở các nơi biên_viễn thì có Trại . Đơn_vị dưới cùng là xã và'
#               ids[:8]=[0, 635, 9, 189, 24795, 23644, 54, 10] | total_tokens=110
#       [TOKEN] id=019e40d1… | raw[0:60]='Cùng tốt là nô, tì và hoành. Hoành là hạng người bị tội đồ,'
#               seg[0:60]='Cùng tốt là nô , tì và hoành . Hoành là hạng người bị tội_đồ'
#               ids[:8]=[0, 962, 167, 8, 21280, 4, 21744, 6] | total_tokens=100
#       [TOKEN] id=019e40d1… | raw[0:60]='Còn một điều lợi nữa là việc nhường ngôi khi vua cha còn số'
#               seg[0:60]='Còn một điều_lợi nữa là việc nhường_ngôi khi vua cha còn sốn'
#               ids[:8]=[0, 631, 16, 20763, 1596, 348, 8, 49] | total_tokens=111
#       [TOKEN] id=019e40d1… | raw[0:60]='Việc quan chế nước ta qua đời Trần cũng sửa đổi lại. Văn võ'
#               seg[0:60]='Việc quan_chế nước ta qua_đời Trần cũng sửa_đổi lại . Văn_võ'
#               ids[:8]=[0, 519, 19748, 3056, 58, 237, 2782, 3212] | total_tokens=171
#       [TOKEN] id=019e40d1… | raw[0:60]='Kinh lược sứ, Phòng ngự sứ, Thủ ngự sứ, Quan sát sứ, Đô hộ,'
#               seg[0:60]='Kinh_lược sứ , Phòng ngự_sứ , Thủ_ngự sứ , Quan_sát sứ , Đô_'
#               ids[:8]=[0, 8360, 8536, 4986, 4, 1119, 44530, 61519] | total_tokens=126
#       [TOKEN] id=019e40d1… | raw[0:60]='Người có quan tước mà con cháu được thừa ấm thì con cháu mới'
#               seg[0:60]='Người có quan_tước mà con_cháu được thừa_ấm thì con_cháu mới'
#               ids[:8]=[0, 345, 10, 55214, 3113, 64, 4902, 11] | total_tokens=86
#       [TOKEN] id=019e40d1… | raw[0:60]='5. Việc Binh Chế và Lực Lượng Quân Đội Đời Trần Sơ Nhà Trần'
#               seg[0:60]='5 . Việc Binh_Chế và Lực_Lượng Quân_Đội Đời Trần_Sơ_Nhà_Trần'
#               ids[:8]=[0, 173, 5, 519, 23637, 29991, 6, 28159] | total_tokens=76
#       [TOKEN] id=019e40d1… | raw[0:60]='Theo Toàn Thư quyển 5, Cương Mục quyển 6, tháng ba năm Kỷ Hợ'
#               seg[0:60]='Theo Toàn Thư_quyển 5 , Cương_Mục quyển 6 , tháng ba năm Kỷ_'
#               ids[:8]=[0, 79, 2663, 17671, 6248, 173, 4, 28763] | total_tokens=155
#       [TOKEN] id=019e40d1… | raw[0:60]='Tại các lộ Thiên Trường (nay là phủ Xuân Trường thuộc Nam Đị'
#               seg[0:60]='Tại các lộ Thiên_Trường ( nay là phủ_Xuân_Trường thuộc Nam_Đ'
#               ids[:8]=[0, 382, 9, 1776, 28695, 20, 136, 8] | total_tokens=145
#       [TOKEN] id=019e40d1… | raw[0:60]='Tháng hai năm Tân Dậu (1261) có việc tuyển binh ở các lộ. Ng'
#               seg[0:60]='Tháng hai năm Tân_Dậu ( 1261 ) có việc tuyển_binh ở các lộ .'
#               ids[:8]=[0, 1641, 82, 29, 2535, 10968, 20, 2789] | total_tokens=126
#       [TOKEN] id=019e40d1… | raw[0:60]='Lại có quân Tứ Xương là những lính chuyên canh gác bốn cửa t'
#               seg[0:60]='Lại có quân Tứ_Xương là những lính chuyên_canh gác bốn cửa t'
#               ids[:8]=[0, 6289, 10, 829, 14387, 10241, 8, 21] | total_tokens=114
#       [TOKEN] id=019e40d1… | raw[0:60]='(Từ đây trở lên đều có tả hữu có nghĩa là bốn Đô và mỗI Lan'
#               seg[0:60]='( Từ đây trở lên đều có tả_hữu có nghĩa là bốn Đô và mỗI Lan'
#               ids[:8]=[0, 20, 404, 97, 682, 72, 131, 10] | total_tokens=166
#       [TOKEN] id=019e40d1… | raw[0:60]='Đây là số quân động viên ở các lộ Đông, Nam. Quân Thanh Ngh'
#               seg[0:60]='Đây là số quân_động_viên ở các lộ_Đông , Nam . Quân_Thanh_Ng'
#               ids[:8]=[0, 282, 8, 100, 10035, 2224, 25, 9] | total_tokens=119
#       [TOKEN] id=019e40d1… | raw[0:60]='đã huy động các dân Bằng Hà (thuộc tỉnh Hải Dương), Na Sầm'
#               seg[0:60]='đã huy_động các dân Bằng_Hà ( thuộc tỉnh Hải_Dương ) , Na_Sầ'
#               ids[:8]=[0, 14, 1509, 9, 452, 11510, 1696, 20] | total_tokens=106
#       [TOKEN] id=019e40d1… | raw[0:60]='Các tướng quân thì có Phiêu kỵ tướng quân là chức riêng pho'
#               seg[0:60]='Các tướng_quân thì có Phiêu_kỵ tướng_quân là chức riêng phon'
#               ids[:8]=[0, 146, 19765, 54, 10, 2474, 34361, 9918] | total_tokens=93
#       [TOKEN] id=019e40d1… | raw[0:60]='6- Kinh Tế và Xã Hội Kinh tế dưới đời nhà Trần vẫn là kinh t'
#               seg[0:60]='6 - Kinh_Tế và Xã_Hội Kinh_tế dưới đời nhà Trần_vẫn là kinh_'
#               ids[:8]=[0, 245, 31, 8360, 17488, 6, 36252, 792] | total_tokens=126
#       [TOKEN] id=019e40d1… | raw[0:60]='Giá mỗi người chỉ có một quan (Toàn thư quyển 5, tờ 59b; Cư'
#               seg[0:60]='Giá mỗi người chỉ có một quan ( Toàn thư quyển 5 , tờ 59 b ;'
#               ids[:8]=[0, 1584, 205, 18, 66, 10, 16, 2665] | total_tokens=110
# Đang đẩy 19 points lên Qdrant Cloud...
#  Đã lưu dữ liệu thành công lên Qdrant Cloud!
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW    3/28 | pages=[166, 167, 168, 169] | chars=7,818
#       [STRUCT] 32 structural boundaries | book='Việt Sử Toàn Thư'
#     [MINI-CHUNK] window chars=7,818 → 74 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
#  {"split_after_indices":[3,7,11,15,19,23,26,29,33,37,41,44,48,51,55,59,63,67,71]}
#
#
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=74 → splits=[3, 7, 11, 15, 19, 23, 26, 29, 33, 37, 41, 44, 48, 51, 55, 59, 63, 67, 71]
# llm trả về
#  [3, 7, 11, 15, 19, 23, 26, 29, 33, 37, 41, 44, 48, 51, 55, 59, 63, 67, 71]
#
#
#
#     [MERGE] 74 mini-chunks + 19 splits → 20 semantic groups
#       [TOKEN] id=019e40d1… | raw[0:60]='Nhân dân hàng năm phải nộp tiền "thân dịch", quà tết tháng g'
#               seg[0:60]='Nhân_dân hàng năm phải nộp tiền " thân_dịch " , quà tết thán'
#               ids[:8]=[0, 2966, 119, 29, 41, 1140, 123, 22] | total_tokens=150
#       [TOKEN] id=019e40d1… | raw[0:60]='Người có một hay hai mẫu phải nộp một quan tiền.\nNgười có ba'
#               seg[0:60]='Người có một hay hai mẫu phải nộp một quan tiền . Người có b'
#               ids[:8]=[0, 345, 10, 16, 118, 82, 585, 41] | total_tokens=94
#       [TOKEN] id=019e40d1… | raw[0:60]='Mỗi thăng bằng 316 tấc khối tức là 10305688 công thăng. Lối'
#               seg[0:60]='Mỗi thăng_bằng 316 tấc_khối tức_là 10305688 công_thăng . Lối'
#               ids[:8]=[0, 1106, 14409, 28339, 1187, 30535, 1041, 3701] | total_tokens=149
#       [TOKEN] id=019e40d1… | raw[0:60]='Ruộng muối thì phải nộp tiền.\nNgoài các thứ thuế trọng yếu t'
#               seg[0:60]='Ruộng muối thì phải nộp tiền . Ngoài các thứ thuế trọng_yếu'
#               ids[:8]=[0, 38526, 1886, 54, 41, 1140, 123, 5] | total_tokens=112
#       [TOKEN] id=019e40d1… | raw[0:60]='Tiền này gọi là "tỉnh mạch tiền".\nBàn đến nông nghiệp dưới đ'
#               seg[0:60]='Tiền này gọi_là " tỉnh mạch tiền " . Bàn đến nông_nghiệp dướ'
#               ids[:8]=[0, 4322, 23, 32326, 22, 98, 3210, 123] | total_tokens=110
#       [TOKEN] id=019e40d1… | raw[0:60]='Con đê chạy dọc theo sông Hồng Hà bấy giờ gọi là Đỉnh nhĩ đ'
#               seg[0:60]='Con đê chạy dọc theo sông Hồng_Hà bấy_giờ gọi_là Đỉnh nhĩ đê'
#               ids[:8]=[0, 1322, 4331, 397, 2010, 63, 490, 13076] | total_tokens=114
#       [TOKEN] id=019e40d1… | raw[0:60]='Về công nghệ, ta nên hiểu thuở đó mới chỉ có thủ công mà th'
#               seg[0:60]='Về công_nghệ , ta nên hiểu thuở đó mới chỉ có thủ_công mà th'
#               ids[:8]=[0, 674, 461, 4, 237, 77, 563, 7367] | total_tokens=82
#       [TOKEN] id=019e40d2… | raw[0:60]='Nhà Trần bảo vệ nhiệt liệt chế độ tư hữu của dân gian. Việc'
#               seg[0:60]='Nhà Trần_bảo_vệ nhiệt_liệt chế_độ tư_hữu của dân_gian . Việc'
#               ids[:8]=[0, 1706, 1359, 360, 17654, 1150, 23797, 55800] | total_tokens=103
#       [TOKEN] id=019e40d2… | raw[0:60]='Theo trên đây, chúng ta biết dưới Trần triều chế độ phong ki'
#               seg[0:60]='Theo trên đây , chúng_ta biết dưới Trần_triều_chế_độ phong_k'
#               ids[:8]=[0, 79, 34, 97, 4, 507, 55, 280] | total_tokens=113
#       [TOKEN] id=019e40d2… | raw[0:60]='Nếu không trả được nợ thì phải đợ mình cho chủ nợ tức là xi'
#               seg[0:60]='Nếu không trả được nợ thì phải đợ mình cho chủ_nợ tức_là xin'
#               ids[:8]=[0, 313, 17, 505, 11, 758, 54, 41] | total_tokens=138
#       [TOKEN] id=019e40d2… | raw[0:60]='Tuy vậy họ được lấy vợ, lấy chồng và sinh sống ở các nơi họ'
#               seg[0:60]='Tuy_vậy họ được lấy vợ , lấy chồng và sinh_sống ở các nơi họ'
#               ids[:8]=[0, 3328, 86, 11, 273, 372, 4, 273] | total_tokens=120
#       [TOKEN] id=019e40d2… | raw[0:60]='Một tính cách phong kiến nữa dưới Trần triều là chế độ tập ấ'
#               seg[0:60]='Một tính_cách phong_kiến nữa dưới Trần_triều là chế_độ tập_ấ'
#               ids[:8]=[0, 242, 3639, 12222, 348, 280, 2062, 58370] | total_tokens=117
#       [TOKEN] id=019e40d2… | raw[0:60]='Hàng năm triều đình cho xã quan khai báo nhân khẩu gọi là "d'
#               seg[0:60]='Hàng năm triều_đình cho xã quan khai_báo nhân_khẩu gọi_là "'
#               ids[:8]=[0, 1383, 29, 8666, 13, 176, 2665, 6441] | total_tokens=116
#       [TOKEN] id=019e40d2… | raw[0:60]='7- Phong Tục Phong tục của dân Việt Nam vào triều đại nhà Tr'
#               seg[0:60]='7 - Phong_Tục Phong_tục của dân Việt_Nam vào triều_đại nhà T'
#               ids[:8]=[0, 317, 31, 6324, 31937, 46233, 7, 452] | total_tokens=109
#       [TOKEN] id=019e40d2… | raw[0:60]='Mồng 5 Tết trong cung vua có ban tiệc khai hạ. Từ quan đến d'
#               seg[0:60]='Mồng 5 Tết trong cung_vua có ban tiệc khai_hạ . Từ_quan đến'
#               ids[:8]=[0, 54807, 173, 708, 12, 21590, 1692, 10] | total_tokens=135
#       [TOKEN] id=019e40d2… | raw[0:60]='Đúng ngày lập xuân, vua cắt người tông trưởng cầm roi vụt và'
#               seg[0:60]='Đúng ngày lập xuân , vua cắt người tông_trưởng cầm roi vụt v'
#               ids[:8]=[0, 3254, 43, 740, 2184, 4, 1692, 919] | total_tokens=142
#       [TOKEN] id=019e40d2… | raw[0:60]='Ngày mồng 5 tháng 5 dân ăn Tết Đoan Ngọ (Tết nầy ta cũng bắt'
#               seg[0:60]='Ngày mồng 5 tháng 5 dân ăn Tết_Đoan_Ngọ ( Tết nầy ta cũng bắ'
#               ids[:8]=[0, 319, 12331, 173, 78, 173, 452, 203] | total_tokens=155
#       [TOKEN] id=019e40d2… | raw[0:60]='Do đó ta có câu: Giá thú bất luận tài. Còn ở những người ng'
#               seg[0:60]='Do_đó ta có câu : Giá_thú bất_luận_tài . Còn ở những người n'
#               ids[:8]=[0, 1528, 237, 10, 528, 27, 19585, 28729] | total_tokens=148
#       [TOKEN] id=019e40d2… | raw[0:60]='Y phục đời bấy giờ như sau đây: vương hầu và thứ dân thường'
#               seg[0:60]='Y_phục đời bấy_giờ như sau đây : vương_hầu và thứ dân_thường'
#               ids[:8]=[0, 18440, 4578, 733, 6318, 42, 53, 97] | total_tokens=124
#       [TOKEN] id=019e40d2… | raw[0:60]='Đồ mặc thường của vua thì quý mầu trắng. Dân không được dùng'
#               seg[0:60]='Đồ mặc thường của vua thì quý_mầu trắng . Dân không được dùn'
#               ids[:8]=[0, 10952, 1036, 311, 7, 1692, 54, 58605] | total_tokens=45
# Đang đẩy 20 points lên Qdrant Cloud...
#  Đã lưu dữ liệu thành công lên Qdrant Cloud!
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW    4/28 | pages=[169, 170, 171, 172] | chars=8,912
#       [STRUCT] 20 structural boundaries | book='Việt Sử Toàn Thư'
#     [MINI-CHUNK] window chars=8,912 → 77 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
#  {"split_after_indices":[3,7,11,15,18,23,26,32,35,42,47,54,59,63,67,71,75]}
#
#
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=77 → splits=[3, 7, 11, 15, 18, 22, 23, 26, 30, 32, 35, 39, 42, 46, 47, 51, 54, 58, 59, 63, 67, 71, 75]
# llm trả về
#  [3, 7, 11, 15, 18, 22, 23, 26, 30, 32, 35, 39, 42, 46, 47, 51, 54, 58, 59, 63, 67, 71, 75]
#
#
#
#     [MERGE] 77 mini-chunks + 23 splits → 24 semantic groups
#       [TOKEN] id=019e40d2… | raw[0:60]='Về hình phạt của Trần triều xét ra nghiêm ngặt hơn Lý triều.'
#               seg[0:60]='Về hình_phạt của Trần_triều_xét ra nghiêm_ngặt hơn Lý_triều'
#               ids[:8]=[0, 674, 4883, 7, 2062, 58370, 23916, 1522] | total_tokens=159
#       [TOKEN] id=019e40d2… | raw[0:60]='8- Văn Hóa Cùng một nhịp với các ngành chính trị, quân sự, k'
#               seg[0:60]='8 - Văn_Hóa Cùng một nhịp với các ngành chính_trị , quân_sự'
#               ids[:8]=[0, 358, 31, 2287, 1125, 11095, 1517, 962] | total_tokens=121
#       [TOKEN] id=019e40d2… | raw[0:60]='Toàn Thư quyển 5, tờ 41 chép rằng dưới triền Trần Nhân Tông'
#               seg[0:60]='Toàn Thư_quyển 5 , tờ 41 chép rằng dưới triền Trần_Nhân_Tông'
#               ids[:8]=[0, 2663, 17671, 6248, 173, 4, 1102, 3513] | total_tokens=104
#       [TOKEN] id=019e40d2… | raw[0:60]='Nói vậy không phải là nhà Trần đã triệt để dùng chữ Nôm. Các'
#               seg[0:60]='Nói vậy không phải là nhà_Trần đã triệt_để dùng chữ Nôm . Cá'
#               ids[:8]=[0, 1950, 702, 17, 41, 8, 9096, 3212] | total_tokens=126
#       [TOKEN] id=019e40d2… | raw[0:60]='nhưng trong khi chữ Nôm phát triển mạnh để đi tới chỗ đại c'
#               seg[0:60]='nhưng trong khi chữ_Nôm phát_triển mạnh để đi tới chỗ đại_ch'
#               ids[:8]=[0, 51, 12, 26, 46552, 134, 384, 24] | total_tokens=110
#       [TOKEN] id=019e40d2… | raw[0:60]='Văn hóa đời Trần cũng dành cho Sử ký một địa vị quan trọng h'
#               seg[0:60]='Văn_hóa đời Trần cũng dành cho Sử_ký một địa_vị quan_trọng h'
#               ids[:8]=[0, 2287, 1340, 11095, 1517, 733, 3212, 32] | total_tokens=113
#       [TOKEN] id=019e40d2… | raw[0:60]='Vũ Đế đến Lý Chiêu Hoàng gồm 30 quyển.'
#               seg[0:60]='Vũ_Đế đến Lý_Chiêu_Hoàng gồm 30 quyển . Nhà Trần_xuất_hiện t'
#               ids[:8]=[0, 30967, 30, 2878, 12982, 1955, 479, 504] | total_tokens=29
#       [TOKEN] id=019e40d2… | raw[0:60]='Nhà Trần xuất hiện trên sân khấu chính trị Việt Nam được 2 n'
#               seg[0:60]='Nhà Trần_xuất_hiện trên sân_khấu chính_trị Việt_Nam được 2 n'
#               ids[:8]=[0, 1706, 1359, 395, 34, 1363, 837, 56] | total_tokens=112
#       [TOKEN] id=019e40d2… | raw[0:60]='Có nên nói rằng ngay trong thời Trần Sơ, Hán văn đã lên tới'
#               seg[0:60]='Có nên nói rằng ngay trong thời Trần_Sơ , Hán_văn đã lên tới'
#               ids[:8]=[0, 503, 77, 96, 87, 249, 12, 790] | total_tokens=126
#       [TOKEN] id=019e40d2… | raw[0:60]='Tờ Thư năm Tân Mùi (1271) gửi cho Trung Thư sảnh nhà Nguyên'
#               seg[0:60]='Tờ Thư năm Tân_Mùi ( 1271 ) gửi cho Trung_Thư sảnh nhà Nguyê'
#               ids[:8]=[0, 3745, 4161, 29, 2535, 7371, 20, 2789] | total_tokens=82
#       [TOKEN] id=019e40d2… | raw[0:60]='Nhà Trần lại cho nghiên cứu và học tập cả tiếng Mán, tiếng T'
#               seg[0:60]='Nhà Trần_lại cho nghiên_cứu và học_tập cả tiếng Mán , tiếng'
#               ids[:8]=[0, 1706, 1359, 44, 13, 410, 6, 1227] | total_tokens=103
#       [TOKEN] id=019e40d2… | raw[0:60]='Vua Nhân Tông soạn được nhiều câu kệ trong tập Trần triều t'
#               seg[0:60]='Vua Nhân_Tông_soạn được nhiều câu kệ trong tập Trần_triều th'
#               ids[:8]=[0, 6933, 6974, 14044, 7021, 11, 36, 528] | total_tokens=129
#       [TOKEN] id=019e40d2… | raw[0:60]='triều đường ra tới ngoài dân đã có rõ rệt một sự gần gũi, v'
#               seg[0:60]='triều đường ra tới ngoài dân đã có rõ_rệt một sự gần_gũi , v'
#               ids[:8]=[0, 5228, 109, 40, 75, 227, 452, 14] | total_tokens=127
#       [TOKEN] id=019e40d2… | raw[0:60]='Đối với chúng nhân, câu "Dân vi quý" của Mạnh Tử được thi hà'
#               seg[0:60]='Đối_với chúng_nhân , câu " Dân vi_quý " của Mạnh_Tử được thi'
#               ids[:8]=[0, 1161, 55252, 1362, 4, 528, 22, 2446] | total_tokens=97
#       [TOKEN] id=019e40d2… | raw[0:60]='là có ý thống trị nhân dân với bàn tay sắt.'
#               seg[0:60]='là có ý_thống_trị nhân_dân với bàn_tay sắt . Kết_quả của cuộ'
#               ids[:8]=[0, 8, 10, 20373, 6698, 62253, 603, 15] | total_tokens=31
#       [TOKEN] id=019e40d2… | raw[0:60]='Kết quả của cuộc chống Mông Cổ ba phen đã chứng minh một cá'
#               seg[0:60]='Kết_quả của cuộc chống Mông_Cổ ba phen đã chứng_minh một_các'
#               ids[:8]=[0, 1657, 7, 110, 335, 8057, 346, 8559] | total_tokens=122
#       [TOKEN] id=019e40d2… | raw[0:60]='Tài chiến trận và huy động mọi lực lượng quốc gia của Hưng'
#               seg[0:60]='Tài_chiến_trận và huy_động mọi lực_lượng quốc_gia của Hưng_Đ'
#               ids[:8]=[0, 12976, 37558, 6, 1509, 207, 340, 257] | total_tokens=86
#       [TOKEN] id=019e40d2… | raw[0:60]='bên trong.Cuộc Chiến Tranh Tự Vệ Vô Cùng Anh Dũng Của Việt N'
#               seg[0:60]='bên trong . Cuộc_Chiến_Tranh_Tự_Vệ Vô_Cùng Anh_Dũng Của Việt'
#               ids[:8]=[0, 145, 12, 5, 22058, 18955, 24629, 11446] | total_tokens=108
#       [TOKEN] id=019e40d2… | raw[0:60]='lịch sử Việt Nam mà cả trong lịch sử thế giới thuở đó - chún'
#               seg[0:60]='lịch_sử Việt_Nam mà cả trong lịch_sử thế_giới thuở đó - chún'
#               ids[:8]=[0, 678, 56, 64, 94, 12, 678, 198] | total_tokens=52
#       [TOKEN] id=019e40d2… | raw[0:60]='Cổ.\nDân số Mông Cổ có gần 3 triệu, đa số là dân du mục. Nhà'
#               seg[0:60]='Cổ . Dân_số Mông_Cổ có gần 3 triệu , đa_số là dân du_mục . N'
#               ids[:8]=[0, 11559, 5, 3898, 8057, 10, 124, 107] | total_tokens=116
#       [TOKEN] id=019e40d2… | raw[0:60]='Từ đời Đường (618-904) ở khoảng thượng lưu Hắc long giang ('
#               seg[0:60]='Từ đời Đường ( 618 - 904 ) ở khoảng thượng_lưu_Hắc long_gian'
#               ids[:8]=[0, 404, 733, 2080, 20, 47448, 31, 1551] | total_tokens=138
#       [TOKEN] id=019e40d2… | raw[0:60]='Họ sắp đặt cơ nào đội ấy rất có thứ tự, sành việc tổ chức v'
#               seg[0:60]='Họ sắp_đặt cơ nào đội ấy rất có thứ_tự , sành việc tổ_chức v'
#               ids[:8]=[0, 783, 10501, 2209, 142, 226, 241, 59] | total_tokens=132
#       [TOKEN] id=019e40d2… | raw[0:60]='Tổ tiên của họ là giống Hung Nô. Tài nguyên của họ là những'
#               seg[0:60]='Tổ_tiên của họ là giống Hung_Nô . Tài_nguyên của họ là những'
#               ids[:8]=[0, 45786, 7, 86, 8, 475, 49999, 5] | total_tokens=129
#       [TOKEN] id=019e40d2… | raw[0:60]='Họ theo đạo Phật nhưng không hiểu nổi triết lý của Phật giá'
#               seg[0:60]='Họ theo đạo_Phật nhưng không hiểu nổi triết_lý của Phật_giáo'
#               ids[:8]=[0, 783, 63, 17848, 3430, 51, 17, 563] | total_tokens=33
# Đang đẩy 24 points lên Qdrant Cloud...
#  Đã lưu dữ liệu thành công lên Qdrant Cloud!
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW    5/28 | pages=[172, 173, 174, 175] | chars=7,592
#       [STRUCT] 28 structural boundaries | book='Việt Sử Toàn Thư'
#     [MINI-CHUNK] window chars=7,592 → 73 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
#  {"split_after_indices":[3,7,11,15,19,23,27,31,35,39,43,47,51,55,59,63,67,71]}
#
#
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=73 → splits=[3, 7, 11, 15, 19, 23, 27, 31, 35, 39, 43, 47, 51, 55, 59, 63, 67, 71]
# llm trả về
#  [3, 7, 11, 15, 19, 23, 27, 31, 35, 39, 43, 47, 51, 55, 59, 63, 67, 71]
#
#
#
#     [MERGE] 73 mini-chunks + 18 splits → 19 semantic groups
#       [TOKEN] id=019e40d2… | raw[0:60]='1) Bộ trong gồm các quân Túc vệ.2) Bộ ngoài là các quân Trấn'
#               seg[0:60]='1 ) Bộ trong gồm các quân_Túc_vệ . 2 ) Bộ ngoài là các quân'
#               ids[:8]=[0, 99, 19, 125, 12, 479, 9, 10035] | total_tokens=147
#       [TOKEN] id=019e40d2… | raw[0:60]='Quân Khiếp tiết và các vệ tuy đều là quân Túc vệ hợp lại gọ'
#               seg[0:60]='Quân Khiếp_tiết và các vệ tuy đều là quân_Túc_vệ_hợp lại gọi'
#               ids[:8]=[0, 2842, 2666, 26673, 18684, 12098, 6, 9] | total_tokens=145
#       [TOKEN] id=019e40d2… | raw[0:60]='Đại khái các nơi biên cương then chốt thì có thân vương, tô'
#               seg[0:60]='Đại_khái các nơi biên_cương then_chốt thì có thân_vương , tô'
#               ids[:8]=[0, 2847, 23636, 9, 189, 23691, 8447, 54] | total_tokens=123
#       [TOKEN] id=019e40d2… | raw[0:60]='bị rối loạn cả chiến lược, chiến thuật.\n2- Thành Tích Chiến'
#               seg[0:60]='bị rối_loạn cả chiến_lược , chiến_thuật . 2 - Thành_Tích Chi'
#               ids[:8]=[0, 45, 3610, 94, 995, 4, 3633, 5] | total_tokens=108
#       [TOKEN] id=019e40d2… | raw[0:60]='Lúc này Trung Quốc chia làm ba khu vực thuộc quyền ba vương'
#               seg[0:60]='Lúc này Trung_Quốc chia làm ba khu_vực thuộc quyền ba vương_'
#               ids[:8]=[0, 1254, 23, 165, 1224, 47, 346, 160] | total_tokens=120
#       [TOKEN] id=019e40d2… | raw[0:60]='Chín năm sau du khách qua vùng này còn thấy đầy dấu tích củ'
#               seg[0:60]='Chín năm sau du_khách qua vùng này còn thấy đầy dấu_tích của'
#               ids[:8]=[0, 10472, 29, 53, 902, 89, 275, 23] | total_tokens=92
#       [TOKEN] id=019e40d2… | raw[0:60]='"Nơi nào ngựa Mông Cổ đi qua, cỏ cây cũng hết sống" của chú'
#               seg[0:60]='" Nơi nào ngựa Mông_Cổ đi qua , cỏ_cây cũng hết sống " của c'
#               ids[:8]=[0, 22, 4031, 142, 3053, 8057, 57, 89] | total_tokens=163
#       [TOKEN] id=019e40d2… | raw[0:60]='dọc từ bời biển Aral tới vịnh Ba Tư.\nMông Cổ tới, bốn chục'
#               seg[0:60]='dọc từ bời biển Aral tới vịnh Ba_Tư . Mông_Cổ tới , bốn chục'
#               ids[:8]=[0, 2010, 39, 55821, 262, 9665, 2228, 75] | total_tokens=85
#       [TOKEN] id=019e40d2… | raw[0:60]='Các quốc gia Tây Âu nghe tin này cũng vô cùng khủng khiếp co'
#               seg[0:60]='Các quốc_gia Tây_Âu nghe tin này cũng vô_cùng khủng_khiếp co'
#               ids[:8]=[0, 146, 257, 17459, 523, 200, 23, 32] | total_tokens=109
#       [TOKEN] id=019e40d2… | raw[0:60]='Tây Hạ đầu hàng và bị sáp nhập vào đế quốc Mông Cổ từ đó.\nT'
#               seg[0:60]='Tây_Hạ đầu_hàng và bị sáp_nhập vào đế_quốc Mông_Cổ từ đó . T'
#               ids[:8]=[0, 3848, 5392, 8371, 6, 45, 4209, 33] | total_tokens=120
#       [TOKEN] id=019e40d2… | raw[0:60]='Hiến Tông phái hai em là Hạt Lô (Houlagen) đi kinh lý Ba Tư'
#               seg[0:60]='Hiến Tông_phái hai em là Hạt_Lô ( Houlagen ) đi kinh_lý Ba_T'
#               ids[:8]=[0, 10046, 14044, 4777, 82, 193, 8, 20716] | total_tokens=139
#       [TOKEN] id=019e40d2… | raw[0:60]='Thật là một đế quốc lớn nhất từ khi có loài người và lịch s'
#               seg[0:60]='Thật là một đế_quốc lớn nhất từ khi có loài_người và lịch_sử'
#               ids[:8]=[0, 3395, 8, 16, 11346, 103, 67, 39] | total_tokens=113
#       [TOKEN] id=019e40d2… | raw[0:60]='vua Trần Thái Tông thần phục về Mông Cổ.\nVua và dân Việt Nam'
#               seg[0:60]='vua Trần_Thái_Tông thần_phục về Mông_Cổ . Vua và dân Việt_Na'
#               ids[:8]=[0, 1692, 24661, 21372, 4578, 28, 8057, 5] | total_tokens=96
#       [TOKEN] id=019e40d2… | raw[0:60]='Mông Cổ theo đường Vân Nam tiến xuống sông Thao, Hưng Hóa và'
#               seg[0:60]='Mông_Cổ theo đường Vân_Nam tiến xuống sông Thao , Hưng_Hóa v'
#               ids[:8]=[0, 8057, 63, 109, 14062, 1447, 307, 490] | total_tokens=121
#       [TOKEN] id=019e40d2… | raw[0:60]='Chỗ này sử không chép rõ, chỉ biết rằng đối với ta quân Môn'
#               seg[0:60]='Chỗ này sử không chép rõ , chỉ biết rằng đối_với ta quân Môn'
#               ids[:8]=[0, 17943, 23, 5717, 17, 8492, 297, 4] | total_tokens=125
#       [TOKEN] id=019e40d2… | raw[0:60]='Thành Thăng Long bỏ ngỏ. Quân Mông Cổ vào thấy ba người sứ c'
#               seg[0:60]='Thành_Thăng_Long bỏ_ngỏ . Quân Mông_Cổ vào thấy ba người sứ'
#               ids[:8]=[0, 5734, 2980, 15287, 5, 2842, 8057, 33] | total_tokens=127
#       [TOKEN] id=019e40d2… | raw[0:60]='- Đầu tôi chưa rơi xuống đất thì xin bệ hạ đừng lo! Đó là câ'
#               seg[0:60]='- Đầu tôi chưa rơi xuống đất thì xin bệ hạ đừng lo ! Đó là c'
#               ids[:8]=[0, 31, 3089, 70, 102, 891, 307, 179] | total_tokens=117
#       [TOKEN] id=019e40d2… | raw[0:60]='Thái Tông tiến quân lên đánh giặc ở Đông Bộ đầu. Giặc chạy'
#               seg[0:60]='Thái_Tông tiến_quân lên đánh giặc ở Đông Bộ đầu . Giặc chạy'
#               ids[:8]=[0, 27024, 25974, 72, 480, 6845, 25, 836] | total_tokens=133
#       [TOKEN] id=019e40d2… | raw[0:60]='Ngài lên làm Thái Thượng Hoàng để cùng trông coi việc nước.'
#               seg[0:60]='Ngài lên làm Thái_Thượng_Hoàng để cùng trông_coi việc nước .'
#               ids[:8]=[0, 12775, 72, 47, 3264, 6293, 1955, 24] | total_tokens=14
# Đang đẩy 19 points lên Qdrant Cloud...
#  Đã lưu dữ liệu thành công lên Qdrant Cloud!
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW    6/28 | pages=[175, 176, 177, 178] | chars=7,164
#       [STRUCT] 22 structural boundaries | book='Việt Sử Toàn Thư'
#     [MINI-CHUNK] window chars=7,164 → 69 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
#  {"split_after_indices":[0,3,6,9,13,17,20,25,28,31,35,38,41,45,48,51,54,57,60,64,67]}
#
#
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=69 → splits=[0, 3, 6, 9, 13, 17, 20, 24, 25, 28, 31, 35, 38, 41, 45, 48, 51, 54, 57, 60, 64, 67]
# llm trả về
#  [0, 3, 6, 9, 13, 17, 20, 24, 25, 28, 31, 35, 38, 41, 45, 48, 51, 54, 57, 60, 64, 67]
#
#
#
#     [MERGE] 69 mini-chunks + 22 splits → 23 semantic groups
#       [TOKEN] id=019e40d2… | raw[0:60]='Thái Tông trị vì được 33 năm, làm Thái Thượng Hoàng được 19'
#               seg[0:60]='Thái Tông_trị_vì được 33 năm , làm Thái_Thượng_Hoàng được 19'
#               ids[:8]=[0, 1709, 37909, 11097, 22549, 90, 11, 2606] | total_tokens=51
#       [TOKEN] id=019e40d2… | raw[0:60]='Trần Thánh Tông (1258 - 1278) - Việc mở mang chính trị - Vi'
#               seg[0:60]='Trần_Thánh_Tông ( 1258 - 1278 ) - Việc mở_mang chính_trị - V'
#               ids[:8]=[0, 40983, 20, 2789, 4023, 31, 2789, 5188] | total_tokens=114
#       [TOKEN] id=019e40d2… | raw[0:60]='Ngài ở ngôi 21 năm, nước nhà được yên trị. Việc học được mở'
#               seg[0:60]='Ngài ở ngôi 21 năm , nước_nhà được yên_trị . Việc học được m'
#               ids[:8]=[0, 12775, 25, 642, 1298, 29, 4, 6206] | total_tokens=84
#       [TOKEN] id=019e40d2… | raw[0:60]='Ngài lại cho Lê Văn Hưu tiếp tục biên soạn sách sử ký. Họ Lê'
#               seg[0:60]='Ngài lại cho Lê_Văn_Hưu tiếp_tục biên_soạn sách sử_ký . Họ L'
#               ids[:8]=[0, 12775, 44, 13, 3226, 35629, 194, 8441] | total_tokens=106
#       [TOKEN] id=019e40d2… | raw[0:60]='2- Việc Ngoại Giao Với Mông Cổ Mông Cổ tuy thua nhưng vẫn kh'
#               seg[0:60]='2 - Việc Ngoại_Giao Với Mông_Cổ_Mông_Cổ tuy_thua nhưng vẫn k'
#               ids[:8]=[0, 76, 31, 519, 16331, 6460, 321, 25550] | total_tokens=119
#       [TOKEN] id=019e40d2… | raw[0:60]='Mùa hạ năm Mậu Ngọ (1258) Mông Cổ sai Nột Loạt Đan sang dụ v'
#               seg[0:60]='Mùa hạ năm Mậu_Ngọ ( 1258 ) Mông_Cổ sai Nột_Loạt Đan sang dụ'
#               ids[:8]=[0, 2822, 1269, 29, 16656, 10566, 20, 2789] | total_tokens=111
#       [TOKEN] id=019e40d2… | raw[0:60]='đến khi thả ra thì một người chết) các ngươi lại dám trói c'
#               seg[0:60]='đến khi thả ra thì một người chết ) các ngươi lại dám trói c'
#               ids[:8]=[0, 30, 26, 2177, 40, 54, 16, 18] | total_tokens=91
#       [TOKEN] id=019e40d2… | raw[0:60]='Vua Trần Thánh Tông hỏi: "Nếu tiểu quốc thành tâm thờ đại qu'
#               seg[0:60]='Vua Trần_Thánh_Tông hỏi : " Nếu tiểu_quốc thành tâm_thờ đại_'
#               ids[:8]=[0, 6933, 40983, 447, 27, 22, 313, 26496] | total_tokens=115
#       [TOKEN] id=019e40d2… | raw[0:60]='Mông Cổ sai sứ sang yêu sách hết điều này đến điều nọ, vua'
#               seg[0:60]='Mông_Cổ sai sứ sang yêu_sách hết điều này đến_điều nọ , vua'
#               ids[:8]=[0, 8057, 1069, 4986, 295, 10172, 351, 184] | total_tokens=55
#       [TOKEN] id=019e40d2… | raw[0:60]='sau câu chuyện ngã ngũ ở chỗ nước Nam chỉ chịu sứ tiến cống'
#               seg[0:60]='sau câu_chuyện ngã_ngũ ở chỗ nước Nam chỉ chịu sứ_tiến cống'
#               ids[:8]=[0, 53, 876, 27635, 25, 683, 58, 590] | total_tokens=136
#       [TOKEN] id=019e40d2… | raw[0:60]='Thật là cả một sự khôn ngoan! Mông Cổ đòi các nhân vật cốt đ'
#               seg[0:60]='Thật là cả một sự khôn_ngoan ! Mông_Cổ đòi các nhân_vật cốt'
#               ids[:8]=[0, 3395, 8, 94, 16, 61, 9277, 381] | total_tokens=91
#       [TOKEN] id=019e40d2… | raw[0:60]='Mông Cổ đặt quan Đạt Lỗ Hoa Xích tức là quan Chưởng Ấn để gi'
#               seg[0:60]='Mông_Cổ đặt quan_Đạt Lỗ_Hoa Xích_tức_là quan Chưởng_Ấn để gi'
#               ids[:8]=[0, 8057, 320, 19748, 4032, 23884, 1597, 1646] | total_tokens=139
#       [TOKEN] id=019e40d2… | raw[0:60]='Sự nhận xét đó đã căn cứ vào chỗ người Mông Cổ đã tung hoàn'
#               seg[0:60]='Sự nhận_xét đó đã căn_cứ vào chỗ người Mông_Cổ đã tung_hoành'
#               ids[:8]=[0, 1139, 2145, 37, 14, 1376, 33, 683] | total_tokens=83
#       [TOKEN] id=019e40d2… | raw[0:60]='Cuộc áp bức bằng quân lực năm Đinh Tị (1257) đã không thành'
#               seg[0:60]='Cuộc áp_bức bằng quân_lực năm Đinh_Tị ( 1257 ) đã không thàn'
#               ids[:8]=[0, 1502, 30087, 121, 10035, 2792, 29, 3912] | total_tokens=101
#       [TOKEN] id=019e40d2… | raw[0:60]='Trái lại họ không ngờ rằng Trần triều hay dân tộc Việt nam'
#               seg[0:60]='Trái_lại họ không ngờ rằng Trần_triều hay dân_tộc Việt_nam t'
#               ids[:8]=[0, 17956, 86, 17, 3217, 87, 2062, 58370] | total_tokens=127
#       [TOKEN] id=019e40d2… | raw[0:60]='đâu đã đủ sức chịu nổi một cuộc trường chiến với một dân tộ'
#               seg[0:60]='đâu đã đủ sức chịu nổi một cuộc trường_chiến với một dân_tộc'
#               ids[:8]=[0, 602, 14, 312, 760, 551, 983, 16] | total_tokens=79
#       [TOKEN] id=019e40d2… | raw[0:60]='là cột trụ của cuộc chống Nguyên quả đã nhìn thời cuộc rất'
#               seg[0:60]='là cột_trụ của cuộc chống Nguyên_quả đã nhìn thời_cuộc rất s'
#               ids[:8]=[0, 8, 34310, 7, 110, 335, 7299, 645] | total_tokens=94
#       [TOKEN] id=019e40d2… | raw[0:60]='Cuộc xô xát giữa đôi bên ra sao?Ba năm sau tức là năm Bính D'
#               seg[0:60]='Cuộc xô_xát giữa đôi bên ra sao ?_Ba năm sau tức_là năm Bính'
#               ids[:8]=[0, 1502, 9036, 147, 464, 145, 40, 423] | total_tokens=120
#       [TOKEN] id=019e40d2… | raw[0:60]='Tờ thứ hai nói về việc tuyển cống nhân tài. Riêng tờ thứ ba'
#               seg[0:60]='Tờ thứ hai nói về việc tuyển cống nhân_tài . Riêng tờ thứ ba'
#               ids[:8]=[0, 3745, 129, 82, 96, 28, 49, 1084] | total_tokens=96
#       [TOKEN] id=019e40d2… | raw[0:60]='Mông Cổ bằng lòng nhưng khoảng tháng 10 năm sau (Đinh Mão tứ'
#               seg[0:60]='Mông_Cổ bằng_lòng nhưng khoảng tháng 10 năm sau ( Đinh_Mão_t'
#               ids[:8]=[0, 8057, 14496, 51, 137, 78, 210, 29] | total_tokens=97
#       [TOKEN] id=019e40d2… | raw[0:60]='Các điều yêu sách của Mông Cổ trước sau đều bị khước từ khéo'
#               seg[0:60]='Các điều yêu_sách của Mông_Cổ trước_sau đều bị khước_từ khéo'
#               ids[:8]=[0, 146, 184, 10172, 7, 8057, 15648, 131] | total_tokens=120
#       [TOKEN] id=019e40d2… | raw[0:60]='2) Đối với việc yêu sách nộp voi, ta thoái thác: ".. Cứ theo'
#               seg[0:60]='2 ) Đối_với việc yêu_sách nộp voi , ta thoái_thác : " .. Cứ'
#               ids[:8]=[0, 76, 19, 1161, 49, 10172, 1140, 3843] | total_tokens=94
#       [TOKEN] id=019e40d2… | raw[0:60]='" 3) Tháng một năm Canh Ngọ (1270) Mông Cổ bắt bẻ vua Trần T'
#               seg[0:60]='" 3 ) Tháng một năm Canh_Ngọ ( 1270 ) Mông_Cổ bắt bẻ vua Trầ'
#               ids[:8]=[0, 22, 107, 19, 1641, 16, 29, 17508] | total_tokens=33
# Đang đẩy 23 points lên Qdrant Cloud...
#  Đã lưu dữ liệu thành công lên Qdrant Cloud!
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW    7/28 | pages=[178, 179, 180, 181, 182] | chars=9,048
#       [STRUCT] 33 structural boundaries | book='Việt Sử Toàn Thư'
#     [MINI-CHUNK] window chars=9,048 → 84 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
#  {"split_after_indices":[3,7,10,13,17,20,23,26,30,34,37,40,43,45,48,52,56,59,63,67,69,72,75,79,82]}
#
#
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=84 → splits=[3, 7, 10, 13, 17, 20, 23, 26, 30, 34, 37, 40, 43, 45, 48, 52, 56, 59, 63, 67, 69, 72, 75, 79, 82]
# llm trả về
#  [3, 7, 10, 13, 17, 20, 23, 26, 30, 34, 37, 40, 43, 45, 48, 52, 56, 59, 63, 67, 69, 72, 75, 79, 82]
#
#
#
#     [MERGE] 84 mini-chunks + 25 splits → 26 semantic groups
#       [TOKEN] id=019e40d2… | raw[0:60]='Vua Trần Thánh Tông trả lời qua Trung thư sảnh nhà Nguyên: "'
#               seg[0:60]='Vua Trần_Thánh_Tông trả_lời qua Trung_thư sảnh nhà_Nguyên :'
#               ids[:8]=[0, 6933, 40983, 799, 89, 2062, 1178, 11023] | total_tokens=115
#       [TOKEN] id=019e40d2… | raw[0:60]='Đối với quan liêu sĩ thứ trong nước phàm mũ áo, điển lễ, ph'
#               seg[0:60]='Đối_với quan_liêu_sĩ thứ trong nước phàm mũ áo , điển_lễ , p'
#               ids[:8]=[0, 1161, 19748, 3, 9031, 129, 12, 58] | total_tokens=134
#       [TOKEN] id=019e40d2… | raw[0:60]='"Tờ dụ lại đòi nho sĩ, thầy thuốc và thợ thuyền. Nhưng khi b'
#               seg[0:60]='" Tờ_dụ lại đòi nho_sĩ , thầy_thuốc và thợ thuyền . Nhưng kh'
#               ids[:8]=[0, 22, 57959, 34492, 44, 1652, 32609, 9031] | total_tokens=102
#       [TOKEN] id=019e40d2… | raw[0:60]='" Năm Tân Mùi (1271) Hốt Tất Liệt cho sứ qua dụ vua Thánh Tô'
#               seg[0:60]='" Năm_Tân_Mùi ( 1271 ) Hốt Tất_Liệt cho sứ qua dụ vua Thánh_'
#               ids[:8]=[0, 22, 28888, 2535, 7371, 20, 2789, 4564] | total_tokens=118
#       [TOKEN] id=019e40d2… | raw[0:60]='"Dẫu được ba năm một lần cống, sứ bộ qua lại đổi thay đi về'
#               seg[0:60]='" Dẫu được ba năm một lần cống , sứ_bộ qua_lại đổi_thay đi v'
#               ids[:8]=[0, 22, 7508, 11, 346, 29, 16, 101] | total_tokens=114
#       [TOKEN] id=019e40d2… | raw[0:60]='"Vả Đạt Lỗ Cát Tề chỉ đáng thi hành với những nước "xấu xí n'
#               seg[0:60]='" Vả_Đạt Lỗ Cát_Tề chỉ đáng thi_hành với những nước " xấu_xí'
#               ids[:8]=[0, 22, 1117, 15021, 4032, 19010, 10355, 19149] | total_tokens=111
#       [TOKEN] id=019e40d2… | raw[0:60]='Theo Trần Trọng Kim về khoản này, vua Thánh Tông xin đổi Đạt'
#               seg[0:60]='Theo Trần_Trọng_Kim về khoản này , vua Thánh_Tông xin đổi Đạ'
#               ids[:8]=[0, 79, 18891, 1816, 28, 666, 23, 4] | total_tokens=106
#       [TOKEN] id=019e40d2… | raw[0:60]='Năm Đinh Sửu (1277) Thái Thượng Hoàng mất ở Thiên Trường phủ'
#               seg[0:60]='Năm Đinh_Sửu ( 1277 ) Thái_Thượng_Hoàng mất ở Thiên_Trường_p'
#               ids[:8]=[0, 434, 3912, 10801, 20, 2789, 4874, 19] | total_tokens=88
#       [TOKEN] id=019e40d2… | raw[0:60]='Trần Nhân Tông (1279 - 1293) Mông Cổ Gây Hấn Lần Thứ Hai -'
#               seg[0:60]='Trần_Nhân_Tông ( 1279 - 1293 ) Mông_Cổ Gây_Hấn Lần Thứ_Hai -'
#               ids[:8]=[0, 18754, 20, 2789, 4981, 31, 2789, 5622] | total_tokens=104
#       [TOKEN] id=019e40d2… | raw[0:60]='Mọi vấn đề dân sinh được ổn định và sinh lực quốc gia mỗi n'
#               seg[0:60]='Mọi vấn_đề dân_sinh được ổn_định và sinh_lực quốc_gia mỗi ng'
# ...
#               ids[:8]=[0, 1562, 207, 49, 56854, 31694, 7, 849] | total_tokens=91
#       [TOKEN] id=019e40d8… | raw[0:60]='Hồ Quý Ly tuy có cải cách nhiều việc trong nước nhưng vẫn c'
#               seg[0:60]='Hồ_Quý_Ly tuy có cải_cách nhiều việc trong nước nhưng vẫn ch'
#               ids[:8]=[0, 43783, 2442, 10, 2103, 36, 49, 12] | total_tokens=100
#       [TOKEN] id=019e40d8… | raw[0:60]='Các nhà làm sử hay các người đọc sử xưa nay thường chỉ nhìn'
#               seg[0:60]='Các nhà làm sử hay các người đọc sử xưa_nay thường chỉ nhìn'
#               ids[:8]=[0, 146, 69, 47, 5717, 118, 9, 18] | total_tokens=106
#       [TOKEN] id=019e40d8… | raw[0:60]='khi ấy các nước Âu Châu chưa đến trình độ bán khai mà nước'
#               seg[0:60]='khi ấy các nước Âu_Châu chưa đến trình_độ bán khai mà nước t'
#               ids[:8]=[0, 26, 241, 9, 58, 15357, 2365, 102] | total_tokens=146
#       [TOKEN] id=019e40d8… | raw[0:60]='Vương cũng có một độ bài xích những lối học huấn hỗ và chú'
#               seg[0:60]='Vương cũng có một độ bài xích những lối học huấn_hỗ và chú_s'
#               ids[:8]=[0, 4379, 32, 10, 16, 378, 387, 7667] | total_tokens=111
#       [TOKEN] id=019e40d8… | raw[0:60]='Bàn tay phá hoại ấy chính là người Minh, nhưng một số đông'
#               seg[0:60]='Bàn_tay phá_hoại ấy chính là người Minh , nhưng một_số đông'
#               ids[:8]=[0, 25579, 5639, 241, 159, 8, 18, 1612] | total_tokens=120
#       [TOKEN] id=019e40d8… | raw[0:60]='đầu thập ngũ thế kỷ.\n"Đem đối chiếu những chính sách của Hồ'
#               seg[0:60]='đầu thập_ngũ thế_kỷ . " Đem đối_chiếu những chính_sách của H'
#               ids[:8]=[0, 127, 56147, 15679, 1786, 5, 22, 19507] | total_tokens=76
# Đang đẩy 20 points lên Qdrant Cloud...
#  Đã lưu dữ liệu thành công lên Qdrant Cloud!
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW   27/28 | pages=[242, 243, 244, 245, 246] | chars=8,586
#       [STRUCT] 24 structural boundaries | book='Việt Sử Toàn Thư'
#     [MINI-CHUNK] window chars=8,586 → 77 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
#  {"split_after_indices":[2,6,10,14,19,23,26,30,34,36,40,44,46,50,54,58,62,66,70,72]}
#
#
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=77 → splits=[2, 6, 10, 14, 18, 19, 23, 26, 30, 34, 36, 40, 44, 46, 50, 54, 58, 62, 66, 70, 72]
# llm trả về
#  [2, 6, 10, 14, 18, 19, 23, 26, 30, 34, 36, 40, 44, 46, 50, 54, 58, 62, 66, 70, 72]
#
#
#
#     [MERGE] 77 mini-chunks + 21 splits → 22 semantic groups
#       [TOKEN] id=019e40d8… | raw[0:60]='"Nhưng đem reo rắc vào một đám dân chúng chưa giác ngộ, nhữn'
#               seg[0:60]='" Nhưng đem reo_rắc vào một đám dân_chúng chưa giác_ngộ , nh'
#               ids[:8]=[0, 22, 293, 873, 3, 10222, 33, 16] | total_tokens=84
#       [TOKEN] id=019e40d8… | raw[0:60]='Phần 3 - Chương 9 Bắc Thuộc Lần Thứ Năm Nhà Hậu Trần (1407-1'
#               seg[0:60]='Phần 3 - Chương 9 Bắc_Thuộc Lần Thứ Năm_Nhà Hậu_Trần ( 1407'
#               ids[:8]=[0, 2918, 107, 31, 6041, 426, 3307, 24349] | total_tokens=125
#       [TOKEN] id=019e40d8… | raw[0:60]='các quan liêu và nhân dân còn lưu luyến họ Trần được nhiều'
#               seg[0:60]='các quan_liêu và nhân_dân còn lưu_luyến họ Trần_được nhiều h'
#               ids[:8]=[0, 9, 17614, 6, 603, 50, 29187, 86] | total_tokens=102
#       [TOKEN] id=019e40d8… | raw[0:60]='Giờ đây, họ dùng hai thủ đoạn chính trị:\n1) Họ treo bảng kêu'
#               seg[0:60]='Giờ_đây , họ dùng hai thủ_đoạn chính_trị : 1 ) Họ treo bảng'
#               ids[:8]=[0, 6180, 4, 86, 175, 82, 5406, 837] | total_tokens=117
#       [TOKEN] id=019e40d8… | raw[0:60]='2) Ngay lúc họ vừa tung ra lời hiệu triệu, họ lại làm tiếp n'
#               seg[0:60]='2 ) Ngay lúc họ vừa tung ra lời hiệu triệu , họ lại làm tiếp'
#               ids[:8]=[0, 76, 19, 869, 219, 86, 164, 1360] | total_tokens=100
#       [TOKEN] id=019e40d8… | raw[0:60]='bằng việc dưới chúng chính thức hóa chế độ đô hộ cổ truyền'
#               seg[0:60]='bằng việc dưới chúng chính_thức hóa chế_độ đô_hộ cổ_truyền c'
#               ids[:8]=[0, 121, 49, 280, 572, 495, 1340, 11095] | total_tokens=41
#       [TOKEN] id=019e40d8… | raw[0:60]='Rồi nhà Minh chia nước ta ra 17 phủ: Giao Châu, Bắc Giang, L'
#               seg[0:60]='Rồi nhà_Minh chia nước ta ra 17 phủ : Giao_Châu , Bắc_Giang'
#               ids[:8]=[0, 3036, 9096, 1612, 1224, 58, 237, 40] | total_tokens=138
#       [TOKEN] id=019e40d8… | raw[0:60]='Về hành chính, họ đặt ra ba ty: Bố Chánh ty, Án Sát ty, Chưở'
#               seg[0:60]='Về hành_chính , họ đặt ra ba_ty : Bố Chánh_ty , Án Sát_ty ,'
#               ids[:8]=[0, 674, 950, 4, 86, 320, 40, 1388] | total_tokens=98
#       [TOKEN] id=019e40d8… | raw[0:60]='Bộ máy hành chính và quân sự bắt đầu quay thì người Minh đã'
#               seg[0:60]='Bộ_máy hành_chính và quân_sự bắt_đầu quay thì người_Minh đã'
#               ids[:8]=[0, 38432, 950, 6, 817, 403, 588, 54] | total_tokens=115
#       [TOKEN] id=019e40d8… | raw[0:60]='các thầy bói toán, các danh y để ban thưởng phẩm hàm hoặc d'
#               seg[0:60]='các thầy bói_toán , các danh_y để ban thưởng_phẩm_hàm hoặc d'
#               ids[:8]=[0, 9, 1249, 41354, 4, 9, 15854, 1231] | total_tokens=123
#       [TOKEN] id=019e40d8… | raw[0:60]='Lữ Nghị và Hoàng Phúc được đặc ủy mọi việc quân chính sau đó'
#               seg[0:60]='Lữ_Nghị và Hoàng_Phúc được đặc_ủy mọi việc quân_chính sau đó'
#               ids[:8]=[0, 15890, 10658, 6, 35606, 11, 47029, 21356] | total_tokens=85
#       [TOKEN] id=019e40d8… | raw[0:60]='Theo Lịch Triều Hiến Chương Văn Tịch chú (Phan Huy Chú) nhữn'
#               seg[0:60]='Theo Lịch_Triều_Hiến Chương_Văn_Tịch chú ( Phan_Huy_Chú ) nh'
#               ids[:8]=[0, 79, 29927, 13079, 10046, 15431, 2287, 32086] | total_tokens=185
#       [TOKEN] id=019e40d8… | raw[0:60]='quyển) 14) Trần Triều Đại Điển của vua Trần Dụ Tông (2 quyển'
#               seg[0:60]='quyển ) 14 ) Trần_Triều_Đại_Điển của vua Trần_Dụ_Tông ( 2 qu'
#               ids[:8]=[0, 6248, 19, 948, 19, 1359, 13079, 2847] | total_tokens=198
#       [TOKEN] id=019e40d8… | raw[0:60]='27) Thảo Nhàn Hiệu Tần của Hồ Tôn Thước (1 quyển) 28) Việt N'
#               seg[0:60]='27 ) Thảo_Nhàn Hiệu_Tần của Hồ_Tôn_Thước ( 1 quyển ) 28 ) Vi'
#               ids[:8]=[0, 1769, 19, 8279, 11521, 29826, 11414, 7] | total_tokens=115
#       [TOKEN] id=019e40d8… | raw[0:60]='các triều đại trước trong 10 thế kỷ đô hộ xưa, họ rất lưu tâ'
#               seg[0:60]='các triều_đại trước trong 10 thế_kỷ đô_hộ xưa , họ rất lưu_t'
#               ids[:8]=[0, 9, 8289, 71, 12, 210, 1786, 34011] | total_tokens=128
#       [TOKEN] id=019e40d8… | raw[0:60]='Sau việc gột rửa cái tinh thần cố hữu là căn bản của mọi cá'
#               seg[0:60]='Sau việc gột_rửa cái tinh_thần cố_hữu là căn_bản của mọi cá_'
#               ids[:8]=[0, 162, 49, 52347, 224, 822, 27839, 8] | total_tokens=152
#       [TOKEN] id=019e40d8… | raw[0:60]='Tại các miền duyên hải, họ ép dân làm muối và cũng có sự kiể'
#               seg[0:60]='Tại các miền duyên_hải , họ ép dân làm muối và cũng có sự ki'
#               ids[:8]=[0, 382, 9, 460, 13048, 4, 86, 2150] | total_tokens=122
#       [TOKEN] id=019e40d8… | raw[0:60]='Để kiểm tra dân chúng (có lẽ vì lý do chính trị), họ phát nh'
#               seg[0:60]='Để kiểm_tra dân_chúng ( có_lẽ vì lý_do chính_trị ) , họ phát'
#               ids[:8]=[0, 483, 342, 9331, 20, 1592, 90, 809] | total_tokens=168
#       [TOKEN] id=019e40d8… | raw[0:60]='[900] chiếc đủ loại.\nVề việc cai trị, các đơn vị hành chính'
#               seg[0:60]='[ 900 ] chiếc đủ loại . Về việc cai_trị , các đơn_vị hành_ch'
#               ids[:8]=[0, 2735, 4474, 2705, 152, 312, 166, 5] | total_tokens=119
#       [TOKEN] id=019e40d8… | raw[0:60]='Ở mỗi lý, phường, tương đề có sổ biên số đinh và số điền, t'
#               seg[0:60]='Ở mỗi lý , phường , tương_đề có sổ biên_số đinh và số điền ,'
#               ids[:8]=[0, 635, 205, 3902, 4, 557, 4, 25964] | total_tokens=132
#       [TOKEN] id=019e40d8… | raw[0:60]='Việc bắt binh lính thì cứ theo sổ bộ. Ở những nơi gọi là vệ'
#               seg[0:60]='Việc bắt_binh_lính thì cứ theo sổ_bộ . Ở những nơi gọi_là vệ'
#               ids[:8]=[0, 519, 12482, 6910, 54, 658, 63, 58340] | total_tokens=83
#       [TOKEN] id=019e40d8… | raw[0:60]='Chính sách đô hộ kể đã chu đáo và việc bóc lột nhân dân đến'
#               seg[0:60]='Chính_sách đô_hộ kể đã chu_đáo và việc bóc_lột nhân_dân đến'
#               ids[:8]=[0, 6011, 34011, 337, 14, 5655, 6, 49] | total_tokens=87
# Đang đẩy 22 points lên Qdrant Cloud...
#  Đã lưu dữ liệu thành công lên Qdrant Cloud!
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW   28/28 | pages=[246, 247, 248, 249] | chars=9,089
#       [STRUCT] 20 structural boundaries | book='Việt Sử Toàn Thư'
#     [MINI-CHUNK] window chars=9,089 → 82 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
#  {"split_after_indices":[3,7,11,15,20,24,28,32,36,40,45,49,52,56,60,64,68,72,76,80]}
#
#
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=82 → splits=[3, 7, 11, 15, 19, 20, 24, 28, 32, 36, 40, 44, 45, 49, 52, 56, 60, 64, 68, 72, 76, 80]
# llm trả về
#  [3, 7, 11, 15, 19, 20, 24, 28, 32, 36, 40, 44, 45, 49, 52, 56, 60, 64, 68, 72, 76, 80]
#
#
#
#     [MERGE] 82 mini-chunks + 22 splits → 23 semantic groups
#       [TOKEN] id=019e40d8… | raw[0:60]='Nhân dân đau khổ hết chỗ nói nhất là với bọn Lý Bân, Mã Kỳ đ'
#               seg[0:60]='Nhân_dân đau_khổ hết chỗ nói nhất_là với bọn Lý_Bân , Mã_Kỳ'
#               ids[:8]=[0, 2966, 5601, 351, 683, 96, 823, 15] | total_tokens=135
#       [TOKEN] id=019e40d8… | raw[0:60]='Trong những kẻ nối giáo cho giặc, chạy theo giặc, một cũng'
#               seg[0:60]='Trong những kẻ nối_giáo cho giặc , chạy theo giặc , một cũng'
#               ids[:8]=[0, 92, 21, 963, 57641, 4368, 13, 6845] | total_tokens=100
#       [TOKEN] id=019e40d8… | raw[0:60]='đặt niên hiệu là Hưng Khánh.\nPhong trào khởi nghĩa không th'
#               seg[0:60]='đặt niên_hiệu là Hưng_Khánh . Phong_trào khởi_nghĩa không th'
#               ids[:8]=[0, 320, 23629, 8, 6381, 3081, 5, 8838] | total_tokens=102
#       [TOKEN] id=019e40d8… | raw[0:60]='Tại Đông Triều (Hải Dương), Trần Nguyệt Hồ cũng chiêu tập b'
#               seg[0:60]='Tại Đông_Triều ( Hải_Dương ) , Trần_Nguyệt_Hồ cũng chiêu_tập'
#               ids[:8]=[0, 382, 13960, 20, 2964, 19, 4, 1359] | total_tokens=149
#       [TOKEN] id=019e40d8… | raw[0:60]='Diễn Châu và Thanh Hóa tiến ra Đông Đô. Quân cách mạng ra t'
#               seg[0:60]='Diễn_Châu và Thanh_Hóa tiến ra Đông_Đô . Quân cách_mạng ra t'
#               ids[:8]=[0, 10435, 6, 2841, 1125, 11095, 1517, 1447] | total_tokens=131
#       [TOKEN] id=019e40d8… | raw[0:60]='Một cuộc giao tranh kịch liệt đã diễn ra. Giản Định tự cầm'
#               seg[0:60]='Một cuộc giao_tranh kịch_liệt đã diễn ra . Giản_Định tự cầm'
#               ids[:8]=[0, 242, 110, 7934, 11892, 14, 229, 40] | total_tokens=67
#       [TOKEN] id=019e40d8… | raw[0:60]='Mộc Thạnh phải bỏ chạy về đóng ở thành Cổ Lộng do quân Minh'
#               seg[0:60]='Mộc_Thạnh phải bỏ chạy về đóng ở thành Cổ_Lộng do quân_Minh'
#               ids[:8]=[0, 16852, 7615, 41, 338, 397, 28, 580] | total_tokens=136
#       [TOKEN] id=019e40d8… | raw[0:60]='3- Trần Quý Khoách Nối Tiếp Cuộc Cách Mạng (1409-1413) Sự vụ'
#               seg[0:60]='3 - Trần_Quý_Khoách Nối_Tiếp_Cuộc Cách_Mạng ( 1409 - 1413 )'
#               ids[:8]=[0, 107, 31, 28116, 8044, 8813, 39960, 20742] | total_tokens=104
#       [TOKEN] id=019e40d8… | raw[0:60]='thuộc Hà Tĩnh) tôn cháu vua Nghệ Tông là Trần Quý Khoách lê'
#               seg[0:60]='thuộc Hà_Tĩnh ) tôn cháu vua Nghệ_Tông là Trần_Quý_Khoách lê'
#               ids[:8]=[0, 187, 1639, 19, 3936, 575, 1692, 27870] | total_tokens=106
#       [TOKEN] id=019e40d8… | raw[0:60]='nhưng giữ chủ quyền hành động vì không tin ở tài năng của G'
#               seg[0:60]='nhưng giữ chủ_quyền hành_động vì không tin ở tài_năng của Gi'
#               ids[:8]=[0, 51, 300, 2495, 688, 90, 17, 200] | total_tokens=105
#       [TOKEN] id=019e40d8… | raw[0:60]='Quân kháng chiến bấy giờ đang chia nhau đánh phá ở miền đông'
#               seg[0:60]='Quân kháng_chiến bấy_giờ đang chia nhau đánh_phá ở miền đông'
#               ids[:8]=[0, 2842, 4873, 6318, 52, 1224, 138, 25353] | total_tokens=126
#       [TOKEN] id=019e40d8… | raw[0:60]='Quân kháng chiến nao núng, Quý Khoách đành rút hết binh đội'
#               seg[0:60]='Quân kháng_chiến nao_núng , Quý_Khoách đành rút hết binh_đội'
#               ids[:8]=[0, 2842, 4873, 36425, 4, 7901, 8044, 8813] | total_tokens=118
#       [TOKEN] id=019e40d8… | raw[0:60]='Trong dịp này, một số người Việt a dua với chúng giết hại n'
#               seg[0:60]='Trong dịp này , một_số người Việt a_dua với chúng giết_hại n'
#               ids[:8]=[0, 92, 867, 23, 4, 172, 18, 350] | total_tokens=56
#       [TOKEN] id=019e40d8… | raw[0:60]='So sánh với mấy thời Bắc thuộc trước, cảnh địa ngục của giặ'
#               seg[0:60]='So_sánh với mấy thời Bắc_thuộc trước , cảnh địa_ngục của giặ'
#               ids[:8]=[0, 15056, 15, 849, 790, 49321, 71, 4] | total_tokens=110
#       [TOKEN] id=019e40d8… | raw[0:60]='Thêm một lần nữa, Trương Phụ tuyên cáo tờ chiếu của vua Minh'
#               seg[0:60]='Thêm một lần nữa , Trương_Phụ tuyên_cáo tờ chiếu của vua_Min'
#               ids[:8]=[0, 2855, 16, 101, 348, 4, 2743, 16002] | total_tokens=113
#       [TOKEN] id=019e40d8… | raw[0:60]='Quý Khoách mấy phen cho người sang Tàu cầu phong với Minh Đế'
#               seg[0:60]='Quý_Khoách mấy phen cho người sang Tàu cầu_phong với Minh_Đế'
#               ids[:8]=[0, 7901, 8044, 8813, 849, 8559, 13, 18] | total_tokens=141
#       [TOKEN] id=019e40d8… | raw[0:60]='Tháng sáu năm Quý Tỵ (1413), quân Minh đánh thành Nghệ An. T'
#               seg[0:60]='Tháng sáu năm Quý_Tỵ ( 1413 ) , quân_Minh đánh thành Nghệ_An'
#               ids[:8]=[0, 1641, 3158, 29, 34840, 20, 3012, 964] | total_tokens=154
#       [TOKEN] id=019e40d8… | raw[0:60]='Tháng 9 năm ấy, quân Minh đã có mặt ở Hóa Châu. Nguyễn Súy v'
#               seg[0:60]='Tháng 9 năm ấy , quân_Minh đã có_mặt ở Hóa_Châu . Nguyễn_Súy'
#               ids[:8]=[0, 1641, 426, 29, 241, 4, 10035, 1612] | total_tokens=115
#       [TOKEN] id=019e40d8… | raw[0:60]='Đi đến nửa đường, Quý Khoách nhảy xuống bể tự tử, còn bọn N'
#               seg[0:60]='Đi đến nửa đường , Quý_Khoách nhảy xuống bể tự_tử , còn bọn'
#               ids[:8]=[0, 2898, 30, 1439, 109, 4, 7901, 8044] | total_tokens=128
#       [TOKEN] id=019e40d8… | raw[0:60]='Nền móng đã lún, cột kèo đã mục, thì làm thế nào khỏi sự sụ'
#               seg[0:60]='Nền_móng đã lún , cột kèo đã mục , thì làm thế_nào khỏi sự s'
#               ids[:8]=[0, 1086, 32004, 4167, 14, 5181, 4, 2364] | total_tokens=112
#       [TOKEN] id=019e40d8… | raw[0:60]='Ngoài ra, nhân dân Việt Nam đã ủng hộ cuộc kháng chiến của h'
#               seg[0:60]='Ngoài_ra , nhân_dân Việt_Nam đã ủng_hộ cuộc kháng_chiến của'
#               ids[:8]=[0, 492, 4, 603, 56, 14, 728, 110] | total_tokens=95
#       [TOKEN] id=019e40d8… | raw[0:60]='Rồi đây, cũng với trời đất, non sông ấy, nhân dân ấy, người'
#               seg[0:60]='Rồi_đây , cũng với trời_đất , non sông ấy , nhân_dân ấy , ng'
#               ids[:8]=[0, 1144, 55973, 4, 32, 15, 18871, 4] | total_tokens=125
#       [TOKEN] id=019e40d8… | raw[0:60]='tâm lý của cả một lớp người thời đó như vậy mà lại trách Qu'
#               seg[0:60]='tâm_lý của cả một lớp người thời đó như_vậy mà_lại trách Quý'
#               ids[:8]=[0, 1523, 7, 94, 16, 459, 18, 790] | total_tokens=23
# Đang đẩy 23 points lên Qdrant Cloud...
#  Đã lưu dữ liệu thành công lên Qdrant Cloud!
#
# ════════════════════════════════════════════════════════════════════════
#   PIPELINE COMPLETE — 'Việt Sử Toàn Thư'
#   Total Qdrant points produced : 588
# ════════════════════════════════════════════════════════════════════════
#
# [SAVE] Writing 588 points → 'full_VietSu_data_qdrant_points.json'…
# [SAVE] Done. 826.4 KB written.

# %% [markdown]
# # Run Vương Trều Trần

# %%
# @title

import os
from google.colab import userdata


# JSON_PATH = "full_DVSK_data.json"           # Đại Việt Sử Ký Toàn Thư
# JSON_PATH = "full_KhamDinh_data.json"        # Khâm Định Việt Sử Thông Giám Cương Mục
# JSON_PATH = "full_VietSu_data.json"                 # Việt Sử Toàn Thư
JSON_PATH = "full_VTT_data.json"                  # Vương Triều Trần
# JSON_PATH = "full_test.json"


OUTPUT_PATH = JSON_PATH.replace(".json", "_qdrant_points.json")


def _load_key(colab_secret: str, env_var: str) -> str:
    try:
        from google.colab import userdata as _ud
        val = _ud.get(colab_secret)
        if val:
            print(f"[KEY] '{colab_secret}' loaded from Colab Secrets.")
            return val
    except Exception:
        pass
    val = os.environ.get(env_var, "")
    if val:
        print(f"[KEY] '{env_var}' loaded from environment variable.")
    return val

GROQ_API_KEY   = _load_key("grok_key",  "grok_key")
GEMINI_API_KEY = _load_key("GEMINI_API_KEY", "GEMINI_API_KEY")

if not GROQ_API_KEY and not GEMINI_API_KEY:
    print("[KEY] ⚠  No API keys found. "
          "Add GROQ_API_KEY and/or GOOGLE_API_KEY to Colab Secrets.")


# USE_BATCH_MODE: bool = True
USE_BATCH_MODE: bool = False

BATCH_ORCHESTRATOR: Optional[GeminiBatchOrchestrator] = None
LLM_BACKENDS:       list[LLMBackend]                  = []

if USE_BATCH_MODE:
    if not GEMINI_API_KEY:
        raise RuntimeError(
            "USE_BATCH_MODE=True but GOOGLE_API_KEY is not set. "
            "Add it to Colab Secrets or switch USE_BATCH_MODE=False."
        )
    BATCH_ORCHESTRATOR = GeminiBatchOrchestrator(
        api_key=GEMINI_API_KEY,
        model_id=GEMINI_MODEL_ID,       # "gemini-2.5-flash"
    )
    print(f"[INIT] Mode A — GeminiBatchOrchestrator ready "
          f"(model={GEMINI_MODEL_ID}, "
          f"sub_batch={GeminiBatchOrchestrator.SUB_BATCH_SIZE} chunks/line)")

else:
    # Build sync fallback chain
    # if GROQ_API_KEY:
    #     LLM_BACKENDS.append(GroqBackend(GROQ_API_KEY, GROQ_MODEL_LLAMA_70B))
    #     LLM_BACKENDS.append(GroqBackend(GROQ_API_KEY, GROQ_MODEL_LLAMA_8B))
    #     LLM_BACKENDS.append(GroqBackend(GROQ_API_KEY, GROQ_MODEL_QWEN))

    if GEMINI_API_KEY:
        try:
            LLM_BACKENDS.append(GeminiBackend(GEMINI_API_KEY, GEMINI_MODEL_ID))
            print("[INIT] GeminiBackend added as last-resort sync fallback.")
        except Exception as _ge:
            print(f"[INIT] GeminiBackend skipped ({type(_ge).__name__}: {_ge}).")

    if not LLM_BACKENDS:
        raise RuntimeError(
            "USE_BATCH_MODE=False but LLM_BACKENDS is empty. "
            "Provide GROQ_API_KEY and/or GOOGLE_API_KEY."
        )

    print(f"[INIT] Mode B — sync fallback chain ({len(LLM_BACKENDS)} backend(s)):")
    for _i, _b in enumerate(LLM_BACKENDS):
        print(f"   [{_i + 1}] {_b.label}")

print()

print(f"[LOAD] Reading '{JSON_PATH}'…")
with open(JSON_PATH, "r", encoding="utf-8") as _fh:
    input_data: dict = json.load(_fh)


assert "book_name"          in input_data, "Missing key: book_name"
assert "full_text"          in input_data, "Missing key: full_text"
assert "page_footnotes_map" in input_data, "Missing key: page_footnotes_map"
assert isinstance(input_data["full_text"],          str),  "full_text must be str"
assert isinstance(input_data["page_footnotes_map"], dict), "page_footnotes_map must be dict"
print("[LOAD] Input validation passed ✓")

qdrant_points: list[dict] = run_pipeline(
    input_data,
    backends           = LLM_BACKENDS,
    batch_orchestrator = BATCH_ORCHESTRATOR,
)

print(f"\n[SAVE] Writing {len(qdrant_points):,} points → '{OUTPUT_PATH}'…")
with open(OUTPUT_PATH, "w", encoding="utf-8") as _fh:
    json.dump(qdrant_points, _fh, ensure_ascii=False, indent=2)
_kb = os.path.getsize(OUTPUT_PATH) / 1024
print(f"[SAVE] Done. {_kb:.1f} KB written.")
# Out:
# [KEY] 'grok_key' loaded from Colab Secrets.
# [KEY] 'GEMINI_API_KEY' loaded from Colab Secrets.
# [INIT] GeminiBackend added as last-resort sync fallback.
# [INIT] Mode B — sync fallback chain (1 backend(s)):
#    [1] gemini-sync/gemini-3.1-flash-lite
#
# [LOAD] Reading 'full_VTT_data.json'…
# [LOAD] Input validation passed ✓
# ════════════════════════════════════════════════════════════════════════
#   PIPELINE START — 'Vương Triều Trần (1226-1400)'
#   full_text chars     :    1,310,006
#   footnote page count :          759
#   LLM mode            : SYNC (Mode B)
#   LLM backend(s)      : gemini-sync/gemini-3.1-flash-lite
# ════════════════════════════════════════════════════════════════════════
# ════════════════════════════════════════════════════════════════════════
#   PIPELINE START — 'Vương Triều Trần (1226-1400)'
#   full_text chars     :    1,310,006
#   footnote page count :          759
# ════════════════════════════════════════════════════════════════════════
# [INIT] Loading tokenizer: bkai-foundation-models/vietnamese-bi-encoder
# [INIT] Loading model → device=cpu
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
#               seg[0:60]='Lần thứ ba trong lịch_sử dân_tộc Việt_Nam , dòng sông Bạch_Đ'
#               ids[:8]=[0, 2385, 129, 346, 12, 678, 872, 56] | total_tokens=69
#       [TOKEN] id=019e40f4… | raw[0:60]='Khi đạo quân Ô Mã Nhi đang bị vây đánh và tiêu diệt trên sôn'
#               seg[0:60]='Khi đạo_quân Ô_Mã_Nhi đang bị vây đánh và tiêu_diệt trên sôn'
#               ids[:8]=[0, 251, 17848, 829, 10576, 2969, 23561, 4154] | total_tokens=91
#       [TOKEN] id=019e40f4… | raw[0:60]='Ngày 8-4-1288, Thoát Hoan bắt đầu rút quân từ Vạn Kiếp theo'
#               seg[0:60]='Ngày 8-4-1288 , Thoát Hoan bắt_đầu rút quân từ Vạn_Kiếp theo'
#               ids[:8]=[0, 319, 6064, 6139, 2789, 4371, 4, 15666] | total_tokens=122
#       [TOKEN] id=019e40f4… | raw[0:60]='Cánh quân Tích Đô Nhi vừa tiến qua cửa Hãm Sa (tức Hãm Nệ, n'
#               seg[0:60]='Cánh quân_Tích Đô_Nhi vừa tiến qua cửa Hãm_Sa ( tức Hãm_Nệ ,'
#               ids[:8]=[0, 7380, 10035, 17054, 19743, 4154, 164, 1447] | total_tokens=99
#       [TOKEN] id=019e40f4… | raw[0:60]='Ngày 11-4, Thoát Hoan dẫn quân đến cửa Nội Bàng thì lọt vào'
#               seg[0:60]='Ngày 11-4 , Thoát Hoan dẫn_quân đến cửa Nội_Bàng thì lọt vào'
#               ids[:8]=[0, 319, 43656, 4, 15666, 9327, 40926, 829] | total_tokens=101
#       [TOKEN] id=019e40f4… | raw[0:60]='Vừa ra khỏi Nội Bàng chưa kịp hoàn hồn, thì tướng giặc lại n'
#               seg[0:60]='Vừa ra khỏi Nội_Bàng chưa kịp hoàn_hồn , thì tướng giặc lại'
#               ids[:8]=[0, 4087, 40, 353, 13504, 16687, 102, 1616] | total_tokens=132
#       [TOKEN] id=019e40f4… | raw[0:60]='Biết bao ky binh giặc đã sa xuống hố bẫy ngựa; biết bao quâ'
#               seg[0:60]='Biết_bao ky_binh giặc đã sa xuống hố bẫy ngựa ; biết_bao quâ'
#               ids[:8]=[0, 53464, 29809, 4006, 6845, 14, 3635, 307] | total_tokens=136
#       [TOKEN] id=019e40f4… | raw[0:60]='Rất nhiều tên xâm lược phải đền tội ngay dọc biên giới. A Bá'
#               seg[0:60]='Rất nhiều tên xâm_lược phải đền_tội ngay dọc biên_giới . A_B'
#               ids[:8]=[0, 2176, 36, 221, 6717, 41, 19807, 55735] | total_tokens=81
#       [TOKEN] id=019e40f4… | raw[0:60]='Cuộc xâm lược lần thứ ba của đế chế Mông - Nguyên đối với Đạ'
#               seg[0:60]='Cuộc xâm_lược lần thứ ba của đế_chế Mông - Nguyên đối_với Đạ'
#               ids[:8]=[0, 1502, 6717, 101, 129, 346, 7, 11228] | total_tokens=86
#       [TOKEN] id=019e40f4… | raw[0:60]='Ngày 18-4-1288, Thượng hoàng Trần Thánh Tông và vua Trần Nhâ'
#               seg[0:60]='Ngày 18-4-1288 , Thượng_hoàng Trần_Thánh_Tông và vua Trần_Nh'
#               ids[:8]=[0, 319, 9767, 6139, 2789, 4371, 4, 6293] | total_tokens=75
# Đang đẩy 24 points lên Qdrant Cloud...
#  Đã lưu dữ liệu thành công lên Qdrant Cloud!
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW   97/152 | pages=[487, 488, 489, 490, 491, 492] | chars=8,580
#       [STRUCT] 19 structural boundaries | book='Vương Triều Trần (1226-1400)'
#     [MINI-CHUNK] window chars=8,580 → 75 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
#  {"split_after_indices":[3,7,11,14,19,23,26,30,34,39,44,49,53,57,60,63,67,71]}
#
#
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=75 → splits=[3, 7, 11, 14, 18, 19, 23, 26, 30, 34, 38, 39, 43, 44, 48, 49, 53, 57, 60, 63, 67, 71]
# llm trả về
#  [3, 7, 11, 14, 18, 19, 23, 26, 30, 34, 38, 39, 43, 44, 48, 49, 53, 57, 60, 63, 67, 71]
#
#
#
#     [MERGE] 75 mini-chunks + 22 splits → 23 semantic groups
#       [TOKEN] id=019e40f5… | raw[0:60]='“Xã tắc lưỡng hồi lao thạch mã, Thiên hà thiên cổ điện kim ô'
#               seg[0:60]='“ Xã tắc_lưỡng hồi lao thạch_mã , Thiên_hà_thiên_cổ điện kim'
#               ids[:8]=[0, 556, 3074, 60803, 15903, 857, 1750, 59130] | total_tokens=142
#       [TOKEN] id=019e40f5… | raw[0:60]='Trong vòng 30 năm, đã ba lần đánh thắng giặc Mông - Nguyên:'
#               seg[0:60]='Trong vòng 30 năm , đã ba lần đánh thắng giặc Mông - Nguyên'
#               ids[:8]=[0, 92, 323, 504, 29, 4, 14, 346] | total_tokens=115
#       [TOKEN] id=019e40f5… | raw[0:60]='Qua chiến tranh, chúng ta thấy nét đặc sắc nổi bật của nghệ'
#               seg[0:60]='Qua chiến_tranh , chúng_ta thấy nét đặc_sắc nổi_bật của nghệ'
#               ids[:8]=[0, 1326, 1536, 4, 507, 108, 1267, 4319] | total_tokens=121
#       [TOKEN] id=019e40f5… | raw[0:60]='đoàn kết cả nước. Chính nhờ đó mà vương triều Trần đã lãnh'
#               seg[0:60]='đoàn_kết cả nước . Chính nhờ đó mà vương_triều Trần đã lãnh_'
#               ids[:8]=[0, 2688, 94, 58, 5, 1008, 595, 37] | total_tokens=78
#       [TOKEN] id=019e40f5… | raw[0:60]='V. QUAN HỆ ĐẠI VIỆT VỚI TRUNG QUỐC, CHĂMPA VÀ CÁC NƯỚC KHÁC'
#               seg[0:60]='V. QUAN_HỆ ĐẠI_VIỆT VỚI_TRUNG_QUỐC , CHĂMPA_VÀ CÁC NƯỚC KHÁC'
#               ids[:8]=[0, 5044, 48390, 4045, 30986, 35640, 23746, 16543] | total_tokens=169
#       [TOKEN] id=019e40f5… | raw[0:60]='Trong bối canh đó, mối bang giao giữa Đại Việt và nhà Tốổng'
#               seg[0:60]='Trong bối_canh đó , mối bang giao giữa Đại_Việt và nhà_Tốổng'
#               ids[:8]=[0, 92, 63958, 2870, 37, 4, 579, 1400] | total_tokens=58
#       [TOKEN] id=019e40f5… | raw[0:60]='Đạ;: Việt sử ký toàn thư chép: Năm Ký Sửu (1229), vua Trần'
#               seg[0:60]='Đạ ; : Việt_sử ký toàn thư_chép : Năm Ký_Sửu ( 1229 ) , vua'
#               ids[:8]=[0, 1782, 3628, 65, 27, 3789, 5717, 765] | total_tokens=181
#       [TOKEN] id=019e40f5… | raw[0:60]='Sau khi Nguyên Thái Tông băng thì cửa ai thường không thông'
#               seg[0:60]='Sau khi Nguyên_Thái Tông_băng thì cửa ai thường không thông'
#               ids[:8]=[0, 162, 26, 7299, 1709, 14044, 1731, 54] | total_tokens=97
#       [TOKEN] id=019e40f5… | raw[0:60]='Có thể thấy, dưới thời vua Trần Thái Tông việc ngoại giao v'
#               seg[0:60]='Có_thể thấy , dưới thời vua Trần_Thái_Tông việc ngoại_giao v'
#               ids[:8]=[0, 1576, 108, 4, 280, 790, 1692, 24661] | total_tokens=115
#       [TOKEN] id=019e40f5… | raw[0:60]='“Đời thứ hai (tức Trần Cảnh). Ơon giữa của Thái Tổ, tính ng'
#               seg[0:60]='“ Đời thứ hai ( tức Trần_Cảnh ) . Ơon giữa của Thái_Tổ , tín'
#               ids[:8]=[0, 556, 10526, 129, 82, 20, 2487, 1359] | total_tokens=174
#       [TOKEN] id=019e40f5… | raw[0:60]='Vua Tống xuống lời dụ chiếu khen và sai sứ thần đem cho vàn'
#               seg[0:60]='Vua Tống xuống lời dụ_chiếu khen và sai sứ_thần đem cho vàng'
#               ids[:8]=[0, 6933, 10251, 307, 278, 30225, 62368, 2317] | total_tokens=145
#       [TOKEN] id=019e40f5… | raw[0:60]='Khoang niên hiệu Bảáo Hựu (1253 - 1258) Tống Lý Tông phong'
#               seg[0:60]='Khoang niên_hiệu Bảáo_Hựu ( 1253 - 1258 ) Tống_Lý_Tông_phong'
#               ids[:8]=[0, 23211, 23629, 20405, 10494, 36225, 20, 2789] | total_tokens=49
#       [TOKEN] id=019e40f5… | raw[0:60]='Lúc đầu cha con đều thần phục thiên triều, đến lúc cha mất,'
#               seg[0:60]='Lúc đầu cha_con đều thần_phục thiên_triều , đến lúc cha mất'
#               ids[:8]=[0, 1254, 127, 8217, 131, 21372, 4578, 52014] | total_tokens=130
#       [TOKEN] id=019e40f5… | raw[0:60]='cho nên suốt đời Thái Tông không có sứ sang phong. Đến đây'
#               seg[0:60]='cho_nên suốt đời Thái_Tông không có sứ sang phong . Đến đây'
#               ids[:8]=[0, 5489, 703, 733, 27024, 17, 10, 4986] | total_tokens=53
#       [TOKEN] id=019e40f5… | raw[0:60]='Đó cũng chỉ là tùy hai nước ấy tự sai sứ sang, nước ta chưa'
#               seg[0:60]='Đó cũng chỉ là tùy hai nước ấy tự sai sứ sang , nước ta chưa'
#               ids[:8]=[0, 669, 32, 66, 8, 32463, 1231, 82] | total_tokens=125
#       [TOKEN] id=019e40f5… | raw[0:60]='nước Nam Tống mới bị quân đội của Hốt Tất Liệt chinh phục s'
#               seg[0:60]='nước Nam_Tống mới bị quân_đội của Hốt Tất_Liệt chinh_phục sa'
#               ids[:8]=[0, 58, 2233, 10251, 60, 45, 830, 7] | total_tokens=52
#       [TOKEN] id=019e40f5… | raw[0:60]='mà thôi. Vì thế, về cơ bản trong thời gian này, quan hệ đối'
#               seg[0:60]='mà thôi . Vì_thế , về cơ_bản trong thời_gian này , quan_hệ đ'
#               ids[:8]=[0, 64, 886, 5, 1999, 4, 28, 1264] | total_tokens=120
#       [TOKEN] id=019e40f5… | raw[0:60]='Sau kháng chiến lần thứ nhất thắng lợi, đất nước thanh bình,'
#               seg[0:60]='Sau kháng_chiến lần thứ nhất thắng_lợi , đất_nước thanh_bình'
#               ids[:8]=[0, 162, 4873, 101, 129, 67, 3824, 4] | total_tokens=123
#       [TOKEN] id=019e40f5… | raw[0:60]='Đại Việt sử ký toàn thư chép: “Mùa xuân, tháng Giêng, ngày'
#               seg[0:60]='Đại_Việt sử_ký toàn thư_chép : “ Mùa xuân , tháng_Giêng , ng'
#               ids[:8]=[0, 12208, 35056, 668, 27124, 8781, 2150, 27] | total_tokens=120
#       [TOKEN] id=019e40f5… | raw[0:60]='Cuối cùng quy định 3 năm một lần tiến cống, coi là thường l'
#               seg[0:60]='Cuối_cùng quy_định 3 năm một lần tiến cống , coi là thường_l'
#               ids[:8]=[0, 3235, 209, 107, 29, 16, 101, 1447] | total_tokens=107
#       [TOKEN] id=019e40f5… | raw[0:60]='Tháng 3-1258, Trần Thái Tông nhường ngôi cho con là Trần Hoả'
#               seg[0:60]='Tháng 3-1258 , Trần_Thái_Tông nhường_ngôi cho con là Trần_Ho'
#               ids[:8]=[0, 1641, 5512, 2789, 4023, 4, 24661, 57252] | total_tokens=128
#       [TOKEN] id=019e40f5… | raw[0:60]='Vua Trần Thánh Tông vẫn mềm mỏng tra lời: “Nước nhỏ thành t'
#               seg[0:60]='Vua Trần_Thánh_Tông vẫn mềm mỏng_tra lời : “ Nước nhỏ thành'
#               ids[:8]=[0, 6933, 40983, 74, 2767, 57571, 11097, 1517] | total_tokens=122
#       [TOKEN] id=019e40f5… | raw[0:60]='nhưng mộng bành trướng xuống các nước Đông Nam Á của Hốt Tấ'
#               seg[0:60]='nhưng mộng bành trướng xuống các nước Đông_Nam_Á của Hốt Tất'
#               ids[:8]=[0, 51, 7847, 34516, 27767, 307, 9, 58] | total_tokens=69
# Đang đẩy 23 points lên Qdrant Cloud...
#  Đã lưu dữ liệu thành công lên Qdrant Cloud!
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW   98/152 | pages=[492, 493, 494, 495, 496, 497] | chars=6,998
#       [STRUCT] 12 structural boundaries | book='Vương Triều Trần (1226-1400)'
#     [MINI-CHUNK] window chars=6,998 → 66 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
#  {"split_after_indices":[3,7,11,15,19,23,27,31,35,39,43,47,51,55,59,63]}
#
#
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=66 → splits=[3, 7, 11, 15, 19, 23, 27, 31, 35, 39, 43, 47, 51, 55, 59, 63]
# llm trả về
#  [3, 7, 11, 15, 19, 23, 27, 31, 35, 39, 43, 47, 51, 55, 59, 63]
#
#
#
#     [MERGE] 66 mini-chunks + 16 splits → 17 semantic groups
#       [TOKEN] id=019e40f5… | raw[0:60]='Tháng 6 năm Tân Dậu (năm 1261) “Nhà Nguyên sai Lễ bộ Lang tr'
#               seg[0:60]='Tháng 6 năm Tân_Dậu ( năm 1261 ) “ Nhà_Nguyên sai Lễ_bộ Lang'
#               ids[:8]=[0, 1641, 245, 29, 2535, 10968, 20, 29] | total_tokens=136
#       [TOKEN] id=019e40f5… | raw[0:60]='“Thánh Tông, năm Thiệu Long thứ 4 (1261) (ngang với năm Cản'
#               seg[0:60]='“ Thánh_Tông , năm Thiệu_Long thứ 4 ( 1261 ) ( ngang với năm'
#               ids[:8]=[0, 556, 48723, 4, 29, 16121, 1871, 129] | total_tokens=141
#       [TOKEN] id=019e40f5… | raw[0:60]='Đồng thời, “nước Mông Cổ phong vương vua làm Án Nam vương ('
#               seg[0:60]='Đồng_thời , “ nước Mông_Cổ_phong vương_vua làm_Án Nam_vương'
#               ids[:8]=[0, 1248, 4, 556, 58, 25550, 7861, 3448] | total_tokens=153
#       [TOKEN] id=019e40f5… | raw[0:60]='cùng đem đến cống?5. Chúng ta biết rằng một lần triều cống,'
#               seg[0:60]='cùng đem đến cống ? 5 . Chúng_ta biết rằng một lần triều cốn'
#               ids[:8]=[0, 81, 873, 30, 4099, 114, 173, 5] | total_tokens=129
#       [TOKEN] id=019e40f5… | raw[0:60]='vua Trần sai Phạm Cự Địa và Trần Kiều sang nước Nguyên vào'
#               seg[0:60]='vua Trần_sai_Phạm_Cự_Địa và Trần_Kiều_sang nước_Nguyên vào t'
#               ids[:8]=[0, 1692, 1359, 33772, 2016, 22050, 14210, 6] | total_tokens=135
#       [TOKEN] id=019e40f5… | raw[0:60]='gấm cho Thánh Tông năm 1262.\n“Thánh Tông, năm Thiệu Long th'
#               seg[0:60]='gấm cho Thánh_Tông năm 1262 . “ Thánh_Tông , năm Thiệu_Long'
#               ids[:8]=[0, 23891, 13, 48723, 29, 2789, 3952, 5] | total_tokens=125
#       [TOKEN] id=019e40f5… | raw[0:60]='“Năm Trung Thống thứ 3 (năm 1262), sai Nạp Lạt Định làm chứ'
#               seg[0:60]='“ Năm_Trung_Thống thứ 3 ( năm 1262 ) , sai Nạp_Lạt_Định làm'
#               ids[:8]=[0, 556, 28888, 3484, 10080, 129, 107, 20] | total_tokens=123
#       [TOKEN] id=019e40f5… | raw[0:60]='Bấy giờ mới định lệ 3 nắăm một lần cống”6. Bắt đầu từ năm 1'
#               seg[0:60]='Bấy_giờ mới định_lệ 3 nắăm một lần cống ” 6 . Bắt_đầu_từ năm'
#               ids[:8]=[0, 31326, 60, 17121, 7235, 107, 1301, 13572] | total_tokens=139
#       [TOKEN] id=019e40f5… | raw[0:60]='Đại Việt sử bý toàn thư chép rõ: “Tháng 2 năm Bính Dần (năm'
#               seg[0:60]='Đại_Việt sử_bý toàn thư_chép rõ : “ Tháng 2 năm Bính_Dần ( n'
#               ids[:8]=[0, 12208, 32841, 40806, 2198, 668, 27124, 8781] | total_tokens=149
#       [TOKEN] id=019e40f5… | raw[0:60]='bon Dương An Dưỡng từ nước Nguyên trở về, mang theo luôn lễ'
#               seg[0:60]='bon_Dương_An_Dưỡng từ nước Nguyên trở về , mang theo luôn lễ'
#               ids[:8]=[0, 31671, 2496, 3187, 19835, 39, 58, 1759] | total_tokens=117
#       [TOKEN] id=019e40f5… | raw[0:60]='Lúc này, Hốt Tất Liệt tiếp tục cuộc chiến tranh chinh phục N'
#               seg[0:60]='Lúc này , Hốt Tất_Liệt tiếp_tục cuộc chiến_tranh chinh_phục'
#               ids[:8]=[0, 1254, 23, 4, 1125, 10587, 15457, 19622] | total_tokens=111
#       [TOKEN] id=019e40f5… | raw[0:60]='Chỉ cần lấy ví dụ, giá sử chấp nhận yêu cầu thứ 6 là cho đặ'
#               seg[0:60]='Chỉ cần lấy ví_dụ , giá sử chấp_nhận yêu_cầu thứ 6 là cho đặ'
#               ids[:8]=[0, 843, 115, 273, 2704, 4, 133, 5717] | total_tokens=134
#       [TOKEN] id=019e40f5… | raw[0:60]='Vua Nguyên trong lời chiếu dụ nước ÁAn Nam tháng 7 năm 1267'
#               seg[0:60]='Vua_Nguyên trong lời chiếu dụ nước ÁAn_Nam tháng 7 năm 1267'
#               ids[:8]=[0, 7481, 1759, 12, 278, 1914, 11536, 58] | total_tokens=111
#       [TOKEN] id=019e40f5… | raw[0:60]='Phàm chư hầu vào đại quốc để cống hiến vật sản, là chế độ t'
#               seg[0:60]='Phàm chư hầu vào đại_quốc để cống_hiến vật_sản , là chế_độ t'
#               ids[:8]=[0, 34197, 27757, 6134, 33, 7250, 3705, 24] | total_tokens=136
#       [TOKEN] id=019e40f5… | raw[0:60]='Nay trâm ban cho các đổồ lễ vật, có kê rõ trong giấy tờ, kh'
#               seg[0:60]='Nay_trâm ban cho các đổồ lễ_vật , có kê rõ trong giấy_tờ , k'
#               ids[:8]=[0, 1086, 44487, 2226, 718, 13, 9, 33950] | total_tokens=167
#       [TOKEN] id=019e40f5… | raw[0:60]='Tháng 11 năm Ất Hợi (năm 1275), người Nguyên đi tuần ở biên'
#               seg[0:60]='Tháng 11 năm Ất_Hợi ( năm 1275 ) , người Nguyên đi tuần ở bi'
#               ids[:8]=[0, 1641, 624, 29, 37259, 10500, 20, 29] | total_tokens=115
#       [TOKEN] id=019e40f5… | raw[0:60]='thực hiện đúng 3 năm một lần tiến cống nhưng các đồ tiến cố'
#               seg[0:60]='thực_hiện đúng 3 năm một lần tiến cống nhưng các đồ_tiến cốn'
#               ids[:8]=[0, 112, 287, 107, 29, 16, 101, 1447] | total_tokens=42
# Đang đẩy 17 points lên Qdrant Cloud...
#  Đã lưu dữ liệu thành công lên Qdrant Cloud!
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW   99/152 | pages=[497, 498, 499, 500, 501, 502] | chars=10,572
#       [STRUCT] 24 structural boundaries | book='Vương Triều Trần (1226-1400)'
#     [MINI-CHUNK] window chars=10,572 → 98 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
#  {"split_after_indices":[3,7,11,15,19,25,30,36,41,45,50,55,59,64,69,75,80,84,89,93,97]}
#
#
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=98 → splits=[3, 7, 11, 15, 19, 23, 25, 29, 30, 34, 36, 40, 41, 45, 49, 50, 54, 55, 59, 63, 64, 68, 69, 73, 75, 79, 80, 84, 88, 89, 93]
# llm trả về
#  [3, 7, 11, 15, 19, 23, 25, 29, 30, 34, 36, 40, 41, 45, 49, 50, 54, 55, 59, 63, 64, 68, 69, 73, 75, 79, 80, 84, 88, 89, 93]
#
#
#
#     [MERGE] 98 mini-chunks + 31 splits → 32 semantic groups
#       [TOKEN] id=019e40f5… | raw[0:60]='“Theo chế độ của tổ tông đã quy định, phàm các nước nội phụ'
#               seg[0:60]='“ Theo chế_độ của tổ_tông đã quy_định , phàm các nước nội_ph'
#               ids[:8]=[0, 556, 79, 1150, 7, 23027, 58709, 14] | total_tokens=143
#       [TOKEN] id=019e40f5… | raw[0:60]='Tình hình hai nước không chỉ dừng lại ở việc bang giao đơn t'
#               seg[0:60]='Tình_hình hai nước không_chỉ dừng lại ở việc bang giao đơn_t'
#               ids[:8]=[0, 6723, 82, 58, 665, 772, 44, 25] | total_tokens=127
#       [TOKEN] id=019e40f5… | raw[0:60]='“Nhà Nguyên nghe tin Thái Tông mất, muốn nhân trong nước có'
#               seg[0:60]='“ Nhà_Nguyên nghe tin Thái_Tông mất , muốn nhân trong nước c'
#               ids[:8]=[0, 556, 7029, 1759, 523, 200, 27024, 274] | total_tokens=119
#       [TOKEN] id=019e40f5… | raw[0:60]='Nhà Nguyên liền cử sứ thần sang yêu cầu vua Trần Nhân Tông'
#               seg[0:60]='Nhà_Nguyên liền cử sứ_thần sang yêu_cầu vua Trần_Nhân_Tông s'
#               ids[:8]=[0, 7029, 1759, 1228, 2370, 50793, 295, 285] | total_tokens=153
#       [TOKEN] id=019e40f5… | raw[0:60]='Vua không nghe..”4. Trần Quang Khải là một trong những người'
#               seg[0:60]='Vua không nghe .. ” 4 . Trần_Quang_Khải là một trong những n'
#               ids[:8]=[0, 6933, 17, 523, 3457, 564, 163, 5] | total_tokens=129
#       [TOKEN] id=019e40f5… | raw[0:60]='Vừq nói cười đó mờà thoốt đã ngộm ngùi chía tayí Cùng nhau'
#               seg[0:60]='Vừq nói_cười đó mờà thoốt đã ngộm_ngùi chía_tayí Cùng nhau x'
#               ids[:8]=[0, 1117, 14583, 9583, 8553, 944, 37, 61172] | total_tokens=104
#       [TOKEN] id=019e40f5… | raw[0:60]='Nhất đàm tiếu khoảnh t phâên Đuệê, Cộng xướng thù gian tích'
#               seg[0:60]='Nhất_đàm_tiếu khoảnh t phâên_Đuệê , Cộng_xướng thù_gian_tích'
#               ids[:8]=[0, 8651, 32381, 20383, 1204, 47292, 34683, 56670] | total_tokens=61
#       [TOKEN] id=019e40f5… | raw[0:60]='Dịch nghĩa:\nTiễn ông trở về riêng những bâng khuâng, Ngựa xa'
#               seg[0:60]='Dịch_nghĩa : Tiễn ông trở về riêng những bâng_khuâng , Ngựa'
#               ids[:8]=[0, 20165, 1645, 27, 33278, 46, 682, 28] | total_tokens=84
#       [TOKEN] id=019e40f5… | raw[0:60]='Chưa biết bao giờ lại được gặp mặt, Đểề cầm tay ân cần tỏ nỗ'
#               seg[0:60]='Chưa biết bao_giờ lại được gặp_mặt , Đểề cầm tay ân_cần tỏ n'
#               ids[:8]=[0, 2066, 55, 789, 44, 11, 4892, 4] | total_tokens=45
#       [TOKEN] id=019e40f5… | raw[0:60]='Khi sứ đoàn nhà Nguyên trở về, vua sai Trịnh Đình Toán và Đỗ'
#               seg[0:60]='Khi sứ_đoàn nhà_Nguyên trở về , vua sai Trịnh_Đình_Toán và Đ'
#               ids[:8]=[0, 251, 58442, 639, 9096, 1759, 682, 28] | total_tokens=110
#       [TOKEN] id=019e40f5… | raw[0:60]='Thế thì bọn Lê Khắc Phục làm sao mà tới được?Hai điều đó là'
#               seg[0:60]='Thế thì bọn Lê_Khắc_Phục làm_sao mà tới được ?_Hai điều đó l'
#               ids[:8]=[0, 1000, 54, 3129, 34252, 18644, 2407, 64] | total_tokens=44
#       [TOKEN] id=019e40f5… | raw[0:60]='Các quan nhà Nguyên bàn nhau muốn tiến quân sang Đại Việt n'
#               seg[0:60]='Các quan nhà_Nguyên bàn nhau muốn tiến_quân sang Đại_Việt nh'
#               ids[:8]=[0, 146, 2665, 9096, 1759, 509, 138, 202] | total_tokens=119
#       [TOKEN] id=019e40f5… | raw[0:60]='Năm 1281, triều đình nhà Trần một mặt chuẩn bị kháng chiến,'
#               seg[0:60]='Năm 1281 , triều_đình nhà Trần_một_mặt chuẩn_bị kháng_chiến'
#               ids[:8]=[0, 434, 2789, 5442, 4, 8666, 69, 1359] | total_tokens=64
#       [TOKEN] id=019e40f5… | raw[0:60]='Nguyên văn lời chiếu như sau: “Lời chiếu dụ cho Thế tử An N'
#               seg[0:60]='Nguyên_văn lời chiếu như sau : “ Lời chiếu_dụ cho Thế_tử_An_'
#               ids[:8]=[0, 43203, 278, 1914, 42, 53, 27, 556] | total_tokens=134
#       [TOKEN] id=019e40f5… | raw[0:60]='trẫm lại xuống một lời chiếu để trách khanh về những việc t'
#               seg[0:60]='trẫm lại xuống một lời chiếu để trách_khanh về những việc th'
#               ids[:8]=[0, 2127, 18244, 44, 307, 16, 278, 1914] | total_tokens=150
#       [TOKEN] id=019e40f5… | raw[0:60]='Vả khanh cùng nước Chiêm Thành là bạn láng giểng đã lâu, kh'
#               seg[0:60]='Vả_khanh cùng nước Chiêm_Thành là bạn láng_giểng đã lâu , kh'
#               ids[:8]=[0, 1117, 15250, 61064, 81, 58, 34831, 8] | total_tokens=63
#       [TOKEN] id=019e40f5… | raw[0:60]='Thế thì bọn Lệ Kháắc Phục làm sao mà tới được? Hai điều đó'
#               seg[0:60]='Thế thì bọn Lệ Kháắc_Phục làm_sao mà tới được ?_Hai điều đó'
#               ids[:8]=[0, 1000, 54, 3129, 9125, 28178, 18312, 18644] | total_tokens=131
#       [TOKEN] id=019e40f5… | raw[0:60]='chứ nay khanh đương tuổi cường tráng, vào chầu mà chịu sắc'
#               seg[0:60]='chứ nay khanh đương_tuổi cường_tráng , vào chầu mà chịu sắc_'
#               ids[:8]=[0, 597, 136, 32423, 3438, 22068, 55439, 41292] | total_tokens=66
#       [TOKEN] id=019e40f5… | raw[0:60]='có sợ gì mà không đi tới một lần? Hoặc giá khanh không lo s'
#               seg[0:60]='có sợ gì mà không đi tới một lần ? Hoặc giá khanh không lo s'
#               ids[:8]=[0, 10, 1080, 148, 64, 17, 57, 75] | total_tokens=119
#       [TOKEN] id=019e40f5… | raw[0:60]='chuẩn bị kháng chiến, vua Trần Nhân Tông đã sai chú họ là Tr'
#               seg[0:60]='chuẩn_bị kháng_chiến , vua Trần_Nhân_Tông đã sai chú họ là T'
#               ids[:8]=[0, 546, 4873, 4, 1692, 18754, 14, 1069] | total_tokens=122
#       [TOKEN] id=019e40f5… | raw[0:60]='Một đoàn đi sứ mà có đến hàng nghìn quân hộ tổng mà triều đ'
#               seg[0:60]='Một đoàn đi sứ mà có đến hàng nghìn quân hộ tổng mà triều_đì'
#               ids[:8]=[0, 242, 639, 57, 4986, 64, 10, 30] | total_tokens=58
#       [TOKEN] id=019e40f5… | raw[0:60]='Tháng 4 cùng năm, Trần Di Ái trở về nước. Tháng 6-12812, vì'
#               seg[0:60]='Tháng 4 cùng năm , Trần_Di_Ái trở về nước . Tháng 6-1281 2 ,'
#               ids[:8]=[0, 1641, 163, 81, 29, 4, 1359, 10236] | total_tokens=111
#       [TOKEN] id=019e40f5… | raw[0:60]='Nay con không có lệnh của triều đình mà tự lập lên làm vua.'
#               seg[0:60]='Nay con không có lệnh của triều_đình mà tự_lập lên làm vua .'
#               ids[:8]=[0, 6993, 73, 17, 10, 1422, 7, 8666] | total_tokens=42
#       [TOKEN] id=019e40f5… | raw[0:60]='Ta sai sứ thần qua triệu thì mượn có không đến chầu, nay lạ'
#               seg[0:60]='Ta sai sứ_thần qua triệu thì mượn có không đến chầu , nay lạ'
#               ids[:8]=[0, 8051, 1069, 50793, 89, 113, 54, 3135] | total_tokens=137
#       [TOKEN] id=019e40f5… | raw[0:60]='Các quan lại và thân sĩ, nhân dân đều cứ ở yên mà sinh lý,'
#               seg[0:60]='Các quan_lại và thân_sĩ , nhân_dân đều cứ ở yên mà sinh_lý ,'
#               ids[:8]=[0, 146, 23123, 6, 18311, 9031, 4, 603] | total_tokens=93
#       [TOKEN] id=019e40f5… | raw[0:60]='Nay dụ các quan và tôn tộc nước Án Nam” (Theo Lê Tắc, Arz N'
#               seg[0:60]='Nay dụ các quan và tôn_tộc nước Án_Nam ” ( Theo Lê_Tắc , Arz'
#               ids[:8]=[0, 6993, 11536, 9, 2665, 6, 15359, 7634] | total_tokens=142
#       [TOKEN] id=019e40f5… | raw[0:60]='Thêm vào đấy phải nộp người hiển tài, người làm thợ và ngườ'
#               seg[0:60]='Thêm vào đấy phải nộp người hiển_tài , người làm thợ và ngườ'
#               ids[:8]=[0, 2855, 33, 1582, 41, 1140, 18, 56476] | total_tokens=62
#       [TOKEN] id=019e40f5… | raw[0:60]='đều gọi là hạng phương kỹ), mỗi hạng hai người. Vì thế nhà'
#               seg[0:60]='đều gọi_là hạng phương kỹ ) , mỗi hạng hai người . Vì_thế nh'
#               ids[:8]=[0, 131, 32326, 1094, 1607, 2199, 19, 4] | total_tokens=164
#       [TOKEN] id=019e40f5… | raw[0:60]='không làm tròn chức trách, không giữ được thể điện quốc gia'
#               seg[0:60]='không làm tròn chức_trách , không giữ được thể_điện quốc_gia'
#               ids[:8]=[0, 17, 47, 2533, 17249, 4, 17, 300] | total_tokens=123
#       [TOKEN] id=019e40f5… | raw[0:60]='Tháng 8-1282, “thú thần Lạng Châu là Lương Uất chạy trạm tâ'
#               seg[0:60]='Tháng 8-1282 , “ thú_thần Lạng_Châu là Lương_Uất chạy trạm t'
#               ids[:8]=[0, 1641, 6064, 2789, 4666, 4, 556, 51640] | total_tokens=70
#       [TOKEN] id=019e40f5… | raw[0:60]='nhưng thực ra sang xâm lược nước ta”1. Cuộc chiến tranh đan'
#               seg[0:60]='nhưng thực_ra sang xâm_lược nước ta ” 1 . Cuộc chiến_tranh đ'
#               ids[:8]=[0, 51, 6999, 295, 6717, 58, 237, 564] | total_tokens=123
#       [TOKEN] id=019e40f5… | raw[0:60]='Ý đồ lấy cớ mượn đường đi đánh Chiêm Thành nhưng thực chất'
#               seg[0:60]='Ý_đồ lấy cớ mượn đường đi đánh Chiêm_Thành nhưng thực_chất l'
#               ids[:8]=[0, 28970, 779, 273, 6750, 3135, 109, 57] | total_tokens=112
# Đang đẩy 32 points lên Qdrant Cloud...
#  Đã lưu dữ liệu thành công lên Qdrant Cloud!
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW  100/152 | pages=[502, 503, 504, 505, 506, 507] | chars=7,241
#       [STRUCT] 17 structural boundaries | book='Vương Triều Trần (1226-1400)'
#     [MINI-CHUNK] window chars=7,241 → 61 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
#  {"split_after_indices":[3,7,11,15,19,23,27,31,35,39,43,47,51,55,59]}
#
#
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=61 → splits=[3, 7, 11, 15, 19, 23, 27, 31, 35, 39, 43, 47, 51, 55, 59]
# llm trả về
#  [3, 7, 11, 15, 19, 23, 27, 31, 35, 39, 43, 47, 51, 55, 59]
#
#
#
#     [MERGE] 61 mini-chunks + 15 splits → 16 semantic groups
#       [TOKEN] id=019e40f6… | raw[0:60]='một mặt sai quan Đạt lỗ hoa xích tại Ngạc Châu Lộ là Triệu C'
#               seg[0:60]='một_mặt sai_quan Đạt lỗ hoa xích tại Ngạc_Châu_Lộ là Triệu_C'
#               ids[:8]=[0, 9649, 33772, 2665, 4032, 2536, 389, 7667] | total_tokens=134
#       [TOKEN] id=019e40f6… | raw[0:60]='nên lần này Hốt Tất Liệt huy động một đội quân rất đông, tr'
#               seg[0:60]='nên lần này Hốt Tất_Liệt huy_động một đội quân rất đông , tr'
#               ids[:8]=[0, 77, 101, 23, 1125, 10587, 15457, 19622] | total_tokens=146
#       [TOKEN] id=019e40f6… | raw[0:60]='Lúc này, nhà Trần càng thấy được nguy cơ cuộc chiến là không'
#               seg[0:60]='Lúc này , nhà Trần_càng thấy được nguy_cơ cuộc_chiến là khôn'
#               ids[:8]=[0, 1254, 23, 4, 69, 1359, 566, 108] | total_tokens=110
#       [TOKEN] id=019e40f6… | raw[0:60]='Để cổ vũ, kêu gọi tnh thần chiến đấu của các tướng sĩ, Trần'
#               seg[0:60]='Để cổ_vũ , kêu_gọi tnh_thần chiến_đấu của các tướng_sĩ , Trầ'
#               ids[:8]=[0, 483, 3708, 4, 1450, 1187, 33274, 1185] | total_tokens=124
#       [TOKEN] id=019e40f6… | raw[0:60]='Trần Hưng Đạo được lệnh đem quân thủy bộ lên trấn giữ vùng'
#               seg[0:60]='Trần_Hưng_Đạo được lệnh đem quân_thủy bộ lên trấn_giữ vùng L'
#               ids[:8]=[0, 8390, 11, 1422, 873, 60282, 21356, 1231] | total_tokens=159
#       [TOKEN] id=019e40f6… | raw[0:60]='buộc phải chở lương thực đến Chiêm Thành cho quân Nguyên và'
#               seg[0:60]='buộc phải chở lương_thực đến Chiêm_Thành cho quân_Nguyên và'
#               ids[:8]=[0, 1009, 41, 988, 4312, 30, 34831, 13] | total_tokens=128
#       [TOKEN] id=019e40f6… | raw[0:60]='Nhưng Quy Lê và Takhai Xaric trở về cùng với các sứ Đại Việ'
#               seg[0:60]='Nhưng Quy_Lê và Takhai_Xaric trở về cùng với các sứ Đại_Việt'
#               ids[:8]=[0, 293, 21042, 47487, 6, 6210, 20898, 1646] | total_tokens=144
#       [TOKEN] id=019e40f6… | raw[0:60]='Quân Thoát Hoan đến châu Tư Miình (huyện Nam Ninh, Quảng Tâ'
#               seg[0:60]='Quân_Thoát Hoan đến châu_Tư_Miình ( huyện Nam_Ninh , Quảng_T'
#               ids[:8]=[0, 8995, 15666, 9327, 30, 26705, 7163, 4272] | total_tokens=136
#       [TOKEN] id=019e40f6… | raw[0:60]='“Sở đĩ ta dấy quân là vì Chiêm Thành, không phải vì An Nam”'
#               seg[0:60]='“ Sở đĩ ta dấy_quân là vì Chiêm_Thành , không phải vì An_Nam'
#               ids[:8]=[0, 556, 406, 48749, 237, 1236, 25190, 829] | total_tokens=142
#       [TOKEN] id=019e40f6… | raw[0:60]='Chúng liền chia quân làm sâu mũi tân công cửa ái này. Trước'
#               seg[0:60]='Chúng liền chia_quân làm sâu mũi tân_công cửa_ái này . Trước'
#               ids[:8]=[0, 2460, 1228, 21159, 829, 47, 808, 1898] | total_tokens=119
#       [TOKEN] id=019e40f6… | raw[0:60]='đem về cho vua Trần đòi vua Trần lui quân mở đường cho quân'
#               seg[0:60]='đem về cho vua Trần_đòi_vua Trần_lui_quân mở_đường cho quân_'
#               ids[:8]=[0, 873, 28, 13, 1692, 45408, 11350, 35500] | total_tokens=142
#       [TOKEN] id=019e40f6… | raw[0:60]='thấy người nào cũng thích hai chữ “Sát Thát” bằng mực và cá'
#               seg[0:60]='thấy người nào cũng thích hai chữ “ Sát_Thát ” bằng mực và c'
#               ids[:8]=[0, 108, 18, 142, 32, 543, 82, 1196] | total_tokens=148
#       [TOKEN] id=019e40f6… | raw[0:60]='Trong khi đó, quân đội nhà Trần lại phải lo đối phó với cán'
#               seg[0:60]='Trong khi đó , quân_đội nhà Trần_lại phải lo đối_phó với cán'
#               ids[:8]=[0, 92, 26, 37, 4, 830, 69, 1359] | total_tokens=116
#       [TOKEN] id=019e40f6… | raw[0:60]='em út của vua Trần Thánh Tông gả cho Thoát Hoan, “là có ý l'
#               seg[0:60]='em_út của vua Trần_Thánh_Tông_gả cho Thoát Hoan , “ là có ý'
#               ids[:8]=[0, 21817, 7, 1692, 1359, 8981, 14044, 18251] | total_tokens=154
#       [TOKEN] id=019e40f6… | raw[0:60]='Có thể thấy rõ rằng, triều đình nhà Trần trong quan hệ bangg'
#               seg[0:60]='Có_thể thấy rõ rằng , triều_đình nhà Trần_trong quan_hệ bang'
#               ids[:8]=[0, 1576, 108, 297, 87, 4, 8666, 69] | total_tokens=132
#       [TOKEN] id=019e40f6… | raw[0:60]='nhân dân Đại Việt: “Hễ tờ chiếu thư này tới nơi ngày nào, th'
#               seg[0:60]='nhân_dân Đại_Việt : “ Hễ_tờ chiếu_thư này tới nơi ngày nào ,'
#               ids[:8]=[0, 603, 12208, 27, 556, 1125, 31992, 4628] | total_tokens=33
# Đang đẩy 16 points lên Qdrant Cloud...
#  Đã lưu dữ liệu thành công lên Qdrant Cloud!
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW  101/152 | pages=[507, 508, 509, 510, 511, 512] | chars=7,774
#       [STRUCT] 14 structural boundaries | book='Vương Triều Trần (1226-1400)'
#     [MINI-CHUNK] window chars=7,774 → 72 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
#  {"split_after_indices":[3,7,11,15,18,21,25,28,31,34,38,41,46,49,53,56,59,62,65,69]}
#
#
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=72 → splits=[3, 7, 11, 15, 18, 21, 25, 28, 31, 34, 38, 41, 45, 46, 49, 53, 56, 59, 62, 65, 69]
# llm trả về
#  [3, 7, 11, 15, 18, 21, 25, 28, 31, 34, 38, 41, 45, 46, 49, 53, 56, 59, 62, 65, 69]
#
#
#
#     [MERGE] 72 mini-chunks + 21 splits → 22 semantic groups
#       [TOKEN] id=019e40f6… | raw[0:60]='1. [2]. [3]. Trong thời gian từ sau cuộc bháng chiến lồn thứ'
#               seg[0:60]='1 . . . Trong thời_gian từ sau cuộc bháng_chiến_lồn thứ hai'
#               ids[:8]=[0, 99, 5, 5, 5, 92, 130, 39] | total_tokens=112
#       [TOKEN] id=019e40f6… | raw[0:60]='liền gấp rút mở một cuộc chiến tranh tiếp theo đánh vào Đại'
#               seg[0:60]='liền gấp_rút mở một cuộc chiến_tranh tiếp_theo đánh vào Đại_'
#               ids[:8]=[0, 1228, 8516, 548, 16, 110, 1536, 1512] | total_tokens=125
#       [TOKEN] id=019e40f6… | raw[0:60]='Năm 1286, việc chuẩn bị lực lượng xâm lược Đại Việt càng đư'
#               seg[0:60]='Năm 1286 , việc chuẩn_bị lực_lượng xâm_lược Đại_Việt càng đư'
#               ids[:8]=[0, 434, 2789, 4799, 4, 49, 546, 340] | total_tokens=109
#       [TOKEN] id=019e40f6… | raw[0:60]='Và, để từng bước thu phục nhân dân Đại Việt, Hốt Tất Liệt đ'
#               seg[0:60]='Và , để từng bước thu_phục nhân_dân Đại_Việt , Hốt Tất_Liệt'
#               ids[:8]=[0, 581, 4, 24, 150, 499, 31086, 603] | total_tokens=103
#       [TOKEN] id=019e40f6… | raw[0:60]='Tháng 2 năm Bính Tuất (25-2 đến 25-3-1286), Khaxa Khaya sang'
#               seg[0:60]='Tháng 2 năm Bính_Tuất ( 25-2 đến 25-3-1286 ) , Khaxa_Khaya s'
#               ids[:8]=[0, 1641, 76, 29, 31504, 12190, 20, 50955] | total_tokens=104
#       [TOKEN] id=019e40f6… | raw[0:60]='Triều đình Đại Việt cũng cử sứ đoàn sang Nguyên tiến cống sả'
#               seg[0:60]='Triều_đình Đại_Việt cũng cử sứ_đoàn sang Nguyên_tiến cống sả'
#               ids[:8]=[0, 43371, 12208, 32, 2370, 58442, 639, 295] | total_tokens=93
#       [TOKEN] id=019e40f6… | raw[0:60]='1. [2]. [4]. Từ sau bhóáng chiến lần thứ bq đến khi nhà Nguy'
#               seg[0:60]='1 . . . Từ sau bhóáng_chiến lần thứ bq đến khi nhà_Nguyên sụ'
#               ids[:8]=[0, 99, 5, 5, 5, 404, 53, 1388] | total_tokens=127
#       [TOKEN] id=019e40f6… | raw[0:60]='Mặc dù con số nêu trên không giống nhau nhưng phần nào đó t'
#               seg[0:60]='Mặc_dù con_số nêu trên không giống nhau nhưng phần_nào đó th'
#               ids[:8]=[0, 1022, 1356, 801, 34, 17, 475, 138] | total_tokens=84
#       [TOKEN] id=019e40f6… | raw[0:60]='Về phía Đại Việt, sau kháng chiến chống quân Nguyên lần thứ'
#               seg[0:60]='Về phía Đại_Việt , sau kháng_chiến chống quân_Nguyên lần thứ'
#               ids[:8]=[0, 674, 216, 12208, 4, 53, 4873, 335] | total_tokens=118
#       [TOKEN] id=019e40f6… | raw[0:60]='Nhà Trần ba lần chiến thắng quân xâm lược Mông - Nguyên nhưn'
#               seg[0:60]='Nhà Trần_ba lần chiến_thắng quân xâm_lược Mông - Nguyên nhưn'
#               ids[:8]=[0, 1706, 1359, 346, 101, 812, 829, 6717] | total_tokens=96
#       [TOKEN] id=019e40f6… | raw[0:60]='Trong bức thư của vua Trần Nhân Tông gửi Hốt Tất Liệt năm 1'
#               seg[0:60]='Trong bức thư của vua Trần_Nhân_Tông gửi Hốt Tất_Liệt năm 12'
#               ids[:8]=[0, 92, 711, 1734, 7, 1692, 18754, 409] | total_tokens=127
#       [TOKEN] id=019e40f6… | raw[0:60]='Nhà Nguyên cũng giữ mối hòa hảo với Đại Việt nên năm sau (nă'
#               seg[0:60]='Nhà_Nguyên cũng giữ mối hòa_hảo với Đại_Việt nên năm sau ( n'
#               ids[:8]=[0, 7029, 1759, 32, 300, 579, 59763, 19798] | total_tokens=110
#       [TOKEN] id=019e40f6… | raw[0:60]='Lê Tắc cũng chép nội dung tương tự: “Năm Chí Nguyên thứ 26'
#               seg[0:60]='Lê_Tắc cũng chép nội_dung tương_tự : “ Năm_Chí_Nguyên thứ 26'
#               ids[:8]=[0, 1475, 27530, 32, 8492, 513, 1319, 27] | total_tokens=134
#       [TOKEN] id=019e40f6… | raw[0:60]='Trong quan hệ giữa Đại Việt và nhà Nguyên, tác giả cho rằng'
#               seg[0:60]='Trong quan_hệ giữa Đại_Việt và nhà_Nguyên , tác_giả cho rằng'
#               ids[:8]=[0, 92, 424, 147, 12208, 6, 9096, 1759] | total_tokens=49
#       [TOKEN] id=019e40f6… | raw[0:60]='Tác giả thống kê số lần Đại Việt triều cống triều Nguyên là'
#               seg[0:60]='Tác_giả thống_kê số lần Đại_Việt triều cống triều_Nguyên là'
#               ids[:8]=[0, 7774, 1799, 100, 101, 12208, 5228, 4099] | total_tokens=177
#       [TOKEN] id=019e40f6… | raw[0:60]='“Mùa Thu, tháng 8, sai Ngô Đình Giới sang cáo phó với nước N'
#               seg[0:60]='“ Mùa_Thu , tháng 8 , sai Ngô_Đình_Giới sang cáo_phó với nướ'
#               ids[:8]=[0, 556, 15882, 2886, 4, 78, 358, 4] | total_tokens=122
#       [TOKEN] id=019e40f6… | raw[0:60]='“Tân Mão (năm 1291), nhà Nguyên sai Lễ bộ Thượng thư Trương'
#               seg[0:60]='“ Tân_Mão ( năm 1291 ) , nhà_Nguyên sai Lễ_bộ Thượng_thư Trư'
#               ids[:8]=[0, 556, 27079, 20, 29, 2789, 5588, 19] | total_tokens=111
#       [TOKEN] id=019e40f6… | raw[0:60]='Phái đoàn trên một nghìn người khởi hành từ Trung Quốc vào'
#               seg[0:60]='Phái_đoàn trên một nghìn người khởi_hành từ Trung_Quốc vào t'
#               ids[:8]=[0, 19380, 34, 16, 824, 18, 7935, 39] | total_tokens=111
#       [TOKEN] id=019e40f6… | raw[0:60]='Vua chối từ vì đương có bệnh, sai Đào Tử Kỳ đem san vật địa'
#               seg[0:60]='Vua chối_từ vì đương có bệnh , sai Đào_Tử_Kỳ đem san_vật địa'
#               ids[:8]=[0, 6933, 34064, 90, 24253, 10, 326, 4] | total_tokens=111
#       [TOKEN] id=019e40f6… | raw[0:60]=', Trong lời tấu của vua Trần Nhân Tông ngày 4-3-1293, nhà vu'
#               seg[0:60]=', Trong lời tấu của vua Trần_Nhân_Tông ngày 4-3-1293 , nhà_v'
#               ids[:8]=[0, 4, 92, 278, 19927, 7, 1692, 18754] | total_tokens=74
#       [TOKEN] id=019e40f6… | raw[0:60]='Trong ngày 14 tháng 2 năm nay thấy thiện sứ là quan Lại bộ'
#               seg[0:60]='Trong ngày 14 tháng 2 năm nay thấy thiện_sứ là quan_Lại_bộ T'
#               ids[:8]=[0, 92, 43, 948, 78, 76, 29, 136] | total_tokens=168
#       [TOKEN] id=019e40f6… | raw[0:60]='“Năm thứ 9 (năm 1293), (ngang với năm Chí Nguyên thứ 30 nhà'
#               seg[0:60]='“ Năm thứ 9 ( năm 1293 ) , ( ngang với năm Chí_Nguyên thứ 30'
#               ids[:8]=[0, 556, 434, 129, 426, 20, 29, 2789] | total_tokens=49
# Đang đẩy 22 points lên Qdrant Cloud...
#  Đã lưu dữ liệu thành công lên Qdrant Cloud!
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW  102/152 | pages=[512, 513, 514, 515, 516, 517] | chars=7,133
#       [STRUCT] 8 structural boundaries | book='Vương Triều Trần (1226-1400)'
#     [MINI-CHUNK] window chars=7,133 → 65 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
#  {"split_after_indices":[3,7,9,13,17,21,25,29,35,39,43,47,51,55,59,63]}
#
#
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=65 → splits=[3, 7, 9, 13, 17, 21, 25, 29, 33, 35, 39, 43, 47, 51, 55, 59, 63]
# llm trả về
#  [3, 7, 9, 13, 17, 21, 25, 29, 33, 35, 39, 43, 47, 51, 55, 59, 63]
#
#
#
#     [MERGE] 65 mini-chunks + 17 splits → 18 semantic groups
#       [TOKEN] id=019e40f6… | raw[0:60]='Như trên đã trình bày, mặc dù đã thua tới ba lần nhưng nhà N'
#               seg[0:60]='Như trên đã trình_bày , mặc_dù đã thua tới ba lần nhưng nhà_'
#               ids[:8]=[0, 1617, 34, 14, 2977, 4, 1695, 14] | total_tokens=138
#       [TOKEN] id=019e40f6… | raw[0:60]='qua đóng đồn tại đất Việt, để chờ qua năm là năm Giáp Ngọ ('
#               seg[0:60]='qua đóng đồn tại đất Việt , để chờ qua năm là năm Giáp_Ngọ ('
#               ids[:8]=[0, 89, 580, 3537, 35, 179, 350, 4] | total_tokens=132
#       [TOKEN] id=019e40f6… | raw[0:60]='chỉ. Lúc đó, Thế tử đã mất từ mấy năm, nên con vua suất các'
#               seg[0:60]='chỉ . Lúc đó , Thế_tử đã mất từ mấy năm , nên con vua_suất c'
#               ids[:8]=[0, 66, 5, 1254, 37, 4, 1827, 29272] | total_tokens=103
#       [TOKEN] id=019e40f6… | raw[0:60]='Khi Trần Anh Tông lên ngôi (1293 - 1314), nhà Nguyên sai sứ'
#               seg[0:60]='Khi Trần_Anh_Tông lên_ngôi ( 1293 - 1314 ) , nhà_Nguyên sai'
#               ids[:8]=[0, 251, 19402, 6483, 4773, 20, 2789, 5622] | total_tokens=118
#       [TOKEN] id=019e40f6… | raw[0:60]='nhà Nguyên sai Thị lang Lý Diễn và Lang trung Tiêu Thái Đăn'
#               seg[0:60]='nhà Nguyên sai_Thị_lang_Lý_Diễn và Lang_trung_Tiêu Thái_Đăng'
#               ids[:8]=[0, 69, 1759, 33772, 33844, 6115, 7062, 2878] | total_tokens=125
#       [TOKEN] id=019e40f6… | raw[0:60]='Phan Huy Chú trong Lịch triều hiệển chương loại chí đã thốn'
#               seg[0:60]='Phan_Huy_Chú trong Lịch triều hiệển_chương loại chí đã thống'
#               ids[:8]=[0, 48677, 12, 5947, 5228, 23164, 57367, 5887] | total_tokens=143
#       [TOKEN] id=019e40f6… | raw[0:60]='sứ nhà Nguyên là Thượng thư An Lỗ Ủy sang báo việc lên ngôi'
#               seg[0:60]='sứ nhà_Nguyên là Thượng_thư An_Lỗ Ủy sang báo việc lên_ngôi'
#               ids[:8]=[0, 4986, 9096, 1759, 8, 31602, 3187, 19010] | total_tokens=142
#       [TOKEN] id=019e40f6… | raw[0:60]='”3, Nhờ tài văn chương và tài ngoại giao, Mạc Đĩnh Chị thân'
#               seg[0:60]='” 3 , Nhờ tài_văn_chương và tài_ngoại_giao , Mạc_Đĩnh Chị th'
#               ids[:8]=[0, 564, 107, 4, 2397, 20995, 8352, 6] | total_tokens=136
#       [TOKEN] id=019e40f6… | raw[0:60]='“Năm thứ 22 (năm 1313), vua nhường ngôi, sai Nguyễn TrungNgạ'
#               seg[0:60]='“ Năm thứ 22 ( năm 1313 ) , vua nhường_ngôi , sai Nguyễn_Tru'
#               ids[:8]=[0, 556, 434, 129, 1443, 20, 29, 3214] | total_tokens=180
#       [TOKEN] id=019e40f6… | raw[0:60]='Sau này, sứ ta sang [Nguyên], có người hỏi rằng: “Tôi nghe'
#               seg[0:60]='Sau_này , sứ ta sang [_Nguyên_] , có người hỏi rằng : “ Tôi'
#               ids[:8]=[0, 5933, 4, 4986, 237, 295, 63576, 1751] | total_tokens=86
#       [TOKEN] id=019e40f6… | raw[0:60]='Trong thời trị vì vua Trần Minh Tông, quan hệ ngoại giao giữ'
#               seg[0:60]='Trong thời_trị_vì vua Trần_Minh_Tông , quan_hệ ngoại_giao gi'
#               ids[:8]=[0, 92, 57774, 15446, 22549, 90, 1692, 10830] | total_tokens=113
#       [TOKEN] id=019e40f6… | raw[0:60]='Có lần sứ nhà Nguyên sang Đại Việt báo việc lên ngôi nhưng'
#               seg[0:60]='Có lần sứ nhà_Nguyên sang Đại_Việt báo việc lên_ngôi nhưng t'
#               ids[:8]=[0, 503, 101, 4986, 9096, 1759, 295, 12208] | total_tokens=145
#       [TOKEN] id=019e40f6… | raw[0:60]='lại dụ nhà vua không nên cho các quan lại ở biên giới sang'
#               seg[0:60]='lại dụ nhà_vua không nên cho các quan_lại ở biên_giới sang x'
#               ids[:8]=[0, 44, 11536, 9084, 17, 77, 13, 9] | total_tokens=111
#       [TOKEN] id=019e40f6… | raw[0:60]='Mùa Hạ, tháng 4, vua Nguyên sai Mã Hợp Mưu, Dương Tôn Thụy'
#               seg[0:60]='Mùa_Hạ , tháng 4 , vua Nguyên_sai Mã_Hợp_Mưu , Dương_Tôn_Thụ'
#               ids[:8]=[0, 15882, 5392, 4, 78, 163, 4, 1692] | total_tokens=146
#       [TOKEN] id=019e40f6… | raw[0:60]='Sách Cương mục, Đại Việt sử bý tiền biên đã bổ sung thêm ch'
#               seg[0:60]='Sách Cương_mục , Đại_Việt sử_bý tiền_biên đã bổ_sung thêm ch'
#               ids[:8]=[0, 6042, 28763, 4089, 4, 12208, 32841, 40806] | total_tokens=150
#       [TOKEN] id=019e40f6… | raw[0:60]='Và, tiếng tăm của lần đi sứ lần trước đã khiến cho chuyến đ'
#               seg[0:60]='Và , tiếng_tăm của lần đi sứ lần trước đã khiến cho chuyến đ'
#               ids[:8]=[0, 581, 4, 15955, 7, 101, 57, 4986] | total_tokens=121
#       [TOKEN] id=019e40f6… | raw[0:60]='nội dung bang giao giữa hai nước chủ yếu là những thông báo'
#               seg[0:60]='nội_dung bang giao giữa hai nước chủ_yếu là những thông_báo'
#               ids[:8]=[0, 513, 1400, 574, 147, 82, 58, 825] | total_tokens=140
#       [TOKEN] id=019e40f6… | raw[0:60]='Nhà Nguyên sai Lại bộ Thượng thư là Tán Chỉ Ngõa sang báo v'
#               seg[0:60]='Nhà Nguyên_sai Lại_bộ Thượng_thư là Tán_Chỉ Ngõa sang báo vi'
#               ids[:8]=[0, 1706, 7299, 1069, 11378, 215, 31602, 8] | total_tokens=29
# Đang đẩy 18 points lên Qdrant Cloud...
#  Đã lưu dữ liệu thành công lên Qdrant Cloud!
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW  103/152 | pages=[517, 518, 519, 520, 521, 522] | chars=7,881
#       [STRUCT] 20 structural boundaries | book='Vương Triều Trần (1226-1400)'
#     [MINI-CHUNK] window chars=7,881 → 75 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
#  {"split_after_indices":[3,7,11,15,18,22,26,30,33,37,41,45,49,52,56,62,65,68,71]}
#
#
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=75 → splits=[3, 7, 11, 15, 18, 22, 26, 30, 33, 37, 41, 45, 49, 52, 56, 60, 62, 65, 68, 71]
# llm trả về
#  [3, 7, 11, 15, 18, 22, 26, 30, 33, 37, 41, 45, 49, 52, 56, 60, 62, 65, 68, 71]
#
#
#
#     [MERGE] 75 mini-chunks + 20 splits → 21 semantic groups
#       [TOKEN] id=019e40f6… | raw[0:60]='Năm 1345, Đại Việt sử bý toàn thư chép sự kiện sứ nhà Nguyên'
#               seg[0:60]='Năm 1345 , Đại_Việt sử_bý toàn thư_chép sự_kiện sứ nhà_Nguyê'
#               ids[:8]=[0, 434, 3214, 1853, 4, 12208, 32841, 40806] | total_tokens=150
#       [TOKEN] id=019e40f6… | raw[0:60]='Năm 1350, Từ Thọ Huy dấy quân tự xưng hoàng đế, nước Nguyên'
#               seg[0:60]='Năm 1350 , Từ_Thọ Huy_dấy quân tự_xưng hoàng_đế , nước Nguyê'
#               ids[:8]=[0, 434, 3214, 821, 4, 13997, 4537, 12076] | total_tokens=108
#       [TOKEN] id=019e40f6… | raw[0:60]='thám thính Đại Việt như trước.\nNăm 1355, Chu Nguyên Chương'
#               seg[0:60]='thám_thính Đại_Việt như trước . Năm 1355 , Chu_Nguyên_Chương'
#               ids[:8]=[0, 25479, 57044, 12208, 42, 71, 5, 434] | total_tokens=123
#       [TOKEN] id=019e40f6… | raw[0:60]='Mùa Xuân, tháng Gêng, nhà Minh sai sứ sang thông hiếu. Bấy'
#               seg[0:60]='Mùa_Xuân , tháng Gêng , nhà_Minh sai sứ sang thông_hiếu . Bấ'
#               ids[:8]=[0, 45190, 4, 78, 1276, 55140, 4, 9096] | total_tokens=128
#       [TOKEN] id=019e40f6… | raw[0:60]='Nhưng cuộc chiến của Minh Thái Tổ với Trần Hữu Lượng vẫn chư'
#               seg[0:60]='Nhưng cuộc_chiến của Minh_Thái_Tổ với Trần_Hữu_Lượng vẫn chư'
#               ids[:8]=[0, 293, 2061, 7, 2775, 40903, 15, 12764] | total_tokens=91
#       [TOKEN] id=019e40f6… | raw[0:60]='Năm 1367, nhà Nguyên sụp đổ. Mối quan hệ giữa Đại Việt với đ'
#               seg[0:60]='Năm 1367 , nhà_Nguyên sụp_đổ . Mối quan_hệ giữa Đại_Việt với'
#               ids[:8]=[0, 434, 3214, 4151, 4, 9096, 1759, 5504] | total_tokens=136
#       [TOKEN] id=019e40f6… | raw[0:60]='1. [3]. Quan hệ uới rnha Mzrh (1368 - 1400) Nhà Minh cai trị'
#               seg[0:60]='1 . . Quan_hệ uới rnha Mzrh ( 1368 - 1400 ) Nhà_Minh cai_trị'
#               ids[:8]=[0, 99, 5, 5, 6833, 1881, 14269, 1698] | total_tokens=191
#       [TOKEN] id=019e40f6… | raw[0:60]='Năm 1368, sau khi lên ngôi hoàng đế ở Kim Lăng, cũng như các'
#               seg[0:60]='Năm 1368 , sau khi lên_ngôi hoàng_đế ở Kim_Lăng , cũng như c'
#               ids[:8]=[0, 434, 3214, 4277, 4, 53, 26, 4773] | total_tokens=129
#       [TOKEN] id=019e40f6… | raw[0:60]='Phan Huy Chú cũng chép với nội dung tương tự: “Năm thứ 2 (1'
#               seg[0:60]='Phan_Huy_Chú cũng chép với nội_dung tương_tự : “ Năm thứ 2 ('
#               ids[:8]=[0, 48677, 32, 8492, 15, 513, 1319, 27] | total_tokens=91
#       [TOKEN] id=019e40f6… | raw[0:60]='Năm 1369, ngày 20 tháng 6 Âm lịch (23-7-1369), Minh thực lục'
#               seg[0:60]='Năm 1369 , ngày 20 tháng 6 Âm_lịch ( 23-7-1369 ) , Minh_thực'
#               ids[:8]=[0, 434, 3214, 4800, 4, 43, 431, 78] | total_tokens=142
#       [TOKEN] id=019e40f6… | raw[0:60]='Viên phó Nguyễn Huân cùng tuỳ tòng 23 người thưởng có sai b'
#               seg[0:60]='Viên phó Nguyễn_Huân cùng tùy tòng 23 người thưởng có sai_bi'
#               ids[:8]=[0, 4364, 2185, 1035, 9043, 81, 32463, 1231] | total_tokens=107
#       [TOKEN] id=019e40f6… | raw[0:60]='Vua quan nhà Minh đã nhắc đi nhắc lại sự kiện này trong Min'
#               seg[0:60]='Vua quan nhà_Minh đã nhắc_đi_nhắc_lại sự_kiện này trong Minh'
#               ids[:8]=[0, 6933, 2665, 9096, 1612, 14, 33203, 776] | total_tokens=105
#       [TOKEN] id=019e40f6… | raw[0:60]='Ngày 30-12-1369 (Dương lịch) nhà Minh sai Biên tu viện Hàn l'
#               seg[0:60]='Ngày 30-12-1369 ( Dương_lịch ) nhà_Minh sai_Biên tu_viện_Hàn'
#               ids[:8]=[0, 319, 7637, 8232, 3214, 4800, 20, 47894] | total_tokens=130
# ...
#       [TOKEN] id=019e4105… | raw[0:60]='Ngay cả đối với dòng họ tông thất, nếu như một khi người đó'
#               seg[0:60]='Ngay cả đối_với dòng_họ tông_thất , nếu_như một_khi người đó'
#               ids[:8]=[0, 869, 94, 190, 7085, 1187, 34241, 11494] | total_tokens=46
#       [TOKEN] id=019e4105… | raw[0:60]='tính chất quý tộc của dòng họ cũng bị mất đi (thí dụ như Tr'
#               seg[0:60]='tính_chất quý_tộc của dòng_họ cũng bị mất đi ( thí_dụ như Tr'
#               ids[:8]=[0, 2836, 11429, 7, 7085, 32, 45, 274] | total_tokens=100
#       [TOKEN] id=019e4105… | raw[0:60]='luôn luôn được bổ sung và đổi mới.'
#               seg[0:60]='luôn_luôn được bổ_sung và đổi_mới . Thứ hai , quan_liêu thời'
#               ids[:8]=[0, 5757, 11, 818, 6, 1446, 5, 1835] | total_tokens=33
#       [TOKEN] id=019e4105… | raw[0:60]='Thứ hai, quan liêu thời Lý Trần cũng không phải là những lãn'
#               seg[0:60]='Thứ hai , quan_liêu thời Lý_Trần cũng không phải là những lã'
#               ids[:8]=[0, 1835, 82, 4, 17614, 790, 2878, 3212] | total_tokens=145
#       [TOKEN] id=019e4105… | raw[0:60]='sau £Ð [7]khi đi đánh Chiêm Thành về (1044) mới được ban th'
#               seg[0:60]='sau £_Đ khi đi đánh Chiêm_Thành về ( 1044 ) mới được ban thư'
#               ids[:8]=[0, 53, 59857, 1751, 6150, 26, 57, 480] | total_tokens=50
#       [TOKEN] id=019e4105… | raw[0:60]='Mặt khác, trong khuôn khổ một nhà nước phong kiến tập quyền'
#               seg[0:60]='Mặt_khác , trong khuôn_khổ một nhà_nước phong_kiến tập_quyền'
#               ids[:8]=[0, 3887, 4, 12, 2702, 16, 816, 12222] | total_tokens=111
#       [TOKEN] id=019e4105… | raw[0:60]='hưởng tô hoặc huy động lao dịch trên một mức độ nhất định,'
#               seg[0:60]='hưởng tô hoặc huy_động lao dịch trên một mức_độ nhất_định ,'
#               ids[:8]=[0, 1315, 5281, 151, 1509, 1750, 1626, 34] | total_tokens=53
#       [TOKEN] id=019e4105… | raw[0:60]='Sử chép trong nhiều trường hợp, nhà vua đã có thể lấy ruộng'
#               seg[0:60]='Sử_chép trong nhiều trường_hợp , nhà_vua đã có_thể lấy ruộng'
#               ids[:8]=[0, 24679, 8781, 2150, 12, 36, 420, 4] | total_tokens=116
#       [TOKEN] id=019e4105… | raw[0:60]='Thời cuối Trần, khi hình thức điền trang phát triển, xâm ph'
#               seg[0:60]='Thời cuối Trần , khi hình_thức điền_trang phát_triển , xâm_p'
#               ids[:8]=[0, 4834, 352, 3212, 4, 26, 937, 54058] | total_tokens=60
#       [TOKEN] id=019e4105… | raw[0:60]='Vì không phải là một tầng lớp lãnh chúa thái ấp, nên đẳng c'
#               seg[0:60]='Vì không phải là một tầng_lớp lãnh_chúa thái_ấp , nên đẳng_c'
#               ids[:8]=[0, 1023, 17, 41, 8, 16, 5017, 39110] | total_tokens=104
#       [TOKEN] id=019e4105… | raw[0:60]='Một phần khác thì sử dụng vào các lợi ích công cộng của nhà'
#               seg[0:60]='Một phần khác thì sử_dụng vào các lợi_ích công_cộng của nhà_'
#               ids[:8]=[0, 242, 230, 85, 54, 117, 33, 9] | total_tokens=34
#       [TOKEN] id=019e4105… | raw[0:60]='Cuối cùng, trong thời Lý Trần, bộ máy quan liêu chưa có điều'
#               seg[0:60]='Cuối_cùng , trong thời Lý_Trần , bộ_máy quan_liêu chưa có đi'
#               ids[:8]=[0, 3235, 4, 12, 790, 2878, 3212, 4] | total_tokens=20
# Đang đẩy 31 points lên Qdrant Cloud...
#  Đã lưu dữ liệu thành công lên Qdrant Cloud!
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW  151/152 | pages=[758, 759, 760, 761, 762, 763] | chars=9,620
#       [STRUCT] 21 structural boundaries | book='Vương Triều Trần (1226-1400)'
#     [MINI-CHUNK] window chars=9,620 → 92 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
#  {"split_after_indices":[3,7,11,15,19,23,27,31,35,39,43,47,51,55,59,63,67,71,75,79,83,87]}
#
#
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=92 → splits=[3, 7, 11, 15, 19, 23, 27, 31, 35, 39, 43, 47, 51, 55, 59, 63, 67, 71, 75, 79, 83, 87]
# llm trả về
#  [3, 7, 11, 15, 19, 23, 27, 31, 35, 39, 43, 47, 51, 55, 59, 63, 67, 71, 75, 79, 83, 87]
#
#
#
#     [MERGE] 92 mini-chunks + 22 splits → 23 semantic groups
#       [TOKEN] id=019e4105… | raw[0:60]='Từ khi khoa cử phát triển, quan liêu còn được tuyển chọn tro'
#               seg[0:60]='Từ khi khoa_cử phát_triển , quan_liêu còn được tuyển_chọn tr'
#               ids[:8]=[0, 404, 26, 51907, 134, 4, 17614, 50] | total_tokens=104
#       [TOKEN] id=019e4106… | raw[0:60]='ta có thể nói đó là một chế độ quan liêu tảo kỳ - thì việc'
#               seg[0:60]='ta có_thể nói đó là một chế_độ quan_liêu tảo_kỳ - thì việc s'
#               ids[:8]=[0, 237, 62, 96, 37, 8, 16, 1150] | total_tokens=105
#       [TOKEN] id=019e4106… | raw[0:60]='Tóm lại, quan liêu thời Lý Trần là bộ phận chủ yếu của đẳng'
#               seg[0:60]='Tóm_lại , quan_liêu thời Lý_Trần_là bộ_phận chủ_yếu của đẳng'
#               ids[:8]=[0, 14425, 4, 17614, 790, 2878, 1359, 8] | total_tokens=79
#       [TOKEN] id=019e4106… | raw[0:60]='Hiện tượng chiếm hữu tư nhân tập trung những tư liệu sản xu'
#               seg[0:60]='Hiện_tượng chiếm_hữu tư_nhân tập_trung những tư_liệu_sản_xuấ'
#               ids[:8]=[0, 9480, 29905, 2668, 489, 21, 53248, 20] | total_tokens=104
#       [TOKEN] id=019e4106… | raw[0:60]='+ Nông dân làng xã Nông dân làng xã là thành phần chủ thể ch'
#               seg[0:60]='+ Nông_dân làng_xã Nông_dân làng_xã là thành_phần chủ_thể ch'
#               ids[:8]=[0, 864, 6759, 26522, 6759, 26522, 8, 2093] | total_tokens=99
#       [TOKEN] id=019e4106… | raw[0:60]='Có thể coi đó là những tế bào cơ sở nuôi dưỡng cả một cơ th'
#               seg[0:60]='Có_thể coi đó là những tế_bào cơ_sở nuôi_dưỡng cả một cơ_thể'
#               ids[:8]=[0, 1576, 774, 37, 8, 21, 2520, 341] | total_tokens=96
#       [TOKEN] id=019e4106… | raw[0:60]='Đại khái, nông dân sống theo làng, quần tụ vừa theo quan hệ'
#               seg[0:60]='Đại_khái , nông_dân sống theo làng , quần_tụ vừa theo quan_h'
#               ids[:8]=[0, 2847, 23636, 4, 1457, 235, 63, 632] | total_tokens=116
#       [TOKEN] id=019e4106… | raw[0:60]='Trong làng xã, đông đảo nông dân cày cấy ruộng công (quan đi'
#               seg[0:60]='Trong làng_xã , đông_đảo nông_dân cày_cấy ruộng_công ( quan_'
#               ids[:8]=[0, 92, 26522, 4, 2760, 1457, 22533, 7483] | total_tokens=115
#       [TOKEN] id=019e4106… | raw[0:60]='Ngoài ra, họ cũng có nghĩa vụ đi lính, xung vào các đội quâ'
#               seg[0:60]='Ngoài_ra , họ cũng có nghĩa_vụ đi lính , xung vào các đội qu'
#               ids[:8]=[0, 492, 4, 86, 32, 10, 3145, 57] | total_tokens=123
#       [TOKEN] id=019e4106… | raw[0:60]='Ở từng đơn vị xã, người đại diện cho nhà nước có lẽ vẫn là'
#               seg[0:60]='Ở từng đơn_vị xã , người đại_diện cho nhà_nước có_lẽ vẫn là'
#               ids[:8]=[0, 635, 150, 304, 176, 4, 18, 554] | total_tokens=119
#       [TOKEN] id=019e4106… | raw[0:60]='Việt điện u linh có nói đến vai trò của các phụ lão thôn ƠC'
#               seg[0:60]='Việt điện u_linh có nói đến vai_trò của các phụ_lão thôn ƠCổ'
#               ids[:8]=[0, 350, 462, 13472, 7274, 10, 96, 30] | total_tokens=125
#       [TOKEN] id=019e4106… | raw[0:60]='Sự kiện có ý nghĩa nhất là việc Trần Nhân Tông mời bô lão c'
#               seg[0:60]='Sự_kiện có ý_nghĩa nhất_là việc Trần_Nhân_Tông mời bô_lão cá'
#               ids[:8]=[0, 5812, 10, 1242, 823, 49, 18754, 844] | total_tokens=91
#       [TOKEN] id=019e4106… | raw[0:60]='tồn tại song song bên cạnh một quyền lực hành chính của nhà'
#               seg[0:60]='tồn_tại song_song bên cạnh một quyền_lực hành_chính của nhà_'
#               ids[:8]=[0, 1285, 5949, 145, 362, 16, 2598, 950] | total_tokens=97
#       [TOKEN] id=019e4106… | raw[0:60]='3, họ đã cần cù lao động sản xuất rồi đi chùa lễ Phật trong'
#               seg[0:60]='3 , họ đã cần_cù_lao_động sản_xuất rồi đi chùa lễ_Phật trong'
#               ids[:8]=[0, 107, 4, 86, 14, 35671, 1395, 46444] | total_tokens=150
#       [TOKEN] id=019e4106… | raw[0:60]='Suốt cả thời kỳ chống Nguyên, nông dân các làng xã đều một'
#               seg[0:60]='Suốt cả thời_kỳ chống Nguyên , nông_dân các làng_xã đều một_'
#               ids[:8]=[0, 5720, 94, 2055, 335, 1759, 4, 1457] | total_tokens=105
#       [TOKEN] id=019e4106… | raw[0:60]='người nông dân Việt Nam thời Lý Trần về căn bản là những nô'
#               seg[0:60]='người nông_dân Việt_Nam thời Lý_Trần_về căn_bản là những nôn'
#               ids[:8]=[0, 18, 1457, 56, 790, 2878, 1359, 28] | total_tokens=99
#       [TOKEN] id=019e4106… | raw[0:60]='và nhất là tệ kiêm tính ruộng đất chưa đến mức độ lấn át để'
#               seg[0:60]='và nhất_là tệ kiêm tính ruộng_đất chưa đến mức_độ lấn_át để'
#               ids[:8]=[0, 6, 823, 4152, 2854, 294, 16936, 102] | total_tokens=98
#       [TOKEN] id=019e4106… | raw[0:60]='Trong lúc này, có thể đã xuất hiện một tầng lớp địa chủ bình'
#               seg[0:60]='Trong lúc này , có_thể đã xuất_hiện một tầng_lớp địa_chủ bìn'
#               ids[:8]=[0, 92, 219, 23, 4, 62, 14, 395] | total_tokens=100
#       [TOKEN] id=019e4106… | raw[0:60]='Trong xã hội, trừ tầng lớp nô tỳ, đại đa số nông dân thời L'
#               seg[0:60]='Trong xã_hội , trừ tầng_lớp nô_tỳ , đại_đa_số nông_dân thời'
#               ids[:8]=[0, 92, 267, 4, 2415, 5017, 1301, 42270] | total_tokens=108
#       [TOKEN] id=019e4106… | raw[0:60]='Khác với người nông dân tư hữu ở phương Tây trong thời trun'
#               seg[0:60]='Khác với người nông_dân tư_hữu ở phương Tây trong thời trung'
#               ids[:8]=[0, 5550, 15, 18, 1457, 23797, 55800, 25] | total_tokens=102
#       [TOKEN] id=019e4106… | raw[0:60]='Ÿ thức về cùng chung một tổ tiên, về một xã hội quân chủ tậ'
#               seg[0:60]='Ÿ_thức về cùng chung một tổ_tiên , về một xã_hội quân_chủ tậ'
#               ids[:8]=[0, 3, 26656, 28, 81, 417, 16, 7065] | total_tokens=102
#       [TOKEN] id=019e4106… | raw[0:60]='Sự thắng lợi oanh lệt của nhân dân ta đối với quân xâm lược'
#               seg[0:60]='Sự thắng_lợi oanh_lệt của nhân_dân ta đối_với quân xâm_lược'
#               ids[:8]=[0, 1139, 3824, 61986, 1494, 19002, 7, 603] | total_tokens=95
#       [TOKEN] id=019e4106… | raw[0:60]='chúng ta hãy thử đi đến một vài nhận định tổng quát về mặt'
#               seg[0:60]='chúng_ta hãy thử đi đến một_vài nhận_định tổng_quát về mặt q'
#               ids[:8]=[0, 507, 852, 1176, 57, 30, 1909, 1170] | total_tokens=81
# Đang đẩy 23 points lên Qdrant Cloud...
#  Đã lưu dữ liệu thành công lên Qdrant Cloud!
#
# ────────────────────────────────────────────────────────────────────────
#   WINDOW  152/152 | pages=[763, 764, 765, 766] | chars=5,971
#       [STRUCT] 15 structural boundaries | book='Vương Triều Trần (1226-1400)'
#     [MINI-CHUNK] window chars=5,971 → 56 mini-chunks
#     [STEP5-SYNC] Calling LLM chain…
#     [LLM-SYNC] Trying: gemini-sync/gemini-3.1-flash-lite
# llm trả lời
#  {"split_after_indices":[3,6,9,12,15,19,22,26,29,33,38,43,47,51,55]}
#
#
#
#     [LLM-SYNC/gemini-sync/gemini-3.1-flash-lite] attempt=1 | chunks=56 → splits=[3, 6, 9, 12, 15, 19, 22, 26, 29, 33, 37, 38, 42, 43, 47, 51]
# llm trả về
#  [3, 6, 9, 12, 15, 19, 22, 26, 29, 33, 37, 38, 42, 43, 47, 51]
#
#
#
#     [MERGE] 56 mini-chunks + 16 splits → 17 semantic groups
#       [TOKEN] id=019e4106… | raw[0:60]='- Thứ nhất, đó là sự ổn định về cơ sở và thiết chế, về nền t'
#               seg[0:60]='- Thứ nhất , đó là sự ổn_định về cơ_sở và thiết_chế , về nền'
#               ids[:8]=[0, 31, 1835, 67, 4, 37, 8, 61] | total_tokens=116
#       [TOKEN] id=019e4106… | raw[0:60]='do nhà nước chỉ đạo và quản lý. Sự tập trung về kinh tế và'
#               seg[0:60]='do nhà_nước chỉ_đạo và quản_lý . Sự tập_trung về kinh_tế và'
#               ids[:8]=[0, 91, 816, 562, 6, 260, 5, 1139] | total_tokens=103
#       [TOKEN] id=019e4106… | raw[0:60]='- Thứ hai, đó là sự ổn định trong cấu trúc nội tại của hệ th'
#               seg[0:60]='- Thứ hai , đó là sự ổn_định trong cấu_trúc nội_tại của hệ_t'
#               ids[:8]=[0, 31, 1835, 82, 4, 37, 8, 61] | total_tokens=78
#       [TOKEN] id=019e4106… | raw[0:60]='- Thứ ba, đó là sự ổn định trong cấu trúc nội tại của những'
#               seg[0:60]='- Thứ ba , đó là sự ổn_định trong cấu_trúc nội_tại của những'
#               ids[:8]=[0, 31, 1835, 346, 4, 37, 8, 61] | total_tokens=84
#       [TOKEN] id=019e4106… | raw[0:60]='Lúc này, nhà nước phong kiến chưa can thiệp được một cách t'
#               seg[0:60]='Lúc này , nhà_nước phong_kiến chưa can_thiệp được một_cách t'
#               ids[:8]=[0, 1254, 23, 4, 816, 12222, 102, 2388] | total_tokens=92
#       [TOKEN] id=019e4106… | raw[0:60]='kinh tế, chính trị và xã hội với một vai trò quan trọng của'
#               seg[0:60]='kinh_tế , chính_trị và xã_hội với một vai_trò quan_trọng của'
#               ids[:8]=[0, 233, 4, 837, 6, 267, 15, 16] | total_tokens=107
#       [TOKEN] id=019e4106… | raw[0:60]='{£ö [4]Thời Lý, nhà vua đã sai đặt chuông ở 2 bên thầm Long'
#               seg[0:60]='{ £_ö Thời_Lý , nhà_vua đã sai đặt chuông ở 2 bên thầm Long_'
#               ids[:8]=[0, 33398, 59857, 1751, 58587, 10941, 3272, 4] | total_tokens=85
#       [TOKEN] id=019e4106… | raw[0:60]='Tóm lại, sự cân bằng ổn định trong kết cấu đẳng cấp của thiế'
#               seg[0:60]='Tóm_lại , sự cân_bằng ổn_định trong kết_cấu đẳng_cấp của thi'
#               ids[:8]=[0, 14425, 4, 61, 2591, 726, 12, 5706] | total_tokens=94
#       [TOKEN] id=019e4106… | raw[0:60]='Chính một kết cấu đắng cấp của thiết chế chính trị - xã hội'
#               seg[0:60]='Chính một kết_cấu đắng cấp của thiết_chế chính_trị - xã_hội'
#               ids[:8]=[0, 1008, 16, 5706, 6032, 181, 7, 15576] | total_tokens=82
#       [TOKEN] id=019e4106… | raw[0:60]='Bộ máy nhà nước đó, do chức năng tập trung và vai trò tối th'
#               seg[0:60]='Bộ_máy nhà_nước đó , do chức_năng tập_trung và vai_trò tối_t'
#               ids[:8]=[0, 38432, 816, 37, 4, 91, 741, 489] | total_tokens=100
#       [TOKEN] id=019e4106… | raw[0:60]='Ở đây, có một mối liên hệ hai chiều. Nhà nước trung ương thờ'
#               seg[0:60]='Ở đây , có một mối liên_hệ hai chiều . Nhà_nước trung_ương t'
#               ids[:8]=[0, 635, 97, 4, 10, 16, 579, 2313] | total_tokens=81
#       [TOKEN] id=019e4106… | raw[0:60]='bao trùm lên cả là một quan hệ gắn bó thân thuộc, có tính c'
#               seg[0:60]='bao_trùm lên cả là một quan_hệ gắn_bó thân_thuộc , có tính_c'
#               ids[:8]=[0, 7707, 72, 94, 8, 16, 424, 2494] | total_tokens=32
#       [TOKEN] id=019e4106… | raw[0:60]='Đó chính là ý nghĩa mà Trần Hưng Đạo đã tổng hết thành một'
#               seg[0:60]='Đó chính là ý_nghĩa mà Trần_Hưng_Đạo đã tổng hết thành một n'
#               ids[:8]=[0, 669, 159, 8, 1242, 64, 8390, 14] | total_tokens=103
#       [TOKEN] id=019e4106… | raw[0:60]='nhưng những đẳng cấp này chưa phát triển đến mức thành xơ c'
#               seg[0:60]='nhưng những đẳng_cấp này chưa phát_triển đến mức thành xơ_cứ'
#               ids[:8]=[0, 51, 21, 3251, 23, 102, 134, 30] | total_tokens=35
#       [TOKEN] id=019e4106… | raw[0:60]='Tuy nhiên, sự cân bằng ổn định về mặt xã hội học của cơ chế'
#               seg[0:60]='Tuy_nhiên , sự cân_bằng ổn_định về mặt xã_hội_học của cơ_chế'
#               ids[:8]=[0, 153, 4, 61, 2591, 726, 28, 373] | total_tokens=106
#       [TOKEN] id=019e4106… | raw[0:60]='hệ thống cộng đồng làng xã hoặc mối liên hệ 2 chiều giữa 2'
#               seg[0:60]='hệ_thống cộng_đồng làng_xã hoặc mối liên_hệ 2 chiều giữa 2 h'
#               ids[:8]=[0, 252, 712, 26522, 151, 579, 2313, 76] | total_tokens=124
#       [TOKEN] id=019e4106… | raw[0:60]='dẫn đến một cuộc khủng hoáng cơ cấu, làm cho thiết chế chín'
#               seg[0:60]='dẫn đến một cuộc khủng_hoáng cơ_cấu , làm cho thiết_chế chín'
#               ids[:8]=[0, 376, 30, 16, 110, 62767, 3040, 9584] | total_tokens=82
# Đang đẩy 17 points lên Qdrant Cloud...
#  Đã lưu dữ liệu thành công lên Qdrant Cloud!
#
# ════════════════════════════════════════════════════════════════════════
#   PIPELINE COMPLETE — 'Vương Triều Trần (1226-1400)'
#   Total Qdrant points produced : 3,352
# ════════════════════════════════════════════════════════════════════════
#
# [SAVE] Writing 3,352 points → 'full_VTT_data_qdrant_points.json'…
# [SAVE] Done. 4928.1 KB written.
